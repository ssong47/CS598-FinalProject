# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.5.0-dev20201215

# %% [markdown]
# # Load Data

# %%
# Fashion MNIST has variety and is more challenging than digit MNIST. Both are small dataset, and used to verify algorithm
# Good starting point for testing and debugging code

# 60,000 training and 10,000 for evaluation

fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# # Define Class Names

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # Preprocess Data

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # Build Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# The first Dense layer has 128 nodes (or neurons). 
# The second (and last) layer returns a logits array with length of 10. 
# Each node contains a score that indicates the current image belongs to one of the 10 classes.

# %% [markdown]
# # Compile Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # Train Model

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 1s 669us/step - loss: 0.6181 - accuracy: 0.7857
# Epoch 2/10
# 1875/1875 [==============================] - 1s 627us/step - loss: 0.3798 - accuracy: 0.8631
# Epoch 3/10
# 1875/1875 [==============================] - 1s 582us/step - loss: 0.3339 - accuracy: 0.8777
# Epoch 4/10
# 1875/1875 [==============================] - 1s 586us/step - loss: 0.3142 - accuracy: 0.8853
# Epoch 5/10
# 1875/1875 [==============================] - 1s 652us/step - loss: 0.2897 - accuracy: 0.8948
# Epoch 6/10
# 1875/1875 [==============================] - 1s 593us/step - loss: 0.2798 - accuracy: 0.8954
# Epoch 7/10
# 1875/1875 [==============================] - 1s 587us/step - loss: 0.2653 - accuracy: 0.9010
# Epoch 8/10
# 1875/1875 [==============================] - 1s 579us/step - loss: 0.2554 - accuracy: 0.9049
# Epoch 9/10
# 1875/1875 [==============================] - 1s 577us/step - loss: 0.2406 - accuracy: 0.9110
# Epoch 10/10
# 1875/1875 [==============================] - 1s 582us/step - loss: 0.2376 - accuracy: 0.9119

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.3527 - accuracy: 0.8764
#
# Test accuracy: 0.8763999938964844

# %% [markdown]
# # Make Predictions using Probability

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([1.08667209e-08, 7.47347906e-10, 1.06468175e-10, 5.05767442e-11,
#        6.84730259e-11, 4.89437161e-03, 2.15929575e-07, 5.53542841e-03,
#        6.76962375e-10, 9.89569902e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# # Verify predictions

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions[i], test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Use the trained model to predict single image

# %%
# Finally, use the trained model to make a prediction about a single image.

img = test_images[1]

print(img.shape)
# Out:
# (28, 28)

# %%
# tf.keras models are optimized to make predictions on a batch, or collection. 
# Accordingly, even though you're using a single image, you need to add it to a list:
# Add the image to a batch where it's the only member.
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = probability_model.predict(img)
print(predictions_single)
# Out:
# [[1.18662165e-05 6.85506746e-14 9.99614596e-01 4.23669190e-11
#   1.61961259e-04 6.23547275e-13 2.11470920e-04 1.32912630e-17
#   1.04538112e-12 1.65696341e-13]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
print(predictions_single[0])
print(np.argmax(predictions_single[0]))
# Out:
# [1.18662165e-05 6.85506746e-14 9.99614596e-01 4.23669190e-11
#  1.61961259e-04 6.23547275e-13 2.11470920e-04 1.32912630e-17
#  1.04538112e-12 1.65696341e-13]
# 2
