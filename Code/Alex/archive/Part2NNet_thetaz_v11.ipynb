# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,25)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (14668, 60, 80, 3)

# %%
tlen = len(xtemp[0])-2 +len(xtemp[1])-2 #remove 2 samples from 24
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

# %%
plt.imshow(x_train[-2])

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,25)
date = ('11_15_2020','11_19_2020')
y_gt = {}
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])-2 +len(y_gt[1])-3 #remove 2 samples from 24 and 3 from 25
y_train = np.zeros((tlen,1))
y_train[:len(y_gt[0])-2] = y_gt[0][:len(y_gt[0])-2]
y_train[(len(y_gt[0])-2):] = y_gt[1][:len(y_gt[1])-3]

# %%
y_gt[0].shape
# Out:
# (12751, 1)

# %%
# Obtain X and Y data
# x_train.shape
# xtrainnew = pd.DataFrame(data=np.reshape(x_train, (x_train.shape[0],x_train.shape[1]*x_train.shape[2])))
# yframe = pd.DataFrame(data=y_train)

# TheData = pd.concat([xtrainnew,yframe],axis=1) #only contains video data
print(x_train.shape)
print(y_train.shape)
# Out:
# (27415, 60, 80, 3)
# (27415, 1)

# %%
print(xtemp[0].shape)
print(y_gt[0].shape)
print(xtemp[1].shape)
print(y_gt[1].shape)
# Out:
# (12751, 60, 80, 3)
# (12751, 1)
# (14668, 60, 80, 3)
# (14669, 1)

# %%
# xtmp = xtrainnew[300,:]
# plt.imshow(np.reshape(xtmp, (x_train.shape[1],x_train.shape[2])))

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
x_train.shape[1]
# Out:
# 60

# %% [markdown]
# # Regress using Neural Network

# %%
np.min(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 0.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.2
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# # model_cnn = BatchNormalization()(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# # model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=96, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Using TensorFlow backend.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 60, 80, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 80, 16)        448
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 80, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 30, 40, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 32)        4640
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 15, 20, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 20, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 20, 64)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 7, 10, 64)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 10, 96)         55392
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 10, 96)         0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 3, 5, 96)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1440)              0
# _________________________________________________________________
# activation_5 (Activation)    (None, 1440)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               184448
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 263,553
# Trainable params: 263,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True)
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 21932 samples, validate on 5483 samples
# Epoch 1/30000
#  - 4s - loss: 0.6706 - mse: 0.9561 - mae: 0.6706 - val_loss: 0.6680 - val_mse: 0.9739 - val_mae: 0.6680
# Epoch 2/30000
#  - 3s - loss: 0.6537 - mse: 0.9167 - mae: 0.6537 - val_loss: 0.6463 - val_mse: 0.9079 - val_mae: 0.6463
# Epoch 3/30000
#  - 3s - loss: 0.6383 - mse: 0.8694 - mae: 0.6383 - val_loss: 0.6296 - val_mse: 0.8690 - val_mae: 0.6296
# Epoch 4/30000
#  - 3s - loss: 0.6208 - mse: 0.8296 - mae: 0.6208 - val_loss: 0.6298 - val_mse: 0.8425 - val_mae: 0.6298
# Epoch 5/30000
#  - 3s - loss: 0.6030 - mse: 0.7897 - mae: 0.6030 - val_loss: 0.6049 - val_mse: 0.8022 - val_mae: 0.6049
# Epoch 6/30000
#  - 3s - loss: 0.5880 - mse: 0.7579 - mae: 0.5880 - val_loss: 0.5910 - val_mse: 0.7794 - val_mae: 0.5910
# Epoch 7/30000
#  - 3s - loss: 0.5706 - mse: 0.7237 - mae: 0.5706 - val_loss: 0.5708 - val_mse: 0.7427 - val_mae: 0.5708
# Epoch 8/30000
#  - 3s - loss: 0.5555 - mse: 0.6939 - mae: 0.5555 - val_loss: 0.5718 - val_mse: 0.7321 - val_mae: 0.5718
# Epoch 9/30000
#  - 3s - loss: 0.5470 - mse: 0.6790 - mae: 0.5470 - val_loss: 0.5501 - val_mse: 0.6942 - val_mae: 0.5501
# Epoch 10/30000
#  - 3s - loss: 0.5363 - mse: 0.6577 - mae: 0.5363 - val_loss: 0.5439 - val_mse: 0.6847 - val_mae: 0.5439
# Epoch 11/30000
#  - 3s - loss: 0.5259 - mse: 0.6399 - mae: 0.5259 - val_loss: 0.5288 - val_mse: 0.6618 - val_mae: 0.5288
# Epoch 12/30000
#  - 3s - loss: 0.5163 - mse: 0.6213 - mae: 0.5163 - val_loss: 0.5241 - val_mse: 0.6505 - val_mae: 0.5241
# Epoch 13/30000
#  - 3s - loss: 0.5097 - mse: 0.6101 - mae: 0.5097 - val_loss: 0.5156 - val_mse: 0.6359 - val_mae: 0.5156
# Epoch 14/30000
#  - 3s - loss: 0.5028 - mse: 0.5982 - mae: 0.5028 - val_loss: 0.5103 - val_mse: 0.6285 - val_mae: 0.5103
# Epoch 15/30000
#  - 3s - loss: 0.4966 - mse: 0.5897 - mae: 0.4966 - val_loss: 0.5026 - val_mse: 0.6097 - val_mae: 0.5026
# Epoch 16/30000
#  - 3s - loss: 0.4877 - mse: 0.5708 - mae: 0.4877 - val_loss: 0.4990 - val_mse: 0.5964 - val_mae: 0.4990
# Epoch 17/30000
#  - 3s - loss: 0.4797 - mse: 0.5575 - mae: 0.4797 - val_loss: 0.4880 - val_mse: 0.5801 - val_mae: 0.4880
# Epoch 18/30000
#  - 3s - loss: 0.4754 - mse: 0.5491 - mae: 0.4754 - val_loss: 0.4880 - val_mse: 0.5741 - val_mae: 0.4880
# Epoch 19/30000
#  - 3s - loss: 0.4704 - mse: 0.5378 - mae: 0.4704 - val_loss: 0.4850 - val_mse: 0.5695 - val_mae: 0.4850
# Epoch 20/30000
#  - 3s - loss: 0.4636 - mse: 0.5262 - mae: 0.4636 - val_loss: 0.4810 - val_mse: 0.5593 - val_mae: 0.4810
# Epoch 21/30000
#  - 3s - loss: 0.4605 - mse: 0.5193 - mae: 0.4605 - val_loss: 0.4657 - val_mse: 0.5422 - val_mae: 0.4657
# Epoch 22/30000
#  - 3s - loss: 0.4522 - mse: 0.5064 - mae: 0.4522 - val_loss: 0.4672 - val_mse: 0.5415 - val_mae: 0.4672
# Epoch 23/30000
#  - 3s - loss: 0.4461 - mse: 0.4992 - mae: 0.4461 - val_loss: 0.4616 - val_mse: 0.5331 - val_mae: 0.4616
# Epoch 24/30000
#  - 3s - loss: 0.4434 - mse: 0.4912 - mae: 0.4434 - val_loss: 0.4603 - val_mse: 0.5244 - val_mae: 0.4603
# Epoch 25/30000
#  - 3s - loss: 0.4344 - mse: 0.4791 - mae: 0.4344 - val_loss: 0.4578 - val_mse: 0.5306 - val_mae: 0.4578
# Epoch 26/30000
#  - 3s - loss: 0.4346 - mse: 0.4756 - mae: 0.4346 - val_loss: 0.4546 - val_mse: 0.5179 - val_mae: 0.4546
# Epoch 27/30000
#  - 3s - loss: 0.4257 - mse: 0.4630 - mae: 0.4257 - val_loss: 0.4481 - val_mse: 0.5083 - val_mae: 0.4481
# Epoch 28/30000
#  - 3s - loss: 0.4227 - mse: 0.4564 - mae: 0.4227 - val_loss: 0.4451 - val_mse: 0.5086 - val_mae: 0.4451
# Epoch 29/30000
#  - 3s - loss: 0.4224 - mse: 0.4545 - mae: 0.4224 - val_loss: 0.4441 - val_mse: 0.5003 - val_mae: 0.4441
# Epoch 30/30000
#  - 3s - loss: 0.4144 - mse: 0.4430 - mae: 0.4144 - val_loss: 0.4480 - val_mse: 0.5027 - val_mae: 0.4480
# Epoch 31/30000
#  - 3s - loss: 0.4133 - mse: 0.4387 - mae: 0.4133 - val_loss: 0.4355 - val_mse: 0.4859 - val_mae: 0.4355
# Epoch 32/30000
#  - 3s - loss: 0.4051 - mse: 0.4264 - mae: 0.4051 - val_loss: 0.4301 - val_mse: 0.4817 - val_mae: 0.4301
# Epoch 33/30000
#  - 3s - loss: 0.3988 - mse: 0.4187 - mae: 0.3988 - val_loss: 0.4330 - val_mse: 0.4765 - val_mae: 0.4330
# Epoch 34/30000
#  - 3s - loss: 0.3996 - mse: 0.4181 - mae: 0.3996 - val_loss: 0.4221 - val_mse: 0.4631 - val_mae: 0.4221
# Epoch 35/30000
#  - 3s - loss: 0.3922 - mse: 0.4053 - mae: 0.3922 - val_loss: 0.4251 - val_mse: 0.4624 - val_mae: 0.4251
# Epoch 36/30000
#  - 3s - loss: 0.3891 - mse: 0.3962 - mae: 0.3891 - val_loss: 0.4211 - val_mse: 0.4606 - val_mae: 0.4211
# Epoch 37/30000
#  - 3s - loss: 0.3865 - mse: 0.3934 - mae: 0.3865 - val_loss: 0.4166 - val_mse: 0.4550 - val_mae: 0.4166
# Epoch 38/30000
#  - 3s - loss: 0.3843 - mse: 0.3914 - mae: 0.3843 - val_loss: 0.4139 - val_mse: 0.4499 - val_mae: 0.4139
# Epoch 39/30000
#  - 3s - loss: 0.3794 - mse: 0.3826 - mae: 0.3794 - val_loss: 0.4108 - val_mse: 0.4487 - val_mae: 0.4108
# Epoch 40/30000
#  - 3s - loss: 0.3759 - mse: 0.3777 - mae: 0.3759 - val_loss: 0.4086 - val_mse: 0.4498 - val_mae: 0.4086
# Epoch 41/30000
#  - 3s - loss: 0.3746 - mse: 0.3735 - mae: 0.3746 - val_loss: 0.4073 - val_mse: 0.4370 - val_mae: 0.4073
# Epoch 42/30000
#  - 3s - loss: 0.3705 - mse: 0.3660 - mae: 0.3705 - val_loss: 0.4022 - val_mse: 0.4301 - val_mae: 0.4022
# Epoch 43/30000
#  - 3s - loss: 0.3642 - mse: 0.3568 - mae: 0.3642 - val_loss: 0.4050 - val_mse: 0.4334 - val_mae: 0.4050
# Epoch 44/30000
#  - 3s - loss: 0.3626 - mse: 0.3545 - mae: 0.3626 - val_loss: 0.3985 - val_mse: 0.4261 - val_mae: 0.3985
# Epoch 45/30000
#  - 3s - loss: 0.3594 - mse: 0.3489 - mae: 0.3594 - val_loss: 0.3931 - val_mse: 0.4140 - val_mae: 0.3931
# Epoch 46/30000
#  - 3s - loss: 0.3583 - mse: 0.3460 - mae: 0.3583 - val_loss: 0.3945 - val_mse: 0.4190 - val_mae: 0.3945
# Epoch 47/30000
#  - 3s - loss: 0.3538 - mse: 0.3408 - mae: 0.3538 - val_loss: 0.3844 - val_mse: 0.4001 - val_mae: 0.3844
# Epoch 48/30000
#  - 3s - loss: 0.3496 - mse: 0.3345 - mae: 0.3496 - val_loss: 0.3921 - val_mse: 0.4112 - val_mae: 0.3921
# Epoch 49/30000
#  - 3s - loss: 0.3491 - mse: 0.3332 - mae: 0.3491 - val_loss: 0.3826 - val_mse: 0.4031 - val_mae: 0.3826
# Epoch 50/30000
#  - 3s - loss: 0.3440 - mse: 0.3262 - mae: 0.3440 - val_loss: 0.3783 - val_mse: 0.3975 - val_mae: 0.3783
# Epoch 51/30000
#  - 3s - loss: 0.3420 - mse: 0.3232 - mae: 0.3420 - val_loss: 0.3810 - val_mse: 0.3950 - val_mae: 0.3810
# Epoch 52/30000
#  - 3s - loss: 0.3396 - mse: 0.3166 - mae: 0.3396 - val_loss: 0.3796 - val_mse: 0.3934 - val_mae: 0.3796
# Epoch 53/30000
#  - 3s - loss: 0.3371 - mse: 0.3152 - mae: 0.3371 - val_loss: 0.3763 - val_mse: 0.3893 - val_mae: 0.3763
# Epoch 54/30000
#  - 3s - loss: 0.3350 - mse: 0.3098 - mae: 0.3350 - val_loss: 0.3897 - val_mse: 0.4032 - val_mae: 0.3897
# Epoch 55/30000
#  - 3s - loss: 0.3338 - mse: 0.3106 - mae: 0.3338 - val_loss: 0.3807 - val_mse: 0.3921 - val_mae: 0.3807
# Epoch 56/30000
#  - 3s - loss: 0.3297 - mse: 0.3035 - mae: 0.3297 - val_loss: 0.3710 - val_mse: 0.3779 - val_mae: 0.3710
# Epoch 57/30000
#  - 3s - loss: 0.3283 - mse: 0.3029 - mae: 0.3283 - val_loss: 0.3661 - val_mse: 0.3766 - val_mae: 0.3661
# Epoch 58/30000
#  - 3s - loss: 0.3244 - mse: 0.2961 - mae: 0.3244 - val_loss: 0.3744 - val_mse: 0.3788 - val_mae: 0.3744
# Epoch 59/30000
#  - 3s - loss: 0.3254 - mse: 0.3002 - mae: 0.3254 - val_loss: 0.3686 - val_mse: 0.3766 - val_mae: 0.3686
# Epoch 60/30000
#  - 3s - loss: 0.3199 - mse: 0.2902 - mae: 0.3199 - val_loss: 0.3632 - val_mse: 0.3667 - val_mae: 0.3632
# Epoch 61/30000
#  - 3s - loss: 0.3195 - mse: 0.2894 - mae: 0.3195 - val_loss: 0.3632 - val_mse: 0.3706 - val_mae: 0.3632
# Epoch 62/30000
#  - 3s - loss: 0.3175 - mse: 0.2845 - mae: 0.3175 - val_loss: 0.3666 - val_mse: 0.3704 - val_mae: 0.3666
# Epoch 63/30000
#  - 3s - loss: 0.3149 - mse: 0.2859 - mae: 0.3149 - val_loss: 0.3629 - val_mse: 0.3723 - val_mae: 0.3629
# Epoch 64/30000
#  - 3s - loss: 0.3152 - mse: 0.2853 - mae: 0.3152 - val_loss: 0.3665 - val_mse: 0.3704 - val_mae: 0.3665
# Epoch 65/30000
#  - 3s - loss: 0.3112 - mse: 0.2793 - mae: 0.3112 - val_loss: 0.3631 - val_mse: 0.3683 - val_mae: 0.3631
# Epoch 66/30000
#  - 3s - loss: 0.3123 - mse: 0.2803 - mae: 0.3123 - val_loss: 0.3583 - val_mse: 0.3646 - val_mae: 0.3583
# Epoch 67/30000
#  - 3s - loss: 0.3088 - mse: 0.2739 - mae: 0.3088 - val_loss: 0.3618 - val_mse: 0.3688 - val_mae: 0.3618
# Epoch 68/30000
#  - 3s - loss: 0.3102 - mse: 0.2767 - mae: 0.3102 - val_loss: 0.3562 - val_mse: 0.3562 - val_mae: 0.3562
# Epoch 69/30000
#  - 3s - loss: 0.3079 - mse: 0.2730 - mae: 0.3079 - val_loss: 0.3551 - val_mse: 0.3541 - val_mae: 0.3551
# Epoch 70/30000
#  - 3s - loss: 0.3032 - mse: 0.2668 - mae: 0.3032 - val_loss: 0.3521 - val_mse: 0.3556 - val_mae: 0.3521
# Epoch 71/30000
#  - 3s - loss: 0.2992 - mse: 0.2631 - mae: 0.2992 - val_loss: 0.3501 - val_mse: 0.3523 - val_mae: 0.3501
# Epoch 72/30000
#  - 3s - loss: 0.2998 - mse: 0.2633 - mae: 0.2998 - val_loss: 0.3489 - val_mse: 0.3471 - val_mae: 0.3489
# Epoch 73/30000
#  - 3s - loss: 0.2977 - mse: 0.2590 - mae: 0.2977 - val_loss: 0.3568 - val_mse: 0.3546 - val_mae: 0.3568
# Epoch 74/30000
#  - 3s - loss: 0.2972 - mse: 0.2581 - mae: 0.2972 - val_loss: 0.3573 - val_mse: 0.3558 - val_mae: 0.3573
# Epoch 75/30000
#  - 3s - loss: 0.2971 - mse: 0.2578 - mae: 0.2971 - val_loss: 0.3448 - val_mse: 0.3427 - val_mae: 0.3448
# Epoch 76/30000
#  - 3s - loss: 0.2978 - mse: 0.2594 - mae: 0.2978 - val_loss: 0.3543 - val_mse: 0.3548 - val_mae: 0.3543
# Epoch 77/30000
#  - 3s - loss: 0.2944 - mse: 0.2540 - mae: 0.2944 - val_loss: 0.3437 - val_mse: 0.3410 - val_mae: 0.3437
# Epoch 78/30000
#  - 3s - loss: 0.2898 - mse: 0.2486 - mae: 0.2898 - val_loss: 0.3486 - val_mse: 0.3441 - val_mae: 0.3486
# Epoch 79/30000
#  - 3s - loss: 0.2886 - mse: 0.2466 - mae: 0.2886 - val_loss: 0.3474 - val_mse: 0.3459 - val_mae: 0.3474
# Epoch 80/30000
#  - 3s - loss: 0.2910 - mse: 0.2479 - mae: 0.2910 - val_loss: 0.3493 - val_mse: 0.3439 - val_mae: 0.3493
# Epoch 81/30000
#  - 3s - loss: 0.2873 - mse: 0.2438 - mae: 0.2873 - val_loss: 0.3402 - val_mse: 0.3309 - val_mae: 0.3402
# Epoch 82/30000
#  - 3s - loss: 0.2864 - mse: 0.2425 - mae: 0.2864 - val_loss: 0.3471 - val_mse: 0.3393 - val_mae: 0.3471
# Epoch 83/30000
#  - 3s - loss: 0.2883 - mse: 0.2428 - mae: 0.2883 - val_loss: 0.3490 - val_mse: 0.3414 - val_mae: 0.3490
# Epoch 84/30000
#  - 3s - loss: 0.2817 - mse: 0.2363 - mae: 0.2817 - val_loss: 0.3478 - val_mse: 0.3383 - val_mae: 0.3478
# Epoch 85/30000
#  - 3s - loss: 0.2841 - mse: 0.2403 - mae: 0.2841 - val_loss: 0.3406 - val_mse: 0.3295 - val_mae: 0.3406
# Epoch 86/30000
#  - 3s - loss: 0.2810 - mse: 0.2336 - mae: 0.2810 - val_loss: 0.3442 - val_mse: 0.3365 - val_mae: 0.3442
# Epoch 87/30000
#  - 3s - loss: 0.2813 - mse: 0.2343 - mae: 0.2813 - val_loss: 0.3467 - val_mse: 0.3370 - val_mae: 0.3467
# Epoch 88/30000
#  - 3s - loss: 0.2822 - mse: 0.2353 - mae: 0.2822 - val_loss: 0.3441 - val_mse: 0.3325 - val_mae: 0.3441
# Epoch 89/30000
#  - 3s - loss: 0.2755 - mse: 0.2289 - mae: 0.2755 - val_loss: 0.3432 - val_mse: 0.3337 - val_mae: 0.3432
# Epoch 90/30000
#  - 3s - loss: 0.2783 - mse: 0.2310 - mae: 0.2783 - val_loss: 0.3482 - val_mse: 0.3375 - val_mae: 0.3482
# Epoch 91/30000
#  - 3s - loss: 0.2758 - mse: 0.2288 - mae: 0.2758 - val_loss: 0.3318 - val_mse: 0.3250 - val_mae: 0.3318
# Epoch 92/30000
#  - 3s - loss: 0.2737 - mse: 0.2248 - mae: 0.2737 - val_loss: 0.3389 - val_mse: 0.3292 - val_mae: 0.3389
# Epoch 93/30000
#  - 3s - loss: 0.2720 - mse: 0.2221 - mae: 0.2720 - val_loss: 0.3459 - val_mse: 0.3386 - val_mae: 0.3459
# Epoch 94/30000
#  - 3s - loss: 0.2735 - mse: 0.2241 - mae: 0.2735 - val_loss: 0.3319 - val_mse: 0.3185 - val_mae: 0.3319
# Epoch 95/30000
#  - 3s - loss: 0.2709 - mse: 0.2223 - mae: 0.2709 - val_loss: 0.3325 - val_mse: 0.3234 - val_mae: 0.3325
# Epoch 96/30000
#  - 3s - loss: 0.2687 - mse: 0.2183 - mae: 0.2687 - val_loss: 0.3316 - val_mse: 0.3195 - val_mae: 0.3316
# Epoch 97/30000
#  - 3s - loss: 0.2697 - mse: 0.2217 - mae: 0.2697 - val_loss: 0.3353 - val_mse: 0.3237 - val_mae: 0.3353
# Epoch 98/30000
#  - 3s - loss: 0.2701 - mse: 0.2178 - mae: 0.2701 - val_loss: 0.3327 - val_mse: 0.3187 - val_mae: 0.3327
# Epoch 99/30000
#  - 3s - loss: 0.2671 - mse: 0.2161 - mae: 0.2671 - val_loss: 0.3355 - val_mse: 0.3229 - val_mae: 0.3355
# Epoch 100/30000
#  - 3s - loss: 0.2707 - mse: 0.2173 - mae: 0.2707 - val_loss: 0.3381 - val_mse: 0.3260 - val_mae: 0.3381
# Epoch 101/30000
#  - 3s - loss: 0.2668 - mse: 0.2165 - mae: 0.2668 - val_loss: 0.3398 - val_mse: 0.3264 - val_mae: 0.3398
# Epoch 102/30000
#  - 3s - loss: 0.2642 - mse: 0.2128 - mae: 0.2642 - val_loss: 0.3259 - val_mse: 0.3116 - val_mae: 0.3259
# Epoch 103/30000
#  - 3s - loss: 0.2594 - mse: 0.2070 - mae: 0.2594 - val_loss: 0.3343 - val_mse: 0.3209 - val_mae: 0.3343
# Epoch 104/30000
#  - 3s - loss: 0.2621 - mse: 0.2087 - mae: 0.2621 - val_loss: 0.3286 - val_mse: 0.3140 - val_mae: 0.3286
# Epoch 105/30000
#  - 3s - loss: 0.2617 - mse: 0.2076 - mae: 0.2617 - val_loss: 0.3247 - val_mse: 0.3076 - val_mae: 0.3247
# Epoch 106/30000
#  - 3s - loss: 0.2611 - mse: 0.2071 - mae: 0.2611 - val_loss: 0.3268 - val_mse: 0.3115 - val_mae: 0.3268
# Epoch 107/30000
#  - 3s - loss: 0.2603 - mse: 0.2075 - mae: 0.2603 - val_loss: 0.3287 - val_mse: 0.3115 - val_mae: 0.3287
# Epoch 108/30000
#  - 3s - loss: 0.2600 - mse: 0.2067 - mae: 0.2600 - val_loss: 0.3297 - val_mse: 0.3160 - val_mae: 0.3297
# Epoch 109/30000
#  - 3s - loss: 0.2543 - mse: 0.1997 - mae: 0.2543 - val_loss: 0.3228 - val_mse: 0.3045 - val_mae: 0.3228
# Epoch 110/30000
#  - 3s - loss: 0.2554 - mse: 0.1989 - mae: 0.2554 - val_loss: 0.3290 - val_mse: 0.3146 - val_mae: 0.3290
# Epoch 111/30000
#  - 3s - loss: 0.2575 - mse: 0.2025 - mae: 0.2575 - val_loss: 0.3222 - val_mse: 0.3049 - val_mae: 0.3222
# Epoch 112/30000
#  - 3s - loss: 0.2530 - mse: 0.1982 - mae: 0.2530 - val_loss: 0.3346 - val_mse: 0.3155 - val_mae: 0.3346
# Epoch 113/30000
#  - 3s - loss: 0.2546 - mse: 0.1992 - mae: 0.2546 - val_loss: 0.3192 - val_mse: 0.3036 - val_mae: 0.3192
# Epoch 114/30000
#  - 3s - loss: 0.2527 - mse: 0.1971 - mae: 0.2527 - val_loss: 0.3234 - val_mse: 0.3078 - val_mae: 0.3234
# Epoch 115/30000
#  - 3s - loss: 0.2509 - mse: 0.1941 - mae: 0.2509 - val_loss: 0.3300 - val_mse: 0.3139 - val_mae: 0.3300
# Epoch 116/30000
#  - 3s - loss: 0.2511 - mse: 0.1937 - mae: 0.2511 - val_loss: 0.3217 - val_mse: 0.3026 - val_mae: 0.3217
# Epoch 117/30000
#  - 3s - loss: 0.2492 - mse: 0.1913 - mae: 0.2492 - val_loss: 0.3248 - val_mse: 0.3068 - val_mae: 0.3248
# Epoch 118/30000
#  - 3s - loss: 0.2507 - mse: 0.1929 - mae: 0.2507 - val_loss: 0.3226 - val_mse: 0.2990 - val_mae: 0.3226
# Epoch 119/30000
#  - 3s - loss: 0.2496 - mse: 0.1895 - mae: 0.2496 - val_loss: 0.3237 - val_mse: 0.3091 - val_mae: 0.3237
# Epoch 120/30000
#  - 3s - loss: 0.2506 - mse: 0.1930 - mae: 0.2506 - val_loss: 0.3242 - val_mse: 0.3053 - val_mae: 0.3242
# Epoch 121/30000
#  - 3s - loss: 0.2466 - mse: 0.1878 - mae: 0.2466 - val_loss: 0.3265 - val_mse: 0.3073 - val_mae: 0.3265
# Epoch 122/30000
#  - 3s - loss: 0.2470 - mse: 0.1882 - mae: 0.2470 - val_loss: 0.3216 - val_mse: 0.3044 - val_mae: 0.3216
# Epoch 123/30000
#  - 3s - loss: 0.2493 - mse: 0.1909 - mae: 0.2493 - val_loss: 0.3217 - val_mse: 0.3048 - val_mae: 0.3217
# Epoch 124/30000
#  - 3s - loss: 0.2434 - mse: 0.1841 - mae: 0.2434 - val_loss: 0.3185 - val_mse: 0.2998 - val_mae: 0.3185
# Epoch 125/30000
#  - 3s - loss: 0.2448 - mse: 0.1861 - mae: 0.2448 - val_loss: 0.3220 - val_mse: 0.3041 - val_mae: 0.3220
# Epoch 126/30000
#  - 3s - loss: 0.2434 - mse: 0.1837 - mae: 0.2434 - val_loss: 0.3212 - val_mse: 0.3059 - val_mae: 0.3212
# Epoch 127/30000
#  - 3s - loss: 0.2440 - mse: 0.1850 - mae: 0.2440 - val_loss: 0.3173 - val_mse: 0.3018 - val_mae: 0.3173
# Epoch 128/30000
#  - 3s - loss: 0.2424 - mse: 0.1832 - mae: 0.2424 - val_loss: 0.3195 - val_mse: 0.2993 - val_mae: 0.3195
# Epoch 129/30000
#  - 3s - loss: 0.2428 - mse: 0.1825 - mae: 0.2428 - val_loss: 0.3191 - val_mse: 0.3017 - val_mae: 0.3191
# Epoch 130/30000
#  - 3s - loss: 0.2424 - mse: 0.1831 - mae: 0.2424 - val_loss: 0.3233 - val_mse: 0.3050 - val_mae: 0.3233
# Epoch 131/30000
#  - 3s - loss: 0.2411 - mse: 0.1828 - mae: 0.2411 - val_loss: 0.3188 - val_mse: 0.2988 - val_mae: 0.3188
# Epoch 132/30000
#  - 3s - loss: 0.2392 - mse: 0.1787 - mae: 0.2392 - val_loss: 0.3208 - val_mse: 0.3014 - val_mae: 0.3208
# Epoch 133/30000
#  - 3s - loss: 0.2394 - mse: 0.1786 - mae: 0.2394 - val_loss: 0.3166 - val_mse: 0.2976 - val_mae: 0.3166
# Epoch 134/30000
#  - 3s - loss: 0.2380 - mse: 0.1745 - mae: 0.2380 - val_loss: 0.3175 - val_mse: 0.2965 - val_mae: 0.3175
# Epoch 135/30000
#  - 3s - loss: 0.2371 - mse: 0.1761 - mae: 0.2371 - val_loss: 0.3161 - val_mse: 0.2934 - val_mae: 0.3161
# Epoch 136/30000
#  - 3s - loss: 0.2359 - mse: 0.1756 - mae: 0.2359 - val_loss: 0.3211 - val_mse: 0.2988 - val_mae: 0.3211
# Epoch 137/30000
#  - 3s - loss: 0.2344 - mse: 0.1717 - mae: 0.2344 - val_loss: 0.3239 - val_mse: 0.3030 - val_mae: 0.3239
# Epoch 138/30000
#  - 3s - loss: 0.2360 - mse: 0.1755 - mae: 0.2360 - val_loss: 0.3140 - val_mse: 0.2906 - val_mae: 0.3140
# Epoch 139/30000
#  - 3s - loss: 0.2354 - mse: 0.1738 - mae: 0.2354 - val_loss: 0.3167 - val_mse: 0.2952 - val_mae: 0.3167
# Epoch 140/30000
#  - 3s - loss: 0.2317 - mse: 0.1707 - mae: 0.2317 - val_loss: 0.3122 - val_mse: 0.2903 - val_mae: 0.3122
# Epoch 141/30000
#  - 3s - loss: 0.2341 - mse: 0.1712 - mae: 0.2341 - val_loss: 0.3213 - val_mse: 0.3005 - val_mae: 0.3213
# Epoch 142/30000
#  - 3s - loss: 0.2344 - mse: 0.1717 - mae: 0.2344 - val_loss: 0.3138 - val_mse: 0.2941 - val_mae: 0.3138
# Epoch 143/30000
#  - 3s - loss: 0.2315 - mse: 0.1697 - mae: 0.2315 - val_loss: 0.3171 - val_mse: 0.2979 - val_mae: 0.3171
# Epoch 144/30000
#  - 3s - loss: 0.2332 - mse: 0.1708 - mae: 0.2332 - val_loss: 0.3183 - val_mse: 0.2965 - val_mae: 0.3183
# Epoch 145/30000
#  - 3s - loss: 0.2298 - mse: 0.1675 - mae: 0.2298 - val_loss: 0.3160 - val_mse: 0.2947 - val_mae: 0.3160
# Epoch 146/30000
#  - 3s - loss: 0.2303 - mse: 0.1691 - mae: 0.2303 - val_loss: 0.3148 - val_mse: 0.2889 - val_mae: 0.3148
# Epoch 147/30000
#  - 3s - loss: 0.2248 - mse: 0.1604 - mae: 0.2248 - val_loss: 0.3118 - val_mse: 0.2903 - val_mae: 0.3118
# Epoch 148/30000
#  - 3s - loss: 0.2306 - mse: 0.1696 - mae: 0.2306 - val_loss: 0.3095 - val_mse: 0.2858 - val_mae: 0.3095
# Epoch 149/30000
#  - 3s - loss: 0.2283 - mse: 0.1667 - mae: 0.2283 - val_loss: 0.3063 - val_mse: 0.2807 - val_mae: 0.3063
# Epoch 150/30000
#  - 3s - loss: 0.2286 - mse: 0.1665 - mae: 0.2286 - val_loss: 0.3112 - val_mse: 0.2860 - val_mae: 0.3112
# Epoch 151/30000
#  - 3s - loss: 0.2276 - mse: 0.1665 - mae: 0.2276 - val_loss: 0.3150 - val_mse: 0.2920 - val_mae: 0.3150
# Epoch 152/30000
#  - 3s - loss: 0.2286 - mse: 0.1647 - mae: 0.2286 - val_loss: 0.3194 - val_mse: 0.3013 - val_mae: 0.3194
# Epoch 153/30000
#  - 3s - loss: 0.2314 - mse: 0.1689 - mae: 0.2314 - val_loss: 0.3187 - val_mse: 0.2959 - val_mae: 0.3187
# Epoch 154/30000
#  - 3s - loss: 0.2269 - mse: 0.1647 - mae: 0.2269 - val_loss: 0.3125 - val_mse: 0.2881 - val_mae: 0.3125
# Epoch 155/30000
#  - 3s - loss: 0.2254 - mse: 0.1639 - mae: 0.2254 - val_loss: 0.3128 - val_mse: 0.2878 - val_mae: 0.3128
# Epoch 156/30000
#  - 3s - loss: 0.2236 - mse: 0.1586 - mae: 0.2236 - val_loss: 0.3066 - val_mse: 0.2838 - val_mae: 0.3066
# Epoch 157/30000
#  - 3s - loss: 0.2245 - mse: 0.1593 - mae: 0.2245 - val_loss: 0.3135 - val_mse: 0.2872 - val_mae: 0.3135
# Epoch 158/30000
#  - 3s - loss: 0.2267 - mse: 0.1624 - mae: 0.2267 - val_loss: 0.3101 - val_mse: 0.2865 - val_mae: 0.3101
# Epoch 159/30000
#  - 3s - loss: 0.2233 - mse: 0.1585 - mae: 0.2233 - val_loss: 0.3089 - val_mse: 0.2822 - val_mae: 0.3089
# Epoch 160/30000
#  - 3s - loss: 0.2221 - mse: 0.1581 - mae: 0.2221 - val_loss: 0.3095 - val_mse: 0.2851 - val_mae: 0.3095
# Epoch 161/30000
#  - 3s - loss: 0.2218 - mse: 0.1574 - mae: 0.2218 - val_loss: 0.3088 - val_mse: 0.2843 - val_mae: 0.3088
# Epoch 162/30000
#  - 3s - loss: 0.2226 - mse: 0.1583 - mae: 0.2226 - val_loss: 0.3084 - val_mse: 0.2825 - val_mae: 0.3084
# Epoch 163/30000
#  - 3s - loss: 0.2196 - mse: 0.1536 - mae: 0.2196 - val_loss: 0.3097 - val_mse: 0.2859 - val_mae: 0.3097
# Epoch 164/30000
#  - 3s - loss: 0.2230 - mse: 0.1593 - mae: 0.2230 - val_loss: 0.3100 - val_mse: 0.2853 - val_mae: 0.3100
# Epoch 165/30000
#  - 3s - loss: 0.2201 - mse: 0.1557 - mae: 0.2201 - val_loss: 0.3143 - val_mse: 0.2862 - val_mae: 0.3143
# Epoch 166/30000
#  - 3s - loss: 0.2224 - mse: 0.1581 - mae: 0.2224 - val_loss: 0.3152 - val_mse: 0.2896 - val_mae: 0.3152
# Epoch 167/30000
#  - 3s - loss: 0.2214 - mse: 0.1578 - mae: 0.2214 - val_loss: 0.3121 - val_mse: 0.2871 - val_mae: 0.3121
# Epoch 168/30000
#  - 3s - loss: 0.2188 - mse: 0.1533 - mae: 0.2188 - val_loss: 0.3054 - val_mse: 0.2831 - val_mae: 0.3054
# Epoch 169/30000
#  - 3s - loss: 0.2200 - mse: 0.1568 - mae: 0.2200 - val_loss: 0.3113 - val_mse: 0.2844 - val_mae: 0.3113
# Epoch 170/30000
#  - 3s - loss: 0.2153 - mse: 0.1505 - mae: 0.2153 - val_loss: 0.3075 - val_mse: 0.2823 - val_mae: 0.3075
# Epoch 171/30000
#  - 3s - loss: 0.2196 - mse: 0.1541 - mae: 0.2196 - val_loss: 0.3138 - val_mse: 0.2839 - val_mae: 0.3138
# Epoch 172/30000
#  - 3s - loss: 0.2203 - mse: 0.1536 - mae: 0.2203 - val_loss: 0.3078 - val_mse: 0.2820 - val_mae: 0.3078
# Epoch 173/30000
#  - 3s - loss: 0.2190 - mse: 0.1533 - mae: 0.2190 - val_loss: 0.3107 - val_mse: 0.2859 - val_mae: 0.3107
# Epoch 174/30000
#  - 3s - loss: 0.2147 - mse: 0.1481 - mae: 0.2147 - val_loss: 0.3103 - val_mse: 0.2838 - val_mae: 0.3103
# Epoch 175/30000
#  - 3s - loss: 0.2154 - mse: 0.1494 - mae: 0.2154 - val_loss: 0.3123 - val_mse: 0.2853 - val_mae: 0.3123
# Epoch 176/30000
#  - 3s - loss: 0.2157 - mse: 0.1502 - mae: 0.2157 - val_loss: 0.3061 - val_mse: 0.2795 - val_mae: 0.3061
# Epoch 177/30000
#  - 3s - loss: 0.2163 - mse: 0.1490 - mae: 0.2163 - val_loss: 0.3113 - val_mse: 0.2875 - val_mae: 0.3113
# Epoch 178/30000
#  - 3s - loss: 0.2159 - mse: 0.1498 - mae: 0.2159 - val_loss: 0.3120 - val_mse: 0.2869 - val_mae: 0.3120
# Epoch 179/30000
#  - 3s - loss: 0.2139 - mse: 0.1484 - mae: 0.2139 - val_loss: 0.3073 - val_mse: 0.2826 - val_mae: 0.3073
# Epoch 180/30000
#  - 3s - loss: 0.2133 - mse: 0.1470 - mae: 0.2133 - val_loss: 0.2999 - val_mse: 0.2738 - val_mae: 0.2999
# Epoch 181/30000
#  - 3s - loss: 0.2103 - mse: 0.1438 - mae: 0.2103 - val_loss: 0.3107 - val_mse: 0.2848 - val_mae: 0.3107
# Epoch 182/30000
#  - 3s - loss: 0.2150 - mse: 0.1488 - mae: 0.2150 - val_loss: 0.3098 - val_mse: 0.2817 - val_mae: 0.3098
# Epoch 183/30000
#  - 3s - loss: 0.2132 - mse: 0.1455 - mae: 0.2132 - val_loss: 0.3095 - val_mse: 0.2840 - val_mae: 0.3095
# Epoch 184/30000
#  - 3s - loss: 0.2122 - mse: 0.1454 - mae: 0.2122 - val_loss: 0.3059 - val_mse: 0.2803 - val_mae: 0.3059
# Epoch 185/30000
#  - 3s - loss: 0.2143 - mse: 0.1471 - mae: 0.2143 - val_loss: 0.3057 - val_mse: 0.2792 - val_mae: 0.3057
# Epoch 186/30000
#  - 3s - loss: 0.2093 - mse: 0.1443 - mae: 0.2093 - val_loss: 0.3022 - val_mse: 0.2755 - val_mae: 0.3022
# Epoch 187/30000
#  - 3s - loss: 0.2134 - mse: 0.1454 - mae: 0.2134 - val_loss: 0.3074 - val_mse: 0.2792 - val_mae: 0.3074
# Epoch 188/30000
#  - 3s - loss: 0.2125 - mse: 0.1452 - mae: 0.2125 - val_loss: 0.3082 - val_mse: 0.2819 - val_mae: 0.3082
# Epoch 189/30000
#  - 3s - loss: 0.2127 - mse: 0.1464 - mae: 0.2127 - val_loss: 0.3014 - val_mse: 0.2722 - val_mae: 0.3014
# Epoch 190/30000
#  - 3s - loss: 0.2083 - mse: 0.1417 - mae: 0.2083 - val_loss: 0.3102 - val_mse: 0.2822 - val_mae: 0.3102
# Epoch 191/30000
#  - 3s - loss: 0.2109 - mse: 0.1446 - mae: 0.2109 - val_loss: 0.3045 - val_mse: 0.2777 - val_mae: 0.3045
# Epoch 192/30000
#  - 3s - loss: 0.2093 - mse: 0.1415 - mae: 0.2093 - val_loss: 0.3120 - val_mse: 0.2821 - val_mae: 0.3120
# Epoch 193/30000
#  - 3s - loss: 0.2094 - mse: 0.1411 - mae: 0.2094 - val_loss: 0.3045 - val_mse: 0.2767 - val_mae: 0.3045
# Epoch 194/30000
#  - 3s - loss: 0.2090 - mse: 0.1419 - mae: 0.2090 - val_loss: 0.3034 - val_mse: 0.2761 - val_mae: 0.3034
# Epoch 195/30000
#  - 3s - loss: 0.2077 - mse: 0.1397 - mae: 0.2077 - val_loss: 0.3019 - val_mse: 0.2736 - val_mae: 0.3019
# Epoch 196/30000
#  - 3s - loss: 0.2079 - mse: 0.1410 - mae: 0.2079 - val_loss: 0.3050 - val_mse: 0.2778 - val_mae: 0.3050
# Epoch 197/30000
#  - 3s - loss: 0.2100 - mse: 0.1422 - mae: 0.2100 - val_loss: 0.3052 - val_mse: 0.2795 - val_mae: 0.3052
# Epoch 198/30000
#  - 3s - loss: 0.2073 - mse: 0.1409 - mae: 0.2073 - val_loss: 0.3061 - val_mse: 0.2749 - val_mae: 0.3061
# Epoch 199/30000
#  - 3s - loss: 0.2059 - mse: 0.1373 - mae: 0.2059 - val_loss: 0.3019 - val_mse: 0.2755 - val_mae: 0.3019
# Epoch 200/30000
#  - 3s - loss: 0.2044 - mse: 0.1375 - mae: 0.2044 - val_loss: 0.2998 - val_mse: 0.2706 - val_mae: 0.2998
# Epoch 201/30000
#  - 3s - loss: 0.2091 - mse: 0.1402 - mae: 0.2091 - val_loss: 0.2984 - val_mse: 0.2705 - val_mae: 0.2984
# Epoch 202/30000
#  - 3s - loss: 0.2048 - mse: 0.1373 - mae: 0.2048 - val_loss: 0.3067 - val_mse: 0.2745 - val_mae: 0.3067
# Epoch 203/30000
#  - 3s - loss: 0.2041 - mse: 0.1354 - mae: 0.2041 - val_loss: 0.3064 - val_mse: 0.2765 - val_mae: 0.3064
# Epoch 204/30000
#  - 3s - loss: 0.2046 - mse: 0.1372 - mae: 0.2046 - val_loss: 0.3073 - val_mse: 0.2747 - val_mae: 0.3073
# Epoch 205/30000
#  - 3s - loss: 0.2069 - mse: 0.1390 - mae: 0.2069 - val_loss: 0.3071 - val_mse: 0.2786 - val_mae: 0.3071
# Epoch 206/30000
#  - 3s - loss: 0.2050 - mse: 0.1367 - mae: 0.2050 - val_loss: 0.3039 - val_mse: 0.2770 - val_mae: 0.3039
# Epoch 207/30000
#  - 3s - loss: 0.2055 - mse: 0.1377 - mae: 0.2055 - val_loss: 0.3040 - val_mse: 0.2739 - val_mae: 0.3040
# Epoch 208/30000
#  - 3s - loss: 0.2023 - mse: 0.1322 - mae: 0.2023 - val_loss: 0.2996 - val_mse: 0.2728 - val_mae: 0.2996
# Epoch 209/30000
#  - 3s - loss: 0.2022 - mse: 0.1334 - mae: 0.2022 - val_loss: 0.2992 - val_mse: 0.2727 - val_mae: 0.2992
# Epoch 210/30000
#  - 3s - loss: 0.2079 - mse: 0.1386 - mae: 0.2079 - val_loss: 0.3068 - val_mse: 0.2760 - val_mae: 0.3068
# Epoch 211/30000
#  - 3s - loss: 0.2033 - mse: 0.1355 - mae: 0.2033 - val_loss: 0.3032 - val_mse: 0.2743 - val_mae: 0.3032
# Epoch 212/30000
#  - 3s - loss: 0.2054 - mse: 0.1363 - mae: 0.2054 - val_loss: 0.2982 - val_mse: 0.2682 - val_mae: 0.2982
# Epoch 213/30000
#  - 3s - loss: 0.2009 - mse: 0.1317 - mae: 0.2009 - val_loss: 0.3016 - val_mse: 0.2753 - val_mae: 0.3016
# Epoch 214/30000
#  - 3s - loss: 0.2003 - mse: 0.1321 - mae: 0.2003 - val_loss: 0.2995 - val_mse: 0.2718 - val_mae: 0.2995
# Epoch 215/30000
#  - 3s - loss: 0.2016 - mse: 0.1343 - mae: 0.2016 - val_loss: 0.3089 - val_mse: 0.2767 - val_mae: 0.3089
# Epoch 216/30000
#  - 3s - loss: 0.2003 - mse: 0.1300 - mae: 0.2003 - val_loss: 0.2993 - val_mse: 0.2685 - val_mae: 0.2993
# Epoch 217/30000
#  - 3s - loss: 0.2007 - mse: 0.1345 - mae: 0.2007 - val_loss: 0.3012 - val_mse: 0.2708 - val_mae: 0.3012
# Epoch 218/30000
#  - 3s - loss: 0.2003 - mse: 0.1314 - mae: 0.2003 - val_loss: 0.3054 - val_mse: 0.2753 - val_mae: 0.3054
# Epoch 219/30000
#  - 3s - loss: 0.2000 - mse: 0.1301 - mae: 0.2000 - val_loss: 0.3012 - val_mse: 0.2694 - val_mae: 0.3012
# Epoch 220/30000
#  - 3s - loss: 0.2048 - mse: 0.1359 - mae: 0.2048 - val_loss: 0.3047 - val_mse: 0.2766 - val_mae: 0.3047
# Epoch 221/30000
#  - 3s - loss: 0.1996 - mse: 0.1311 - mae: 0.1996 - val_loss: 0.3090 - val_mse: 0.2781 - val_mae: 0.3090
# Epoch 222/30000
#  - 3s - loss: 0.2014 - mse: 0.1314 - mae: 0.2014 - val_loss: 0.3075 - val_mse: 0.2781 - val_mae: 0.3075
# Epoch 223/30000
#  - 3s - loss: 0.2005 - mse: 0.1305 - mae: 0.2005 - val_loss: 0.3072 - val_mse: 0.2779 - val_mae: 0.3072
# Epoch 224/30000
#  - 3s - loss: 0.1979 - mse: 0.1277 - mae: 0.1979 - val_loss: 0.3066 - val_mse: 0.2781 - val_mae: 0.3066
# Epoch 225/30000
#  - 3s - loss: 0.1999 - mse: 0.1296 - mae: 0.1999 - val_loss: 0.3045 - val_mse: 0.2768 - val_mae: 0.3045
# Epoch 226/30000
#  - 3s - loss: 0.1980 - mse: 0.1295 - mae: 0.1980 - val_loss: 0.3025 - val_mse: 0.2708 - val_mae: 0.3025
# Epoch 227/30000
#  - 3s - loss: 0.1980 - mse: 0.1282 - mae: 0.1980 - val_loss: 0.3043 - val_mse: 0.2727 - val_mae: 0.3043
# Epoch 228/30000
#  - 3s - loss: 0.1977 - mse: 0.1276 - mae: 0.1977 - val_loss: 0.3033 - val_mse: 0.2719 - val_mae: 0.3033
# Epoch 229/30000
#  - 3s - loss: 0.1968 - mse: 0.1266 - mae: 0.1968 - val_loss: 0.2946 - val_mse: 0.2698 - val_mae: 0.2946
# Epoch 230/30000
#  - 3s - loss: 0.1967 - mse: 0.1255 - mae: 0.1967 - val_loss: 0.3022 - val_mse: 0.2713 - val_mae: 0.3022
# Epoch 231/30000
#  - 3s - loss: 0.1978 - mse: 0.1264 - mae: 0.1978 - val_loss: 0.2985 - val_mse: 0.2676 - val_mae: 0.2985
# Epoch 232/30000
#  - 3s - loss: 0.1960 - mse: 0.1287 - mae: 0.1960 - val_loss: 0.3042 - val_mse: 0.2758 - val_mae: 0.3042
# Epoch 233/30000
#  - 3s - loss: 0.1979 - mse: 0.1288 - mae: 0.1979 - val_loss: 0.3014 - val_mse: 0.2695 - val_mae: 0.3014
# Epoch 234/30000
#  - 3s - loss: 0.1957 - mse: 0.1250 - mae: 0.1957 - val_loss: 0.3010 - val_mse: 0.2760 - val_mae: 0.3010
# Epoch 235/30000
#  - 3s - loss: 0.1981 - mse: 0.1292 - mae: 0.1981 - val_loss: 0.3042 - val_mse: 0.2760 - val_mae: 0.3042
# Epoch 236/30000
#  - 3s - loss: 0.1957 - mse: 0.1257 - mae: 0.1957 - val_loss: 0.3048 - val_mse: 0.2755 - val_mae: 0.3048
# Epoch 237/30000
#  - 3s - loss: 0.1964 - mse: 0.1266 - mae: 0.1964 - val_loss: 0.3000 - val_mse: 0.2730 - val_mae: 0.3000
# Epoch 238/30000
#  - 3s - loss: 0.1935 - mse: 0.1231 - mae: 0.1935 - val_loss: 0.2970 - val_mse: 0.2693 - val_mae: 0.2970
# Epoch 239/30000
#  - 3s - loss: 0.1927 - mse: 0.1220 - mae: 0.1927 - val_loss: 0.2992 - val_mse: 0.2700 - val_mae: 0.2992
# Epoch 240/30000
#  - 3s - loss: 0.1944 - mse: 0.1231 - mae: 0.1944 - val_loss: 0.2966 - val_mse: 0.2669 - val_mae: 0.2966
# Epoch 241/30000
#  - 3s - loss: 0.1923 - mse: 0.1225 - mae: 0.1923 - val_loss: 0.3012 - val_mse: 0.2713 - val_mae: 0.3012
# Epoch 242/30000
#  - 3s - loss: 0.1932 - mse: 0.1210 - mae: 0.1932 - val_loss: 0.2979 - val_mse: 0.2676 - val_mae: 0.2979
# Epoch 243/30000
#  - 3s - loss: 0.1936 - mse: 0.1229 - mae: 0.1936 - val_loss: 0.2978 - val_mse: 0.2661 - val_mae: 0.2978
# Epoch 244/30000
#  - 3s - loss: 0.1927 - mse: 0.1208 - mae: 0.1927 - val_loss: 0.2992 - val_mse: 0.2688 - val_mae: 0.2992
# Epoch 245/30000
#  - 3s - loss: 0.1942 - mse: 0.1236 - mae: 0.1942 - val_loss: 0.3002 - val_mse: 0.2734 - val_mae: 0.3002
# Epoch 246/30000
#  - 3s - loss: 0.1915 - mse: 0.1202 - mae: 0.1915 - val_loss: 0.3029 - val_mse: 0.2713 - val_mae: 0.3029
# Epoch 247/30000
#  - 3s - loss: 0.1944 - mse: 0.1230 - mae: 0.1944 - val_loss: 0.2993 - val_mse: 0.2664 - val_mae: 0.2993
# Epoch 248/30000
#  - 3s - loss: 0.1916 - mse: 0.1213 - mae: 0.1916 - val_loss: 0.2978 - val_mse: 0.2630 - val_mae: 0.2978
# Epoch 249/30000
#  - 3s - loss: 0.1895 - mse: 0.1185 - mae: 0.1895 - val_loss: 0.2979 - val_mse: 0.2724 - val_mae: 0.2979
# Epoch 250/30000
#  - 3s - loss: 0.1939 - mse: 0.1227 - mae: 0.1939 - val_loss: 0.2993 - val_mse: 0.2695 - val_mae: 0.2993
# Epoch 251/30000
#  - 3s - loss: 0.1901 - mse: 0.1182 - mae: 0.1901 - val_loss: 0.2981 - val_mse: 0.2687 - val_mae: 0.2981
# Epoch 252/30000
#  - 3s - loss: 0.1913 - mse: 0.1227 - mae: 0.1913 - val_loss: 0.3052 - val_mse: 0.2727 - val_mae: 0.3052
# Epoch 253/30000
#  - 3s - loss: 0.1912 - mse: 0.1205 - mae: 0.1912 - val_loss: 0.3009 - val_mse: 0.2699 - val_mae: 0.3009
# Epoch 254/30000
#  - 3s - loss: 0.1888 - mse: 0.1186 - mae: 0.1888 - val_loss: 0.3052 - val_mse: 0.2754 - val_mae: 0.3052
# Epoch 255/30000
#  - 3s - loss: 0.1924 - mse: 0.1216 - mae: 0.1924 - val_loss: 0.2922 - val_mse: 0.2584 - val_mae: 0.2922
# Epoch 256/30000
#  - 3s - loss: 0.1889 - mse: 0.1185 - mae: 0.1889 - val_loss: 0.2960 - val_mse: 0.2631 - val_mae: 0.2960
# Epoch 257/30000
#  - 3s - loss: 0.1888 - mse: 0.1174 - mae: 0.1888 - val_loss: 0.2944 - val_mse: 0.2620 - val_mae: 0.2944
# Epoch 258/30000
#  - 3s - loss: 0.1881 - mse: 0.1177 - mae: 0.1881 - val_loss: 0.2994 - val_mse: 0.2670 - val_mae: 0.2994
# Epoch 259/30000
#  - 3s - loss: 0.1904 - mse: 0.1205 - mae: 0.1904 - val_loss: 0.2958 - val_mse: 0.2650 - val_mae: 0.2958
# Epoch 260/30000
#  - 3s - loss: 0.1870 - mse: 0.1189 - mae: 0.1870 - val_loss: 0.2981 - val_mse: 0.2661 - val_mae: 0.2981
# Epoch 261/30000
#  - 3s - loss: 0.1886 - mse: 0.1166 - mae: 0.1886 - val_loss: 0.3004 - val_mse: 0.2675 - val_mae: 0.3004
# Epoch 262/30000
#  - 3s - loss: 0.1887 - mse: 0.1187 - mae: 0.1887 - val_loss: 0.2948 - val_mse: 0.2655 - val_mae: 0.2948
# Epoch 263/30000
#  - 3s - loss: 0.1886 - mse: 0.1177 - mae: 0.1886 - val_loss: 0.3017 - val_mse: 0.2730 - val_mae: 0.3017
# Epoch 264/30000
#  - 3s - loss: 0.1869 - mse: 0.1165 - mae: 0.1869 - val_loss: 0.2957 - val_mse: 0.2683 - val_mae: 0.2957
# Epoch 265/30000
#  - 3s - loss: 0.1893 - mse: 0.1197 - mae: 0.1893 - val_loss: 0.2933 - val_mse: 0.2642 - val_mae: 0.2933
# Epoch 266/30000
#  - 3s - loss: 0.1884 - mse: 0.1186 - mae: 0.1884 - val_loss: 0.3000 - val_mse: 0.2677 - val_mae: 0.3000
# Epoch 267/30000
#  - 3s - loss: 0.1840 - mse: 0.1144 - mae: 0.1840 - val_loss: 0.2959 - val_mse: 0.2638 - val_mae: 0.2959
# Epoch 268/30000
#  - 3s - loss: 0.1863 - mse: 0.1171 - mae: 0.1863 - val_loss: 0.2975 - val_mse: 0.2678 - val_mae: 0.2975
# Epoch 269/30000
#  - 3s - loss: 0.1863 - mse: 0.1153 - mae: 0.1863 - val_loss: 0.2963 - val_mse: 0.2651 - val_mae: 0.2963
# Epoch 270/30000
#  - 3s - loss: 0.1871 - mse: 0.1163 - mae: 0.1871 - val_loss: 0.2962 - val_mse: 0.2648 - val_mae: 0.2962
# Epoch 271/30000
#  - 3s - loss: 0.1880 - mse: 0.1175 - mae: 0.1880 - val_loss: 0.2995 - val_mse: 0.2724 - val_mae: 0.2995
# Epoch 272/30000
#  - 3s - loss: 0.1868 - mse: 0.1186 - mae: 0.1868 - val_loss: 0.2982 - val_mse: 0.2661 - val_mae: 0.2982
# Epoch 273/30000
#  - 3s - loss: 0.1868 - mse: 0.1175 - mae: 0.1868 - val_loss: 0.3030 - val_mse: 0.2732 - val_mae: 0.3030
# Epoch 274/30000
#  - 3s - loss: 0.1850 - mse: 0.1136 - mae: 0.1850 - val_loss: 0.3000 - val_mse: 0.2716 - val_mae: 0.3000
# Epoch 275/30000
#  - 3s - loss: 0.1903 - mse: 0.1188 - mae: 0.1903 - val_loss: 0.2989 - val_mse: 0.2671 - val_mae: 0.2989
# Epoch 276/30000
#  - 3s - loss: 0.1861 - mse: 0.1160 - mae: 0.1861 - val_loss: 0.2977 - val_mse: 0.2640 - val_mae: 0.2977
# Epoch 277/30000
#  - 3s - loss: 0.1845 - mse: 0.1146 - mae: 0.1845 - val_loss: 0.2974 - val_mse: 0.2642 - val_mae: 0.2974
# Epoch 278/30000
#  - 3s - loss: 0.1856 - mse: 0.1157 - mae: 0.1856 - val_loss: 0.2970 - val_mse: 0.2650 - val_mae: 0.2970
# Epoch 279/30000
#  - 3s - loss: 0.1857 - mse: 0.1141 - mae: 0.1857 - val_loss: 0.2960 - val_mse: 0.2672 - val_mae: 0.2960
# Epoch 280/30000
#  - 3s - loss: 0.1863 - mse: 0.1156 - mae: 0.1863 - val_loss: 0.3038 - val_mse: 0.2698 - val_mae: 0.3038
# Epoch 281/30000
#  - 3s - loss: 0.1848 - mse: 0.1151 - mae: 0.1848 - val_loss: 0.2987 - val_mse: 0.2689 - val_mae: 0.2987
# Epoch 282/30000
#  - 3s - loss: 0.1869 - mse: 0.1168 - mae: 0.1869 - val_loss: 0.3032 - val_mse: 0.2716 - val_mae: 0.3032
# Epoch 283/30000
#  - 3s - loss: 0.1850 - mse: 0.1147 - mae: 0.1850 - val_loss: 0.2977 - val_mse: 0.2670 - val_mae: 0.2977
# Epoch 284/30000
#  - 3s - loss: 0.1834 - mse: 0.1134 - mae: 0.1834 - val_loss: 0.3003 - val_mse: 0.2686 - val_mae: 0.3003
# Epoch 285/30000
#  - 3s - loss: 0.1853 - mse: 0.1140 - mae: 0.1853 - val_loss: 0.2950 - val_mse: 0.2646 - val_mae: 0.2950
# Epoch 286/30000
#  - 3s - loss: 0.1823 - mse: 0.1122 - mae: 0.1823 - val_loss: 0.2989 - val_mse: 0.2660 - val_mae: 0.2989
# Epoch 287/30000
#  - 3s - loss: 0.1834 - mse: 0.1124 - mae: 0.1834 - val_loss: 0.2942 - val_mse: 0.2630 - val_mae: 0.2942
# Epoch 288/30000
#  - 3s - loss: 0.1809 - mse: 0.1119 - mae: 0.1809 - val_loss: 0.2927 - val_mse: 0.2643 - val_mae: 0.2927
# Epoch 289/30000
#  - 3s - loss: 0.1820 - mse: 0.1118 - mae: 0.1820 - val_loss: 0.2962 - val_mse: 0.2636 - val_mae: 0.2962
# Epoch 290/30000
#  - 3s - loss: 0.1817 - mse: 0.1093 - mae: 0.1817 - val_loss: 0.2963 - val_mse: 0.2630 - val_mae: 0.2963
# Epoch 291/30000
#  - 3s - loss: 0.1835 - mse: 0.1125 - mae: 0.1835 - val_loss: 0.2968 - val_mse: 0.2660 - val_mae: 0.2968
# Epoch 292/30000
#  - 3s - loss: 0.1844 - mse: 0.1141 - mae: 0.1844 - val_loss: 0.3007 - val_mse: 0.2705 - val_mae: 0.3007
# Epoch 293/30000
#  - 3s - loss: 0.1824 - mse: 0.1117 - mae: 0.1824 - val_loss: 0.2976 - val_mse: 0.2697 - val_mae: 0.2976
# Epoch 294/30000
#  - 3s - loss: 0.1840 - mse: 0.1140 - mae: 0.1840 - val_loss: 0.2971 - val_mse: 0.2653 - val_mae: 0.2971
# Epoch 295/30000
#  - 3s - loss: 0.1814 - mse: 0.1113 - mae: 0.1814 - val_loss: 0.2938 - val_mse: 0.2626 - val_mae: 0.2938
# Epoch 296/30000
#  - 3s - loss: 0.1802 - mse: 0.1098 - mae: 0.1802 - val_loss: 0.2942 - val_mse: 0.2649 - val_mae: 0.2942
# Epoch 297/30000
#  - 3s - loss: 0.1830 - mse: 0.1136 - mae: 0.1830 - val_loss: 0.2966 - val_mse: 0.2629 - val_mae: 0.2966
# Epoch 298/30000
#  - 3s - loss: 0.1795 - mse: 0.1084 - mae: 0.1795 - val_loss: 0.2947 - val_mse: 0.2597 - val_mae: 0.2947
# Epoch 299/30000
#  - 3s - loss: 0.1804 - mse: 0.1086 - mae: 0.1804 - val_loss: 0.2943 - val_mse: 0.2621 - val_mae: 0.2943
# Epoch 300/30000
#  - 3s - loss: 0.1812 - mse: 0.1118 - mae: 0.1812 - val_loss: 0.2925 - val_mse: 0.2580 - val_mae: 0.2925
# Epoch 301/30000
#  - 3s - loss: 0.1778 - mse: 0.1069 - mae: 0.1778 - val_loss: 0.2963 - val_mse: 0.2649 - val_mae: 0.2963
# Epoch 302/30000
#  - 3s - loss: 0.1788 - mse: 0.1090 - mae: 0.1788 - val_loss: 0.2957 - val_mse: 0.2622 - val_mae: 0.2957
# Epoch 303/30000
#  - 3s - loss: 0.1806 - mse: 0.1100 - mae: 0.1806 - val_loss: 0.2902 - val_mse: 0.2583 - val_mae: 0.2902
# Epoch 304/30000
#  - 3s - loss: 0.1803 - mse: 0.1090 - mae: 0.1803 - val_loss: 0.2940 - val_mse: 0.2586 - val_mae: 0.2940
# Epoch 305/30000
#  - 3s - loss: 0.1788 - mse: 0.1086 - mae: 0.1788 - val_loss: 0.2948 - val_mse: 0.2598 - val_mae: 0.2948
# Epoch 306/30000
#  - 3s - loss: 0.1799 - mse: 0.1098 - mae: 0.1799 - val_loss: 0.2962 - val_mse: 0.2610 - val_mae: 0.2962
# Epoch 307/30000
#  - 3s - loss: 0.1778 - mse: 0.1060 - mae: 0.1778 - val_loss: 0.2955 - val_mse: 0.2626 - val_mae: 0.2955
# Epoch 308/30000
#  - 3s - loss: 0.1778 - mse: 0.1079 - mae: 0.1778 - val_loss: 0.2974 - val_mse: 0.2645 - val_mae: 0.2974
# Epoch 309/30000
#  - 3s - loss: 0.1786 - mse: 0.1066 - mae: 0.1786 - val_loss: 0.2923 - val_mse: 0.2598 - val_mae: 0.2923
# Epoch 310/30000
#  - 3s - loss: 0.1805 - mse: 0.1099 - mae: 0.1805 - val_loss: 0.2981 - val_mse: 0.2659 - val_mae: 0.2981
# Epoch 311/30000
#  - 3s - loss: 0.1780 - mse: 0.1083 - mae: 0.1780 - val_loss: 0.2951 - val_mse: 0.2619 - val_mae: 0.2951
# Epoch 312/30000
#  - 3s - loss: 0.1766 - mse: 0.1049 - mae: 0.1766 - val_loss: 0.2966 - val_mse: 0.2603 - val_mae: 0.2966
# Epoch 313/30000
#  - 3s - loss: 0.1774 - mse: 0.1058 - mae: 0.1774 - val_loss: 0.2916 - val_mse: 0.2588 - val_mae: 0.2916
# Epoch 314/30000
#  - 3s - loss: 0.1763 - mse: 0.1058 - mae: 0.1763 - val_loss: 0.2947 - val_mse: 0.2621 - val_mae: 0.2947
# Epoch 315/30000
#  - 3s - loss: 0.1778 - mse: 0.1080 - mae: 0.1778 - val_loss: 0.2898 - val_mse: 0.2558 - val_mae: 0.2898
# Epoch 316/30000
#  - 3s - loss: 0.1748 - mse: 0.1040 - mae: 0.1748 - val_loss: 0.2957 - val_mse: 0.2611 - val_mae: 0.2957
# Epoch 317/30000
#  - 3s - loss: 0.1797 - mse: 0.1080 - mae: 0.1797 - val_loss: 0.2921 - val_mse: 0.2587 - val_mae: 0.2921
# Epoch 318/30000
#  - 3s - loss: 0.1780 - mse: 0.1073 - mae: 0.1780 - val_loss: 0.2980 - val_mse: 0.2624 - val_mae: 0.2980
# Epoch 319/30000
#  - 3s - loss: 0.1765 - mse: 0.1049 - mae: 0.1765 - val_loss: 0.2982 - val_mse: 0.2651 - val_mae: 0.2982
# Epoch 320/30000
#  - 3s - loss: 0.1761 - mse: 0.1054 - mae: 0.1761 - val_loss: 0.2965 - val_mse: 0.2644 - val_mae: 0.2965
# Epoch 321/30000
#  - 3s - loss: 0.1792 - mse: 0.1086 - mae: 0.1792 - val_loss: 0.2982 - val_mse: 0.2645 - val_mae: 0.2982
# Epoch 322/30000
#  - 3s - loss: 0.1764 - mse: 0.1052 - mae: 0.1764 - val_loss: 0.2944 - val_mse: 0.2615 - val_mae: 0.2944
# Epoch 323/30000
#  - 3s - loss: 0.1758 - mse: 0.1062 - mae: 0.1758 - val_loss: 0.2947 - val_mse: 0.2596 - val_mae: 0.2947
# Epoch 324/30000
#  - 3s - loss: 0.1764 - mse: 0.1077 - mae: 0.1764 - val_loss: 0.2952 - val_mse: 0.2607 - val_mae: 0.2952
# Epoch 325/30000
#  - 3s - loss: 0.1748 - mse: 0.1030 - mae: 0.1748 - val_loss: 0.2941 - val_mse: 0.2575 - val_mae: 0.2941
# Epoch 326/30000
#  - 3s - loss: 0.1766 - mse: 0.1049 - mae: 0.1766 - val_loss: 0.2982 - val_mse: 0.2668 - val_mae: 0.2982
# Epoch 327/30000
#  - 3s - loss: 0.1764 - mse: 0.1069 - mae: 0.1764 - val_loss: 0.2954 - val_mse: 0.2583 - val_mae: 0.2954
# Epoch 328/30000
#  - 3s - loss: 0.1750 - mse: 0.1028 - mae: 0.1750 - val_loss: 0.2931 - val_mse: 0.2600 - val_mae: 0.2931
# Epoch 329/30000
#  - 3s - loss: 0.1749 - mse: 0.1038 - mae: 0.1749 - val_loss: 0.2953 - val_mse: 0.2607 - val_mae: 0.2953
# Epoch 330/30000
#  - 3s - loss: 0.1757 - mse: 0.1045 - mae: 0.1757 - val_loss: 0.2941 - val_mse: 0.2583 - val_mae: 0.2941
# Epoch 331/30000
#  - 3s - loss: 0.1760 - mse: 0.1043 - mae: 0.1760 - val_loss: 0.2929 - val_mse: 0.2580 - val_mae: 0.2929
# Epoch 332/30000
#  - 3s - loss: 0.1730 - mse: 0.1033 - mae: 0.1730 - val_loss: 0.2964 - val_mse: 0.2614 - val_mae: 0.2964
# Epoch 333/30000
#  - 3s - loss: 0.1746 - mse: 0.1050 - mae: 0.1746 - val_loss: 0.2959 - val_mse: 0.2566 - val_mae: 0.2959
# Epoch 334/30000
#  - 3s - loss: 0.1731 - mse: 0.1008 - mae: 0.1731 - val_loss: 0.2955 - val_mse: 0.2605 - val_mae: 0.2955
# Epoch 335/30000
#  - 3s - loss: 0.1752 - mse: 0.1031 - mae: 0.1752 - val_loss: 0.2912 - val_mse: 0.2587 - val_mae: 0.2912
# Epoch 336/30000
#  - 3s - loss: 0.1735 - mse: 0.1013 - mae: 0.1735 - val_loss: 0.2946 - val_mse: 0.2584 - val_mae: 0.2946
# Epoch 337/30000
#  - 3s - loss: 0.1748 - mse: 0.1028 - mae: 0.1748 - val_loss: 0.2939 - val_mse: 0.2595 - val_mae: 0.2939
# Epoch 338/30000
#  - 3s - loss: 0.1727 - mse: 0.1021 - mae: 0.1727 - val_loss: 0.2946 - val_mse: 0.2597 - val_mae: 0.2946
# Epoch 339/30000
#  - 3s - loss: 0.1726 - mse: 0.0995 - mae: 0.1726 - val_loss: 0.2941 - val_mse: 0.2605 - val_mae: 0.2941
# Epoch 340/30000
#  - 3s - loss: 0.1737 - mse: 0.1043 - mae: 0.1737 - val_loss: 0.2898 - val_mse: 0.2512 - val_mae: 0.2898
# Epoch 341/30000
#  - 3s - loss: 0.1721 - mse: 0.1006 - mae: 0.1721 - val_loss: 0.2982 - val_mse: 0.2605 - val_mae: 0.2982
# Epoch 342/30000
#  - 3s - loss: 0.1723 - mse: 0.1024 - mae: 0.1723 - val_loss: 0.2906 - val_mse: 0.2549 - val_mae: 0.2906
# Epoch 343/30000
#  - 3s - loss: 0.1723 - mse: 0.1009 - mae: 0.1723 - val_loss: 0.2910 - val_mse: 0.2588 - val_mae: 0.2910
# Epoch 344/30000
#  - 3s - loss: 0.1714 - mse: 0.1008 - mae: 0.1714 - val_loss: 0.2966 - val_mse: 0.2634 - val_mae: 0.2966
# Epoch 345/30000
#  - 3s - loss: 0.1719 - mse: 0.1017 - mae: 0.1719 - val_loss: 0.2909 - val_mse: 0.2529 - val_mae: 0.2909
# Epoch 346/30000
#  - 3s - loss: 0.1710 - mse: 0.0982 - mae: 0.1710 - val_loss: 0.2929 - val_mse: 0.2547 - val_mae: 0.2929
# Epoch 347/30000
#  - 3s - loss: 0.1714 - mse: 0.1033 - mae: 0.1714 - val_loss: 0.2944 - val_mse: 0.2563 - val_mae: 0.2944
# Epoch 348/30000
#  - 3s - loss: 0.1712 - mse: 0.0992 - mae: 0.1712 - val_loss: 0.2951 - val_mse: 0.2593 - val_mae: 0.2951
# Epoch 349/30000
#  - 3s - loss: 0.1720 - mse: 0.1002 - mae: 0.1720 - val_loss: 0.2918 - val_mse: 0.2587 - val_mae: 0.2918
# Epoch 350/30000
#  - 3s - loss: 0.1693 - mse: 0.0989 - mae: 0.1693 - val_loss: 0.2967 - val_mse: 0.2593 - val_mae: 0.2967
# Epoch 351/30000
#  - 3s - loss: 0.1716 - mse: 0.0994 - mae: 0.1716 - val_loss: 0.2935 - val_mse: 0.2583 - val_mae: 0.2935
# Epoch 352/30000
#  - 3s - loss: 0.1749 - mse: 0.1037 - mae: 0.1749 - val_loss: 0.2929 - val_mse: 0.2571 - val_mae: 0.2929
# Epoch 353/30000
#  - 3s - loss: 0.1711 - mse: 0.1004 - mae: 0.1711 - val_loss: 0.2966 - val_mse: 0.2554 - val_mae: 0.2966
# Epoch 354/30000
#  - 3s - loss: 0.1718 - mse: 0.0987 - mae: 0.1718 - val_loss: 0.2959 - val_mse: 0.2557 - val_mae: 0.2959
# Epoch 355/30000
#  - 3s - loss: 0.1710 - mse: 0.1004 - mae: 0.1710 - val_loss: 0.2895 - val_mse: 0.2547 - val_mae: 0.2895
# Epoch 356/30000
#  - 3s - loss: 0.1700 - mse: 0.0985 - mae: 0.1700 - val_loss: 0.2906 - val_mse: 0.2518 - val_mae: 0.2906
# Epoch 357/30000
#  - 3s - loss: 0.1705 - mse: 0.1001 - mae: 0.1705 - val_loss: 0.2863 - val_mse: 0.2500 - val_mae: 0.2863
# Epoch 358/30000
#  - 3s - loss: 0.1695 - mse: 0.0981 - mae: 0.1695 - val_loss: 0.2899 - val_mse: 0.2548 - val_mae: 0.2899
# Epoch 359/30000
#  - 3s - loss: 0.1698 - mse: 0.0987 - mae: 0.1698 - val_loss: 0.2945 - val_mse: 0.2587 - val_mae: 0.2945
# Epoch 360/30000
#  - 3s - loss: 0.1703 - mse: 0.0998 - mae: 0.1703 - val_loss: 0.2951 - val_mse: 0.2557 - val_mae: 0.2951
# Epoch 361/30000
#  - 3s - loss: 0.1705 - mse: 0.0980 - mae: 0.1705 - val_loss: 0.2911 - val_mse: 0.2548 - val_mae: 0.2911
# Epoch 362/30000
#  - 3s - loss: 0.1702 - mse: 0.0995 - mae: 0.1702 - val_loss: 0.2911 - val_mse: 0.2528 - val_mae: 0.2911
# Epoch 363/30000
#  - 3s - loss: 0.1686 - mse: 0.0978 - mae: 0.1686 - val_loss: 0.2873 - val_mse: 0.2495 - val_mae: 0.2873
# Epoch 364/30000
#  - 3s - loss: 0.1684 - mse: 0.0973 - mae: 0.1684 - val_loss: 0.2872 - val_mse: 0.2494 - val_mae: 0.2872
# Epoch 365/30000
#  - 3s - loss: 0.1680 - mse: 0.0986 - mae: 0.1680 - val_loss: 0.2915 - val_mse: 0.2534 - val_mae: 0.2915
# Epoch 366/30000
#  - 3s - loss: 0.1693 - mse: 0.0977 - mae: 0.1693 - val_loss: 0.2901 - val_mse: 0.2506 - val_mae: 0.2901
# Epoch 367/30000
#  - 3s - loss: 0.1685 - mse: 0.0962 - mae: 0.1685 - val_loss: 0.2888 - val_mse: 0.2504 - val_mae: 0.2888
# Epoch 368/30000
#  - 3s - loss: 0.1688 - mse: 0.0968 - mae: 0.1688 - val_loss: 0.2906 - val_mse: 0.2522 - val_mae: 0.2906
# Epoch 369/30000
#  - 3s - loss: 0.1671 - mse: 0.0958 - mae: 0.1671 - val_loss: 0.2903 - val_mse: 0.2558 - val_mae: 0.2903
# Epoch 370/30000
#  - 3s - loss: 0.1665 - mse: 0.0975 - mae: 0.1665 - val_loss: 0.2904 - val_mse: 0.2536 - val_mae: 0.2904
# Epoch 371/30000
#  - 3s - loss: 0.1682 - mse: 0.0967 - mae: 0.1682 - val_loss: 0.2916 - val_mse: 0.2532 - val_mae: 0.2916
# Epoch 372/30000
#  - 3s - loss: 0.1662 - mse: 0.0943 - mae: 0.1662 - val_loss: 0.2940 - val_mse: 0.2549 - val_mae: 0.2940
# Epoch 373/30000
#  - 3s - loss: 0.1703 - mse: 0.0979 - mae: 0.1703 - val_loss: 0.2906 - val_mse: 0.2549 - val_mae: 0.2906
# Epoch 374/30000
#  - 3s - loss: 0.1697 - mse: 0.0976 - mae: 0.1697 - val_loss: 0.2910 - val_mse: 0.2515 - val_mae: 0.2910
# Epoch 375/30000
#  - 3s - loss: 0.1671 - mse: 0.0945 - mae: 0.1671 - val_loss: 0.2925 - val_mse: 0.2549 - val_mae: 0.2925
# Epoch 376/30000
#  - 3s - loss: 0.1690 - mse: 0.0982 - mae: 0.1690 - val_loss: 0.2913 - val_mse: 0.2545 - val_mae: 0.2913
# Epoch 377/30000
#  - 3s - loss: 0.1692 - mse: 0.0962 - mae: 0.1692 - val_loss: 0.2920 - val_mse: 0.2536 - val_mae: 0.2920
# Epoch 378/30000
#  - 3s - loss: 0.1672 - mse: 0.0951 - mae: 0.1672 - val_loss: 0.2942 - val_mse: 0.2553 - val_mae: 0.2942
# Epoch 379/30000
#  - 3s - loss: 0.1678 - mse: 0.0948 - mae: 0.1678 - val_loss: 0.2936 - val_mse: 0.2535 - val_mae: 0.2936
# Epoch 380/30000
#  - 3s - loss: 0.1673 - mse: 0.0956 - mae: 0.1673 - val_loss: 0.2868 - val_mse: 0.2478 - val_mae: 0.2868
# Epoch 381/30000
#  - 3s - loss: 0.1662 - mse: 0.0970 - mae: 0.1662 - val_loss: 0.2923 - val_mse: 0.2543 - val_mae: 0.2923
# Epoch 382/30000
#  - 3s - loss: 0.1690 - mse: 0.0974 - mae: 0.1690 - val_loss: 0.2920 - val_mse: 0.2528 - val_mae: 0.2920
# Epoch 383/30000
#  - 3s - loss: 0.1678 - mse: 0.0975 - mae: 0.1678 - val_loss: 0.2895 - val_mse: 0.2515 - val_mae: 0.2895
# Epoch 384/30000
#  - 3s - loss: 0.1674 - mse: 0.0967 - mae: 0.1674 - val_loss: 0.2913 - val_mse: 0.2524 - val_mae: 0.2913
# Epoch 385/30000
#  - 3s - loss: 0.1691 - mse: 0.0971 - mae: 0.1691 - val_loss: 0.2898 - val_mse: 0.2499 - val_mae: 0.2898
# Epoch 386/30000
#  - 3s - loss: 0.1659 - mse: 0.0945 - mae: 0.1659 - val_loss: 0.2928 - val_mse: 0.2559 - val_mae: 0.2928
# Epoch 387/30000
#  - 3s - loss: 0.1650 - mse: 0.0944 - mae: 0.1650 - val_loss: 0.2883 - val_mse: 0.2486 - val_mae: 0.2883
# Epoch 388/30000
#  - 3s - loss: 0.1641 - mse: 0.0914 - mae: 0.1641 - val_loss: 0.2917 - val_mse: 0.2552 - val_mae: 0.2917
# Epoch 389/30000
#  - 3s - loss: 0.1648 - mse: 0.0921 - mae: 0.1648 - val_loss: 0.2901 - val_mse: 0.2524 - val_mae: 0.2901
# Epoch 390/30000
#  - 3s - loss: 0.1663 - mse: 0.0952 - mae: 0.1663 - val_loss: 0.2928 - val_mse: 0.2582 - val_mae: 0.2928
# Epoch 391/30000
#  - 3s - loss: 0.1640 - mse: 0.0919 - mae: 0.1640 - val_loss: 0.2906 - val_mse: 0.2482 - val_mae: 0.2906
# Epoch 392/30000
#  - 3s - loss: 0.1669 - mse: 0.0969 - mae: 0.1669 - val_loss: 0.2897 - val_mse: 0.2503 - val_mae: 0.2897
# Epoch 393/30000
#  - 3s - loss: 0.1665 - mse: 0.0949 - mae: 0.1665 - val_loss: 0.2928 - val_mse: 0.2561 - val_mae: 0.2928
# Epoch 394/30000
#  - 3s - loss: 0.1653 - mse: 0.0961 - mae: 0.1653 - val_loss: 0.2883 - val_mse: 0.2511 - val_mae: 0.2883
# Epoch 395/30000
#  - 3s - loss: 0.1663 - mse: 0.0928 - mae: 0.1663 - val_loss: 0.2896 - val_mse: 0.2524 - val_mae: 0.2896
# Epoch 396/30000
#  - 3s - loss: 0.1653 - mse: 0.0924 - mae: 0.1653 - val_loss: 0.2909 - val_mse: 0.2518 - val_mae: 0.2909
# Epoch 397/30000
#  - 3s - loss: 0.1631 - mse: 0.0895 - mae: 0.1631 - val_loss: 0.2872 - val_mse: 0.2482 - val_mae: 0.2872
# Epoch 398/30000
#  - 3s - loss: 0.1656 - mse: 0.0918 - mae: 0.1656 - val_loss: 0.2882 - val_mse: 0.2497 - val_mae: 0.2882
# Epoch 399/30000
#  - 3s - loss: 0.1629 - mse: 0.0908 - mae: 0.1629 - val_loss: 0.2940 - val_mse: 0.2548 - val_mae: 0.2940
# Epoch 400/30000
#  - 3s - loss: 0.1635 - mse: 0.0916 - mae: 0.1635 - val_loss: 0.2929 - val_mse: 0.2557 - val_mae: 0.2929
# Epoch 401/30000
#  - 3s - loss: 0.1631 - mse: 0.0913 - mae: 0.1631 - val_loss: 0.2964 - val_mse: 0.2579 - val_mae: 0.2964
# Epoch 402/30000
#  - 3s - loss: 0.1636 - mse: 0.0909 - mae: 0.1636 - val_loss: 0.2894 - val_mse: 0.2503 - val_mae: 0.2894
# Epoch 403/30000
#  - 3s - loss: 0.1640 - mse: 0.0918 - mae: 0.1640 - val_loss: 0.2885 - val_mse: 0.2490 - val_mae: 0.2885
# Epoch 404/30000
#  - 3s - loss: 0.1638 - mse: 0.0915 - mae: 0.1638 - val_loss: 0.2857 - val_mse: 0.2478 - val_mae: 0.2857
# Epoch 405/30000
#  - 3s - loss: 0.1633 - mse: 0.0903 - mae: 0.1633 - val_loss: 0.2900 - val_mse: 0.2543 - val_mae: 0.2900
# Epoch 406/30000
#  - 3s - loss: 0.1652 - mse: 0.0931 - mae: 0.1652 - val_loss: 0.2886 - val_mse: 0.2522 - val_mae: 0.2886
# Epoch 407/30000
#  - 3s - loss: 0.1626 - mse: 0.0920 - mae: 0.1626 - val_loss: 0.2925 - val_mse: 0.2534 - val_mae: 0.2925
# Epoch 408/30000
#  - 3s - loss: 0.1630 - mse: 0.0910 - mae: 0.1630 - val_loss: 0.2916 - val_mse: 0.2506 - val_mae: 0.2916
# Epoch 409/30000
#  - 3s - loss: 0.1642 - mse: 0.0927 - mae: 0.1642 - val_loss: 0.2884 - val_mse: 0.2501 - val_mae: 0.2884
# Epoch 410/30000
#  - 3s - loss: 0.1630 - mse: 0.0932 - mae: 0.1630 - val_loss: 0.2891 - val_mse: 0.2494 - val_mae: 0.2891
# Epoch 411/30000
#  - 3s - loss: 0.1600 - mse: 0.0888 - mae: 0.1600 - val_loss: 0.2890 - val_mse: 0.2466 - val_mae: 0.2890
# Epoch 412/30000
#  - 3s - loss: 0.1651 - mse: 0.0911 - mae: 0.1651 - val_loss: 0.2937 - val_mse: 0.2550 - val_mae: 0.2937
# Epoch 413/30000
#  - 3s - loss: 0.1648 - mse: 0.0919 - mae: 0.1648 - val_loss: 0.2924 - val_mse: 0.2516 - val_mae: 0.2924
# Epoch 414/30000
#  - 3s - loss: 0.1651 - mse: 0.0925 - mae: 0.1651 - val_loss: 0.2925 - val_mse: 0.2494 - val_mae: 0.2925
# Epoch 415/30000
#  - 3s - loss: 0.1640 - mse: 0.0935 - mae: 0.1640 - val_loss: 0.2891 - val_mse: 0.2480 - val_mae: 0.2891
# Epoch 416/30000
#  - 3s - loss: 0.1634 - mse: 0.0911 - mae: 0.1634 - val_loss: 0.2873 - val_mse: 0.2483 - val_mae: 0.2873
# Epoch 417/30000
#  - 3s - loss: 0.1637 - mse: 0.0931 - mae: 0.1637 - val_loss: 0.2900 - val_mse: 0.2541 - val_mae: 0.2900
# Epoch 418/30000
#  - 3s - loss: 0.1618 - mse: 0.0911 - mae: 0.1618 - val_loss: 0.2885 - val_mse: 0.2499 - val_mae: 0.2885
# Epoch 419/30000
#  - 3s - loss: 0.1610 - mse: 0.0904 - mae: 0.1610 - val_loss: 0.2864 - val_mse: 0.2505 - val_mae: 0.2864
# Epoch 420/30000
#  - 3s - loss: 0.1612 - mse: 0.0911 - mae: 0.1612 - val_loss: 0.3002 - val_mse: 0.2616 - val_mae: 0.3002
# Epoch 421/30000
#  - 3s - loss: 0.1637 - mse: 0.0894 - mae: 0.1637 - val_loss: 0.2848 - val_mse: 0.2479 - val_mae: 0.2848
# Epoch 422/30000
#  - 3s - loss: 0.1629 - mse: 0.0896 - mae: 0.1629 - val_loss: 0.2891 - val_mse: 0.2534 - val_mae: 0.2891
# Epoch 423/30000
#  - 3s - loss: 0.1629 - mse: 0.0919 - mae: 0.1629 - val_loss: 0.2901 - val_mse: 0.2515 - val_mae: 0.2901
# Epoch 424/30000
#  - 3s - loss: 0.1632 - mse: 0.0914 - mae: 0.1632 - val_loss: 0.2901 - val_mse: 0.2527 - val_mae: 0.2901
# Epoch 425/30000
#  - 3s - loss: 0.1614 - mse: 0.0897 - mae: 0.1614 - val_loss: 0.2886 - val_mse: 0.2515 - val_mae: 0.2886
# Epoch 426/30000
#  - 3s - loss: 0.1641 - mse: 0.0903 - mae: 0.1641 - val_loss: 0.2869 - val_mse: 0.2505 - val_mae: 0.2869
# Epoch 427/30000
#  - 3s - loss: 0.1620 - mse: 0.0898 - mae: 0.1620 - val_loss: 0.2883 - val_mse: 0.2520 - val_mae: 0.2883
# Epoch 428/30000
#  - 3s - loss: 0.1611 - mse: 0.0901 - mae: 0.1611 - val_loss: 0.2876 - val_mse: 0.2499 - val_mae: 0.2876
# Epoch 429/30000
#  - 3s - loss: 0.1590 - mse: 0.0874 - mae: 0.1590 - val_loss: 0.2904 - val_mse: 0.2503 - val_mae: 0.2904
# Epoch 430/30000
#  - 3s - loss: 0.1608 - mse: 0.0876 - mae: 0.1608 - val_loss: 0.2864 - val_mse: 0.2481 - val_mae: 0.2864
# Epoch 431/30000
#  - 3s - loss: 0.1610 - mse: 0.0879 - mae: 0.1610 - val_loss: 0.2915 - val_mse: 0.2529 - val_mae: 0.2915
# Epoch 432/30000
#  - 3s - loss: 0.1611 - mse: 0.0884 - mae: 0.1611 - val_loss: 0.2876 - val_mse: 0.2517 - val_mae: 0.2876
# Epoch 433/30000
#  - 3s - loss: 0.1620 - mse: 0.0899 - mae: 0.1620 - val_loss: 0.2872 - val_mse: 0.2472 - val_mae: 0.2872
# Epoch 434/30000
#  - 3s - loss: 0.1610 - mse: 0.0883 - mae: 0.1610 - val_loss: 0.2916 - val_mse: 0.2496 - val_mae: 0.2916
# Epoch 435/30000
#  - 3s - loss: 0.1599 - mse: 0.0886 - mae: 0.1599 - val_loss: 0.2934 - val_mse: 0.2576 - val_mae: 0.2934
# Epoch 436/30000
#  - 3s - loss: 0.1594 - mse: 0.0890 - mae: 0.1594 - val_loss: 0.2876 - val_mse: 0.2501 - val_mae: 0.2876
# Epoch 437/30000
#  - 3s - loss: 0.1608 - mse: 0.0871 - mae: 0.1608 - val_loss: 0.2900 - val_mse: 0.2513 - val_mae: 0.2900
# Epoch 438/30000
#  - 3s - loss: 0.1597 - mse: 0.0888 - mae: 0.1597 - val_loss: 0.2955 - val_mse: 0.2534 - val_mae: 0.2955
# Epoch 439/30000
#  - 3s - loss: 0.1601 - mse: 0.0887 - mae: 0.1601 - val_loss: 0.2928 - val_mse: 0.2555 - val_mae: 0.2928
# Epoch 440/30000
#  - 3s - loss: 0.1593 - mse: 0.0865 - mae: 0.1593 - val_loss: 0.2877 - val_mse: 0.2507 - val_mae: 0.2877
# Epoch 441/30000
#  - 3s - loss: 0.1590 - mse: 0.0867 - mae: 0.1590 - val_loss: 0.2885 - val_mse: 0.2488 - val_mae: 0.2885
# Epoch 442/30000
#  - 3s - loss: 0.1589 - mse: 0.0859 - mae: 0.1589 - val_loss: 0.2879 - val_mse: 0.2501 - val_mae: 0.2879
# Epoch 443/30000
#  - 3s - loss: 0.1593 - mse: 0.0858 - mae: 0.1593 - val_loss: 0.2908 - val_mse: 0.2515 - val_mae: 0.2908
# Epoch 444/30000
#  - 3s - loss: 0.1577 - mse: 0.0862 - mae: 0.1577 - val_loss: 0.2881 - val_mse: 0.2491 - val_mae: 0.2881
# Epoch 445/30000
#  - 3s - loss: 0.1585 - mse: 0.0884 - mae: 0.1585 - val_loss: 0.2865 - val_mse: 0.2467 - val_mae: 0.2865
# Epoch 446/30000
#  - 3s - loss: 0.1597 - mse: 0.0890 - mae: 0.1597 - val_loss: 0.2888 - val_mse: 0.2487 - val_mae: 0.2888
# Epoch 447/30000
#  - 3s - loss: 0.1578 - mse: 0.0859 - mae: 0.1578 - val_loss: 0.2906 - val_mse: 0.2464 - val_mae: 0.2906
# Epoch 448/30000
#  - 3s - loss: 0.1599 - mse: 0.0872 - mae: 0.1599 - val_loss: 0.2894 - val_mse: 0.2487 - val_mae: 0.2894
# Epoch 449/30000
#  - 3s - loss: 0.1589 - mse: 0.0868 - mae: 0.1589 - val_loss: 0.2891 - val_mse: 0.2447 - val_mae: 0.2891
# Epoch 450/30000
#  - 3s - loss: 0.1601 - mse: 0.0864 - mae: 0.1601 - val_loss: 0.2855 - val_mse: 0.2460 - val_mae: 0.2855
# Epoch 451/30000
#  - 3s - loss: 0.1607 - mse: 0.0876 - mae: 0.1607 - val_loss: 0.2895 - val_mse: 0.2491 - val_mae: 0.2895
# Epoch 452/30000
#  - 3s - loss: 0.1574 - mse: 0.0847 - mae: 0.1574 - val_loss: 0.2929 - val_mse: 0.2552 - val_mae: 0.2929
# Epoch 453/30000
#  - 3s - loss: 0.1575 - mse: 0.0849 - mae: 0.1575 - val_loss: 0.2894 - val_mse: 0.2515 - val_mae: 0.2894
# Epoch 454/30000
#  - 3s - loss: 0.1592 - mse: 0.0878 - mae: 0.1592 - val_loss: 0.2861 - val_mse: 0.2456 - val_mae: 0.2861
# Epoch 455/30000
#  - 3s - loss: 0.1582 - mse: 0.0870 - mae: 0.1582 - val_loss: 0.2873 - val_mse: 0.2516 - val_mae: 0.2873
# Epoch 456/30000
#  - 3s - loss: 0.1598 - mse: 0.0892 - mae: 0.1598 - val_loss: 0.2880 - val_mse: 0.2510 - val_mae: 0.2880
# Epoch 457/30000
#  - 3s - loss: 0.1554 - mse: 0.0831 - mae: 0.1554 - val_loss: 0.2863 - val_mse: 0.2468 - val_mae: 0.2863
# Epoch 458/30000
#  - 3s - loss: 0.1584 - mse: 0.0859 - mae: 0.1584 - val_loss: 0.2895 - val_mse: 0.2488 - val_mae: 0.2895
# Epoch 459/30000
#  - 3s - loss: 0.1578 - mse: 0.0842 - mae: 0.1578 - val_loss: 0.2864 - val_mse: 0.2496 - val_mae: 0.2864
# Epoch 460/30000
#  - 3s - loss: 0.1587 - mse: 0.0876 - mae: 0.1587 - val_loss: 0.2934 - val_mse: 0.2541 - val_mae: 0.2934
# Epoch 461/30000
#  - 3s - loss: 0.1604 - mse: 0.0883 - mae: 0.1604 - val_loss: 0.2876 - val_mse: 0.2486 - val_mae: 0.2876
# Epoch 462/30000
#  - 3s - loss: 0.1579 - mse: 0.0870 - mae: 0.1579 - val_loss: 0.2903 - val_mse: 0.2511 - val_mae: 0.2903
# Epoch 463/30000
#  - 3s - loss: 0.1572 - mse: 0.0862 - mae: 0.1572 - val_loss: 0.2861 - val_mse: 0.2483 - val_mae: 0.2861
# Epoch 464/30000
#  - 3s - loss: 0.1567 - mse: 0.0852 - mae: 0.1567 - val_loss: 0.2879 - val_mse: 0.2506 - val_mae: 0.2879
# Epoch 465/30000
#  - 3s - loss: 0.1582 - mse: 0.0869 - mae: 0.1582 - val_loss: 0.2889 - val_mse: 0.2506 - val_mae: 0.2889
# Epoch 466/30000
#  - 3s - loss: 0.1574 - mse: 0.0848 - mae: 0.1574 - val_loss: 0.2864 - val_mse: 0.2474 - val_mae: 0.2864
# Epoch 467/30000
#  - 3s - loss: 0.1556 - mse: 0.0840 - mae: 0.1556 - val_loss: 0.2881 - val_mse: 0.2482 - val_mae: 0.2881
# Epoch 468/30000
#  - 3s - loss: 0.1561 - mse: 0.0841 - mae: 0.1561 - val_loss: 0.2917 - val_mse: 0.2535 - val_mae: 0.2917
# Epoch 469/30000
#  - 3s - loss: 0.1598 - mse: 0.0871 - mae: 0.1598 - val_loss: 0.2910 - val_mse: 0.2469 - val_mae: 0.2910
# Epoch 470/30000
#  - 3s - loss: 0.1561 - mse: 0.0839 - mae: 0.1561 - val_loss: 0.2905 - val_mse: 0.2494 - val_mae: 0.2905
# Epoch 471/30000
#  - 3s - loss: 0.1576 - mse: 0.0835 - mae: 0.1576 - val_loss: 0.2874 - val_mse: 0.2496 - val_mae: 0.2874

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is 0.09 degrees
# Root Mean Squared Error is 1.46 degrees
# Mean Absolute Error is 1.46 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is -0.00 degrees
# Root Mean Squared Error is 3.88 degrees
# Mean Absolute Error is 3.88 degrees

# %%
save_notebookparams = 0
if save_notebookparams:
    pkl_filename = "depthmodelparam_cnn3v10.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthmodel_cnn3v10.h5')
