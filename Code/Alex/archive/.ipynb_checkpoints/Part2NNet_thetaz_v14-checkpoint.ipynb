# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,30,31,32,33,35)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (28044, 60, 80, 3)

# %%
# tlen = len(xtemp[0])-2 +len(xtemp[1])-2+len(xtemp[2])+len(xtemp[3]) #remove 2 samples from 24
# x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
# x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
# x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

tlen = len(xtemp[0]) +len(xtemp[1])+len(xtemp[2])+len(xtemp[3])+len(xtemp[4])+len(xtemp[5]) #remove 2 samples from 24 and 3 from 25
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
xrun = len(xtemp[0])
x_train[:xrun,:,:,:] = xtemp[0][:xrun,:,:,:]
xrun1 = xrun + len(xtemp[1])
x_train[xrun:xrun1,:,:,:]=xtemp[1][:xrun1-xrun,:,:,:]
xrun2 = xrun1 + len(xtemp[2])
x_train[xrun1:xrun2,:,:,:] = xtemp[2][:xrun2-xrun1,:,:,:]
xrun3 = xrun2 + len(xtemp[3])
x_train[xrun2:xrun3,:,:,:] = xtemp[3][:xrun3-xrun2,:,:,:]
xrun4 = xrun3 + len(xtemp[4])
x_train[xrun3:xrun4,:,:,:] = xtemp[4][:xrun4-xrun3,:,:,:]
xrun5 = xrun4 + len(xtemp[5])
x_train[xrun4:xrun5,:,:,:] = xtemp[5][:xrun5-xrun4,:,:,:]

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,30,31,32,33,35)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020')
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
y_train = np.zeros((tlen,1))
xrun = len(y_gt[0])
y_train[:xrun] = y_gt[0][:xrun]
xrun1 = xrun + len(y_gt[1])
y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
xrun2 = xrun1 + len(y_gt[2])
y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
xrun3 = xrun2 + len(y_gt[3])
y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
xrun4 = xrun3 + len(y_gt[4])
y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
xrun5 = xrun4 + len(y_gt[5])
y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (82381, 60, 80, 3)
# (82381, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %% [markdown]
# # Regress using Neural Network

# %%
np.max(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 1.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.2
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# # model_cnn = BatchNormalization()(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# # model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Using TensorFlow backend.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 60, 80, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 80, 8)         224
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 80, 8)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 30, 40, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 40, 16)        1168
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 40, 16)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 15, 20, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 20, 32)        4640
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 20, 32)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 7, 10, 32)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 10, 64)         18496
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 10, 64)         0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 3, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 960)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               123008
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 147,665
# Trainable params: 147,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 65904 samples, validate on 16477 samples
# Epoch 1/30000
#  - 8s - loss: 0.6165 - mse: 0.9161 - mae: 0.6165 - val_loss: 0.5605 - val_mse: 0.7442 - val_mae: 0.5605
# Epoch 2/30000
#  - 6s - loss: 0.5671 - mse: 0.8085 - mae: 0.5671 - val_loss: 0.5396 - val_mse: 0.7010 - val_mae: 0.5396
# Epoch 3/30000
#  - 6s - loss: 0.5415 - mse: 0.7658 - mae: 0.5415 - val_loss: 0.5146 - val_mse: 0.6622 - val_mae: 0.5146
# Epoch 4/30000
#  - 6s - loss: 0.5233 - mse: 0.7356 - mae: 0.5233 - val_loss: 0.5012 - val_mse: 0.6350 - val_mae: 0.5012
# Epoch 5/30000
#  - 6s - loss: 0.5092 - mse: 0.7132 - mae: 0.5092 - val_loss: 0.4827 - val_mse: 0.6119 - val_mae: 0.4827
# Epoch 6/30000
#  - 6s - loss: 0.4939 - mse: 0.6906 - mae: 0.4939 - val_loss: 0.4732 - val_mse: 0.5962 - val_mae: 0.4732
# Epoch 7/30000
#  - 6s - loss: 0.4829 - mse: 0.6741 - mae: 0.4829 - val_loss: 0.4560 - val_mse: 0.5762 - val_mae: 0.4560
# Epoch 8/30000
#  - 6s - loss: 0.4688 - mse: 0.6525 - mae: 0.4688 - val_loss: 0.4427 - val_mse: 0.5557 - val_mae: 0.4427
# Epoch 9/30000
#  - 6s - loss: 0.4582 - mse: 0.6367 - mae: 0.4582 - val_loss: 0.4394 - val_mse: 0.5511 - val_mae: 0.4394
# Epoch 10/30000
#  - 6s - loss: 0.4478 - mse: 0.6206 - mae: 0.4478 - val_loss: 0.4284 - val_mse: 0.5365 - val_mae: 0.4284
# Epoch 11/30000
#  - 6s - loss: 0.4402 - mse: 0.6091 - mae: 0.4402 - val_loss: 0.4160 - val_mse: 0.5189 - val_mae: 0.4160
# Epoch 12/30000
#  - 6s - loss: 0.4308 - mse: 0.5962 - mae: 0.4308 - val_loss: 0.4101 - val_mse: 0.5127 - val_mae: 0.4101
# Epoch 13/30000
#  - 6s - loss: 0.4230 - mse: 0.5848 - mae: 0.4230 - val_loss: 0.4005 - val_mse: 0.5017 - val_mae: 0.4005
# Epoch 14/30000
#  - 6s - loss: 0.4178 - mse: 0.5786 - mae: 0.4178 - val_loss: 0.3950 - val_mse: 0.4929 - val_mae: 0.3950
# Epoch 15/30000
#  - 6s - loss: 0.4071 - mse: 0.5638 - mae: 0.4071 - val_loss: 0.3878 - val_mse: 0.4811 - val_mae: 0.3878
# Epoch 16/30000
#  - 6s - loss: 0.4012 - mse: 0.5562 - mae: 0.4012 - val_loss: 0.3852 - val_mse: 0.4799 - val_mae: 0.3852
# Epoch 17/30000
#  - 6s - loss: 0.3972 - mse: 0.5503 - mae: 0.3972 - val_loss: 0.3853 - val_mse: 0.4785 - val_mae: 0.3853
# Epoch 18/30000
#  - 6s - loss: 0.3904 - mse: 0.5405 - mae: 0.3904 - val_loss: 0.3790 - val_mse: 0.4727 - val_mae: 0.3790
# Epoch 19/30000
#  - 6s - loss: 0.3863 - mse: 0.5366 - mae: 0.3863 - val_loss: 0.3853 - val_mse: 0.4782 - val_mae: 0.3853
# Epoch 20/30000
#  - 6s - loss: 0.3815 - mse: 0.5294 - mae: 0.3815 - val_loss: 0.3657 - val_mse: 0.4543 - val_mae: 0.3657
# Epoch 21/30000
#  - 6s - loss: 0.3744 - mse: 0.5209 - mae: 0.3744 - val_loss: 0.3676 - val_mse: 0.4543 - val_mae: 0.3676
# Epoch 22/30000
#  - 6s - loss: 0.3714 - mse: 0.5149 - mae: 0.3714 - val_loss: 0.3611 - val_mse: 0.4463 - val_mae: 0.3611
# Epoch 23/30000
#  - 6s - loss: 0.3665 - mse: 0.5084 - mae: 0.3665 - val_loss: 0.3539 - val_mse: 0.4409 - val_mae: 0.3539
# Epoch 24/30000
#  - 6s - loss: 0.3631 - mse: 0.5025 - mae: 0.3631 - val_loss: 0.3494 - val_mse: 0.4331 - val_mae: 0.3494
# Epoch 25/30000
#  - 6s - loss: 0.3603 - mse: 0.4960 - mae: 0.3603 - val_loss: 0.3565 - val_mse: 0.4375 - val_mae: 0.3565
# Epoch 26/30000
#  - 6s - loss: 0.3539 - mse: 0.4849 - mae: 0.3539 - val_loss: 0.3457 - val_mse: 0.4281 - val_mae: 0.3457
# Epoch 27/30000
#  - 6s - loss: 0.3513 - mse: 0.4809 - mae: 0.3513 - val_loss: 0.3390 - val_mse: 0.4200 - val_mae: 0.3390
# Epoch 28/30000
#  - 6s - loss: 0.3467 - mse: 0.4710 - mae: 0.3467 - val_loss: 0.3449 - val_mse: 0.4215 - val_mae: 0.3449
# Epoch 29/30000
#  - 6s - loss: 0.3438 - mse: 0.4637 - mae: 0.3438 - val_loss: 0.3391 - val_mse: 0.4150 - val_mae: 0.3391
# Epoch 30/30000
#  - 6s - loss: 0.3402 - mse: 0.4592 - mae: 0.3402 - val_loss: 0.3474 - val_mse: 0.4259 - val_mae: 0.3474
# Epoch 31/30000
#  - 6s - loss: 0.3362 - mse: 0.4519 - mae: 0.3362 - val_loss: 0.3379 - val_mse: 0.4114 - val_mae: 0.3379
# Epoch 32/30000
#  - 6s - loss: 0.3325 - mse: 0.4450 - mae: 0.3325 - val_loss: 0.3348 - val_mse: 0.4116 - val_mae: 0.3348
# Epoch 33/30000
#  - 6s - loss: 0.3311 - mse: 0.4447 - mae: 0.3311 - val_loss: 0.3333 - val_mse: 0.4090 - val_mae: 0.3333
# Epoch 34/30000
#  - 6s - loss: 0.3279 - mse: 0.4420 - mae: 0.3279 - val_loss: 0.3240 - val_mse: 0.3980 - val_mae: 0.3240
# Epoch 35/30000
#  - 6s - loss: 0.3251 - mse: 0.4381 - mae: 0.3251 - val_loss: 0.3197 - val_mse: 0.3914 - val_mae: 0.3197
# Epoch 36/30000
#  - 6s - loss: 0.3232 - mse: 0.4355 - mae: 0.3232 - val_loss: 0.3234 - val_mse: 0.3903 - val_mae: 0.3234
# Epoch 37/30000
#  - 6s - loss: 0.3213 - mse: 0.4320 - mae: 0.3213 - val_loss: 0.3174 - val_mse: 0.3850 - val_mae: 0.3174
# Epoch 38/30000
#  - 6s - loss: 0.3174 - mse: 0.4264 - mae: 0.3174 - val_loss: 0.3185 - val_mse: 0.3886 - val_mae: 0.3185
# Epoch 39/30000
#  - 6s - loss: 0.3154 - mse: 0.4244 - mae: 0.3154 - val_loss: 0.3221 - val_mse: 0.3923 - val_mae: 0.3221
# Epoch 40/30000
#  - 6s - loss: 0.3131 - mse: 0.4207 - mae: 0.3131 - val_loss: 0.3190 - val_mse: 0.3846 - val_mae: 0.3190
# Epoch 41/30000
#  - 6s - loss: 0.3114 - mse: 0.4191 - mae: 0.3114 - val_loss: 0.3110 - val_mse: 0.3764 - val_mae: 0.3110
# Epoch 42/30000
#  - 6s - loss: 0.3086 - mse: 0.4154 - mae: 0.3086 - val_loss: 0.3075 - val_mse: 0.3758 - val_mae: 0.3075
# Epoch 43/30000
#  - 6s - loss: 0.3090 - mse: 0.4138 - mae: 0.3090 - val_loss: 0.3076 - val_mse: 0.3718 - val_mae: 0.3076
# Epoch 44/30000
#  - 6s - loss: 0.3051 - mse: 0.4089 - mae: 0.3051 - val_loss: 0.3091 - val_mse: 0.3727 - val_mae: 0.3091
# Epoch 45/30000
#  - 6s - loss: 0.3043 - mse: 0.4093 - mae: 0.3043 - val_loss: 0.3028 - val_mse: 0.3649 - val_mae: 0.3028
# Epoch 46/30000
#  - 6s - loss: 0.3009 - mse: 0.4051 - mae: 0.3009 - val_loss: 0.3011 - val_mse: 0.3638 - val_mae: 0.3011
# Epoch 47/30000
#  - 6s - loss: 0.3015 - mse: 0.4033 - mae: 0.3015 - val_loss: 0.3007 - val_mse: 0.3593 - val_mae: 0.3007
# Epoch 48/30000
#  - 6s - loss: 0.2987 - mse: 0.4007 - mae: 0.2987 - val_loss: 0.2985 - val_mse: 0.3571 - val_mae: 0.2985
# Epoch 49/30000
#  - 6s - loss: 0.2968 - mse: 0.3969 - mae: 0.2968 - val_loss: 0.3037 - val_mse: 0.3650 - val_mae: 0.3037
# Epoch 50/30000
#  - 6s - loss: 0.2954 - mse: 0.3963 - mae: 0.2954 - val_loss: 0.2995 - val_mse: 0.3577 - val_mae: 0.2995
# Epoch 51/30000
#  - 6s - loss: 0.2931 - mse: 0.3904 - mae: 0.2931 - val_loss: 0.2976 - val_mse: 0.3591 - val_mae: 0.2976
# Epoch 52/30000
#  - 6s - loss: 0.2917 - mse: 0.3919 - mae: 0.2917 - val_loss: 0.2978 - val_mse: 0.3512 - val_mae: 0.2978
# Epoch 53/30000
#  - 6s - loss: 0.2894 - mse: 0.3881 - mae: 0.2894 - val_loss: 0.2910 - val_mse: 0.3454 - val_mae: 0.2910
# Epoch 54/30000
#  - 6s - loss: 0.2879 - mse: 0.3856 - mae: 0.2879 - val_loss: 0.2888 - val_mse: 0.3450 - val_mae: 0.2888
# Epoch 55/30000
#  - 6s - loss: 0.2888 - mse: 0.3863 - mae: 0.2888 - val_loss: 0.2993 - val_mse: 0.3515 - val_mae: 0.2993
# Epoch 56/30000
#  - 6s - loss: 0.2879 - mse: 0.3848 - mae: 0.2879 - val_loss: 0.2968 - val_mse: 0.3513 - val_mae: 0.2968
# Epoch 57/30000
#  - 6s - loss: 0.2851 - mse: 0.3812 - mae: 0.2851 - val_loss: 0.3008 - val_mse: 0.3513 - val_mae: 0.3008
# Epoch 58/30000
#  - 6s - loss: 0.2840 - mse: 0.3764 - mae: 0.2840 - val_loss: 0.2904 - val_mse: 0.3407 - val_mae: 0.2904
# Epoch 59/30000
#  - 6s - loss: 0.2821 - mse: 0.3739 - mae: 0.2821 - val_loss: 0.2893 - val_mse: 0.3420 - val_mae: 0.2893
# Epoch 60/30000
#  - 6s - loss: 0.2816 - mse: 0.3733 - mae: 0.2816 - val_loss: 0.2863 - val_mse: 0.3359 - val_mae: 0.2863
# Epoch 61/30000
#  - 6s - loss: 0.2792 - mse: 0.3690 - mae: 0.2792 - val_loss: 0.2832 - val_mse: 0.3324 - val_mae: 0.2832
# Epoch 62/30000
#  - 6s - loss: 0.2791 - mse: 0.3693 - mae: 0.2791 - val_loss: 0.2894 - val_mse: 0.3358 - val_mae: 0.2894
# Epoch 63/30000
#  - 6s - loss: 0.2773 - mse: 0.3658 - mae: 0.2773 - val_loss: 0.2871 - val_mse: 0.3309 - val_mae: 0.2871
# Epoch 64/30000
#  - 6s - loss: 0.2767 - mse: 0.3646 - mae: 0.2767 - val_loss: 0.2900 - val_mse: 0.3384 - val_mae: 0.2900
# Epoch 65/30000
#  - 6s - loss: 0.2771 - mse: 0.3637 - mae: 0.2771 - val_loss: 0.2895 - val_mse: 0.3286 - val_mae: 0.2895
# Epoch 66/30000
#  - 6s - loss: 0.2730 - mse: 0.3590 - mae: 0.2730 - val_loss: 0.2904 - val_mse: 0.3304 - val_mae: 0.2904
# Epoch 67/30000
#  - 6s - loss: 0.2717 - mse: 0.3549 - mae: 0.2717 - val_loss: 0.2852 - val_mse: 0.3244 - val_mae: 0.2852
# Epoch 68/30000
#  - 6s - loss: 0.2720 - mse: 0.3534 - mae: 0.2720 - val_loss: 0.2861 - val_mse: 0.3293 - val_mae: 0.2861
# Epoch 69/30000
#  - 6s - loss: 0.2715 - mse: 0.3528 - mae: 0.2715 - val_loss: 0.2762 - val_mse: 0.3151 - val_mae: 0.2762
# Epoch 70/30000
#  - 6s - loss: 0.2698 - mse: 0.3496 - mae: 0.2698 - val_loss: 0.2785 - val_mse: 0.3201 - val_mae: 0.2785
# Epoch 71/30000
#  - 6s - loss: 0.2693 - mse: 0.3494 - mae: 0.2693 - val_loss: 0.2809 - val_mse: 0.3135 - val_mae: 0.2809
# Epoch 72/30000
#  - 6s - loss: 0.2683 - mse: 0.3459 - mae: 0.2683 - val_loss: 0.2837 - val_mse: 0.3161 - val_mae: 0.2837
# Epoch 73/30000
#  - 6s - loss: 0.2673 - mse: 0.3455 - mae: 0.2673 - val_loss: 0.2785 - val_mse: 0.3165 - val_mae: 0.2785
# Epoch 74/30000
#  - 6s - loss: 0.2661 - mse: 0.3406 - mae: 0.2661 - val_loss: 0.2807 - val_mse: 0.3119 - val_mae: 0.2807
# Epoch 75/30000
#  - 6s - loss: 0.2648 - mse: 0.3359 - mae: 0.2648 - val_loss: 0.2780 - val_mse: 0.3134 - val_mae: 0.2780
# Epoch 76/30000
#  - 6s - loss: 0.2642 - mse: 0.3347 - mae: 0.2642 - val_loss: 0.2811 - val_mse: 0.3182 - val_mae: 0.2811
# Epoch 77/30000
#  - 6s - loss: 0.2628 - mse: 0.3335 - mae: 0.2628 - val_loss: 0.2803 - val_mse: 0.3100 - val_mae: 0.2803
# Epoch 78/30000
#  - 6s - loss: 0.2620 - mse: 0.3325 - mae: 0.2620 - val_loss: 0.2778 - val_mse: 0.3040 - val_mae: 0.2778
# Epoch 79/30000
#  - 6s - loss: 0.2624 - mse: 0.3298 - mae: 0.2624 - val_loss: 0.2778 - val_mse: 0.3021 - val_mae: 0.2778
# Epoch 80/30000
#  - 6s - loss: 0.2586 - mse: 0.3236 - mae: 0.2586 - val_loss: 0.2739 - val_mse: 0.3013 - val_mae: 0.2739
# Epoch 81/30000
#  - 6s - loss: 0.2596 - mse: 0.3230 - mae: 0.2596 - val_loss: 0.2751 - val_mse: 0.3000 - val_mae: 0.2751
# Epoch 82/30000
#  - 6s - loss: 0.2581 - mse: 0.3205 - mae: 0.2581 - val_loss: 0.2687 - val_mse: 0.2929 - val_mae: 0.2687
# Epoch 83/30000
#  - 6s - loss: 0.2579 - mse: 0.3191 - mae: 0.2579 - val_loss: 0.2746 - val_mse: 0.2961 - val_mae: 0.2746
# Epoch 84/30000
#  - 6s - loss: 0.2563 - mse: 0.3122 - mae: 0.2563 - val_loss: 0.2678 - val_mse: 0.2938 - val_mae: 0.2678
# Epoch 85/30000
#  - 6s - loss: 0.2554 - mse: 0.3151 - mae: 0.2554 - val_loss: 0.2720 - val_mse: 0.2915 - val_mae: 0.2720
# Epoch 86/30000
#  - 6s - loss: 0.2551 - mse: 0.3122 - mae: 0.2551 - val_loss: 0.2735 - val_mse: 0.2982 - val_mae: 0.2735
# Epoch 87/30000
#  - 6s - loss: 0.2539 - mse: 0.3138 - mae: 0.2539 - val_loss: 0.2695 - val_mse: 0.2896 - val_mae: 0.2695
# Epoch 88/30000
#  - 6s - loss: 0.2532 - mse: 0.3047 - mae: 0.2532 - val_loss: 0.2705 - val_mse: 0.2889 - val_mae: 0.2705
# Epoch 89/30000
#  - 6s - loss: 0.2513 - mse: 0.3088 - mae: 0.2513 - val_loss: 0.2681 - val_mse: 0.2890 - val_mae: 0.2681
# Epoch 90/30000
#  - 6s - loss: 0.2526 - mse: 0.3020 - mae: 0.2526 - val_loss: 0.2723 - val_mse: 0.2933 - val_mae: 0.2723
# Epoch 91/30000
#  - 6s - loss: 0.2521 - mse: 0.3081 - mae: 0.2521 - val_loss: 0.2658 - val_mse: 0.2846 - val_mae: 0.2658
# Epoch 92/30000
#  - 6s - loss: 0.2518 - mse: 0.3059 - mae: 0.2518 - val_loss: 0.2658 - val_mse: 0.2818 - val_mae: 0.2658
# Epoch 93/30000
#  - 6s - loss: 0.2518 - mse: 0.3026 - mae: 0.2518 - val_loss: 0.2690 - val_mse: 0.2878 - val_mae: 0.2690
# Epoch 94/30000
#  - 6s - loss: 0.2482 - mse: 0.2970 - mae: 0.2482 - val_loss: 0.2660 - val_mse: 0.2886 - val_mae: 0.2660
# Epoch 95/30000
#  - 6s - loss: 0.2474 - mse: 0.2976 - mae: 0.2474 - val_loss: 0.2675 - val_mse: 0.2857 - val_mae: 0.2675
# Epoch 96/30000
#  - 6s - loss: 0.2476 - mse: 0.2957 - mae: 0.2476 - val_loss: 0.2651 - val_mse: 0.2814 - val_mae: 0.2651
# Epoch 97/30000
#  - 6s - loss: 0.2452 - mse: 0.2916 - mae: 0.2452 - val_loss: 0.2637 - val_mse: 0.2763 - val_mae: 0.2637
# Epoch 98/30000
#  - 6s - loss: 0.2455 - mse: 0.2918 - mae: 0.2455 - val_loss: 0.2679 - val_mse: 0.2830 - val_mae: 0.2679
# Epoch 99/30000
#  - 6s - loss: 0.2424 - mse: 0.2863 - mae: 0.2424 - val_loss: 0.2649 - val_mse: 0.2829 - val_mae: 0.2649
# Epoch 100/30000
#  - 6s - loss: 0.2433 - mse: 0.2885 - mae: 0.2433 - val_loss: 0.2645 - val_mse: 0.2839 - val_mae: 0.2645
# Epoch 101/30000
#  - 6s - loss: 0.2427 - mse: 0.2868 - mae: 0.2427 - val_loss: 0.2638 - val_mse: 0.2807 - val_mae: 0.2638
# Epoch 102/30000
#  - 6s - loss: 0.2425 - mse: 0.2881 - mae: 0.2425 - val_loss: 0.2615 - val_mse: 0.2740 - val_mae: 0.2615
# Epoch 103/30000
#  - 6s - loss: 0.2427 - mse: 0.2847 - mae: 0.2427 - val_loss: 0.2628 - val_mse: 0.2782 - val_mae: 0.2628
# Epoch 104/30000
#  - 6s - loss: 0.2416 - mse: 0.2827 - mae: 0.2416 - val_loss: 0.2647 - val_mse: 0.2766 - val_mae: 0.2647
# Epoch 105/30000
#  - 6s - loss: 0.2409 - mse: 0.2850 - mae: 0.2409 - val_loss: 0.2616 - val_mse: 0.2735 - val_mae: 0.2616
# Epoch 106/30000
#  - 6s - loss: 0.2405 - mse: 0.2830 - mae: 0.2405 - val_loss: 0.2601 - val_mse: 0.2756 - val_mae: 0.2601
# Epoch 107/30000
#  - 6s - loss: 0.2398 - mse: 0.2799 - mae: 0.2398 - val_loss: 0.2679 - val_mse: 0.2779 - val_mae: 0.2679
# Epoch 108/30000
#  - 6s - loss: 0.2385 - mse: 0.2772 - mae: 0.2385 - val_loss: 0.2619 - val_mse: 0.2718 - val_mae: 0.2619
# Epoch 109/30000
#  - 6s - loss: 0.2379 - mse: 0.2770 - mae: 0.2379 - val_loss: 0.2601 - val_mse: 0.2769 - val_mae: 0.2601
# Epoch 110/30000
#  - 6s - loss: 0.2383 - mse: 0.2781 - mae: 0.2383 - val_loss: 0.2592 - val_mse: 0.2744 - val_mae: 0.2592
# Epoch 111/30000
#  - 6s - loss: 0.2377 - mse: 0.2764 - mae: 0.2377 - val_loss: 0.2638 - val_mse: 0.2721 - val_mae: 0.2638
# Epoch 112/30000
#  - 6s - loss: 0.2379 - mse: 0.2765 - mae: 0.2379 - val_loss: 0.2620 - val_mse: 0.2714 - val_mae: 0.2620
# Epoch 113/30000
#  - 6s - loss: 0.2357 - mse: 0.2753 - mae: 0.2357 - val_loss: 0.2608 - val_mse: 0.2717 - val_mae: 0.2608
# Epoch 114/30000
#  - 6s - loss: 0.2361 - mse: 0.2757 - mae: 0.2361 - val_loss: 0.2599 - val_mse: 0.2685 - val_mae: 0.2599
# Epoch 115/30000
#  - 6s - loss: 0.2355 - mse: 0.2777 - mae: 0.2355 - val_loss: 0.2617 - val_mse: 0.2721 - val_mae: 0.2617
# Epoch 116/30000
#  - 6s - loss: 0.2357 - mse: 0.2718 - mae: 0.2357 - val_loss: 0.2575 - val_mse: 0.2696 - val_mae: 0.2575
# Epoch 117/30000
#  - 6s - loss: 0.2350 - mse: 0.2752 - mae: 0.2350 - val_loss: 0.2576 - val_mse: 0.2676 - val_mae: 0.2576
# Epoch 118/30000
#  - 6s - loss: 0.2335 - mse: 0.2717 - mae: 0.2335 - val_loss: 0.2573 - val_mse: 0.2706 - val_mae: 0.2573
# Epoch 119/30000
#  - 6s - loss: 0.2335 - mse: 0.2728 - mae: 0.2335 - val_loss: 0.2608 - val_mse: 0.2706 - val_mae: 0.2608
# Epoch 120/30000
#  - 6s - loss: 0.2340 - mse: 0.2723 - mae: 0.2340 - val_loss: 0.2568 - val_mse: 0.2699 - val_mae: 0.2568
# Epoch 121/30000
#  - 6s - loss: 0.2306 - mse: 0.2659 - mae: 0.2306 - val_loss: 0.2548 - val_mse: 0.2652 - val_mae: 0.2548
# Epoch 122/30000
#  - 6s - loss: 0.2324 - mse: 0.2690 - mae: 0.2324 - val_loss: 0.2574 - val_mse: 0.2680 - val_mae: 0.2574
# Epoch 123/30000
#  - 6s - loss: 0.2316 - mse: 0.2688 - mae: 0.2316 - val_loss: 0.2600 - val_mse: 0.2767 - val_mae: 0.2600
# Epoch 124/30000
#  - 6s - loss: 0.2301 - mse: 0.2640 - mae: 0.2301 - val_loss: 0.2591 - val_mse: 0.2657 - val_mae: 0.2591
# Epoch 125/30000
#  - 6s - loss: 0.2304 - mse: 0.2664 - mae: 0.2304 - val_loss: 0.2558 - val_mse: 0.2640 - val_mae: 0.2558
# Epoch 126/30000
#  - 6s - loss: 0.2312 - mse: 0.2682 - mae: 0.2312 - val_loss: 0.2555 - val_mse: 0.2677 - val_mae: 0.2555
# Epoch 127/30000
#  - 6s - loss: 0.2298 - mse: 0.2646 - mae: 0.2298 - val_loss: 0.2564 - val_mse: 0.2681 - val_mae: 0.2564
# Epoch 128/30000
#  - 6s - loss: 0.2280 - mse: 0.2625 - mae: 0.2280 - val_loss: 0.2552 - val_mse: 0.2659 - val_mae: 0.2552
# Epoch 129/30000
#  - 6s - loss: 0.2282 - mse: 0.2611 - mae: 0.2282 - val_loss: 0.2510 - val_mse: 0.2628 - val_mae: 0.2510
# Epoch 130/30000
#  - 6s - loss: 0.2285 - mse: 0.2645 - mae: 0.2285 - val_loss: 0.2530 - val_mse: 0.2629 - val_mae: 0.2530
# Epoch 131/30000
#  - 6s - loss: 0.2277 - mse: 0.2615 - mae: 0.2277 - val_loss: 0.2540 - val_mse: 0.2682 - val_mae: 0.2540
# Epoch 132/30000
#  - 6s - loss: 0.2273 - mse: 0.2650 - mae: 0.2273 - val_loss: 0.2553 - val_mse: 0.2620 - val_mae: 0.2553
# Epoch 133/30000
#  - 6s - loss: 0.2277 - mse: 0.2641 - mae: 0.2277 - val_loss: 0.2535 - val_mse: 0.2629 - val_mae: 0.2535
# Epoch 134/30000
#  - 6s - loss: 0.2262 - mse: 0.2621 - mae: 0.2262 - val_loss: 0.2539 - val_mse: 0.2641 - val_mae: 0.2539
# Epoch 135/30000
#  - 6s - loss: 0.2261 - mse: 0.2636 - mae: 0.2261 - val_loss: 0.2525 - val_mse: 0.2579 - val_mae: 0.2525
# Epoch 136/30000
#  - 6s - loss: 0.2264 - mse: 0.2623 - mae: 0.2264 - val_loss: 0.2564 - val_mse: 0.2631 - val_mae: 0.2564
# Epoch 137/30000
#  - 6s - loss: 0.2247 - mse: 0.2559 - mae: 0.2247 - val_loss: 0.2538 - val_mse: 0.2630 - val_mae: 0.2538
# Epoch 138/30000
#  - 6s - loss: 0.2251 - mse: 0.2579 - mae: 0.2251 - val_loss: 0.2564 - val_mse: 0.2637 - val_mae: 0.2564
# Epoch 139/30000
#  - 6s - loss: 0.2231 - mse: 0.2588 - mae: 0.2231 - val_loss: 0.2539 - val_mse: 0.2643 - val_mae: 0.2539
# Epoch 140/30000
#  - 6s - loss: 0.2225 - mse: 0.2541 - mae: 0.2225 - val_loss: 0.2542 - val_mse: 0.2614 - val_mae: 0.2542
# Epoch 141/30000
#  - 6s - loss: 0.2233 - mse: 0.2561 - mae: 0.2233 - val_loss: 0.2469 - val_mse: 0.2553 - val_mae: 0.2469
# Epoch 142/30000
#  - 6s - loss: 0.2240 - mse: 0.2579 - mae: 0.2240 - val_loss: 0.2543 - val_mse: 0.2595 - val_mae: 0.2543
# Epoch 143/30000
#  - 6s - loss: 0.2220 - mse: 0.2552 - mae: 0.2220 - val_loss: 0.2493 - val_mse: 0.2625 - val_mae: 0.2493
# Epoch 144/30000
#  - 6s - loss: 0.2225 - mse: 0.2569 - mae: 0.2225 - val_loss: 0.2556 - val_mse: 0.2681 - val_mae: 0.2556
# Epoch 145/30000
#  - 6s - loss: 0.2227 - mse: 0.2556 - mae: 0.2227 - val_loss: 0.2511 - val_mse: 0.2610 - val_mae: 0.2511
# Epoch 146/30000
#  - 6s - loss: 0.2212 - mse: 0.2564 - mae: 0.2212 - val_loss: 0.2504 - val_mse: 0.2600 - val_mae: 0.2504
# Epoch 147/30000
#  - 6s - loss: 0.2214 - mse: 0.2559 - mae: 0.2214 - val_loss: 0.2487 - val_mse: 0.2591 - val_mae: 0.2487
# Epoch 148/30000
#  - 6s - loss: 0.2220 - mse: 0.2559 - mae: 0.2220 - val_loss: 0.2524 - val_mse: 0.2603 - val_mae: 0.2524
# Epoch 149/30000
#  - 6s - loss: 0.2202 - mse: 0.2536 - mae: 0.2202 - val_loss: 0.2524 - val_mse: 0.2621 - val_mae: 0.2524
# Epoch 150/30000
#  - 6s - loss: 0.2199 - mse: 0.2508 - mae: 0.2199 - val_loss: 0.2519 - val_mse: 0.2583 - val_mae: 0.2519
# Epoch 151/30000
#  - 6s - loss: 0.2205 - mse: 0.2535 - mae: 0.2205 - val_loss: 0.2546 - val_mse: 0.2608 - val_mae: 0.2546
# Epoch 152/30000
#  - 6s - loss: 0.2189 - mse: 0.2523 - mae: 0.2189 - val_loss: 0.2489 - val_mse: 0.2546 - val_mae: 0.2489
# Epoch 153/30000
#  - 6s - loss: 0.2198 - mse: 0.2534 - mae: 0.2198 - val_loss: 0.2468 - val_mse: 0.2538 - val_mae: 0.2468
# Epoch 154/30000
#  - 6s - loss: 0.2177 - mse: 0.2484 - mae: 0.2177 - val_loss: 0.2522 - val_mse: 0.2572 - val_mae: 0.2522
# Epoch 155/30000
#  - 6s - loss: 0.2176 - mse: 0.2477 - mae: 0.2176 - val_loss: 0.2471 - val_mse: 0.2608 - val_mae: 0.2471
# Epoch 156/30000
#  - 6s - loss: 0.2193 - mse: 0.2526 - mae: 0.2193 - val_loss: 0.2530 - val_mse: 0.2611 - val_mae: 0.2530
# Epoch 157/30000
#  - 6s - loss: 0.2184 - mse: 0.2503 - mae: 0.2184 - val_loss: 0.2525 - val_mse: 0.2588 - val_mae: 0.2525
# Epoch 158/30000
#  - 6s - loss: 0.2194 - mse: 0.2526 - mae: 0.2194 - val_loss: 0.2483 - val_mse: 0.2578 - val_mae: 0.2483
# Epoch 159/30000
#  - 6s - loss: 0.2167 - mse: 0.2457 - mae: 0.2167 - val_loss: 0.2489 - val_mse: 0.2610 - val_mae: 0.2489
# Epoch 160/30000
#  - 6s - loss: 0.2181 - mse: 0.2479 - mae: 0.2181 - val_loss: 0.2464 - val_mse: 0.2531 - val_mae: 0.2464
# Epoch 161/30000
#  - 6s - loss: 0.2158 - mse: 0.2477 - mae: 0.2158 - val_loss: 0.2510 - val_mse: 0.2565 - val_mae: 0.2510
# Epoch 162/30000
#  - 6s - loss: 0.2155 - mse: 0.2466 - mae: 0.2155 - val_loss: 0.2454 - val_mse: 0.2543 - val_mae: 0.2454
# Epoch 163/30000
#  - 6s - loss: 0.2153 - mse: 0.2472 - mae: 0.2153 - val_loss: 0.2509 - val_mse: 0.2658 - val_mae: 0.2509
# Epoch 164/30000
#  - 6s - loss: 0.2147 - mse: 0.2438 - mae: 0.2147 - val_loss: 0.2474 - val_mse: 0.2531 - val_mae: 0.2474
# Epoch 165/30000
#  - 6s - loss: 0.2147 - mse: 0.2450 - mae: 0.2147 - val_loss: 0.2474 - val_mse: 0.2539 - val_mae: 0.2474
# Epoch 166/30000
#  - 6s - loss: 0.2139 - mse: 0.2439 - mae: 0.2139 - val_loss: 0.2492 - val_mse: 0.2586 - val_mae: 0.2492
# Epoch 167/30000
#  - 6s - loss: 0.2142 - mse: 0.2436 - mae: 0.2142 - val_loss: 0.2452 - val_mse: 0.2604 - val_mae: 0.2452
# Epoch 168/30000
#  - 6s - loss: 0.2145 - mse: 0.2481 - mae: 0.2145 - val_loss: 0.2433 - val_mse: 0.2500 - val_mae: 0.2433
# Epoch 169/30000
#  - 6s - loss: 0.2127 - mse: 0.2408 - mae: 0.2127 - val_loss: 0.2441 - val_mse: 0.2538 - val_mae: 0.2441
# Epoch 170/30000
#  - 6s - loss: 0.2130 - mse: 0.2422 - mae: 0.2130 - val_loss: 0.2490 - val_mse: 0.2527 - val_mae: 0.2490
# Epoch 171/30000
#  - 6s - loss: 0.2143 - mse: 0.2457 - mae: 0.2143 - val_loss: 0.2467 - val_mse: 0.2627 - val_mae: 0.2467
# Epoch 172/30000
#  - 6s - loss: 0.2130 - mse: 0.2426 - mae: 0.2130 - val_loss: 0.2481 - val_mse: 0.2571 - val_mae: 0.2481
# Epoch 173/30000
#  - 6s - loss: 0.2121 - mse: 0.2409 - mae: 0.2121 - val_loss: 0.2502 - val_mse: 0.2590 - val_mae: 0.2502
# Epoch 174/30000
#  - 6s - loss: 0.2130 - mse: 0.2420 - mae: 0.2130 - val_loss: 0.2453 - val_mse: 0.2547 - val_mae: 0.2453
# Epoch 175/30000
#  - 6s - loss: 0.2121 - mse: 0.2428 - mae: 0.2121 - val_loss: 0.2429 - val_mse: 0.2521 - val_mae: 0.2429
# Epoch 176/30000
#  - 6s - loss: 0.2129 - mse: 0.2420 - mae: 0.2129 - val_loss: 0.2466 - val_mse: 0.2547 - val_mae: 0.2466
# Epoch 177/30000
#  - 6s - loss: 0.2127 - mse: 0.2420 - mae: 0.2127 - val_loss: 0.2426 - val_mse: 0.2520 - val_mae: 0.2426
# Epoch 178/30000
#  - 6s - loss: 0.2113 - mse: 0.2418 - mae: 0.2113 - val_loss: 0.2440 - val_mse: 0.2513 - val_mae: 0.2440
# Epoch 179/30000
#  - 6s - loss: 0.2112 - mse: 0.2414 - mae: 0.2112 - val_loss: 0.2452 - val_mse: 0.2613 - val_mae: 0.2452
# Epoch 180/30000
#  - 6s - loss: 0.2113 - mse: 0.2409 - mae: 0.2113 - val_loss: 0.2463 - val_mse: 0.2514 - val_mae: 0.2463
# Epoch 181/30000
#  - 6s - loss: 0.2104 - mse: 0.2397 - mae: 0.2104 - val_loss: 0.2473 - val_mse: 0.2629 - val_mae: 0.2473
# Epoch 182/30000
#  - 6s - loss: 0.2103 - mse: 0.2373 - mae: 0.2103 - val_loss: 0.2448 - val_mse: 0.2551 - val_mae: 0.2448
# Epoch 183/30000
#  - 6s - loss: 0.2102 - mse: 0.2406 - mae: 0.2102 - val_loss: 0.2418 - val_mse: 0.2497 - val_mae: 0.2418
# Epoch 184/30000
#  - 6s - loss: 0.2106 - mse: 0.2378 - mae: 0.2106 - val_loss: 0.2431 - val_mse: 0.2482 - val_mae: 0.2431
# Epoch 185/30000
#  - 6s - loss: 0.2087 - mse: 0.2374 - mae: 0.2087 - val_loss: 0.2508 - val_mse: 0.2574 - val_mae: 0.2508
# Epoch 186/30000
#  - 6s - loss: 0.2096 - mse: 0.2375 - mae: 0.2096 - val_loss: 0.2425 - val_mse: 0.2498 - val_mae: 0.2425
# Epoch 187/30000
#  - 6s - loss: 0.2081 - mse: 0.2372 - mae: 0.2081 - val_loss: 0.2438 - val_mse: 0.2577 - val_mae: 0.2438
# Epoch 188/30000
#  - 6s - loss: 0.2078 - mse: 0.2338 - mae: 0.2078 - val_loss: 0.2467 - val_mse: 0.2540 - val_mae: 0.2467
# Epoch 189/30000
#  - 6s - loss: 0.2082 - mse: 0.2341 - mae: 0.2082 - val_loss: 0.2424 - val_mse: 0.2502 - val_mae: 0.2424
# Epoch 190/30000
#  - 6s - loss: 0.2094 - mse: 0.2354 - mae: 0.2094 - val_loss: 0.2437 - val_mse: 0.2483 - val_mae: 0.2437
# Epoch 191/30000
#  - 6s - loss: 0.2082 - mse: 0.2347 - mae: 0.2082 - val_loss: 0.2443 - val_mse: 0.2507 - val_mae: 0.2443
# Epoch 192/30000
#  - 6s - loss: 0.2078 - mse: 0.2330 - mae: 0.2078 - val_loss: 0.2433 - val_mse: 0.2455 - val_mae: 0.2433
# Epoch 193/30000
#  - 6s - loss: 0.2077 - mse: 0.2322 - mae: 0.2077 - val_loss: 0.2413 - val_mse: 0.2476 - val_mae: 0.2413
# Epoch 194/30000
#  - 6s - loss: 0.2072 - mse: 0.2356 - mae: 0.2072 - val_loss: 0.2416 - val_mse: 0.2483 - val_mae: 0.2416
# Epoch 195/30000
#  - 6s - loss: 0.2069 - mse: 0.2299 - mae: 0.2069 - val_loss: 0.2438 - val_mse: 0.2501 - val_mae: 0.2438
# Epoch 196/30000
#  - 6s - loss: 0.2063 - mse: 0.2345 - mae: 0.2063 - val_loss: 0.2426 - val_mse: 0.2502 - val_mae: 0.2426
# Epoch 197/30000
#  - 6s - loss: 0.2065 - mse: 0.2338 - mae: 0.2065 - val_loss: 0.2412 - val_mse: 0.2509 - val_mae: 0.2412
# Epoch 198/30000
#  - 6s - loss: 0.2073 - mse: 0.2305 - mae: 0.2073 - val_loss: 0.2433 - val_mse: 0.2499 - val_mae: 0.2433
# Epoch 199/30000
#  - 6s - loss: 0.2057 - mse: 0.2274 - mae: 0.2057 - val_loss: 0.2410 - val_mse: 0.2481 - val_mae: 0.2410
# Epoch 200/30000
#  - 6s - loss: 0.2066 - mse: 0.2300 - mae: 0.2066 - val_loss: 0.2481 - val_mse: 0.2526 - val_mae: 0.2481
# Epoch 201/30000
#  - 6s - loss: 0.2064 - mse: 0.2317 - mae: 0.2064 - val_loss: 0.2414 - val_mse: 0.2483 - val_mae: 0.2414
# Epoch 202/30000
#  - 6s - loss: 0.2047 - mse: 0.2302 - mae: 0.2047 - val_loss: 0.2456 - val_mse: 0.2592 - val_mae: 0.2456
# Epoch 203/30000
#  - 6s - loss: 0.2054 - mse: 0.2279 - mae: 0.2054 - val_loss: 0.2397 - val_mse: 0.2456 - val_mae: 0.2397
# Epoch 204/30000
#  - 6s - loss: 0.2052 - mse: 0.2285 - mae: 0.2052 - val_loss: 0.2426 - val_mse: 0.2478 - val_mae: 0.2426
# Epoch 205/30000
#  - 6s - loss: 0.2037 - mse: 0.2271 - mae: 0.2037 - val_loss: 0.2442 - val_mse: 0.2473 - val_mae: 0.2442
# Epoch 206/30000
#  - 6s - loss: 0.2042 - mse: 0.2287 - mae: 0.2042 - val_loss: 0.2415 - val_mse: 0.2470 - val_mae: 0.2415
# Epoch 207/30000
#  - 6s - loss: 0.2046 - mse: 0.2258 - mae: 0.2046 - val_loss: 0.2425 - val_mse: 0.2466 - val_mae: 0.2425
# Epoch 208/30000
#  - 6s - loss: 0.2028 - mse: 0.2232 - mae: 0.2028 - val_loss: 0.2403 - val_mse: 0.2439 - val_mae: 0.2403
# Epoch 209/30000
#  - 6s - loss: 0.2033 - mse: 0.2268 - mae: 0.2033 - val_loss: 0.2466 - val_mse: 0.2606 - val_mae: 0.2466
# Epoch 210/30000
#  - 6s - loss: 0.2021 - mse: 0.2196 - mae: 0.2021 - val_loss: 0.2383 - val_mse: 0.2479 - val_mae: 0.2383
# Epoch 211/30000
#  - 6s - loss: 0.2013 - mse: 0.2224 - mae: 0.2013 - val_loss: 0.2390 - val_mse: 0.2422 - val_mae: 0.2390
# Epoch 212/30000
#  - 6s - loss: 0.2030 - mse: 0.2254 - mae: 0.2030 - val_loss: 0.2435 - val_mse: 0.2463 - val_mae: 0.2435
# Epoch 213/30000
#  - 6s - loss: 0.2022 - mse: 0.2240 - mae: 0.2022 - val_loss: 0.2449 - val_mse: 0.2467 - val_mae: 0.2449
# Epoch 214/30000
#  - 6s - loss: 0.2018 - mse: 0.2198 - mae: 0.2018 - val_loss: 0.2436 - val_mse: 0.2496 - val_mae: 0.2436
# Epoch 215/30000
#  - 6s - loss: 0.2026 - mse: 0.2264 - mae: 0.2026 - val_loss: 0.2409 - val_mse: 0.2440 - val_mae: 0.2409
# Epoch 216/30000
#  - 6s - loss: 0.2017 - mse: 0.2234 - mae: 0.2017 - val_loss: 0.2402 - val_mse: 0.2412 - val_mae: 0.2402
# Epoch 217/30000
#  - 6s - loss: 0.2016 - mse: 0.2213 - mae: 0.2016 - val_loss: 0.2390 - val_mse: 0.2404 - val_mae: 0.2390
# Epoch 218/30000
#  - 6s - loss: 0.2026 - mse: 0.2254 - mae: 0.2026 - val_loss: 0.2407 - val_mse: 0.2431 - val_mae: 0.2407
# Epoch 219/30000
#  - 6s - loss: 0.2011 - mse: 0.2223 - mae: 0.2011 - val_loss: 0.2408 - val_mse: 0.2462 - val_mae: 0.2408
# Epoch 220/30000
#  - 6s - loss: 0.2010 - mse: 0.2208 - mae: 0.2010 - val_loss: 0.2428 - val_mse: 0.2452 - val_mae: 0.2428
# Epoch 221/30000
#  - 6s - loss: 0.2003 - mse: 0.2187 - mae: 0.2003 - val_loss: 0.2451 - val_mse: 0.2454 - val_mae: 0.2451
# Epoch 222/30000
#  - 6s - loss: 0.2012 - mse: 0.2216 - mae: 0.2012 - val_loss: 0.2414 - val_mse: 0.2438 - val_mae: 0.2414
# Epoch 223/30000
#  - 6s - loss: 0.2002 - mse: 0.2160 - mae: 0.2002 - val_loss: 0.2396 - val_mse: 0.2469 - val_mae: 0.2396
# Epoch 224/30000
#  - 6s - loss: 0.2001 - mse: 0.2238 - mae: 0.2001 - val_loss: 0.2405 - val_mse: 0.2437 - val_mae: 0.2405
# Epoch 225/30000
#  - 6s - loss: 0.2006 - mse: 0.2206 - mae: 0.2006 - val_loss: 0.2415 - val_mse: 0.2400 - val_mae: 0.2415
# Epoch 226/30000
#  - 6s - loss: 0.2002 - mse: 0.2185 - mae: 0.2002 - val_loss: 0.2431 - val_mse: 0.2465 - val_mae: 0.2431
# Epoch 227/30000
#  - 6s - loss: 0.1994 - mse: 0.2195 - mae: 0.1994 - val_loss: 0.2389 - val_mse: 0.2395 - val_mae: 0.2389
# Epoch 228/30000
#  - 6s - loss: 0.1989 - mse: 0.2173 - mae: 0.1989 - val_loss: 0.2403 - val_mse: 0.2463 - val_mae: 0.2403
# Epoch 229/30000
#  - 6s - loss: 0.1986 - mse: 0.2165 - mae: 0.1986 - val_loss: 0.2411 - val_mse: 0.2427 - val_mae: 0.2411
# Epoch 230/30000
#  - 6s - loss: 0.1994 - mse: 0.2169 - mae: 0.1994 - val_loss: 0.2377 - val_mse: 0.2403 - val_mae: 0.2377
# Epoch 231/30000
#  - 6s - loss: 0.1977 - mse: 0.2139 - mae: 0.1977 - val_loss: 0.2393 - val_mse: 0.2398 - val_mae: 0.2393
# Epoch 232/30000
#  - 6s - loss: 0.1974 - mse: 0.2134 - mae: 0.1974 - val_loss: 0.2405 - val_mse: 0.2480 - val_mae: 0.2405
# Epoch 233/30000
#  - 6s - loss: 0.1992 - mse: 0.2182 - mae: 0.1992 - val_loss: 0.2412 - val_mse: 0.2425 - val_mae: 0.2412
# Epoch 234/30000
#  - 6s - loss: 0.1987 - mse: 0.2176 - mae: 0.1987 - val_loss: 0.2362 - val_mse: 0.2382 - val_mae: 0.2362
# Epoch 235/30000
#  - 6s - loss: 0.1976 - mse: 0.2166 - mae: 0.1976 - val_loss: 0.2370 - val_mse: 0.2399 - val_mae: 0.2370
# Epoch 236/30000
#  - 6s - loss: 0.1986 - mse: 0.2175 - mae: 0.1986 - val_loss: 0.2443 - val_mse: 0.2447 - val_mae: 0.2443
# Epoch 237/30000
#  - 6s - loss: 0.1975 - mse: 0.2113 - mae: 0.1975 - val_loss: 0.2418 - val_mse: 0.2435 - val_mae: 0.2418
# Epoch 238/30000
#  - 6s - loss: 0.1969 - mse: 0.2115 - mae: 0.1969 - val_loss: 0.2406 - val_mse: 0.2401 - val_mae: 0.2406
# Epoch 239/30000
#  - 6s - loss: 0.1986 - mse: 0.2160 - mae: 0.1986 - val_loss: 0.2449 - val_mse: 0.2463 - val_mae: 0.2449
# Epoch 240/30000
#  - 6s - loss: 0.1970 - mse: 0.2125 - mae: 0.1970 - val_loss: 0.2398 - val_mse: 0.2377 - val_mae: 0.2398
# Epoch 241/30000
#  - 6s - loss: 0.1972 - mse: 0.2136 - mae: 0.1972 - val_loss: 0.2392 - val_mse: 0.2382 - val_mae: 0.2392
# Epoch 242/30000
#  - 6s - loss: 0.1973 - mse: 0.2112 - mae: 0.1973 - val_loss: 0.2379 - val_mse: 0.2408 - val_mae: 0.2379
# Epoch 243/30000
#  - 6s - loss: 0.1981 - mse: 0.2130 - mae: 0.1981 - val_loss: 0.2381 - val_mse: 0.2414 - val_mae: 0.2381
# Epoch 244/30000
#  - 6s - loss: 0.1961 - mse: 0.2104 - mae: 0.1961 - val_loss: 0.2389 - val_mse: 0.2421 - val_mae: 0.2389
# Epoch 245/30000
#  - 6s - loss: 0.1973 - mse: 0.2117 - mae: 0.1973 - val_loss: 0.2352 - val_mse: 0.2387 - val_mae: 0.2352
# Epoch 246/30000
#  - 6s - loss: 0.1959 - mse: 0.2065 - mae: 0.1959 - val_loss: 0.2357 - val_mse: 0.2366 - val_mae: 0.2357
# Epoch 247/30000
#  - 6s - loss: 0.1959 - mse: 0.2076 - mae: 0.1959 - val_loss: 0.2381 - val_mse: 0.2436 - val_mae: 0.2381
# Epoch 248/30000
#  - 6s - loss: 0.1970 - mse: 0.2147 - mae: 0.1970 - val_loss: 0.2358 - val_mse: 0.2381 - val_mae: 0.2358
# Epoch 249/30000
#  - 6s - loss: 0.1957 - mse: 0.2106 - mae: 0.1957 - val_loss: 0.2384 - val_mse: 0.2365 - val_mae: 0.2384
# Epoch 250/30000
#  - 6s - loss: 0.1959 - mse: 0.2090 - mae: 0.1959 - val_loss: 0.2375 - val_mse: 0.2373 - val_mae: 0.2375
# Epoch 251/30000
#  - 6s - loss: 0.1942 - mse: 0.2077 - mae: 0.1942 - val_loss: 0.2343 - val_mse: 0.2337 - val_mae: 0.2343
# Epoch 252/30000
#  - 6s - loss: 0.1954 - mse: 0.2065 - mae: 0.1954 - val_loss: 0.2360 - val_mse: 0.2342 - val_mae: 0.2360
# Epoch 253/30000
#  - 6s - loss: 0.1954 - mse: 0.2087 - mae: 0.1954 - val_loss: 0.2353 - val_mse: 0.2336 - val_mae: 0.2353
# Epoch 254/30000
#  - 6s - loss: 0.1942 - mse: 0.2093 - mae: 0.1942 - val_loss: 0.2355 - val_mse: 0.2336 - val_mae: 0.2355
# Epoch 255/30000
#  - 6s - loss: 0.1937 - mse: 0.2067 - mae: 0.1937 - val_loss: 0.2418 - val_mse: 0.2435 - val_mae: 0.2418
# Epoch 256/30000
#  - 6s - loss: 0.1952 - mse: 0.2068 - mae: 0.1952 - val_loss: 0.2379 - val_mse: 0.2402 - val_mae: 0.2379
# Epoch 257/30000
#  - 6s - loss: 0.1941 - mse: 0.2024 - mae: 0.1941 - val_loss: 0.2396 - val_mse: 0.2371 - val_mae: 0.2396
# Epoch 258/30000
#  - 6s - loss: 0.1938 - mse: 0.2032 - mae: 0.1938 - val_loss: 0.2364 - val_mse: 0.2349 - val_mae: 0.2364
# Epoch 259/30000
#  - 6s - loss: 0.1936 - mse: 0.2020 - mae: 0.1936 - val_loss: 0.2356 - val_mse: 0.2391 - val_mae: 0.2356
# Epoch 260/30000
#  - 6s - loss: 0.1939 - mse: 0.2024 - mae: 0.1939 - val_loss: 0.2370 - val_mse: 0.2369 - val_mae: 0.2370
# Epoch 261/30000
#  - 6s - loss: 0.1946 - mse: 0.2057 - mae: 0.1946 - val_loss: 0.2346 - val_mse: 0.2308 - val_mae: 0.2346
# Epoch 262/30000
#  - 6s - loss: 0.1933 - mse: 0.2019 - mae: 0.1933 - val_loss: 0.2389 - val_mse: 0.2384 - val_mae: 0.2389
# Epoch 263/30000
#  - 6s - loss: 0.1926 - mse: 0.2012 - mae: 0.1926 - val_loss: 0.2433 - val_mse: 0.2353 - val_mae: 0.2433
# Epoch 264/30000
#  - 6s - loss: 0.1927 - mse: 0.2012 - mae: 0.1927 - val_loss: 0.2372 - val_mse: 0.2386 - val_mae: 0.2372
# Epoch 265/30000
#  - 6s - loss: 0.1922 - mse: 0.1985 - mae: 0.1922 - val_loss: 0.2377 - val_mse: 0.2406 - val_mae: 0.2377
# Epoch 266/30000
#  - 6s - loss: 0.1931 - mse: 0.2015 - mae: 0.1931 - val_loss: 0.2409 - val_mse: 0.2393 - val_mae: 0.2409
# Epoch 267/30000
#  - 6s - loss: 0.1932 - mse: 0.2036 - mae: 0.1932 - val_loss: 0.2347 - val_mse: 0.2331 - val_mae: 0.2347
# Epoch 268/30000
#  - 6s - loss: 0.1920 - mse: 0.1999 - mae: 0.1920 - val_loss: 0.2381 - val_mse: 0.2405 - val_mae: 0.2381
# Epoch 269/30000
#  - 6s - loss: 0.1914 - mse: 0.1998 - mae: 0.1914 - val_loss: 0.2373 - val_mse: 0.2340 - val_mae: 0.2373
# Epoch 270/30000
#  - 6s - loss: 0.1917 - mse: 0.1975 - mae: 0.1917 - val_loss: 0.2406 - val_mse: 0.2420 - val_mae: 0.2406
# Epoch 271/30000
#  - 6s - loss: 0.1934 - mse: 0.2010 - mae: 0.1934 - val_loss: 0.2376 - val_mse: 0.2360 - val_mae: 0.2376
# Epoch 272/30000
#  - 6s - loss: 0.1923 - mse: 0.2035 - mae: 0.1923 - val_loss: 0.2372 - val_mse: 0.2333 - val_mae: 0.2372
# Epoch 273/30000
#  - 6s - loss: 0.1914 - mse: 0.1959 - mae: 0.1914 - val_loss: 0.2405 - val_mse: 0.2415 - val_mae: 0.2405
# Epoch 274/30000
#  - 6s - loss: 0.1913 - mse: 0.2007 - mae: 0.1913 - val_loss: 0.2381 - val_mse: 0.2385 - val_mae: 0.2381
# Epoch 275/30000
#  - 6s - loss: 0.1912 - mse: 0.1966 - mae: 0.1912 - val_loss: 0.2374 - val_mse: 0.2346 - val_mae: 0.2374
# Epoch 276/30000
#  - 6s - loss: 0.1908 - mse: 0.1937 - mae: 0.1908 - val_loss: 0.2402 - val_mse: 0.2385 - val_mae: 0.2402
# Epoch 277/30000
#  - 6s - loss: 0.1903 - mse: 0.1988 - mae: 0.1903 - val_loss: 0.2391 - val_mse: 0.2364 - val_mae: 0.2391
# Epoch 278/30000
#  - 6s - loss: 0.1917 - mse: 0.1994 - mae: 0.1917 - val_loss: 0.2343 - val_mse: 0.2292 - val_mae: 0.2343
# Epoch 279/30000
#  - 6s - loss: 0.1907 - mse: 0.1950 - mae: 0.1907 - val_loss: 0.2396 - val_mse: 0.2390 - val_mae: 0.2396
# Epoch 280/30000
#  - 6s - loss: 0.1901 - mse: 0.1920 - mae: 0.1901 - val_loss: 0.2370 - val_mse: 0.2349 - val_mae: 0.2370
# Epoch 281/30000
#  - 6s - loss: 0.1906 - mse: 0.1975 - mae: 0.1906 - val_loss: 0.2393 - val_mse: 0.2382 - val_mae: 0.2393
# Epoch 282/30000
#  - 6s - loss: 0.1897 - mse: 0.1938 - mae: 0.1897 - val_loss: 0.2359 - val_mse: 0.2318 - val_mae: 0.2359
# Epoch 283/30000
#  - 6s - loss: 0.1906 - mse: 0.1968 - mae: 0.1906 - val_loss: 0.2371 - val_mse: 0.2331 - val_mae: 0.2371
# Epoch 284/30000
#  - 6s - loss: 0.1882 - mse: 0.1918 - mae: 0.1882 - val_loss: 0.2345 - val_mse: 0.2314 - val_mae: 0.2345
# Epoch 285/30000
#  - 6s - loss: 0.1885 - mse: 0.1948 - mae: 0.1885 - val_loss: 0.2355 - val_mse: 0.2311 - val_mae: 0.2355
# Epoch 286/30000
#  - 6s - loss: 0.1892 - mse: 0.1917 - mae: 0.1892 - val_loss: 0.2349 - val_mse: 0.2341 - val_mae: 0.2349
# Epoch 287/30000
#  - 6s - loss: 0.1885 - mse: 0.1920 - mae: 0.1885 - val_loss: 0.2336 - val_mse: 0.2302 - val_mae: 0.2336
# Epoch 288/30000
#  - 6s - loss: 0.1895 - mse: 0.1895 - mae: 0.1895 - val_loss: 0.2378 - val_mse: 0.2436 - val_mae: 0.2378
# Epoch 289/30000
#  - 6s - loss: 0.1893 - mse: 0.1960 - mae: 0.1893 - val_loss: 0.2344 - val_mse: 0.2347 - val_mae: 0.2344
# Epoch 290/30000
#  - 6s - loss: 0.1884 - mse: 0.1947 - mae: 0.1884 - val_loss: 0.2391 - val_mse: 0.2336 - val_mae: 0.2391
# Epoch 291/30000
#  - 6s - loss: 0.1889 - mse: 0.1927 - mae: 0.1889 - val_loss: 0.2381 - val_mse: 0.2357 - val_mae: 0.2381
# Epoch 292/30000
#  - 6s - loss: 0.1888 - mse: 0.1927 - mae: 0.1888 - val_loss: 0.2359 - val_mse: 0.2330 - val_mae: 0.2359
# Epoch 293/30000
#  - 6s - loss: 0.1884 - mse: 0.1912 - mae: 0.1884 - val_loss: 0.2370 - val_mse: 0.2315 - val_mae: 0.2370
# Epoch 294/30000
#  - 6s - loss: 0.1894 - mse: 0.1926 - mae: 0.1894 - val_loss: 0.2341 - val_mse: 0.2296 - val_mae: 0.2341
# Epoch 295/30000
#  - 6s - loss: 0.1875 - mse: 0.1907 - mae: 0.1875 - val_loss: 0.2368 - val_mse: 0.2324 - val_mae: 0.2368
# Epoch 296/30000
#  - 6s - loss: 0.1880 - mse: 0.1959 - mae: 0.1880 - val_loss: 0.2350 - val_mse: 0.2318 - val_mae: 0.2350
# Epoch 297/30000
#  - 6s - loss: 0.1882 - mse: 0.1947 - mae: 0.1882 - val_loss: 0.2360 - val_mse: 0.2362 - val_mae: 0.2360
# Epoch 298/30000
#  - 6s - loss: 0.1886 - mse: 0.1963 - mae: 0.1886 - val_loss: 0.2323 - val_mse: 0.2325 - val_mae: 0.2323
# Epoch 299/30000
#  - 6s - loss: 0.1866 - mse: 0.1922 - mae: 0.1866 - val_loss: 0.2360 - val_mse: 0.2387 - val_mae: 0.2360
# Epoch 300/30000
#  - 6s - loss: 0.1873 - mse: 0.1939 - mae: 0.1873 - val_loss: 0.2359 - val_mse: 0.2332 - val_mae: 0.2359
# Epoch 301/30000
#  - 6s - loss: 0.1867 - mse: 0.1898 - mae: 0.1867 - val_loss: 0.2395 - val_mse: 0.2371 - val_mae: 0.2395
# Epoch 302/30000
#  - 6s - loss: 0.1879 - mse: 0.1926 - mae: 0.1879 - val_loss: 0.2352 - val_mse: 0.2329 - val_mae: 0.2352
# Epoch 303/30000
#  - 6s - loss: 0.1868 - mse: 0.1918 - mae: 0.1868 - val_loss: 0.2347 - val_mse: 0.2297 - val_mae: 0.2347
# Epoch 304/30000
#  - 6s - loss: 0.1849 - mse: 0.1872 - mae: 0.1849 - val_loss: 0.2356 - val_mse: 0.2347 - val_mae: 0.2356
# Epoch 305/30000
#  - 6s - loss: 0.1858 - mse: 0.1889 - mae: 0.1858 - val_loss: 0.2360 - val_mse: 0.2299 - val_mae: 0.2360
# Epoch 306/30000
#  - 6s - loss: 0.1869 - mse: 0.1915 - mae: 0.1869 - val_loss: 0.2346 - val_mse: 0.2332 - val_mae: 0.2346
# Epoch 307/30000
#  - 6s - loss: 0.1867 - mse: 0.1896 - mae: 0.1867 - val_loss: 0.2330 - val_mse: 0.2280 - val_mae: 0.2330
# Epoch 308/30000
#  - 6s - loss: 0.1870 - mse: 0.1923 - mae: 0.1870 - val_loss: 0.2361 - val_mse: 0.2324 - val_mae: 0.2361
# Epoch 309/30000
#  - 6s - loss: 0.1864 - mse: 0.1881 - mae: 0.1864 - val_loss: 0.2365 - val_mse: 0.2327 - val_mae: 0.2365
# Epoch 310/30000
#  - 6s - loss: 0.1857 - mse: 0.1910 - mae: 0.1857 - val_loss: 0.2333 - val_mse: 0.2297 - val_mae: 0.2333
# Epoch 311/30000
#  - 6s - loss: 0.1869 - mse: 0.1909 - mae: 0.1869 - val_loss: 0.2327 - val_mse: 0.2296 - val_mae: 0.2327
# Epoch 312/30000
#  - 6s - loss: 0.1860 - mse: 0.1891 - mae: 0.1860 - val_loss: 0.2364 - val_mse: 0.2340 - val_mae: 0.2364
# Epoch 313/30000
#  - 6s - loss: 0.1846 - mse: 0.1897 - mae: 0.1846 - val_loss: 0.2372 - val_mse: 0.2354 - val_mae: 0.2372
# Epoch 314/30000
#  - 6s - loss: 0.1855 - mse: 0.1874 - mae: 0.1855 - val_loss: 0.2346 - val_mse: 0.2313 - val_mae: 0.2346
# Epoch 315/30000
#  - 6s - loss: 0.1850 - mse: 0.1888 - mae: 0.1850 - val_loss: 0.2358 - val_mse: 0.2358 - val_mae: 0.2358
# Epoch 316/30000
#  - 6s - loss: 0.1857 - mse: 0.1858 - mae: 0.1857 - val_loss: 0.2359 - val_mse: 0.2351 - val_mae: 0.2359
# Epoch 317/30000
#  - 6s - loss: 0.1849 - mse: 0.1891 - mae: 0.1849 - val_loss: 0.2348 - val_mse: 0.2335 - val_mae: 0.2348
# Epoch 318/30000
#  - 6s - loss: 0.1856 - mse: 0.1901 - mae: 0.1856 - val_loss: 0.2376 - val_mse: 0.2350 - val_mae: 0.2376
# Epoch 319/30000
#  - 6s - loss: 0.1846 - mse: 0.1865 - mae: 0.1846 - val_loss: 0.2339 - val_mse: 0.2316 - val_mae: 0.2339
# Epoch 320/30000
#  - 6s - loss: 0.1844 - mse: 0.1883 - mae: 0.1844 - val_loss: 0.2347 - val_mse: 0.2320 - val_mae: 0.2347
# Epoch 321/30000
#  - 6s - loss: 0.1849 - mse: 0.1879 - mae: 0.1849 - val_loss: 0.2337 - val_mse: 0.2341 - val_mae: 0.2337
# Epoch 322/30000
#  - 6s - loss: 0.1867 - mse: 0.1926 - mae: 0.1867 - val_loss: 0.2328 - val_mse: 0.2353 - val_mae: 0.2328
# Epoch 323/30000
#  - 6s - loss: 0.1851 - mse: 0.1903 - mae: 0.1851 - val_loss: 0.2363 - val_mse: 0.2341 - val_mae: 0.2363
# Epoch 324/30000
#  - 6s - loss: 0.1847 - mse: 0.1904 - mae: 0.1847 - val_loss: 0.2364 - val_mse: 0.2331 - val_mae: 0.2364
# Epoch 325/30000
#  - 6s - loss: 0.1830 - mse: 0.1857 - mae: 0.1830 - val_loss: 0.2360 - val_mse: 0.2365 - val_mae: 0.2360
# Epoch 326/30000
#  - 6s - loss: 0.1842 - mse: 0.1918 - mae: 0.1842 - val_loss: 0.2354 - val_mse: 0.2375 - val_mae: 0.2354
# Epoch 327/30000
#  - 6s - loss: 0.1842 - mse: 0.1856 - mae: 0.1842 - val_loss: 0.2351 - val_mse: 0.2361 - val_mae: 0.2351
# Epoch 328/30000
#  - 6s - loss: 0.1839 - mse: 0.1874 - mae: 0.1839 - val_loss: 0.2340 - val_mse: 0.2308 - val_mae: 0.2340
# Epoch 329/30000
#  - 6s - loss: 0.1848 - mse: 0.1876 - mae: 0.1848 - val_loss: 0.2363 - val_mse: 0.2336 - val_mae: 0.2363
# Epoch 330/30000
#  - 6s - loss: 0.1832 - mse: 0.1830 - mae: 0.1832 - val_loss: 0.2340 - val_mse: 0.2298 - val_mae: 0.2340
# Epoch 331/30000
#  - 6s - loss: 0.1846 - mse: 0.1873 - mae: 0.1846 - val_loss: 0.2369 - val_mse: 0.2303 - val_mae: 0.2369
# Epoch 332/30000
#  - 6s - loss: 0.1828 - mse: 0.1850 - mae: 0.1828 - val_loss: 0.2347 - val_mse: 0.2328 - val_mae: 0.2347
# Epoch 333/30000
#  - 6s - loss: 0.1839 - mse: 0.1888 - mae: 0.1839 - val_loss: 0.2330 - val_mse: 0.2300 - val_mae: 0.2330
# Epoch 334/30000
#  - 6s - loss: 0.1832 - mse: 0.1867 - mae: 0.1832 - val_loss: 0.2352 - val_mse: 0.2358 - val_mae: 0.2352
# Epoch 335/30000
#  - 6s - loss: 0.1825 - mse: 0.1848 - mae: 0.1825 - val_loss: 0.2318 - val_mse: 0.2311 - val_mae: 0.2318
# Epoch 336/30000
#  - 6s - loss: 0.1838 - mse: 0.1885 - mae: 0.1838 - val_loss: 0.2329 - val_mse: 0.2292 - val_mae: 0.2329
# Epoch 337/30000
#  - 6s - loss: 0.1843 - mse: 0.1880 - mae: 0.1843 - val_loss: 0.2374 - val_mse: 0.2353 - val_mae: 0.2374
# Epoch 338/30000
#  - 6s - loss: 0.1832 - mse: 0.1846 - mae: 0.1832 - val_loss: 0.2343 - val_mse: 0.2344 - val_mae: 0.2343
# Epoch 339/30000
#  - 6s - loss: 0.1833 - mse: 0.1841 - mae: 0.1833 - val_loss: 0.2393 - val_mse: 0.2379 - val_mae: 0.2393
# Epoch 340/30000
#  - 6s - loss: 0.1829 - mse: 0.1854 - mae: 0.1829 - val_loss: 0.2378 - val_mse: 0.2364 - val_mae: 0.2378
# Epoch 341/30000
#  - 6s - loss: 0.1828 - mse: 0.1864 - mae: 0.1828 - val_loss: 0.2361 - val_mse: 0.2343 - val_mae: 0.2361
# Epoch 342/30000
#  - 6s - loss: 0.1831 - mse: 0.1870 - mae: 0.1831 - val_loss: 0.2391 - val_mse: 0.2355 - val_mae: 0.2391
# Epoch 343/30000
#  - 6s - loss: 0.1827 - mse: 0.1842 - mae: 0.1827 - val_loss: 0.2347 - val_mse: 0.2337 - val_mae: 0.2347
# Epoch 344/30000
#  - 6s - loss: 0.1816 - mse: 0.1826 - mae: 0.1816 - val_loss: 0.2338 - val_mse: 0.2318 - val_mae: 0.2338
# Epoch 345/30000
#  - 6s - loss: 0.1824 - mse: 0.1856 - mae: 0.1824 - val_loss: 0.2351 - val_mse: 0.2319 - val_mae: 0.2351
# Epoch 346/30000
#  - 6s - loss: 0.1814 - mse: 0.1845 - mae: 0.1814 - val_loss: 0.2356 - val_mse: 0.2318 - val_mae: 0.2356
# Epoch 347/30000
#  - 6s - loss: 0.1814 - mse: 0.1856 - mae: 0.1814 - val_loss: 0.2339 - val_mse: 0.2297 - val_mae: 0.2339
# Epoch 348/30000
#  - 6s - loss: 0.1819 - mse: 0.1822 - mae: 0.1819 - val_loss: 0.2355 - val_mse: 0.2301 - val_mae: 0.2355
# Epoch 349/30000
#  - 6s - loss: 0.1831 - mse: 0.1855 - mae: 0.1831 - val_loss: 0.2373 - val_mse: 0.2349 - val_mae: 0.2373
# Epoch 350/30000
#  - 6s - loss: 0.1808 - mse: 0.1839 - mae: 0.1808 - val_loss: 0.2340 - val_mse: 0.2318 - val_mae: 0.2340
# Epoch 351/30000
#  - 6s - loss: 0.1808 - mse: 0.1830 - mae: 0.1808 - val_loss: 0.2331 - val_mse: 0.2322 - val_mae: 0.2331
# Epoch 352/30000
#  - 6s - loss: 0.1815 - mse: 0.1829 - mae: 0.1815 - val_loss: 0.2329 - val_mse: 0.2339 - val_mae: 0.2329
# Epoch 353/30000
#  - 6s - loss: 0.1828 - mse: 0.1856 - mae: 0.1828 - val_loss: 0.2337 - val_mse: 0.2294 - val_mae: 0.2337
# Epoch 354/30000
#  - 6s - loss: 0.1813 - mse: 0.1835 - mae: 0.1813 - val_loss: 0.2361 - val_mse: 0.2350 - val_mae: 0.2361
# Epoch 355/30000
#  - 6s - loss: 0.1815 - mse: 0.1832 - mae: 0.1815 - val_loss: 0.2324 - val_mse: 0.2344 - val_mae: 0.2324
# Epoch 356/30000
#  - 6s - loss: 0.1807 - mse: 0.1840 - mae: 0.1807 - val_loss: 0.2361 - val_mse: 0.2374 - val_mae: 0.2361
# Epoch 357/30000
#  - 6s - loss: 0.1805 - mse: 0.1836 - mae: 0.1805 - val_loss: 0.2341 - val_mse: 0.2338 - val_mae: 0.2341
# Epoch 358/30000
#  - 6s - loss: 0.1820 - mse: 0.1839 - mae: 0.1820 - val_loss: 0.2334 - val_mse: 0.2327 - val_mae: 0.2334
# Epoch 359/30000
#  - 6s - loss: 0.1802 - mse: 0.1810 - mae: 0.1802 - val_loss: 0.2329 - val_mse: 0.2288 - val_mae: 0.2329
# Epoch 360/30000
#  - 6s - loss: 0.1793 - mse: 0.1806 - mae: 0.1793 - val_loss: 0.2348 - val_mse: 0.2336 - val_mae: 0.2348
# Epoch 361/30000
#  - 6s - loss: 0.1811 - mse: 0.1840 - mae: 0.1811 - val_loss: 0.2300 - val_mse: 0.2323 - val_mae: 0.2300
# Epoch 362/30000
#  - 6s - loss: 0.1796 - mse: 0.1837 - mae: 0.1796 - val_loss: 0.2317 - val_mse: 0.2322 - val_mae: 0.2317
# Epoch 363/30000
#  - 6s - loss: 0.1796 - mse: 0.1811 - mae: 0.1796 - val_loss: 0.2338 - val_mse: 0.2312 - val_mae: 0.2338
# Epoch 364/30000
#  - 6s - loss: 0.1792 - mse: 0.1814 - mae: 0.1792 - val_loss: 0.2357 - val_mse: 0.2288 - val_mae: 0.2357
# Epoch 365/30000
#  - 6s - loss: 0.1805 - mse: 0.1810 - mae: 0.1805 - val_loss: 0.2325 - val_mse: 0.2288 - val_mae: 0.2325
# Epoch 366/30000
#  - 6s - loss: 0.1804 - mse: 0.1824 - mae: 0.1804 - val_loss: 0.2359 - val_mse: 0.2309 - val_mae: 0.2359
# Epoch 367/30000
#  - 6s - loss: 0.1807 - mse: 0.1822 - mae: 0.1807 - val_loss: 0.2329 - val_mse: 0.2260 - val_mae: 0.2329
# Epoch 368/30000
#  - 6s - loss: 0.1796 - mse: 0.1837 - mae: 0.1796 - val_loss: 0.2372 - val_mse: 0.2350 - val_mae: 0.2372
# Epoch 369/30000
#  - 6s - loss: 0.1805 - mse: 0.1814 - mae: 0.1805 - val_loss: 0.2344 - val_mse: 0.2364 - val_mae: 0.2344
# Epoch 370/30000
#  - 6s - loss: 0.1798 - mse: 0.1802 - mae: 0.1798 - val_loss: 0.2324 - val_mse: 0.2319 - val_mae: 0.2324
# Epoch 371/30000
#  - 6s - loss: 0.1790 - mse: 0.1824 - mae: 0.1790 - val_loss: 0.2333 - val_mse: 0.2339 - val_mae: 0.2333
# Epoch 372/30000
#  - 6s - loss: 0.1793 - mse: 0.1832 - mae: 0.1793 - val_loss: 0.2306 - val_mse: 0.2293 - val_mae: 0.2306
# Epoch 373/30000
#  - 6s - loss: 0.1784 - mse: 0.1807 - mae: 0.1784 - val_loss: 0.2323 - val_mse: 0.2292 - val_mae: 0.2323
# Epoch 374/30000
#  - 6s - loss: 0.1796 - mse: 0.1834 - mae: 0.1796 - val_loss: 0.2349 - val_mse: 0.2365 - val_mae: 0.2349
# Epoch 375/30000
#  - 6s - loss: 0.1794 - mse: 0.1808 - mae: 0.1794 - val_loss: 0.2331 - val_mse: 0.2331 - val_mae: 0.2331
# Epoch 376/30000
#  - 6s - loss: 0.1778 - mse: 0.1789 - mae: 0.1778 - val_loss: 0.2341 - val_mse: 0.2335 - val_mae: 0.2341
# Epoch 377/30000
#  - 6s - loss: 0.1782 - mse: 0.1787 - mae: 0.1782 - val_loss: 0.2330 - val_mse: 0.2308 - val_mae: 0.2330
# Epoch 378/30000
#  - 6s - loss: 0.1784 - mse: 0.1815 - mae: 0.1784 - val_loss: 0.2327 - val_mse: 0.2304 - val_mae: 0.2327
# Epoch 379/30000
#  - 6s - loss: 0.1804 - mse: 0.1821 - mae: 0.1804 - val_loss: 0.2354 - val_mse: 0.2354 - val_mae: 0.2354
# Epoch 380/30000
#  - 6s - loss: 0.1781 - mse: 0.1792 - mae: 0.1781 - val_loss: 0.2323 - val_mse: 0.2297 - val_mae: 0.2323
# Epoch 381/30000
#  - 6s - loss: 0.1779 - mse: 0.1801 - mae: 0.1779 - val_loss: 0.2331 - val_mse: 0.2313 - val_mae: 0.2331
# Epoch 382/30000
#  - 6s - loss: 0.1780 - mse: 0.1791 - mae: 0.1780 - val_loss: 0.2323 - val_mse: 0.2299 - val_mae: 0.2323
# Epoch 383/30000
#  - 6s - loss: 0.1784 - mse: 0.1819 - mae: 0.1784 - val_loss: 0.2316 - val_mse: 0.2284 - val_mae: 0.2316
# Epoch 384/30000
#  - 6s - loss: 0.1787 - mse: 0.1790 - mae: 0.1787 - val_loss: 0.2347 - val_mse: 0.2329 - val_mae: 0.2347
# Epoch 385/30000
#  - 6s - loss: 0.1788 - mse: 0.1797 - mae: 0.1788 - val_loss: 0.2326 - val_mse: 0.2346 - val_mae: 0.2326
# Epoch 386/30000
#  - 6s - loss: 0.1786 - mse: 0.1783 - mae: 0.1786 - val_loss: 0.2344 - val_mse: 0.2317 - val_mae: 0.2344
# Epoch 387/30000
#  - 6s - loss: 0.1787 - mse: 0.1785 - mae: 0.1787 - val_loss: 0.2337 - val_mse: 0.2366 - val_mae: 0.2337
# Epoch 388/30000
#  - 6s - loss: 0.1785 - mse: 0.1824 - mae: 0.1785 - val_loss: 0.2368 - val_mse: 0.2311 - val_mae: 0.2368
# Epoch 389/30000
#  - 6s - loss: 0.1785 - mse: 0.1807 - mae: 0.1785 - val_loss: 0.2314 - val_mse: 0.2296 - val_mae: 0.2314
# Epoch 390/30000
#  - 6s - loss: 0.1781 - mse: 0.1805 - mae: 0.1781 - val_loss: 0.2303 - val_mse: 0.2298 - val_mae: 0.2303
# Epoch 391/30000
#  - 6s - loss: 0.1772 - mse: 0.1806 - mae: 0.1772 - val_loss: 0.2350 - val_mse: 0.2389 - val_mae: 0.2350
# Epoch 392/30000
#  - 6s - loss: 0.1770 - mse: 0.1790 - mae: 0.1770 - val_loss: 0.2321 - val_mse: 0.2339 - val_mae: 0.2321
# Epoch 393/30000
#  - 6s - loss: 0.1776 - mse: 0.1792 - mae: 0.1776 - val_loss: 0.2359 - val_mse: 0.2303 - val_mae: 0.2359
# Epoch 394/30000
#  - 6s - loss: 0.1784 - mse: 0.1808 - mae: 0.1784 - val_loss: 0.2301 - val_mse: 0.2291 - val_mae: 0.2301
# Epoch 395/30000
#  - 6s - loss: 0.1777 - mse: 0.1809 - mae: 0.1777 - val_loss: 0.2326 - val_mse: 0.2296 - val_mae: 0.2326
# Epoch 396/30000
#  - 6s - loss: 0.1782 - mse: 0.1799 - mae: 0.1782 - val_loss: 0.2351 - val_mse: 0.2352 - val_mae: 0.2351
# Epoch 397/30000
#  - 6s - loss: 0.1778 - mse: 0.1769 - mae: 0.1778 - val_loss: 0.2326 - val_mse: 0.2341 - val_mae: 0.2326
# Epoch 398/30000
#  - 6s - loss: 0.1776 - mse: 0.1785 - mae: 0.1776 - val_loss: 0.2298 - val_mse: 0.2270 - val_mae: 0.2298
# Epoch 399/30000
#  - 6s - loss: 0.1762 - mse: 0.1781 - mae: 0.1762 - val_loss: 0.2330 - val_mse: 0.2350 - val_mae: 0.2330
# Epoch 400/30000
#  - 6s - loss: 0.1774 - mse: 0.1796 - mae: 0.1774 - val_loss: 0.2299 - val_mse: 0.2275 - val_mae: 0.2299
# Epoch 401/30000
#  - 6s - loss: 0.1767 - mse: 0.1777 - mae: 0.1767 - val_loss: 0.2322 - val_mse: 0.2278 - val_mae: 0.2322
# Epoch 402/30000
#  - 6s - loss: 0.1767 - mse: 0.1758 - mae: 0.1767 - val_loss: 0.2317 - val_mse: 0.2309 - val_mae: 0.2317
# Epoch 403/30000
#  - 6s - loss: 0.1786 - mse: 0.1787 - mae: 0.1786 - val_loss: 0.2352 - val_mse: 0.2349 - val_mae: 0.2352
# Epoch 404/30000
#  - 6s - loss: 0.1765 - mse: 0.1759 - mae: 0.1765 - val_loss: 0.2386 - val_mse: 0.2364 - val_mae: 0.2386
# Epoch 405/30000
#  - 6s - loss: 0.1774 - mse: 0.1788 - mae: 0.1774 - val_loss: 0.2318 - val_mse: 0.2310 - val_mae: 0.2318
# Epoch 406/30000
#  - 6s - loss: 0.1759 - mse: 0.1765 - mae: 0.1759 - val_loss: 0.2321 - val_mse: 0.2314 - val_mae: 0.2321
# Epoch 407/30000
#  - 6s - loss: 0.1748 - mse: 0.1734 - mae: 0.1748 - val_loss: 0.2338 - val_mse: 0.2320 - val_mae: 0.2338
# Epoch 408/30000
#  - 6s - loss: 0.1774 - mse: 0.1787 - mae: 0.1774 - val_loss: 0.2289 - val_mse: 0.2280 - val_mae: 0.2289
# Epoch 409/30000
#  - 6s - loss: 0.1756 - mse: 0.1761 - mae: 0.1756 - val_loss: 0.2319 - val_mse: 0.2311 - val_mae: 0.2319
# Epoch 410/30000
#  - 6s - loss: 0.1764 - mse: 0.1754 - mae: 0.1764 - val_loss: 0.2320 - val_mse: 0.2294 - val_mae: 0.2320
# Epoch 411/30000
#  - 6s - loss: 0.1761 - mse: 0.1736 - mae: 0.1761 - val_loss: 0.2343 - val_mse: 0.2390 - val_mae: 0.2343
# Epoch 412/30000
#  - 6s - loss: 0.1757 - mse: 0.1732 - mae: 0.1757 - val_loss: 0.2338 - val_mse: 0.2466 - val_mae: 0.2338
# Epoch 413/30000
#  - 6s - loss: 0.1759 - mse: 0.1753 - mae: 0.1759 - val_loss: 0.2351 - val_mse: 0.2336 - val_mae: 0.2351
# Epoch 414/30000
#  - 6s - loss: 0.1761 - mse: 0.1751 - mae: 0.1761 - val_loss: 0.2334 - val_mse: 0.2314 - val_mae: 0.2334
# Epoch 415/30000
#  - 6s - loss: 0.1758 - mse: 0.1737 - mae: 0.1758 - val_loss: 0.2342 - val_mse: 0.2311 - val_mae: 0.2342
# Epoch 416/30000
#  - 6s - loss: 0.1744 - mse: 0.1745 - mae: 0.1744 - val_loss: 0.2333 - val_mse: 0.2324 - val_mae: 0.2333
# Epoch 417/30000
#  - 6s - loss: 0.1755 - mse: 0.1760 - mae: 0.1755 - val_loss: 0.2352 - val_mse: 0.2329 - val_mae: 0.2352
# Epoch 418/30000
#  - 6s - loss: 0.1748 - mse: 0.1710 - mae: 0.1748 - val_loss: 0.2317 - val_mse: 0.2299 - val_mae: 0.2317
# Epoch 419/30000
#  - 6s - loss: 0.1760 - mse: 0.1744 - mae: 0.1760 - val_loss: 0.2340 - val_mse: 0.2325 - val_mae: 0.2340
# Epoch 420/30000
#  - 6s - loss: 0.1759 - mse: 0.1773 - mae: 0.1759 - val_loss: 0.2303 - val_mse: 0.2286 - val_mae: 0.2303
# Epoch 421/30000
#  - 6s - loss: 0.1755 - mse: 0.1765 - mae: 0.1755 - val_loss: 0.2311 - val_mse: 0.2294 - val_mae: 0.2311
# Epoch 422/30000
#  - 6s - loss: 0.1760 - mse: 0.1791 - mae: 0.1760 - val_loss: 0.2301 - val_mse: 0.2283 - val_mae: 0.2301
# Epoch 423/30000
#  - 6s - loss: 0.1752 - mse: 0.1756 - mae: 0.1752 - val_loss: 0.2340 - val_mse: 0.2307 - val_mae: 0.2340
# Epoch 424/30000
#  - 6s - loss: 0.1750 - mse: 0.1745 - mae: 0.1750 - val_loss: 0.2324 - val_mse: 0.2285 - val_mae: 0.2324
# Epoch 425/30000
#  - 6s - loss: 0.1743 - mse: 0.1727 - mae: 0.1743 - val_loss: 0.2342 - val_mse: 0.2360 - val_mae: 0.2342
# Epoch 426/30000
#  - 6s - loss: 0.1755 - mse: 0.1755 - mae: 0.1755 - val_loss: 0.2324 - val_mse: 0.2316 - val_mae: 0.2324
# Epoch 427/30000
#  - 6s - loss: 0.1742 - mse: 0.1728 - mae: 0.1742 - val_loss: 0.2310 - val_mse: 0.2317 - val_mae: 0.2310
# Epoch 428/30000
#  - 6s - loss: 0.1750 - mse: 0.1755 - mae: 0.1750 - val_loss: 0.2343 - val_mse: 0.2315 - val_mae: 0.2343
# Epoch 429/30000
#  - 6s - loss: 0.1745 - mse: 0.1775 - mae: 0.1745 - val_loss: 0.2295 - val_mse: 0.2315 - val_mae: 0.2295
# Epoch 430/30000
#  - 6s - loss: 0.1750 - mse: 0.1738 - mae: 0.1750 - val_loss: 0.2299 - val_mse: 0.2296 - val_mae: 0.2299
# Epoch 431/30000
#  - 6s - loss: 0.1754 - mse: 0.1749 - mae: 0.1754 - val_loss: 0.2323 - val_mse: 0.2292 - val_mae: 0.2323
# Epoch 432/30000
#  - 6s - loss: 0.1753 - mse: 0.1756 - mae: 0.1753 - val_loss: 0.2307 - val_mse: 0.2315 - val_mae: 0.2307
# Epoch 433/30000
#  - 6s - loss: 0.1732 - mse: 0.1721 - mae: 0.1732 - val_loss: 0.2352 - val_mse: 0.2319 - val_mae: 0.2352
# Epoch 434/30000
#  - 6s - loss: 0.1762 - mse: 0.1785 - mae: 0.1762 - val_loss: 0.2345 - val_mse: 0.2328 - val_mae: 0.2345
# Epoch 435/30000
#  - 6s - loss: 0.1759 - mse: 0.1741 - mae: 0.1759 - val_loss: 0.2302 - val_mse: 0.2307 - val_mae: 0.2302
# Epoch 436/30000
#  - 6s - loss: 0.1748 - mse: 0.1762 - mae: 0.1748 - val_loss: 0.2325 - val_mse: 0.2296 - val_mae: 0.2325
# Epoch 437/30000
#  - 6s - loss: 0.1745 - mse: 0.1776 - mae: 0.1745 - val_loss: 0.2310 - val_mse: 0.2298 - val_mae: 0.2310
# Epoch 438/30000
#  - 6s - loss: 0.1739 - mse: 0.1711 - mae: 0.1739 - val_loss: 0.2301 - val_mse: 0.2285 - val_mae: 0.2301
# Epoch 439/30000
#  - 6s - loss: 0.1755 - mse: 0.1771 - mae: 0.1755 - val_loss: 0.2304 - val_mse: 0.2271 - val_mae: 0.2304
# Epoch 440/30000
#  - 6s - loss: 0.1739 - mse: 0.1756 - mae: 0.1739 - val_loss: 0.2331 - val_mse: 0.2341 - val_mae: 0.2331
# Epoch 441/30000
#  - 6s - loss: 0.1744 - mse: 0.1766 - mae: 0.1744 - val_loss: 0.2332 - val_mse: 0.2282 - val_mae: 0.2332
# Epoch 442/30000
#  - 6s - loss: 0.1731 - mse: 0.1736 - mae: 0.1731 - val_loss: 0.2318 - val_mse: 0.2311 - val_mae: 0.2318
# Epoch 443/30000
#  - 6s - loss: 0.1742 - mse: 0.1752 - mae: 0.1742 - val_loss: 0.2321 - val_mse: 0.2320 - val_mae: 0.2321
# Epoch 444/30000
#  - 6s - loss: 0.1738 - mse: 0.1741 - mae: 0.1738 - val_loss: 0.2350 - val_mse: 0.2389 - val_mae: 0.2350
# Epoch 445/30000
#  - 6s - loss: 0.1737 - mse: 0.1735 - mae: 0.1737 - val_loss: 0.2339 - val_mse: 0.2325 - val_mae: 0.2339
# Epoch 446/30000
#  - 6s - loss: 0.1744 - mse: 0.1713 - mae: 0.1744 - val_loss: 0.2361 - val_mse: 0.2372 - val_mae: 0.2361
# Epoch 447/30000
#  - 6s - loss: 0.1741 - mse: 0.1724 - mae: 0.1741 - val_loss: 0.2326 - val_mse: 0.2332 - val_mae: 0.2326
# Epoch 448/30000
#  - 6s - loss: 0.1737 - mse: 0.1726 - mae: 0.1737 - val_loss: 0.2370 - val_mse: 0.2357 - val_mae: 0.2370
# Epoch 449/30000
#  - 6s - loss: 0.1736 - mse: 0.1737 - mae: 0.1736 - val_loss: 0.2354 - val_mse: 0.2348 - val_mae: 0.2354
# Epoch 450/30000
#  - 6s - loss: 0.1730 - mse: 0.1724 - mae: 0.1730 - val_loss: 0.2317 - val_mse: 0.2314 - val_mae: 0.2317
# Epoch 451/30000
#  - 6s - loss: 0.1720 - mse: 0.1723 - mae: 0.1720 - val_loss: 0.2357 - val_mse: 0.2342 - val_mae: 0.2357
# Epoch 452/30000
#  - 6s - loss: 0.1732 - mse: 0.1738 - mae: 0.1732 - val_loss: 0.2331 - val_mse: 0.2313 - val_mae: 0.2331
# Epoch 453/30000
#  - 6s - loss: 0.1732 - mse: 0.1734 - mae: 0.1732 - val_loss: 0.2329 - val_mse: 0.2323 - val_mae: 0.2329
# Epoch 454/30000
#  - 6s - loss: 0.1722 - mse: 0.1720 - mae: 0.1722 - val_loss: 0.2353 - val_mse: 0.2343 - val_mae: 0.2353
# Epoch 455/30000
#  - 6s - loss: 0.1725 - mse: 0.1726 - mae: 0.1725 - val_loss: 0.2345 - val_mse: 0.2308 - val_mae: 0.2345
# Epoch 456/30000
#  - 6s - loss: 0.1728 - mse: 0.1739 - mae: 0.1728 - val_loss: 0.2324 - val_mse: 0.2296 - val_mae: 0.2324
# Epoch 457/30000
#  - 6s - loss: 0.1726 - mse: 0.1699 - mae: 0.1726 - val_loss: 0.2352 - val_mse: 0.2285 - val_mae: 0.2352
# Epoch 458/30000
#  - 6s - loss: 0.1725 - mse: 0.1718 - mae: 0.1725 - val_loss: 0.2299 - val_mse: 0.2283 - val_mae: 0.2299

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.03 degrees
# Root Mean Squared Error is 1.77 degrees
# Mean Absolute Error is 1.77 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is 0.08 degrees
# Root Mean Squared Error is 3.32 degrees
# Mean Absolute Error is 3.32 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthmodelparam_cnn3v14.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthmodel_cnn3v14.h5')
