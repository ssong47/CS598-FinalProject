# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,30,31,32,33,35)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (28044, 120, 160, 3)

# %%
# tlen = len(xtemp[0])-2 +len(xtemp[1])-2+len(xtemp[2])+len(xtemp[3]) #remove 2 samples from 24
# x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
# x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
# x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

tlen = len(xtemp[0]) +len(xtemp[1])+len(xtemp[2])+len(xtemp[3])+len(xtemp[4])+len(xtemp[5]) #remove 2 samples from 24 and 3 from 25
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
xrun = len(xtemp[0])
x_train[:xrun,:,:,:] = xtemp[0][:xrun,:,:,:]
xrun1 = xrun + len(xtemp[1])
x_train[xrun:xrun1,:,:,:]=xtemp[1][:xrun1-xrun,:,:,:]
xrun2 = xrun1 + len(xtemp[2])
x_train[xrun1:xrun2,:,:,:] = xtemp[2][:xrun2-xrun1,:,:,:]
xrun3 = xrun2 + len(xtemp[3])
x_train[xrun2:xrun3,:,:,:] = xtemp[3][:xrun3-xrun2,:,:,:]
xrun4 = xrun3 + len(xtemp[4])
x_train[xrun3:xrun4,:,:,:] = xtemp[4][:xrun4-xrun3,:,:,:]
xrun5 = xrun4 + len(xtemp[5])
x_train[xrun4:xrun5,:,:,:] = xtemp[5][:xrun5-xrun4,:,:,:]

# %%
print(x_train.shape)
del xtemp
# Out:
# (82381, 60, 80, 3)

# %% [markdown]
# # read fcss data

# %%
n_test = (24,30,31,32,33,35)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020')
xfcss_gt = {}
yrun = 0
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + "/" +test_str
    fcss_data_dir = data_dir + "/fcss_processed_leo_" + test_str + '_' + date[i] + '.txt'
    xfcss_gttemp = pd.read_csv(fcss_data_dir)
    xfcss_gt[i]=xfcss_gttemp
    if i==0:
        xfcss_train=xfcss_gttemp
    else:
        xfcss_train = pd.concat([xfcss_train,xfcss_gt[i]],axis=0)

# %%
# tmpdata.head()

# %%
xfcss_train.shape
# Out:
# (82381, 6)

# %% [markdown]
# # Read Output Data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,30,31,32,33,35)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020')
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
y_train = np.zeros((tlen,1))
xrun = len(y_gt[0])
y_train[:xrun] = y_gt[0][:xrun]
xrun1 = xrun + len(y_gt[1])
y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
xrun2 = xrun1 + len(y_gt[2])
y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
xrun3 = xrun2 + len(y_gt[3])
y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
xrun4 = xrun3 + len(y_gt[4])
y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
xrun5 = xrun4 + len(y_gt[5])
y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]
del y_gt

# %%
print(x_train.shape)
print(xfcss_train.shape)
print(y_train.shape)
# Out:
# (82381, 60, 80, 3)
# (82381, 6)
# (82381, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Trainset2 = xfcss_train.values[rannums,:]
Testset = x_train[test_set,:]
Testset2 = xfcss_train.values[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_X2 = StandardScaler()
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
Xtrainz2 = Trainset2
ytrainz = Trainy
X = Xtrainz
X2 = sc_X2.fit_transform(Xtrainz2)
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset
Xvalid2 = sc_X2.transform(Testset2)
y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %% [markdown]
# # Regress using Neural Network

# %%
x_train.shape
# Out:
# (82381, 60, 80, 3)

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()
import keras
from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model
dropout_rate = 0.2

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_start2 = Input(shape=(xfcss_train.shape[1],))
model_cnn = model_start
model_perc = model_start2

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Conv2D(filters=96, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Flatten()(model_cnn)
# model_perc = Flatten()(model_perc)
# model_cnn = Activation('relu')(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

model_comb = concatenate([model_cnn,model_perc],axis=-1)

output = Dense(1)(model_comb)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=[model_start,model_start2],outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience.
# Out:
# TensorShape([None, 100])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_56 (InputLayer)           (None, 60, 80, 3)    0
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 60, 80, 16)   448         input_56[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 60, 80, 16)   0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_109 (AverageP (None, 30, 40, 16)   0           activation_186[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 30, 40, 32)   4640        average_pooling2d_109[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 30, 40, 32)   0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_110 (AverageP (None, 15, 20, 32)   0           activation_188[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 15, 20, 64)   18496       average_pooling2d_110[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 15, 20, 64)   0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_111 (AverageP (None, 7, 10, 64)    0           activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 7, 10, 96)    55392       average_pooling2d_111[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 7, 10, 96)    0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_112 (AverageP (None, 3, 5, 96)     0           activation_191[0][0]
# __________________________________________________________________________________________________
# input_57 (InputLayer)           (None, 6)            0
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 1440)         0           average_pooling2d_112[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 100)          700         input_57[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 128)          184448      flatten_29[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 100)          0           dense_69[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 128)          0           dense_71[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 100)          10100       activation_187[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           activation_192[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 100)          0           dense_70[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 228)          0           dropout_4[0][0]
#                                                                  activation_189[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 1)            229         concatenate_7[0][0]
# __________________________________________________________________________________________________
# thetaz_out (Activation)         (None, 1)            0           dense_72[0][0]
# ==================================================================================================
# Total params: 274,453
# Trainable params: 274,453
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
history = model.fit([X,X2], y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = ([Xvalid,Xvalid2], y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 65904 samples, validate on 16477 samples
# Epoch 1/30000
#  - 11s - loss: 0.4982 - mse: 0.7630 - mae: 0.4982 - val_loss: 0.4618 - val_mse: 0.6678 - val_mae: 0.4618
# Epoch 2/30000
#  - 8s - loss: 0.4402 - mse: 0.6222 - mae: 0.4402 - val_loss: 0.4114 - val_mse: 0.5645 - val_mae: 0.4114
# Epoch 3/30000
#  - 8s - loss: 0.4054 - mse: 0.5694 - mae: 0.4054 - val_loss: 0.3825 - val_mse: 0.5181 - val_mae: 0.3825
# Epoch 4/30000
#  - 8s - loss: 0.3877 - mse: 0.5427 - mae: 0.3877 - val_loss: 0.3687 - val_mse: 0.5031 - val_mae: 0.3687
# Epoch 5/30000
#  - 8s - loss: 0.3708 - mse: 0.5207 - mae: 0.3708 - val_loss: 0.3593 - val_mse: 0.4902 - val_mae: 0.3593
# Epoch 6/30000
#  - 8s - loss: 0.3605 - mse: 0.5074 - mae: 0.3605 - val_loss: 0.3449 - val_mse: 0.4703 - val_mae: 0.3449
# Epoch 7/30000
#  - 8s - loss: 0.3501 - mse: 0.4927 - mae: 0.3501 - val_loss: 0.3377 - val_mse: 0.4654 - val_mae: 0.3377
# Epoch 8/30000
#  - 8s - loss: 0.3409 - mse: 0.4818 - mae: 0.3409 - val_loss: 0.3304 - val_mse: 0.4548 - val_mae: 0.3304
# Epoch 9/30000
#  - 8s - loss: 0.3334 - mse: 0.4736 - mae: 0.3334 - val_loss: 0.3305 - val_mse: 0.4549 - val_mae: 0.3305
# Epoch 10/30000
#  - 8s - loss: 0.3253 - mse: 0.4630 - mae: 0.3253 - val_loss: 0.3161 - val_mse: 0.4379 - val_mae: 0.3161
# Epoch 11/30000
#  - 8s - loss: 0.3200 - mse: 0.4563 - mae: 0.3200 - val_loss: 0.3093 - val_mse: 0.4283 - val_mae: 0.3093
# Epoch 12/30000
#  - 8s - loss: 0.3137 - mse: 0.4483 - mae: 0.3137 - val_loss: 0.3089 - val_mse: 0.4298 - val_mae: 0.3089
# Epoch 13/30000
#  - 8s - loss: 0.3072 - mse: 0.4403 - mae: 0.3072 - val_loss: 0.2983 - val_mse: 0.4186 - val_mae: 0.2983
# Epoch 14/30000
#  - 8s - loss: 0.3020 - mse: 0.4341 - mae: 0.3020 - val_loss: 0.2969 - val_mse: 0.4166 - val_mae: 0.2969
# Epoch 15/30000
#  - 8s - loss: 0.2968 - mse: 0.4272 - mae: 0.2968 - val_loss: 0.2973 - val_mse: 0.4138 - val_mae: 0.2973
# Epoch 16/30000
#  - 8s - loss: 0.2919 - mse: 0.4211 - mae: 0.2919 - val_loss: 0.2864 - val_mse: 0.4038 - val_mae: 0.2864
# Epoch 17/30000
#  - 8s - loss: 0.2886 - mse: 0.4165 - mae: 0.2886 - val_loss: 0.2904 - val_mse: 0.4078 - val_mae: 0.2904
# Epoch 18/30000
#  - 8s - loss: 0.2821 - mse: 0.4095 - mae: 0.2821 - val_loss: 0.2936 - val_mse: 0.4108 - val_mae: 0.2936
# Epoch 19/30000
#  - 8s - loss: 0.2792 - mse: 0.4053 - mae: 0.2792 - val_loss: 0.2773 - val_mse: 0.3929 - val_mae: 0.2773
# Epoch 20/30000
#  - 8s - loss: 0.2769 - mse: 0.4023 - mae: 0.2769 - val_loss: 0.2764 - val_mse: 0.3917 - val_mae: 0.2764
# Epoch 21/30000
#  - 8s - loss: 0.2734 - mse: 0.3986 - mae: 0.2734 - val_loss: 0.2770 - val_mse: 0.3924 - val_mae: 0.2770
# Epoch 22/30000
#  - 8s - loss: 0.2697 - mse: 0.3934 - mae: 0.2697 - val_loss: 0.2675 - val_mse: 0.3848 - val_mae: 0.2675
# Epoch 23/30000
#  - 8s - loss: 0.2645 - mse: 0.3873 - mae: 0.2645 - val_loss: 0.2702 - val_mse: 0.3864 - val_mae: 0.2702
# Epoch 24/30000
#  - 8s - loss: 0.2628 - mse: 0.3835 - mae: 0.2628 - val_loss: 0.2641 - val_mse: 0.3779 - val_mae: 0.2641
# Epoch 25/30000
#  - 8s - loss: 0.2591 - mse: 0.3788 - mae: 0.2591 - val_loss: 0.2618 - val_mse: 0.3762 - val_mae: 0.2618
# Epoch 26/30000
#  - 8s - loss: 0.2569 - mse: 0.3734 - mae: 0.2569 - val_loss: 0.2555 - val_mse: 0.3672 - val_mae: 0.2555
# Epoch 27/30000
#  - 8s - loss: 0.2538 - mse: 0.3678 - mae: 0.2538 - val_loss: 0.2525 - val_mse: 0.3621 - val_mae: 0.2525
# Epoch 28/30000
#  - 8s - loss: 0.2503 - mse: 0.3592 - mae: 0.2503 - val_loss: 0.2544 - val_mse: 0.3577 - val_mae: 0.2544
# Epoch 29/30000
#  - 8s - loss: 0.2481 - mse: 0.3496 - mae: 0.2481 - val_loss: 0.2527 - val_mse: 0.3534 - val_mae: 0.2527
# Epoch 30/30000
#  - 8s - loss: 0.2434 - mse: 0.3390 - mae: 0.2434 - val_loss: 0.2484 - val_mse: 0.3378 - val_mae: 0.2484
# Epoch 31/30000
#  - 8s - loss: 0.2406 - mse: 0.3279 - mae: 0.2406 - val_loss: 0.2536 - val_mse: 0.3365 - val_mae: 0.2536
# Epoch 32/30000
#  - 8s - loss: 0.2401 - mse: 0.3220 - mae: 0.2401 - val_loss: 0.2442 - val_mse: 0.3214 - val_mae: 0.2442
# Epoch 33/30000
#  - 8s - loss: 0.2358 - mse: 0.3075 - mae: 0.2358 - val_loss: 0.2466 - val_mse: 0.3183 - val_mae: 0.2466
# Epoch 34/30000
#  - 8s - loss: 0.2340 - mse: 0.3032 - mae: 0.2340 - val_loss: 0.2442 - val_mse: 0.3254 - val_mae: 0.2442
# Epoch 35/30000
#  - 8s - loss: 0.2308 - mse: 0.3016 - mae: 0.2308 - val_loss: 0.2403 - val_mse: 0.3041 - val_mae: 0.2403
# Epoch 36/30000
#  - 8s - loss: 0.2279 - mse: 0.2929 - mae: 0.2279 - val_loss: 0.2335 - val_mse: 0.3014 - val_mae: 0.2335
# Epoch 37/30000
#  - 8s - loss: 0.2267 - mse: 0.2941 - mae: 0.2267 - val_loss: 0.2313 - val_mse: 0.2997 - val_mae: 0.2313
# Epoch 38/30000
#  - 8s - loss: 0.2235 - mse: 0.2876 - mae: 0.2235 - val_loss: 0.2344 - val_mse: 0.2963 - val_mae: 0.2344
# Epoch 39/30000
#  - 8s - loss: 0.2220 - mse: 0.2840 - mae: 0.2220 - val_loss: 0.2333 - val_mse: 0.3155 - val_mae: 0.2333
# Epoch 40/30000
#  - 8s - loss: 0.2208 - mse: 0.2830 - mae: 0.2208 - val_loss: 0.2282 - val_mse: 0.2923 - val_mae: 0.2282
# Epoch 41/30000
#  - 8s - loss: 0.2198 - mse: 0.2828 - mae: 0.2198 - val_loss: 0.2251 - val_mse: 0.2885 - val_mae: 0.2251
# Epoch 42/30000
#  - 8s - loss: 0.2172 - mse: 0.2804 - mae: 0.2172 - val_loss: 0.2282 - val_mse: 0.2849 - val_mae: 0.2282
# Epoch 43/30000
#  - 8s - loss: 0.2145 - mse: 0.2710 - mae: 0.2145 - val_loss: 0.2289 - val_mse: 0.2889 - val_mae: 0.2289
# Epoch 44/30000
#  - 8s - loss: 0.2138 - mse: 0.2726 - mae: 0.2138 - val_loss: 0.2280 - val_mse: 0.2905 - val_mae: 0.2280
# Epoch 45/30000
#  - 8s - loss: 0.2122 - mse: 0.2705 - mae: 0.2122 - val_loss: 0.2305 - val_mse: 0.2896 - val_mae: 0.2305
# Epoch 46/30000
#  - 8s - loss: 0.2107 - mse: 0.2663 - mae: 0.2107 - val_loss: 0.2275 - val_mse: 0.2783 - val_mae: 0.2275
# Epoch 47/30000
#  - 8s - loss: 0.2092 - mse: 0.2660 - mae: 0.2092 - val_loss: 0.2217 - val_mse: 0.2762 - val_mae: 0.2217
# Epoch 48/30000
#  - 8s - loss: 0.2072 - mse: 0.2622 - mae: 0.2072 - val_loss: 0.2252 - val_mse: 0.2770 - val_mae: 0.2252
# Epoch 49/30000
#  - 8s - loss: 0.2067 - mse: 0.2634 - mae: 0.2067 - val_loss: 0.2242 - val_mse: 0.2773 - val_mae: 0.2242
# Epoch 50/30000
#  - 8s - loss: 0.2057 - mse: 0.2590 - mae: 0.2057 - val_loss: 0.2192 - val_mse: 0.2743 - val_mae: 0.2192
# Epoch 51/30000
#  - 8s - loss: 0.2039 - mse: 0.2568 - mae: 0.2039 - val_loss: 0.2224 - val_mse: 0.2766 - val_mae: 0.2224
# Epoch 52/30000
#  - 8s - loss: 0.2018 - mse: 0.2556 - mae: 0.2018 - val_loss: 0.2228 - val_mse: 0.2683 - val_mae: 0.2228
# Epoch 53/30000
#  - 8s - loss: 0.2007 - mse: 0.2518 - mae: 0.2007 - val_loss: 0.2191 - val_mse: 0.2687 - val_mae: 0.2191
# Epoch 54/30000
#  - 8s - loss: 0.1995 - mse: 0.2501 - mae: 0.1995 - val_loss: 0.2136 - val_mse: 0.2639 - val_mae: 0.2136
# Epoch 55/30000
#  - 8s - loss: 0.1986 - mse: 0.2475 - mae: 0.1986 - val_loss: 0.2126 - val_mse: 0.2592 - val_mae: 0.2126
# Epoch 56/30000
#  - 8s - loss: 0.1972 - mse: 0.2449 - mae: 0.1972 - val_loss: 0.2165 - val_mse: 0.2582 - val_mae: 0.2165
# Epoch 57/30000
#  - 8s - loss: 0.1976 - mse: 0.2445 - mae: 0.1976 - val_loss: 0.2168 - val_mse: 0.2614 - val_mae: 0.2168
# Epoch 58/30000
#  - 8s - loss: 0.1954 - mse: 0.2413 - mae: 0.1954 - val_loss: 0.2121 - val_mse: 0.2525 - val_mae: 0.2121
# Epoch 59/30000
#  - 8s - loss: 0.1939 - mse: 0.2379 - mae: 0.1939 - val_loss: 0.2164 - val_mse: 0.2596 - val_mae: 0.2164
# Epoch 60/30000
#  - 8s - loss: 0.1929 - mse: 0.2362 - mae: 0.1929 - val_loss: 0.2130 - val_mse: 0.2513 - val_mae: 0.2130
# Epoch 61/30000
#  - 8s - loss: 0.1908 - mse: 0.2319 - mae: 0.1908 - val_loss: 0.2089 - val_mse: 0.2503 - val_mae: 0.2089
# Epoch 62/30000
#  - 8s - loss: 0.1918 - mse: 0.2316 - mae: 0.1918 - val_loss: 0.2084 - val_mse: 0.2495 - val_mae: 0.2084
# Epoch 63/30000
#  - 8s - loss: 0.1902 - mse: 0.2265 - mae: 0.1902 - val_loss: 0.2085 - val_mse: 0.2460 - val_mae: 0.2085
# Epoch 64/30000
#  - 8s - loss: 0.1887 - mse: 0.2236 - mae: 0.1887 - val_loss: 0.2073 - val_mse: 0.2457 - val_mae: 0.2073
# Epoch 65/30000
#  - 8s - loss: 0.1858 - mse: 0.2178 - mae: 0.1858 - val_loss: 0.2084 - val_mse: 0.2406 - val_mae: 0.2084
# Epoch 66/30000
#  - 8s - loss: 0.1858 - mse: 0.2148 - mae: 0.1858 - val_loss: 0.2058 - val_mse: 0.2387 - val_mae: 0.2058
# Epoch 67/30000
#  - 8s - loss: 0.1850 - mse: 0.2112 - mae: 0.1850 - val_loss: 0.2073 - val_mse: 0.2414 - val_mae: 0.2073
# Epoch 68/30000
#  - 8s - loss: 0.1833 - mse: 0.2066 - mae: 0.1833 - val_loss: 0.2047 - val_mse: 0.2432 - val_mae: 0.2047
# Epoch 69/30000
#  - 8s - loss: 0.1835 - mse: 0.2065 - mae: 0.1835 - val_loss: 0.2067 - val_mse: 0.2358 - val_mae: 0.2067
# Epoch 70/30000
#  - 8s - loss: 0.1815 - mse: 0.1991 - mae: 0.1815 - val_loss: 0.2049 - val_mse: 0.2414 - val_mae: 0.2049
# Epoch 71/30000
#  - 8s - loss: 0.1815 - mse: 0.1988 - mae: 0.1815 - val_loss: 0.2027 - val_mse: 0.2353 - val_mae: 0.2027
# Epoch 72/30000
#  - 8s - loss: 0.1799 - mse: 0.1957 - mae: 0.1799 - val_loss: 0.2030 - val_mse: 0.2398 - val_mae: 0.2030
# Epoch 73/30000
#  - 8s - loss: 0.1792 - mse: 0.1942 - mae: 0.1792 - val_loss: 0.2056 - val_mse: 0.2378 - val_mae: 0.2056
# Epoch 74/30000
#  - 8s - loss: 0.1777 - mse: 0.1934 - mae: 0.1777 - val_loss: 0.2046 - val_mse: 0.2370 - val_mae: 0.2046
# Epoch 75/30000
#  - 8s - loss: 0.1774 - mse: 0.1878 - mae: 0.1774 - val_loss: 0.2025 - val_mse: 0.2365 - val_mae: 0.2025
# Epoch 76/30000
#  - 8s - loss: 0.1753 - mse: 0.1832 - mae: 0.1753 - val_loss: 0.1988 - val_mse: 0.2334 - val_mae: 0.1988
# Epoch 77/30000
#  - 8s - loss: 0.1751 - mse: 0.1836 - mae: 0.1751 - val_loss: 0.2057 - val_mse: 0.2366 - val_mae: 0.2057
# Epoch 78/30000
#  - 8s - loss: 0.1741 - mse: 0.1830 - mae: 0.1741 - val_loss: 0.2002 - val_mse: 0.2310 - val_mae: 0.2002
# Epoch 79/30000
#  - 8s - loss: 0.1731 - mse: 0.1799 - mae: 0.1731 - val_loss: 0.1987 - val_mse: 0.2292 - val_mae: 0.1987
# Epoch 80/30000
#  - 8s - loss: 0.1721 - mse: 0.1771 - mae: 0.1721 - val_loss: 0.1995 - val_mse: 0.2340 - val_mae: 0.1995
# Epoch 81/30000
#  - 8s - loss: 0.1718 - mse: 0.1779 - mae: 0.1718 - val_loss: 0.1960 - val_mse: 0.2264 - val_mae: 0.1960
# Epoch 82/30000
#  - 8s - loss: 0.1717 - mse: 0.1775 - mae: 0.1717 - val_loss: 0.2002 - val_mse: 0.2233 - val_mae: 0.2002
# Epoch 83/30000
#  - 8s - loss: 0.1708 - mse: 0.1717 - mae: 0.1708 - val_loss: 0.2014 - val_mse: 0.2406 - val_mae: 0.2014
# Epoch 84/30000
#  - 8s - loss: 0.1702 - mse: 0.1724 - mae: 0.1702 - val_loss: 0.1968 - val_mse: 0.2235 - val_mae: 0.1968
# Epoch 85/30000
#  - 8s - loss: 0.1695 - mse: 0.1696 - mae: 0.1695 - val_loss: 0.2010 - val_mse: 0.2276 - val_mae: 0.2010
# Epoch 86/30000
#  - 8s - loss: 0.1690 - mse: 0.1730 - mae: 0.1690 - val_loss: 0.1948 - val_mse: 0.2229 - val_mae: 0.1948
# Epoch 87/30000
#  - 8s - loss: 0.1665 - mse: 0.1649 - mae: 0.1665 - val_loss: 0.1945 - val_mse: 0.2178 - val_mae: 0.1945
# Epoch 88/30000
#  - 8s - loss: 0.1671 - mse: 0.1660 - mae: 0.1671 - val_loss: 0.1983 - val_mse: 0.2182 - val_mae: 0.1983
# Epoch 89/30000
#  - 8s - loss: 0.1667 - mse: 0.1655 - mae: 0.1667 - val_loss: 0.1956 - val_mse: 0.2223 - val_mae: 0.1956
# Epoch 90/30000
#  - 8s - loss: 0.1664 - mse: 0.1644 - mae: 0.1664 - val_loss: 0.1974 - val_mse: 0.2180 - val_mae: 0.1974
# Epoch 91/30000
#  - 8s - loss: 0.1647 - mse: 0.1611 - mae: 0.1647 - val_loss: 0.1935 - val_mse: 0.2144 - val_mae: 0.1935
# Epoch 92/30000
#  - 8s - loss: 0.1639 - mse: 0.1604 - mae: 0.1639 - val_loss: 0.1951 - val_mse: 0.2136 - val_mae: 0.1951
# Epoch 93/30000
#  - 8s - loss: 0.1634 - mse: 0.1594 - mae: 0.1634 - val_loss: 0.1937 - val_mse: 0.2126 - val_mae: 0.1937
# Epoch 94/30000
#  - 8s - loss: 0.1628 - mse: 0.1578 - mae: 0.1628 - val_loss: 0.1927 - val_mse: 0.2216 - val_mae: 0.1927
# Epoch 95/30000
#  - 8s - loss: 0.1635 - mse: 0.1592 - mae: 0.1635 - val_loss: 0.1928 - val_mse: 0.2084 - val_mae: 0.1928
# Epoch 96/30000
#  - 8s - loss: 0.1618 - mse: 0.1552 - mae: 0.1618 - val_loss: 0.1951 - val_mse: 0.2172 - val_mae: 0.1951
# Epoch 97/30000
#  - 8s - loss: 0.1611 - mse: 0.1529 - mae: 0.1611 - val_loss: 0.1921 - val_mse: 0.2091 - val_mae: 0.1921
# Epoch 98/30000
#  - 8s - loss: 0.1604 - mse: 0.1521 - mae: 0.1604 - val_loss: 0.1976 - val_mse: 0.2129 - val_mae: 0.1976
# Epoch 99/30000
#  - 8s - loss: 0.1606 - mse: 0.1536 - mae: 0.1606 - val_loss: 0.1934 - val_mse: 0.2127 - val_mae: 0.1934
# Epoch 100/30000
#  - 8s - loss: 0.1597 - mse: 0.1537 - mae: 0.1597 - val_loss: 0.1920 - val_mse: 0.2068 - val_mae: 0.1920
# Epoch 101/30000
#  - 8s - loss: 0.1587 - mse: 0.1503 - mae: 0.1587 - val_loss: 0.1903 - val_mse: 0.2089 - val_mae: 0.1903
# Epoch 102/30000
#  - 8s - loss: 0.1586 - mse: 0.1502 - mae: 0.1586 - val_loss: 0.1912 - val_mse: 0.2096 - val_mae: 0.1912
# Epoch 103/30000
#  - 8s - loss: 0.1580 - mse: 0.1491 - mae: 0.1580 - val_loss: 0.1899 - val_mse: 0.2065 - val_mae: 0.1899
# Epoch 104/30000
#  - 8s - loss: 0.1575 - mse: 0.1490 - mae: 0.1575 - val_loss: 0.1918 - val_mse: 0.2078 - val_mae: 0.1918
# Epoch 105/30000
#  - 8s - loss: 0.1559 - mse: 0.1465 - mae: 0.1559 - val_loss: 0.1914 - val_mse: 0.2084 - val_mae: 0.1914
# Epoch 106/30000
#  - 8s - loss: 0.1564 - mse: 0.1465 - mae: 0.1564 - val_loss: 0.1895 - val_mse: 0.2070 - val_mae: 0.1895
# Epoch 107/30000
#  - 8s - loss: 0.1565 - mse: 0.1456 - mae: 0.1565 - val_loss: 0.1934 - val_mse: 0.2102 - val_mae: 0.1934
# Epoch 108/30000
#  - 8s - loss: 0.1557 - mse: 0.1440 - mae: 0.1557 - val_loss: 0.1881 - val_mse: 0.2036 - val_mae: 0.1881
# Epoch 109/30000
#  - 8s - loss: 0.1555 - mse: 0.1441 - mae: 0.1555 - val_loss: 0.1881 - val_mse: 0.2012 - val_mae: 0.1881
# Epoch 110/30000
#  - 8s - loss: 0.1529 - mse: 0.1410 - mae: 0.1529 - val_loss: 0.1920 - val_mse: 0.2040 - val_mae: 0.1920
# Epoch 111/30000
#  - 8s - loss: 0.1548 - mse: 0.1445 - mae: 0.1548 - val_loss: 0.1908 - val_mse: 0.2043 - val_mae: 0.1908
# Epoch 112/30000
#  - 8s - loss: 0.1538 - mse: 0.1433 - mae: 0.1538 - val_loss: 0.1880 - val_mse: 0.2052 - val_mae: 0.1880
# Epoch 113/30000
#  - 8s - loss: 0.1528 - mse: 0.1432 - mae: 0.1528 - val_loss: 0.1857 - val_mse: 0.2017 - val_mae: 0.1857
# Epoch 114/30000
#  - 8s - loss: 0.1522 - mse: 0.1405 - mae: 0.1522 - val_loss: 0.1898 - val_mse: 0.2059 - val_mae: 0.1898
# Epoch 115/30000
#  - 8s - loss: 0.1515 - mse: 0.1395 - mae: 0.1515 - val_loss: 0.1869 - val_mse: 0.2044 - val_mae: 0.1869
# Epoch 116/30000
#  - 8s - loss: 0.1512 - mse: 0.1359 - mae: 0.1512 - val_loss: 0.1893 - val_mse: 0.2079 - val_mae: 0.1893
# Epoch 117/30000
#  - 8s - loss: 0.1503 - mse: 0.1372 - mae: 0.1503 - val_loss: 0.1878 - val_mse: 0.1985 - val_mae: 0.1878
# Epoch 118/30000
#  - 8s - loss: 0.1514 - mse: 0.1385 - mae: 0.1514 - val_loss: 0.1878 - val_mse: 0.2034 - val_mae: 0.1878
# Epoch 119/30000
#  - 8s - loss: 0.1503 - mse: 0.1356 - mae: 0.1503 - val_loss: 0.1870 - val_mse: 0.1991 - val_mae: 0.1870
# Epoch 120/30000
#  - 8s - loss: 0.1503 - mse: 0.1345 - mae: 0.1503 - val_loss: 0.1864 - val_mse: 0.2038 - val_mae: 0.1864
# Epoch 121/30000
#  - 8s - loss: 0.1501 - mse: 0.1353 - mae: 0.1501 - val_loss: 0.1882 - val_mse: 0.2039 - val_mae: 0.1882
# Epoch 122/30000
#  - 8s - loss: 0.1493 - mse: 0.1341 - mae: 0.1493 - val_loss: 0.1875 - val_mse: 0.2089 - val_mae: 0.1875
# Epoch 123/30000
#  - 8s - loss: 0.1496 - mse: 0.1353 - mae: 0.1496 - val_loss: 0.1882 - val_mse: 0.2050 - val_mae: 0.1882
# Epoch 124/30000
#  - 8s - loss: 0.1481 - mse: 0.1322 - mae: 0.1481 - val_loss: 0.1920 - val_mse: 0.2157 - val_mae: 0.1920
# Epoch 125/30000
#  - 8s - loss: 0.1486 - mse: 0.1326 - mae: 0.1486 - val_loss: 0.1864 - val_mse: 0.2008 - val_mae: 0.1864
# Epoch 126/30000
#  - 8s - loss: 0.1489 - mse: 0.1328 - mae: 0.1489 - val_loss: 0.1862 - val_mse: 0.2008 - val_mae: 0.1862
# Epoch 127/30000
#  - 8s - loss: 0.1472 - mse: 0.1309 - mae: 0.1472 - val_loss: 0.1853 - val_mse: 0.2010 - val_mae: 0.1853
# Epoch 128/30000
#  - 8s - loss: 0.1471 - mse: 0.1323 - mae: 0.1471 - val_loss: 0.1869 - val_mse: 0.1998 - val_mae: 0.1869
# Epoch 129/30000
#  - 8s - loss: 0.1469 - mse: 0.1301 - mae: 0.1469 - val_loss: 0.1852 - val_mse: 0.1993 - val_mae: 0.1852
# Epoch 130/30000
#  - 8s - loss: 0.1464 - mse: 0.1300 - mae: 0.1464 - val_loss: 0.1837 - val_mse: 0.1980 - val_mae: 0.1837
# Epoch 131/30000
#  - 8s - loss: 0.1451 - mse: 0.1286 - mae: 0.1451 - val_loss: 0.1851 - val_mse: 0.2014 - val_mae: 0.1851
# Epoch 132/30000
#  - 8s - loss: 0.1455 - mse: 0.1281 - mae: 0.1455 - val_loss: 0.1855 - val_mse: 0.1990 - val_mae: 0.1855
# Epoch 133/30000
#  - 8s - loss: 0.1450 - mse: 0.1278 - mae: 0.1450 - val_loss: 0.1864 - val_mse: 0.2044 - val_mae: 0.1864
# Epoch 134/30000
#  - 8s - loss: 0.1449 - mse: 0.1269 - mae: 0.1449 - val_loss: 0.1870 - val_mse: 0.2075 - val_mae: 0.1870
# Epoch 135/30000
#  - 8s - loss: 0.1457 - mse: 0.1278 - mae: 0.1457 - val_loss: 0.1844 - val_mse: 0.1989 - val_mae: 0.1844
# Epoch 136/30000
#  - 8s - loss: 0.1436 - mse: 0.1255 - mae: 0.1436 - val_loss: 0.1865 - val_mse: 0.2052 - val_mae: 0.1865
# Epoch 137/30000
#  - 8s - loss: 0.1442 - mse: 0.1256 - mae: 0.1442 - val_loss: 0.1846 - val_mse: 0.2035 - val_mae: 0.1846
# Epoch 138/30000
#  - 8s - loss: 0.1432 - mse: 0.1257 - mae: 0.1432 - val_loss: 0.1840 - val_mse: 0.1976 - val_mae: 0.1840
# Epoch 139/30000
#  - 8s - loss: 0.1435 - mse: 0.1258 - mae: 0.1435 - val_loss: 0.1810 - val_mse: 0.1924 - val_mae: 0.1810
# Epoch 140/30000
#  - 8s - loss: 0.1419 - mse: 0.1222 - mae: 0.1419 - val_loss: 0.1835 - val_mse: 0.1966 - val_mae: 0.1835
# Epoch 141/30000
#  - 8s - loss: 0.1429 - mse: 0.1227 - mae: 0.1429 - val_loss: 0.1816 - val_mse: 0.1973 - val_mae: 0.1816
# Epoch 142/30000
#  - 8s - loss: 0.1421 - mse: 0.1215 - mae: 0.1421 - val_loss: 0.1836 - val_mse: 0.1972 - val_mae: 0.1836
# Epoch 143/30000
#  - 8s - loss: 0.1424 - mse: 0.1231 - mae: 0.1424 - val_loss: 0.1864 - val_mse: 0.2002 - val_mae: 0.1864
# Epoch 144/30000
#  - 8s - loss: 0.1421 - mse: 0.1214 - mae: 0.1421 - val_loss: 0.1852 - val_mse: 0.2010 - val_mae: 0.1852
# Epoch 145/30000
#  - 8s - loss: 0.1408 - mse: 0.1212 - mae: 0.1408 - val_loss: 0.1848 - val_mse: 0.2001 - val_mae: 0.1848
# Epoch 146/30000
#  - 8s - loss: 0.1412 - mse: 0.1210 - mae: 0.1412 - val_loss: 0.1837 - val_mse: 0.2046 - val_mae: 0.1837
# Epoch 147/30000
#  - 8s - loss: 0.1406 - mse: 0.1200 - mae: 0.1406 - val_loss: 0.1860 - val_mse: 0.2016 - val_mae: 0.1860
# Epoch 148/30000
#  - 8s - loss: 0.1407 - mse: 0.1200 - mae: 0.1407 - val_loss: 0.1841 - val_mse: 0.2016 - val_mae: 0.1841
# Epoch 149/30000
#  - 8s - loss: 0.1406 - mse: 0.1193 - mae: 0.1406 - val_loss: 0.1827 - val_mse: 0.1970 - val_mae: 0.1827
# Epoch 150/30000
#  - 8s - loss: 0.1400 - mse: 0.1204 - mae: 0.1400 - val_loss: 0.1826 - val_mse: 0.1955 - val_mae: 0.1826
# Epoch 151/30000
#  - 8s - loss: 0.1399 - mse: 0.1193 - mae: 0.1399 - val_loss: 0.1821 - val_mse: 0.1985 - val_mae: 0.1821
# Epoch 152/30000
#  - 8s - loss: 0.1393 - mse: 0.1176 - mae: 0.1393 - val_loss: 0.1842 - val_mse: 0.2014 - val_mae: 0.1842
# Epoch 153/30000
#  - 8s - loss: 0.1386 - mse: 0.1172 - mae: 0.1386 - val_loss: 0.1823 - val_mse: 0.2003 - val_mae: 0.1823
# Epoch 154/30000
#  - 8s - loss: 0.1391 - mse: 0.1207 - mae: 0.1391 - val_loss: 0.1845 - val_mse: 0.2032 - val_mae: 0.1845
# Epoch 155/30000
#  - 8s - loss: 0.1378 - mse: 0.1172 - mae: 0.1378 - val_loss: 0.1825 - val_mse: 0.1947 - val_mae: 0.1825
# Epoch 156/30000
#  - 8s - loss: 0.1387 - mse: 0.1174 - mae: 0.1387 - val_loss: 0.1819 - val_mse: 0.1963 - val_mae: 0.1819
# Epoch 157/30000
#  - 8s - loss: 0.1380 - mse: 0.1167 - mae: 0.1380 - val_loss: 0.1836 - val_mse: 0.1966 - val_mae: 0.1836
# Epoch 158/30000
#  - 8s - loss: 0.1374 - mse: 0.1155 - mae: 0.1374 - val_loss: 0.1830 - val_mse: 0.2027 - val_mae: 0.1830
# Epoch 159/30000
#  - 8s - loss: 0.1365 - mse: 0.1151 - mae: 0.1365 - val_loss: 0.1810 - val_mse: 0.1942 - val_mae: 0.1810
# Epoch 160/30000
#  - 8s - loss: 0.1374 - mse: 0.1147 - mae: 0.1374 - val_loss: 0.1846 - val_mse: 0.2018 - val_mae: 0.1846
# Epoch 161/30000
#  - 8s - loss: 0.1372 - mse: 0.1139 - mae: 0.1372 - val_loss: 0.1812 - val_mse: 0.1948 - val_mae: 0.1812
# Epoch 162/30000
#  - 8s - loss: 0.1367 - mse: 0.1154 - mae: 0.1367 - val_loss: 0.1807 - val_mse: 0.1936 - val_mae: 0.1807
# Epoch 163/30000
#  - 8s - loss: 0.1354 - mse: 0.1128 - mae: 0.1354 - val_loss: 0.1806 - val_mse: 0.1916 - val_mae: 0.1806
# Epoch 164/30000
#  - 8s - loss: 0.1353 - mse: 0.1125 - mae: 0.1353 - val_loss: 0.1822 - val_mse: 0.1930 - val_mae: 0.1822
# Epoch 165/30000
#  - 8s - loss: 0.1355 - mse: 0.1134 - mae: 0.1355 - val_loss: 0.1819 - val_mse: 0.1925 - val_mae: 0.1819
# Epoch 166/30000
#  - 8s - loss: 0.1355 - mse: 0.1118 - mae: 0.1355 - val_loss: 0.1815 - val_mse: 0.1965 - val_mae: 0.1815
# Epoch 167/30000
#  - 8s - loss: 0.1351 - mse: 0.1115 - mae: 0.1351 - val_loss: 0.1842 - val_mse: 0.2007 - val_mae: 0.1842
# Epoch 168/30000
#  - 8s - loss: 0.1342 - mse: 0.1107 - mae: 0.1342 - val_loss: 0.1824 - val_mse: 0.1954 - val_mae: 0.1824
# Epoch 169/30000
#  - 8s - loss: 0.1341 - mse: 0.1110 - mae: 0.1341 - val_loss: 0.1850 - val_mse: 0.2007 - val_mae: 0.1850
# Epoch 170/30000
#  - 8s - loss: 0.1341 - mse: 0.1131 - mae: 0.1341 - val_loss: 0.1830 - val_mse: 0.1998 - val_mae: 0.1830
# Epoch 171/30000
#  - 8s - loss: 0.1336 - mse: 0.1096 - mae: 0.1336 - val_loss: 0.1834 - val_mse: 0.2009 - val_mae: 0.1834
# Epoch 172/30000
#  - 8s - loss: 0.1344 - mse: 0.1105 - mae: 0.1344 - val_loss: 0.1834 - val_mse: 0.1970 - val_mae: 0.1834
# Epoch 173/30000
#  - 8s - loss: 0.1339 - mse: 0.1108 - mae: 0.1339 - val_loss: 0.1807 - val_mse: 0.1977 - val_mae: 0.1807
# Epoch 174/30000
#  - 8s - loss: 0.1337 - mse: 0.1080 - mae: 0.1337 - val_loss: 0.1817 - val_mse: 0.1997 - val_mae: 0.1817
# Epoch 175/30000
#  - 8s - loss: 0.1346 - mse: 0.1118 - mae: 0.1346 - val_loss: 0.1809 - val_mse: 0.1954 - val_mae: 0.1809
# Epoch 176/30000
#  - 8s - loss: 0.1326 - mse: 0.1088 - mae: 0.1326 - val_loss: 0.1817 - val_mse: 0.1988 - val_mae: 0.1817
# Epoch 177/30000
#  - 8s - loss: 0.1325 - mse: 0.1084 - mae: 0.1325 - val_loss: 0.1812 - val_mse: 0.1962 - val_mae: 0.1812
# Epoch 178/30000
#  - 8s - loss: 0.1325 - mse: 0.1094 - mae: 0.1325 - val_loss: 0.1812 - val_mse: 0.1961 - val_mae: 0.1812
# Epoch 179/30000
#  - 8s - loss: 0.1325 - mse: 0.1081 - mae: 0.1325 - val_loss: 0.1794 - val_mse: 0.2004 - val_mae: 0.1794
# Epoch 180/30000
#  - 8s - loss: 0.1325 - mse: 0.1078 - mae: 0.1325 - val_loss: 0.1800 - val_mse: 0.1947 - val_mae: 0.1800
# Epoch 181/30000
#  - 8s - loss: 0.1325 - mse: 0.1087 - mae: 0.1325 - val_loss: 0.1822 - val_mse: 0.1968 - val_mae: 0.1822
# Epoch 182/30000
#  - 8s - loss: 0.1324 - mse: 0.1086 - mae: 0.1324 - val_loss: 0.1841 - val_mse: 0.1924 - val_mae: 0.1841
# Epoch 183/30000
#  - 8s - loss: 0.1315 - mse: 0.1078 - mae: 0.1315 - val_loss: 0.1798 - val_mse: 0.1961 - val_mae: 0.1798
# Epoch 184/30000
#  - 8s - loss: 0.1312 - mse: 0.1078 - mae: 0.1312 - val_loss: 0.1817 - val_mse: 0.2008 - val_mae: 0.1817
# Epoch 185/30000
#  - 8s - loss: 0.1310 - mse: 0.1063 - mae: 0.1310 - val_loss: 0.1816 - val_mse: 0.1989 - val_mae: 0.1816
# Epoch 186/30000
#  - 8s - loss: 0.1307 - mse: 0.1065 - mae: 0.1307 - val_loss: 0.1791 - val_mse: 0.1918 - val_mae: 0.1791
# Epoch 187/30000
#  - 8s - loss: 0.1310 - mse: 0.1071 - mae: 0.1310 - val_loss: 0.1847 - val_mse: 0.1986 - val_mae: 0.1847
# Epoch 188/30000
#  - 8s - loss: 0.1299 - mse: 0.1047 - mae: 0.1299 - val_loss: 0.1788 - val_mse: 0.1884 - val_mae: 0.1788
# Epoch 189/30000
#  - 8s - loss: 0.1303 - mse: 0.1052 - mae: 0.1303 - val_loss: 0.1845 - val_mse: 0.1997 - val_mae: 0.1845
# Epoch 190/30000
#  - 8s - loss: 0.1303 - mse: 0.1062 - mae: 0.1303 - val_loss: 0.1834 - val_mse: 0.1994 - val_mae: 0.1834
# Epoch 191/30000
#  - 8s - loss: 0.1295 - mse: 0.1047 - mae: 0.1295 - val_loss: 0.1773 - val_mse: 0.1929 - val_mae: 0.1773
# Epoch 192/30000
#  - 8s - loss: 0.1285 - mse: 0.1035 - mae: 0.1285 - val_loss: 0.1812 - val_mse: 0.1996 - val_mae: 0.1812
# Epoch 193/30000
#  - 8s - loss: 0.1296 - mse: 0.1060 - mae: 0.1296 - val_loss: 0.1802 - val_mse: 0.1977 - val_mae: 0.1802
# Epoch 194/30000
#  - 8s - loss: 0.1290 - mse: 0.1047 - mae: 0.1290 - val_loss: 0.1818 - val_mse: 0.1951 - val_mae: 0.1818
# Epoch 195/30000
#  - 8s - loss: 0.1301 - mse: 0.1056 - mae: 0.1301 - val_loss: 0.1790 - val_mse: 0.1852 - val_mae: 0.1790
# Epoch 196/30000
#  - 8s - loss: 0.1288 - mse: 0.1042 - mae: 0.1288 - val_loss: 0.1790 - val_mse: 0.1889 - val_mae: 0.1790
# Epoch 197/30000
#  - 8s - loss: 0.1290 - mse: 0.1050 - mae: 0.1290 - val_loss: 0.1829 - val_mse: 0.1931 - val_mae: 0.1829
# Epoch 198/30000
#  - 8s - loss: 0.1292 - mse: 0.1033 - mae: 0.1292 - val_loss: 0.1828 - val_mse: 0.1968 - val_mae: 0.1828
# Epoch 199/30000
#  - 8s - loss: 0.1278 - mse: 0.1026 - mae: 0.1278 - val_loss: 0.1809 - val_mse: 0.1959 - val_mae: 0.1809
# Epoch 200/30000
#  - 8s - loss: 0.1279 - mse: 0.1029 - mae: 0.1279 - val_loss: 0.1788 - val_mse: 0.1894 - val_mae: 0.1788
# Epoch 201/30000
#  - 8s - loss: 0.1267 - mse: 0.1021 - mae: 0.1267 - val_loss: 0.1785 - val_mse: 0.1882 - val_mae: 0.1785
# Epoch 202/30000
#  - 8s - loss: 0.1283 - mse: 0.1027 - mae: 0.1283 - val_loss: 0.1818 - val_mse: 0.1971 - val_mae: 0.1818
# Epoch 203/30000
#  - 8s - loss: 0.1281 - mse: 0.1033 - mae: 0.1281 - val_loss: 0.1797 - val_mse: 0.1902 - val_mae: 0.1797
# Epoch 204/30000
#  - 8s - loss: 0.1267 - mse: 0.1027 - mae: 0.1267 - val_loss: 0.1805 - val_mse: 0.1931 - val_mae: 0.1805
# Epoch 205/30000
#  - 8s - loss: 0.1275 - mse: 0.1017 - mae: 0.1275 - val_loss: 0.1808 - val_mse: 0.1935 - val_mae: 0.1808
# Epoch 206/30000
#  - 8s - loss: 0.1266 - mse: 0.1015 - mae: 0.1266 - val_loss: 0.1800 - val_mse: 0.2012 - val_mae: 0.1800
# Epoch 207/30000
#  - 8s - loss: 0.1271 - mse: 0.1031 - mae: 0.1271 - val_loss: 0.1822 - val_mse: 0.2016 - val_mae: 0.1822
# Epoch 208/30000
#  - 8s - loss: 0.1266 - mse: 0.1027 - mae: 0.1266 - val_loss: 0.1832 - val_mse: 0.2022 - val_mae: 0.1832
# Epoch 209/30000
#  - 8s - loss: 0.1270 - mse: 0.1018 - mae: 0.1270 - val_loss: 0.1807 - val_mse: 0.1955 - val_mae: 0.1807
# Epoch 210/30000
#  - 8s - loss: 0.1259 - mse: 0.1008 - mae: 0.1259 - val_loss: 0.1792 - val_mse: 0.1963 - val_mae: 0.1792
# Epoch 211/30000
#  - 8s - loss: 0.1250 - mse: 0.0998 - mae: 0.1250 - val_loss: 0.1819 - val_mse: 0.2003 - val_mae: 0.1819
# Epoch 212/30000
#  - 8s - loss: 0.1251 - mse: 0.0993 - mae: 0.1251 - val_loss: 0.1784 - val_mse: 0.1957 - val_mae: 0.1784
# Epoch 213/30000
#  - 8s - loss: 0.1253 - mse: 0.0996 - mae: 0.1253 - val_loss: 0.1791 - val_mse: 0.1929 - val_mae: 0.1791
# Epoch 214/30000
#  - 8s - loss: 0.1252 - mse: 0.1008 - mae: 0.1252 - val_loss: 0.1771 - val_mse: 0.1912 - val_mae: 0.1771
# Epoch 215/30000
#  - 8s - loss: 0.1262 - mse: 0.1015 - mae: 0.1262 - val_loss: 0.1774 - val_mse: 0.1947 - val_mae: 0.1774
# Epoch 216/30000
#  - 8s - loss: 0.1248 - mse: 0.0992 - mae: 0.1248 - val_loss: 0.1783 - val_mse: 0.1924 - val_mae: 0.1783
# Epoch 217/30000
#  - 8s - loss: 0.1248 - mse: 0.0994 - mae: 0.1248 - val_loss: 0.1836 - val_mse: 0.2040 - val_mae: 0.1836
# Epoch 218/30000
#  - 8s - loss: 0.1253 - mse: 0.1000 - mae: 0.1253 - val_loss: 0.1802 - val_mse: 0.1903 - val_mae: 0.1802
# Epoch 219/30000
#  - 8s - loss: 0.1264 - mse: 0.1007 - mae: 0.1264 - val_loss: 0.1791 - val_mse: 0.1935 - val_mae: 0.1791
# Epoch 220/30000
#  - 8s - loss: 0.1255 - mse: 0.1005 - mae: 0.1255 - val_loss: 0.1788 - val_mse: 0.1965 - val_mae: 0.1788
# Epoch 221/30000
#  - 8s - loss: 0.1247 - mse: 0.1001 - mae: 0.1247 - val_loss: 0.1756 - val_mse: 0.1827 - val_mae: 0.1756
# Epoch 222/30000
#  - 8s - loss: 0.1242 - mse: 0.0987 - mae: 0.1242 - val_loss: 0.1771 - val_mse: 0.1928 - val_mae: 0.1771
# Epoch 223/30000
#  - 8s - loss: 0.1246 - mse: 0.0986 - mae: 0.1246 - val_loss: 0.1778 - val_mse: 0.1878 - val_mae: 0.1778
# Epoch 224/30000
#  - 8s - loss: 0.1228 - mse: 0.0972 - mae: 0.1228 - val_loss: 0.1798 - val_mse: 0.1924 - val_mae: 0.1798
# Epoch 225/30000
#  - 8s - loss: 0.1241 - mse: 0.0993 - mae: 0.1241 - val_loss: 0.1775 - val_mse: 0.1913 - val_mae: 0.1775
# Epoch 226/30000
#  - 8s - loss: 0.1237 - mse: 0.0969 - mae: 0.1237 - val_loss: 0.1777 - val_mse: 0.1908 - val_mae: 0.1777
# Epoch 227/30000
#  - 8s - loss: 0.1221 - mse: 0.0981 - mae: 0.1221 - val_loss: 0.1772 - val_mse: 0.1898 - val_mae: 0.1772
# Epoch 228/30000
#  - 8s - loss: 0.1234 - mse: 0.0976 - mae: 0.1234 - val_loss: 0.1795 - val_mse: 0.1970 - val_mae: 0.1795
# Epoch 229/30000
#  - 8s - loss: 0.1225 - mse: 0.0975 - mae: 0.1225 - val_loss: 0.1793 - val_mse: 0.1913 - val_mae: 0.1793
# Epoch 230/30000
#  - 8s - loss: 0.1222 - mse: 0.0965 - mae: 0.1222 - val_loss: 0.1789 - val_mse: 0.1884 - val_mae: 0.1789
# Epoch 231/30000
#  - 8s - loss: 0.1236 - mse: 0.0975 - mae: 0.1236 - val_loss: 0.1793 - val_mse: 0.1889 - val_mae: 0.1793
# Epoch 232/30000
#  - 8s - loss: 0.1228 - mse: 0.0958 - mae: 0.1228 - val_loss: 0.1760 - val_mse: 0.1888 - val_mae: 0.1760
# Epoch 233/30000
#  - 8s - loss: 0.1226 - mse: 0.0967 - mae: 0.1226 - val_loss: 0.1779 - val_mse: 0.1885 - val_mae: 0.1779
# Epoch 234/30000
#  - 8s - loss: 0.1222 - mse: 0.0967 - mae: 0.1222 - val_loss: 0.1784 - val_mse: 0.1944 - val_mae: 0.1784
# Epoch 235/30000
#  - 8s - loss: 0.1229 - mse: 0.0973 - mae: 0.1229 - val_loss: 0.1771 - val_mse: 0.1936 - val_mae: 0.1771
# Epoch 236/30000
#  - 8s - loss: 0.1221 - mse: 0.0973 - mae: 0.1221 - val_loss: 0.1777 - val_mse: 0.1910 - val_mae: 0.1777
# Epoch 237/30000
#  - 8s - loss: 0.1226 - mse: 0.0961 - mae: 0.1226 - val_loss: 0.1760 - val_mse: 0.1905 - val_mae: 0.1760
# Epoch 238/30000
#  - 8s - loss: 0.1236 - mse: 0.0985 - mae: 0.1236 - val_loss: 0.1800 - val_mse: 0.1913 - val_mae: 0.1800
# Epoch 239/30000
#  - 8s - loss: 0.1219 - mse: 0.0951 - mae: 0.1219 - val_loss: 0.1766 - val_mse: 0.1917 - val_mae: 0.1766
# Epoch 240/30000
#  - 8s - loss: 0.1213 - mse: 0.0950 - mae: 0.1213 - val_loss: 0.1772 - val_mse: 0.1936 - val_mae: 0.1772
# Epoch 241/30000
#  - 8s - loss: 0.1216 - mse: 0.0960 - mae: 0.1216 - val_loss: 0.1752 - val_mse: 0.1868 - val_mae: 0.1752
# Epoch 242/30000
#  - 8s - loss: 0.1214 - mse: 0.0953 - mae: 0.1214 - val_loss: 0.1785 - val_mse: 0.1881 - val_mae: 0.1785
# Epoch 243/30000
#  - 8s - loss: 0.1217 - mse: 0.0945 - mae: 0.1217 - val_loss: 0.1779 - val_mse: 0.1919 - val_mae: 0.1779
# Epoch 244/30000
#  - 8s - loss: 0.1213 - mse: 0.0947 - mae: 0.1213 - val_loss: 0.1785 - val_mse: 0.1896 - val_mae: 0.1785
# Epoch 245/30000
#  - 8s - loss: 0.1218 - mse: 0.0945 - mae: 0.1218 - val_loss: 0.1794 - val_mse: 0.1942 - val_mae: 0.1794
# Epoch 246/30000
#  - 8s - loss: 0.1206 - mse: 0.0942 - mae: 0.1206 - val_loss: 0.1755 - val_mse: 0.1855 - val_mae: 0.1755
# Epoch 247/30000
#  - 8s - loss: 0.1209 - mse: 0.0944 - mae: 0.1209 - val_loss: 0.1793 - val_mse: 0.1877 - val_mae: 0.1793
# Epoch 248/30000
#  - 8s - loss: 0.1195 - mse: 0.0930 - mae: 0.1195 - val_loss: 0.1783 - val_mse: 0.1901 - val_mae: 0.1783
# Epoch 249/30000
#  - 8s - loss: 0.1205 - mse: 0.0934 - mae: 0.1205 - val_loss: 0.1819 - val_mse: 0.1913 - val_mae: 0.1819
# Epoch 250/30000
#  - 8s - loss: 0.1206 - mse: 0.0923 - mae: 0.1206 - val_loss: 0.1794 - val_mse: 0.1907 - val_mae: 0.1794
# Epoch 251/30000
#  - 8s - loss: 0.1208 - mse: 0.0924 - mae: 0.1208 - val_loss: 0.1758 - val_mse: 0.1884 - val_mae: 0.1758
# Epoch 252/30000
#  - 8s - loss: 0.1203 - mse: 0.0921 - mae: 0.1203 - val_loss: 0.1800 - val_mse: 0.1861 - val_mae: 0.1800
# Epoch 253/30000
#  - 8s - loss: 0.1200 - mse: 0.0913 - mae: 0.1200 - val_loss: 0.1798 - val_mse: 0.1856 - val_mae: 0.1798
# Epoch 254/30000
#  - 8s - loss: 0.1197 - mse: 0.0928 - mae: 0.1197 - val_loss: 0.1775 - val_mse: 0.1879 - val_mae: 0.1775
# Epoch 255/30000
#  - 8s - loss: 0.1195 - mse: 0.0923 - mae: 0.1195 - val_loss: 0.1761 - val_mse: 0.1817 - val_mae: 0.1761
# Epoch 256/30000
#  - 8s - loss: 0.1194 - mse: 0.0918 - mae: 0.1194 - val_loss: 0.1781 - val_mse: 0.1859 - val_mae: 0.1781
# Epoch 257/30000
#  - 8s - loss: 0.1192 - mse: 0.0902 - mae: 0.1192 - val_loss: 0.1793 - val_mse: 0.1907 - val_mae: 0.1793
# Epoch 258/30000
#  - 8s - loss: 0.1190 - mse: 0.0896 - mae: 0.1190 - val_loss: 0.1789 - val_mse: 0.1890 - val_mae: 0.1789
# Epoch 259/30000
#  - 8s - loss: 0.1194 - mse: 0.0902 - mae: 0.1194 - val_loss: 0.1761 - val_mse: 0.1858 - val_mae: 0.1761
# Epoch 260/30000
#  - 8s - loss: 0.1188 - mse: 0.0904 - mae: 0.1188 - val_loss: 0.1766 - val_mse: 0.1933 - val_mae: 0.1766
# Epoch 261/30000
#  - 8s - loss: 0.1191 - mse: 0.0904 - mae: 0.1191 - val_loss: 0.1772 - val_mse: 0.1847 - val_mae: 0.1772
# Epoch 262/30000
#  - 8s - loss: 0.1196 - mse: 0.0905 - mae: 0.1196 - val_loss: 0.1748 - val_mse: 0.1818 - val_mae: 0.1748
# Epoch 263/30000
#  - 8s - loss: 0.1182 - mse: 0.0883 - mae: 0.1182 - val_loss: 0.1754 - val_mse: 0.1834 - val_mae: 0.1754
# Epoch 264/30000
#  - 8s - loss: 0.1176 - mse: 0.0875 - mae: 0.1176 - val_loss: 0.1766 - val_mse: 0.1850 - val_mae: 0.1766
# Epoch 265/30000
#  - 8s - loss: 0.1180 - mse: 0.0869 - mae: 0.1180 - val_loss: 0.1763 - val_mse: 0.1863 - val_mae: 0.1763
# Epoch 266/30000
#  - 8s - loss: 0.1189 - mse: 0.0904 - mae: 0.1189 - val_loss: 0.1800 - val_mse: 0.1907 - val_mae: 0.1800
# Epoch 267/30000
#  - 8s - loss: 0.1179 - mse: 0.0875 - mae: 0.1179 - val_loss: 0.1756 - val_mse: 0.1865 - val_mae: 0.1756
# Epoch 268/30000
#  - 8s - loss: 0.1175 - mse: 0.0855 - mae: 0.1175 - val_loss: 0.1775 - val_mse: 0.1890 - val_mae: 0.1775
# Epoch 269/30000
#  - 8s - loss: 0.1178 - mse: 0.0874 - mae: 0.1178 - val_loss: 0.1771 - val_mse: 0.1866 - val_mae: 0.1771
# Epoch 270/30000
#  - 8s - loss: 0.1169 - mse: 0.0848 - mae: 0.1169 - val_loss: 0.1782 - val_mse: 0.1964 - val_mae: 0.1782
# Epoch 271/30000
#  - 8s - loss: 0.1175 - mse: 0.0864 - mae: 0.1175 - val_loss: 0.1781 - val_mse: 0.1936 - val_mae: 0.1781
# Epoch 272/30000
#  - 8s - loss: 0.1178 - mse: 0.0851 - mae: 0.1178 - val_loss: 0.1751 - val_mse: 0.1893 - val_mae: 0.1751
# Epoch 273/30000
#  - 8s - loss: 0.1175 - mse: 0.0845 - mae: 0.1175 - val_loss: 0.1777 - val_mse: 0.1847 - val_mae: 0.1777
# Epoch 274/30000
#  - 8s - loss: 0.1176 - mse: 0.0866 - mae: 0.1176 - val_loss: 0.1758 - val_mse: 0.1873 - val_mae: 0.1758
# Epoch 275/30000
#  - 8s - loss: 0.1169 - mse: 0.0855 - mae: 0.1169 - val_loss: 0.1767 - val_mse: 0.1833 - val_mae: 0.1767
# Epoch 276/30000
#  - 8s - loss: 0.1168 - mse: 0.0861 - mae: 0.1168 - val_loss: 0.1772 - val_mse: 0.1874 - val_mae: 0.1772
# Epoch 277/30000
#  - 8s - loss: 0.1161 - mse: 0.0829 - mae: 0.1161 - val_loss: 0.1749 - val_mse: 0.1911 - val_mae: 0.1749
# Epoch 278/30000
#  - 8s - loss: 0.1175 - mse: 0.0855 - mae: 0.1175 - val_loss: 0.1748 - val_mse: 0.1866 - val_mae: 0.1748
# Epoch 279/30000
#  - 8s - loss: 0.1160 - mse: 0.0839 - mae: 0.1160 - val_loss: 0.1771 - val_mse: 0.1930 - val_mae: 0.1771
# Epoch 280/30000
#  - 8s - loss: 0.1167 - mse: 0.0817 - mae: 0.1167 - val_loss: 0.1775 - val_mse: 0.1942 - val_mae: 0.1775
# Epoch 281/30000
#  - 8s - loss: 0.1162 - mse: 0.0846 - mae: 0.1162 - val_loss: 0.1752 - val_mse: 0.1805 - val_mae: 0.1752
# Epoch 282/30000
#  - 8s - loss: 0.1157 - mse: 0.0830 - mae: 0.1157 - val_loss: 0.1742 - val_mse: 0.1821 - val_mae: 0.1742
# Epoch 283/30000
#  - 8s - loss: 0.1152 - mse: 0.0810 - mae: 0.1152 - val_loss: 0.1796 - val_mse: 0.1895 - val_mae: 0.1796
# Epoch 284/30000
#  - 8s - loss: 0.1154 - mse: 0.0819 - mae: 0.1154 - val_loss: 0.1770 - val_mse: 0.1912 - val_mae: 0.1770
# Epoch 285/30000
#  - 8s - loss: 0.1155 - mse: 0.0808 - mae: 0.1155 - val_loss: 0.1771 - val_mse: 0.1864 - val_mae: 0.1771
# Epoch 286/30000
#  - 8s - loss: 0.1152 - mse: 0.0815 - mae: 0.1152 - val_loss: 0.1772 - val_mse: 0.1883 - val_mae: 0.1772
# Epoch 287/30000
#  - 8s - loss: 0.1151 - mse: 0.0813 - mae: 0.1151 - val_loss: 0.1780 - val_mse: 0.1901 - val_mae: 0.1780
# Epoch 288/30000
#  - 8s - loss: 0.1148 - mse: 0.0811 - mae: 0.1148 - val_loss: 0.1791 - val_mse: 0.1962 - val_mae: 0.1791
# Epoch 289/30000
#  - 8s - loss: 0.1145 - mse: 0.0822 - mae: 0.1145 - val_loss: 0.1769 - val_mse: 0.1898 - val_mae: 0.1769
# Epoch 290/30000
#  - 8s - loss: 0.1138 - mse: 0.0806 - mae: 0.1138 - val_loss: 0.1788 - val_mse: 0.1844 - val_mae: 0.1788
# Epoch 291/30000
#  - 8s - loss: 0.1147 - mse: 0.0793 - mae: 0.1147 - val_loss: 0.1781 - val_mse: 0.1898 - val_mae: 0.1781
# Epoch 292/30000
#  - 8s - loss: 0.1149 - mse: 0.0820 - mae: 0.1149 - val_loss: 0.1764 - val_mse: 0.1830 - val_mae: 0.1764
# Epoch 293/30000
#  - 8s - loss: 0.1144 - mse: 0.0786 - mae: 0.1144 - val_loss: 0.1821 - val_mse: 0.1903 - val_mae: 0.1821
# Epoch 294/30000
#  - 8s - loss: 0.1148 - mse: 0.0796 - mae: 0.1148 - val_loss: 0.1769 - val_mse: 0.1863 - val_mae: 0.1769
# Epoch 295/30000
#  - 8s - loss: 0.1149 - mse: 0.0801 - mae: 0.1149 - val_loss: 0.1745 - val_mse: 0.1886 - val_mae: 0.1745
# Epoch 296/30000
#  - 8s - loss: 0.1134 - mse: 0.0776 - mae: 0.1134 - val_loss: 0.1750 - val_mse: 0.1861 - val_mae: 0.1750
# Epoch 297/30000
#  - 8s - loss: 0.1132 - mse: 0.0780 - mae: 0.1132 - val_loss: 0.1763 - val_mse: 0.1889 - val_mae: 0.1763
# Epoch 298/30000
#  - 8s - loss: 0.1135 - mse: 0.0790 - mae: 0.1135 - val_loss: 0.1777 - val_mse: 0.1887 - val_mae: 0.1777
# Epoch 299/30000
#  - 8s - loss: 0.1137 - mse: 0.0803 - mae: 0.1137 - val_loss: 0.1773 - val_mse: 0.1860 - val_mae: 0.1773
# Epoch 300/30000
#  - 8s - loss: 0.1132 - mse: 0.0773 - mae: 0.1132 - val_loss: 0.1782 - val_mse: 0.1905 - val_mae: 0.1782
# Epoch 301/30000
#  - 8s - loss: 0.1140 - mse: 0.0793 - mae: 0.1140 - val_loss: 0.1784 - val_mse: 0.1914 - val_mae: 0.1784
# Epoch 302/30000
#  - 8s - loss: 0.1130 - mse: 0.0752 - mae: 0.1130 - val_loss: 0.1782 - val_mse: 0.1935 - val_mae: 0.1782
# Epoch 303/30000
#  - 8s - loss: 0.1141 - mse: 0.0789 - mae: 0.1141 - val_loss: 0.1777 - val_mse: 0.1872 - val_mae: 0.1777
# Epoch 304/30000
#  - 8s - loss: 0.1131 - mse: 0.0774 - mae: 0.1131 - val_loss: 0.1808 - val_mse: 0.1859 - val_mae: 0.1808
# Epoch 305/30000
#  - 8s - loss: 0.1132 - mse: 0.0796 - mae: 0.1132 - val_loss: 0.1783 - val_mse: 0.1966 - val_mae: 0.1783
# Epoch 306/30000
#  - 8s - loss: 0.1133 - mse: 0.0767 - mae: 0.1133 - val_loss: 0.1787 - val_mse: 0.1863 - val_mae: 0.1787
# Epoch 307/30000
#  - 8s - loss: 0.1134 - mse: 0.0777 - mae: 0.1134 - val_loss: 0.1767 - val_mse: 0.1853 - val_mae: 0.1767
# Epoch 308/30000
#  - 8s - loss: 0.1130 - mse: 0.0774 - mae: 0.1130 - val_loss: 0.1754 - val_mse: 0.1833 - val_mae: 0.1754
# Epoch 309/30000
#  - 8s - loss: 0.1126 - mse: 0.0778 - mae: 0.1126 - val_loss: 0.1784 - val_mse: 0.1866 - val_mae: 0.1784
# Epoch 310/30000
#  - 8s - loss: 0.1130 - mse: 0.0759 - mae: 0.1130 - val_loss: 0.1791 - val_mse: 0.1858 - val_mae: 0.1791
# Epoch 311/30000
#  - 8s - loss: 0.1126 - mse: 0.0763 - mae: 0.1126 - val_loss: 0.1749 - val_mse: 0.1845 - val_mae: 0.1749
# Epoch 312/30000
#  - 8s - loss: 0.1122 - mse: 0.0744 - mae: 0.1122 - val_loss: 0.1770 - val_mse: 0.1986 - val_mae: 0.1770
# Epoch 313/30000
#  - 8s - loss: 0.1122 - mse: 0.0775 - mae: 0.1122 - val_loss: 0.1757 - val_mse: 0.1858 - val_mae: 0.1757
# Epoch 314/30000
#  - 8s - loss: 0.1111 - mse: 0.0740 - mae: 0.1111 - val_loss: 0.1753 - val_mse: 0.1859 - val_mae: 0.1753
# Epoch 315/30000
#  - 8s - loss: 0.1115 - mse: 0.0741 - mae: 0.1115 - val_loss: 0.1777 - val_mse: 0.1963 - val_mae: 0.1777
# Epoch 316/30000
#  - 8s - loss: 0.1121 - mse: 0.0746 - mae: 0.1121 - val_loss: 0.1755 - val_mse: 0.1818 - val_mae: 0.1755
# Epoch 317/30000
#  - 8s - loss: 0.1114 - mse: 0.0748 - mae: 0.1114 - val_loss: 0.1756 - val_mse: 0.1903 - val_mae: 0.1756
# Epoch 318/30000
#  - 8s - loss: 0.1119 - mse: 0.0743 - mae: 0.1119 - val_loss: 0.1767 - val_mse: 0.1906 - val_mae: 0.1767
# Epoch 319/30000
#  - 8s - loss: 0.1123 - mse: 0.0763 - mae: 0.1123 - val_loss: 0.1767 - val_mse: 0.1874 - val_mae: 0.1767
# Epoch 320/30000
#  - 8s - loss: 0.1119 - mse: 0.0752 - mae: 0.1119 - val_loss: 0.1769 - val_mse: 0.1854 - val_mae: 0.1769
# Epoch 321/30000
#  - 8s - loss: 0.1118 - mse: 0.0754 - mae: 0.1118 - val_loss: 0.1790 - val_mse: 0.1884 - val_mae: 0.1790
# Epoch 322/30000
#  - 8s - loss: 0.1110 - mse: 0.0734 - mae: 0.1110 - val_loss: 0.1744 - val_mse: 0.1832 - val_mae: 0.1744
# Epoch 323/30000
#  - 8s - loss: 0.1104 - mse: 0.0725 - mae: 0.1104 - val_loss: 0.1777 - val_mse: 0.1906 - val_mae: 0.1777
# Epoch 324/30000
#  - 8s - loss: 0.1114 - mse: 0.0738 - mae: 0.1114 - val_loss: 0.1768 - val_mse: 0.1908 - val_mae: 0.1768
# Epoch 325/30000
#  - 8s - loss: 0.1116 - mse: 0.0758 - mae: 0.1116 - val_loss: 0.1762 - val_mse: 0.1934 - val_mae: 0.1762
# Epoch 326/30000
#  - 8s - loss: 0.1113 - mse: 0.0731 - mae: 0.1113 - val_loss: 0.1744 - val_mse: 0.1897 - val_mae: 0.1744
# Epoch 327/30000
#  - 8s - loss: 0.1116 - mse: 0.0760 - mae: 0.1116 - val_loss: 0.1767 - val_mse: 0.1892 - val_mae: 0.1767
# Epoch 328/30000
#  - 8s - loss: 0.1103 - mse: 0.0716 - mae: 0.1103 - val_loss: 0.1759 - val_mse: 0.1924 - val_mae: 0.1759
# Epoch 329/30000
#  - 8s - loss: 0.1099 - mse: 0.0716 - mae: 0.1099 - val_loss: 0.1768 - val_mse: 0.1843 - val_mae: 0.1768
# Epoch 330/30000
#  - 8s - loss: 0.1115 - mse: 0.0739 - mae: 0.1115 - val_loss: 0.1792 - val_mse: 0.1915 - val_mae: 0.1792
# Epoch 331/30000
#  - 8s - loss: 0.1108 - mse: 0.0716 - mae: 0.1108 - val_loss: 0.1770 - val_mse: 0.1900 - val_mae: 0.1770
# Epoch 332/30000
#  - 8s - loss: 0.1102 - mse: 0.0711 - mae: 0.1102 - val_loss: 0.1755 - val_mse: 0.1881 - val_mae: 0.1755

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrainz = Trainset
Xtrainz2 = sc_X2.transform(Trainset2)
y_pred = model.predict([Xtrainz,Xtrainz2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.04 degrees
# Root Mean Squared Error is 1.16 degrees
# Mean Absolute Error is 1.16 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
Xtest2 = sc_X2.transform(Testset2)
y_pred = model.predict([Xtest,Xtest2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is 0.03 degrees
# Root Mean Squared Error is 2.51 degrees
# Mean Absolute Error is 2.51 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v15.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,sc_X2,modelhistory], file)
        
    model.save('depthforcemodel_cnn3v15.h5')
