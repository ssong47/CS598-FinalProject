# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MaxAbsScaler, LabelBinarizer, OneHotEncoder
from sklearn.svm import SVR
import random
import cv2
from scipy import stats
import os
import tensorflow as tf


# In[2]:


# Add tensorboard stuff
# %load_ext tensorboard
# import datetime

# !rm -rf ./logs/


# In[3]:


#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow


# # Read Depth Camera

# In[4]:


# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#             gray_frame = frame/np.maximum(np.max(frame),255) keep as int8 for memory savings
            gray_frame = frame
            gray_frame = cv2.resize(gray_frame,                                     (int(frame_width/nw_resize), int(frame_height/nh_resize)),                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data


# In[5]:


def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return


# In[6]:


def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return


# In[7]:


#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)

n_test = (24,30,31,32,33,35,57,58,59,60)
# nw_resize = 2
# nh_resize = 2
nw_resize = 4
nh_resize = 3
xtemp = {}
show_video = 0

subj = ['leo','leo','leo','leo','leo','leo','leo','leo','leo','leo']
        
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    # data_dir = os.path.join('/home/asilador/scratch/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
#     train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    train_dcamera_path = os.path.join(data_dir , 'depth_processed_'+subj[i]+'_test'+str(n_test[i])+'.avi')
    xtemp[i] = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize).astype('uint8')
    


# In[8]:


tlen=0
for x in range(len(xtemp)):
    tlen+= xtemp[x].shape[0]
xrun_cum = 0
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]),dtype='uint8')
for i in range (len(xtemp)):
    xrun_n = len(xtemp[i])
    x_train[xrun_cum:xrun_cum+xrun_n,:,:,:] = xtemp[i][:xrun_n,:,:,:]
    xrun_cum += xrun_n


# In[11]:


print(x_train.shape)
del xtemp


# 

# # read fcss data

# In[12]:



n_test = (24,30,31,32,33,35,57,58,59,60)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','01_10_2021','01_11_2021','01_11_2021','01_11_2021')
subj = ['leo','leo','leo','leo','leo','leo','leo','leo','leo','leo']
subjwgt = [67, 67, 67, 67, 67, 67, 67, 67, 67, 67]
subjht = [174, 174, 174, 174, 174, 174, 174, 174, 174, 174]
xfcss_gt = {}
yrun = 0
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    # data_dir = os.path.join('/home/asilador/scratch/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    fcss_data_dir = os.path.join(data_dir , 'fcss_processed_'+subj[i]+'_' + test_str + '_' + date[i] + '.txt')
    xfcss_gttemp = pd.read_csv(fcss_data_dir)/subjwgt[i]*subjht[i]**2
    xfcss_gt[i]=xfcss_gttemp
#     xfcss_gt[i]['weight'] = subjwgt[i]# hacky but will work for now
#     xfcss_gt[i]['height'] = subjht[i]# hacky but will work for now
    if i==0:
        xfcss_train=xfcss_gttemp
    else:
        xfcss_train = pd.concat([xfcss_train,xfcss_gt[i]],axis=0)
del xfcss_gt


# # Read Output Data
# 

# In[14]:



n_test = (24,30,31,32,33,35,57,58,59,60)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','01_10_2021','01_11_2021','01_11_2021','01_11_2021')
subj = ['leo','leo','leo','leo','leo','leo','leo','leo','leo','leo']
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    # data_dir = os.path.join('/home/asilador/scratch/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    qtm_file_data_dir = os.path.join(data_dir , 'qtm_processed_'+subj[i]+'_test' + str(n_test[i]) + '_' + date[i] + '.txt')
    y_gt[i] = read_output_data(qtm_file_data_dir,theta_interest).values


# In[15]:


tlen=0
for x in range(len(y_gt)):
    tlen+= y_gt[x].shape[0]
yrun_cum = 0
y_train = np.zeros((tlen,1))
for i in range (len(y_gt)):
    yrun_n = len(y_gt[i])
    y_train[yrun_cum:yrun_cum+yrun_n] = y_gt[i][:]
    yrun_cum += yrun_n


# In[16]:


# Saturate output
def saturate(theta, min_val, max_val):
    for i in range(len(theta)):
        if theta[i] < min_val:
            theta[i] = min_val
            continue
        if theta[i] > max_val:
            theta[i] = max_val
            continue
    return theta


def round_of_rating(number):
    """Round a number to the closest half integer.
    >>> round_of_rating(1.3)
    1.5
    >>> round_of_rating(2.6)
    2.5
    >>> round_of_rating(3.0)
    3.0
    >>> round_of_rating(4.1)
    4.0"""

    return np.round(number * 2) / 2


min_val = -40
max_val = 40

y_train = round_of_rating(saturate(y_train, min_val, max_val))

r_int = 0.5
slist = np.arange(min_val,max_val+r_int,r_int)*2 #multiply by 2 to allow labelbinarizer to work
lb = LabelBinarizer()
lb.fit(slist)
ylabels = lb.transform(y_train*2)

# In[17]:


print(x_train.shape)
print(xfcss_train.shape)
print(ylabels.shape)

# In[18]:


nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#


# In[34]:


Trainset = x_train[rannums,:]
Trainset2 = xfcss_train.values[rannums,:]
Testset = x_train[test_set,:]
Testset2 = xfcss_train.values[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# In[20]:


# sc_X2 = StandardScaler()
# sc_y = StandardScaler()

sc_X2 = MaxAbsScaler()
#sc_y = MaxAbsScaler()


# In[21]:


#make validation data available to model.fit
Xtrainz = Trainset
Xtrainz2 = Trainset2
ytrainz = Trainy
X = Xtrainz
X2 = sc_X2.fit_transform(Xtrainz2)
y = lb.transform(ytrainz*2) #scale output by 2 to allow intervals of 0.5


# In[22]:

#make validation data available to model.fit
Xvalid = Testset
Xvalid2 = sc_X2.transform(Testset2)
y_valid = Testy
y_valid = lb.transform(y_valid*2) #scale output by 2 to allow intervals of 0.5



# In[23]:


# clear up some used variables
del Xtrainz
del Xtrainz2
del Trainset
del Trainset2
del Testset
del Testset2

#
from tensorflow.keras import layers
with tf.device('/device:CPU:0'):
#with tf.device('/device:GPU:0'):
    data_augmentation = tf.keras.Sequential([
        layers.experimental.preprocessing.RandomRotation(0.05),
        # randomzoom not available in Campuscluster (tf 2.2.0)
        layers.experimental.preprocessing.RandomZoom(height_factor = (-0.2,0.2),
                                               width_factor = (-0.2,0.2),
                                               fill_mode = 'constant'),
        ],
        name='data_augmentation')

# # Regress using Neural Network

# In[25]:

# Create Neural Netowrk

from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, concatenate, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Add
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute, Flatten
from tensorflow.keras.models import Model
dropout_rate = 0.5

def res_net_block(input_data, filters, conv_size):
    x = Conv2D(filters, conv_size, activation='relu', padding='same')(input_data)
    x = BatchNormalization()(x)
    x = Conv2D(filters, conv_size, activation=None, padding='same')(x)
    x = BatchNormalization()(x)
    x = Add()([x, input_data])
    x = Activation('relu')(x)
    return x

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_start2 = Input(shape=(xfcss_train.shape[1],))
model_resnet = model_start
model_perc = model_start2


model_resnet = Conv2D(filters=32, kernel_size=3, activation='relu')(model_resnet)
model_resnet = Conv2D(64, 3, activation='relu')(model_resnet)
mosel_resnet = MaxPooling2D(3)(model_resnet)
num_res_net_blocks = 34
for i in range(num_res_net_blocks):
    model_resnet = res_net_block(model_resnet, 64, 3)
model_resnet = Conv2D(64, 3, activation='relu')(model_resnet)
model_resnet = GlobalAveragePooling2D()(model_resnet)
model_resnet = Dense(256, activation='relu')(model_resnet)

model_resnet = Dropout(dropout_rate)(model_resnet)


model_perc = Dense(50)(model_perc)
model_perc = BatchNormalization()(model_perc)
model_perc = Activation('relu')(model_perc)


# model_perc = Flatten()(model_perc)
# model_cnn = Activation('relu')(model_cnn)

#model_cnn = Dense(50)(model_cnn)
#model_cnn = BatchNormalization()(model_cnn)
#model_cnn = Activation('relu')(model_cnn)


model_comb = concatenate([model_resnet,model_perc],axis=-1)

#model_comb = Dense(50)(model_comb)
#model_comb = BatchNormalization()(model_comb)
model_comb = Activation('relu')(model_comb)
#model_comb = Dropout(dropout_rate)(model_comb)

output = Dense(y.shape[1])(model_comb)
output = Activation('softmax', name='thetaz_out')(output)
model = Model(inputs=[model_start,model_start2],outputs=output)
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2),
              metrics=['categorical_accuracy'])


# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
# callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50,restore_best_weights=True) #Moving to 1000 patience.


# In[26]:


model.summary()


# In[27]:


print(tf.__version__)


# In[28]:


print(tf.config.list_physical_devices('GPU'))


# In[29]:

#
# from tensorflow.keras import layers
# with tf.device('/device:CPU:0'):
#     data_augmentation = tf.keras.Sequential([
#         layers.experimental.preprocessing.RandomRotation(0.05),
#         # randomzoom not available in Campuscluster (tf 2.2.0)
#         #layers.experimental.preprocessing.RandomZoom(height_factor = (-0.2,0.2),
#                                                #width_factor = (-0.2,0.2),
#                                                #fill_mode = 'constant'),
#         ],
#         name='data_augmentation')
#
# create data generator
def get_generator_cyclic(features1, features2, labels, batch_size=256):
    while True:
        for n in range(int(len(features1)/batch_size)):
            X = features1[n*batch_size: (n+1)*batch_size]
            with tf.device('/device:CPU:0'): #to prevent hogging limited gpu space
                augmented_images = data_augmentation(X)
                Xnew =  tf.cast(augmented_images,tf.float64)/255
            yield [Xnew, features2[n*batch_size: (n+1)*batch_size], labels[n*batch_size: (n+1)*batch_size]]
        permuted = np.random.permutation(len(features1))
        features1 = features1[permuted]
        features2 = features2[permuted]
        labels = labels[permuted]


# In[30]:


def scheduler(epoch, lr):
    if e < 20: #very hacky
        return 0.001
    else:
        if batches==0:
            return lr * 0.90
        else:
            return lr
callback1 = tf.keras.callbacks.LearningRateScheduler(scheduler)
callback2 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50,restore_best_weights=True)

save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v42_pb.pkl"
    randata = {}
    randata['nsamps'] = nsamps
    randata['n80p'] = n80p
    randata['rannums'] = rannums
    randata['test_set'] = test_set
    #     modelhistory = history.history

    with open(pkl_filename, 'wb') as file:
        #         pickle.dump([randata,sc_y,sc_X2,modelhistory], file)
        pickle.dump([randata, lb, sc_X2, slist], file)

#     !mkdir -p saved_model
#     model.save('saved_model/cnn3v22')
# In[31]:

#from datetime import datetime
# Out:
# (115095, 40, 40, 3)
# (115095, 40, 40, 3)
# (115095, 6)
# (115095, 161)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 40, 40, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 38, 38, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 36, 36, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 36, 36, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 36, 36, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 36, 36, 64)   36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 36, 36, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 36, 64)   0           batch_normalization_1[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 36, 36, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 36, 36, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 36, 36, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 36, 36, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 36, 36, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 36, 36, 64)   0           batch_normalization_3[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 36, 36, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 36, 36, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 36, 36, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 36, 36, 64)   36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 36, 36, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 36, 36, 64)   0           batch_normalization_5[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 36, 36, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 36, 36, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 36, 36, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 36, 36, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 36, 36, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 36, 36, 64)   0           batch_normalization_7[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 36, 36, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 36, 36, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 36, 36, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 36, 36, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 36, 36, 64)   0           batch_normalization_9[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 36, 36, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 36, 36, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 36, 36, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 36, 36, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 36, 36, 64)   0           batch_normalization_11[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 36, 36, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 36, 36, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 36, 36, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 36, 36, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 36, 36, 64)   0           batch_normalization_13[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 36, 36, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 36, 36, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 36, 36, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 36, 36, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 36, 36, 64)   0           batch_normalization_15[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 36, 36, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 36, 36, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 36, 36, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 36, 36, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 36, 36, 64)   0           batch_normalization_17[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 36, 36, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 36, 36, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 36, 36, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 36, 36, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 36, 36, 64)   0           batch_normalization_19[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 36, 36, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 36, 36, 64)   36928       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 36, 36, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 36, 36, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 36, 36, 64)   0           batch_normalization_21[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 36, 36, 64)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 36, 36, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 36, 36, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 36, 36, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 36, 36, 64)   0           batch_normalization_23[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 36, 36, 64)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 36, 36, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 36, 36, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 36, 36, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 36, 36, 64)   0           batch_normalization_25[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 36, 36, 64)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 36, 36, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 36, 36, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 36, 36, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 36, 36, 64)   0           batch_normalization_27[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 36, 36, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 36, 36, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 36, 36, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 36, 36, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 36, 36, 64)   0           batch_normalization_29[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 36, 36, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 36, 36, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 36, 36, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 36, 36, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 36, 36, 64)   0           batch_normalization_31[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 36, 36, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 36, 36, 64)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 36, 36, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 36, 36, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 36, 36, 64)   0           batch_normalization_33[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 36, 36, 64)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 36, 36, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 36, 36, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 36, 36, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 36, 36, 64)   0           batch_normalization_35[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 36, 36, 64)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 36, 36, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 36, 36, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 36, 36, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 36, 36, 64)   0           batch_normalization_37[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 36, 36, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 36, 36, 64)   36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 36, 36, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 36, 36, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 36, 36, 64)   0           batch_normalization_39[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 36, 36, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 36, 36, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 36, 36, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 36, 36, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 36, 36, 64)   0           batch_normalization_41[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 36, 36, 64)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 36, 36, 64)   36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 36, 36, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 36, 36, 64)   256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 36, 36, 64)   0           batch_normalization_43[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 36, 36, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 36, 36, 64)   36928       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 36, 36, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 36, 36, 64)   256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 36, 36, 64)   0           batch_normalization_45[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 36, 36, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 36, 36, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 36, 36, 64)   256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 36, 36, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 36, 36, 64)   0           batch_normalization_47[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 36, 36, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 36, 36, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 36, 36, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 36, 36, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 36, 36, 64)   0           batch_normalization_49[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 36, 36, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 36, 36, 64)   36928       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 36, 36, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 36, 36, 64)   256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 36, 36, 64)   0           batch_normalization_51[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 36, 36, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 36, 36, 64)   36928       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 36, 36, 64)   256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 36, 36, 64)   256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 36, 36, 64)   0           batch_normalization_53[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 36, 36, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 36, 36, 64)   36928       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 36, 36, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 36, 36, 64)   256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 36, 36, 64)   0           batch_normalization_55[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 36, 36, 64)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 36, 36, 64)   36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 36, 36, 64)   256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 36, 36, 64)   256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 36, 36, 64)   0           batch_normalization_57[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 36, 36, 64)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 36, 36, 64)   36928       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 36, 36, 64)   256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 36, 36, 64)   256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 36, 36, 64)   0           batch_normalization_59[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 36, 36, 64)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 36, 36, 64)   36928       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 36, 36, 64)   256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 36, 36, 64)   256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 36, 36, 64)   0           batch_normalization_61[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 36, 36, 64)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 36, 36, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 36, 36, 64)   256         conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 36, 36, 64)   256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 36, 36, 64)   0           batch_normalization_63[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 36, 36, 64)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 36, 36, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 36, 36, 64)   256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 36, 36, 64)   256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 36, 36, 64)   0           batch_normalization_65[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 36, 36, 64)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 36, 36, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 36, 36, 64)   256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 36, 36, 64)   36928       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 36, 36, 64)   256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 36, 36, 64)   0           batch_normalization_67[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 36, 36, 64)   0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 34, 34, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           350         input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          16640       global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 50)           200         dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 50)           0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 306)          0           dropout[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 306)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 161)          49427       activation_35[0][0]
# __________________________________________________________________________________________________
# thetaz_out (Activation)         (None, 161)          0           dense_2[0][0]
# ==================================================================================================
# Total params: 2,651,449
# Trainable params: 2,642,645
# Non-trainable params: 8,804
# __________________________________________________________________________________________________
# 2.3.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from datetime import datetime



batch_size = 32
batch_mult = 2
readin = int(batch_size * batch_mult)
epochs = int(30)
training_generator = get_generator_cyclic(X,X2,y,readin)
acc_best = 0
# for e in range(epochs):
#     #Xaug = tf.cast(data_augmentation(X),tf.float64)/255
#     Xaug = data_augmentation(X)
#     model.fit([Xaug, X2], y, epochs=1, callbacks=[callback1, callback2], validation_data = ([Xvalid,Xvalid2], y_valid),batch_size=batch_size, verbose=1)
#     model.save('cnn3v42')
for e in range(epochs):
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S")
    print('Epoch', e,'Time: ', current_time)
    batches = 0
    while batches< len(X)/readin:
        Xtrain_1, Xtrain_2, ytrain_1 = next(training_generator)
        model.fit([Xtrain_1, Xtrain_2], ytrain_1, callbacks=[callback1],batch_size=batch_size, verbose=0)
        batches += 1
        
    losscat, metcat = model.evaluate([Xvalid/255.,Xvalid2], y_valid)
    if metcat>acc_best:
        acc_best=metcat
        model.save('cnn3v42')
        print('Saved new parameters at {:4.4f}'.format(metcat))
# In[32]:
# Out:
# Epoch 0 Time:  00:03:39
# 720/720 [==============================] - 50s 70ms/step - loss: 3.8241 - categorical_accuracy: 0.1361
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1361
# Epoch 1 Time:  00:18:40
# 720/720 [==============================] - 51s 70ms/step - loss: 3.8330 - categorical_accuracy: 0.1353
# Epoch 2 Time:  00:32:54
# 720/720 [==============================] - 51s 70ms/step - loss: 3.7987 - categorical_accuracy: 0.1423
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1423
# Epoch 3 Time:  00:48:01
# 720/720 [==============================] - 51s 70ms/step - loss: 3.8350 - categorical_accuracy: 0.1345
# Epoch 4 Time:  01:02:17
# 720/720 [==============================] - 51s 70ms/step - loss: 3.7940 - categorical_accuracy: 0.1433
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1433
# Epoch 5 Time:  01:17:24
# 720/720 [==============================] - 51s 70ms/step - loss: 3.7957 - categorical_accuracy: 0.1435
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1435
# Epoch 6 Time:  01:32:30
# 720/720 [==============================] - 51s 70ms/step - loss: 3.7865 - categorical_accuracy: 0.1484
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1484
# Epoch 7 Time:  01:47:36
# 720/720 [==============================] - 51s 70ms/step - loss: 3.8374 - categorical_accuracy: 0.13850s - loss: 3.8387 - categorical_ac
# Epoch 8 Time:  02:01:52
# 720/720 [==============================] - 51s 70ms/step - loss: 3.7534 - categorical_accuracy: 0.1570
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1570
# Epoch 9 Time:  02:17:00
# 720/720 [==============================] - 53s 73ms/step - loss: 3.7848 - categorical_accuracy: 0.1451
# Epoch 10 Time:  02:31:24
# 720/720 [==============================] - 53s 73ms/step - loss: 3.7760 - categorical_accuracy: 0.1477
# Epoch 11 Time:  02:45:44
# 720/720 [==============================] - 53s 73ms/step - loss: 3.8097 - categorical_accuracy: 0.1368
# Epoch 12 Time:  03:00:05
# 720/720 [==============================] - 51s 71ms/step - loss: 3.8769 - categorical_accuracy: 0.1257
# Epoch 13 Time:  03:14:25
# 720/720 [==============================] - 51s 71ms/step - loss: 3.7684 - categorical_accuracy: 0.1527
# Epoch 14 Time:  03:28:43
# 720/720 [==============================] - 51s 71ms/step - loss: 3.7586 - categorical_accuracy: 0.1560
# Epoch 15 Time:  03:43:02
# 720/720 [==============================] - 53s 73ms/step - loss: 3.8307 - categorical_accuracy: 0.1404
# Epoch 16 Time:  03:57:28
# 720/720 [==============================] - 53s 73ms/step - loss: 3.7432 - categorical_accuracy: 0.1577
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1577
# Epoch 17 Time:  04:12:40
# 720/720 [==============================] - 53s 73ms/step - loss: 3.7211 - categorical_accuracy: 0.1606
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1606
# Epoch 18 Time:  04:27:49
# 720/720 [==============================] - 53s 73ms/step - loss: 3.7309 - categorical_accuracy: 0.1602
# Epoch 19 Time:  04:42:08
# 720/720 [==============================] - 53s 74ms/step - loss: 3.7133 - categorical_accuracy: 0.1628
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1628
# Epoch 20 Time:  04:57:19
# 720/720 [==============================] - 53s 74ms/step - loss: 3.7252 - categorical_accuracy: 0.1605
# Epoch 21 Time:  05:11:37
# 720/720 [==============================] - 51s 71ms/step - loss: 3.7452 - categorical_accuracy: 0.1642
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1642
# Epoch 22 Time:  05:26:46
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6709 - categorical_accuracy: 0.1751
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1751
# Epoch 23 Time:  05:41:55
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6776 - categorical_accuracy: 0.1728
# Epoch 24 Time:  05:56:11
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6641 - categorical_accuracy: 0.1752
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1752
# Epoch 25 Time:  06:11:20
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6437 - categorical_accuracy: 0.1848
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1848
# Epoch 26 Time:  06:26:28
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6367 - categorical_accuracy: 0.1838
# Epoch 27 Time:  06:40:44
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6428 - categorical_accuracy: 0.18151s - loss: 3.641
# Epoch 28 Time:  06:55:02
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6276 - categorical_accuracy: 0.1873
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1873
# Epoch 29 Time:  07:10:11
# 720/720 [==============================] - 51s 71ms/step - loss: 3.6130 - categorical_accuracy: 0.1903
# INFO:tensorflow:Assets written to: cnn3v42\assets
# Saved new parameters at 0.1903
