# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MaxAbsScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats
import os

# %%
# Add tensorboard stuff
# %load_ext tensorboard
# import datetime

# !rm -rf ./logs/

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#             gray_frame = frame/np.maximum(np.max(frame),255) keep as int8 for memory savings
            gray_frame = frame
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)

n_test = (1,2,24,30,31,32,33,35,1,3)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0

subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
        
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
#     train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    train_dcamera_path = os.path.join(data_dir , 'depth_processed_'+subj[i]+'_test'+str(n_test[i])+'.avi')
    xtemp[i] = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize).astype('uint8')

# %%
tlen=0
for x in range(len(xtemp)):
    tlen+= xtemp[x].shape[0]
xrun_cum = 0
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]),dtype='uint8')
for i in range (len(xtemp)):
    xrun_n = len(xtemp[i])
    x_train[xrun_cum:xrun_cum+xrun_n,:,:,:] = xtemp[i][:xrun_n,:,:,:]
    xrun_cum += xrun_n

# %%
x_train.shape
# Out:
# (153421, 60, 80, 3)

# %%
plt.imshow(x_train[153418])

# %%
print(x_train.shape)
del xtemp
# Out:
# (153421, 60, 80, 3)

# %% [markdown]
# # read fcss data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
subjwgt = [61,61, 67, 67, 67, 67, 67, 67, 70, 70]
subjht = [180, 180, 174, 174, 174, 174, 174, 174, 170, 170]
xfcss_gt = {}
yrun = 0
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    fcss_data_dir = os.path.join(data_dir , 'fcss_processed_'+subj[i]+'_' + test_str + '_' + date[i] + '.txt')
    xfcss_gttemp = pd.read_csv(fcss_data_dir)/subjwgt[i]*subjht[i]**2
    xfcss_gt[i]=xfcss_gttemp
#     xfcss_gt[i]['weight'] = subjwgt[i]# hacky but will work for now
#     xfcss_gt[i]['height'] = subjht[i]# hacky but will work for now
    if i==0:
        xfcss_train=xfcss_gttemp
    else:
        xfcss_train = pd.concat([xfcss_train,xfcss_gt[i]],axis=0)
del xfcss_gt

# %%
xfcss_train
# Out:
#        Fz bottom (kg)  Fz left (kg)  Fz right (kg)  Fx left (kg)  \
# 0       -26833.573770  -6124.131148   -6421.573770   4865.311475
# 1       -26727.344262  -6150.688525   -6490.622951   4865.311475
# 2       -26652.983607  -6193.180328   -6570.295082   4854.688525
# 3       -26605.180328  -6246.295082   -6628.721311   4860.000000
# 4       -26605.180328  -6288.786885   -6687.147541   4854.688525
# ...               ...           ...            ...           ...
# 23050   -20539.642857  -7877.314286   -7183.714286   4751.985714
# 23051   -20552.028571  -7798.871429   -7175.457143   4785.014286
# 23052   -20539.642857  -7695.657143   -7179.585714   4801.528571
# 23053   -20527.257143  -7600.700000   -7191.971429   4830.428571
# 23054   -20531.385714  -7518.128571   -7200.228571   4867.585714
#
#        Fx right (kg)     Fy (kg)
# 0        6352.524590  127.475410
# 1        6315.344262  100.918033
# 2        6294.098361   84.983607
# 3        6315.344262   74.360656
# 4        6368.459016   74.360656
# ...              ...         ...
# 23050    5276.314286  169.271429
# 23051    5164.842857  202.300000
# 23052    5028.600000  222.942857
# 23053    4908.871429  231.200000
# 23054    4793.271429  214.685714
#
# [153421 rows x 6 columns]

# %% [markdown]
# # Read Output Data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    qtm_file_data_dir = os.path.join(data_dir , 'qtm_processed_'+subj[i]+'_test' + str(n_test[i]) + '_' + date[i] + '.txt')
    y_gt[i] = read_output_data(qtm_file_data_dir,theta_interest).values

    

# tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
# y_train = np.zeros((tlen,1))
# xrun = len(y_gt[0])
# y_train[:xrun] = y_gt[0][:xrun]
# xrun1 = xrun + len(y_gt[1])
# y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
# xrun2 = xrun1 + len(y_gt[2])
# y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
# xrun3 = xrun2 + len(y_gt[3])
# y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
# xrun4 = xrun3 + len(y_gt[4])
# y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
# xrun5 = xrun4 + len(y_gt[5])
# y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]
# del y_gt

# %%
tlen=0
for x in range(len(y_gt)):
    tlen+= y_gt[x].shape[0]
yrun_cum = 0
y_train = np.zeros((tlen,1))
for i in range (len(y_gt)):
    yrun_n = len(y_gt[i])
    y_train[yrun_cum:yrun_cum+yrun_n] = y_gt[i][:]
    yrun_cum += yrun_n

# %%
# Saturate output
def saturate(theta, min_val, max_val):
    for i in range(len(theta)):
        if theta[i] < min_val:
            theta[i] = min_val
            continue
        if theta[i] > max_val:
            theta[i] = max_val
            continue
    return theta
            
min_val = -50
max_val = 50
    
y_train = saturate(y_train, min_val, max_val)

# %%
print(x_train.shape)
print(xfcss_train.shape)
print(y_train.shape)
# Out:
# (153421, 60, 80, 3)
# (153421, 6)
# (153421, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Trainset2 = xfcss_train.values[rannums,:]
Testset = x_train[test_set,:]
Testset2 = xfcss_train.values[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
# sc_X2 = StandardScaler()
# sc_y = StandardScaler()

sc_X2 = MaxAbsScaler()
sc_y = MaxAbsScaler()

# %%
Xtrainz = Trainset
Xtrainz2 = Trainset2
ytrainz = Trainy
X = Xtrainz
X2 = sc_X2.fit_transform(Xtrainz2)
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset
Xvalid2 = sc_X2.transform(Testset2)
y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
# clear up some used variables
del Trainset
del Trainset2
del Testset
del Testset2

# %% [markdown]
# # Regress using Neural Network

# %%
x_train.shape
# Out:
# (153421, 60, 80, 3)

# %%
# Create Neural Netowrk

from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, concatenate, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute, Flatten
from tensorflow.keras.models import Model
# dropout_rate = 0.2

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_start2 = Input(shape=(xfcss_train.shape[1],))
model_cnn = model_start
model_perc = model_start2

model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same',use_bias=False)(model_cnn)
model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Flatten()(model_cnn)
# model_perc = Flatten()(model_perc)
# model_cnn = Activation('relu')(model_cnn)

model_cnn = Dense(100)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_comb = concatenate([model_cnn,model_perc],axis=-1)

model_comb = Dense(128)(model_comb)
# model_comb = BatchNormalization()(model_comb)
model_comb = Activation('relu')(model_comb)
# model_comb = Dropout(dropout_rate)(model_comb)

output = Dense(1)(model_comb)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=[model_start,model_start2],outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
# callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50,restore_best_weights=True) #Moving to 1000 patience.

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 80, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 80, 8)    216         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60, 80, 8)    32          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 60, 80, 8)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 60, 80, 8)    576         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 60, 80, 8)    32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 60, 80, 8)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 40, 8)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 30, 40, 16)   1152        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 30, 40, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 40, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 40, 16)   2304        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 40, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 30, 40, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 15, 20, 16)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 15, 20, 32)   4608        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 20, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 15, 20, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 15, 20, 32)   9216        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 20, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 15, 20, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 10, 32)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 10, 64)    18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 10, 64)    256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 10, 64)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 10, 64)    36864       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 10, 64)    256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 10, 64)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 3, 5, 64)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          700         input_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 960)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          96100       flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200)          0           activation_10[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          25728       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            129         activation_11[0][0]
# __________________________________________________________________________________________________
# thetaz_out (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 207,085
# Trainable params: 206,605
# Non-trainable params: 480
# __________________________________________________________________________________________________

# %%
print(tf.__version__)
# Out:
# 2.3.1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras import layers
with tf.device('/device:CPU:0'):
    data_augmentation = tf.keras.Sequential([
        layers.experimental.preprocessing.RandomRotation(0.05),
        layers.experimental.preprocessing.RandomZoom(height_factor = (-0.2,0.2),
                                               width_factor = (-0.2,0.2), 
                                               fill_mode = 'constant'),
        ], 
        name='data_augmentation')

# create data generator
def get_generator_cyclic(features1, features2, labels, batch_size=256):
    while True:
        for n in range(int(len(features1)/batch_size)):
            X = features1[n*batch_size: (n+1)*batch_size]
            with tf.device('/device:CPU:0'): #to prevent hogging limited gpu space
                augmented_images = data_augmentation(X)
                Xnew =  tf.cast(augmented_images,tf.float64)/255
            yield [Xnew, features2[n*batch_size: (n+1)*batch_size], labels[n*batch_size: (n+1)*batch_size]]
        permuted = np.random.permutation(len(features1))
        features1 = features1[permuted]
        features2 = features2[permuted]
        labels = labels[permuted]

# %%
def scheduler(epoch, lr):
    if e%300 < 200: #very hacky
        return 0.001
    else:
        if e%25==0 & batches==0:
            return lr * 0.99
        else:
            return lr
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
from datetime import datetime
batch_size = 128
batch_mult = 4
readin = int(batch_size*batch_mult)
epochs = int(1200)
mae_best = 10000
training_generator = get_generator_cyclic(X,X2,y,readin)
# test_generator = get_generator_cyclic(Xvalid,Xvalid2,y_valid,readin)
for e in range(epochs):
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S")
    print('Epoch', e,'Time: ', current_time)
    batches = 0
    while batches< len(X)/readin:
        Xtrain_1, Xtrain_2, ytrain_1 = next(training_generator)
#         Xtest_1, Xtest_2, ytest_1 =next(test_generator)
#         model.fit([Xtrain_1, Xtrain_2], ytrain_1, callbacks = [callback],validation_data = ([Xtest_1,Xtest_2], ytest_1),batch_size=batch_size,verbose = 0)
        model.fit([Xtrain_1, Xtrain_2], ytrain_1, callbacks = [callback],batch_size=batch_size,verbose = 0)
        batches += 1
    
    #calculates and prints the running validation once per epoch
    losssc, msesc, maesc = model.evaluate([Xvalid/255.,Xvalid2],y_valid,verbose=0)
    mae = sc_y.inverse_transform(np.array(maesc).reshape(1,-1))[0][0]
    if mae<mae_best:
        modelbest = model
        mae_best = mae
    print('Mean absolute error at {:4.0f} is: {:4.2f}'.format(e,mae))
modelbest.save('saved_model/cnn3v27')
# Out:
# Epoch 0 Time:  21:22:42
# Mean absolute error at    0 is: 6.80
# Epoch 1 Time:  21:24:03
# Mean absolute error at    1 is: 5.46
# Epoch 2 Time:  21:25:21
# Mean absolute error at    2 is: 6.93
# Epoch 3 Time:  21:26:38
# Mean absolute error at    3 is: 4.85
# Epoch 4 Time:  21:27:55
# Mean absolute error at    4 is: 5.11
# Epoch 5 Time:  21:29:12
# Mean absolute error at    5 is: 6.34
# Epoch 6 Time:  21:30:28
# Mean absolute error at    6 is: 5.09
# Epoch 7 Time:  21:31:45
# Mean absolute error at    7 is: 4.47
# Epoch 8 Time:  21:33:01
# Mean absolute error at    8 is: 4.17
# Epoch 9 Time:  21:34:18
# Mean absolute error at    9 is: 4.13
# Epoch 10 Time:  21:35:35
# Mean absolute error at   10 is: 4.39
# Epoch 11 Time:  21:36:52
# Mean absolute error at   11 is: 3.84
# Epoch 12 Time:  21:38:09
# Mean absolute error at   12 is: 4.21
# Epoch 13 Time:  21:39:26
# Mean absolute error at   13 is: 4.05
# Epoch 14 Time:  21:40:42
# Mean absolute error at   14 is: 3.92
# Epoch 15 Time:  21:41:59
# Mean absolute error at   15 is: 3.64
# Epoch 16 Time:  21:43:15
# Mean absolute error at   16 is: 3.64
# Epoch 17 Time:  21:44:32
# Mean absolute error at   17 is: 3.71
# Epoch 18 Time:  21:45:48
# Mean absolute error at   18 is: 3.72
# Epoch 19 Time:  21:47:05
# Mean absolute error at   19 is: 3.73
# Epoch 20 Time:  21:48:22
# Mean absolute error at   20 is: 3.64
# Epoch 21 Time:  21:49:38
# Mean absolute error at   21 is: 3.64
# Epoch 22 Time:  21:50:55
# Mean absolute error at   22 is: 3.49
# Epoch 23 Time:  21:52:11
# Mean absolute error at   23 is: 3.81
# Epoch 24 Time:  21:53:28
# Mean absolute error at   24 is: 3.44
# Epoch 25 Time:  21:54:45
# Mean absolute error at   25 is: 3.56
# Epoch 26 Time:  21:56:01
# Mean absolute error at   26 is: 3.52
# Epoch 27 Time:  21:57:18
# Mean absolute error at   27 is: 3.29
# Epoch 28 Time:  21:58:34
# Mean absolute error at   28 is: 3.44
# Epoch 29 Time:  21:59:51
# Mean absolute error at   29 is: 3.35
# Epoch 30 Time:  22:01:08
# Mean absolute error at   30 is: 3.33
# Epoch 31 Time:  22:02:24
# Mean absolute error at   31 is: 3.52
# Epoch 32 Time:  22:03:41
# Mean absolute error at   32 is: 3.37
# Epoch 33 Time:  22:04:58
# Mean absolute error at   33 is: 3.94
# Epoch 34 Time:  22:06:14
# Mean absolute error at   34 is: 3.17
# Epoch 35 Time:  22:07:31
# Mean absolute error at   35 is: 3.16
# Epoch 36 Time:  22:08:48
# Mean absolute error at   36 is: 3.17
# Epoch 37 Time:  22:10:05
# Mean absolute error at   37 is: 3.24
# Epoch 38 Time:  22:11:21
# Mean absolute error at   38 is: 3.15
# Epoch 39 Time:  22:12:38
# Mean absolute error at   39 is: 3.25
# Epoch 40 Time:  22:13:55
# Mean absolute error at   40 is: 3.01
# Epoch 41 Time:  22:15:11
# Mean absolute error at   41 is: 3.04
# Epoch 42 Time:  22:16:28
# Mean absolute error at   42 is: 3.03
# Epoch 43 Time:  22:17:45
# Mean absolute error at   43 is: 3.94
# Epoch 44 Time:  22:19:01
# Mean absolute error at   44 is: 3.16
# Epoch 45 Time:  22:20:18
# Mean absolute error at   45 is: 2.97
# Epoch 46 Time:  22:21:35
# Mean absolute error at   46 is: 3.01
# Epoch 47 Time:  22:22:51
# Mean absolute error at   47 is: 3.05
# Epoch 48 Time:  22:24:08
# Mean absolute error at   48 is: 2.95
# Epoch 49 Time:  22:25:25
# Mean absolute error at   49 is: 2.94
# Epoch 50 Time:  22:26:41
# Mean absolute error at   50 is: 2.92
# Epoch 51 Time:  22:27:58
# Mean absolute error at   51 is: 2.86
# Epoch 52 Time:  22:29:15
# Mean absolute error at   52 is: 2.94
# Epoch 53 Time:  22:30:31
# Mean absolute error at   53 is: 3.23
# Epoch 54 Time:  22:31:48
# Mean absolute error at   54 is: 2.85
# Epoch 55 Time:  22:33:04
# Mean absolute error at   55 is: 2.93
# Epoch 56 Time:  22:34:21
# Mean absolute error at   56 is: 2.84
# Epoch 57 Time:  22:35:38
# Mean absolute error at   57 is: 2.79
# Epoch 58 Time:  22:37:22
# Mean absolute error at   58 is: 2.76
# Epoch 59 Time:  22:38:38
# Mean absolute error at   59 is: 2.91
# Epoch 60 Time:  22:39:55
# Mean absolute error at   60 is: 2.99
# Epoch 61 Time:  22:41:11
# Mean absolute error at   61 is: 2.89
# Epoch 62 Time:  22:42:30
# Mean absolute error at   62 is: 2.82
# Epoch 63 Time:  22:43:47
# Mean absolute error at   63 is: 2.90
# Epoch 64 Time:  22:45:04
# Mean absolute error at   64 is: 2.83
# Epoch 65 Time:  22:46:20
# Mean absolute error at   65 is: 2.84
# Epoch 66 Time:  22:47:37
# Mean absolute error at   66 is: 2.96
# Epoch 67 Time:  22:48:54
# Mean absolute error at   67 is: 2.77
# Epoch 68 Time:  22:50:11
# Mean absolute error at   68 is: 2.90
# Epoch 69 Time:  22:51:27
# Mean absolute error at   69 is: 2.79
# Epoch 70 Time:  22:52:44
# Mean absolute error at   70 is: 2.90
# Epoch 71 Time:  22:54:00
# Mean absolute error at   71 is: 2.80
# Epoch 72 Time:  22:55:17
# Mean absolute error at   72 is: 2.71
# Epoch 73 Time:  22:56:34
# Mean absolute error at   73 is: 2.73
# Epoch 74 Time:  22:57:50
# Mean absolute error at   74 is: 3.26
# Epoch 75 Time:  22:59:07
# Mean absolute error at   75 is: 2.78
# Epoch 76 Time:  23:00:24
# Mean absolute error at   76 is: 2.69
# Epoch 77 Time:  23:01:40
# Mean absolute error at   77 is: 2.65
# Epoch 78 Time:  23:02:57
# Mean absolute error at   78 is: 2.72
# Epoch 79 Time:  23:04:14
# Mean absolute error at   79 is: 2.82
# Epoch 80 Time:  23:05:30
# Mean absolute error at   80 is: 2.73
# Epoch 81 Time:  23:06:47
# Mean absolute error at   81 is: 2.67
# Epoch 82 Time:  23:08:03
# Mean absolute error at   82 is: 2.64
# Epoch 83 Time:  23:09:20
# Mean absolute error at   83 is: 2.60
# Epoch 84 Time:  23:10:36
# Mean absolute error at   84 is: 2.71
# Epoch 85 Time:  23:11:53
# Mean absolute error at   85 is: 2.64
# Epoch 86 Time:  23:13:10
# Mean absolute error at   86 is: 2.68
# Epoch 87 Time:  23:14:26
# Mean absolute error at   87 is: 2.71
# Epoch 88 Time:  23:15:43
# Mean absolute error at   88 is: 2.64
# Epoch 89 Time:  23:16:59
# Mean absolute error at   89 is: 2.58
# Epoch 90 Time:  23:18:15
# Mean absolute error at   90 is: 2.65
# Epoch 91 Time:  23:19:32
# Mean absolute error at   91 is: 2.64
# Epoch 92 Time:  23:20:49
# Mean absolute error at   92 is: 2.63
# Epoch 93 Time:  23:22:05
# Mean absolute error at   93 is: 2.60
# Epoch 94 Time:  23:23:21
# Mean absolute error at   94 is: 2.64
# Epoch 95 Time:  23:24:38
# Mean absolute error at   95 is: 2.75
# Epoch 96 Time:  23:25:55
# Mean absolute error at   96 is: 2.69
# Epoch 97 Time:  23:27:11
# Mean absolute error at   97 is: 2.60
# Epoch 98 Time:  23:28:28
# Mean absolute error at   98 is: 2.61
# Epoch 99 Time:  23:29:45
# Mean absolute error at   99 is: 2.51
# Epoch 100 Time:  23:31:01
# Mean absolute error at  100 is: 2.64
# Epoch 101 Time:  23:32:18
# Mean absolute error at  101 is: 2.60
# Epoch 102 Time:  23:33:34
# Mean absolute error at  102 is: 2.60
# Epoch 103 Time:  23:34:51
# Mean absolute error at  103 is: 2.75
# Epoch 104 Time:  23:36:07
# Mean absolute error at  104 is: 2.61
# Epoch 105 Time:  23:37:24
# Mean absolute error at  105 is: 2.51
# Epoch 106 Time:  23:38:40
# Mean absolute error at  106 is: 2.53
# Epoch 107 Time:  23:39:57
# Mean absolute error at  107 is: 2.51
# Epoch 108 Time:  23:41:13
# Mean absolute error at  108 is: 2.47
# Epoch 109 Time:  23:42:30
# Mean absolute error at  109 is: 2.48
# Epoch 110 Time:  23:43:46
# Mean absolute error at  110 is: 2.56
# Epoch 111 Time:  23:45:03
# Mean absolute error at  111 is: 2.48
# Epoch 112 Time:  23:46:20
# Mean absolute error at  112 is: 2.54
# Epoch 113 Time:  23:47:36
# Mean absolute error at  113 is: 2.66
# Epoch 114 Time:  23:48:53
# Mean absolute error at  114 is: 2.54
# Epoch 115 Time:  23:50:09
# Mean absolute error at  115 is: 2.48
# Epoch 116 Time:  23:51:25
# Mean absolute error at  116 is: 2.45
# Epoch 117 Time:  23:52:42
# Mean absolute error at  117 is: 2.53
# Epoch 118 Time:  23:53:59
# Mean absolute error at  118 is: 2.49
# Epoch 119 Time:  23:55:15
# Mean absolute error at  119 is: 2.46
# Epoch 120 Time:  23:56:32
# Mean absolute error at  120 is: 2.50
# Epoch 121 Time:  23:57:48
# Mean absolute error at  121 is: 2.45
# Epoch 122 Time:  23:59:05
# Mean absolute error at  122 is: 2.47
# Epoch 123 Time:  00:00:21
# Mean absolute error at  123 is: 2.43
# Epoch 124 Time:  00:01:39
# Mean absolute error at  124 is: 2.61
# Epoch 125 Time:  00:02:55
# Mean absolute error at  125 is: 2.57
# Epoch 126 Time:  00:04:11
# Mean absolute error at  126 is: 2.41
# Epoch 127 Time:  00:05:28
# Mean absolute error at  127 is: 2.44
# Epoch 128 Time:  00:06:45
# Mean absolute error at  128 is: 2.50
# Epoch 129 Time:  00:08:01
# Mean absolute error at  129 is: 2.52
# Epoch 130 Time:  00:09:18
# Mean absolute error at  130 is: 2.43
# Epoch 131 Time:  00:10:34
# Mean absolute error at  131 is: 2.58
# Epoch 132 Time:  00:11:51
# Mean absolute error at  132 is: 2.45
# Epoch 133 Time:  00:13:07
# Mean absolute error at  133 is: 2.54
# Epoch 134 Time:  00:14:25
# Mean absolute error at  134 is: 2.44
# Epoch 135 Time:  00:15:41
# Mean absolute error at  135 is: 2.47
# Epoch 136 Time:  00:16:57
# Mean absolute error at  136 is: 2.42
# Epoch 137 Time:  00:18:14
# Mean absolute error at  137 is: 2.37
# Epoch 138 Time:  00:19:31
# Mean absolute error at  138 is: 2.42
# Epoch 139 Time:  00:20:47
# Mean absolute error at  139 is: 2.43
# Epoch 140 Time:  00:22:04
# Mean absolute error at  140 is: 2.47
# Epoch 141 Time:  00:23:20
# Mean absolute error at  141 is: 2.45
# Epoch 142 Time:  00:24:37
# Mean absolute error at  142 is: 2.43
# Epoch 143 Time:  00:25:53
# Mean absolute error at  143 is: 2.38
# Epoch 144 Time:  00:27:10
# Mean absolute error at  144 is: 2.58
# Epoch 145 Time:  00:28:26
# Mean absolute error at  145 is: 2.38
# Epoch 146 Time:  00:29:43
# Mean absolute error at  146 is: 2.41
# Epoch 147 Time:  00:31:00
# Mean absolute error at  147 is: 2.38
# Epoch 148 Time:  00:32:17
# Mean absolute error at  148 is: 2.34
# Epoch 149 Time:  00:33:33
# Mean absolute error at  149 is: 2.37
# Epoch 150 Time:  00:34:50
# Mean absolute error at  150 is: 2.46
# Epoch 151 Time:  00:36:06
# Mean absolute error at  151 is: 2.43
# Epoch 152 Time:  00:37:23
# Mean absolute error at  152 is: 2.45
# Epoch 153 Time:  00:38:39
# Mean absolute error at  153 is: 2.50
# Epoch 154 Time:  00:39:56
# Mean absolute error at  154 is: 2.47
# Epoch 155 Time:  00:41:12
# Mean absolute error at  155 is: 2.32
# Epoch 156 Time:  00:42:29
# Mean absolute error at  156 is: 2.37
# Epoch 157 Time:  00:43:46
# Mean absolute error at  157 is: 2.42
# Epoch 158 Time:  00:45:02
# Mean absolute error at  158 is: 2.31
# Epoch 159 Time:  00:46:19
# Mean absolute error at  159 is: 2.29
# Epoch 160 Time:  00:47:35
# Mean absolute error at  160 is: 2.43
# Epoch 161 Time:  00:48:52
# Mean absolute error at  161 is: 2.32
# Epoch 162 Time:  00:50:08
# Mean absolute error at  162 is: 2.35
# Epoch 163 Time:  00:51:25
# Mean absolute error at  163 is: 2.32
# Epoch 164 Time:  00:52:41
# Mean absolute error at  164 is: 2.37
# Epoch 165 Time:  00:53:57
# Mean absolute error at  165 is: 2.30
# Epoch 166 Time:  00:55:14
# Mean absolute error at  166 is: 2.35
# Epoch 167 Time:  00:56:31
# Mean absolute error at  167 is: 2.38
# Epoch 168 Time:  00:57:48
# Mean absolute error at  168 is: 2.29
# Epoch 169 Time:  00:59:04
# Mean absolute error at  169 is: 2.45
# Epoch 170 Time:  01:00:21
# Mean absolute error at  170 is: 2.31
# Epoch 171 Time:  01:01:37
# Mean absolute error at  171 is: 2.32
# Epoch 172 Time:  01:02:54
# Mean absolute error at  172 is: 2.38
# Epoch 173 Time:  01:04:10
# Mean absolute error at  173 is: 2.27
# Epoch 174 Time:  01:05:27
# Mean absolute error at  174 is: 2.30
# Epoch 175 Time:  01:06:44
# Mean absolute error at  175 is: 2.31
# Epoch 176 Time:  01:08:00
# Mean absolute error at  176 is: 2.29
# Epoch 177 Time:  01:09:17
# Mean absolute error at  177 is: 2.31
# Epoch 178 Time:  01:10:33
# Mean absolute error at  178 is: 2.37
# Epoch 179 Time:  01:11:50
# Mean absolute error at  179 is: 2.23
# Epoch 180 Time:  01:13:07
# Mean absolute error at  180 is: 2.24
# Epoch 181 Time:  01:14:23
# Mean absolute error at  181 is: 2.27
# Epoch 182 Time:  01:15:40
# Mean absolute error at  182 is: 2.31
# Epoch 183 Time:  01:16:56
# Mean absolute error at  183 is: 2.28
# Epoch 184 Time:  01:18:13
# Mean absolute error at  184 is: 2.38
# Epoch 185 Time:  01:19:29
# Mean absolute error at  185 is: 2.28
# Epoch 186 Time:  01:20:46
# Mean absolute error at  186 is: 2.34
# Epoch 187 Time:  01:22:03
# Mean absolute error at  187 is: 2.43
# Epoch 188 Time:  01:23:19
# Mean absolute error at  188 is: 2.27
# Epoch 189 Time:  01:24:36
# Mean absolute error at  189 is: 2.31
# Epoch 190 Time:  01:25:52
# Mean absolute error at  190 is: 2.29
# Epoch 191 Time:  01:27:09
# Mean absolute error at  191 is: 2.27
# Epoch 192 Time:  01:28:25
# Mean absolute error at  192 is: 2.27
# Epoch 193 Time:  01:29:42
# Mean absolute error at  193 is: 2.36
# Epoch 194 Time:  01:30:59
# Mean absolute error at  194 is: 2.29
# Epoch 195 Time:  01:32:15
# Mean absolute error at  195 is: 2.28
# Epoch 196 Time:  01:33:32
# Mean absolute error at  196 is: 2.27
# Epoch 197 Time:  01:34:49
# Mean absolute error at  197 is: 2.35
# Epoch 198 Time:  01:36:05
# Mean absolute error at  198 is: 2.31
# Epoch 199 Time:  01:37:22
# Mean absolute error at  199 is: 2.25
# Epoch 200 Time:  01:38:38
# Mean absolute error at  200 is: 2.05
# Epoch 201 Time:  01:39:55
# Mean absolute error at  201 is: 2.03
# Epoch 202 Time:  01:41:11
# Mean absolute error at  202 is: 2.03
# Epoch 203 Time:  01:42:28
# Mean absolute error at  203 is: 2.02
# Epoch 204 Time:  01:43:44
# Mean absolute error at  204 is: 2.02
# Epoch 205 Time:  01:45:01
# Mean absolute error at  205 is: 2.02
# Epoch 206 Time:  01:46:18
# Mean absolute error at  206 is: 2.00
# Epoch 207 Time:  01:47:34
# Mean absolute error at  207 is: 2.00
# Epoch 208 Time:  01:48:51
# Mean absolute error at  208 is: 2.01
# Epoch 209 Time:  01:50:08
# Mean absolute error at  209 is: 2.00
# Epoch 210 Time:  01:51:24
# Mean absolute error at  210 is: 2.01
# Epoch 211 Time:  01:52:41
# Mean absolute error at  211 is: 2.01
# Epoch 212 Time:  01:53:57
# Mean absolute error at  212 is: 2.00
# Epoch 213 Time:  01:55:14
# Mean absolute error at  213 is: 2.00
# Epoch 214 Time:  01:56:30
# Mean absolute error at  214 is: 2.01
# Epoch 215 Time:  01:57:47
# Mean absolute error at  215 is: 2.00
# Epoch 216 Time:  01:59:04
# Mean absolute error at  216 is: 2.01
# Epoch 217 Time:  02:00:21
# Mean absolute error at  217 is: 1.99
# Epoch 218 Time:  02:01:37
# Mean absolute error at  218 is: 1.99
# Epoch 219 Time:  02:02:54
# Mean absolute error at  219 is: 2.00
# Epoch 220 Time:  02:04:10
# Mean absolute error at  220 is: 2.00
# Epoch 221 Time:  02:05:26
# Mean absolute error at  221 is: 1.98
# Epoch 222 Time:  02:06:43
# Mean absolute error at  222 is: 2.00
# Epoch 223 Time:  02:08:02
# Mean absolute error at  223 is: 1.99
# Epoch 224 Time:  02:09:19
# Mean absolute error at  224 is: 1.98
# Epoch 225 Time:  02:10:35
# Mean absolute error at  225 is: 1.98
# Epoch 226 Time:  02:11:52
# Mean absolute error at  226 is: 1.98
# Epoch 227 Time:  02:13:08
# Mean absolute error at  227 is: 1.98
# Epoch 228 Time:  02:14:25
# Mean absolute error at  228 is: 1.98
# Epoch 229 Time:  02:15:41
# Mean absolute error at  229 is: 1.98
# Epoch 230 Time:  02:16:58
# Mean absolute error at  230 is: 1.98
# Epoch 231 Time:  02:18:14
# Mean absolute error at  231 is: 1.98
# Epoch 232 Time:  02:19:31
# Mean absolute error at  232 is: 1.98
# Epoch 233 Time:  02:20:47
# Mean absolute error at  233 is: 1.98
# Epoch 234 Time:  02:22:04
# Mean absolute error at  234 is: 1.98
# Epoch 235 Time:  02:23:21
# Mean absolute error at  235 is: 1.98
# Epoch 236 Time:  02:24:37
# Mean absolute error at  236 is: 1.97
# Epoch 237 Time:  02:25:54
# Mean absolute error at  237 is: 1.98
# Epoch 238 Time:  02:27:10
# Mean absolute error at  238 is: 1.98
# Epoch 239 Time:  02:28:27
# Mean absolute error at  239 is: 1.97
# Epoch 240 Time:  02:29:44
# Mean absolute error at  240 is: 1.98
# Epoch 241 Time:  02:31:00
# Mean absolute error at  241 is: 1.98
# Epoch 242 Time:  02:32:17
# Mean absolute error at  242 is: 1.98
# Epoch 243 Time:  02:33:33
# Mean absolute error at  243 is: 1.97
# Epoch 244 Time:  02:34:50
# Mean absolute error at  244 is: 1.97
# Epoch 245 Time:  02:36:06
# Mean absolute error at  245 is: 1.97
# Epoch 246 Time:  02:37:23
# Mean absolute error at  246 is: 1.97
# Epoch 247 Time:  02:38:39
# Mean absolute error at  247 is: 1.97
# Epoch 248 Time:  02:39:56
# Mean absolute error at  248 is: 1.97
# Epoch 249 Time:  02:41:13
# Mean absolute error at  249 is: 1.97
# Epoch 250 Time:  02:42:29
# Mean absolute error at  250 is: 1.97
# Epoch 251 Time:  02:43:46
# Mean absolute error at  251 is: 1.97
# Epoch 252 Time:  02:45:03
# Mean absolute error at  252 is: 1.97
# Epoch 253 Time:  02:46:19
# Mean absolute error at  253 is: 1.97
# Epoch 254 Time:  02:47:36
# Mean absolute error at  254 is: 1.97
# Epoch 255 Time:  02:48:52
# Mean absolute error at  255 is: 1.97
# Epoch 256 Time:  02:50:09
# Mean absolute error at  256 is: 1.97
# Epoch 257 Time:  02:51:25
# Mean absolute error at  257 is: 1.97
# Epoch 258 Time:  02:52:42
# Mean absolute error at  258 is: 1.97
# Epoch 259 Time:  02:53:59
# Mean absolute error at  259 is: 1.97
# Epoch 260 Time:  02:55:15
# Mean absolute error at  260 is: 1.97
# Epoch 261 Time:  02:56:32
# Mean absolute error at  261 is: 1.97
# Epoch 262 Time:  02:57:49
# Mean absolute error at  262 is: 1.97
# Epoch 263 Time:  02:59:05
# Mean absolute error at  263 is: 1.97
# Epoch 264 Time:  03:00:21
# Mean absolute error at  264 is: 1.97
# Epoch 265 Time:  03:01:38
# Mean absolute error at  265 is: 1.97
# Epoch 266 Time:  03:02:55
# Mean absolute error at  266 is: 1.97
# Epoch 267 Time:  03:04:11
# Mean absolute error at  267 is: 1.97
# Epoch 268 Time:  03:05:28
# Mean absolute error at  268 is: 1.97
# Epoch 269 Time:  03:06:44
# Mean absolute error at  269 is: 1.97
# Epoch 270 Time:  03:08:01
# Mean absolute error at  270 is: 1.97
# Epoch 271 Time:  03:09:17
# Mean absolute error at  271 is: 1.97
# Epoch 272 Time:  03:10:34
# Mean absolute error at  272 is: 1.97
# Epoch 273 Time:  03:11:50
# Mean absolute error at  273 is: 1.97
# Epoch 274 Time:  03:13:07
# Mean absolute error at  274 is: 1.97
# Epoch 275 Time:  03:14:23
# Mean absolute error at  275 is: 1.97
# Epoch 276 Time:  03:15:40
# Mean absolute error at  276 is: 1.97
# Epoch 277 Time:  03:16:56
# Mean absolute error at  277 is: 1.97
# Epoch 278 Time:  03:18:13
# Mean absolute error at  278 is: 1.97
# Epoch 279 Time:  03:19:29
# Mean absolute error at  279 is: 1.97
# Epoch 280 Time:  03:20:46
# Mean absolute error at  280 is: 1.97
# Epoch 281 Time:  03:22:02
# Mean absolute error at  281 is: 1.97
# Epoch 282 Time:  03:23:19
# Mean absolute error at  282 is: 1.97
# Epoch 283 Time:  03:24:35
# Mean absolute error at  283 is: 1.97
# Epoch 284 Time:  03:25:57
# Mean absolute error at  284 is: 1.97
# Epoch 285 Time:  03:27:14
# Mean absolute error at  285 is: 1.97
# Epoch 286 Time:  03:28:30
# Mean absolute error at  286 is: 1.97
# Epoch 287 Time:  03:29:47
# Mean absolute error at  287 is: 1.97
# Epoch 288 Time:  03:31:04
# Mean absolute error at  288 is: 1.97
# Epoch 289 Time:  03:32:20
# Mean absolute error at  289 is: 1.97
# Epoch 290 Time:  03:33:37
# Mean absolute error at  290 is: 1.97
# Epoch 291 Time:  03:34:54
# Mean absolute error at  291 is: 1.97
# Epoch 292 Time:  03:36:10
# Mean absolute error at  292 is: 1.97
# Epoch 293 Time:  03:37:27
# Mean absolute error at  293 is: 1.97
# Epoch 294 Time:  03:38:43
# Mean absolute error at  294 is: 1.97
# Epoch 295 Time:  03:40:00
# Mean absolute error at  295 is: 1.97
# Epoch 296 Time:  03:41:17
# Mean absolute error at  296 is: 1.97
# Epoch 297 Time:  03:42:33
# Mean absolute error at  297 is: 1.97
# Epoch 298 Time:  03:43:50
# Mean absolute error at  298 is: 1.97
# Epoch 299 Time:  03:45:06
# Mean absolute error at  299 is: 1.97
# Epoch 300 Time:  03:46:23
# Mean absolute error at  300 is: 2.30
# Epoch 301 Time:  03:47:40
# Mean absolute error at  301 is: 2.21
# Epoch 302 Time:  03:48:56
# Mean absolute error at  302 is: 2.24
# Epoch 303 Time:  03:50:13
# Mean absolute error at  303 is: 2.36
# Epoch 304 Time:  03:51:29
# Mean absolute error at  304 is: 2.27
# Epoch 305 Time:  03:52:46
# Mean absolute error at  305 is: 2.30
# Epoch 306 Time:  03:54:02
# Mean absolute error at  306 is: 2.31
# Epoch 307 Time:  03:55:19
# Mean absolute error at  307 is: 2.18
# Epoch 308 Time:  03:56:36
# Mean absolute error at  308 is: 2.29
# Epoch 309 Time:  03:57:52
# Mean absolute error at  309 is: 2.27
# Epoch 310 Time:  03:59:09
# Mean absolute error at  310 is: 2.26
# Epoch 311 Time:  04:00:26
# Mean absolute error at  311 is: 2.26
# Epoch 312 Time:  04:01:42
# Mean absolute error at  312 is: 2.25
# Epoch 313 Time:  04:02:59
# Mean absolute error at  313 is: 2.21
# Epoch 314 Time:  04:04:15
# Mean absolute error at  314 is: 2.39
# Epoch 315 Time:  04:05:32
# Mean absolute error at  315 is: 2.23
# Epoch 316 Time:  04:06:49
# Mean absolute error at  316 is: 2.20
# Epoch 317 Time:  04:08:05
# Mean absolute error at  317 is: 2.23
# Epoch 318 Time:  04:09:22
# Mean absolute error at  318 is: 2.29
# Epoch 319 Time:  04:10:38
# Mean absolute error at  319 is: 2.21
# Epoch 320 Time:  04:11:55
# Mean absolute error at  320 is: 2.19
# Epoch 321 Time:  04:13:11
# Mean absolute error at  321 is: 2.29
# Epoch 322 Time:  04:14:28
# Mean absolute error at  322 is: 2.30
# Epoch 323 Time:  04:15:44
# Mean absolute error at  323 is: 2.22
# Epoch 324 Time:  04:17:01
# Mean absolute error at  324 is: 2.22
# Epoch 325 Time:  04:18:17
# Mean absolute error at  325 is: 2.22
# Epoch 326 Time:  04:19:34
# Mean absolute error at  326 is: 2.19
# Epoch 327 Time:  04:20:50
# Mean absolute error at  327 is: 2.18
# Epoch 328 Time:  04:22:06
# Mean absolute error at  328 is: 2.20
# Epoch 329 Time:  04:23:23
# Mean absolute error at  329 is: 2.18
# Epoch 330 Time:  04:24:40
# Mean absolute error at  330 is: 2.24
# Epoch 331 Time:  04:25:57
# Mean absolute error at  331 is: 2.23
# Epoch 332 Time:  04:27:13
# Mean absolute error at  332 is: 2.30
# Epoch 333 Time:  04:28:30
# Mean absolute error at  333 is: 2.22
# Epoch 334 Time:  04:29:47
# Mean absolute error at  334 is: 2.18
# Epoch 335 Time:  04:31:03
# Mean absolute error at  335 is: 2.19
# Epoch 336 Time:  04:32:19
# Mean absolute error at  336 is: 2.18
# Epoch 337 Time:  04:33:36
# Mean absolute error at  337 is: 2.34
# Epoch 338 Time:  04:34:52
# Mean absolute error at  338 is: 2.17
# Epoch 339 Time:  04:36:09
# Mean absolute error at  339 is: 2.23
# Epoch 340 Time:  04:37:25
# Mean absolute error at  340 is: 2.25
# Epoch 341 Time:  04:38:42
# Mean absolute error at  341 is: 2.20
# Epoch 342 Time:  04:39:58
# Mean absolute error at  342 is: 2.22
# Epoch 343 Time:  04:41:15
# Mean absolute error at  343 is: 2.22
# Epoch 344 Time:  04:42:32
# Mean absolute error at  344 is: 2.24
# Epoch 345 Time:  04:43:48
# Mean absolute error at  345 is: 2.15
# Epoch 346 Time:  04:45:05
# Mean absolute error at  346 is: 2.18
# Epoch 347 Time:  04:46:21
# Mean absolute error at  347 is: 2.18
# Epoch 348 Time:  04:47:38
# Mean absolute error at  348 is: 2.20
# Epoch 349 Time:  04:48:54
# Mean absolute error at  349 is: 2.27
# Epoch 350 Time:  04:50:11
# Mean absolute error at  350 is: 2.18
# Epoch 351 Time:  04:51:27
# Mean absolute error at  351 is: 2.17
# Epoch 352 Time:  04:52:44
# Mean absolute error at  352 is: 2.26
# Epoch 353 Time:  04:54:01
# Mean absolute error at  353 is: 2.22
# Epoch 354 Time:  04:55:17
# Mean absolute error at  354 is: 2.18
# Epoch 355 Time:  04:56:33
# Mean absolute error at  355 is: 2.18
# Epoch 356 Time:  04:57:50
# Mean absolute error at  356 is: 2.20
# Epoch 357 Time:  04:59:07
# Mean absolute error at  357 is: 2.22
# Epoch 358 Time:  05:00:23
# Mean absolute error at  358 is: 2.14
# Epoch 359 Time:  05:01:40
# Mean absolute error at  359 is: 2.21
# Epoch 360 Time:  05:02:57
# Mean absolute error at  360 is: 2.18
# Epoch 361 Time:  05:04:13
# Mean absolute error at  361 is: 2.15
# Epoch 362 Time:  05:05:29
# Mean absolute error at  362 is: 2.22
# Epoch 363 Time:  05:06:46
# Mean absolute error at  363 is: 2.30
# Epoch 364 Time:  05:08:04
# Mean absolute error at  364 is: 2.26
# Epoch 365 Time:  05:09:20
# Mean absolute error at  365 is: 2.18
# Epoch 366 Time:  05:10:36
# Mean absolute error at  366 is: 2.12
# Epoch 367 Time:  05:11:53
# Mean absolute error at  367 is: 2.19
# Epoch 368 Time:  05:13:09
# Mean absolute error at  368 is: 2.15
# Epoch 369 Time:  05:14:26
# Mean absolute error at  369 is: 2.15
# Epoch 370 Time:  05:15:43
# Mean absolute error at  370 is: 2.14
# Epoch 371 Time:  05:16:59
# Mean absolute error at  371 is: 2.20
# Epoch 372 Time:  05:18:16
# Mean absolute error at  372 is: 2.14
# Epoch 373 Time:  05:19:32
# Mean absolute error at  373 is: 2.21
# Epoch 374 Time:  05:20:49
# Mean absolute error at  374 is: 2.17
# Epoch 375 Time:  05:22:06
# Mean absolute error at  375 is: 2.12
# Epoch 376 Time:  05:23:22
# Mean absolute error at  376 is: 2.13
# Epoch 377 Time:  05:24:38
# Mean absolute error at  377 is: 2.18
# Epoch 378 Time:  05:25:55
# Mean absolute error at  378 is: 2.23
# Epoch 379 Time:  05:27:12
# Mean absolute error at  379 is: 2.11
# Epoch 380 Time:  05:28:28
# Mean absolute error at  380 is: 2.15
# Epoch 381 Time:  05:29:44
# Mean absolute error at  381 is: 2.13
# Epoch 382 Time:  05:31:01
# Mean absolute error at  382 is: 2.14
# Epoch 383 Time:  05:32:18
# Mean absolute error at  383 is: 2.17
# Epoch 384 Time:  05:33:34
# Mean absolute error at  384 is: 2.16
# Epoch 385 Time:  05:34:51
# Mean absolute error at  385 is: 2.25
# Epoch 386 Time:  05:36:08
# Mean absolute error at  386 is: 2.14
# Epoch 387 Time:  05:37:24
# Mean absolute error at  387 is: 2.19
# Epoch 388 Time:  05:38:40
# Mean absolute error at  388 is: 2.14
# Epoch 389 Time:  05:39:57
# Mean absolute error at  389 is: 2.17
# Epoch 390 Time:  05:41:13
# Mean absolute error at  390 is: 2.16
# Epoch 391 Time:  05:42:30
# Mean absolute error at  391 is: 2.14
# Epoch 392 Time:  05:43:47
# Mean absolute error at  392 is: 2.15
# Epoch 393 Time:  05:45:03
# Mean absolute error at  393 is: 2.13
# Epoch 394 Time:  05:46:20
# Mean absolute error at  394 is: 2.13
# Epoch 395 Time:  05:47:36
# Mean absolute error at  395 is: 2.16
# Epoch 396 Time:  05:48:53
# Mean absolute error at  396 is: 2.18
# Epoch 397 Time:  05:50:09
# Mean absolute error at  397 is: 2.24
# Epoch 398 Time:  05:51:26
# Mean absolute error at  398 is: 2.13
# Epoch 399 Time:  05:52:43
# Mean absolute error at  399 is: 2.25
# Epoch 400 Time:  05:53:59
# Mean absolute error at  400 is: 2.18
# Epoch 401 Time:  05:55:16
# Mean absolute error at  401 is: 2.26
# Epoch 402 Time:  05:56:32
# Mean absolute error at  402 is: 2.09
# Epoch 403 Time:  05:57:49
# Mean absolute error at  403 is: 2.10
# Epoch 404 Time:  05:59:05
# Mean absolute error at  404 is: 2.14
# Epoch 405 Time:  06:00:22
# Mean absolute error at  405 is: 2.15
# Epoch 406 Time:  06:01:39
# Mean absolute error at  406 is: 2.22
# Epoch 407 Time:  06:02:55
# Mean absolute error at  407 is: 2.23
# Epoch 408 Time:  06:04:12
# Mean absolute error at  408 is: 2.10
# Epoch 409 Time:  06:05:28
# Mean absolute error at  409 is: 2.10
# Epoch 410 Time:  06:06:44
# Mean absolute error at  410 is: 2.09
# Epoch 411 Time:  06:08:01
# Mean absolute error at  411 is: 2.13
# Epoch 412 Time:  06:09:18
# Mean absolute error at  412 is: 2.15
# Epoch 413 Time:  06:10:34
# Mean absolute error at  413 is: 2.12
# Epoch 414 Time:  06:11:50
# Mean absolute error at  414 is: 2.11
# Epoch 415 Time:  06:13:07
# Mean absolute error at  415 is: 2.17
# Epoch 416 Time:  06:14:24
# Mean absolute error at  416 is: 2.14
# Epoch 417 Time:  06:15:40
# Mean absolute error at  417 is: 2.12
# Epoch 418 Time:  06:16:57
# Mean absolute error at  418 is: 2.17
# Epoch 419 Time:  06:18:13
# Mean absolute error at  419 is: 2.14
# Epoch 420 Time:  06:19:30
# Mean absolute error at  420 is: 2.10
# Epoch 421 Time:  06:20:46
# Mean absolute error at  421 is: 2.13
# Epoch 422 Time:  06:22:03
# Mean absolute error at  422 is: 2.21
# Epoch 423 Time:  06:23:19
# Mean absolute error at  423 is: 2.14
# Epoch 424 Time:  06:24:36
# Mean absolute error at  424 is: 2.33
# Epoch 425 Time:  06:25:52
# Mean absolute error at  425 is: 2.28
# Epoch 426 Time:  06:27:09
# Mean absolute error at  426 is: 2.17
# Epoch 427 Time:  06:28:25
# Mean absolute error at  427 is: 2.18
# Epoch 428 Time:  06:29:42
# Mean absolute error at  428 is: 2.14
# Epoch 429 Time:  06:30:58
# Mean absolute error at  429 is: 2.11
# Epoch 430 Time:  06:32:15
# Mean absolute error at  430 is: 2.12
# Epoch 431 Time:  06:33:31
# Mean absolute error at  431 is: 2.10
# Epoch 432 Time:  06:34:48
# Mean absolute error at  432 is: 2.17
# Epoch 433 Time:  06:36:04
# Mean absolute error at  433 is: 2.16
# Epoch 434 Time:  06:37:21
# Mean absolute error at  434 is: 2.11
# Epoch 435 Time:  06:38:37
# Mean absolute error at  435 is: 2.16
# Epoch 436 Time:  06:39:54
# Mean absolute error at  436 is: 2.23
# Epoch 437 Time:  06:41:10
# Mean absolute error at  437 is: 2.07
# Epoch 438 Time:  06:42:27
# Mean absolute error at  438 is: 2.15
# Epoch 439 Time:  06:43:43
# Mean absolute error at  439 is: 2.08
# Epoch 440 Time:  06:45:00
# Mean absolute error at  440 is: 2.12
# Epoch 441 Time:  06:46:17
# Mean absolute error at  441 is: 2.22
# Epoch 442 Time:  06:47:34
# Mean absolute error at  442 is: 2.14
# Epoch 443 Time:  06:48:50
# Mean absolute error at  443 is: 2.16
# Epoch 444 Time:  06:50:07
# Mean absolute error at  444 is: 2.08
# Epoch 445 Time:  06:51:23
# Mean absolute error at  445 is: 2.20
# Epoch 446 Time:  06:52:40
# Mean absolute error at  446 is: 2.14
# Epoch 447 Time:  06:53:56
# Mean absolute error at  447 is: 2.11
# Epoch 448 Time:  06:55:13
# Mean absolute error at  448 is: 2.06
# Epoch 449 Time:  06:56:29
# Mean absolute error at  449 is: 2.10
# Epoch 450 Time:  06:57:46
# Mean absolute error at  450 is: 2.03
# Epoch 451 Time:  06:59:02
# Mean absolute error at  451 is: 2.09
# Epoch 452 Time:  07:00:19
# Mean absolute error at  452 is: 2.20
# Epoch 453 Time:  07:01:35
# Mean absolute error at  453 is: 2.15
# Epoch 454 Time:  07:02:52
# Mean absolute error at  454 is: 2.10
# Epoch 455 Time:  07:04:09
# Mean absolute error at  455 is: 2.05
# Epoch 456 Time:  07:05:25
# Mean absolute error at  456 is: 2.06
# Epoch 457 Time:  07:06:42
# Mean absolute error at  457 is: 2.05
# Epoch 458 Time:  07:07:58
# Mean absolute error at  458 is: 2.15
# Epoch 459 Time:  07:09:15
# Mean absolute error at  459 is: 2.24
# Epoch 460 Time:  07:10:31
# Mean absolute error at  460 is: 2.08
# Epoch 461 Time:  07:11:48
# Mean absolute error at  461 is: 2.07
# Epoch 462 Time:  07:13:05
# Mean absolute error at  462 is: 2.10
# Epoch 463 Time:  07:14:21
# Mean absolute error at  463 is: 2.07
# Epoch 464 Time:  07:15:37
# Mean absolute error at  464 is: 2.11
# Epoch 465 Time:  07:16:54
# Mean absolute error at  465 is: 2.07
# Epoch 466 Time:  07:18:10
# Mean absolute error at  466 is: 2.05
# Epoch 467 Time:  07:19:27
# Mean absolute error at  467 is: 2.06
# Epoch 468 Time:  07:20:43
# Mean absolute error at  468 is: 2.12
# Epoch 469 Time:  07:22:00
# Mean absolute error at  469 is: 2.04
# Epoch 470 Time:  07:23:16
# Mean absolute error at  470 is: 2.03
# Epoch 471 Time:  07:24:33
# Mean absolute error at  471 is: 2.07
# Epoch 472 Time:  07:25:49
# Mean absolute error at  472 is: 2.00
# Epoch 473 Time:  07:27:06
# Mean absolute error at  473 is: 2.05
# Epoch 474 Time:  07:28:23
# Mean absolute error at  474 is: 2.08
# Epoch 475 Time:  07:29:39
# Mean absolute error at  475 is: 2.12
# Epoch 476 Time:  07:30:56
# Mean absolute error at  476 is: 2.08
# Epoch 477 Time:  07:32:12
# Mean absolute error at  477 is: 2.18
# Epoch 478 Time:  07:33:29
# Mean absolute error at  478 is: 2.04
# Epoch 479 Time:  07:34:46
# Mean absolute error at  479 is: 2.01
# Epoch 480 Time:  07:36:03
# Mean absolute error at  480 is: 2.05
# Epoch 481 Time:  07:37:19
# Mean absolute error at  481 is: 2.06
# Epoch 482 Time:  07:38:36
# Mean absolute error at  482 is: 2.07
# Epoch 483 Time:  07:39:52
# Mean absolute error at  483 is: 2.09
# Epoch 484 Time:  07:41:09
# Mean absolute error at  484 is: 2.06
# Epoch 485 Time:  07:42:25
# Mean absolute error at  485 is: 2.04
# Epoch 486 Time:  07:43:42
# Mean absolute error at  486 is: 2.13
# Epoch 487 Time:  07:44:58
# Mean absolute error at  487 is: 2.11
# Epoch 488 Time:  07:46:14
# Mean absolute error at  488 is: 2.06
# Epoch 489 Time:  07:47:31
# Mean absolute error at  489 is: 2.07
# Epoch 490 Time:  07:48:48
# Mean absolute error at  490 is: 2.05
# Epoch 491 Time:  07:50:04
# Mean absolute error at  491 is: 2.08
# Epoch 492 Time:  07:51:20
# Mean absolute error at  492 is: 2.13
# Epoch 493 Time:  07:52:37
# Mean absolute error at  493 is: 2.09
# Epoch 494 Time:  07:53:54
# Mean absolute error at  494 is: 2.11
# Epoch 495 Time:  07:55:10
# Mean absolute error at  495 is: 2.05
# Epoch 496 Time:  07:56:26
# Mean absolute error at  496 is: 2.13
# Epoch 497 Time:  07:57:43
# Mean absolute error at  497 is: 2.10
# Epoch 498 Time:  07:58:59
# Mean absolute error at  498 is: 2.17
# Epoch 499 Time:  08:00:16
# Mean absolute error at  499 is: 2.09
# Epoch 500 Time:  08:01:33
# Mean absolute error at  500 is: 1.85
# Epoch 501 Time:  08:02:50
# Mean absolute error at  501 is: 1.85
# Epoch 502 Time:  08:04:06
# Mean absolute error at  502 is: 1.84
# Epoch 503 Time:  08:05:23
# Mean absolute error at  503 is: 1.84
# Epoch 504 Time:  08:06:39
# Mean absolute error at  504 is: 1.83
# Epoch 505 Time:  08:07:55
# Mean absolute error at  505 is: 1.82
# Epoch 506 Time:  08:09:12
# Mean absolute error at  506 is: 1.81
# Epoch 507 Time:  08:10:29
# Mean absolute error at  507 is: 1.83
# Epoch 508 Time:  08:11:45
# Mean absolute error at  508 is: 1.83
# Epoch 509 Time:  08:13:21
# Mean absolute error at  509 is: 1.83
# Epoch 510 Time:  08:14:46
# Mean absolute error at  510 is: 1.83
# Epoch 511 Time:  08:16:02
# Mean absolute error at  511 is: 1.83
# Epoch 512 Time:  08:17:19
# Mean absolute error at  512 is: 1.82
# Epoch 513 Time:  08:18:35
# Mean absolute error at  513 is: 1.82
# Epoch 514 Time:  08:19:52
# Mean absolute error at  514 is: 1.83
# Epoch 515 Time:  08:21:08
# Mean absolute error at  515 is: 1.82
# Epoch 516 Time:  08:22:25
# Mean absolute error at  516 is: 1.82
# Epoch 517 Time:  08:23:42
# Mean absolute error at  517 is: 1.81
# Epoch 518 Time:  08:24:58
# Mean absolute error at  518 is: 1.82
# Epoch 519 Time:  08:26:14
# Mean absolute error at  519 is: 1.83
# Epoch 520 Time:  08:27:31
# Mean absolute error at  520 is: 1.83
# Epoch 521 Time:  08:28:47
# Mean absolute error at  521 is: 1.81
# Epoch 522 Time:  08:30:04
# Mean absolute error at  522 is: 1.82
# Epoch 523 Time:  08:31:21
# Mean absolute error at  523 is: 1.82
# Epoch 524 Time:  08:32:37
# Mean absolute error at  524 is: 1.82
# Epoch 525 Time:  08:33:54
# Mean absolute error at  525 is: 1.81
# Epoch 526 Time:  08:35:11
# Mean absolute error at  526 is: 1.81
# Epoch 527 Time:  08:36:27
# Mean absolute error at  527 is: 1.81
# Epoch 528 Time:  08:37:44
# Mean absolute error at  528 is: 1.81
# Epoch 529 Time:  08:39:00
# Mean absolute error at  529 is: 1.81
# Epoch 530 Time:  08:40:17
# Mean absolute error at  530 is: 1.81
# Epoch 531 Time:  08:41:33
# Mean absolute error at  531 is: 1.81
# Epoch 532 Time:  08:42:50
# Mean absolute error at  532 is: 1.81
# Epoch 533 Time:  08:44:06
# Mean absolute error at  533 is: 1.81
# Epoch 534 Time:  08:45:23
# Mean absolute error at  534 is: 1.81
# Epoch 535 Time:  08:46:39
# Mean absolute error at  535 is: 1.81
# Epoch 536 Time:  08:47:56
# Mean absolute error at  536 is: 1.81
# Epoch 537 Time:  08:49:12
# Mean absolute error at  537 is: 1.81
# Epoch 538 Time:  08:50:29
# Mean absolute error at  538 is: 1.81
# Epoch 539 Time:  08:51:45
# Mean absolute error at  539 is: 1.81
# Epoch 540 Time:  08:53:02
# Mean absolute error at  540 is: 1.81
# Epoch 541 Time:  08:54:18
# Mean absolute error at  541 is: 1.81
# Epoch 542 Time:  08:55:35
# Mean absolute error at  542 is: 1.81
# Epoch 543 Time:  08:56:52
# Mean absolute error at  543 is: 1.81
# Epoch 544 Time:  08:58:10
# Mean absolute error at  544 is: 1.81
# Epoch 545 Time:  08:59:26
# Mean absolute error at  545 is: 1.81
# Epoch 546 Time:  09:00:43
# Mean absolute error at  546 is: 1.81
# Epoch 547 Time:  09:01:59
# Mean absolute error at  547 is: 1.81
# Epoch 548 Time:  09:03:16
# Mean absolute error at  548 is: 1.80
# Epoch 549 Time:  09:04:33
# Mean absolute error at  549 is: 1.81
# Epoch 550 Time:  09:05:50
# Mean absolute error at  550 is: 1.80
# Epoch 551 Time:  09:07:06
# Mean absolute error at  551 is: 1.80
# Epoch 552 Time:  09:08:23
# Mean absolute error at  552 is: 1.81
# Epoch 553 Time:  09:09:40
# Mean absolute error at  553 is: 1.80
# Epoch 554 Time:  09:10:56
# Mean absolute error at  554 is: 1.80
# Epoch 555 Time:  09:12:12
# Mean absolute error at  555 is: 1.80
# Epoch 556 Time:  09:13:29
# Mean absolute error at  556 is: 1.80
# Epoch 557 Time:  09:14:45
# Mean absolute error at  557 is: 1.80
# Epoch 558 Time:  09:16:02
# Mean absolute error at  558 is: 1.80
# Epoch 559 Time:  09:17:18
# Mean absolute error at  559 is: 1.80
# Epoch 560 Time:  09:18:35
# Mean absolute error at  560 is: 1.80
# Epoch 561 Time:  09:19:51
# Mean absolute error at  561 is: 1.80
# Epoch 562 Time:  09:21:08
# Mean absolute error at  562 is: 1.81
# Epoch 563 Time:  09:22:25
# Mean absolute error at  563 is: 1.80
# Epoch 564 Time:  09:23:41
# Mean absolute error at  564 is: 1.80
# Epoch 565 Time:  09:24:58
# Mean absolute error at  565 is: 1.81
# Epoch 566 Time:  09:26:14
# Mean absolute error at  566 is: 1.80
# Epoch 567 Time:  09:27:31
# Mean absolute error at  567 is: 1.80
# Epoch 568 Time:  09:28:47
# Mean absolute error at  568 is: 1.80
# Epoch 569 Time:  09:30:04
# Mean absolute error at  569 is: 1.80
# Epoch 570 Time:  09:31:20
# Mean absolute error at  570 is: 1.81
# Epoch 571 Time:  09:32:37
# Mean absolute error at  571 is: 1.80
# Epoch 572 Time:  09:33:54
# Mean absolute error at  572 is: 1.80
# Epoch 573 Time:  09:35:10
# Mean absolute error at  573 is: 1.80
# Epoch 574 Time:  09:36:27
# Mean absolute error at  574 is: 1.80
# Epoch 575 Time:  09:37:43
# Mean absolute error at  575 is: 1.80
# Epoch 576 Time:  09:39:00
# Mean absolute error at  576 is: 1.80
# Epoch 577 Time:  09:40:16
# Mean absolute error at  577 is: 1.80
# Epoch 578 Time:  09:41:33
# Mean absolute error at  578 is: 1.80
# Epoch 579 Time:  09:42:49
# Mean absolute error at  579 is: 1.80
# Epoch 580 Time:  09:44:06
# Mean absolute error at  580 is: 1.80
# Epoch 581 Time:  09:45:22
# Mean absolute error at  581 is: 1.80
# Epoch 582 Time:  09:46:39
# Mean absolute error at  582 is: 1.80
# Epoch 583 Time:  09:47:55
# Mean absolute error at  583 is: 1.80
# Epoch 584 Time:  09:49:12
# Mean absolute error at  584 is: 1.80
# Epoch 585 Time:  09:50:28
# Mean absolute error at  585 is: 1.80
# Epoch 586 Time:  09:51:45
# Mean absolute error at  586 is: 1.80
# Epoch 587 Time:  09:53:02
# Mean absolute error at  587 is: 1.80
# Epoch 588 Time:  09:54:18
# Mean absolute error at  588 is: 1.80
# Epoch 589 Time:  09:55:35
# Mean absolute error at  589 is: 1.80
# Epoch 590 Time:  09:56:51
# Mean absolute error at  590 is: 1.80
# Epoch 591 Time:  09:58:08
# Mean absolute error at  591 is: 1.80
# Epoch 592 Time:  09:59:25
# Mean absolute error at  592 is: 1.80
# Epoch 593 Time:  10:00:41
# Mean absolute error at  593 is: 1.81
# Epoch 594 Time:  10:01:57
# Mean absolute error at  594 is: 1.80
# Epoch 595 Time:  10:03:14
# Mean absolute error at  595 is: 1.80
# Epoch 596 Time:  10:04:30
# Mean absolute error at  596 is: 1.81
# Epoch 597 Time:  10:05:47
# Mean absolute error at  597 is: 1.80
# Epoch 598 Time:  10:07:03
# Mean absolute error at  598 is: 1.80
# Epoch 599 Time:  10:08:20
# Mean absolute error at  599 is: 1.80
# Epoch 600 Time:  10:09:36
# Mean absolute error at  600 is: 2.02
# Epoch 601 Time:  10:10:53
# Mean absolute error at  601 is: 2.02
# Epoch 602 Time:  10:12:10
# Mean absolute error at  602 is: 2.03
# Epoch 603 Time:  10:13:26
# Mean absolute error at  603 is: 2.04
# Epoch 604 Time:  10:14:43
# Mean absolute error at  604 is: 2.07
# Epoch 605 Time:  10:15:59
# Mean absolute error at  605 is: 2.07
# Epoch 606 Time:  10:17:16
# Mean absolute error at  606 is: 2.08
# Epoch 607 Time:  10:18:32
# Mean absolute error at  607 is: 2.17
# Epoch 608 Time:  10:19:49
# Mean absolute error at  608 is: 2.09
# Epoch 609 Time:  10:21:06
# Mean absolute error at  609 is: 2.07
# Epoch 610 Time:  10:22:22
# Mean absolute error at  610 is: 2.07
# Epoch 611 Time:  10:23:39
# Mean absolute error at  611 is: 2.06
# Epoch 612 Time:  10:24:55
# Mean absolute error at  612 is: 2.08
# Epoch 613 Time:  10:26:12
# Mean absolute error at  613 is: 2.06
# Epoch 614 Time:  10:27:28
# Mean absolute error at  614 is: 2.10
# Epoch 615 Time:  10:28:45
# Mean absolute error at  615 is: 2.03
# Epoch 616 Time:  10:30:01
# Mean absolute error at  616 is: 2.03
# Epoch 617 Time:  10:31:18
# Mean absolute error at  617 is: 2.07
# Epoch 618 Time:  10:32:35
# Mean absolute error at  618 is: 2.18
# Epoch 619 Time:  10:33:51
# Mean absolute error at  619 is: 2.04
# Epoch 620 Time:  10:35:08
# Mean absolute error at  620 is: 2.11
# Epoch 621 Time:  10:36:24
# Mean absolute error at  621 is: 2.05
# Epoch 622 Time:  10:37:40
# Mean absolute error at  622 is: 2.01
# Epoch 623 Time:  10:38:57
# Mean absolute error at  623 is: 2.02
# Epoch 624 Time:  10:40:14
# Mean absolute error at  624 is: 2.04
# Epoch 625 Time:  10:41:31
# Mean absolute error at  625 is: 2.03
# Epoch 626 Time:  10:42:47
# Mean absolute error at  626 is: 2.04
# Epoch 627 Time:  10:44:04
# Mean absolute error at  627 is: 2.01
# Epoch 628 Time:  10:45:20
# Mean absolute error at  628 is: 2.04
# Epoch 629 Time:  10:46:36
# Mean absolute error at  629 is: 2.01
# Epoch 630 Time:  10:47:53
# Mean absolute error at  630 is: 2.01
# Epoch 631 Time:  10:49:10
# Mean absolute error at  631 is: 2.02
# Epoch 632 Time:  10:50:26
# Mean absolute error at  632 is: 2.06
# Epoch 633 Time:  10:51:43
# Mean absolute error at  633 is: 2.04
# Epoch 634 Time:  10:52:59
# Mean absolute error at  634 is: 2.05
# Epoch 635 Time:  10:54:16
# Mean absolute error at  635 is: 2.03
# Epoch 636 Time:  10:55:32
# Mean absolute error at  636 is: 2.06
# Epoch 637 Time:  10:56:49
# Mean absolute error at  637 is: 2.07
# Epoch 638 Time:  10:58:06
# Mean absolute error at  638 is: 2.07
# Epoch 639 Time:  10:59:22
# Mean absolute error at  639 is: 2.09
# Epoch 640 Time:  11:00:39
# Mean absolute error at  640 is: 2.04
# Epoch 641 Time:  11:01:55
# Mean absolute error at  641 is: 2.02
# Epoch 642 Time:  11:03:11
# Mean absolute error at  642 is: 2.06
# Epoch 643 Time:  11:04:28
# Mean absolute error at  643 is: 2.12
# Epoch 644 Time:  11:05:45
# Mean absolute error at  644 is: 2.08
# Epoch 645 Time:  11:07:01
# Mean absolute error at  645 is: 2.07
# Epoch 646 Time:  11:08:18
# Mean absolute error at  646 is: 2.07
# Epoch 647 Time:  11:09:34
# Mean absolute error at  647 is: 2.03
# Epoch 648 Time:  11:10:51
# Mean absolute error at  648 is: 2.01
# Epoch 649 Time:  11:12:07
# Mean absolute error at  649 is: 2.07
# Epoch 650 Time:  11:13:24
# Mean absolute error at  650 is: 2.07
# Epoch 651 Time:  11:14:41
# Mean absolute error at  651 is: 2.05
# Epoch 652 Time:  11:15:57
# Mean absolute error at  652 is: 2.01
# Epoch 653 Time:  11:17:13
# Mean absolute error at  653 is: 2.04
# Epoch 654 Time:  11:18:30
# Mean absolute error at  654 is: 2.04
# Epoch 655 Time:  11:19:46
# Mean absolute error at  655 is: 1.98
# Epoch 656 Time:  11:21:03
# Mean absolute error at  656 is: 2.05
# Epoch 657 Time:  11:22:20
# Mean absolute error at  657 is: 2.07
# Epoch 658 Time:  11:23:36
# Mean absolute error at  658 is: 2.03
# Epoch 659 Time:  11:24:53
# Mean absolute error at  659 is: 2.12
# Epoch 660 Time:  11:26:09
# Mean absolute error at  660 is: 2.05
# Epoch 661 Time:  11:27:26
# Mean absolute error at  661 is: 2.03
# Epoch 662 Time:  11:28:42
# Mean absolute error at  662 is: 2.08
# Epoch 663 Time:  11:29:59
# Mean absolute error at  663 is: 2.06
# Epoch 664 Time:  11:31:16
# Mean absolute error at  664 is: 2.04
# Epoch 665 Time:  11:32:32
# Mean absolute error at  665 is: 2.00
# Epoch 666 Time:  11:33:49
# Mean absolute error at  666 is: 2.01
# Epoch 667 Time:  11:35:05
# Mean absolute error at  667 is: 2.07
# Epoch 668 Time:  11:36:22
# Mean absolute error at  668 is: 2.05
# Epoch 669 Time:  11:37:38
# Mean absolute error at  669 is: 2.04
# Epoch 670 Time:  11:38:55
# Mean absolute error at  670 is: 1.99
# Epoch 671 Time:  11:40:11
# Mean absolute error at  671 is: 2.02
# Epoch 672 Time:  11:41:28
# Mean absolute error at  672 is: 2.07
# Epoch 673 Time:  11:42:45
# Mean absolute error at  673 is: 2.08
# Epoch 674 Time:  11:44:01
# Mean absolute error at  674 is: 2.10
# Epoch 675 Time:  11:45:18
# Mean absolute error at  675 is: 2.06
# Epoch 676 Time:  11:46:34
# Mean absolute error at  676 is: 2.00
# Epoch 677 Time:  11:47:51
# Mean absolute error at  677 is: 2.00
# Epoch 678 Time:  11:49:07
# Mean absolute error at  678 is: 2.03
# Epoch 679 Time:  11:50:24
# Mean absolute error at  679 is: 2.01
# Epoch 680 Time:  11:51:41
# Mean absolute error at  680 is: 2.03
# Epoch 681 Time:  11:52:57
# Mean absolute error at  681 is: 2.04
# Epoch 682 Time:  11:54:13
# Mean absolute error at  682 is: 2.00
# Epoch 683 Time:  11:55:30
# Mean absolute error at  683 is: 1.99
# Epoch 684 Time:  11:56:46
# Mean absolute error at  684 is: 2.05
# Epoch 685 Time:  11:58:03
# Mean absolute error at  685 is: 2.08
# Epoch 686 Time:  11:59:20
# Mean absolute error at  686 is: 2.03
# Epoch 687 Time:  12:00:36
# Mean absolute error at  687 is: 1.95
# Epoch 688 Time:  12:01:53
# Mean absolute error at  688 is: 1.99
# Epoch 689 Time:  12:03:10
# Mean absolute error at  689 is: 2.08
# Epoch 690 Time:  12:04:26
# Mean absolute error at  690 is: 2.04
# Epoch 691 Time:  12:05:43
# Mean absolute error at  691 is: 2.03
# Epoch 692 Time:  12:06:59
# Mean absolute error at  692 is: 2.09
# Epoch 693 Time:  12:08:16
# Mean absolute error at  693 is: 2.07
# Epoch 694 Time:  12:09:32
# Mean absolute error at  694 is: 1.99
# Epoch 695 Time:  12:10:49
# Mean absolute error at  695 is: 2.03
# Epoch 696 Time:  12:12:06
# Mean absolute error at  696 is: 2.04
# Epoch 697 Time:  12:13:22
# Mean absolute error at  697 is: 2.01
# Epoch 698 Time:  12:14:38
# Mean absolute error at  698 is: 1.99
# Epoch 699 Time:  12:15:55
# Mean absolute error at  699 is: 1.97
# Epoch 700 Time:  12:17:12
# Mean absolute error at  700 is: 2.00
# Epoch 701 Time:  12:18:28
# Mean absolute error at  701 is: 2.02
# Epoch 702 Time:  12:19:45
# Mean absolute error at  702 is: 1.99
# Epoch 703 Time:  12:21:01
# Mean absolute error at  703 is: 2.00
# Epoch 704 Time:  12:22:17
# Mean absolute error at  704 is: 2.04
# Epoch 705 Time:  12:23:34
# Mean absolute error at  705 is: 2.01
# Epoch 706 Time:  12:24:51
# Mean absolute error at  706 is: 2.07
# Epoch 707 Time:  12:26:08
# Mean absolute error at  707 is: 2.01
# Epoch 708 Time:  12:27:41
# Mean absolute error at  708 is: 2.01
# Epoch 709 Time:  12:29:05
# Mean absolute error at  709 is: 2.01
# Epoch 710 Time:  12:30:21
# Mean absolute error at  710 is: 1.97
# Epoch 711 Time:  12:31:38
# Mean absolute error at  711 is: 2.03
# Epoch 712 Time:  12:32:54
# Mean absolute error at  712 is: 2.03
# Epoch 713 Time:  12:34:11
# Mean absolute error at  713 is: 2.02
# Epoch 714 Time:  12:35:28
# Mean absolute error at  714 is: 2.01
# Epoch 715 Time:  12:36:44
# Mean absolute error at  715 is: 1.98
# Epoch 716 Time:  12:38:01
# Mean absolute error at  716 is: 2.01
# Epoch 717 Time:  12:39:17
# Mean absolute error at  717 is: 1.99
# Epoch 718 Time:  12:40:35
# Mean absolute error at  718 is: 2.00
# Epoch 719 Time:  12:41:51
# Mean absolute error at  719 is: 2.12
# Epoch 720 Time:  12:43:08
# Mean absolute error at  720 is: 2.10
# Epoch 721 Time:  12:44:24
# Mean absolute error at  721 is: 1.97
# Epoch 722 Time:  12:45:41
# Mean absolute error at  722 is: 1.97
# Epoch 723 Time:  12:46:58
# Mean absolute error at  723 is: 2.01
# Epoch 724 Time:  12:48:14
# Mean absolute error at  724 is: 1.98
# Epoch 725 Time:  12:49:31
# Mean absolute error at  725 is: 2.01
# Epoch 726 Time:  12:50:47
# Mean absolute error at  726 is: 1.97
# Epoch 727 Time:  12:52:03
# Mean absolute error at  727 is: 2.06
# Epoch 728 Time:  12:53:20
# Mean absolute error at  728 is: 2.04
# Epoch 729 Time:  12:54:37
# Mean absolute error at  729 is: 2.03
# Epoch 730 Time:  12:55:53
# Mean absolute error at  730 is: 1.96
# Epoch 731 Time:  12:57:10
# Mean absolute error at  731 is: 1.96
# Epoch 732 Time:  12:58:27
# Mean absolute error at  732 is: 2.00
# Epoch 733 Time:  12:59:43
# Mean absolute error at  733 is: 1.97
# Epoch 734 Time:  13:01:00
# Mean absolute error at  734 is: 1.98
# Epoch 735 Time:  13:02:16
# Mean absolute error at  735 is: 2.01
# Epoch 736 Time:  13:03:33
# Mean absolute error at  736 is: 1.99
# Epoch 737 Time:  13:04:49
# Mean absolute error at  737 is: 1.97
# Epoch 738 Time:  13:06:06
# Mean absolute error at  738 is: 1.99
# Epoch 739 Time:  13:07:25
# Mean absolute error at  739 is: 2.02
# Epoch 740 Time:  13:08:41
# Mean absolute error at  740 is: 2.06
# Epoch 741 Time:  13:09:58
# Mean absolute error at  741 is: 2.00
# Epoch 742 Time:  13:11:14
# Mean absolute error at  742 is: 1.96
# Epoch 743 Time:  13:12:31
# Mean absolute error at  743 is: 2.00
# Epoch 744 Time:  13:13:47
# Mean absolute error at  744 is: 2.05
# Epoch 745 Time:  13:15:04
# Mean absolute error at  745 is: 2.00
# Epoch 746 Time:  13:16:21
# Mean absolute error at  746 is: 1.98
# Epoch 747 Time:  13:17:37
# Mean absolute error at  747 is: 1.97
# Epoch 748 Time:  13:19:11
# Mean absolute error at  748 is: 2.05
# Epoch 749 Time:  13:20:28
# Mean absolute error at  749 is: 2.07
# Epoch 750 Time:  13:21:44
# Mean absolute error at  750 is: 1.98
# Epoch 751 Time:  13:23:00
# Mean absolute error at  751 is: 2.15
# Epoch 752 Time:  13:24:17
# Mean absolute error at  752 is: 2.03
# Epoch 753 Time:  13:25:33
# Mean absolute error at  753 is: 2.03
# Epoch 754 Time:  13:26:50
# Mean absolute error at  754 is: 1.95
# Epoch 755 Time:  13:28:06
# Mean absolute error at  755 is: 2.02
# Epoch 756 Time:  13:29:23
# Mean absolute error at  756 is: 1.98
# Epoch 757 Time:  13:30:39
# Mean absolute error at  757 is: 1.97
# Epoch 758 Time:  13:31:56
# Mean absolute error at  758 is: 1.96
# Epoch 759 Time:  13:33:12
# Mean absolute error at  759 is: 1.96
# Epoch 760 Time:  13:34:29
# Mean absolute error at  760 is: 1.97
# Epoch 761 Time:  13:35:45
# Mean absolute error at  761 is: 1.98
# Epoch 762 Time:  13:37:02
# Mean absolute error at  762 is: 1.99
# Epoch 763 Time:  13:38:18
# ...
# Mean absolute error at  962 is: 1.94
# Epoch 963 Time:  17:53:47
# Mean absolute error at  963 is: 2.00
# Epoch 964 Time:  17:55:03
# Mean absolute error at  964 is: 1.96
# Epoch 965 Time:  17:56:20
# Mean absolute error at  965 is: 1.98
# Epoch 966 Time:  17:57:36
# Mean absolute error at  966 is: 1.98
# Epoch 967 Time:  17:58:53
# Mean absolute error at  967 is: 1.93
# Epoch 968 Time:  18:00:09
# Mean absolute error at  968 is: 1.95
# Epoch 969 Time:  18:01:26
# Mean absolute error at  969 is: 1.97
# Epoch 970 Time:  18:02:42
# Mean absolute error at  970 is: 1.99
# Epoch 971 Time:  18:03:59
# Mean absolute error at  971 is: 1.94
# Epoch 972 Time:  18:05:15
# Mean absolute error at  972 is: 1.94
# Epoch 973 Time:  18:06:32
# Mean absolute error at  973 is: 1.98
# Epoch 974 Time:  18:07:48
# Mean absolute error at  974 is: 1.93
# Epoch 975 Time:  18:09:04
# Mean absolute error at  975 is: 1.92
# Epoch 976 Time:  18:10:44
# Mean absolute error at  976 is: 1.89
# Epoch 977 Time:  18:12:00
# Mean absolute error at  977 is: 1.93
# Epoch 978 Time:  18:13:17
# Mean absolute error at  978 is: 1.96
# Epoch 979 Time:  18:14:33
# Mean absolute error at  979 is: 1.95
# Epoch 980 Time:  18:15:50
# Mean absolute error at  980 is: 1.94
# Epoch 981 Time:  18:17:07
# Mean absolute error at  981 is: 1.98
# Epoch 982 Time:  18:18:23
# Mean absolute error at  982 is: 2.00
# Epoch 983 Time:  18:19:39
# Mean absolute error at  983 is: 1.90
# Epoch 984 Time:  18:20:56
# Mean absolute error at  984 is: 1.93
# Epoch 985 Time:  18:22:12
# Mean absolute error at  985 is: 1.92
# Epoch 986 Time:  18:23:29
# Mean absolute error at  986 is: 1.97
# Epoch 987 Time:  18:24:45
# Mean absolute error at  987 is: 1.91
# Epoch 988 Time:  18:26:02
# Mean absolute error at  988 is: 1.95
# Epoch 989 Time:  18:27:18
# Mean absolute error at  989 is: 1.94
# Epoch 990 Time:  18:28:35
# Mean absolute error at  990 is: 1.94
# Epoch 991 Time:  18:29:51
# Mean absolute error at  991 is: 1.99
# Epoch 992 Time:  18:31:08
# Mean absolute error at  992 is: 1.93
# Epoch 993 Time:  18:32:24
# Mean absolute error at  993 is: 1.97
# Epoch 994 Time:  18:33:41
# Mean absolute error at  994 is: 1.97
# Epoch 995 Time:  18:34:57
# Mean absolute error at  995 is: 1.93
# Epoch 996 Time:  18:36:13
# Mean absolute error at  996 is: 1.96
# Epoch 997 Time:  18:37:30
# Mean absolute error at  997 is: 1.96
# Epoch 998 Time:  18:38:46
# Mean absolute error at  998 is: 1.97
# Epoch 999 Time:  18:40:02
# Mean absolute error at  999 is: 1.95
# Epoch 1000 Time:  18:41:19
# Mean absolute error at 1000 is: 1.89
# Epoch 1001 Time:  18:42:36
# Mean absolute error at 1001 is: 2.00
# Epoch 1002 Time:  18:43:52
# Mean absolute error at 1002 is: 2.00
# Epoch 1003 Time:  18:45:09
# Mean absolute error at 1003 is: 2.00
# Epoch 1004 Time:  18:46:25
# Mean absolute error at 1004 is: 1.91
# Epoch 1005 Time:  18:47:41
# Mean absolute error at 1005 is: 1.92
# Epoch 1006 Time:  18:48:58
# Mean absolute error at 1006 is: 1.98
# Epoch 1007 Time:  18:50:14
# Mean absolute error at 1007 is: 2.01
# Epoch 1008 Time:  18:51:31
# Mean absolute error at 1008 is: 1.92
# Epoch 1009 Time:  18:52:47
# Mean absolute error at 1009 is: 1.92
# Epoch 1010 Time:  18:54:04
# Mean absolute error at 1010 is: 1.95
# Epoch 1011 Time:  18:55:20
# Mean absolute error at 1011 is: 1.92
# Epoch 1012 Time:  18:56:36
# Mean absolute error at 1012 is: 1.98
# Epoch 1013 Time:  18:57:53
# Mean absolute error at 1013 is: 1.97
# Epoch 1014 Time:  18:59:09
# Mean absolute error at 1014 is: 1.98
# Epoch 1015 Time:  19:00:25
# Mean absolute error at 1015 is: 1.93
# Epoch 1016 Time:  19:01:42
# Mean absolute error at 1016 is: 1.96
# Epoch 1017 Time:  19:02:59
# Mean absolute error at 1017 is: 1.96
# Epoch 1018 Time:  19:04:15
# Mean absolute error at 1018 is: 1.96
# Epoch 1019 Time:  19:05:31
# Mean absolute error at 1019 is: 1.95
# Epoch 1020 Time:  19:06:48
# Mean absolute error at 1020 is: 1.94
# Epoch 1021 Time:  19:08:04
# Mean absolute error at 1021 is: 1.95
# Epoch 1022 Time:  19:09:21
# Mean absolute error at 1022 is: 2.01
# Epoch 1023 Time:  19:10:38
# Mean absolute error at 1023 is: 1.95
# Epoch 1024 Time:  19:11:54
# Mean absolute error at 1024 is: 1.93
# Epoch 1025 Time:  19:13:10
# Mean absolute error at 1025 is: 2.04
# Epoch 1026 Time:  19:14:27
# Mean absolute error at 1026 is: 2.00
# Epoch 1027 Time:  19:15:43
# Mean absolute error at 1027 is: 1.99
# Epoch 1028 Time:  19:17:00
# Mean absolute error at 1028 is: 1.98
# Epoch 1029 Time:  19:18:16
# Mean absolute error at 1029 is: 1.92
# Epoch 1030 Time:  19:19:33
# Mean absolute error at 1030 is: 1.96
# Epoch 1031 Time:  19:20:49
# Mean absolute error at 1031 is: 1.92
# Epoch 1032 Time:  19:22:05
# Mean absolute error at 1032 is: 1.91
# Epoch 1033 Time:  19:23:22
# Mean absolute error at 1033 is: 1.94
# Epoch 1034 Time:  19:24:38
# Mean absolute error at 1034 is: 1.91
# Epoch 1035 Time:  19:25:55
# Mean absolute error at 1035 is: 1.91
# Epoch 1036 Time:  19:27:11
# Mean absolute error at 1036 is: 1.94
# Epoch 1037 Time:  19:28:28
# Mean absolute error at 1037 is: 1.96
# Epoch 1038 Time:  19:29:44
# Mean absolute error at 1038 is: 1.94
# Epoch 1039 Time:  19:31:01
# Mean absolute error at 1039 is: 1.99
# Epoch 1040 Time:  19:32:17
# Mean absolute error at 1040 is: 1.98
# Epoch 1041 Time:  19:33:33
# Mean absolute error at 1041 is: 1.94
# Epoch 1042 Time:  19:34:50
# Mean absolute error at 1042 is: 1.97
# Epoch 1043 Time:  19:36:06
# Mean absolute error at 1043 is: 1.91
# Epoch 1044 Time:  19:37:39
# Mean absolute error at 1044 is: 1.93
# Epoch 1045 Time:  19:38:56
# Mean absolute error at 1045 is: 1.92
# Epoch 1046 Time:  19:40:13
# Mean absolute error at 1046 is: 1.95
# Epoch 1047 Time:  19:41:29
# Mean absolute error at 1047 is: 1.95
# Epoch 1048 Time:  19:42:46
# Mean absolute error at 1048 is: 1.96
# Epoch 1049 Time:  19:44:03
# Mean absolute error at 1049 is: 2.09
# Epoch 1050 Time:  19:45:20
# Mean absolute error at 1050 is: 1.96
# Epoch 1051 Time:  19:46:36
# Mean absolute error at 1051 is: 1.94
# Epoch 1052 Time:  19:47:53
# Mean absolute error at 1052 is: 1.95
# Epoch 1053 Time:  19:49:09
# Mean absolute error at 1053 is: 1.93
# Epoch 1054 Time:  19:50:26
# Mean absolute error at 1054 is: 1.95
# Epoch 1055 Time:  19:51:43
# Mean absolute error at 1055 is: 1.93
# Epoch 1056 Time:  19:52:59
# Mean absolute error at 1056 is: 1.95
# Epoch 1057 Time:  19:54:15
# Mean absolute error at 1057 is: 1.93
# Epoch 1058 Time:  19:55:32
# Mean absolute error at 1058 is: 1.93
# Epoch 1059 Time:  19:56:49
# Mean absolute error at 1059 is: 1.94
# Epoch 1060 Time:  19:58:05
# Mean absolute error at 1060 is: 1.93
# Epoch 1061 Time:  19:59:22
# Mean absolute error at 1061 is: 1.91
# Epoch 1062 Time:  20:00:39
# Mean absolute error at 1062 is: 1.94
# Epoch 1063 Time:  20:01:55
# Mean absolute error at 1063 is: 1.93
# Epoch 1064 Time:  20:03:12
# Mean absolute error at 1064 is: 1.92
# Epoch 1065 Time:  20:04:29
# Mean absolute error at 1065 is: 1.89
# Epoch 1066 Time:  20:05:46
# Mean absolute error at 1066 is: 1.92
# Epoch 1067 Time:  20:07:02
# Mean absolute error at 1067 is: 1.89
# Epoch 1068 Time:  20:08:19
# Mean absolute error at 1068 is: 1.94
# Epoch 1069 Time:  20:09:35
# Mean absolute error at 1069 is: 1.98
# Epoch 1070 Time:  20:10:52
# Mean absolute error at 1070 is: 1.96
# Epoch 1071 Time:  20:12:08
# Mean absolute error at 1071 is: 1.93
# Epoch 1072 Time:  20:13:25
# Mean absolute error at 1072 is: 1.91
# Epoch 1073 Time:  20:14:41
# Mean absolute error at 1073 is: 1.96
# Epoch 1074 Time:  20:15:58
# Mean absolute error at 1074 is: 1.93
# Epoch 1075 Time:  20:17:15
# Mean absolute error at 1075 is: 1.92
# Epoch 1076 Time:  20:18:31
# Mean absolute error at 1076 is: 1.95
# Epoch 1077 Time:  20:19:48
# Mean absolute error at 1077 is: 1.89
# Epoch 1078 Time:  20:21:05
# Mean absolute error at 1078 is: 1.94
# Epoch 1079 Time:  20:22:21
# Mean absolute error at 1079 is: 1.90
# Epoch 1080 Time:  20:23:38
# Mean absolute error at 1080 is: 1.99
# Epoch 1081 Time:  20:24:55
# Mean absolute error at 1081 is: 1.94
# Epoch 1082 Time:  20:26:12
# Mean absolute error at 1082 is: 1.98
# Epoch 1083 Time:  20:27:28
# Mean absolute error at 1083 is: 1.97
# Epoch 1084 Time:  20:28:45
# Mean absolute error at 1084 is: 1.94
# Epoch 1085 Time:  20:30:02
# Mean absolute error at 1085 is: 1.92
# Epoch 1086 Time:  20:31:18
# Mean absolute error at 1086 is: 1.95
# Epoch 1087 Time:  20:32:34
# Mean absolute error at 1087 is: 1.91
# Epoch 1088 Time:  20:33:51
# Mean absolute error at 1088 is: 1.89
# Epoch 1089 Time:  20:35:08
# Mean absolute error at 1089 is: 1.93
# Epoch 1090 Time:  20:36:24
# Mean absolute error at 1090 is: 1.90
# Epoch 1091 Time:  20:37:41
# Mean absolute error at 1091 is: 1.94
# Epoch 1092 Time:  20:38:57
# Mean absolute error at 1092 is: 1.91
# Epoch 1093 Time:  20:40:13
# Mean absolute error at 1093 is: 1.96
# Epoch 1094 Time:  20:41:30
# Mean absolute error at 1094 is: 1.89
# Epoch 1095 Time:  20:42:47
# Mean absolute error at 1095 is: 1.95
# Epoch 1096 Time:  20:44:03
# Mean absolute error at 1096 is: 1.89
# Epoch 1097 Time:  20:45:20
# Mean absolute error at 1097 is: 1.97
# Epoch 1098 Time:  20:46:36
# Mean absolute error at 1098 is: 1.94
# Epoch 1099 Time:  20:47:53
# Mean absolute error at 1099 is: 1.97
# Epoch 1100 Time:  20:49:09
# Mean absolute error at 1100 is: 1.75
# Epoch 1101 Time:  20:50:26
# Mean absolute error at 1101 is: 1.74
# Epoch 1102 Time:  20:51:42
# Mean absolute error at 1102 is: 1.74
# Epoch 1103 Time:  20:52:58
# Mean absolute error at 1103 is: 1.74
# Epoch 1104 Time:  20:54:15
# Mean absolute error at 1104 is: 1.74
# Epoch 1105 Time:  20:55:33
# Mean absolute error at 1105 is: 1.73
# Epoch 1106 Time:  20:56:49
# Mean absolute error at 1106 is: 1.73
# Epoch 1107 Time:  20:58:06
# Mean absolute error at 1107 is: 1.72
# Epoch 1108 Time:  20:59:23
# Mean absolute error at 1108 is: 1.73
# Epoch 1109 Time:  21:00:39
# Mean absolute error at 1109 is: 1.73
# Epoch 1110 Time:  21:01:56
# Mean absolute error at 1110 is: 1.73
# Epoch 1111 Time:  21:03:12
# Mean absolute error at 1111 is: 1.72
# Epoch 1112 Time:  21:04:29
# Mean absolute error at 1112 is: 1.72
# Epoch 1113 Time:  21:05:45
# Mean absolute error at 1113 is: 1.72
# Epoch 1114 Time:  21:07:03
# Mean absolute error at 1114 is: 1.72
# Epoch 1115 Time:  21:08:20
# Mean absolute error at 1115 is: 1.73
# Epoch 1116 Time:  21:09:36
# Mean absolute error at 1116 is: 1.72
# Epoch 1117 Time:  21:10:53
# Mean absolute error at 1117 is: 1.73
# Epoch 1118 Time:  21:12:10
# Mean absolute error at 1118 is: 1.71
# Epoch 1119 Time:  21:13:26
# Mean absolute error at 1119 is: 1.73
# Epoch 1120 Time:  21:14:42
# Mean absolute error at 1120 is: 1.72
# Epoch 1121 Time:  21:15:59
# Mean absolute error at 1121 is: 1.71
# Epoch 1122 Time:  21:17:15
# Mean absolute error at 1122 is: 1.72
# Epoch 1123 Time:  21:18:32
# Mean absolute error at 1123 is: 1.72
# Epoch 1124 Time:  21:19:49
# Mean absolute error at 1124 is: 1.73
# Epoch 1125 Time:  21:21:05
# Mean absolute error at 1125 is: 1.71
# Epoch 1126 Time:  21:22:22
# Mean absolute error at 1126 is: 1.71
# Epoch 1127 Time:  21:23:38
# Mean absolute error at 1127 is: 1.71
# Epoch 1128 Time:  21:24:55
# Mean absolute error at 1128 is: 1.71
# Epoch 1129 Time:  21:26:11
# Mean absolute error at 1129 is: 1.71
# Epoch 1130 Time:  21:27:28
# Mean absolute error at 1130 is: 1.71
# Epoch 1131 Time:  21:28:45
# Mean absolute error at 1131 is: 1.71
# Epoch 1132 Time:  21:30:01
# Mean absolute error at 1132 is: 1.71
# Epoch 1133 Time:  21:31:18
# Mean absolute error at 1133 is: 1.71
# Epoch 1134 Time:  21:32:35
# Mean absolute error at 1134 is: 1.71
# Epoch 1135 Time:  21:33:51
# Mean absolute error at 1135 is: 1.71
# Epoch 1136 Time:  21:35:08
# Mean absolute error at 1136 is: 1.71
# Epoch 1137 Time:  21:36:24
# Mean absolute error at 1137 is: 1.71
# Epoch 1138 Time:  21:37:41
# Mean absolute error at 1138 is: 1.71
# Epoch 1139 Time:  21:38:57
# Mean absolute error at 1139 is: 1.71
# Epoch 1140 Time:  21:40:14
# Mean absolute error at 1140 is: 1.70
# Epoch 1141 Time:  21:41:31
# Mean absolute error at 1141 is: 1.71
# Epoch 1142 Time:  21:42:47
# Mean absolute error at 1142 is: 1.71
# Epoch 1143 Time:  21:44:04
# Mean absolute error at 1143 is: 1.71
# Epoch 1144 Time:  21:45:20
# Mean absolute error at 1144 is: 1.71
# Epoch 1145 Time:  21:46:37
# Mean absolute error at 1145 is: 1.71
# Epoch 1146 Time:  21:47:54
# Mean absolute error at 1146 is: 1.71
# Epoch 1147 Time:  21:49:10
# Mean absolute error at 1147 is: 1.71
# Epoch 1148 Time:  21:50:27
# Mean absolute error at 1148 is: 1.71
# Epoch 1149 Time:  21:51:43
# Mean absolute error at 1149 is: 1.71
# Epoch 1150 Time:  21:53:00
# Mean absolute error at 1150 is: 1.70
# Epoch 1151 Time:  21:54:17
# Mean absolute error at 1151 is: 1.70
# Epoch 1152 Time:  21:55:33
# Mean absolute error at 1152 is: 1.70
# Epoch 1153 Time:  21:56:50
# Mean absolute error at 1153 is: 1.71
# Epoch 1154 Time:  21:58:07
# Mean absolute error at 1154 is: 1.71
# Epoch 1155 Time:  21:59:23
# Mean absolute error at 1155 is: 1.70
# Epoch 1156 Time:  22:00:40
# Mean absolute error at 1156 is: 1.71
# Epoch 1157 Time:  22:01:56
# Mean absolute error at 1157 is: 1.70
# Epoch 1158 Time:  22:03:13
# Mean absolute error at 1158 is: 1.70
# Epoch 1159 Time:  22:04:29
# Mean absolute error at 1159 is: 1.70
# Epoch 1160 Time:  22:05:46
# Mean absolute error at 1160 is: 1.70
# Epoch 1161 Time:  22:07:03
# Mean absolute error at 1161 is: 1.70
# Epoch 1162 Time:  22:08:20
# Mean absolute error at 1162 is: 1.71
# Epoch 1163 Time:  22:09:37
# Mean absolute error at 1163 is: 1.71
# Epoch 1164 Time:  22:10:53
# Mean absolute error at 1164 is: 1.70
# Epoch 1165 Time:  22:12:10
# Mean absolute error at 1165 is: 1.71
# Epoch 1166 Time:  22:13:28
# Mean absolute error at 1166 is: 1.70
# Epoch 1167 Time:  22:14:45
# Mean absolute error at 1167 is: 1.70
# Epoch 1168 Time:  22:16:01
# Mean absolute error at 1168 is: 1.71
# Epoch 1169 Time:  22:17:18
# Mean absolute error at 1169 is: 1.71
# Epoch 1170 Time:  22:18:35
# Mean absolute error at 1170 is: 1.70
# Epoch 1171 Time:  22:19:51
# Mean absolute error at 1171 is: 1.71
# Epoch 1172 Time:  22:21:08
# Mean absolute error at 1172 is: 1.70
# Epoch 1173 Time:  22:22:25
# Mean absolute error at 1173 is: 1.71
# Epoch 1174 Time:  22:23:41
# Mean absolute error at 1174 is: 1.71
# Epoch 1175 Time:  22:24:57
# Mean absolute error at 1175 is: 1.71
# Epoch 1176 Time:  22:26:14
# Mean absolute error at 1176 is: 1.70
# Epoch 1177 Time:  22:27:32
# Mean absolute error at 1177 is: 1.71
# Epoch 1178 Time:  22:28:48
# Mean absolute error at 1178 is: 1.71
# Epoch 1179 Time:  22:30:05
# Mean absolute error at 1179 is: 1.70
# Epoch 1180 Time:  22:31:21
# Mean absolute error at 1180 is: 1.70
# Epoch 1181 Time:  22:32:38
# Mean absolute error at 1181 is: 1.71
# Epoch 1182 Time:  22:33:55
# Mean absolute error at 1182 is: 1.71
# Epoch 1183 Time:  22:35:11
# Mean absolute error at 1183 is: 1.70
# Epoch 1184 Time:  22:36:28
# Mean absolute error at 1184 is: 1.70
# Epoch 1185 Time:  22:37:44
# Mean absolute error at 1185 is: 1.71
# Epoch 1186 Time:  22:39:01
# Mean absolute error at 1186 is: 1.71
# Epoch 1187 Time:  22:40:17
# Mean absolute error at 1187 is: 1.71
# Epoch 1188 Time:  22:41:34
# Mean absolute error at 1188 is: 1.71
# Epoch 1189 Time:  22:42:51
# Mean absolute error at 1189 is: 1.70
# Epoch 1190 Time:  22:44:07
# Mean absolute error at 1190 is: 1.70
# Epoch 1191 Time:  22:45:24
# Mean absolute error at 1191 is: 1.71
# Epoch 1192 Time:  22:46:41
# Mean absolute error at 1192 is: 1.71
# Epoch 1193 Time:  22:47:58
# Mean absolute error at 1193 is: 1.71
# Epoch 1194 Time:  22:49:15
# Mean absolute error at 1194 is: 1.70
# Epoch 1195 Time:  22:50:31
# Mean absolute error at 1195 is: 1.71
# Epoch 1196 Time:  22:51:49
# Mean absolute error at 1196 is: 1.70
# Epoch 1197 Time:  22:53:05
# Mean absolute error at 1197 is: 1.70
# Epoch 1198 Time:  22:54:22
# Mean absolute error at 1198 is: 1.71
# Epoch 1199 Time:  22:55:38
# Mean absolute error at 1199 is: 1.71
# WARNING:tensorflow:From C:\Users\Alex\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Alex\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/cnn3v27\assets

# %%
#%tensorboard --logdir logs/fit
sc_y.inverse_transform(np.array(maesc).reshape(1,-1))[0][0]

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# cheap way to check mse for test set
losssc, msesc, maesc = model.evaluate([Xvalid/255.,Xvalid2],y_valid)
mae = maesc*(sc_y.var_)**0.5
print('Mean absolute error is: {:4.2f}'.format(mae[0]))

# %%
losssc, msesc, maesc = model.evaluate([Xvalid/255.,Xvalid2],y_valid)
mae = maesc*(sc_y.var_[0])**0.5
print('Mean absolute error is: {:4.2f}'.format(mae))

# %%
# Redo test set
Xtest = Testset/255.
Xtest2 = sc_X2.transform(Testset2)
y_pred = model.predict([Xtest,Xtest2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is -0.02 degrees
# Root Mean Squared Error is 1.71 degrees
# Mean Absolute Error is 1.71 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v27_pb.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
#     modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
#         pickle.dump([randata,sc_y,sc_X2,modelhistory], file)
          pickle.dump([randata,sc_y,sc_X2], file)
        
#     !mkdir -p saved_model
#     model.save('saved_model/cnn3v22')

# %%
model.save('saved_model/cnn3v27')

# %%
# 
# %matplotlib qt

# %%
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
