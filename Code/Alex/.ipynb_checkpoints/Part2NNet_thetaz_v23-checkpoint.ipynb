# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats
import os

# %%
# Add tensorboard stuff
# %load_ext tensorboard
# import datetime

# !rm -rf ./logs/

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#             gray_frame = frame/np.maximum(np.max(frame),255) keep as int8 for memory savings
            gray_frame = frame
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)

n_test = (1,2,24,30,31,32,33,35,1,3)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
        
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
#     train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    train_dcamera_path = os.path.join(data_dir , 'depth_processed_'+subj[i]+'_test'+str(n_test[i])+'.avi')
    xtemp[i] = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize).astype('uint8')

# %%
tlen=0
for x in range(len(xtemp)):
    tlen+= xtemp[x].shape[0]
xrun_cum = 0
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]),dtype='uint8')
for i in range (len(xtemp)):
    xrun_n = len(xtemp[i])
    x_train[xrun_cum:xrun_cum+xrun_n,:,:,:] = xtemp[i][:xrun_n,:,:,:]
    xrun_cum += xrun_n

# %%
x_train.shape
# Out:
# (153421, 60, 80, 3)

# %%
plt.imshow(x_train[153418])

# %%
print(x_train.shape)
del xtemp
# Out:
# (153421, 60, 80, 3)

# %% [markdown]
# # read fcss data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
subjwgt = [61,61, 67, 67, 67, 67, 67, 67, 70, 70]
subjht = [180, 180, 174, 174, 174, 174, 174, 174, 170, 170]
xfcss_gt = {}
yrun = 0
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    fcss_data_dir = os.path.join(data_dir , 'fcss_processed_'+subj[i]+'_' + test_str + '_' + date[i] + '.txt')
    xfcss_gttemp = pd.read_csv(fcss_data_dir)/subjwgt[i]
    xfcss_gt[i]=xfcss_gttemp
#     xfcss_gt[i]['weight'] = subjwgt[i]# hacky but will work for now
#     xfcss_gt[i]['height'] = subjht[i]# hacky but will work for now
    if i==0:
        xfcss_train=xfcss_gttemp
    else:
        xfcss_train = pd.concat([xfcss_train,xfcss_gt[i]],axis=0)
del xfcss_gt

# %%
xfcss_train
# Out:
#        Fz bottom (kg)  Fz left (kg)  Fz right (kg)  Fx left (kg)  \
# 0           -0.828197     -0.189016      -0.198197      0.150164
# 1           -0.824918     -0.189836      -0.200328      0.150164
# 2           -0.822623     -0.191148      -0.202787      0.149836
# 3           -0.821148     -0.192787      -0.204590      0.150000
# 4           -0.821148     -0.194098      -0.206393      0.149836
# ...               ...           ...            ...           ...
# 23050       -0.710714     -0.272571      -0.248571      0.164429
# 23051       -0.711143     -0.269857      -0.248286      0.165571
# 23052       -0.710714     -0.266286      -0.248429      0.166143
# 23053       -0.710286     -0.263000      -0.248857      0.167143
# 23054       -0.710429     -0.260143      -0.249143      0.168429
#
#        Fx right (kg)   Fy (kg)
# 0           0.196066  0.003934
# 1           0.194918  0.003115
# 2           0.194262  0.002623
# 3           0.194918  0.002295
# 4           0.196557  0.002295
# ...              ...       ...
# 23050       0.182571  0.005857
# 23051       0.178714  0.007000
# 23052       0.174000  0.007714
# 23053       0.169857  0.008000
# 23054       0.165857  0.007429
#
# [153421 rows x 6 columns]

# %% [markdown]
# # Read Output Data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
#     data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    qtm_file_data_dir = os.path.join(data_dir , 'qtm_processed_'+subj[i]+'_test' + str(n_test[i]) + '_' + date[i] + '.txt')
    y_gt[i] = read_output_data(qtm_file_data_dir,theta_interest).values

    

# tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
# y_train = np.zeros((tlen,1))
# xrun = len(y_gt[0])
# y_train[:xrun] = y_gt[0][:xrun]
# xrun1 = xrun + len(y_gt[1])
# y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
# xrun2 = xrun1 + len(y_gt[2])
# y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
# xrun3 = xrun2 + len(y_gt[3])
# y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
# xrun4 = xrun3 + len(y_gt[4])
# y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
# xrun5 = xrun4 + len(y_gt[5])
# y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]
# del y_gt

# %%
tlen=0
for x in range(len(y_gt)):
    tlen+= y_gt[x].shape[0]
yrun_cum = 0
y_train = np.zeros((tlen,1))
for i in range (len(y_gt)):
    yrun_n = len(y_gt[i])
    y_train[yrun_cum:yrun_cum+yrun_n] = y_gt[i][:]
    yrun_cum += yrun_n

# %%
# Saturate output
def saturate(theta, min_val, max_val):
    for i in range(len(theta)):
        if theta[i] < min_val:
            theta[i] = min_val
            continue
        if theta[i] > max_val:
            theta[i] = max_val
            continue
    return theta
            
min_val = -50
max_val = 50
    
y_train = saturate(y_train, min_val, max_val)

# %%
print(x_train.shape)
print(xfcss_train.shape)
print(y_train.shape)
# Out:
# (153421, 60, 80, 3)
# (153421, 6)
# (153421, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Trainset2 = xfcss_train.values[rannums,:]
Testset = x_train[test_set,:]
Testset2 = xfcss_train.values[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_X2 = StandardScaler()
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
Xtrainz2 = Trainset2
ytrainz = Trainy
X = Xtrainz
X2 = sc_X2.fit_transform(Xtrainz2)
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset
Xvalid2 = sc_X2.transform(Testset2)
y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
# clear up some used variables
del Trainset
del Trainset2
del Testset
del Testset2

# %% [markdown]
# # Regress using Neural Network

# %%
x_train.shape

# %%
# Create Neural Netowrk

from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, concatenate, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute, Flatten
from tensorflow.keras.models import Model
dropout_rate = 0.2

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_start2 = Input(shape=(xfcss_train.shape[1],))
model_cnn = model_start
model_perc = model_start2

model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(32)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

# model_perc = Dense(32)(model_perc)
# model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Flatten()(model_cnn)
# model_perc = Flatten()(model_perc)
# model_cnn = Activation('relu')(model_cnn)

# model_cnn = Dense(128)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_comb = concatenate([model_cnn,model_perc],axis=-1)

model_comb = Dense(256)(model_comb)
# model_comb = BatchNormalization()(model_comb)
model_comb = Activation('relu')(model_comb)
model_comb = Dropout(dropout_rate)(model_comb)

output = Dense(1)(model_comb)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=[model_start,model_start2],outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50,restore_best_weights=True) #Moving to 1000 patience.

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 80, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 80, 8)    224         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 60, 80, 8)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 40, 8)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 30, 40, 16)   1168        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 40, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 15, 20, 16)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 15, 20, 32)   4640        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 15, 20, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 10, 32)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 10, 64)    18496       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 7, 10, 64)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 3, 5, 64)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           224         input_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 960)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 992)          0           flatten[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          254208      concatenate[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dropout[0][0]
# __________________________________________________________________________________________________
# thetaz_out (Activation)         (None, 1)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 279,217
# Trainable params: 279,217
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print(tf.__version__)
# Out:
# 2.3.1

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# # create data generator
# def get_generator_cyclic(features1, features2, labels, batch_size=256):
#     while True:
#         for n in range(int(len(features1)/batch_size)):
#             yield [features1[n*batch_size: (n+1)*batch_size]/255., features2[n*batch_size: (n+1)*batch_size], labels[n*batch_size: (n+1)*batch_size]]
#         permuted = np.random.permutation(len(features1))
#         features1 = features1[permuted]
#         features2 = features2[permuted]
#         labels = labels[permuted]

# %%
# x1, x2, y = next(training_generator)
# plt.imshow(x1[0])

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# image_data_gen = ImageDataGenerator(rescale=1/255.,height_shift_range=0.2, fill_mode='nearest')

# %%
epochs = int(30000)
batch_size = 256
# training_generator = get_generator_cyclic(Xtrainz, Xtrainz2, ytrainz, batch_size=batch_size)
history = model.fit([X/255.,X2], y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = ([Xvalid/255.,Xvalid2], y_valid),verbose=2)
# history = model.fit_generator(get_generator_cyclic(Xtrainz, Xtrainz2, ytrainz, batch_size=batch_size))


# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Epoch 1/30000
# 480/480 - 13s - loss: 0.5328 - mse: 0.6398 - mae: 0.5328 - val_loss: 0.4840 - val_mse: 0.5434 - val_mae: 0.4840
# Epoch 2/30000
# 480/480 - 12s - loss: 0.4548 - mse: 0.4960 - mae: 0.4548 - val_loss: 0.4235 - val_mse: 0.4544 - val_mae: 0.4235
# Epoch 3/30000
# 480/480 - 12s - loss: 0.4155 - mse: 0.4310 - mae: 0.4155 - val_loss: 0.3972 - val_mse: 0.4063 - val_mae: 0.3972
# Epoch 4/30000
# 480/480 - 12s - loss: 0.3826 - mse: 0.3786 - mae: 0.3826 - val_loss: 0.3717 - val_mse: 0.3664 - val_mae: 0.3717
# Epoch 5/30000
# 480/480 - 12s - loss: 0.3602 - mse: 0.3446 - mae: 0.3602 - val_loss: 0.3475 - val_mse: 0.3311 - val_mae: 0.3475
# Epoch 6/30000
# 480/480 - 12s - loss: 0.3415 - mse: 0.3193 - mae: 0.3415 - val_loss: 0.3295 - val_mse: 0.3090 - val_mae: 0.3295
# Epoch 7/30000
# 480/480 - 12s - loss: 0.3290 - mse: 0.3016 - mae: 0.3290 - val_loss: 0.3142 - val_mse: 0.2899 - val_mae: 0.3142
# Epoch 8/30000
# 480/480 - 12s - loss: 0.3158 - mse: 0.2845 - mae: 0.3158 - val_loss: 0.3080 - val_mse: 0.2801 - val_mae: 0.3080
# Epoch 9/30000
# 480/480 - 12s - loss: 0.3056 - mse: 0.2721 - mae: 0.3056 - val_loss: 0.2956 - val_mse: 0.2663 - val_mae: 0.2956
# Epoch 10/30000
# 480/480 - 12s - loss: 0.2980 - mse: 0.2612 - mae: 0.2980 - val_loss: 0.2844 - val_mse: 0.2525 - val_mae: 0.2844
# Epoch 11/30000
# 480/480 - 12s - loss: 0.2898 - mse: 0.2513 - mae: 0.2898 - val_loss: 0.2852 - val_mse: 0.2506 - val_mae: 0.2852
# Epoch 12/30000
# 480/480 - 12s - loss: 0.2826 - mse: 0.2422 - mae: 0.2826 - val_loss: 0.2735 - val_mse: 0.2402 - val_mae: 0.2735
# Epoch 13/30000
# 480/480 - 12s - loss: 0.2765 - mse: 0.2342 - mae: 0.2765 - val_loss: 0.2705 - val_mse: 0.2342 - val_mae: 0.2705
# Epoch 14/30000
# 480/480 - 12s - loss: 0.2708 - mse: 0.2265 - mae: 0.2708 - val_loss: 0.2642 - val_mse: 0.2276 - val_mae: 0.2642
# Epoch 15/30000
# 480/480 - 12s - loss: 0.2646 - mse: 0.2196 - mae: 0.2646 - val_loss: 0.2538 - val_mse: 0.2164 - val_mae: 0.2538
# Epoch 16/30000
# 480/480 - 12s - loss: 0.2609 - mse: 0.2141 - mae: 0.2609 - val_loss: 0.2523 - val_mse: 0.2114 - val_mae: 0.2523
# Epoch 17/30000
# 480/480 - 12s - loss: 0.2558 - mse: 0.2086 - mae: 0.2558 - val_loss: 0.2547 - val_mse: 0.2147 - val_mae: 0.2547
# Epoch 18/30000
# 480/480 - 12s - loss: 0.2524 - mse: 0.2043 - mae: 0.2524 - val_loss: 0.2465 - val_mse: 0.2061 - val_mae: 0.2465
# Epoch 19/30000
# 480/480 - 12s - loss: 0.2481 - mse: 0.1989 - mae: 0.2481 - val_loss: 0.2434 - val_mse: 0.2030 - val_mae: 0.2434
# Epoch 20/30000
# 480/480 - 12s - loss: 0.2440 - mse: 0.1943 - mae: 0.2440 - val_loss: 0.2372 - val_mse: 0.1959 - val_mae: 0.2372
# Epoch 21/30000
# 480/480 - 12s - loss: 0.2402 - mse: 0.1892 - mae: 0.2402 - val_loss: 0.2403 - val_mse: 0.1987 - val_mae: 0.2403
# Epoch 22/30000
# 480/480 - 12s - loss: 0.2380 - mse: 0.1860 - mae: 0.2380 - val_loss: 0.2360 - val_mse: 0.1924 - val_mae: 0.2360
# Epoch 23/30000
# 480/480 - 12s - loss: 0.2345 - mse: 0.1821 - mae: 0.2345 - val_loss: 0.2298 - val_mse: 0.1865 - val_mae: 0.2298
# Epoch 24/30000
# 480/480 - 12s - loss: 0.2316 - mse: 0.1789 - mae: 0.2316 - val_loss: 0.2236 - val_mse: 0.1806 - val_mae: 0.2236
# Epoch 25/30000
# 480/480 - 12s - loss: 0.2288 - mse: 0.1754 - mae: 0.2288 - val_loss: 0.2203 - val_mse: 0.1772 - val_mae: 0.2203
# Epoch 26/30000
# 480/480 - 12s - loss: 0.2272 - mse: 0.1737 - mae: 0.2272 - val_loss: 0.2233 - val_mse: 0.1795 - val_mae: 0.2233
# Epoch 27/30000
# 480/480 - 12s - loss: 0.2244 - mse: 0.1701 - mae: 0.2244 - val_loss: 0.2211 - val_mse: 0.1750 - val_mae: 0.2211
# Epoch 28/30000
# 480/480 - 12s - loss: 0.2216 - mse: 0.1670 - mae: 0.2216 - val_loss: 0.2184 - val_mse: 0.1733 - val_mae: 0.2184
# Epoch 29/30000
# 480/480 - 12s - loss: 0.2193 - mse: 0.1645 - mae: 0.2193 - val_loss: 0.2122 - val_mse: 0.1686 - val_mae: 0.2122
# Epoch 30/30000
# 480/480 - 12s - loss: 0.2177 - mse: 0.1627 - mae: 0.2177 - val_loss: 0.2119 - val_mse: 0.1669 - val_mae: 0.2119
# Epoch 31/30000
# 480/480 - 12s - loss: 0.2152 - mse: 0.1600 - mae: 0.2152 - val_loss: 0.2086 - val_mse: 0.1638 - val_mae: 0.2086
# Epoch 32/30000
# 480/480 - 12s - loss: 0.2127 - mse: 0.1574 - mae: 0.2127 - val_loss: 0.2063 - val_mse: 0.1627 - val_mae: 0.2063
# Epoch 33/30000
# 480/480 - 12s - loss: 0.2117 - mse: 0.1566 - mae: 0.2117 - val_loss: 0.2147 - val_mse: 0.1682 - val_mae: 0.2147
# Epoch 34/30000
# 480/480 - 12s - loss: 0.2098 - mse: 0.1540 - mae: 0.2098 - val_loss: 0.2042 - val_mse: 0.1587 - val_mae: 0.2042
# Epoch 35/30000
# 480/480 - 12s - loss: 0.2077 - mse: 0.1525 - mae: 0.2077 - val_loss: 0.2034 - val_mse: 0.1584 - val_mae: 0.2034
# Epoch 36/30000
# 480/480 - 12s - loss: 0.2068 - mse: 0.1507 - mae: 0.2068 - val_loss: 0.2061 - val_mse: 0.1591 - val_mae: 0.2061
# Epoch 37/30000
# 480/480 - 12s - loss: 0.2045 - mse: 0.1488 - mae: 0.2045 - val_loss: 0.2014 - val_mse: 0.1560 - val_mae: 0.2014
# Epoch 38/30000
# 480/480 - 12s - loss: 0.2028 - mse: 0.1469 - mae: 0.2028 - val_loss: 0.2066 - val_mse: 0.1583 - val_mae: 0.2066
# Epoch 39/30000
# 480/480 - 12s - loss: 0.2009 - mse: 0.1451 - mae: 0.2009 - val_loss: 0.1993 - val_mse: 0.1528 - val_mae: 0.1993
# Epoch 40/30000
# 480/480 - 12s - loss: 0.2001 - mse: 0.1437 - mae: 0.2001 - val_loss: 0.1981 - val_mse: 0.1523 - val_mae: 0.1981
# Epoch 41/30000
# 480/480 - 12s - loss: 0.1989 - mse: 0.1423 - mae: 0.1989 - val_loss: 0.2006 - val_mse: 0.1539 - val_mae: 0.2006
# Epoch 42/30000
# 480/480 - 12s - loss: 0.1973 - mse: 0.1411 - mae: 0.1973 - val_loss: 0.1969 - val_mse: 0.1502 - val_mae: 0.1969
# Epoch 43/30000
# 480/480 - 12s - loss: 0.1956 - mse: 0.1394 - mae: 0.1956 - val_loss: 0.1941 - val_mse: 0.1470 - val_mae: 0.1941
# Epoch 44/30000
# 480/480 - 12s - loss: 0.1952 - mse: 0.1382 - mae: 0.1952 - val_loss: 0.1911 - val_mse: 0.1452 - val_mae: 0.1911
# Epoch 45/30000
# 480/480 - 12s - loss: 0.1941 - mse: 0.1372 - mae: 0.1941 - val_loss: 0.1928 - val_mse: 0.1473 - val_mae: 0.1928
# Epoch 46/30000
# 480/480 - 12s - loss: 0.1920 - mse: 0.1354 - mae: 0.1920 - val_loss: 0.1900 - val_mse: 0.1453 - val_mae: 0.1900
# Epoch 47/30000
# 480/480 - 12s - loss: 0.1914 - mse: 0.1342 - mae: 0.1914 - val_loss: 0.1891 - val_mse: 0.1434 - val_mae: 0.1891
# Epoch 48/30000
# 480/480 - 12s - loss: 0.1907 - mse: 0.1337 - mae: 0.1907 - val_loss: 0.1890 - val_mse: 0.1422 - val_mae: 0.1890
# Epoch 49/30000
# 480/480 - 12s - loss: 0.1889 - mse: 0.1321 - mae: 0.1889 - val_loss: 0.1861 - val_mse: 0.1413 - val_mae: 0.1861
# Epoch 50/30000
# 480/480 - 12s - loss: 0.1882 - mse: 0.1318 - mae: 0.1882 - val_loss: 0.1880 - val_mse: 0.1411 - val_mae: 0.1880
# Epoch 51/30000
# 480/480 - 12s - loss: 0.1876 - mse: 0.1304 - mae: 0.1876 - val_loss: 0.1865 - val_mse: 0.1400 - val_mae: 0.1865
# Epoch 52/30000
# 480/480 - 12s - loss: 0.1866 - mse: 0.1300 - mae: 0.1866 - val_loss: 0.1853 - val_mse: 0.1391 - val_mae: 0.1853
# Epoch 53/30000
# 480/480 - 12s - loss: 0.1854 - mse: 0.1291 - mae: 0.1854 - val_loss: 0.1851 - val_mse: 0.1403 - val_mae: 0.1851
# Epoch 54/30000
# 480/480 - 12s - loss: 0.1840 - mse: 0.1275 - mae: 0.1840 - val_loss: 0.1852 - val_mse: 0.1395 - val_mae: 0.1852
# Epoch 55/30000
# 480/480 - 12s - loss: 0.1844 - mse: 0.1274 - mae: 0.1844 - val_loss: 0.1821 - val_mse: 0.1360 - val_mae: 0.1821
# Epoch 56/30000
# 480/480 - 12s - loss: 0.1834 - mse: 0.1263 - mae: 0.1834 - val_loss: 0.1893 - val_mse: 0.1411 - val_mae: 0.1893
# Epoch 57/30000
# 480/480 - 12s - loss: 0.1822 - mse: 0.1252 - mae: 0.1822 - val_loss: 0.1797 - val_mse: 0.1347 - val_mae: 0.1797
# Epoch 58/30000
# 480/480 - 12s - loss: 0.1813 - mse: 0.1250 - mae: 0.1813 - val_loss: 0.1790 - val_mse: 0.1338 - val_mae: 0.1790
# Epoch 59/30000
# 480/480 - 12s - loss: 0.1798 - mse: 0.1234 - mae: 0.1798 - val_loss: 0.1793 - val_mse: 0.1344 - val_mae: 0.1793
# Epoch 60/30000
# 480/480 - 12s - loss: 0.1790 - mse: 0.1226 - mae: 0.1790 - val_loss: 0.1807 - val_mse: 0.1341 - val_mae: 0.1807
# Epoch 61/30000
# 480/480 - 12s - loss: 0.1787 - mse: 0.1223 - mae: 0.1787 - val_loss: 0.1793 - val_mse: 0.1337 - val_mae: 0.1793
# Epoch 62/30000
# 480/480 - 12s - loss: 0.1784 - mse: 0.1217 - mae: 0.1784 - val_loss: 0.1808 - val_mse: 0.1344 - val_mae: 0.1808
# Epoch 63/30000
# 480/480 - 12s - loss: 0.1770 - mse: 0.1205 - mae: 0.1770 - val_loss: 0.1792 - val_mse: 0.1327 - val_mae: 0.1792
# Epoch 64/30000
# 480/480 - 12s - loss: 0.1778 - mse: 0.1215 - mae: 0.1778 - val_loss: 0.1772 - val_mse: 0.1314 - val_mae: 0.1772
# Epoch 65/30000
# 480/480 - 12s - loss: 0.1769 - mse: 0.1198 - mae: 0.1769 - val_loss: 0.1766 - val_mse: 0.1315 - val_mae: 0.1766
# Epoch 66/30000
# 480/480 - 12s - loss: 0.1750 - mse: 0.1188 - mae: 0.1750 - val_loss: 0.1768 - val_mse: 0.1312 - val_mae: 0.1768
# Epoch 67/30000
# 480/480 - 12s - loss: 0.1740 - mse: 0.1177 - mae: 0.1740 - val_loss: 0.1807 - val_mse: 0.1326 - val_mae: 0.1807
# Epoch 68/30000
# 480/480 - 12s - loss: 0.1741 - mse: 0.1176 - mae: 0.1741 - val_loss: 0.1767 - val_mse: 0.1313 - val_mae: 0.1767
# Epoch 69/30000
# 480/480 - 12s - loss: 0.1730 - mse: 0.1172 - mae: 0.1730 - val_loss: 0.1700 - val_mse: 0.1262 - val_mae: 0.1700
# Epoch 70/30000
# 480/480 - 12s - loss: 0.1730 - mse: 0.1169 - mae: 0.1730 - val_loss: 0.1734 - val_mse: 0.1291 - val_mae: 0.1734
# Epoch 71/30000
# 480/480 - 12s - loss: 0.1721 - mse: 0.1164 - mae: 0.1721 - val_loss: 0.1785 - val_mse: 0.1302 - val_mae: 0.1785
# Epoch 72/30000
# 480/480 - 12s - loss: 0.1713 - mse: 0.1153 - mae: 0.1713 - val_loss: 0.1761 - val_mse: 0.1300 - val_mae: 0.1761
# Epoch 73/30000
# 480/480 - 12s - loss: 0.1709 - mse: 0.1149 - mae: 0.1709 - val_loss: 0.1704 - val_mse: 0.1266 - val_mae: 0.1704
# Epoch 74/30000
# 480/480 - 12s - loss: 0.1711 - mse: 0.1151 - mae: 0.1711 - val_loss: 0.1738 - val_mse: 0.1275 - val_mae: 0.1738
# Epoch 75/30000
# 480/480 - 12s - loss: 0.1695 - mse: 0.1136 - mae: 0.1695 - val_loss: 0.1713 - val_mse: 0.1260 - val_mae: 0.1713
# Epoch 76/30000
# 480/480 - 12s - loss: 0.1692 - mse: 0.1133 - mae: 0.1692 - val_loss: 0.1705 - val_mse: 0.1269 - val_mae: 0.1705
# Epoch 77/30000
# 480/480 - 12s - loss: 0.1688 - mse: 0.1129 - mae: 0.1688 - val_loss: 0.1688 - val_mse: 0.1253 - val_mae: 0.1688
# Epoch 78/30000
# 480/480 - 12s - loss: 0.1685 - mse: 0.1130 - mae: 0.1685 - val_loss: 0.1692 - val_mse: 0.1259 - val_mae: 0.1692
# Epoch 79/30000
# 480/480 - 12s - loss: 0.1671 - mse: 0.1118 - mae: 0.1671 - val_loss: 0.1730 - val_mse: 0.1266 - val_mae: 0.1730
# Epoch 80/30000
# 480/480 - 12s - loss: 0.1680 - mse: 0.1123 - mae: 0.1680 - val_loss: 0.1703 - val_mse: 0.1249 - val_mae: 0.1703
# Epoch 81/30000
# 480/480 - 12s - loss: 0.1664 - mse: 0.1113 - mae: 0.1664 - val_loss: 0.1709 - val_mse: 0.1252 - val_mae: 0.1709
# Epoch 82/30000
# 480/480 - 12s - loss: 0.1663 - mse: 0.1108 - mae: 0.1663 - val_loss: 0.1720 - val_mse: 0.1269 - val_mae: 0.1720
# Epoch 83/30000
# 480/480 - 12s - loss: 0.1663 - mse: 0.1112 - mae: 0.1663 - val_loss: 0.1738 - val_mse: 0.1276 - val_mae: 0.1738
# Epoch 84/30000
# 480/480 - 12s - loss: 0.1660 - mse: 0.1101 - mae: 0.1660 - val_loss: 0.1649 - val_mse: 0.1212 - val_mae: 0.1649
# Epoch 85/30000
# 480/480 - 14s - loss: 0.1645 - mse: 0.1090 - mae: 0.1645 - val_loss: 0.1674 - val_mse: 0.1225 - val_mae: 0.1674
# Epoch 86/30000
# 480/480 - 12s - loss: 0.1648 - mse: 0.1094 - mae: 0.1648 - val_loss: 0.1674 - val_mse: 0.1227 - val_mae: 0.1674
# Epoch 87/30000
# 480/480 - 12s - loss: 0.1637 - mse: 0.1086 - mae: 0.1637 - val_loss: 0.1690 - val_mse: 0.1238 - val_mae: 0.1690
# Epoch 88/30000
# 480/480 - 12s - loss: 0.1635 - mse: 0.1081 - mae: 0.1635 - val_loss: 0.1667 - val_mse: 0.1223 - val_mae: 0.1667
# Epoch 89/30000
# 480/480 - 12s - loss: 0.1635 - mse: 0.1087 - mae: 0.1635 - val_loss: 0.1672 - val_mse: 0.1216 - val_mae: 0.1672
# Epoch 90/30000
# 480/480 - 12s - loss: 0.1625 - mse: 0.1072 - mae: 0.1625 - val_loss: 0.1667 - val_mse: 0.1217 - val_mae: 0.1667
# Epoch 91/30000
# 480/480 - 12s - loss: 0.1622 - mse: 0.1079 - mae: 0.1622 - val_loss: 0.1654 - val_mse: 0.1216 - val_mae: 0.1654
# Epoch 92/30000
# 480/480 - 12s - loss: 0.1622 - mse: 0.1072 - mae: 0.1622 - val_loss: 0.1655 - val_mse: 0.1213 - val_mae: 0.1655
# Epoch 93/30000
# 480/480 - 12s - loss: 0.1619 - mse: 0.1070 - mae: 0.1619 - val_loss: 0.1648 - val_mse: 0.1210 - val_mae: 0.1648
# Epoch 94/30000
# 480/480 - 12s - loss: 0.1614 - mse: 0.1064 - mae: 0.1614 - val_loss: 0.1658 - val_mse: 0.1205 - val_mae: 0.1658
# Epoch 95/30000
# 480/480 - 12s - loss: 0.1607 - mse: 0.1062 - mae: 0.1607 - val_loss: 0.1651 - val_mse: 0.1193 - val_mae: 0.1651
# Epoch 96/30000
# 480/480 - 12s - loss: 0.1607 - mse: 0.1056 - mae: 0.1607 - val_loss: 0.1626 - val_mse: 0.1186 - val_mae: 0.1626
# Epoch 97/30000
# 480/480 - 12s - loss: 0.1602 - mse: 0.1051 - mae: 0.1602 - val_loss: 0.1648 - val_mse: 0.1199 - val_mae: 0.1648
# Epoch 98/30000
# 480/480 - 12s - loss: 0.1597 - mse: 0.1046 - mae: 0.1597 - val_loss: 0.1629 - val_mse: 0.1184 - val_mae: 0.1629
# Epoch 99/30000
# 480/480 - 12s - loss: 0.1601 - mse: 0.1049 - mae: 0.1601 - val_loss: 0.1602 - val_mse: 0.1170 - val_mae: 0.1602
# Epoch 100/30000
# 480/480 - 12s - loss: 0.1591 - mse: 0.1045 - mae: 0.1591 - val_loss: 0.1635 - val_mse: 0.1191 - val_mae: 0.1635
# Epoch 101/30000
# 480/480 - 12s - loss: 0.1585 - mse: 0.1039 - mae: 0.1585 - val_loss: 0.1618 - val_mse: 0.1181 - val_mae: 0.1618
# Epoch 102/30000
# 480/480 - 12s - loss: 0.1582 - mse: 0.1035 - mae: 0.1582 - val_loss: 0.1638 - val_mse: 0.1190 - val_mae: 0.1638
# Epoch 103/30000
# 480/480 - 12s - loss: 0.1578 - mse: 0.1035 - mae: 0.1578 - val_loss: 0.1595 - val_mse: 0.1168 - val_mae: 0.1595
# Epoch 104/30000
# 480/480 - 12s - loss: 0.1579 - mse: 0.1032 - mae: 0.1579 - val_loss: 0.1593 - val_mse: 0.1160 - val_mae: 0.1593
# Epoch 105/30000
# 480/480 - 12s - loss: 0.1576 - mse: 0.1028 - mae: 0.1576 - val_loss: 0.1640 - val_mse: 0.1195 - val_mae: 0.1640
# Epoch 106/30000
# 480/480 - 12s - loss: 0.1576 - mse: 0.1024 - mae: 0.1576 - val_loss: 0.1588 - val_mse: 0.1159 - val_mae: 0.1588
# Epoch 107/30000
# 480/480 - 12s - loss: 0.1568 - mse: 0.1023 - mae: 0.1568 - val_loss: 0.1604 - val_mse: 0.1155 - val_mae: 0.1604
# Epoch 108/30000
# 480/480 - 12s - loss: 0.1564 - mse: 0.1018 - mae: 0.1564 - val_loss: 0.1616 - val_mse: 0.1159 - val_mae: 0.1616
# Epoch 109/30000
# 480/480 - 12s - loss: 0.1562 - mse: 0.1012 - mae: 0.1562 - val_loss: 0.1597 - val_mse: 0.1147 - val_mae: 0.1597
# Epoch 110/30000
# 480/480 - 12s - loss: 0.1554 - mse: 0.1010 - mae: 0.1554 - val_loss: 0.1602 - val_mse: 0.1150 - val_mae: 0.1602
# Epoch 111/30000
# 480/480 - 12s - loss: 0.1549 - mse: 0.1004 - mae: 0.1549 - val_loss: 0.1598 - val_mse: 0.1148 - val_mae: 0.1598
# Epoch 112/30000
# 480/480 - 12s - loss: 0.1557 - mse: 0.1008 - mae: 0.1557 - val_loss: 0.1570 - val_mse: 0.1142 - val_mae: 0.1570
# Epoch 113/30000
# 480/480 - 12s - loss: 0.1544 - mse: 0.0997 - mae: 0.1544 - val_loss: 0.1587 - val_mse: 0.1138 - val_mae: 0.1587
# Epoch 114/30000
# 480/480 - 12s - loss: 0.1545 - mse: 0.1001 - mae: 0.1545 - val_loss: 0.1606 - val_mse: 0.1151 - val_mae: 0.1606
# Epoch 115/30000
# 480/480 - 12s - loss: 0.1544 - mse: 0.0992 - mae: 0.1544 - val_loss: 0.1566 - val_mse: 0.1126 - val_mae: 0.1566
# Epoch 116/30000
# 480/480 - 12s - loss: 0.1532 - mse: 0.0984 - mae: 0.1532 - val_loss: 0.1612 - val_mse: 0.1148 - val_mae: 0.1612
# Epoch 117/30000
# 480/480 - 12s - loss: 0.1539 - mse: 0.0991 - mae: 0.1539 - val_loss: 0.1616 - val_mse: 0.1149 - val_mae: 0.1616
# Epoch 118/30000
# 480/480 - 12s - loss: 0.1535 - mse: 0.0981 - mae: 0.1535 - val_loss: 0.1597 - val_mse: 0.1140 - val_mae: 0.1597
# Epoch 119/30000
# 480/480 - 12s - loss: 0.1534 - mse: 0.0983 - mae: 0.1534 - val_loss: 0.1577 - val_mse: 0.1125 - val_mae: 0.1577
# Epoch 120/30000
# 480/480 - 12s - loss: 0.1522 - mse: 0.0973 - mae: 0.1522 - val_loss: 0.1572 - val_mse: 0.1115 - val_mae: 0.1572
# Epoch 121/30000
# 480/480 - 12s - loss: 0.1525 - mse: 0.0973 - mae: 0.1525 - val_loss: 0.1570 - val_mse: 0.1108 - val_mae: 0.1570
# Epoch 122/30000
# 480/480 - 12s - loss: 0.1522 - mse: 0.0967 - mae: 0.1522 - val_loss: 0.1587 - val_mse: 0.1122 - val_mae: 0.1587
# Epoch 123/30000
# 480/480 - 12s - loss: 0.1524 - mse: 0.0970 - mae: 0.1524 - val_loss: 0.1551 - val_mse: 0.1106 - val_mae: 0.1551
# Epoch 124/30000
# 480/480 - 12s - loss: 0.1518 - mse: 0.0969 - mae: 0.1518 - val_loss: 0.1558 - val_mse: 0.1106 - val_mae: 0.1558
# Epoch 125/30000
# 480/480 - 12s - loss: 0.1509 - mse: 0.0959 - mae: 0.1509 - val_loss: 0.1582 - val_mse: 0.1117 - val_mae: 0.1582
# Epoch 126/30000
# 480/480 - 12s - loss: 0.1515 - mse: 0.0959 - mae: 0.1515 - val_loss: 0.1556 - val_mse: 0.1090 - val_mae: 0.1556
# Epoch 127/30000
# 480/480 - 12s - loss: 0.1513 - mse: 0.0954 - mae: 0.1513 - val_loss: 0.1562 - val_mse: 0.1108 - val_mae: 0.1562
# Epoch 128/30000
# 480/480 - 12s - loss: 0.1508 - mse: 0.0952 - mae: 0.1508 - val_loss: 0.1555 - val_mse: 0.1090 - val_mae: 0.1555
# Epoch 129/30000
# 480/480 - 12s - loss: 0.1505 - mse: 0.0949 - mae: 0.1505 - val_loss: 0.1544 - val_mse: 0.1085 - val_mae: 0.1544
# Epoch 130/30000
# 480/480 - 12s - loss: 0.1498 - mse: 0.0941 - mae: 0.1498 - val_loss: 0.1644 - val_mse: 0.1130 - val_mae: 0.1644
# Epoch 131/30000
# 480/480 - 12s - loss: 0.1501 - mse: 0.0942 - mae: 0.1501 - val_loss: 0.1541 - val_mse: 0.1083 - val_mae: 0.1541
# Epoch 132/30000
# 480/480 - 12s - loss: 0.1497 - mse: 0.0935 - mae: 0.1497 - val_loss: 0.1567 - val_mse: 0.1089 - val_mae: 0.1567
# Epoch 133/30000
# 480/480 - 12s - loss: 0.1489 - mse: 0.0929 - mae: 0.1489 - val_loss: 0.1546 - val_mse: 0.1079 - val_mae: 0.1546
# Epoch 134/30000
# 480/480 - 12s - loss: 0.1495 - mse: 0.0934 - mae: 0.1495 - val_loss: 0.1566 - val_mse: 0.1091 - val_mae: 0.1566
# Epoch 135/30000
# 480/480 - 12s - loss: 0.1482 - mse: 0.0924 - mae: 0.1482 - val_loss: 0.1550 - val_mse: 0.1077 - val_mae: 0.1550
# Epoch 136/30000
# 480/480 - 12s - loss: 0.1484 - mse: 0.0921 - mae: 0.1484 - val_loss: 0.1562 - val_mse: 0.1089 - val_mae: 0.1562
# Epoch 137/30000
# 480/480 - 12s - loss: 0.1481 - mse: 0.0919 - mae: 0.1481 - val_loss: 0.1509 - val_mse: 0.1053 - val_mae: 0.1509
# Epoch 138/30000
# 480/480 - 12s - loss: 0.1481 - mse: 0.0921 - mae: 0.1481 - val_loss: 0.1603 - val_mse: 0.1097 - val_mae: 0.1603
# Epoch 139/30000
# 480/480 - 12s - loss: 0.1479 - mse: 0.0916 - mae: 0.1479 - val_loss: 0.1541 - val_mse: 0.1071 - val_mae: 0.1541
# Epoch 140/30000
# 480/480 - 12s - loss: 0.1474 - mse: 0.0910 - mae: 0.1474 - val_loss: 0.1539 - val_mse: 0.1070 - val_mae: 0.1539
# Epoch 141/30000
# 480/480 - 12s - loss: 0.1471 - mse: 0.0906 - mae: 0.1471 - val_loss: 0.1547 - val_mse: 0.1071 - val_mae: 0.1547
# Epoch 142/30000
# 480/480 - 12s - loss: 0.1467 - mse: 0.0907 - mae: 0.1467 - val_loss: 0.1549 - val_mse: 0.1076 - val_mae: 0.1549
# Epoch 143/30000
# 480/480 - 12s - loss: 0.1467 - mse: 0.0906 - mae: 0.1467 - val_loss: 0.1542 - val_mse: 0.1069 - val_mae: 0.1542
# Epoch 144/30000
# 480/480 - 12s - loss: 0.1466 - mse: 0.0900 - mae: 0.1466 - val_loss: 0.1525 - val_mse: 0.1062 - val_mae: 0.1525
# Epoch 145/30000
# 480/480 - 12s - loss: 0.1467 - mse: 0.0899 - mae: 0.1467 - val_loss: 0.1548 - val_mse: 0.1071 - val_mae: 0.1548
# Epoch 146/30000
# 480/480 - 12s - loss: 0.1464 - mse: 0.0896 - mae: 0.1464 - val_loss: 0.1516 - val_mse: 0.1049 - val_mae: 0.1516
# Epoch 147/30000
# 480/480 - 12s - loss: 0.1461 - mse: 0.0896 - mae: 0.1461 - val_loss: 0.1537 - val_mse: 0.1053 - val_mae: 0.1537
# Epoch 148/30000
# 480/480 - 12s - loss: 0.1463 - mse: 0.0896 - mae: 0.1463 - val_loss: 0.1495 - val_mse: 0.1030 - val_mae: 0.1495
# Epoch 149/30000
# 480/480 - 12s - loss: 0.1461 - mse: 0.0889 - mae: 0.1461 - val_loss: 0.1522 - val_mse: 0.1056 - val_mae: 0.1522
# Epoch 150/30000
# 480/480 - 12s - loss: 0.1457 - mse: 0.0888 - mae: 0.1457 - val_loss: 0.1493 - val_mse: 0.1028 - val_mae: 0.1493
# Epoch 151/30000
# 480/480 - 12s - loss: 0.1446 - mse: 0.0882 - mae: 0.1446 - val_loss: 0.1521 - val_mse: 0.1040 - val_mae: 0.1521
# Epoch 152/30000
# 480/480 - 12s - loss: 0.1448 - mse: 0.0881 - mae: 0.1448 - val_loss: 0.1544 - val_mse: 0.1059 - val_mae: 0.1544
# Epoch 153/30000
# 480/480 - 12s - loss: 0.1445 - mse: 0.0876 - mae: 0.1445 - val_loss: 0.1531 - val_mse: 0.1038 - val_mae: 0.1531
# Epoch 154/30000
# 480/480 - 12s - loss: 0.1443 - mse: 0.0875 - mae: 0.1443 - val_loss: 0.1518 - val_mse: 0.1034 - val_mae: 0.1518
# Epoch 155/30000
# 480/480 - 12s - loss: 0.1440 - mse: 0.0872 - mae: 0.1440 - val_loss: 0.1539 - val_mse: 0.1041 - val_mae: 0.1539
# Epoch 156/30000
# 480/480 - 12s - loss: 0.1442 - mse: 0.0865 - mae: 0.1442 - val_loss: 0.1532 - val_mse: 0.1035 - val_mae: 0.1532
# Epoch 157/30000
# 480/480 - 12s - loss: 0.1446 - mse: 0.0867 - mae: 0.1446 - val_loss: 0.1527 - val_mse: 0.1035 - val_mae: 0.1527
# Epoch 158/30000
# 480/480 - 12s - loss: 0.1440 - mse: 0.0868 - mae: 0.1440 - val_loss: 0.1522 - val_mse: 0.1038 - val_mae: 0.1522
# Epoch 159/30000
# 480/480 - 12s - loss: 0.1437 - mse: 0.0858 - mae: 0.1437 - val_loss: 0.1519 - val_mse: 0.1040 - val_mae: 0.1519
# Epoch 160/30000
# 480/480 - 12s - loss: 0.1438 - mse: 0.0860 - mae: 0.1438 - val_loss: 0.1489 - val_mse: 0.1011 - val_mae: 0.1489
# Epoch 161/30000
# 480/480 - 12s - loss: 0.1439 - mse: 0.0857 - mae: 0.1439 - val_loss: 0.1516 - val_mse: 0.1027 - val_mae: 0.1516
# Epoch 162/30000
# 480/480 - 12s - loss: 0.1431 - mse: 0.0855 - mae: 0.1431 - val_loss: 0.1521 - val_mse: 0.1032 - val_mae: 0.1521
# Epoch 163/30000
# 480/480 - 12s - loss: 0.1426 - mse: 0.0850 - mae: 0.1426 - val_loss: 0.1493 - val_mse: 0.1018 - val_mae: 0.1493
# Epoch 164/30000
# 480/480 - 12s - loss: 0.1433 - mse: 0.0847 - mae: 0.1433 - val_loss: 0.1518 - val_mse: 0.1030 - val_mae: 0.1518
# Epoch 165/30000
# 480/480 - 12s - loss: 0.1435 - mse: 0.0854 - mae: 0.1435 - val_loss: 0.1504 - val_mse: 0.1010 - val_mae: 0.1504
# Epoch 166/30000
# 480/480 - 12s - loss: 0.1426 - mse: 0.0844 - mae: 0.1426 - val_loss: 0.1487 - val_mse: 0.1011 - val_mae: 0.1487
# Epoch 167/30000
# 480/480 - 12s - loss: 0.1430 - mse: 0.0842 - mae: 0.1430 - val_loss: 0.1545 - val_mse: 0.1031 - val_mae: 0.1545
# Epoch 168/30000
# 480/480 - 12s - loss: 0.1428 - mse: 0.0842 - mae: 0.1428 - val_loss: 0.1505 - val_mse: 0.1019 - val_mae: 0.1505
# Epoch 169/30000
# 480/480 - 12s - loss: 0.1419 - mse: 0.0829 - mae: 0.1419 - val_loss: 0.1480 - val_mse: 0.0999 - val_mae: 0.1480
# Epoch 170/30000
# 480/480 - 12s - loss: 0.1416 - mse: 0.0825 - mae: 0.1416 - val_loss: 0.1514 - val_mse: 0.1012 - val_mae: 0.1514
# Epoch 171/30000
# 480/480 - 12s - loss: 0.1422 - mse: 0.0829 - mae: 0.1422 - val_loss: 0.1488 - val_mse: 0.1019 - val_mae: 0.1488
# Epoch 172/30000
# 480/480 - 12s - loss: 0.1415 - mse: 0.0825 - mae: 0.1415 - val_loss: 0.1499 - val_mse: 0.0999 - val_mae: 0.1499
# Epoch 173/30000
# 480/480 - 12s - loss: 0.1405 - mse: 0.0807 - mae: 0.1405 - val_loss: 0.1506 - val_mse: 0.1012 - val_mae: 0.1506
# Epoch 174/30000
# 480/480 - 12s - loss: 0.1415 - mse: 0.0821 - mae: 0.1415 - val_loss: 0.1489 - val_mse: 0.0993 - val_mae: 0.1489
# Epoch 175/30000
# 480/480 - 12s - loss: 0.1410 - mse: 0.0818 - mae: 0.1410 - val_loss: 0.1476 - val_mse: 0.0985 - val_mae: 0.1476
# Epoch 176/30000
# 480/480 - 12s - loss: 0.1409 - mse: 0.0808 - mae: 0.1409 - val_loss: 0.1492 - val_mse: 0.0997 - val_mae: 0.1492
# Epoch 177/30000
# 480/480 - 12s - loss: 0.1406 - mse: 0.0810 - mae: 0.1406 - val_loss: 0.1495 - val_mse: 0.0992 - val_mae: 0.1495
# Epoch 178/30000
# 480/480 - 12s - loss: 0.1401 - mse: 0.0806 - mae: 0.1401 - val_loss: 0.1534 - val_mse: 0.1016 - val_mae: 0.1534
# Epoch 179/30000
# 480/480 - 12s - loss: 0.1400 - mse: 0.0796 - mae: 0.1400 - val_loss: 0.1471 - val_mse: 0.0979 - val_mae: 0.1471
# Epoch 180/30000
# 480/480 - 12s - loss: 0.1396 - mse: 0.0803 - mae: 0.1396 - val_loss: 0.1497 - val_mse: 0.0991 - val_mae: 0.1497
# Epoch 181/30000
# 480/480 - 12s - loss: 0.1407 - mse: 0.0806 - mae: 0.1407 - val_loss: 0.1487 - val_mse: 0.0981 - val_mae: 0.1487
# Epoch 182/30000
# 480/480 - 12s - loss: 0.1398 - mse: 0.0799 - mae: 0.1398 - val_loss: 0.1545 - val_mse: 0.1004 - val_mae: 0.1545
# Epoch 183/30000
# 480/480 - 12s - loss: 0.1394 - mse: 0.0802 - mae: 0.1394 - val_loss: 0.1464 - val_mse: 0.0967 - val_mae: 0.1464
# Epoch 184/30000
# 480/480 - 12s - loss: 0.1398 - mse: 0.0799 - mae: 0.1398 - val_loss: 0.1471 - val_mse: 0.0975 - val_mae: 0.1471
# Epoch 185/30000
# 480/480 - 12s - loss: 0.1392 - mse: 0.0798 - mae: 0.1392 - val_loss: 0.1517 - val_mse: 0.0998 - val_mae: 0.1517
# Epoch 186/30000
# 480/480 - 12s - loss: 0.1395 - mse: 0.0796 - mae: 0.1395 - val_loss: 0.1507 - val_mse: 0.0988 - val_mae: 0.1507
# Epoch 187/30000
# 480/480 - 12s - loss: 0.1390 - mse: 0.0791 - mae: 0.1390 - val_loss: 0.1455 - val_mse: 0.0962 - val_mae: 0.1455
# Epoch 188/30000
# 480/480 - 12s - loss: 0.1397 - mse: 0.0792 - mae: 0.1397 - val_loss: 0.1491 - val_mse: 0.1001 - val_mae: 0.1491
# Epoch 189/30000
# 480/480 - 12s - loss: 0.1385 - mse: 0.0792 - mae: 0.1385 - val_loss: 0.1465 - val_mse: 0.0968 - val_mae: 0.1465
# Epoch 190/30000
# 480/480 - 12s - loss: 0.1386 - mse: 0.0789 - mae: 0.1386 - val_loss: 0.1481 - val_mse: 0.0978 - val_mae: 0.1481
# Epoch 191/30000
# 480/480 - 12s - loss: 0.1379 - mse: 0.0783 - mae: 0.1379 - val_loss: 0.1489 - val_mse: 0.0979 - val_mae: 0.1489
# Epoch 192/30000
# 480/480 - 12s - loss: 0.1387 - mse: 0.0791 - mae: 0.1387 - val_loss: 0.1465 - val_mse: 0.0962 - val_mae: 0.1465
# Epoch 193/30000
# 480/480 - 12s - loss: 0.1381 - mse: 0.0784 - mae: 0.1381 - val_loss: 0.1516 - val_mse: 0.1008 - val_mae: 0.1516
# Epoch 194/30000
# 480/480 - 12s - loss: 0.1380 - mse: 0.0783 - mae: 0.1380 - val_loss: 0.1442 - val_mse: 0.0949 - val_mae: 0.1442
# Epoch 195/30000
# 480/480 - 12s - loss: 0.1376 - mse: 0.0784 - mae: 0.1376 - val_loss: 0.1464 - val_mse: 0.0978 - val_mae: 0.1464
# Epoch 196/30000
# 480/480 - 12s - loss: 0.1377 - mse: 0.0782 - mae: 0.1377 - val_loss: 0.1488 - val_mse: 0.0972 - val_mae: 0.1488
# Epoch 197/30000
# 480/480 - 12s - loss: 0.1379 - mse: 0.0781 - mae: 0.1379 - val_loss: 0.1454 - val_mse: 0.0953 - val_mae: 0.1454
# Epoch 198/30000
# 480/480 - 12s - loss: 0.1376 - mse: 0.0776 - mae: 0.1376 - val_loss: 0.1465 - val_mse: 0.0962 - val_mae: 0.1465
# Epoch 199/30000
# 480/480 - 12s - loss: 0.1372 - mse: 0.0781 - mae: 0.1372 - val_loss: 0.1450 - val_mse: 0.0955 - val_mae: 0.1450
# Epoch 200/30000
# 480/480 - 12s - loss: 0.1373 - mse: 0.0773 - mae: 0.1373 - val_loss: 0.1478 - val_mse: 0.0975 - val_mae: 0.1478
# Epoch 201/30000
# 480/480 - 12s - loss: 0.1377 - mse: 0.0780 - mae: 0.1377 - val_loss: 0.1464 - val_mse: 0.0962 - val_mae: 0.1464
# Epoch 202/30000
# 480/480 - 12s - loss: 0.1370 - mse: 0.0776 - mae: 0.1370 - val_loss: 0.1461 - val_mse: 0.0959 - val_mae: 0.1461
# Epoch 203/30000
# 480/480 - 12s - loss: 0.1370 - mse: 0.0775 - mae: 0.1370 - val_loss: 0.1478 - val_mse: 0.0962 - val_mae: 0.1478
# Epoch 204/30000
# 480/480 - 12s - loss: 0.1372 - mse: 0.0778 - mae: 0.1372 - val_loss: 0.1486 - val_mse: 0.0970 - val_mae: 0.1486
# Epoch 205/30000
# 480/480 - 12s - loss: 0.1360 - mse: 0.0764 - mae: 0.1360 - val_loss: 0.1444 - val_mse: 0.0947 - val_mae: 0.1444
# Epoch 206/30000
# 480/480 - 12s - loss: 0.1370 - mse: 0.0776 - mae: 0.1370 - val_loss: 0.1447 - val_mse: 0.0961 - val_mae: 0.1447
# Epoch 207/30000
# 480/480 - 12s - loss: 0.1367 - mse: 0.0766 - mae: 0.1367 - val_loss: 0.1461 - val_mse: 0.0956 - val_mae: 0.1461
# Epoch 208/30000
# 480/480 - 12s - loss: 0.1355 - mse: 0.0762 - mae: 0.1355 - val_loss: 0.1456 - val_mse: 0.0952 - val_mae: 0.1456
# Epoch 209/30000
# 480/480 - 12s - loss: 0.1363 - mse: 0.0763 - mae: 0.1363 - val_loss: 0.1465 - val_mse: 0.0955 - val_mae: 0.1465
# Epoch 210/30000
# 480/480 - 12s - loss: 0.1366 - mse: 0.0774 - mae: 0.1366 - val_loss: 0.1449 - val_mse: 0.0940 - val_mae: 0.1449
# Epoch 211/30000
# 480/480 - 12s - loss: 0.1361 - mse: 0.0760 - mae: 0.1361 - val_loss: 0.1458 - val_mse: 0.0940 - val_mae: 0.1458
# Epoch 212/30000
# 480/480 - 12s - loss: 0.1352 - mse: 0.0759 - mae: 0.1352 - val_loss: 0.1459 - val_mse: 0.0949 - val_mae: 0.1459
# Epoch 213/30000
# 480/480 - 12s - loss: 0.1360 - mse: 0.0767 - mae: 0.1360 - val_loss: 0.1457 - val_mse: 0.0948 - val_mae: 0.1457
# Epoch 214/30000
# 480/480 - 12s - loss: 0.1353 - mse: 0.0763 - mae: 0.1353 - val_loss: 0.1453 - val_mse: 0.0944 - val_mae: 0.1453
# Epoch 215/30000
# 480/480 - 12s - loss: 0.1354 - mse: 0.0757 - mae: 0.1354 - val_loss: 0.1451 - val_mse: 0.0944 - val_mae: 0.1451
# Epoch 216/30000
# 480/480 - 12s - loss: 0.1351 - mse: 0.0759 - mae: 0.1351 - val_loss: 0.1455 - val_mse: 0.0939 - val_mae: 0.1455
# Epoch 217/30000
# 480/480 - 12s - loss: 0.1353 - mse: 0.0756 - mae: 0.1353 - val_loss: 0.1468 - val_mse: 0.0943 - val_mae: 0.1468
# Epoch 218/30000
# 480/480 - 12s - loss: 0.1353 - mse: 0.0758 - mae: 0.1353 - val_loss: 0.1446 - val_mse: 0.0938 - val_mae: 0.1446
# Epoch 219/30000
# 480/480 - 12s - loss: 0.1358 - mse: 0.0761 - mae: 0.1358 - val_loss: 0.1498 - val_mse: 0.0965 - val_mae: 0.1498
# Epoch 220/30000
# 480/480 - 12s - loss: 0.1350 - mse: 0.0756 - mae: 0.1350 - val_loss: 0.1497 - val_mse: 0.0966 - val_mae: 0.1497
# Epoch 221/30000
# 480/480 - 12s - loss: 0.1347 - mse: 0.0751 - mae: 0.1347 - val_loss: 0.1442 - val_mse: 0.0939 - val_mae: 0.1442
# Epoch 222/30000
# 480/480 - 12s - loss: 0.1354 - mse: 0.0763 - mae: 0.1354 - val_loss: 0.1496 - val_mse: 0.0965 - val_mae: 0.1496
# Epoch 223/30000
# 480/480 - 12s - loss: 0.1342 - mse: 0.0753 - mae: 0.1342 - val_loss: 0.1441 - val_mse: 0.0933 - val_mae: 0.1441
# Epoch 224/30000
# 480/480 - 12s - loss: 0.1343 - mse: 0.0750 - mae: 0.1343 - val_loss: 0.1440 - val_mse: 0.0930 - val_mae: 0.1440
# Epoch 225/30000
# 480/480 - 12s - loss: 0.1343 - mse: 0.0753 - mae: 0.1343 - val_loss: 0.1444 - val_mse: 0.0940 - val_mae: 0.1444
# Epoch 226/30000
# 480/480 - 12s - loss: 0.1343 - mse: 0.0750 - mae: 0.1343 - val_loss: 0.1437 - val_mse: 0.0939 - val_mae: 0.1437
# Epoch 227/30000
# 480/480 - 12s - loss: 0.1336 - mse: 0.0737 - mae: 0.1336 - val_loss: 0.1480 - val_mse: 0.0960 - val_mae: 0.1480
# Epoch 228/30000
# 480/480 - 12s - loss: 0.1350 - mse: 0.0750 - mae: 0.1350 - val_loss: 0.1458 - val_mse: 0.0945 - val_mae: 0.1458
# Epoch 229/30000
# 480/480 - 12s - loss: 0.1339 - mse: 0.0743 - mae: 0.1339 - val_loss: 0.1427 - val_mse: 0.0928 - val_mae: 0.1427
# Epoch 230/30000
# 480/480 - 12s - loss: 0.1335 - mse: 0.0744 - mae: 0.1335 - val_loss: 0.1495 - val_mse: 0.0966 - val_mae: 0.1495
# Epoch 231/30000
# 480/480 - 12s - loss: 0.1331 - mse: 0.0739 - mae: 0.1331 - val_loss: 0.1477 - val_mse: 0.0952 - val_mae: 0.1477
# Epoch 232/30000
# 480/480 - 12s - loss: 0.1338 - mse: 0.0742 - mae: 0.1338 - val_loss: 0.1459 - val_mse: 0.0948 - val_mae: 0.1459
# Epoch 233/30000
# 480/480 - 12s - loss: 0.1333 - mse: 0.0739 - mae: 0.1333 - val_loss: 0.1436 - val_mse: 0.0930 - val_mae: 0.1436
# Epoch 234/30000
# 480/480 - 12s - loss: 0.1334 - mse: 0.0745 - mae: 0.1334 - val_loss: 0.1438 - val_mse: 0.0929 - val_mae: 0.1438
# Epoch 235/30000
# 480/480 - 12s - loss: 0.1333 - mse: 0.0738 - mae: 0.1333 - val_loss: 0.1449 - val_mse: 0.0934 - val_mae: 0.1449
# Epoch 236/30000
# 480/480 - 12s - loss: 0.1332 - mse: 0.0736 - mae: 0.1332 - val_loss: 0.1476 - val_mse: 0.0940 - val_mae: 0.1476
# Epoch 237/30000
# 480/480 - 12s - loss: 0.1325 - mse: 0.0731 - mae: 0.1325 - val_loss: 0.1430 - val_mse: 0.0918 - val_mae: 0.1430
# Epoch 238/30000
# 480/480 - 12s - loss: 0.1323 - mse: 0.0722 - mae: 0.1323 - val_loss: 0.1446 - val_mse: 0.0930 - val_mae: 0.1446
# Epoch 239/30000
# 480/480 - 12s - loss: 0.1333 - mse: 0.0741 - mae: 0.1333 - val_loss: 0.1423 - val_mse: 0.0933 - val_mae: 0.1423
# Epoch 240/30000
# 480/480 - 12s - loss: 0.1328 - mse: 0.0729 - mae: 0.1328 - val_loss: 0.1448 - val_mse: 0.0925 - val_mae: 0.1448
# Epoch 241/30000
# 480/480 - 12s - loss: 0.1335 - mse: 0.0740 - mae: 0.1335 - val_loss: 0.1464 - val_mse: 0.0938 - val_mae: 0.1464
# Epoch 242/30000
# 480/480 - 12s - loss: 0.1322 - mse: 0.0724 - mae: 0.1322 - val_loss: 0.1462 - val_mse: 0.0931 - val_mae: 0.1462
# Epoch 243/30000
# 480/480 - 12s - loss: 0.1328 - mse: 0.0736 - mae: 0.1328 - val_loss: 0.1434 - val_mse: 0.0911 - val_mae: 0.1434
# Epoch 244/30000
# 480/480 - 12s - loss: 0.1321 - mse: 0.0719 - mae: 0.1321 - val_loss: 0.1468 - val_mse: 0.0941 - val_mae: 0.1468
# Epoch 245/30000
# 480/480 - 12s - loss: 0.1328 - mse: 0.0732 - mae: 0.1328 - val_loss: 0.1457 - val_mse: 0.0929 - val_mae: 0.1457
# Epoch 246/30000
# 480/480 - 12s - loss: 0.1321 - mse: 0.0721 - mae: 0.1321 - val_loss: 0.1440 - val_mse: 0.0915 - val_mae: 0.1440
# Epoch 247/30000
# 480/480 - 12s - loss: 0.1319 - mse: 0.0717 - mae: 0.1319 - val_loss: 0.1427 - val_mse: 0.0911 - val_mae: 0.1427
# Epoch 248/30000
# 480/480 - 12s - loss: 0.1322 - mse: 0.0723 - mae: 0.1322 - val_loss: 0.1421 - val_mse: 0.0899 - val_mae: 0.1421
# Epoch 249/30000
# 480/480 - 12s - loss: 0.1318 - mse: 0.0723 - mae: 0.1318 - val_loss: 0.1430 - val_mse: 0.0906 - val_mae: 0.1430
# Epoch 250/30000
# 480/480 - 12s - loss: 0.1321 - mse: 0.0722 - mae: 0.1321 - val_loss: 0.1435 - val_mse: 0.0902 - val_mae: 0.1435
# Epoch 251/30000
# 480/480 - 12s - loss: 0.1311 - mse: 0.0716 - mae: 0.1311 - val_loss: 0.1446 - val_mse: 0.0919 - val_mae: 0.1446
# Epoch 252/30000
# 480/480 - 12s - loss: 0.1310 - mse: 0.0710 - mae: 0.1310 - val_loss: 0.1444 - val_mse: 0.0927 - val_mae: 0.1444
# Epoch 253/30000
# 480/480 - 12s - loss: 0.1315 - mse: 0.0722 - mae: 0.1315 - val_loss: 0.1407 - val_mse: 0.0907 - val_mae: 0.1407
# Epoch 254/30000
# 480/480 - 12s - loss: 0.1313 - mse: 0.0717 - mae: 0.1313 - val_loss: 0.1430 - val_mse: 0.0899 - val_mae: 0.1430
# Epoch 255/30000
# 480/480 - 12s - loss: 0.1312 - mse: 0.0718 - mae: 0.1312 - val_loss: 0.1436 - val_mse: 0.0923 - val_mae: 0.1436
# Epoch 256/30000
# 480/480 - 12s - loss: 0.1308 - mse: 0.0712 - mae: 0.1308 - val_loss: 0.1402 - val_mse: 0.0896 - val_mae: 0.1402
# Epoch 257/30000
# 480/480 - 12s - loss: 0.1304 - mse: 0.0701 - mae: 0.1304 - val_loss: 0.1425 - val_mse: 0.0907 - val_mae: 0.1425
# Epoch 258/30000
# 480/480 - 12s - loss: 0.1312 - mse: 0.0715 - mae: 0.1312 - val_loss: 0.1421 - val_mse: 0.0907 - val_mae: 0.1421
# Epoch 259/30000
# 480/480 - 12s - loss: 0.1312 - mse: 0.0720 - mae: 0.1312 - val_loss: 0.1437 - val_mse: 0.0908 - val_mae: 0.1437
# Epoch 260/30000
# 480/480 - 12s - loss: 0.1308 - mse: 0.0712 - mae: 0.1308 - val_loss: 0.1455 - val_mse: 0.0920 - val_mae: 0.1455
# Epoch 261/30000
# 480/480 - 12s - loss: 0.1309 - mse: 0.0706 - mae: 0.1309 - val_loss: 0.1406 - val_mse: 0.0892 - val_mae: 0.1406
# Epoch 262/30000
# 480/480 - 12s - loss: 0.1301 - mse: 0.0708 - mae: 0.1301 - val_loss: 0.1435 - val_mse: 0.0910 - val_mae: 0.1435
# Epoch 263/30000
# 480/480 - 12s - loss: 0.1315 - mse: 0.0723 - mae: 0.1315 - val_loss: 0.1467 - val_mse: 0.0918 - val_mae: 0.1467
# Epoch 264/30000
# 480/480 - 12s - loss: 0.1305 - mse: 0.0712 - mae: 0.1305 - val_loss: 0.1452 - val_mse: 0.0920 - val_mae: 0.1452
# Epoch 265/30000
# 480/480 - 12s - loss: 0.1306 - mse: 0.0712 - mae: 0.1306 - val_loss: 0.1399 - val_mse: 0.0879 - val_mae: 0.1399
# Epoch 266/30000
# 480/480 - 12s - loss: 0.1302 - mse: 0.0711 - mae: 0.1302 - val_loss: 0.1408 - val_mse: 0.0895 - val_mae: 0.1408
# Epoch 267/30000
# 480/480 - 12s - loss: 0.1300 - mse: 0.0702 - mae: 0.1300 - val_loss: 0.1474 - val_mse: 0.0925 - val_mae: 0.1474
# Epoch 268/30000
# 480/480 - 12s - loss: 0.1304 - mse: 0.0707 - mae: 0.1304 - val_loss: 0.1452 - val_mse: 0.0910 - val_mae: 0.1452
# Epoch 269/30000
# 480/480 - 12s - loss: 0.1302 - mse: 0.0706 - mae: 0.1302 - val_loss: 0.1406 - val_mse: 0.0917 - val_mae: 0.1406
# Epoch 270/30000
# 480/480 - 12s - loss: 0.1297 - mse: 0.0699 - mae: 0.1297 - val_loss: 0.1419 - val_mse: 0.0893 - val_mae: 0.1419
# Epoch 271/30000
# 480/480 - 12s - loss: 0.1300 - mse: 0.0701 - mae: 0.1300 - val_loss: 0.1423 - val_mse: 0.0898 - val_mae: 0.1423
# Epoch 272/30000
# 480/480 - 12s - loss: 0.1299 - mse: 0.0708 - mae: 0.1299 - val_loss: 0.1464 - val_mse: 0.0903 - val_mae: 0.1464
# Epoch 273/30000
# 480/480 - 12s - loss: 0.1300 - mse: 0.0704 - mae: 0.1300 - val_loss: 0.1421 - val_mse: 0.0895 - val_mae: 0.1421
# Epoch 274/30000
# 480/480 - 12s - loss: 0.1293 - mse: 0.0694 - mae: 0.1293 - val_loss: 0.1461 - val_mse: 0.0919 - val_mae: 0.1461
# Epoch 275/30000
# 480/480 - 12s - loss: 0.1297 - mse: 0.0700 - mae: 0.1297 - val_loss: 0.1413 - val_mse: 0.0896 - val_mae: 0.1413
# Epoch 276/30000
# 480/480 - 12s - loss: 0.1296 - mse: 0.0697 - mae: 0.1296 - val_loss: 0.1402 - val_mse: 0.0877 - val_mae: 0.1402
# Epoch 277/30000
# 480/480 - 12s - loss: 0.1289 - mse: 0.0690 - mae: 0.1289 - val_loss: 0.1406 - val_mse: 0.0884 - val_mae: 0.1406
# Epoch 278/30000
# 480/480 - 12s - loss: 0.1293 - mse: 0.0704 - mae: 0.1293 - val_loss: 0.1401 - val_mse: 0.0892 - val_mae: 0.1401
# Epoch 279/30000
# 480/480 - 12s - loss: 0.1295 - mse: 0.0704 - mae: 0.1295 - val_loss: 0.1421 - val_mse: 0.0905 - val_mae: 0.1421
# Epoch 280/30000
# 480/480 - 12s - loss: 0.1290 - mse: 0.0690 - mae: 0.1290 - val_loss: 0.1415 - val_mse: 0.0875 - val_mae: 0.1415
# Epoch 281/30000
# 480/480 - 12s - loss: 0.1289 - mse: 0.0701 - mae: 0.1289 - val_loss: 0.1398 - val_mse: 0.0873 - val_mae: 0.1398
# Epoch 282/30000
# 480/480 - 12s - loss: 0.1294 - mse: 0.0698 - mae: 0.1294 - val_loss: 0.1426 - val_mse: 0.0888 - val_mae: 0.1426
# Epoch 283/30000
# 480/480 - 12s - loss: 0.1295 - mse: 0.0698 - mae: 0.1295 - val_loss: 0.1438 - val_mse: 0.0901 - val_mae: 0.1438
# Epoch 284/30000
# 480/480 - 12s - loss: 0.1291 - mse: 0.0695 - mae: 0.1291 - val_loss: 0.1399 - val_mse: 0.0877 - val_mae: 0.1399
# Epoch 285/30000
# 480/480 - 12s - loss: 0.1286 - mse: 0.0689 - mae: 0.1286 - val_loss: 0.1426 - val_mse: 0.0890 - val_mae: 0.1426
# Epoch 286/30000
# 480/480 - 12s - loss: 0.1292 - mse: 0.0696 - mae: 0.1292 - val_loss: 0.1406 - val_mse: 0.0869 - val_mae: 0.1406
# Epoch 287/30000
# 480/480 - 12s - loss: 0.1287 - mse: 0.0692 - mae: 0.1287 - val_loss: 0.1415 - val_mse: 0.0886 - val_mae: 0.1415
# Epoch 288/30000
# 480/480 - 12s - loss: 0.1284 - mse: 0.0693 - mae: 0.1284 - val_loss: 0.1427 - val_mse: 0.0899 - val_mae: 0.1427
# Epoch 289/30000
# 480/480 - 12s - loss: 0.1284 - mse: 0.0691 - mae: 0.1284 - val_loss: 0.1400 - val_mse: 0.0880 - val_mae: 0.1400
# Epoch 290/30000
# 480/480 - 12s - loss: 0.1283 - mse: 0.0685 - mae: 0.1283 - val_loss: 0.1406 - val_mse: 0.0883 - val_mae: 0.1406
# Epoch 291/30000
# 480/480 - 12s - loss: 0.1287 - mse: 0.0695 - mae: 0.1287 - val_loss: 0.1408 - val_mse: 0.0881 - val_mae: 0.1408
# Epoch 292/30000
# 480/480 - 12s - loss: 0.1286 - mse: 0.0692 - mae: 0.1286 - val_loss: 0.1458 - val_mse: 0.0910 - val_mae: 0.1458
# Epoch 293/30000
# 480/480 - 12s - loss: 0.1289 - mse: 0.0691 - mae: 0.1289 - val_loss: 0.1422 - val_mse: 0.0904 - val_mae: 0.1422
# Epoch 294/30000
# 480/480 - 12s - loss: 0.1280 - mse: 0.0681 - mae: 0.1280 - val_loss: 0.1388 - val_mse: 0.0870 - val_mae: 0.1388
# Epoch 295/30000
# 480/480 - 12s - loss: 0.1278 - mse: 0.0687 - mae: 0.1278 - val_loss: 0.1403 - val_mse: 0.0880 - val_mae: 0.1403
# Epoch 296/30000
# 480/480 - 12s - loss: 0.1283 - mse: 0.0687 - mae: 0.1283 - val_loss: 0.1423 - val_mse: 0.0907 - val_mae: 0.1423
# Epoch 297/30000
# 480/480 - 12s - loss: 0.1277 - mse: 0.0682 - mae: 0.1277 - val_loss: 0.1408 - val_mse: 0.0874 - val_mae: 0.1408
# Epoch 298/30000
# 480/480 - 12s - loss: 0.1280 - mse: 0.0686 - mae: 0.1280 - val_loss: 0.1413 - val_mse: 0.0897 - val_mae: 0.1413
# Epoch 299/30000
# 480/480 - 12s - loss: 0.1280 - mse: 0.0683 - mae: 0.1280 - val_loss: 0.1399 - val_mse: 0.0867 - val_mae: 0.1399
# Epoch 300/30000
# 480/480 - 12s - loss: 0.1278 - mse: 0.0686 - mae: 0.1278 - val_loss: 0.1432 - val_mse: 0.0893 - val_mae: 0.1432
# Epoch 301/30000
# 480/480 - 12s - loss: 0.1276 - mse: 0.0682 - mae: 0.1276 - val_loss: 0.1413 - val_mse: 0.0889 - val_mae: 0.1413
# Epoch 302/30000
# 480/480 - 12s - loss: 0.1277 - mse: 0.0682 - mae: 0.1277 - val_loss: 0.1433 - val_mse: 0.0894 - val_mae: 0.1433
# Epoch 303/30000
# 480/480 - 12s - loss: 0.1279 - mse: 0.0685 - mae: 0.1279 - val_loss: 0.1427 - val_mse: 0.0897 - val_mae: 0.1427
# Epoch 304/30000
# 480/480 - 12s - loss: 0.1285 - mse: 0.0688 - mae: 0.1285 - val_loss: 0.1398 - val_mse: 0.0871 - val_mae: 0.1398
# Epoch 305/30000
# 480/480 - 12s - loss: 0.1283 - mse: 0.0687 - mae: 0.1283 - val_loss: 0.1399 - val_mse: 0.0867 - val_mae: 0.1399
# Epoch 306/30000
# 480/480 - 12s - loss: 0.1276 - mse: 0.0678 - mae: 0.1276 - val_loss: 0.1424 - val_mse: 0.0879 - val_mae: 0.1424
# Epoch 307/30000
# 480/480 - 12s - loss: 0.1268 - mse: 0.0675 - mae: 0.1268 - val_loss: 0.1417 - val_mse: 0.0896 - val_mae: 0.1417
# Epoch 308/30000
# 480/480 - 12s - loss: 0.1273 - mse: 0.0674 - mae: 0.1273 - val_loss: 0.1443 - val_mse: 0.0903 - val_mae: 0.1443
# Epoch 309/30000
# 480/480 - 12s - loss: 0.1276 - mse: 0.0675 - mae: 0.1276 - val_loss: 0.1385 - val_mse: 0.0865 - val_mae: 0.1385
# Epoch 310/30000
# 480/480 - 12s - loss: 0.1265 - mse: 0.0667 - mae: 0.1265 - val_loss: 0.1444 - val_mse: 0.0883 - val_mae: 0.1444
# Epoch 311/30000
# 480/480 - 12s - loss: 0.1277 - mse: 0.0686 - mae: 0.1277 - val_loss: 0.1383 - val_mse: 0.0853 - val_mae: 0.1383
# Epoch 312/30000
# 480/480 - 12s - loss: 0.1271 - mse: 0.0679 - mae: 0.1271 - val_loss: 0.1411 - val_mse: 0.0881 - val_mae: 0.1411
# Epoch 313/30000
# 480/480 - 12s - loss: 0.1270 - mse: 0.0674 - mae: 0.1270 - val_loss: 0.1386 - val_mse: 0.0853 - val_mae: 0.1386
# Epoch 314/30000
# 480/480 - 12s - loss: 0.1275 - mse: 0.0682 - mae: 0.1275 - val_loss: 0.1379 - val_mse: 0.0855 - val_mae: 0.1379
# Epoch 315/30000
# 480/480 - 12s - loss: 0.1267 - mse: 0.0684 - mae: 0.1267 - val_loss: 0.1391 - val_mse: 0.0861 - val_mae: 0.1391
# Epoch 316/30000
# 480/480 - 12s - loss: 0.1264 - mse: 0.0668 - mae: 0.1264 - val_loss: 0.1408 - val_mse: 0.0877 - val_mae: 0.1408
# Epoch 317/30000
# 480/480 - 12s - loss: 0.1268 - mse: 0.0679 - mae: 0.1268 - val_loss: 0.1393 - val_mse: 0.0874 - val_mae: 0.1393
# Epoch 318/30000
# 480/480 - 12s - loss: 0.1272 - mse: 0.0680 - mae: 0.1272 - val_loss: 0.1393 - val_mse: 0.0881 - val_mae: 0.1393
# Epoch 319/30000
# 480/480 - 12s - loss: 0.1263 - mse: 0.0671 - mae: 0.1263 - val_loss: 0.1404 - val_mse: 0.0852 - val_mae: 0.1404
# Epoch 320/30000
# 480/480 - 12s - loss: 0.1261 - mse: 0.0672 - mae: 0.1261 - val_loss: 0.1381 - val_mse: 0.0859 - val_mae: 0.1381
# Epoch 321/30000
# 480/480 - 12s - loss: 0.1265 - mse: 0.0671 - mae: 0.1265 - val_loss: 0.1409 - val_mse: 0.0861 - val_mae: 0.1409
# Epoch 322/30000
# 480/480 - 12s - loss: 0.1268 - mse: 0.0670 - mae: 0.1268 - val_loss: 0.1404 - val_mse: 0.0877 - val_mae: 0.1404
# Epoch 323/30000
# 480/480 - 12s - loss: 0.1259 - mse: 0.0668 - mae: 0.1259 - val_loss: 0.1378 - val_mse: 0.0855 - val_mae: 0.1378
# Epoch 324/30000
# 480/480 - 12s - loss: 0.1261 - mse: 0.0664 - mae: 0.1261 - val_loss: 0.1439 - val_mse: 0.0895 - val_mae: 0.1439
# Epoch 325/30000
# 480/480 - 12s - loss: 0.1263 - mse: 0.0667 - mae: 0.1263 - val_loss: 0.1410 - val_mse: 0.0855 - val_mae: 0.1410
# Epoch 326/30000
# 480/480 - 12s - loss: 0.1266 - mse: 0.0667 - mae: 0.1266 - val_loss: 0.1385 - val_mse: 0.0847 - val_mae: 0.1385
# Epoch 327/30000
# 480/480 - 12s - loss: 0.1261 - mse: 0.0660 - mae: 0.1261 - val_loss: 0.1440 - val_mse: 0.0879 - val_mae: 0.1440
# Epoch 328/30000
# 480/480 - 12s - loss: 0.1262 - mse: 0.0664 - mae: 0.1262 - val_loss: 0.1400 - val_mse: 0.0853 - val_mae: 0.1400
# Epoch 329/30000
# 480/480 - 12s - loss: 0.1258 - mse: 0.0663 - mae: 0.1258 - val_loss: 0.1423 - val_mse: 0.0866 - val_mae: 0.1423
# Epoch 330/30000
# 480/480 - 12s - loss: 0.1259 - mse: 0.0670 - mae: 0.1259 - val_loss: 0.1412 - val_mse: 0.0873 - val_mae: 0.1412
# Epoch 331/30000
# 480/480 - 12s - loss: 0.1258 - mse: 0.0663 - mae: 0.1258 - val_loss: 0.1398 - val_mse: 0.0853 - val_mae: 0.1398
# Epoch 332/30000
# 480/480 - 12s - loss: 0.1258 - mse: 0.0667 - mae: 0.1258 - val_loss: 0.1446 - val_mse: 0.0875 - val_mae: 0.1446
# Epoch 333/30000
# 480/480 - 12s - loss: 0.1258 - mse: 0.0667 - mae: 0.1258 - val_loss: 0.1398 - val_mse: 0.0876 - val_mae: 0.1398
# Epoch 334/30000
# 480/480 - 12s - loss: 0.1257 - mse: 0.0666 - mae: 0.1257 - val_loss: 0.1381 - val_mse: 0.0854 - val_mae: 0.1381
# Epoch 335/30000
# 480/480 - 12s - loss: 0.1253 - mse: 0.0665 - mae: 0.1253 - val_loss: 0.1391 - val_mse: 0.0873 - val_mae: 0.1391
# Epoch 336/30000
# 480/480 - 12s - loss: 0.1253 - mse: 0.0658 - mae: 0.1253 - val_loss: 0.1391 - val_mse: 0.0847 - val_mae: 0.1391
# Epoch 337/30000
# 480/480 - 12s - loss: 0.1258 - mse: 0.0673 - mae: 0.1258 - val_loss: 0.1399 - val_mse: 0.0859 - val_mae: 0.1399
# Epoch 338/30000
# 480/480 - 12s - loss: 0.1251 - mse: 0.0656 - mae: 0.1251 - val_loss: 0.1396 - val_mse: 0.0867 - val_mae: 0.1396
# Epoch 339/30000
# 480/480 - 12s - loss: 0.1256 - mse: 0.0664 - mae: 0.1256 - val_loss: 0.1395 - val_mse: 0.0872 - val_mae: 0.1395
# Epoch 340/30000
# 480/480 - 12s - loss: 0.1253 - mse: 0.0662 - mae: 0.1253 - val_loss: 0.1405 - val_mse: 0.0876 - val_mae: 0.1405
# Epoch 341/30000
# 480/480 - 12s - loss: 0.1251 - mse: 0.0660 - mae: 0.1251 - val_loss: 0.1412 - val_mse: 0.0860 - val_mae: 0.1412
# Epoch 342/30000
# 480/480 - 12s - loss: 0.1247 - mse: 0.0657 - mae: 0.1247 - val_loss: 0.1399 - val_mse: 0.0874 - val_mae: 0.1399
# Epoch 343/30000
# 480/480 - 12s - loss: 0.1250 - mse: 0.0664 - mae: 0.1250 - val_loss: 0.1403 - val_mse: 0.0868 - val_mae: 0.1403
# Epoch 344/30000
# 480/480 - 12s - loss: 0.1255 - mse: 0.0667 - mae: 0.1255 - val_loss: 0.1428 - val_mse: 0.0883 - val_mae: 0.1428
# Epoch 345/30000
# 480/480 - 12s - loss: 0.1252 - mse: 0.0658 - mae: 0.1252 - val_loss: 0.1410 - val_mse: 0.0878 - val_mae: 0.1410
# Epoch 346/30000
# 480/480 - 12s - loss: 0.1250 - mse: 0.0656 - mae: 0.1250 - val_loss: 0.1421 - val_mse: 0.0880 - val_mae: 0.1421
# Epoch 347/30000
# 480/480 - 12s - loss: 0.1244 - mse: 0.0652 - mae: 0.1244 - val_loss: 0.1398 - val_mse: 0.0838 - val_mae: 0.1398
# Epoch 348/30000
# 480/480 - 12s - loss: 0.1243 - mse: 0.0649 - mae: 0.1243 - val_loss: 0.1389 - val_mse: 0.0841 - val_mae: 0.1389
# Epoch 349/30000
# 480/480 - 12s - loss: 0.1251 - mse: 0.0654 - mae: 0.1251 - val_loss: 0.1380 - val_mse: 0.0854 - val_mae: 0.1380
# Epoch 350/30000
# 480/480 - 12s - loss: 0.1250 - mse: 0.0656 - mae: 0.1250 - val_loss: 0.1422 - val_mse: 0.0877 - val_mae: 0.1422
# Epoch 351/30000
# 480/480 - 12s - loss: 0.1247 - mse: 0.0658 - mae: 0.1247 - val_loss: 0.1377 - val_mse: 0.0858 - val_mae: 0.1377
# Epoch 352/30000
# 480/480 - 12s - loss: 0.1246 - mse: 0.0656 - mae: 0.1246 - val_loss: 0.1393 - val_mse: 0.0835 - val_mae: 0.1393
# Epoch 353/30000
# 480/480 - 12s - loss: 0.1252 - mse: 0.0654 - mae: 0.1252 - val_loss: 0.1410 - val_mse: 0.0859 - val_mae: 0.1410
# Epoch 354/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0650 - mae: 0.1240 - val_loss: 0.1391 - val_mse: 0.0841 - val_mae: 0.1391
# Epoch 355/30000
# 480/480 - 12s - loss: 0.1251 - mse: 0.0656 - mae: 0.1251 - val_loss: 0.1399 - val_mse: 0.0854 - val_mae: 0.1399
# Epoch 356/30000
# 480/480 - 12s - loss: 0.1244 - mse: 0.0654 - mae: 0.1244 - val_loss: 0.1380 - val_mse: 0.0859 - val_mae: 0.1380
# Epoch 357/30000
# 480/480 - 12s - loss: 0.1245 - mse: 0.0652 - mae: 0.1245 - val_loss: 0.1376 - val_mse: 0.0841 - val_mae: 0.1376
# Epoch 358/30000
# 480/480 - 12s - loss: 0.1250 - mse: 0.0657 - mae: 0.1250 - val_loss: 0.1408 - val_mse: 0.0877 - val_mae: 0.1408
# Epoch 359/30000
# 480/480 - 12s - loss: 0.1241 - mse: 0.0646 - mae: 0.1241 - val_loss: 0.1404 - val_mse: 0.0869 - val_mae: 0.1404
# Epoch 360/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0648 - mae: 0.1240 - val_loss: 0.1395 - val_mse: 0.0856 - val_mae: 0.1395
# Epoch 361/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0653 - mae: 0.1240 - val_loss: 0.1397 - val_mse: 0.0843 - val_mae: 0.1397
# Epoch 362/30000
# 480/480 - 12s - loss: 0.1241 - mse: 0.0650 - mae: 0.1241 - val_loss: 0.1443 - val_mse: 0.0861 - val_mae: 0.1443
# Epoch 363/30000
# 480/480 - 12s - loss: 0.1242 - mse: 0.0652 - mae: 0.1242 - val_loss: 0.1405 - val_mse: 0.0871 - val_mae: 0.1405
# Epoch 364/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0650 - mae: 0.1240 - val_loss: 0.1378 - val_mse: 0.0834 - val_mae: 0.1378
# Epoch 365/30000
# 480/480 - 12s - loss: 0.1238 - mse: 0.0641 - mae: 0.1238 - val_loss: 0.1384 - val_mse: 0.0846 - val_mae: 0.1384
# Epoch 366/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0647 - mae: 0.1240 - val_loss: 0.1424 - val_mse: 0.0889 - val_mae: 0.1424
# Epoch 367/30000
# 480/480 - 12s - loss: 0.1243 - mse: 0.0646 - mae: 0.1243 - val_loss: 0.1404 - val_mse: 0.0853 - val_mae: 0.1404
# Epoch 368/30000
# 480/480 - 12s - loss: 0.1241 - mse: 0.0645 - mae: 0.1241 - val_loss: 0.1415 - val_mse: 0.0881 - val_mae: 0.1415
# Epoch 369/30000
# 480/480 - 12s - loss: 0.1235 - mse: 0.0642 - mae: 0.1235 - val_loss: 0.1403 - val_mse: 0.0855 - val_mae: 0.1403
# Epoch 370/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0649 - mae: 0.1240 - val_loss: 0.1399 - val_mse: 0.0850 - val_mae: 0.1399
# Epoch 371/30000
# 480/480 - 12s - loss: 0.1241 - mse: 0.0650 - mae: 0.1241 - val_loss: 0.1390 - val_mse: 0.0846 - val_mae: 0.1390
# Epoch 372/30000
# 480/480 - 12s - loss: 0.1230 - mse: 0.0639 - mae: 0.1230 - val_loss: 0.1403 - val_mse: 0.0859 - val_mae: 0.1403
# Epoch 373/30000
# 480/480 - 12s - loss: 0.1240 - mse: 0.0643 - mae: 0.1240 - val_loss: 0.1389 - val_mse: 0.0855 - val_mae: 0.1389
# Epoch 374/30000
# 480/480 - 12s - loss: 0.1236 - mse: 0.0640 - mae: 0.1236 - val_loss: 0.1412 - val_mse: 0.0848 - val_mae: 0.1412
# Epoch 375/30000
# 480/480 - 12s - loss: 0.1230 - mse: 0.0645 - mae: 0.1230 - val_loss: 0.1378 - val_mse: 0.0834 - val_mae: 0.1378
# Epoch 376/30000
# ...
# Epoch 1120/30000
# 480/480 - 12s - loss: 0.1096 - mse: 0.0509 - mae: 0.1096 - val_loss: 0.1400 - val_mse: 0.0821 - val_mae: 0.1400
# Epoch 1121/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0510 - mae: 0.1093 - val_loss: 0.1346 - val_mse: 0.0801 - val_mae: 0.1346
# Epoch 1122/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0511 - mae: 0.1092 - val_loss: 0.1376 - val_mse: 0.0800 - val_mae: 0.1376
# Epoch 1123/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0504 - mae: 0.1090 - val_loss: 0.1336 - val_mse: 0.0771 - val_mae: 0.1336
# Epoch 1124/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0508 - mae: 0.1089 - val_loss: 0.1330 - val_mse: 0.0777 - val_mae: 0.1330
# Epoch 1125/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0508 - mae: 0.1090 - val_loss: 0.1365 - val_mse: 0.0792 - val_mae: 0.1365
# Epoch 1126/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0505 - mae: 0.1090 - val_loss: 0.1346 - val_mse: 0.0779 - val_mae: 0.1346
# Epoch 1127/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0506 - mae: 0.1091 - val_loss: 0.1343 - val_mse: 0.0773 - val_mae: 0.1343
# Epoch 1128/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0507 - mae: 0.1093 - val_loss: 0.1349 - val_mse: 0.0776 - val_mae: 0.1349
# Epoch 1129/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0508 - mae: 0.1092 - val_loss: 0.1387 - val_mse: 0.0805 - val_mae: 0.1387
# Epoch 1130/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0508 - mae: 0.1090 - val_loss: 0.1339 - val_mse: 0.0799 - val_mae: 0.1339
# Epoch 1131/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0507 - mae: 0.1089 - val_loss: 0.1378 - val_mse: 0.0806 - val_mae: 0.1378
# Epoch 1132/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0515 - mae: 0.1093 - val_loss: 0.1335 - val_mse: 0.0789 - val_mae: 0.1335
# Epoch 1133/30000
# 480/480 - 12s - loss: 0.1099 - mse: 0.0513 - mae: 0.1099 - val_loss: 0.1337 - val_mse: 0.0788 - val_mae: 0.1337
# Epoch 1134/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0500 - mae: 0.1089 - val_loss: 0.1348 - val_mse: 0.0785 - val_mae: 0.1348
# Epoch 1135/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0511 - mae: 0.1093 - val_loss: 0.1353 - val_mse: 0.0786 - val_mae: 0.1353
# Epoch 1136/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0505 - mae: 0.1091 - val_loss: 0.1339 - val_mse: 0.0776 - val_mae: 0.1339
# Epoch 1137/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0520 - mae: 0.1092 - val_loss: 0.1379 - val_mse: 0.0810 - val_mae: 0.1379
# Epoch 1138/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0512 - mae: 0.1091 - val_loss: 0.1342 - val_mse: 0.0766 - val_mae: 0.1342
# Epoch 1139/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0500 - mae: 0.1091 - val_loss: 0.1351 - val_mse: 0.0780 - val_mae: 0.1351
# Epoch 1140/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0516 - mae: 0.1095 - val_loss: 0.1374 - val_mse: 0.0793 - val_mae: 0.1374
# Epoch 1141/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0512 - mae: 0.1092 - val_loss: 0.1357 - val_mse: 0.0789 - val_mae: 0.1357
# Epoch 1142/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0506 - mae: 0.1087 - val_loss: 0.1352 - val_mse: 0.0784 - val_mae: 0.1352
# Epoch 1143/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0509 - mae: 0.1089 - val_loss: 0.1382 - val_mse: 0.0789 - val_mae: 0.1382
# Epoch 1144/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0507 - mae: 0.1089 - val_loss: 0.1337 - val_mse: 0.0792 - val_mae: 0.1337
# Epoch 1145/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0504 - mae: 0.1089 - val_loss: 0.1374 - val_mse: 0.0803 - val_mae: 0.1374
# Epoch 1146/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0501 - mae: 0.1092 - val_loss: 0.1338 - val_mse: 0.0773 - val_mae: 0.1338
# Epoch 1147/30000
# 480/480 - 12s - loss: 0.1094 - mse: 0.0506 - mae: 0.1094 - val_loss: 0.1362 - val_mse: 0.0778 - val_mae: 0.1362
# Epoch 1148/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0518 - mae: 0.1095 - val_loss: 0.1335 - val_mse: 0.0770 - val_mae: 0.1335
# Epoch 1149/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0507 - mae: 0.1088 - val_loss: 0.1368 - val_mse: 0.0809 - val_mae: 0.1368
# Epoch 1150/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0505 - mae: 0.1090 - val_loss: 0.1331 - val_mse: 0.0781 - val_mae: 0.1331
# Epoch 1151/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0509 - mae: 0.1089 - val_loss: 0.1348 - val_mse: 0.0777 - val_mae: 0.1348
# Epoch 1152/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0511 - mae: 0.1087 - val_loss: 0.1330 - val_mse: 0.0773 - val_mae: 0.1330
# Epoch 1153/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0511 - mae: 0.1092 - val_loss: 0.1355 - val_mse: 0.0786 - val_mae: 0.1355
# Epoch 1154/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0505 - mae: 0.1084 - val_loss: 0.1355 - val_mse: 0.0783 - val_mae: 0.1355
# Epoch 1155/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0507 - mae: 0.1090 - val_loss: 0.1366 - val_mse: 0.0801 - val_mae: 0.1366
# Epoch 1156/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0504 - mae: 0.1090 - val_loss: 0.1357 - val_mse: 0.0774 - val_mae: 0.1357
# Epoch 1157/30000
# 480/480 - 12s - loss: 0.1082 - mse: 0.0500 - mae: 0.1082 - val_loss: 0.1345 - val_mse: 0.0785 - val_mae: 0.1345
# Epoch 1158/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0511 - mae: 0.1092 - val_loss: 0.1358 - val_mse: 0.0787 - val_mae: 0.1358
# Epoch 1159/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0502 - mae: 0.1084 - val_loss: 0.1350 - val_mse: 0.0786 - val_mae: 0.1350
# Epoch 1160/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0510 - mae: 0.1091 - val_loss: 0.1362 - val_mse: 0.0788 - val_mae: 0.1362
# Epoch 1161/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0517 - mae: 0.1095 - val_loss: 0.1357 - val_mse: 0.0774 - val_mae: 0.1357
# Epoch 1162/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0513 - mae: 0.1090 - val_loss: 0.1351 - val_mse: 0.0786 - val_mae: 0.1351
# Epoch 1163/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0513 - mae: 0.1091 - val_loss: 0.1372 - val_mse: 0.0792 - val_mae: 0.1372
# Epoch 1164/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0515 - mae: 0.1090 - val_loss: 0.1347 - val_mse: 0.0788 - val_mae: 0.1347
# Epoch 1165/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0509 - mae: 0.1089 - val_loss: 0.1345 - val_mse: 0.0793 - val_mae: 0.1345
# Epoch 1166/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0507 - mae: 0.1089 - val_loss: 0.1358 - val_mse: 0.0803 - val_mae: 0.1358
# Epoch 1167/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0511 - mae: 0.1093 - val_loss: 0.1349 - val_mse: 0.0785 - val_mae: 0.1349
# Epoch 1168/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0505 - mae: 0.1087 - val_loss: 0.1341 - val_mse: 0.0778 - val_mae: 0.1341
# Epoch 1169/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0511 - mae: 0.1088 - val_loss: 0.1338 - val_mse: 0.0785 - val_mae: 0.1338
# Epoch 1170/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0501 - mae: 0.1087 - val_loss: 0.1351 - val_mse: 0.0774 - val_mae: 0.1351
# Epoch 1171/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0505 - mae: 0.1089 - val_loss: 0.1356 - val_mse: 0.0786 - val_mae: 0.1356
# Epoch 1172/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0512 - mae: 0.1095 - val_loss: 0.1369 - val_mse: 0.0785 - val_mae: 0.1369
# Epoch 1173/30000
# 480/480 - 12s - loss: 0.1085 - mse: 0.0504 - mae: 0.1085 - val_loss: 0.1342 - val_mse: 0.0786 - val_mae: 0.1342
# Epoch 1174/30000
# 480/480 - 12s - loss: 0.1098 - mse: 0.0518 - mae: 0.1098 - val_loss: 0.1364 - val_mse: 0.0789 - val_mae: 0.1364
# Epoch 1175/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0508 - mae: 0.1088 - val_loss: 0.1360 - val_mse: 0.0806 - val_mae: 0.1360
# Epoch 1176/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0506 - mae: 0.1089 - val_loss: 0.1381 - val_mse: 0.0802 - val_mae: 0.1381
# Epoch 1177/30000
# 480/480 - 12s - loss: 0.1094 - mse: 0.0511 - mae: 0.1094 - val_loss: 0.1340 - val_mse: 0.0778 - val_mae: 0.1340
# Epoch 1178/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0514 - mae: 0.1091 - val_loss: 0.1367 - val_mse: 0.0796 - val_mae: 0.1367
# Epoch 1179/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0505 - mae: 0.1091 - val_loss: 0.1341 - val_mse: 0.0782 - val_mae: 0.1341
# Epoch 1180/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0506 - mae: 0.1087 - val_loss: 0.1363 - val_mse: 0.0784 - val_mae: 0.1363
# Epoch 1181/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0502 - mae: 0.1084 - val_loss: 0.1334 - val_mse: 0.0780 - val_mae: 0.1334
# Epoch 1182/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0510 - mae: 0.1090 - val_loss: 0.1361 - val_mse: 0.0786 - val_mae: 0.1361
# Epoch 1183/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0504 - mae: 0.1086 - val_loss: 0.1332 - val_mse: 0.0773 - val_mae: 0.1332
# Epoch 1184/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0503 - mae: 0.1088 - val_loss: 0.1358 - val_mse: 0.0784 - val_mae: 0.1358
# Epoch 1185/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0503 - mae: 0.1089 - val_loss: 0.1346 - val_mse: 0.0798 - val_mae: 0.1346
# Epoch 1186/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0504 - mae: 0.1086 - val_loss: 0.1340 - val_mse: 0.0782 - val_mae: 0.1340
# Epoch 1187/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0501 - mae: 0.1088 - val_loss: 0.1335 - val_mse: 0.0769 - val_mae: 0.1335
# Epoch 1188/30000
# 480/480 - 12s - loss: 0.1094 - mse: 0.0513 - mae: 0.1094 - val_loss: 0.1365 - val_mse: 0.0791 - val_mae: 0.1365
# Epoch 1189/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0522 - mae: 0.1095 - val_loss: 0.1381 - val_mse: 0.0810 - val_mae: 0.1381
# Epoch 1190/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0518 - mae: 0.1095 - val_loss: 0.1347 - val_mse: 0.0787 - val_mae: 0.1347
# Epoch 1191/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0501 - mae: 0.1091 - val_loss: 0.1356 - val_mse: 0.0787 - val_mae: 0.1356
# Epoch 1192/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0507 - mae: 0.1084 - val_loss: 0.1346 - val_mse: 0.0785 - val_mae: 0.1346
# Epoch 1193/30000
# 480/480 - 12s - loss: 0.1080 - mse: 0.0502 - mae: 0.1080 - val_loss: 0.1348 - val_mse: 0.0777 - val_mae: 0.1348
# Epoch 1194/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0497 - mae: 0.1084 - val_loss: 0.1337 - val_mse: 0.0775 - val_mae: 0.1337
# Epoch 1195/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0502 - mae: 0.1088 - val_loss: 0.1348 - val_mse: 0.0777 - val_mae: 0.1348
# Epoch 1196/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0510 - mae: 0.1093 - val_loss: 0.1341 - val_mse: 0.0785 - val_mae: 0.1341
# Epoch 1197/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0505 - mae: 0.1088 - val_loss: 0.1352 - val_mse: 0.0783 - val_mae: 0.1352
# Epoch 1198/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0509 - mae: 0.1086 - val_loss: 0.1366 - val_mse: 0.0775 - val_mae: 0.1366
# Epoch 1199/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0507 - mae: 0.1088 - val_loss: 0.1349 - val_mse: 0.0784 - val_mae: 0.1349
# Epoch 1200/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0507 - mae: 0.1086 - val_loss: 0.1366 - val_mse: 0.0792 - val_mae: 0.1366
# Epoch 1201/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0508 - mae: 0.1084 - val_loss: 0.1357 - val_mse: 0.0781 - val_mae: 0.1357
# Epoch 1202/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0510 - mae: 0.1091 - val_loss: 0.1370 - val_mse: 0.0798 - val_mae: 0.1370
# Epoch 1203/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0511 - mae: 0.1092 - val_loss: 0.1338 - val_mse: 0.0771 - val_mae: 0.1338
# Epoch 1204/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0510 - mae: 0.1088 - val_loss: 0.1349 - val_mse: 0.0778 - val_mae: 0.1349
# Epoch 1205/30000
# 480/480 - 12s - loss: 0.1083 - mse: 0.0506 - mae: 0.1083 - val_loss: 0.1341 - val_mse: 0.0778 - val_mae: 0.1341
# Epoch 1206/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0512 - mae: 0.1091 - val_loss: 0.1364 - val_mse: 0.0776 - val_mae: 0.1364
# Epoch 1207/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0505 - mae: 0.1091 - val_loss: 0.1397 - val_mse: 0.0828 - val_mae: 0.1397
# Epoch 1208/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0503 - mae: 0.1084 - val_loss: 0.1338 - val_mse: 0.0785 - val_mae: 0.1338
# Epoch 1209/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0512 - mae: 0.1089 - val_loss: 0.1411 - val_mse: 0.0834 - val_mae: 0.1411
# Epoch 1210/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0508 - mae: 0.1092 - val_loss: 0.1333 - val_mse: 0.0762 - val_mae: 0.1333
# Epoch 1211/30000
# 480/480 - 12s - loss: 0.1083 - mse: 0.0501 - mae: 0.1083 - val_loss: 0.1363 - val_mse: 0.0784 - val_mae: 0.1363
# Epoch 1212/30000
# 480/480 - 12s - loss: 0.1089 - mse: 0.0504 - mae: 0.1089 - val_loss: 0.1356 - val_mse: 0.0784 - val_mae: 0.1356
# Epoch 1213/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0506 - mae: 0.1086 - val_loss: 0.1338 - val_mse: 0.0780 - val_mae: 0.1338
# Epoch 1214/30000
# 480/480 - 12s - loss: 0.1082 - mse: 0.0501 - mae: 0.1082 - val_loss: 0.1356 - val_mse: 0.0796 - val_mae: 0.1356
# Epoch 1215/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0500 - mae: 0.1084 - val_loss: 0.1361 - val_mse: 0.0781 - val_mae: 0.1361
# Epoch 1216/30000
# 480/480 - 12s - loss: 0.1085 - mse: 0.0506 - mae: 0.1085 - val_loss: 0.1363 - val_mse: 0.0782 - val_mae: 0.1363
# Epoch 1217/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0506 - mae: 0.1088 - val_loss: 0.1360 - val_mse: 0.0791 - val_mae: 0.1360
# Epoch 1218/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0506 - mae: 0.1086 - val_loss: 0.1362 - val_mse: 0.0782 - val_mae: 0.1362
# Epoch 1219/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0509 - mae: 0.1091 - val_loss: 0.1433 - val_mse: 0.0840 - val_mae: 0.1433
# Epoch 1220/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0510 - mae: 0.1093 - val_loss: 0.1357 - val_mse: 0.0780 - val_mae: 0.1357
# Epoch 1221/30000
# 480/480 - 12s - loss: 0.1095 - mse: 0.0513 - mae: 0.1095 - val_loss: 0.1361 - val_mse: 0.0796 - val_mae: 0.1361
# Epoch 1222/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0509 - mae: 0.1087 - val_loss: 0.1331 - val_mse: 0.0777 - val_mae: 0.1331
# Epoch 1223/30000
# 480/480 - 12s - loss: 0.1085 - mse: 0.0504 - mae: 0.1085 - val_loss: 0.1331 - val_mse: 0.0767 - val_mae: 0.1331
# Epoch 1224/30000
# 480/480 - 12s - loss: 0.1087 - mse: 0.0511 - mae: 0.1087 - val_loss: 0.1351 - val_mse: 0.0772 - val_mae: 0.1351
# Epoch 1225/30000
# 480/480 - 12s - loss: 0.1091 - mse: 0.0511 - mae: 0.1091 - val_loss: 0.1336 - val_mse: 0.0765 - val_mae: 0.1336
# Epoch 1226/30000
# 480/480 - 12s - loss: 0.1090 - mse: 0.0504 - mae: 0.1090 - val_loss: 0.1361 - val_mse: 0.0787 - val_mae: 0.1361
# Epoch 1227/30000
# 480/480 - 12s - loss: 0.1086 - mse: 0.0507 - mae: 0.1086 - val_loss: 0.1371 - val_mse: 0.0788 - val_mae: 0.1371
# Epoch 1228/30000
# 480/480 - 12s - loss: 0.1092 - mse: 0.0512 - mae: 0.1092 - val_loss: 0.1414 - val_mse: 0.0818 - val_mae: 0.1414
# Epoch 1229/30000
# 480/480 - 12s - loss: 0.1082 - mse: 0.0502 - mae: 0.1082 - val_loss: 0.1404 - val_mse: 0.0790 - val_mae: 0.1404
# Epoch 1230/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0506 - mae: 0.1084 - val_loss: 0.1346 - val_mse: 0.0784 - val_mae: 0.1346
# Epoch 1231/30000
# 480/480 - 12s - loss: 0.1082 - mse: 0.0510 - mae: 0.1082 - val_loss: 0.1366 - val_mse: 0.0792 - val_mae: 0.1366
# Epoch 1232/30000
# 480/480 - 12s - loss: 0.1081 - mse: 0.0500 - mae: 0.1081 - val_loss: 0.1427 - val_mse: 0.0831 - val_mae: 0.1427
# Epoch 1233/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0506 - mae: 0.1088 - val_loss: 0.1401 - val_mse: 0.0806 - val_mae: 0.1401
# Epoch 1234/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0509 - mae: 0.1088 - val_loss: 0.1327 - val_mse: 0.0777 - val_mae: 0.1327
# Epoch 1235/30000
# 480/480 - 12s - loss: 0.1085 - mse: 0.0504 - mae: 0.1085 - val_loss: 0.1350 - val_mse: 0.0778 - val_mae: 0.1350
# Epoch 1236/30000
# 480/480 - 12s - loss: 0.1085 - mse: 0.0505 - mae: 0.1085 - val_loss: 0.1445 - val_mse: 0.0839 - val_mae: 0.1445
# Epoch 1237/30000
# 480/480 - 12s - loss: 0.1093 - mse: 0.0510 - mae: 0.1093 - val_loss: 0.1365 - val_mse: 0.0790 - val_mae: 0.1365
# Epoch 1238/30000
# 480/480 - 12s - loss: 0.1082 - mse: 0.0497 - mae: 0.1082 - val_loss: 0.1350 - val_mse: 0.0784 - val_mae: 0.1350
# Epoch 1239/30000
# 480/480 - 12s - loss: 0.1088 - mse: 0.0503 - mae: 0.1088 - val_loss: 0.1344 - val_mse: 0.0776 - val_mae: 0.1344
# Epoch 1240/30000
# 480/480 - 12s - loss: 0.1080 - mse: 0.0501 - mae: 0.1080 - val_loss: 0.1396 - val_mse: 0.0812 - val_mae: 0.1396
# Epoch 1241/30000
# 480/480 - 12s - loss: 0.1084 - mse: 0.0496 - mae: 0.1084 - val_loss: 0.1335 - val_mse: 0.0786 - val_mae: 0.1335
# Epoch 1242/30000
# 480/480 - 12s - loss: 0.1083 - mse: 0.0505 - mae: 0.1083 - val_loss: 0.1376 - val_mse: 0.0804 - val_mae: 0.1376
# Epoch 1243/30000
# 480/480 - 12s - loss: 0.1081 - mse: 0.0504 - mae: 0.1081 - val_loss: 0.1331 - val_mse: 0.0783 - val_mae: 0.1331

# %%
#%tensorboard --logdir logs/fit

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrainz = Trainset/255.
Xtrainz2 = sc_X2.transform(Trainset2)
y_pred = model.predict([Xtrainz,Xtrainz2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.07 degrees
# Root Mean Squared Error is 0.77 degrees
# Mean Absolute Error is 0.77 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset/255.
Xtest2 = sc_X2.transform(Testset2)
y_pred = model.predict([Xtest,Xtest2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is -0.04 degrees
# Root Mean Squared Error is 1.58 degrees
# Mean Absolute Error is 1.58 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v23_pb.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,sc_X2,modelhistory], file)
        
#     !mkdir -p saved_model
#     model.save('saved_model/cnn3v22')

# %%
model.save('saved_model/cnn3v23.h5')
