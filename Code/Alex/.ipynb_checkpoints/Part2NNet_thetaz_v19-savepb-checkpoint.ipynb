# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats
import os

# %%
# Add tensorboard stuff
# %load_ext tensorboard
# import datetime

# !rm -rf ./logs/

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#             gray_frame = frame/np.maximum(np.max(frame),255) keep as int8 for memory savings
            gray_frame = frame
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)

n_test = (1,2,24,30,31,32,33,35,1,3)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
        
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    
    data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
#     data_dir = os.path.join(r'C:\Users\Alex\Box\CS598 - Final Project\Preliminary Data V5','Test_Subject_'+subj[i],test_str)
#     train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    train_dcamera_path = os.path.join(data_dir , 'depth_processed_'+subj[i]+'_test'+str(n_test[i])+'.avi')
    xtemp[i] = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize).astype('uint8')

# %%
tlen=0
for x in range(len(xtemp)):
    tlen+= xtemp[x].shape[0]
xrun_cum = 0
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]),dtype='uint8')
for i in range (len(xtemp)):
    xrun_n = len(xtemp[i])
    x_train[xrun_cum:xrun_cum+xrun_n,:,:,:] = xtemp[i][:xrun_n,:,:,:]
    xrun_cum += xrun_n

# %%
x_train.shape
# Out:
# (153421, 60, 80, 3)

# %%
plt.imshow(x_train[153418])

# %%
print(x_train.shape)
del xtemp
# Out:
# (153421, 60, 80, 3)

# %% [markdown]
# # read fcss data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
subjwgt = [61,61, 67, 67, 67, 67, 67, 67, 70, 70]
subjht = [180, 180, 170, 170, 170, 170, 170, 170, 174, 174]
xfcss_gt = {}
yrun = 0
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    fcss_data_dir = os.path.join(data_dir , 'fcss_processed_'+subj[i]+'_' + test_str + '_' + date[i] + '.txt')
    xfcss_gttemp = pd.read_csv(fcss_data_dir)
    xfcss_gt[i]=xfcss_gttemp
    xfcss_gt[i]['weight'] = subjwgt[i]# hacky but will work for now
    xfcss_gt[i]['height'] = subjht[i]# hacky but will work for now
    if i==0:
        xfcss_train=xfcss_gttemp
    else:
        xfcss_train = pd.concat([xfcss_train,xfcss_gt[i]],axis=0)
del xfcss_gt

# %%
xfcss_train
# Out:
#        Fz bottom (kg)  Fz left (kg)  Fz right (kg)  Fx left (kg)  \
# 0              -50.52        -11.53         -12.09          9.16
# 1              -50.32        -11.58         -12.22          9.16
# 2              -50.18        -11.66         -12.37          9.14
# 3              -50.09        -11.76         -12.48          9.15
# 4              -50.09        -11.84         -12.59          9.14
# ...               ...           ...            ...           ...
# 23050          -49.75        -19.08         -17.40         11.51
# 23051          -49.78        -18.89         -17.38         11.59
# 23052          -49.75        -18.64         -17.39         11.63
# 23053          -49.72        -18.41         -17.42         11.70
# 23054          -49.73        -18.21         -17.44         11.79
#
#        Fx right (kg)  Fy (kg)  weight  height
# 0              11.96     0.24      61     180
# 1              11.89     0.19      61     180
# 2              11.85     0.16      61     180
# 3              11.89     0.14      61     180
# 4              11.99     0.14      61     180
# ...              ...      ...     ...     ...
# 23050          12.78     0.41      70     174
# 23051          12.51     0.49      70     174
# 23052          12.18     0.54      70     174
# 23053          11.89     0.56      70     174
# 23054          11.61     0.52      70     174
#
# [153421 rows x 8 columns]

# %% [markdown]
# # Read Output Data

# %%
n_test = (1,2,24,30,31,32,33,35,1,3)
date = ('12_2_2020','12_11_2020','11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020','12_2_2020','12_11_2020')
subj = ['cz','cz','leo','leo','leo','leo','leo','leo','yc','yc']
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = 'test' + str(n_test[i])
    data_dir = os.path.join('/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5','Test_Subject_'+subj[i],test_str)
    qtm_file_data_dir = os.path.join(data_dir , 'qtm_processed_'+subj[i]+'_test' + str(n_test[i]) + '_' + date[i] + '.txt')
    y_gt[i] = read_output_data(qtm_file_data_dir,theta_interest).values

    

# tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
# y_train = np.zeros((tlen,1))
# xrun = len(y_gt[0])
# y_train[:xrun] = y_gt[0][:xrun]
# xrun1 = xrun + len(y_gt[1])
# y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
# xrun2 = xrun1 + len(y_gt[2])
# y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
# xrun3 = xrun2 + len(y_gt[3])
# y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
# xrun4 = xrun3 + len(y_gt[4])
# y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
# xrun5 = xrun4 + len(y_gt[5])
# y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]
# del y_gt

# %%
tlen=0
for x in range(len(y_gt)):
    tlen+= y_gt[x].shape[0]
yrun_cum = 0
y_train = np.zeros((tlen,1))
for i in range (len(y_gt)):
    yrun_n = len(y_gt[i])
    y_train[yrun_cum:yrun_cum+yrun_n] = y_gt[i][:]
    yrun_cum += yrun_n

# %%
## Saturate output
def saturate(theta, min_val, max_val):
    for i in range(len(theta)):
        if theta[i] < min_val:
            theta[i] = min_val
            continue
        if theta[i] > max_val:
            theta[i] = max_val
            continue
    return theta
            
min_val = -50
max_val = 50
    
y_train = saturate(y_train, min_val, max_val)

# %%
print(x_train.shape)
print(xfcss_train.shape)
print(y_train.shape)
# Out:
# (153421, 60, 80, 3)
# (153421, 8)
# (153421, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Trainset2 = xfcss_train.values[rannums,:]
Testset = x_train[test_set,:]
Testset2 = xfcss_train.values[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_X2 = StandardScaler()
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
Xtrainz2 = Trainset2
ytrainz = Trainy
X = Xtrainz
X2 = sc_X2.fit_transform(Xtrainz2)
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset
Xvalid2 = sc_X2.transform(Testset2)
y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
# clear up some used variables
del Trainset
del Trainset2
del Testset
del Testset2

# %% [markdown]
# # Regress using Neural Network

# %%
x_train.shape
# Out:
# (153421, 60, 80, 3)

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()
from tensorflow.keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, concatenate, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Activation, Dropout, Reshape, Permute, Flatten
from tensorflow.keras.models import Model
dropout_rate = 0.2

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_start2 = Input(shape=(xfcss_train.shape[1],))
model_cnn = model_start
model_perc = model_start2

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_perc = Dense(100)(model_perc)
model_perc = Activation('relu')(model_perc)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Conv2D(filters=96, kernel_size=(3, 3),padding='same')(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)

model_cnn = Flatten()(model_cnn)
# model_perc = Flatten()(model_perc)
# model_cnn = Activation('relu')(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_comb = concatenate([model_cnn,model_perc],axis=-1)

model_comb = Dense(100)(model_comb)
model_comb = Activation('relu')(model_comb)
model_comb = Dropout(dropout_rate)(model_comb)

output = Dense(1)(model_comb)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=[model_start,model_start2],outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60, 80, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 60, 80, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 60, 80, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 30, 40, 16)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 30, 40, 32)   4640        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 40, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 15, 20, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 15, 20, 64)   18496       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 20, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 7, 10, 64)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 10, 96)    55392       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 10, 96)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 3, 5, 96)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          900         input_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1440)         0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          184448      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       activation_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 228)          0           activation_6[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          22900       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            101         dropout[0][0]
# __________________________________________________________________________________________________
# thetaz_out (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 297,425
# Trainable params: 297,425
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print(tf.__version__)
# Out:
# 2.1.2

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# # create data generator
# def get_generator_cyclic(features1, features2, labels, batch_size=256):
#     while True:
#         for n in range(int(len(features1)/batch_size)):
#             yield [features1[n*batch_size: (n+1)*batch_size]/255., features2[n*batch_size: (n+1)*batch_size], labels[n*batch_size: (n+1)*batch_size]]
#         permuted = np.random.permutation(len(features1))
#         features1 = features1[permuted]
#         features2 = features2[permuted]
#         labels = labels[permuted]

# %%
# x1, x2, y = next(training_generator)
# plt.imshow(x1[0])

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# image_data_gen = ImageDataGenerator(rescale=1/255.,height_shift_range=0.2, fill_mode='nearest')

# %%
epochs = int(30000)
batch_size = 256
# training_generator = get_generator_cyclic(Xtrainz, Xtrainz2, ytrainz, batch_size=batch_size)
history = model.fit([X/255.,X2], y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = ([Xvalid/255.,Xvalid2], y_valid),verbose=2)
# history = model.fit_generator(get_generator_cyclic(Xtrainz, Xtrainz2, ytrainz, batch_size=batch_size))


# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 122736 samples, validate on 30685 samples
# Epoch 1/30000
# 122736/122736 - 16s - loss: 0.5064 - mse: 0.6181 - mae: 0.5064 - val_loss: 0.4702 - val_mse: 0.5210 - val_mae: 0.4702
# Epoch 2/30000
# 122736/122736 - 14s - loss: 0.4272 - mse: 0.4579 - mae: 0.4272 - val_loss: 0.3932 - val_mse: 0.4105 - val_mae: 0.3932
# Epoch 3/30000
# 122736/122736 - 14s - loss: 0.3822 - mse: 0.3807 - mae: 0.3822 - val_loss: 0.3561 - val_mse: 0.3510 - val_mae: 0.3561
# Epoch 4/30000
# 122736/122736 - 14s - loss: 0.3541 - mse: 0.3399 - mae: 0.3541 - val_loss: 0.3373 - val_mse: 0.3259 - val_mae: 0.3373
# Epoch 5/30000
# 122736/122736 - 14s - loss: 0.3340 - mse: 0.3115 - mae: 0.3340 - val_loss: 0.3195 - val_mse: 0.2984 - val_mae: 0.3195
# Epoch 6/30000
# 122736/122736 - 14s - loss: 0.3195 - mse: 0.2912 - mae: 0.3195 - val_loss: 0.3140 - val_mse: 0.2877 - val_mae: 0.3140
# Epoch 7/30000
# 122736/122736 - 14s - loss: 0.3075 - mse: 0.2744 - mae: 0.3075 - val_loss: 0.2921 - val_mse: 0.2645 - val_mae: 0.2921
# Epoch 8/30000
# 122736/122736 - 14s - loss: 0.2957 - mse: 0.2589 - mae: 0.2957 - val_loss: 0.2836 - val_mse: 0.2517 - val_mae: 0.2836
# Epoch 9/30000
# 122736/122736 - 14s - loss: 0.2859 - mse: 0.2459 - mae: 0.2859 - val_loss: 0.2760 - val_mse: 0.2416 - val_mae: 0.2760
# Epoch 10/30000
# 122736/122736 - 14s - loss: 0.2790 - mse: 0.2365 - mae: 0.2790 - val_loss: 0.2736 - val_mse: 0.2370 - val_mae: 0.2736
# Epoch 11/30000
# 122736/122736 - 14s - loss: 0.2698 - mse: 0.2260 - mae: 0.2698 - val_loss: 0.2596 - val_mse: 0.2252 - val_mae: 0.2596
# Epoch 12/30000
# 122736/122736 - 14s - loss: 0.2629 - mse: 0.2170 - mae: 0.2629 - val_loss: 0.2547 - val_mse: 0.2154 - val_mae: 0.2547
# Epoch 13/30000
# 122736/122736 - 14s - loss: 0.2571 - mse: 0.2094 - mae: 0.2571 - val_loss: 0.2528 - val_mse: 0.2139 - val_mae: 0.2528
# Epoch 14/30000
# 122736/122736 - 14s - loss: 0.2518 - mse: 0.2027 - mae: 0.2518 - val_loss: 0.2446 - val_mse: 0.2051 - val_mae: 0.2446
# Epoch 15/30000
# 122736/122736 - 14s - loss: 0.2462 - mse: 0.1965 - mae: 0.2462 - val_loss: 0.2456 - val_mse: 0.2040 - val_mae: 0.2456
# Epoch 16/30000
# 122736/122736 - 14s - loss: 0.2419 - mse: 0.1902 - mae: 0.2419 - val_loss: 0.2339 - val_mse: 0.1927 - val_mae: 0.2339
# Epoch 17/30000
# 122736/122736 - 14s - loss: 0.2361 - mse: 0.1846 - mae: 0.2361 - val_loss: 0.2357 - val_mse: 0.1902 - val_mae: 0.2357
# Epoch 18/30000
# 122736/122736 - 14s - loss: 0.2325 - mse: 0.1790 - mae: 0.2325 - val_loss: 0.2283 - val_mse: 0.1837 - val_mae: 0.2283
# Epoch 19/30000
# 122736/122736 - 14s - loss: 0.2279 - mse: 0.1733 - mae: 0.2279 - val_loss: 0.2285 - val_mse: 0.1835 - val_mae: 0.2285
# Epoch 20/30000
# 122736/122736 - 14s - loss: 0.2255 - mse: 0.1707 - mae: 0.2255 - val_loss: 0.2288 - val_mse: 0.1827 - val_mae: 0.2288
# Epoch 21/30000
# 122736/122736 - 14s - loss: 0.2206 - mse: 0.1652 - mae: 0.2206 - val_loss: 0.2202 - val_mse: 0.1735 - val_mae: 0.2202
# Epoch 22/30000
# 122736/122736 - 14s - loss: 0.2182 - mse: 0.1618 - mae: 0.2182 - val_loss: 0.2196 - val_mse: 0.1714 - val_mae: 0.2196
# Epoch 23/30000
# 122736/122736 - 14s - loss: 0.2136 - mse: 0.1564 - mae: 0.2136 - val_loss: 0.2127 - val_mse: 0.1654 - val_mae: 0.2127
# Epoch 24/30000
# 122736/122736 - 14s - loss: 0.2109 - mse: 0.1534 - mae: 0.2109 - val_loss: 0.2143 - val_mse: 0.1660 - val_mae: 0.2143
# Epoch 25/30000
# 122736/122736 - 14s - loss: 0.2080 - mse: 0.1497 - mae: 0.2080 - val_loss: 0.2096 - val_mse: 0.1601 - val_mae: 0.2096
# Epoch 26/30000
# 122736/122736 - 14s - loss: 0.2058 - mse: 0.1467 - mae: 0.2058 - val_loss: 0.2021 - val_mse: 0.1542 - val_mae: 0.2021
# Epoch 27/30000
# 122736/122736 - 14s - loss: 0.2034 - mse: 0.1434 - mae: 0.2034 - val_loss: 0.2060 - val_mse: 0.1543 - val_mae: 0.2060
# Epoch 28/30000
# 122736/122736 - 14s - loss: 0.2008 - mse: 0.1403 - mae: 0.2008 - val_loss: 0.1965 - val_mse: 0.1473 - val_mae: 0.1965
# Epoch 29/30000
# 122736/122736 - 14s - loss: 0.1980 - mse: 0.1365 - mae: 0.1980 - val_loss: 0.1991 - val_mse: 0.1469 - val_mae: 0.1991
# Epoch 30/30000
# 122736/122736 - 14s - loss: 0.1968 - mse: 0.1336 - mae: 0.1968 - val_loss: 0.2037 - val_mse: 0.1502 - val_mae: 0.2037
# Epoch 31/30000
# 122736/122736 - 14s - loss: 0.1936 - mse: 0.1288 - mae: 0.1936 - val_loss: 0.1978 - val_mse: 0.1439 - val_mae: 0.1978
# Epoch 32/30000
# 122736/122736 - 14s - loss: 0.1914 - mse: 0.1251 - mae: 0.1914 - val_loss: 0.1948 - val_mse: 0.1387 - val_mae: 0.1948
# Epoch 33/30000
# 122736/122736 - 14s - loss: 0.1899 - mse: 0.1233 - mae: 0.1899 - val_loss: 0.1951 - val_mse: 0.1408 - val_mae: 0.1951
# Epoch 34/30000
# 122736/122736 - 14s - loss: 0.1882 - mse: 0.1197 - mae: 0.1882 - val_loss: 0.1894 - val_mse: 0.1339 - val_mae: 0.1894
# Epoch 35/30000
# 122736/122736 - 14s - loss: 0.1858 - mse: 0.1175 - mae: 0.1858 - val_loss: 0.1973 - val_mse: 0.1385 - val_mae: 0.1973
# Epoch 36/30000
# 122736/122736 - 14s - loss: 0.1840 - mse: 0.1153 - mae: 0.1840 - val_loss: 0.1894 - val_mse: 0.1328 - val_mae: 0.1894
# Epoch 37/30000
# 122736/122736 - 14s - loss: 0.1823 - mse: 0.1131 - mae: 0.1823 - val_loss: 0.1873 - val_mse: 0.1304 - val_mae: 0.1873
# Epoch 38/30000
# 122736/122736 - 14s - loss: 0.1811 - mse: 0.1114 - mae: 0.1811 - val_loss: 0.1906 - val_mse: 0.1325 - val_mae: 0.1906
# Epoch 39/30000
# 122736/122736 - 14s - loss: 0.1789 - mse: 0.1093 - mae: 0.1789 - val_loss: 0.1867 - val_mse: 0.1277 - val_mae: 0.1867
# Epoch 40/30000
# 122736/122736 - 14s - loss: 0.1769 - mse: 0.1070 - mae: 0.1769 - val_loss: 0.1853 - val_mse: 0.1259 - val_mae: 0.1853
# Epoch 41/30000
# 122736/122736 - 14s - loss: 0.1756 - mse: 0.1058 - mae: 0.1756 - val_loss: 0.1840 - val_mse: 0.1234 - val_mae: 0.1840
# Epoch 42/30000
# 122736/122736 - 14s - loss: 0.1744 - mse: 0.1041 - mae: 0.1744 - val_loss: 0.1807 - val_mse: 0.1215 - val_mae: 0.1807
# Epoch 43/30000
# 122736/122736 - 14s - loss: 0.1727 - mse: 0.1028 - mae: 0.1727 - val_loss: 0.1811 - val_mse: 0.1230 - val_mae: 0.1811
# Epoch 44/30000
# 122736/122736 - 14s - loss: 0.1714 - mse: 0.1011 - mae: 0.1714 - val_loss: 0.1766 - val_mse: 0.1183 - val_mae: 0.1766
# Epoch 45/30000
# 122736/122736 - 14s - loss: 0.1700 - mse: 0.0995 - mae: 0.1700 - val_loss: 0.1818 - val_mse: 0.1219 - val_mae: 0.1818
# Epoch 46/30000
# 122736/122736 - 14s - loss: 0.1693 - mse: 0.0992 - mae: 0.1693 - val_loss: 0.1769 - val_mse: 0.1166 - val_mae: 0.1769
# Epoch 47/30000
# 122736/122736 - 14s - loss: 0.1679 - mse: 0.0974 - mae: 0.1679 - val_loss: 0.1771 - val_mse: 0.1185 - val_mae: 0.1771
# Epoch 48/30000
# 122736/122736 - 14s - loss: 0.1665 - mse: 0.0963 - mae: 0.1665 - val_loss: 0.1753 - val_mse: 0.1145 - val_mae: 0.1753
# Epoch 49/30000
# 122736/122736 - 14s - loss: 0.1649 - mse: 0.0945 - mae: 0.1649 - val_loss: 0.1761 - val_mse: 0.1183 - val_mae: 0.1761
# Epoch 50/30000
# 122736/122736 - 14s - loss: 0.1647 - mse: 0.0941 - mae: 0.1647 - val_loss: 0.1727 - val_mse: 0.1131 - val_mae: 0.1727
# Epoch 51/30000
# 122736/122736 - 14s - loss: 0.1634 - mse: 0.0934 - mae: 0.1634 - val_loss: 0.1763 - val_mse: 0.1148 - val_mae: 0.1763
# Epoch 52/30000
# 122736/122736 - 14s - loss: 0.1619 - mse: 0.0918 - mae: 0.1619 - val_loss: 0.1730 - val_mse: 0.1127 - val_mae: 0.1730
# Epoch 53/30000
# 122736/122736 - 14s - loss: 0.1609 - mse: 0.0905 - mae: 0.1609 - val_loss: 0.1688 - val_mse: 0.1117 - val_mae: 0.1688
# Epoch 54/30000
# 122736/122736 - 14s - loss: 0.1597 - mse: 0.0900 - mae: 0.1597 - val_loss: 0.1711 - val_mse: 0.1118 - val_mae: 0.1711
# Epoch 55/30000
# 122736/122736 - 14s - loss: 0.1588 - mse: 0.0888 - mae: 0.1588 - val_loss: 0.1702 - val_mse: 0.1117 - val_mae: 0.1702
# Epoch 56/30000
# 122736/122736 - 14s - loss: 0.1587 - mse: 0.0888 - mae: 0.1587 - val_loss: 0.1694 - val_mse: 0.1111 - val_mae: 0.1694
# Epoch 57/30000
# 122736/122736 - 14s - loss: 0.1575 - mse: 0.0878 - mae: 0.1575 - val_loss: 0.1700 - val_mse: 0.1093 - val_mae: 0.1700
# Epoch 58/30000
# 122736/122736 - 14s - loss: 0.1567 - mse: 0.0865 - mae: 0.1567 - val_loss: 0.1714 - val_mse: 0.1105 - val_mae: 0.1714
# Epoch 59/30000
# 122736/122736 - 14s - loss: 0.1558 - mse: 0.0858 - mae: 0.1558 - val_loss: 0.1685 - val_mse: 0.1098 - val_mae: 0.1685
# Epoch 60/30000
# 122736/122736 - 14s - loss: 0.1546 - mse: 0.0855 - mae: 0.1546 - val_loss: 0.1678 - val_mse: 0.1080 - val_mae: 0.1678
# Epoch 61/30000
# 122736/122736 - 14s - loss: 0.1533 - mse: 0.0837 - mae: 0.1533 - val_loss: 0.1696 - val_mse: 0.1091 - val_mae: 0.1696
# Epoch 62/30000
# 122736/122736 - 14s - loss: 0.1526 - mse: 0.0829 - mae: 0.1526 - val_loss: 0.1653 - val_mse: 0.1057 - val_mae: 0.1653
# Epoch 63/30000
# 122736/122736 - 14s - loss: 0.1534 - mse: 0.0834 - mae: 0.1534 - val_loss: 0.1645 - val_mse: 0.1065 - val_mae: 0.1645
# Epoch 64/30000
# 122736/122736 - 14s - loss: 0.1513 - mse: 0.0819 - mae: 0.1513 - val_loss: 0.1666 - val_mse: 0.1067 - val_mae: 0.1666
# Epoch 65/30000
# 122736/122736 - 14s - loss: 0.1508 - mse: 0.0814 - mae: 0.1508 - val_loss: 0.1656 - val_mse: 0.1059 - val_mae: 0.1656
# Epoch 66/30000
# 122736/122736 - 14s - loss: 0.1500 - mse: 0.0809 - mae: 0.1500 - val_loss: 0.1632 - val_mse: 0.1045 - val_mae: 0.1632
# Epoch 67/30000
# 122736/122736 - 14s - loss: 0.1494 - mse: 0.0798 - mae: 0.1494 - val_loss: 0.1625 - val_mse: 0.1035 - val_mae: 0.1625
# Epoch 68/30000
# 122736/122736 - 14s - loss: 0.1483 - mse: 0.0792 - mae: 0.1483 - val_loss: 0.1636 - val_mse: 0.1064 - val_mae: 0.1636
# Epoch 69/30000
# 122736/122736 - 14s - loss: 0.1479 - mse: 0.0788 - mae: 0.1479 - val_loss: 0.1596 - val_mse: 0.1014 - val_mae: 0.1596
# Epoch 70/30000
# 122736/122736 - 14s - loss: 0.1471 - mse: 0.0781 - mae: 0.1471 - val_loss: 0.1611 - val_mse: 0.1032 - val_mae: 0.1611
# Epoch 71/30000
# 122736/122736 - 14s - loss: 0.1463 - mse: 0.0775 - mae: 0.1463 - val_loss: 0.1621 - val_mse: 0.1032 - val_mae: 0.1621
# Epoch 72/30000
# 122736/122736 - 14s - loss: 0.1452 - mse: 0.0765 - mae: 0.1452 - val_loss: 0.1617 - val_mse: 0.1035 - val_mae: 0.1617
# Epoch 73/30000
# 122736/122736 - 14s - loss: 0.1458 - mse: 0.0765 - mae: 0.1458 - val_loss: 0.1627 - val_mse: 0.1010 - val_mae: 0.1627
# Epoch 74/30000
# 122736/122736 - 14s - loss: 0.1450 - mse: 0.0755 - mae: 0.1450 - val_loss: 0.1664 - val_mse: 0.1043 - val_mae: 0.1664
# Epoch 75/30000
# 122736/122736 - 14s - loss: 0.1450 - mse: 0.0764 - mae: 0.1450 - val_loss: 0.1578 - val_mse: 0.0983 - val_mae: 0.1578
# Epoch 76/30000
# 122736/122736 - 14s - loss: 0.1430 - mse: 0.0745 - mae: 0.1430 - val_loss: 0.1577 - val_mse: 0.1003 - val_mae: 0.1577
# Epoch 77/30000
# 122736/122736 - 14s - loss: 0.1427 - mse: 0.0743 - mae: 0.1427 - val_loss: 0.1576 - val_mse: 0.0985 - val_mae: 0.1576
# Epoch 78/30000
# 122736/122736 - 14s - loss: 0.1419 - mse: 0.0735 - mae: 0.1419 - val_loss: 0.1570 - val_mse: 0.0966 - val_mae: 0.1570
# Epoch 79/30000
# 122736/122736 - 14s - loss: 0.1420 - mse: 0.0733 - mae: 0.1420 - val_loss: 0.1612 - val_mse: 0.1019 - val_mae: 0.1612
# Epoch 80/30000
# 122736/122736 - 14s - loss: 0.1418 - mse: 0.0733 - mae: 0.1418 - val_loss: 0.1576 - val_mse: 0.0988 - val_mae: 0.1576
# Epoch 81/30000
# 122736/122736 - 14s - loss: 0.1408 - mse: 0.0729 - mae: 0.1408 - val_loss: 0.1563 - val_mse: 0.0985 - val_mae: 0.1563
# Epoch 82/30000
# 122736/122736 - 14s - loss: 0.1402 - mse: 0.0728 - mae: 0.1402 - val_loss: 0.1556 - val_mse: 0.0971 - val_mae: 0.1556
# Epoch 83/30000
# 122736/122736 - 14s - loss: 0.1396 - mse: 0.0710 - mae: 0.1396 - val_loss: 0.1554 - val_mse: 0.0959 - val_mae: 0.1554
# Epoch 84/30000
# 122736/122736 - 14s - loss: 0.1389 - mse: 0.0705 - mae: 0.1389 - val_loss: 0.1566 - val_mse: 0.0985 - val_mae: 0.1566
# Epoch 85/30000
# 122736/122736 - 14s - loss: 0.1385 - mse: 0.0707 - mae: 0.1385 - val_loss: 0.1568 - val_mse: 0.0993 - val_mae: 0.1568
# Epoch 86/30000
# 122736/122736 - 14s - loss: 0.1391 - mse: 0.0709 - mae: 0.1391 - val_loss: 0.1544 - val_mse: 0.0957 - val_mae: 0.1544
# Epoch 87/30000
# 122736/122736 - 14s - loss: 0.1377 - mse: 0.0697 - mae: 0.1377 - val_loss: 0.1575 - val_mse: 0.0984 - val_mae: 0.1575
# Epoch 88/30000
# 122736/122736 - 14s - loss: 0.1370 - mse: 0.0695 - mae: 0.1370 - val_loss: 0.1537 - val_mse: 0.0956 - val_mae: 0.1537
# Epoch 89/30000
# 122736/122736 - 14s - loss: 0.1375 - mse: 0.0701 - mae: 0.1375 - val_loss: 0.1571 - val_mse: 0.0979 - val_mae: 0.1571
# Epoch 90/30000
# 122736/122736 - 14s - loss: 0.1359 - mse: 0.0682 - mae: 0.1359 - val_loss: 0.1554 - val_mse: 0.0978 - val_mae: 0.1554
# Epoch 91/30000
# 122736/122736 - 14s - loss: 0.1368 - mse: 0.0693 - mae: 0.1368 - val_loss: 0.1505 - val_mse: 0.0926 - val_mae: 0.1505
# Epoch 92/30000
# 122736/122736 - 14s - loss: 0.1353 - mse: 0.0681 - mae: 0.1353 - val_loss: 0.1530 - val_mse: 0.0972 - val_mae: 0.1530
# Epoch 93/30000
# 122736/122736 - 14s - loss: 0.1348 - mse: 0.0675 - mae: 0.1348 - val_loss: 0.1550 - val_mse: 0.0961 - val_mae: 0.1550
# Epoch 94/30000
# 122736/122736 - 14s - loss: 0.1342 - mse: 0.0667 - mae: 0.1342 - val_loss: 0.1534 - val_mse: 0.0970 - val_mae: 0.1534
# Epoch 95/30000
# 122736/122736 - 14s - loss: 0.1342 - mse: 0.0670 - mae: 0.1342 - val_loss: 0.1515 - val_mse: 0.0928 - val_mae: 0.1515
# Epoch 96/30000
# 122736/122736 - 14s - loss: 0.1342 - mse: 0.0669 - mae: 0.1342 - val_loss: 0.1559 - val_mse: 0.0947 - val_mae: 0.1559
# Epoch 97/30000
# 122736/122736 - 14s - loss: 0.1336 - mse: 0.0669 - mae: 0.1336 - val_loss: 0.1521 - val_mse: 0.0929 - val_mae: 0.1521
# Epoch 98/30000
# 122736/122736 - 14s - loss: 0.1334 - mse: 0.0664 - mae: 0.1334 - val_loss: 0.1521 - val_mse: 0.0926 - val_mae: 0.1521
# Epoch 99/30000
# 122736/122736 - 14s - loss: 0.1332 - mse: 0.0660 - mae: 0.1332 - val_loss: 0.1592 - val_mse: 0.0960 - val_mae: 0.1592
# Epoch 100/30000
# 122736/122736 - 14s - loss: 0.1319 - mse: 0.0654 - mae: 0.1319 - val_loss: 0.1540 - val_mse: 0.0945 - val_mae: 0.1540
# Epoch 101/30000
# 122736/122736 - 14s - loss: 0.1320 - mse: 0.0651 - mae: 0.1320 - val_loss: 0.1515 - val_mse: 0.0934 - val_mae: 0.1515
# Epoch 102/30000
# 122736/122736 - 14s - loss: 0.1316 - mse: 0.0650 - mae: 0.1316 - val_loss: 0.1536 - val_mse: 0.0933 - val_mae: 0.1536
# Epoch 103/30000
# 122736/122736 - 14s - loss: 0.1307 - mse: 0.0644 - mae: 0.1307 - val_loss: 0.1512 - val_mse: 0.0932 - val_mae: 0.1512
# Epoch 104/30000
# 122736/122736 - 14s - loss: 0.1307 - mse: 0.0646 - mae: 0.1307 - val_loss: 0.1550 - val_mse: 0.0951 - val_mae: 0.1550
# Epoch 105/30000
# 122736/122736 - 14s - loss: 0.1300 - mse: 0.0643 - mae: 0.1300 - val_loss: 0.1515 - val_mse: 0.0926 - val_mae: 0.1515
# Epoch 106/30000
# 122736/122736 - 14s - loss: 0.1301 - mse: 0.0637 - mae: 0.1301 - val_loss: 0.1502 - val_mse: 0.0927 - val_mae: 0.1502
# Epoch 107/30000
# 122736/122736 - 14s - loss: 0.1296 - mse: 0.0633 - mae: 0.1296 - val_loss: 0.1532 - val_mse: 0.0937 - val_mae: 0.1532
# Epoch 108/30000
# 122736/122736 - 14s - loss: 0.1293 - mse: 0.0630 - mae: 0.1293 - val_loss: 0.1507 - val_mse: 0.0927 - val_mae: 0.1507
# Epoch 109/30000
# 122736/122736 - 14s - loss: 0.1289 - mse: 0.0628 - mae: 0.1289 - val_loss: 0.1496 - val_mse: 0.0910 - val_mae: 0.1496
# Epoch 110/30000
# 122736/122736 - 14s - loss: 0.1287 - mse: 0.0628 - mae: 0.1287 - val_loss: 0.1554 - val_mse: 0.0944 - val_mae: 0.1554
# Epoch 111/30000
# 122736/122736 - 14s - loss: 0.1277 - mse: 0.0616 - mae: 0.1277 - val_loss: 0.1514 - val_mse: 0.0924 - val_mae: 0.1514
# Epoch 112/30000
# 122736/122736 - 14s - loss: 0.1274 - mse: 0.0616 - mae: 0.1274 - val_loss: 0.1476 - val_mse: 0.0892 - val_mae: 0.1476
# Epoch 113/30000
# 122736/122736 - 14s - loss: 0.1276 - mse: 0.0620 - mae: 0.1276 - val_loss: 0.1482 - val_mse: 0.0905 - val_mae: 0.1482
# Epoch 114/30000
# 122736/122736 - 14s - loss: 0.1274 - mse: 0.0619 - mae: 0.1274 - val_loss: 0.1514 - val_mse: 0.0918 - val_mae: 0.1514
# Epoch 115/30000
# 122736/122736 - 14s - loss: 0.1271 - mse: 0.0614 - mae: 0.1271 - val_loss: 0.1499 - val_mse: 0.0914 - val_mae: 0.1499
# Epoch 116/30000
# 122736/122736 - 14s - loss: 0.1272 - mse: 0.0612 - mae: 0.1272 - val_loss: 0.1497 - val_mse: 0.0902 - val_mae: 0.1497
# Epoch 117/30000
# 122736/122736 - 14s - loss: 0.1271 - mse: 0.0618 - mae: 0.1271 - val_loss: 0.1496 - val_mse: 0.0904 - val_mae: 0.1496
# Epoch 118/30000
# 122736/122736 - 14s - loss: 0.1266 - mse: 0.0616 - mae: 0.1266 - val_loss: 0.1485 - val_mse: 0.0897 - val_mae: 0.1485
# Epoch 119/30000
# 122736/122736 - 14s - loss: 0.1254 - mse: 0.0608 - mae: 0.1254 - val_loss: 0.1493 - val_mse: 0.0910 - val_mae: 0.1493
# Epoch 120/30000
# 122736/122736 - 14s - loss: 0.1259 - mse: 0.0607 - mae: 0.1259 - val_loss: 0.1473 - val_mse: 0.0881 - val_mae: 0.1473
# Epoch 121/30000
# 122736/122736 - 14s - loss: 0.1251 - mse: 0.0596 - mae: 0.1251 - val_loss: 0.1473 - val_mse: 0.0893 - val_mae: 0.1473
# Epoch 122/30000
# 122736/122736 - 14s - loss: 0.1254 - mse: 0.0601 - mae: 0.1254 - val_loss: 0.1480 - val_mse: 0.0892 - val_mae: 0.1480
# Epoch 123/30000
# 122736/122736 - 14s - loss: 0.1253 - mse: 0.0602 - mae: 0.1253 - val_loss: 0.1494 - val_mse: 0.0922 - val_mae: 0.1494
# Epoch 124/30000
# 122736/122736 - 14s - loss: 0.1245 - mse: 0.0598 - mae: 0.1245 - val_loss: 0.1477 - val_mse: 0.0928 - val_mae: 0.1477
# Epoch 125/30000
# 122736/122736 - 14s - loss: 0.1240 - mse: 0.0594 - mae: 0.1240 - val_loss: 0.1480 - val_mse: 0.0907 - val_mae: 0.1480
# Epoch 126/30000
# 122736/122736 - 14s - loss: 0.1247 - mse: 0.0601 - mae: 0.1247 - val_loss: 0.1472 - val_mse: 0.0895 - val_mae: 0.1472
# Epoch 127/30000
# 122736/122736 - 14s - loss: 0.1235 - mse: 0.0592 - mae: 0.1235 - val_loss: 0.1487 - val_mse: 0.0915 - val_mae: 0.1487
# Epoch 128/30000
# 122736/122736 - 14s - loss: 0.1241 - mse: 0.0593 - mae: 0.1241 - val_loss: 0.1461 - val_mse: 0.0876 - val_mae: 0.1461
# Epoch 129/30000
# 122736/122736 - 14s - loss: 0.1231 - mse: 0.0585 - mae: 0.1231 - val_loss: 0.1445 - val_mse: 0.0873 - val_mae: 0.1445
# Epoch 130/30000
# 122736/122736 - 14s - loss: 0.1223 - mse: 0.0582 - mae: 0.1223 - val_loss: 0.1480 - val_mse: 0.0909 - val_mae: 0.1480
# Epoch 131/30000
# 122736/122736 - 14s - loss: 0.1228 - mse: 0.0588 - mae: 0.1228 - val_loss: 0.1454 - val_mse: 0.0896 - val_mae: 0.1454
# Epoch 132/30000
# 122736/122736 - 14s - loss: 0.1229 - mse: 0.0585 - mae: 0.1229 - val_loss: 0.1471 - val_mse: 0.0889 - val_mae: 0.1471
# Epoch 133/30000
# 122736/122736 - 14s - loss: 0.1221 - mse: 0.0584 - mae: 0.1221 - val_loss: 0.1477 - val_mse: 0.0911 - val_mae: 0.1477
# Epoch 134/30000
# 122736/122736 - 14s - loss: 0.1218 - mse: 0.0578 - mae: 0.1218 - val_loss: 0.1475 - val_mse: 0.0897 - val_mae: 0.1475
# Epoch 135/30000
# 122736/122736 - 14s - loss: 0.1217 - mse: 0.0581 - mae: 0.1217 - val_loss: 0.1456 - val_mse: 0.0880 - val_mae: 0.1456
# Epoch 136/30000
# 122736/122736 - 14s - loss: 0.1214 - mse: 0.0575 - mae: 0.1214 - val_loss: 0.1461 - val_mse: 0.0889 - val_mae: 0.1461
# Epoch 137/30000
# 122736/122736 - 14s - loss: 0.1212 - mse: 0.0576 - mae: 0.1212 - val_loss: 0.1478 - val_mse: 0.0884 - val_mae: 0.1478
# Epoch 138/30000
# 122736/122736 - 14s - loss: 0.1208 - mse: 0.0574 - mae: 0.1208 - val_loss: 0.1442 - val_mse: 0.0876 - val_mae: 0.1442
# Epoch 139/30000
# 122736/122736 - 14s - loss: 0.1211 - mse: 0.0579 - mae: 0.1211 - val_loss: 0.1452 - val_mse: 0.0878 - val_mae: 0.1452
# Epoch 140/30000
# 122736/122736 - 14s - loss: 0.1208 - mse: 0.0572 - mae: 0.1208 - val_loss: 0.1460 - val_mse: 0.0885 - val_mae: 0.1460
# Epoch 141/30000
# 122736/122736 - 14s - loss: 0.1205 - mse: 0.0571 - mae: 0.1205 - val_loss: 0.1447 - val_mse: 0.0871 - val_mae: 0.1447
# Epoch 142/30000
# 122736/122736 - 14s - loss: 0.1201 - mse: 0.0570 - mae: 0.1201 - val_loss: 0.1456 - val_mse: 0.0885 - val_mae: 0.1456
# Epoch 143/30000
# 122736/122736 - 14s - loss: 0.1204 - mse: 0.0571 - mae: 0.1204 - val_loss: 0.1440 - val_mse: 0.0885 - val_mae: 0.1440
# Epoch 144/30000
# 122736/122736 - 14s - loss: 0.1197 - mse: 0.0566 - mae: 0.1197 - val_loss: 0.1466 - val_mse: 0.0881 - val_mae: 0.1466
# Epoch 145/30000
# 122736/122736 - 14s - loss: 0.1186 - mse: 0.0562 - mae: 0.1186 - val_loss: 0.1451 - val_mse: 0.0873 - val_mae: 0.1451
# Epoch 146/30000
# 122736/122736 - 14s - loss: 0.1196 - mse: 0.0569 - mae: 0.1196 - val_loss: 0.1445 - val_mse: 0.0868 - val_mae: 0.1445
# Epoch 147/30000
# 122736/122736 - 14s - loss: 0.1188 - mse: 0.0564 - mae: 0.1188 - val_loss: 0.1448 - val_mse: 0.0876 - val_mae: 0.1448
# Epoch 148/30000
# 122736/122736 - 14s - loss: 0.1195 - mse: 0.0566 - mae: 0.1195 - val_loss: 0.1441 - val_mse: 0.0874 - val_mae: 0.1441
# Epoch 149/30000
# 122736/122736 - 14s - loss: 0.1190 - mse: 0.0559 - mae: 0.1190 - val_loss: 0.1455 - val_mse: 0.0887 - val_mae: 0.1455
# Epoch 150/30000
# 122736/122736 - 14s - loss: 0.1189 - mse: 0.0564 - mae: 0.1189 - val_loss: 0.1454 - val_mse: 0.0874 - val_mae: 0.1454
# Epoch 151/30000
# 122736/122736 - 14s - loss: 0.1182 - mse: 0.0555 - mae: 0.1182 - val_loss: 0.1471 - val_mse: 0.0896 - val_mae: 0.1471
# Epoch 152/30000
# 122736/122736 - 14s - loss: 0.1180 - mse: 0.0555 - mae: 0.1180 - val_loss: 0.1430 - val_mse: 0.0870 - val_mae: 0.1430
# Epoch 153/30000
# 122736/122736 - 14s - loss: 0.1182 - mse: 0.0555 - mae: 0.1182 - val_loss: 0.1423 - val_mse: 0.0864 - val_mae: 0.1423
# Epoch 154/30000
# 122736/122736 - 14s - loss: 0.1179 - mse: 0.0555 - mae: 0.1179 - val_loss: 0.1458 - val_mse: 0.0868 - val_mae: 0.1458
# Epoch 155/30000
# 122736/122736 - 14s - loss: 0.1180 - mse: 0.0557 - mae: 0.1180 - val_loss: 0.1424 - val_mse: 0.0859 - val_mae: 0.1424
# Epoch 156/30000
# 122736/122736 - 14s - loss: 0.1173 - mse: 0.0550 - mae: 0.1173 - val_loss: 0.1431 - val_mse: 0.0870 - val_mae: 0.1431
# Epoch 157/30000
# 122736/122736 - 14s - loss: 0.1175 - mse: 0.0550 - mae: 0.1175 - val_loss: 0.1456 - val_mse: 0.0873 - val_mae: 0.1456
# Epoch 158/30000
# 122736/122736 - 14s - loss: 0.1163 - mse: 0.0542 - mae: 0.1163 - val_loss: 0.1450 - val_mse: 0.0890 - val_mae: 0.1450
# Epoch 159/30000
# 122736/122736 - 14s - loss: 0.1167 - mse: 0.0547 - mae: 0.1167 - val_loss: 0.1465 - val_mse: 0.0897 - val_mae: 0.1465
# Epoch 160/30000
# 122736/122736 - 14s - loss: 0.1162 - mse: 0.0541 - mae: 0.1162 - val_loss: 0.1433 - val_mse: 0.0856 - val_mae: 0.1433
# Epoch 161/30000
# 122736/122736 - 14s - loss: 0.1162 - mse: 0.0542 - mae: 0.1162 - val_loss: 0.1423 - val_mse: 0.0860 - val_mae: 0.1423
# Epoch 162/30000
# 122736/122736 - 14s - loss: 0.1162 - mse: 0.0544 - mae: 0.1162 - val_loss: 0.1459 - val_mse: 0.0875 - val_mae: 0.1459
# Epoch 163/30000
# 122736/122736 - 14s - loss: 0.1165 - mse: 0.0549 - mae: 0.1165 - val_loss: 0.1478 - val_mse: 0.0907 - val_mae: 0.1478
# Epoch 164/30000
# 122736/122736 - 14s - loss: 0.1161 - mse: 0.0545 - mae: 0.1161 - val_loss: 0.1444 - val_mse: 0.0879 - val_mae: 0.1444
# Epoch 165/30000
# 122736/122736 - 14s - loss: 0.1156 - mse: 0.0543 - mae: 0.1156 - val_loss: 0.1457 - val_mse: 0.0915 - val_mae: 0.1457
# Epoch 166/30000
# 122736/122736 - 14s - loss: 0.1159 - mse: 0.0542 - mae: 0.1159 - val_loss: 0.1425 - val_mse: 0.0864 - val_mae: 0.1425
# Epoch 167/30000
# 122736/122736 - 14s - loss: 0.1152 - mse: 0.0537 - mae: 0.1152 - val_loss: 0.1429 - val_mse: 0.0870 - val_mae: 0.1429
# Epoch 168/30000
# 122736/122736 - 14s - loss: 0.1151 - mse: 0.0538 - mae: 0.1151 - val_loss: 0.1421 - val_mse: 0.0858 - val_mae: 0.1421
# Epoch 169/30000
# 122736/122736 - 14s - loss: 0.1150 - mse: 0.0538 - mae: 0.1150 - val_loss: 0.1414 - val_mse: 0.0855 - val_mae: 0.1414
# Epoch 170/30000
# 122736/122736 - 14s - loss: 0.1143 - mse: 0.0528 - mae: 0.1143 - val_loss: 0.1445 - val_mse: 0.0884 - val_mae: 0.1445
# Epoch 171/30000
# 122736/122736 - 14s - loss: 0.1148 - mse: 0.0532 - mae: 0.1148 - val_loss: 0.1474 - val_mse: 0.0894 - val_mae: 0.1474
# Epoch 172/30000
# 122736/122736 - 14s - loss: 0.1148 - mse: 0.0540 - mae: 0.1148 - val_loss: 0.1447 - val_mse: 0.0880 - val_mae: 0.1447
# Epoch 173/30000
# 122736/122736 - 14s - loss: 0.1146 - mse: 0.0534 - mae: 0.1146 - val_loss: 0.1437 - val_mse: 0.0868 - val_mae: 0.1437
# Epoch 174/30000
# 122736/122736 - 14s - loss: 0.1140 - mse: 0.0533 - mae: 0.1140 - val_loss: 0.1426 - val_mse: 0.0885 - val_mae: 0.1426
# Epoch 175/30000
# 122736/122736 - 14s - loss: 0.1138 - mse: 0.0532 - mae: 0.1138 - val_loss: 0.1430 - val_mse: 0.0876 - val_mae: 0.1430
# Epoch 176/30000
# 122736/122736 - 14s - loss: 0.1140 - mse: 0.0529 - mae: 0.1140 - val_loss: 0.1416 - val_mse: 0.0851 - val_mae: 0.1416
# Epoch 177/30000
# 122736/122736 - 14s - loss: 0.1135 - mse: 0.0528 - mae: 0.1135 - val_loss: 0.1425 - val_mse: 0.0858 - val_mae: 0.1425
# Epoch 178/30000
# 122736/122736 - 14s - loss: 0.1135 - mse: 0.0527 - mae: 0.1135 - val_loss: 0.1404 - val_mse: 0.0846 - val_mae: 0.1404
# Epoch 179/30000
# 122736/122736 - 14s - loss: 0.1133 - mse: 0.0526 - mae: 0.1133 - val_loss: 0.1434 - val_mse: 0.0869 - val_mae: 0.1434
# Epoch 180/30000
# 122736/122736 - 14s - loss: 0.1135 - mse: 0.0528 - mae: 0.1135 - val_loss: 0.1435 - val_mse: 0.0863 - val_mae: 0.1435
# Epoch 181/30000
# 122736/122736 - 14s - loss: 0.1133 - mse: 0.0529 - mae: 0.1133 - val_loss: 0.1433 - val_mse: 0.0871 - val_mae: 0.1433
# Epoch 182/30000
# 122736/122736 - 14s - loss: 0.1125 - mse: 0.0519 - mae: 0.1125 - val_loss: 0.1456 - val_mse: 0.0886 - val_mae: 0.1456
# Epoch 183/30000
# 122736/122736 - 14s - loss: 0.1123 - mse: 0.0521 - mae: 0.1123 - val_loss: 0.1424 - val_mse: 0.0877 - val_mae: 0.1424
# Epoch 184/30000
# 122736/122736 - 14s - loss: 0.1130 - mse: 0.0524 - mae: 0.1130 - val_loss: 0.1420 - val_mse: 0.0848 - val_mae: 0.1420
# Epoch 185/30000
# 122736/122736 - 14s - loss: 0.1124 - mse: 0.0522 - mae: 0.1124 - val_loss: 0.1429 - val_mse: 0.0861 - val_mae: 0.1429
# Epoch 186/30000
# 122736/122736 - 14s - loss: 0.1124 - mse: 0.0520 - mae: 0.1124 - val_loss: 0.1462 - val_mse: 0.0932 - val_mae: 0.1462
# Epoch 187/30000
# 122736/122736 - 14s - loss: 0.1121 - mse: 0.0521 - mae: 0.1121 - val_loss: 0.1431 - val_mse: 0.0849 - val_mae: 0.1431
# Epoch 188/30000
# 122736/122736 - 14s - loss: 0.1121 - mse: 0.0519 - mae: 0.1121 - val_loss: 0.1451 - val_mse: 0.0891 - val_mae: 0.1451
# Epoch 189/30000
# 122736/122736 - 14s - loss: 0.1114 - mse: 0.0515 - mae: 0.1114 - val_loss: 0.1428 - val_mse: 0.0866 - val_mae: 0.1428
# Epoch 190/30000
# 122736/122736 - 14s - loss: 0.1121 - mse: 0.0520 - mae: 0.1121 - val_loss: 0.1427 - val_mse: 0.0857 - val_mae: 0.1427
# Epoch 191/30000
# 122736/122736 - 14s - loss: 0.1118 - mse: 0.0519 - mae: 0.1118 - val_loss: 0.1432 - val_mse: 0.0862 - val_mae: 0.1432
# Epoch 192/30000
# 122736/122736 - 14s - loss: 0.1113 - mse: 0.0516 - mae: 0.1113 - val_loss: 0.1423 - val_mse: 0.0856 - val_mae: 0.1423
# Epoch 193/30000
# 122736/122736 - 14s - loss: 0.1111 - mse: 0.0514 - mae: 0.1111 - val_loss: 0.1415 - val_mse: 0.0860 - val_mae: 0.1415
# Epoch 194/30000
# 122736/122736 - 14s - loss: 0.1111 - mse: 0.0514 - mae: 0.1111 - val_loss: 0.1453 - val_mse: 0.0872 - val_mae: 0.1453
# Epoch 195/30000
# 122736/122736 - 14s - loss: 0.1113 - mse: 0.0514 - mae: 0.1113 - val_loss: 0.1412 - val_mse: 0.0851 - val_mae: 0.1412
# Epoch 196/30000
# 122736/122736 - 14s - loss: 0.1111 - mse: 0.0514 - mae: 0.1111 - val_loss: 0.1429 - val_mse: 0.0871 - val_mae: 0.1429
# Epoch 197/30000
# 122736/122736 - 14s - loss: 0.1103 - mse: 0.0507 - mae: 0.1103 - val_loss: 0.1443 - val_mse: 0.0872 - val_mae: 0.1443
# Epoch 198/30000
# 122736/122736 - 14s - loss: 0.1106 - mse: 0.0511 - mae: 0.1106 - val_loss: 0.1418 - val_mse: 0.0858 - val_mae: 0.1418
# Epoch 199/30000
# 122736/122736 - 14s - loss: 0.1103 - mse: 0.0510 - mae: 0.1103 - val_loss: 0.1395 - val_mse: 0.0835 - val_mae: 0.1395
# Epoch 200/30000
# 122736/122736 - 14s - loss: 0.1107 - mse: 0.0511 - mae: 0.1107 - val_loss: 0.1421 - val_mse: 0.0866 - val_mae: 0.1421
# Epoch 201/30000
# 122736/122736 - 14s - loss: 0.1099 - mse: 0.0503 - mae: 0.1099 - val_loss: 0.1399 - val_mse: 0.0839 - val_mae: 0.1399
# Epoch 202/30000
# 122736/122736 - 14s - loss: 0.1105 - mse: 0.0510 - mae: 0.1105 - val_loss: 0.1439 - val_mse: 0.0868 - val_mae: 0.1439
# Epoch 203/30000
# 122736/122736 - 14s - loss: 0.1098 - mse: 0.0506 - mae: 0.1098 - val_loss: 0.1421 - val_mse: 0.0859 - val_mae: 0.1421
# Epoch 204/30000
# 122736/122736 - 14s - loss: 0.1103 - mse: 0.0512 - mae: 0.1103 - val_loss: 0.1415 - val_mse: 0.0854 - val_mae: 0.1415
# Epoch 205/30000
# 122736/122736 - 14s - loss: 0.1095 - mse: 0.0502 - mae: 0.1095 - val_loss: 0.1401 - val_mse: 0.0866 - val_mae: 0.1401
# Epoch 206/30000
# 122736/122736 - 14s - loss: 0.1089 - mse: 0.0501 - mae: 0.1089 - val_loss: 0.1419 - val_mse: 0.0856 - val_mae: 0.1419
# Epoch 207/30000
# 122736/122736 - 14s - loss: 0.1095 - mse: 0.0502 - mae: 0.1095 - val_loss: 0.1422 - val_mse: 0.0862 - val_mae: 0.1422
# Epoch 208/30000
# 122736/122736 - 14s - loss: 0.1087 - mse: 0.0500 - mae: 0.1087 - val_loss: 0.1408 - val_mse: 0.0854 - val_mae: 0.1408
# Epoch 209/30000
# 122736/122736 - 14s - loss: 0.1093 - mse: 0.0504 - mae: 0.1093 - val_loss: 0.1406 - val_mse: 0.0846 - val_mae: 0.1406
# Epoch 210/30000
# 122736/122736 - 14s - loss: 0.1090 - mse: 0.0500 - mae: 0.1090 - val_loss: 0.1422 - val_mse: 0.0854 - val_mae: 0.1422
# Epoch 211/30000
# 122736/122736 - 14s - loss: 0.1088 - mse: 0.0500 - mae: 0.1088 - val_loss: 0.1418 - val_mse: 0.0859 - val_mae: 0.1418
# Epoch 212/30000
# 122736/122736 - 14s - loss: 0.1086 - mse: 0.0496 - mae: 0.1086 - val_loss: 0.1399 - val_mse: 0.0843 - val_mae: 0.1399
# Epoch 213/30000
# 122736/122736 - 14s - loss: 0.1084 - mse: 0.0498 - mae: 0.1084 - val_loss: 0.1436 - val_mse: 0.0880 - val_mae: 0.1436
# Epoch 214/30000
# 122736/122736 - 14s - loss: 0.1082 - mse: 0.0496 - mae: 0.1082 - val_loss: 0.1398 - val_mse: 0.0845 - val_mae: 0.1398
# Epoch 215/30000
# 122736/122736 - 14s - loss: 0.1078 - mse: 0.0493 - mae: 0.1078 - val_loss: 0.1413 - val_mse: 0.0857 - val_mae: 0.1413
# Epoch 216/30000
# 122736/122736 - 14s - loss: 0.1082 - mse: 0.0496 - mae: 0.1082 - val_loss: 0.1396 - val_mse: 0.0846 - val_mae: 0.1396
# Epoch 217/30000
# 122736/122736 - 14s - loss: 0.1078 - mse: 0.0494 - mae: 0.1078 - val_loss: 0.1407 - val_mse: 0.0839 - val_mae: 0.1407
# Epoch 218/30000
# 122736/122736 - 14s - loss: 0.1080 - mse: 0.0495 - mae: 0.1080 - val_loss: 0.1431 - val_mse: 0.0865 - val_mae: 0.1431
# Epoch 219/30000
# 122736/122736 - 14s - loss: 0.1082 - mse: 0.0497 - mae: 0.1082 - val_loss: 0.1412 - val_mse: 0.0864 - val_mae: 0.1412
# Epoch 220/30000
# 122736/122736 - 14s - loss: 0.1079 - mse: 0.0497 - mae: 0.1079 - val_loss: 0.1432 - val_mse: 0.0861 - val_mae: 0.1432
# Epoch 221/30000
# 122736/122736 - 14s - loss: 0.1081 - mse: 0.0495 - mae: 0.1081 - val_loss: 0.1410 - val_mse: 0.0844 - val_mae: 0.1410
# Epoch 222/30000
# 122736/122736 - 14s - loss: 0.1082 - mse: 0.0496 - mae: 0.1082 - val_loss: 0.1402 - val_mse: 0.0842 - val_mae: 0.1402
# Epoch 223/30000
# 122736/122736 - 14s - loss: 0.1072 - mse: 0.0493 - mae: 0.1072 - val_loss: 0.1407 - val_mse: 0.0832 - val_mae: 0.1407
# Epoch 224/30000
# 122736/122736 - 14s - loss: 0.1073 - mse: 0.0491 - mae: 0.1073 - val_loss: 0.1390 - val_mse: 0.0839 - val_mae: 0.1390
# Epoch 225/30000
# 122736/122736 - 14s - loss: 0.1074 - mse: 0.0492 - mae: 0.1074 - val_loss: 0.1396 - val_mse: 0.0842 - val_mae: 0.1396
# Epoch 226/30000
# 122736/122736 - 14s - loss: 0.1067 - mse: 0.0487 - mae: 0.1067 - val_loss: 0.1403 - val_mse: 0.0841 - val_mae: 0.1403
# Epoch 227/30000
# 122736/122736 - 14s - loss: 0.1066 - mse: 0.0489 - mae: 0.1066 - val_loss: 0.1402 - val_mse: 0.0841 - val_mae: 0.1402
# Epoch 228/30000
# 122736/122736 - 14s - loss: 0.1069 - mse: 0.0488 - mae: 0.1069 - val_loss: 0.1412 - val_mse: 0.0844 - val_mae: 0.1412
# Epoch 229/30000
# 122736/122736 - 14s - loss: 0.1071 - mse: 0.0492 - mae: 0.1071 - val_loss: 0.1406 - val_mse: 0.0858 - val_mae: 0.1406
# Epoch 230/30000
# 122736/122736 - 14s - loss: 0.1067 - mse: 0.0489 - mae: 0.1067 - val_loss: 0.1414 - val_mse: 0.0876 - val_mae: 0.1414
# Epoch 231/30000
# 122736/122736 - 14s - loss: 0.1063 - mse: 0.0490 - mae: 0.1063 - val_loss: 0.1424 - val_mse: 0.0862 - val_mae: 0.1424
# Epoch 232/30000
# 122736/122736 - 14s - loss: 0.1066 - mse: 0.0488 - mae: 0.1066 - val_loss: 0.1396 - val_mse: 0.0843 - val_mae: 0.1396
# Epoch 233/30000
# 122736/122736 - 14s - loss: 0.1061 - mse: 0.0485 - mae: 0.1061 - val_loss: 0.1426 - val_mse: 0.0863 - val_mae: 0.1426
# Epoch 234/30000
# 122736/122736 - 14s - loss: 0.1066 - mse: 0.0491 - mae: 0.1066 - val_loss: 0.1389 - val_mse: 0.0836 - val_mae: 0.1389
# Epoch 235/30000
# 122736/122736 - 14s - loss: 0.1058 - mse: 0.0483 - mae: 0.1058 - val_loss: 0.1417 - val_mse: 0.0875 - val_mae: 0.1417
# Epoch 236/30000
# 122736/122736 - 14s - loss: 0.1063 - mse: 0.0487 - mae: 0.1063 - val_loss: 0.1407 - val_mse: 0.0845 - val_mae: 0.1407
# Epoch 237/30000
# 122736/122736 - 14s - loss: 0.1057 - mse: 0.0482 - mae: 0.1057 - val_loss: 0.1404 - val_mse: 0.0843 - val_mae: 0.1404
# Epoch 238/30000
# 122736/122736 - 14s - loss: 0.1051 - mse: 0.0479 - mae: 0.1051 - val_loss: 0.1415 - val_mse: 0.0848 - val_mae: 0.1415
# Epoch 239/30000
# 122736/122736 - 14s - loss: 0.1056 - mse: 0.0481 - mae: 0.1056 - val_loss: 0.1412 - val_mse: 0.0857 - val_mae: 0.1412
# Epoch 240/30000
# 122736/122736 - 14s - loss: 0.1058 - mse: 0.0482 - mae: 0.1058 - val_loss: 0.1395 - val_mse: 0.0834 - val_mae: 0.1395
# Epoch 241/30000
# 122736/122736 - 14s - loss: 0.1059 - mse: 0.0484 - mae: 0.1059 - val_loss: 0.1415 - val_mse: 0.0857 - val_mae: 0.1415
# Epoch 242/30000
# 122736/122736 - 14s - loss: 0.1054 - mse: 0.0480 - mae: 0.1054 - val_loss: 0.1405 - val_mse: 0.0854 - val_mae: 0.1405
# Epoch 243/30000
# 122736/122736 - 14s - loss: 0.1052 - mse: 0.0482 - mae: 0.1052 - val_loss: 0.1437 - val_mse: 0.0847 - val_mae: 0.1437
# Epoch 244/30000
# 122736/122736 - 14s - loss: 0.1058 - mse: 0.0483 - mae: 0.1058 - val_loss: 0.1388 - val_mse: 0.0833 - val_mae: 0.1388
# Epoch 245/30000
# 122736/122736 - 14s - loss: 0.1042 - mse: 0.0472 - mae: 0.1042 - val_loss: 0.1387 - val_mse: 0.0829 - val_mae: 0.1387
# Epoch 246/30000
# 122736/122736 - 14s - loss: 0.1049 - mse: 0.0477 - mae: 0.1049 - val_loss: 0.1403 - val_mse: 0.0838 - val_mae: 0.1403
# Epoch 247/30000
# 122736/122736 - 14s - loss: 0.1049 - mse: 0.0478 - mae: 0.1049 - val_loss: 0.1395 - val_mse: 0.0838 - val_mae: 0.1395
# Epoch 248/30000
# 122736/122736 - 14s - loss: 0.1048 - mse: 0.0478 - mae: 0.1048 - val_loss: 0.1419 - val_mse: 0.0862 - val_mae: 0.1419
# Epoch 249/30000
# 122736/122736 - 14s - loss: 0.1046 - mse: 0.0477 - mae: 0.1046 - val_loss: 0.1411 - val_mse: 0.0839 - val_mae: 0.1411
# Epoch 250/30000
# 122736/122736 - 14s - loss: 0.1046 - mse: 0.0480 - mae: 0.1046 - val_loss: 0.1439 - val_mse: 0.0863 - val_mae: 0.1439
# Epoch 251/30000
# 122736/122736 - 14s - loss: 0.1045 - mse: 0.0475 - mae: 0.1045 - val_loss: 0.1415 - val_mse: 0.0833 - val_mae: 0.1415
# Epoch 252/30000
# 122736/122736 - 14s - loss: 0.1045 - mse: 0.0476 - mae: 0.1045 - val_loss: 0.1391 - val_mse: 0.0838 - val_mae: 0.1391
# Epoch 253/30000
# 122736/122736 - 14s - loss: 0.1042 - mse: 0.0473 - mae: 0.1042 - val_loss: 0.1428 - val_mse: 0.0867 - val_mae: 0.1428
# Epoch 254/30000
# 122736/122736 - 14s - loss: 0.1042 - mse: 0.0472 - mae: 0.1042 - val_loss: 0.1409 - val_mse: 0.0853 - val_mae: 0.1409
# Epoch 255/30000
# 122736/122736 - 14s - loss: 0.1037 - mse: 0.0473 - mae: 0.1037 - val_loss: 0.1398 - val_mse: 0.0834 - val_mae: 0.1398
# Epoch 256/30000
# 122736/122736 - 14s - loss: 0.1036 - mse: 0.0474 - mae: 0.1036 - val_loss: 0.1403 - val_mse: 0.0864 - val_mae: 0.1403
# Epoch 257/30000
# 122736/122736 - 14s - loss: 0.1041 - mse: 0.0473 - mae: 0.1041 - val_loss: 0.1389 - val_mse: 0.0838 - val_mae: 0.1389
# Epoch 258/30000
# 122736/122736 - 14s - loss: 0.1039 - mse: 0.0472 - mae: 0.1039 - val_loss: 0.1391 - val_mse: 0.0829 - val_mae: 0.1391
# Epoch 259/30000
# 122736/122736 - 14s - loss: 0.1035 - mse: 0.0472 - mae: 0.1035 - val_loss: 0.1395 - val_mse: 0.0854 - val_mae: 0.1395
# Epoch 260/30000
# 122736/122736 - 14s - loss: 0.1033 - mse: 0.0470 - mae: 0.1033 - val_loss: 0.1420 - val_mse: 0.0849 - val_mae: 0.1420
# Epoch 261/30000
# 122736/122736 - 14s - loss: 0.1034 - mse: 0.0472 - mae: 0.1034 - val_loss: 0.1406 - val_mse: 0.0845 - val_mae: 0.1406
# Epoch 262/30000
# 122736/122736 - 14s - loss: 0.1034 - mse: 0.0472 - mae: 0.1034 - val_loss: 0.1400 - val_mse: 0.0840 - val_mae: 0.1400
# Epoch 263/30000
# 122736/122736 - 14s - loss: 0.1038 - mse: 0.0477 - mae: 0.1038 - val_loss: 0.1422 - val_mse: 0.0873 - val_mae: 0.1422
# Epoch 264/30000
# 122736/122736 - 14s - loss: 0.1037 - mse: 0.0472 - mae: 0.1037 - val_loss: 0.1416 - val_mse: 0.0851 - val_mae: 0.1416
# Epoch 265/30000
# 122736/122736 - 14s - loss: 0.1033 - mse: 0.0471 - mae: 0.1033 - val_loss: 0.1395 - val_mse: 0.0848 - val_mae: 0.1395
# Epoch 266/30000
# 122736/122736 - 14s - loss: 0.1032 - mse: 0.0471 - mae: 0.1032 - val_loss: 0.1399 - val_mse: 0.0848 - val_mae: 0.1399
# Epoch 267/30000
# 122736/122736 - 14s - loss: 0.1027 - mse: 0.0468 - mae: 0.1027 - val_loss: 0.1436 - val_mse: 0.0875 - val_mae: 0.1436
# Epoch 268/30000
# 122736/122736 - 14s - loss: 0.1036 - mse: 0.0474 - mae: 0.1036 - val_loss: 0.1439 - val_mse: 0.0863 - val_mae: 0.1439
# Epoch 269/30000
# 122736/122736 - 14s - loss: 0.1032 - mse: 0.0471 - mae: 0.1032 - val_loss: 0.1403 - val_mse: 0.0837 - val_mae: 0.1403
# Epoch 270/30000
# 122736/122736 - 14s - loss: 0.1031 - mse: 0.0467 - mae: 0.1031 - val_loss: 0.1388 - val_mse: 0.0830 - val_mae: 0.1388
# Epoch 271/30000
# 122736/122736 - 14s - loss: 0.1028 - mse: 0.0467 - mae: 0.1028 - val_loss: 0.1408 - val_mse: 0.0843 - val_mae: 0.1408
# Epoch 272/30000
# 122736/122736 - 14s - loss: 0.1028 - mse: 0.0467 - mae: 0.1028 - val_loss: 0.1391 - val_mse: 0.0835 - val_mae: 0.1391
# Epoch 273/30000
# 122736/122736 - 14s - loss: 0.1026 - mse: 0.0472 - mae: 0.1026 - val_loss: 0.1416 - val_mse: 0.0846 - val_mae: 0.1416
# Epoch 274/30000
# 122736/122736 - 14s - loss: 0.1030 - mse: 0.0468 - mae: 0.1030 - val_loss: 0.1397 - val_mse: 0.0842 - val_mae: 0.1397
# Epoch 275/30000
# 122736/122736 - 14s - loss: 0.1028 - mse: 0.0468 - mae: 0.1028 - val_loss: 0.1390 - val_mse: 0.0832 - val_mae: 0.1390
# Epoch 276/30000
# 122736/122736 - 14s - loss: 0.1033 - mse: 0.0468 - mae: 0.1033 - val_loss: 0.1415 - val_mse: 0.0841 - val_mae: 0.1415
# Epoch 277/30000
# 122736/122736 - 14s - loss: 0.1018 - mse: 0.0462 - mae: 0.1018 - val_loss: 0.1398 - val_mse: 0.0845 - val_mae: 0.1398
# Epoch 278/30000
# 122736/122736 - 14s - loss: 0.1023 - mse: 0.0464 - mae: 0.1023 - val_loss: 0.1408 - val_mse: 0.0845 - val_mae: 0.1408
# Epoch 279/30000
# 122736/122736 - 14s - loss: 0.1024 - mse: 0.0464 - mae: 0.1024 - val_loss: 0.1386 - val_mse: 0.0847 - val_mae: 0.1386
# Epoch 280/30000
# 122736/122736 - 14s - loss: 0.1017 - mse: 0.0459 - mae: 0.1017 - val_loss: 0.1384 - val_mse: 0.0828 - val_mae: 0.1384
# Epoch 281/30000
# 122736/122736 - 14s - loss: 0.1018 - mse: 0.0461 - mae: 0.1018 - val_loss: 0.1394 - val_mse: 0.0851 - val_mae: 0.1394
# Epoch 282/30000
# 122736/122736 - 14s - loss: 0.1015 - mse: 0.0461 - mae: 0.1015 - val_loss: 0.1400 - val_mse: 0.0843 - val_mae: 0.1400
# Epoch 283/30000
# 122736/122736 - 14s - loss: 0.1019 - mse: 0.0465 - mae: 0.1019 - val_loss: 0.1382 - val_mse: 0.0819 - val_mae: 0.1382
# Epoch 284/30000
# 122736/122736 - 14s - loss: 0.1013 - mse: 0.0459 - mae: 0.1013 - val_loss: 0.1392 - val_mse: 0.0838 - val_mae: 0.1392
# Epoch 285/30000
# 122736/122736 - 14s - loss: 0.1014 - mse: 0.0462 - mae: 0.1014 - val_loss: 0.1401 - val_mse: 0.0840 - val_mae: 0.1401
# Epoch 286/30000
# 122736/122736 - 14s - loss: 0.1017 - mse: 0.0463 - mae: 0.1017 - val_loss: 0.1384 - val_mse: 0.0832 - val_mae: 0.1384
# Epoch 287/30000
# 122736/122736 - 14s - loss: 0.1015 - mse: 0.0462 - mae: 0.1015 - val_loss: 0.1404 - val_mse: 0.0829 - val_mae: 0.1404
# Epoch 288/30000
# 122736/122736 - 14s - loss: 0.1018 - mse: 0.0464 - mae: 0.1018 - val_loss: 0.1379 - val_mse: 0.0821 - val_mae: 0.1379
# Epoch 289/30000
# 122736/122736 - 14s - loss: 0.1011 - mse: 0.0462 - mae: 0.1011 - val_loss: 0.1411 - val_mse: 0.0843 - val_mae: 0.1411
# Epoch 290/30000
# 122736/122736 - 14s - loss: 0.1012 - mse: 0.0459 - mae: 0.1012 - val_loss: 0.1415 - val_mse: 0.0849 - val_mae: 0.1415
# Epoch 291/30000
# 122736/122736 - 14s - loss: 0.1013 - mse: 0.0461 - mae: 0.1013 - val_loss: 0.1400 - val_mse: 0.0856 - val_mae: 0.1400
# Epoch 292/30000
# 122736/122736 - 14s - loss: 0.1011 - mse: 0.0461 - mae: 0.1011 - val_loss: 0.1405 - val_mse: 0.0844 - val_mae: 0.1405
# Epoch 293/30000
# 122736/122736 - 14s - loss: 0.1008 - mse: 0.0459 - mae: 0.1008 - val_loss: 0.1393 - val_mse: 0.0844 - val_mae: 0.1393
# Epoch 294/30000
# 122736/122736 - 14s - loss: 0.1006 - mse: 0.0456 - mae: 0.1006 - val_loss: 0.1378 - val_mse: 0.0827 - val_mae: 0.1378
# Epoch 295/30000
# 122736/122736 - 14s - loss: 0.1002 - mse: 0.0455 - mae: 0.1002 - val_loss: 0.1384 - val_mse: 0.0836 - val_mae: 0.1384
# Epoch 296/30000
# 122736/122736 - 14s - loss: 0.1013 - mse: 0.0460 - mae: 0.1013 - val_loss: 0.1401 - val_mse: 0.0854 - val_mae: 0.1401
# Epoch 297/30000
# 122736/122736 - 14s - loss: 0.1007 - mse: 0.0460 - mae: 0.1007 - val_loss: 0.1398 - val_mse: 0.0839 - val_mae: 0.1398
# Epoch 298/30000
# 122736/122736 - 14s - loss: 0.1006 - mse: 0.0457 - mae: 0.1006 - val_loss: 0.1437 - val_mse: 0.0863 - val_mae: 0.1437
# Epoch 299/30000
# 122736/122736 - 14s - loss: 0.1012 - mse: 0.0460 - mae: 0.1012 - val_loss: 0.1399 - val_mse: 0.0851 - val_mae: 0.1399
# Epoch 300/30000
# 122736/122736 - 14s - loss: 0.1011 - mse: 0.0459 - mae: 0.1011 - val_loss: 0.1391 - val_mse: 0.0849 - val_mae: 0.1391
# Epoch 301/30000
# 122736/122736 - 14s - loss: 0.0999 - mse: 0.0455 - mae: 0.0999 - val_loss: 0.1396 - val_mse: 0.0844 - val_mae: 0.1396
# Epoch 302/30000
# 122736/122736 - 14s - loss: 0.1002 - mse: 0.0457 - mae: 0.1002 - val_loss: 0.1379 - val_mse: 0.0822 - val_mae: 0.1379
# Epoch 303/30000
# 122736/122736 - 14s - loss: 0.1000 - mse: 0.0454 - mae: 0.1000 - val_loss: 0.1421 - val_mse: 0.0842 - val_mae: 0.1421
# Epoch 304/30000
# 122736/122736 - 14s - loss: 0.1002 - mse: 0.0456 - mae: 0.1002 - val_loss: 0.1389 - val_mse: 0.0837 - val_mae: 0.1389
# Epoch 305/30000
# 122736/122736 - 14s - loss: 0.1003 - mse: 0.0457 - mae: 0.1003 - val_loss: 0.1407 - val_mse: 0.0844 - val_mae: 0.1407
# Epoch 306/30000
# 122736/122736 - 14s - loss: 0.0998 - mse: 0.0453 - mae: 0.0998 - val_loss: 0.1455 - val_mse: 0.0856 - val_mae: 0.1455
# Epoch 307/30000
# 122736/122736 - 14s - loss: 0.1000 - mse: 0.0451 - mae: 0.1000 - val_loss: 0.1387 - val_mse: 0.0833 - val_mae: 0.1387
# Epoch 308/30000
# 122736/122736 - 14s - loss: 0.1003 - mse: 0.0455 - mae: 0.1003 - val_loss: 0.1384 - val_mse: 0.0836 - val_mae: 0.1384
# Epoch 309/30000
# 122736/122736 - 14s - loss: 0.0996 - mse: 0.0452 - mae: 0.0996 - val_loss: 0.1394 - val_mse: 0.0835 - val_mae: 0.1394
# Epoch 310/30000
# 122736/122736 - 14s - loss: 0.0996 - mse: 0.0452 - mae: 0.0996 - val_loss: 0.1371 - val_mse: 0.0824 - val_mae: 0.1371
# Epoch 311/30000
# 122736/122736 - 14s - loss: 0.0996 - mse: 0.0451 - mae: 0.0996 - val_loss: 0.1394 - val_mse: 0.0833 - val_mae: 0.1394
# Epoch 312/30000
# 122736/122736 - 14s - loss: 0.0995 - mse: 0.0453 - mae: 0.0995 - val_loss: 0.1421 - val_mse: 0.0855 - val_mae: 0.1421
# Epoch 313/30000
# 122736/122736 - 14s - loss: 0.0993 - mse: 0.0451 - mae: 0.0993 - val_loss: 0.1411 - val_mse: 0.0844 - val_mae: 0.1411
# Epoch 314/30000
# 122736/122736 - 14s - loss: 0.0997 - mse: 0.0456 - mae: 0.0997 - val_loss: 0.1416 - val_mse: 0.0847 - val_mae: 0.1416
# Epoch 315/30000
# 122736/122736 - 14s - loss: 0.1000 - mse: 0.0454 - mae: 0.1000 - val_loss: 0.1390 - val_mse: 0.0832 - val_mae: 0.1390
# Epoch 316/30000
# 122736/122736 - 14s - loss: 0.0997 - mse: 0.0452 - mae: 0.0997 - val_loss: 0.1395 - val_mse: 0.0847 - val_mae: 0.1395
# Epoch 317/30000
# 122736/122736 - 14s - loss: 0.0992 - mse: 0.0450 - mae: 0.0992 - val_loss: 0.1407 - val_mse: 0.0845 - val_mae: 0.1407
# Epoch 318/30000
# 122736/122736 - 14s - loss: 0.0995 - mse: 0.0451 - mae: 0.0995 - val_loss: 0.1381 - val_mse: 0.0844 - val_mae: 0.1381
# Epoch 319/30000
# 122736/122736 - 14s - loss: 0.0988 - mse: 0.0449 - mae: 0.0988 - val_loss: 0.1381 - val_mse: 0.0839 - val_mae: 0.1381
# Epoch 320/30000
# 122736/122736 - 14s - loss: 0.0988 - mse: 0.0449 - mae: 0.0988 - val_loss: 0.1391 - val_mse: 0.0834 - val_mae: 0.1391
# Epoch 321/30000
# 122736/122736 - 14s - loss: 0.0996 - mse: 0.0454 - mae: 0.0996 - val_loss: 0.1371 - val_mse: 0.0824 - val_mae: 0.1371
# Epoch 322/30000
# 122736/122736 - 14s - loss: 0.0984 - mse: 0.0446 - mae: 0.0984 - val_loss: 0.1395 - val_mse: 0.0838 - val_mae: 0.1395
# Epoch 323/30000
# 122736/122736 - 14s - loss: 0.0992 - mse: 0.0451 - mae: 0.0992 - val_loss: 0.1392 - val_mse: 0.0834 - val_mae: 0.1392
# Epoch 324/30000
# 122736/122736 - 14s - loss: 0.0984 - mse: 0.0448 - mae: 0.0984 - val_loss: 0.1390 - val_mse: 0.0826 - val_mae: 0.1390
# Epoch 325/30000
# 122736/122736 - 14s - loss: 0.0987 - mse: 0.0449 - mae: 0.0987 - val_loss: 0.1397 - val_mse: 0.0840 - val_mae: 0.1397
# Epoch 326/30000
# 122736/122736 - 14s - loss: 0.0986 - mse: 0.0447 - mae: 0.0986 - val_loss: 0.1389 - val_mse: 0.0835 - val_mae: 0.1389
# Epoch 327/30000
# 122736/122736 - 14s - loss: 0.0985 - mse: 0.0449 - mae: 0.0985 - val_loss: 0.1404 - val_mse: 0.0835 - val_mae: 0.1404
# Epoch 328/30000
# 122736/122736 - 14s - loss: 0.0983 - mse: 0.0448 - mae: 0.0983 - val_loss: 0.1380 - val_mse: 0.0821 - val_mae: 0.1380
# Epoch 329/30000
# 122736/122736 - 14s - loss: 0.0985 - mse: 0.0447 - mae: 0.0985 - val_loss: 0.1406 - val_mse: 0.0845 - val_mae: 0.1406
# Epoch 330/30000
# 122736/122736 - 14s - loss: 0.0984 - mse: 0.0445 - mae: 0.0984 - val_loss: 0.1412 - val_mse: 0.0844 - val_mae: 0.1412
# Epoch 331/30000
# 122736/122736 - 14s - loss: 0.0980 - mse: 0.0444 - mae: 0.0980 - val_loss: 0.1409 - val_mse: 0.0843 - val_mae: 0.1409
# Epoch 332/30000
# 122736/122736 - 14s - loss: 0.0982 - mse: 0.0445 - mae: 0.0982 - val_loss: 0.1406 - val_mse: 0.0834 - val_mae: 0.1406
# Epoch 333/30000
# 122736/122736 - 14s - loss: 0.0980 - mse: 0.0446 - mae: 0.0980 - val_loss: 0.1420 - val_mse: 0.0858 - val_mae: 0.1420
# Epoch 334/30000
# 122736/122736 - 14s - loss: 0.0984 - mse: 0.0448 - mae: 0.0984 - val_loss: 0.1370 - val_mse: 0.0819 - val_mae: 0.1370
# Epoch 335/30000
# 122736/122736 - 14s - loss: 0.0980 - mse: 0.0445 - mae: 0.0980 - val_loss: 0.1377 - val_mse: 0.0822 - val_mae: 0.1377
# Epoch 336/30000
# 122736/122736 - 14s - loss: 0.0981 - mse: 0.0447 - mae: 0.0981 - val_loss: 0.1390 - val_mse: 0.0828 - val_mae: 0.1390
# Epoch 337/30000
# 122736/122736 - 14s - loss: 0.0982 - mse: 0.0446 - mae: 0.0982 - val_loss: 0.1388 - val_mse: 0.0833 - val_mae: 0.1388
# Epoch 338/30000
# 122736/122736 - 14s - loss: 0.0978 - mse: 0.0444 - mae: 0.0978 - val_loss: 0.1404 - val_mse: 0.0846 - val_mae: 0.1404
# Epoch 339/30000
# 122736/122736 - 14s - loss: 0.0979 - mse: 0.0444 - mae: 0.0979 - val_loss: 0.1424 - val_mse: 0.0866 - val_mae: 0.1424
# Epoch 340/30000
# 122736/122736 - 14s - loss: 0.0976 - mse: 0.0442 - mae: 0.0976 - val_loss: 0.1383 - val_mse: 0.0831 - val_mae: 0.1383
# Epoch 341/30000
# 122736/122736 - 14s - loss: 0.0976 - mse: 0.0444 - mae: 0.0976 - val_loss: 0.1394 - val_mse: 0.0832 - val_mae: 0.1394
# Epoch 342/30000
# 122736/122736 - 14s - loss: 0.0977 - mse: 0.0443 - mae: 0.0977 - val_loss: 0.1389 - val_mse: 0.0829 - val_mae: 0.1389
# Epoch 343/30000
# 122736/122736 - 14s - loss: 0.0980 - mse: 0.0444 - mae: 0.0980 - val_loss: 0.1391 - val_mse: 0.0840 - val_mae: 0.1391
# Epoch 344/30000
# 122736/122736 - 14s - loss: 0.0982 - mse: 0.0445 - mae: 0.0982 - val_loss: 0.1382 - val_mse: 0.0829 - val_mae: 0.1382
# Epoch 345/30000
# 122736/122736 - 14s - loss: 0.0975 - mse: 0.0446 - mae: 0.0975 - val_loss: 0.1390 - val_mse: 0.0829 - val_mae: 0.1390
# Epoch 346/30000
# 122736/122736 - 14s - loss: 0.0977 - mse: 0.0442 - mae: 0.0977 - val_loss: 0.1411 - val_mse: 0.0848 - val_mae: 0.1411
# Epoch 347/30000
# 122736/122736 - 14s - loss: 0.0975 - mse: 0.0442 - mae: 0.0975 - val_loss: 0.1379 - val_mse: 0.0828 - val_mae: 0.1379
# Epoch 348/30000
# 122736/122736 - 14s - loss: 0.0971 - mse: 0.0442 - mae: 0.0971 - val_loss: 0.1396 - val_mse: 0.0856 - val_mae: 0.1396
# Epoch 349/30000
# 122736/122736 - 14s - loss: 0.0975 - mse: 0.0442 - mae: 0.0975 - val_loss: 0.1424 - val_mse: 0.0851 - val_mae: 0.1424
# Epoch 350/30000
# 122736/122736 - 14s - loss: 0.0969 - mse: 0.0439 - mae: 0.0969 - val_loss: 0.1387 - val_mse: 0.0836 - val_mae: 0.1387
# Epoch 351/30000
# 122736/122736 - 14s - loss: 0.0975 - mse: 0.0443 - mae: 0.0975 - val_loss: 0.1388 - val_mse: 0.0833 - val_mae: 0.1388
# Epoch 352/30000
# 122736/122736 - 14s - loss: 0.0974 - mse: 0.0439 - mae: 0.0974 - val_loss: 0.1415 - val_mse: 0.0851 - val_mae: 0.1415
# Epoch 353/30000
# 122736/122736 - 14s - loss: 0.0976 - mse: 0.0442 - mae: 0.0976 - val_loss: 0.1394 - val_mse: 0.0841 - val_mae: 0.1394
# Epoch 354/30000
# 122736/122736 - 14s - loss: 0.0969 - mse: 0.0440 - mae: 0.0969 - val_loss: 0.1371 - val_mse: 0.0820 - val_mae: 0.1371
# Epoch 355/30000
# 122736/122736 - 14s - loss: 0.0965 - mse: 0.0438 - mae: 0.0965 - val_loss: 0.1376 - val_mse: 0.0849 - val_mae: 0.1376
# Epoch 356/30000
# 122736/122736 - 14s - loss: 0.0972 - mse: 0.0447 - mae: 0.0972 - val_loss: 0.1379 - val_mse: 0.0818 - val_mae: 0.1379
# Epoch 357/30000
# 122736/122736 - 14s - loss: 0.0974 - mse: 0.0441 - mae: 0.0974 - val_loss: 0.1438 - val_mse: 0.0866 - val_mae: 0.1438
# Epoch 358/30000
# 122736/122736 - 14s - loss: 0.0970 - mse: 0.0442 - mae: 0.0970 - val_loss: 0.1377 - val_mse: 0.0825 - val_mae: 0.1377
# Epoch 359/30000
# 122736/122736 - 14s - loss: 0.0968 - mse: 0.0439 - mae: 0.0968 - val_loss: 0.1388 - val_mse: 0.0832 - val_mae: 0.1388
# Epoch 360/30000
# 122736/122736 - 14s - loss: 0.0966 - mse: 0.0437 - mae: 0.0966 - val_loss: 0.1393 - val_mse: 0.0840 - val_mae: 0.1393
# Epoch 361/30000
# 122736/122736 - 14s - loss: 0.0971 - mse: 0.0440 - mae: 0.0971 - val_loss: 0.1393 - val_mse: 0.0841 - val_mae: 0.1393
# Epoch 362/30000
# 122736/122736 - 14s - loss: 0.0963 - mse: 0.0436 - mae: 0.0963 - val_loss: 0.1412 - val_mse: 0.0846 - val_mae: 0.1412
# Epoch 363/30000
# 122736/122736 - 14s - loss: 0.0967 - mse: 0.0438 - mae: 0.0967 - val_loss: 0.1421 - val_mse: 0.0851 - val_mae: 0.1421
# Epoch 364/30000
# 122736/122736 - 14s - loss: 0.0968 - mse: 0.0436 - mae: 0.0968 - val_loss: 0.1380 - val_mse: 0.0821 - val_mae: 0.1380
# Epoch 365/30000
# 122736/122736 - 14s - loss: 0.0962 - mse: 0.0437 - mae: 0.0962 - val_loss: 0.1381 - val_mse: 0.0819 - val_mae: 0.1381
# Epoch 366/30000
# 122736/122736 - 14s - loss: 0.0967 - mse: 0.0439 - mae: 0.0967 - val_loss: 0.1387 - val_mse: 0.0840 - val_mae: 0.1387
# Epoch 367/30000
# 122736/122736 - 14s - loss: 0.0964 - mse: 0.0437 - mae: 0.0964 - val_loss: 0.1395 - val_mse: 0.0835 - val_mae: 0.1395
# Epoch 368/30000
# 122736/122736 - 14s - loss: 0.0964 - mse: 0.0436 - mae: 0.0964 - val_loss: 0.1375 - val_mse: 0.0833 - val_mae: 0.1375
# Epoch 369/30000
# 122736/122736 - 14s - loss: 0.0962 - mse: 0.0439 - mae: 0.0962 - val_loss: 0.1391 - val_mse: 0.0835 - val_mae: 0.1391
# Epoch 370/30000
# 122736/122736 - 14s - loss: 0.0962 - mse: 0.0437 - mae: 0.0962 - val_loss: 0.1385 - val_mse: 0.0835 - val_mae: 0.1385
# Epoch 371/30000
# 122736/122736 - 14s - loss: 0.0959 - mse: 0.0436 - mae: 0.0959 - val_loss: 0.1404 - val_mse: 0.0856 - val_mae: 0.1404
# Epoch 372/30000
# 122736/122736 - 14s - loss: 0.0963 - mse: 0.0437 - mae: 0.0963 - val_loss: 0.1392 - val_mse: 0.0845 - val_mae: 0.1392
# Epoch 373/30000
# 122736/122736 - 14s - loss: 0.0960 - mse: 0.0434 - mae: 0.0960 - val_loss: 0.1383 - val_mse: 0.0831 - val_mae: 0.1383
# Epoch 374/30000
# 122736/122736 - 14s - loss: 0.0962 - mse: 0.0435 - mae: 0.0962 - val_loss: 0.1404 - val_mse: 0.0844 - val_mae: 0.1404
# Epoch 375/30000
# 122736/122736 - 14s - loss: 0.0962 - mse: 0.0437 - mae: 0.0962 - val_loss: 0.1380 - val_mse: 0.0832 - val_mae: 0.1380
# Epoch 376/30000
# 122736/122736 - 14s - loss: 0.0958 - mse: 0.0435 - mae: 0.0958 - val_loss: 0.1380 - val_mse: 0.0828 - val_mae: 0.1380
# Epoch 377/30000
# 122736/122736 - 14s - loss: 0.0954 - mse: 0.0434 - mae: 0.0954 - val_loss: 0.1390 - val_mse: 0.0836 - val_mae: 0.1390
# Epoch 378/30000
# 122736/122736 - 14s - loss: 0.0956 - mse: 0.0433 - mae: 0.0956 - val_loss: 0.1419 - val_mse: 0.0861 - val_mae: 0.1419
# Epoch 379/30000
# 122736/122736 - 14s - loss: 0.0961 - mse: 0.0435 - mae: 0.0961 - val_loss: 0.1392 - val_mse: 0.0833 - val_mae: 0.1392
# Epoch 380/30000
# 122736/122736 - 14s - loss: 0.0954 - mse: 0.0433 - mae: 0.0954 - val_loss: 0.1410 - val_mse: 0.0861 - val_mae: 0.1410
# Epoch 381/30000
# 122736/122736 - 14s - loss: 0.0960 - mse: 0.0436 - mae: 0.0960 - val_loss: 0.1392 - val_mse: 0.0837 - val_mae: 0.1392
# Epoch 382/30000
# 122736/122736 - 14s - loss: 0.0954 - mse: 0.0431 - mae: 0.0954 - val_loss: 0.1387 - val_mse: 0.0843 - val_mae: 0.1387
# Epoch 383/30000
# 122736/122736 - 14s - loss: 0.0956 - mse: 0.0433 - mae: 0.0956 - val_loss: 0.1394 - val_mse: 0.0839 - val_mae: 0.1394
# Epoch 384/30000
# 122736/122736 - 14s - loss: 0.0959 - mse: 0.0433 - mae: 0.0959 - val_loss: 0.1388 - val_mse: 0.0854 - val_mae: 0.1388

# %%
#%tensorboard --logdir logs/fit

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrainz = Trainset/255.
Xtrainz2 = sc_X2.transform(Trainset2)
y_pred = model.predict([Xtrainz,Xtrainz2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is 0.03 degrees
# Root Mean Squared Error is 0.80 degrees
# Mean Absolute Error is 0.80 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset/255.
Xtest2 = sc_X2.transform(Testset2)
y_pred = model.predict([Xtest,Xtest2])
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is 0.03 degrees
# Root Mean Squared Error is 1.60 degrees
# Mean Absolute Error is 1.60 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v19_pb.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,sc_X2,modelhistory], file)
        
    # !mkdir -p saved_model
    model.save('saved_model/cnn3v19')
# Out:
# WARNING:tensorflow:From /home/asilador/env37_Alex/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: saved_model/cnn3v19/assets
