# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %%
#fix all seeds for random number generators
# Set seed value
seed_value = 9
import os
os.environ['PYTHONHASHSEED']=str(seed_value)# 2. Set `python` built-in pseudo-random generator at a fixed value
random.seed(seed_value)# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)
tf.random.set_seed(seed_value)# 5. Configure a new global `tensorflow` session

# TODO need to add session thing for tensorflow

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,30,31,32,33,35)
nw_resize = 2
nh_resize = 2
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (28044, 60, 80, 3)

# %%
# tlen = len(xtemp[0])-2 +len(xtemp[1])-2+len(xtemp[2])+len(xtemp[3]) #remove 2 samples from 24
# x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
# x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
# x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

tlen = len(xtemp[0]) +len(xtemp[1])+len(xtemp[2])+len(xtemp[3])+len(xtemp[4])+len(xtemp[5]) #remove 2 samples from 24 and 3 from 25
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
xrun = len(xtemp[0])
x_train[:xrun,:,:,:] = xtemp[0][:xrun,:,:,:]
xrun1 = xrun + len(xtemp[1])
x_train[xrun:xrun1,:,:,:]=xtemp[1][:xrun1-xrun,:,:,:]
xrun2 = xrun1 + len(xtemp[2])
x_train[xrun1:xrun2,:,:,:] = xtemp[2][:xrun2-xrun1,:,:,:]
xrun3 = xrun2 + len(xtemp[3])
x_train[xrun2:xrun3,:,:,:] = xtemp[3][:xrun3-xrun2,:,:,:]
xrun4 = xrun3 + len(xtemp[4])
x_train[xrun3:xrun4,:,:,:] = xtemp[4][:xrun4-xrun3,:,:,:]
xrun5 = xrun4 + len(xtemp[5])
x_train[xrun4:xrun5,:,:,:] = xtemp[5][:xrun5-xrun4,:,:,:]

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,30,31,32,33,35)
date = ('11_15_2020','11_24_2020','11_24_2020','11_25_2020','11_25_2020','11_25_2020')
y_gt = {}
yrun = 0
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])+len(y_gt[1])+len(y_gt[2])+len(y_gt[3])+len(y_gt[4])+len(y_gt[5])
y_train = np.zeros((tlen,1))
xrun = len(y_gt[0])
y_train[:xrun] = y_gt[0][:xrun]
xrun1 = xrun + len(y_gt[1])
y_train[xrun:xrun1]=y_gt[1][:xrun1-xrun]
xrun2 = xrun1 + len(y_gt[2])
y_train[xrun1:xrun2] = y_gt[2][:xrun2-xrun1]
xrun3 = xrun2 + len(y_gt[3])
y_train[xrun2:xrun3] = y_gt[3][:xrun3-xrun2]
xrun4 = xrun3 + len(y_gt[4])
y_train[xrun3:xrun4] = y_gt[4][:xrun4-xrun3]
xrun5 = xrun4 + len(y_gt[5])
y_train[xrun4:xrun5] = y_gt[5][:xrun5-xrun4]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (82381, 60, 80, 3)
# (82381, 1)

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %% [markdown]
# # Regress using Neural Network

# %%
np.max(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 1.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.2
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# # model_cnn = BatchNormalization()(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# # model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=96, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 60, 80, 3)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 60, 80, 16)        448
# _________________________________________________________________
# activation_31 (Activation)   (None, 60, 80, 16)        0
# _________________________________________________________________
# average_pooling2d_21 (Averag (None, 30, 40, 16)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 30, 40, 32)        4640
# _________________________________________________________________
# activation_32 (Activation)   (None, 30, 40, 32)        0
# _________________________________________________________________
# average_pooling2d_22 (Averag (None, 15, 20, 32)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 15, 20, 64)        18496
# _________________________________________________________________
# activation_33 (Activation)   (None, 15, 20, 64)        0
# _________________________________________________________________
# average_pooling2d_23 (Averag (None, 7, 10, 64)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 7, 10, 96)         55392
# _________________________________________________________________
# activation_34 (Activation)   (None, 7, 10, 96)         0
# _________________________________________________________________
# average_pooling2d_24 (Averag (None, 3, 5, 96)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1440)              0
# _________________________________________________________________
# activation_35 (Activation)   (None, 1440)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               184448
# _________________________________________________________________
# activation_36 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 263,553
# Trainable params: 263,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 65904 samples, validate on 16477 samples
# Epoch 1/30000
#  - 8s - loss: 0.6249 - mse: 0.9338 - mae: 0.6249 - val_loss: 0.5937 - val_mse: 0.8165 - val_mae: 0.5937
# Epoch 2/30000
#  - 8s - loss: 0.5667 - mse: 0.8019 - mae: 0.5667 - val_loss: 0.5336 - val_mse: 0.7193 - val_mae: 0.5336
# Epoch 3/30000
#  - 8s - loss: 0.5337 - mse: 0.7448 - mae: 0.5337 - val_loss: 0.5160 - val_mse: 0.6935 - val_mae: 0.5160
# Epoch 4/30000
#  - 8s - loss: 0.5116 - mse: 0.7113 - mae: 0.5116 - val_loss: 0.5035 - val_mse: 0.6634 - val_mae: 0.5035
# Epoch 5/30000
#  - 8s - loss: 0.4965 - mse: 0.6884 - mae: 0.4965 - val_loss: 0.4922 - val_mse: 0.6453 - val_mae: 0.4922
# Epoch 6/30000
#  - 8s - loss: 0.4787 - mse: 0.6624 - mae: 0.4787 - val_loss: 0.4624 - val_mse: 0.6103 - val_mae: 0.4624
# Epoch 7/30000
#  - 8s - loss: 0.4657 - mse: 0.6430 - mae: 0.4657 - val_loss: 0.4470 - val_mse: 0.5868 - val_mae: 0.4470
# Epoch 8/30000
#  - 8s - loss: 0.4521 - mse: 0.6205 - mae: 0.4521 - val_loss: 0.4372 - val_mse: 0.5732 - val_mae: 0.4372
# Epoch 9/30000
#  - 8s - loss: 0.4418 - mse: 0.6063 - mae: 0.4418 - val_loss: 0.4233 - val_mse: 0.5564 - val_mae: 0.4233
# Epoch 10/30000
#  - 8s - loss: 0.4308 - mse: 0.5921 - mae: 0.4308 - val_loss: 0.4274 - val_mse: 0.5537 - val_mae: 0.4274
# Epoch 11/30000
#  - 8s - loss: 0.4194 - mse: 0.5758 - mae: 0.4194 - val_loss: 0.4114 - val_mse: 0.5363 - val_mae: 0.4114
# Epoch 12/30000
#  - 8s - loss: 0.4097 - mse: 0.5634 - mae: 0.4097 - val_loss: 0.4017 - val_mse: 0.5213 - val_mae: 0.4017
# Epoch 13/30000
#  - 8s - loss: 0.4033 - mse: 0.5539 - mae: 0.4033 - val_loss: 0.3989 - val_mse: 0.5177 - val_mae: 0.3989
# Epoch 14/30000
#  - 8s - loss: 0.3931 - mse: 0.5403 - mae: 0.3931 - val_loss: 0.3879 - val_mse: 0.5029 - val_mae: 0.3879
# Epoch 15/30000
#  - 8s - loss: 0.3882 - mse: 0.5328 - mae: 0.3882 - val_loss: 0.3819 - val_mse: 0.4966 - val_mae: 0.3819
# Epoch 16/30000
#  - 8s - loss: 0.3792 - mse: 0.5209 - mae: 0.3792 - val_loss: 0.3737 - val_mse: 0.4828 - val_mae: 0.3737
# Epoch 17/30000
#  - 8s - loss: 0.3744 - mse: 0.5113 - mae: 0.3744 - val_loss: 0.3740 - val_mse: 0.4891 - val_mae: 0.3740
# Epoch 18/30000
#  - 8s - loss: 0.3690 - mse: 0.5046 - mae: 0.3690 - val_loss: 0.3641 - val_mse: 0.4687 - val_mae: 0.3641
# Epoch 19/30000
#  - 8s - loss: 0.3615 - mse: 0.4917 - mae: 0.3615 - val_loss: 0.3680 - val_mse: 0.4614 - val_mae: 0.3680
# Epoch 20/30000
#  - 8s - loss: 0.3565 - mse: 0.4787 - mae: 0.3565 - val_loss: 0.3510 - val_mse: 0.4433 - val_mae: 0.3510
# Epoch 21/30000
#  - 8s - loss: 0.3479 - mse: 0.4645 - mae: 0.3479 - val_loss: 0.3436 - val_mse: 0.4309 - val_mae: 0.3436
# Epoch 22/30000
#  - 8s - loss: 0.3445 - mse: 0.4543 - mae: 0.3445 - val_loss: 0.3378 - val_mse: 0.4218 - val_mae: 0.3378
# Epoch 23/30000
#  - 8s - loss: 0.3393 - mse: 0.4455 - mae: 0.3393 - val_loss: 0.3416 - val_mse: 0.4211 - val_mae: 0.3416
# Epoch 24/30000
#  - 8s - loss: 0.3328 - mse: 0.4346 - mae: 0.3328 - val_loss: 0.3326 - val_mse: 0.4114 - val_mae: 0.3326
# Epoch 25/30000
#  - 8s - loss: 0.3295 - mse: 0.4266 - mae: 0.3295 - val_loss: 0.3302 - val_mse: 0.4063 - val_mae: 0.3302
# Epoch 26/30000
#  - 8s - loss: 0.3248 - mse: 0.4204 - mae: 0.3248 - val_loss: 0.3286 - val_mse: 0.4020 - val_mae: 0.3286
# Epoch 27/30000
#  - 8s - loss: 0.3206 - mse: 0.4102 - mae: 0.3206 - val_loss: 0.3222 - val_mse: 0.3965 - val_mae: 0.3222
# Epoch 28/30000
#  - 8s - loss: 0.3157 - mse: 0.4015 - mae: 0.3157 - val_loss: 0.3243 - val_mse: 0.3886 - val_mae: 0.3243
# Epoch 29/30000
#  - 8s - loss: 0.3126 - mse: 0.3943 - mae: 0.3126 - val_loss: 0.3167 - val_mse: 0.3810 - val_mae: 0.3167
# Epoch 30/30000
#  - 8s - loss: 0.3102 - mse: 0.3858 - mae: 0.3102 - val_loss: 0.3181 - val_mse: 0.3767 - val_mae: 0.3181
# Epoch 31/30000
#  - 8s - loss: 0.3049 - mse: 0.3771 - mae: 0.3049 - val_loss: 0.3197 - val_mse: 0.3740 - val_mae: 0.3197
# Epoch 32/30000
#  - 8s - loss: 0.3012 - mse: 0.3717 - mae: 0.3012 - val_loss: 0.3084 - val_mse: 0.3564 - val_mae: 0.3084
# Epoch 33/30000
#  - 8s - loss: 0.2978 - mse: 0.3605 - mae: 0.2978 - val_loss: 0.3119 - val_mse: 0.3622 - val_mae: 0.3119
# Epoch 34/30000
#  - 8s - loss: 0.2967 - mse: 0.3584 - mae: 0.2967 - val_loss: 0.3059 - val_mse: 0.3510 - val_mae: 0.3059
# Epoch 35/30000
#  - 8s - loss: 0.2913 - mse: 0.3489 - mae: 0.2913 - val_loss: 0.3005 - val_mse: 0.3529 - val_mae: 0.3005
# Epoch 36/30000
#  - 8s - loss: 0.2888 - mse: 0.3475 - mae: 0.2888 - val_loss: 0.2986 - val_mse: 0.3484 - val_mae: 0.2986
# Epoch 37/30000
#  - 8s - loss: 0.2869 - mse: 0.3441 - mae: 0.2869 - val_loss: 0.3002 - val_mse: 0.3420 - val_mae: 0.3002
# Epoch 38/30000
#  - 8s - loss: 0.2828 - mse: 0.3398 - mae: 0.2828 - val_loss: 0.2991 - val_mse: 0.3495 - val_mae: 0.2991
# Epoch 39/30000
#  - 8s - loss: 0.2817 - mse: 0.3371 - mae: 0.2817 - val_loss: 0.2931 - val_mse: 0.3447 - val_mae: 0.2931
# Epoch 40/30000
#  - 8s - loss: 0.2802 - mse: 0.3348 - mae: 0.2802 - val_loss: 0.2945 - val_mse: 0.3392 - val_mae: 0.2945
# Epoch 41/30000
#  - 8s - loss: 0.2764 - mse: 0.3304 - mae: 0.2764 - val_loss: 0.2878 - val_mse: 0.3348 - val_mae: 0.2878
# Epoch 42/30000
#  - 8s - loss: 0.2743 - mse: 0.3270 - mae: 0.2743 - val_loss: 0.2900 - val_mse: 0.3340 - val_mae: 0.2900
# Epoch 43/30000
#  - 8s - loss: 0.2724 - mse: 0.3241 - mae: 0.2724 - val_loss: 0.2855 - val_mse: 0.3273 - val_mae: 0.2855
# Epoch 44/30000
#  - 8s - loss: 0.2699 - mse: 0.3202 - mae: 0.2699 - val_loss: 0.2852 - val_mse: 0.3280 - val_mae: 0.2852
# Epoch 45/30000
#  - 8s - loss: 0.2677 - mse: 0.3165 - mae: 0.2677 - val_loss: 0.2837 - val_mse: 0.3357 - val_mae: 0.2837
# Epoch 46/30000
#  - 8s - loss: 0.2662 - mse: 0.3148 - mae: 0.2662 - val_loss: 0.2820 - val_mse: 0.3261 - val_mae: 0.2820
# Epoch 47/30000
#  - 8s - loss: 0.2642 - mse: 0.3130 - mae: 0.2642 - val_loss: 0.2837 - val_mse: 0.3267 - val_mae: 0.2837
# Epoch 48/30000
#  - 8s - loss: 0.2605 - mse: 0.3102 - mae: 0.2605 - val_loss: 0.2816 - val_mse: 0.3276 - val_mae: 0.2816
# Epoch 49/30000
#  - 8s - loss: 0.2593 - mse: 0.3067 - mae: 0.2593 - val_loss: 0.2865 - val_mse: 0.3295 - val_mae: 0.2865
# Epoch 50/30000
#  - 8s - loss: 0.2582 - mse: 0.3054 - mae: 0.2582 - val_loss: 0.2807 - val_mse: 0.3240 - val_mae: 0.2807
# Epoch 51/30000
#  - 8s - loss: 0.2566 - mse: 0.3036 - mae: 0.2566 - val_loss: 0.2788 - val_mse: 0.3187 - val_mae: 0.2788
# Epoch 52/30000
#  - 8s - loss: 0.2547 - mse: 0.3006 - mae: 0.2547 - val_loss: 0.2782 - val_mse: 0.3241 - val_mae: 0.2782
# Epoch 53/30000
#  - 8s - loss: 0.2526 - mse: 0.2971 - mae: 0.2526 - val_loss: 0.2756 - val_mse: 0.3201 - val_mae: 0.2756
# Epoch 54/30000
#  - 8s - loss: 0.2521 - mse: 0.2968 - mae: 0.2521 - val_loss: 0.2806 - val_mse: 0.3193 - val_mae: 0.2806
# Epoch 55/30000
#  - 8s - loss: 0.2491 - mse: 0.2937 - mae: 0.2491 - val_loss: 0.2724 - val_mse: 0.3170 - val_mae: 0.2724
# Epoch 56/30000
#  - 8s - loss: 0.2502 - mse: 0.2910 - mae: 0.2502 - val_loss: 0.2773 - val_mse: 0.3214 - val_mae: 0.2773
# Epoch 57/30000
#  - 8s - loss: 0.2467 - mse: 0.2890 - mae: 0.2467 - val_loss: 0.2811 - val_mse: 0.3190 - val_mae: 0.2811
# Epoch 58/30000
#  - 8s - loss: 0.2470 - mse: 0.2888 - mae: 0.2470 - val_loss: 0.2718 - val_mse: 0.3144 - val_mae: 0.2718
# Epoch 59/30000
#  - 8s - loss: 0.2458 - mse: 0.2889 - mae: 0.2458 - val_loss: 0.2734 - val_mse: 0.3202 - val_mae: 0.2734
# Epoch 60/30000
#  - 8s - loss: 0.2426 - mse: 0.2854 - mae: 0.2426 - val_loss: 0.2688 - val_mse: 0.3103 - val_mae: 0.2688
# Epoch 61/30000
#  - 8s - loss: 0.2416 - mse: 0.2825 - mae: 0.2416 - val_loss: 0.2759 - val_mse: 0.3170 - val_mae: 0.2759
# Epoch 62/30000
#  - 8s - loss: 0.2407 - mse: 0.2805 - mae: 0.2407 - val_loss: 0.2698 - val_mse: 0.3139 - val_mae: 0.2698
# Epoch 63/30000
#  - 8s - loss: 0.2395 - mse: 0.2780 - mae: 0.2395 - val_loss: 0.2706 - val_mse: 0.3143 - val_mae: 0.2706
# Epoch 64/30000
#  - 8s - loss: 0.2386 - mse: 0.2772 - mae: 0.2386 - val_loss: 0.2677 - val_mse: 0.3108 - val_mae: 0.2677
# Epoch 65/30000
#  - 8s - loss: 0.2377 - mse: 0.2754 - mae: 0.2377 - val_loss: 0.2661 - val_mse: 0.3034 - val_mae: 0.2661
# Epoch 66/30000
#  - 8s - loss: 0.2352 - mse: 0.2717 - mae: 0.2352 - val_loss: 0.2626 - val_mse: 0.3037 - val_mae: 0.2626
# Epoch 67/30000
#  - 8s - loss: 0.2350 - mse: 0.2733 - mae: 0.2350 - val_loss: 0.2671 - val_mse: 0.3058 - val_mae: 0.2671
# Epoch 68/30000
#  - 8s - loss: 0.2350 - mse: 0.2704 - mae: 0.2350 - val_loss: 0.2686 - val_mse: 0.3064 - val_mae: 0.2686
# Epoch 69/30000
#  - 8s - loss: 0.2315 - mse: 0.2664 - mae: 0.2315 - val_loss: 0.2661 - val_mse: 0.3024 - val_mae: 0.2661
# Epoch 70/30000
#  - 8s - loss: 0.2314 - mse: 0.2654 - mae: 0.2314 - val_loss: 0.2635 - val_mse: 0.2994 - val_mae: 0.2635
# Epoch 71/30000
#  - 8s - loss: 0.2296 - mse: 0.2605 - mae: 0.2296 - val_loss: 0.2638 - val_mse: 0.3021 - val_mae: 0.2638
# Epoch 72/30000
#  - 8s - loss: 0.2287 - mse: 0.2589 - mae: 0.2287 - val_loss: 0.2591 - val_mse: 0.2904 - val_mae: 0.2591
# Epoch 73/30000
#  - 8s - loss: 0.2277 - mse: 0.2580 - mae: 0.2277 - val_loss: 0.2616 - val_mse: 0.2948 - val_mae: 0.2616
# Epoch 74/30000
#  - 8s - loss: 0.2272 - mse: 0.2541 - mae: 0.2272 - val_loss: 0.2626 - val_mse: 0.2989 - val_mae: 0.2626
# Epoch 75/30000
#  - 8s - loss: 0.2273 - mse: 0.2542 - mae: 0.2273 - val_loss: 0.2595 - val_mse: 0.2940 - val_mae: 0.2595
# Epoch 76/30000
#  - 8s - loss: 0.2248 - mse: 0.2509 - mae: 0.2248 - val_loss: 0.2603 - val_mse: 0.2943 - val_mae: 0.2603
# Epoch 77/30000
#  - 8s - loss: 0.2253 - mse: 0.2503 - mae: 0.2253 - val_loss: 0.2564 - val_mse: 0.2879 - val_mae: 0.2564
# Epoch 78/30000
#  - 8s - loss: 0.2220 - mse: 0.2475 - mae: 0.2220 - val_loss: 0.2594 - val_mse: 0.2874 - val_mae: 0.2594
# Epoch 79/30000
#  - 8s - loss: 0.2224 - mse: 0.2472 - mae: 0.2224 - val_loss: 0.2618 - val_mse: 0.2941 - val_mae: 0.2618
# Epoch 80/30000
#  - 8s - loss: 0.2214 - mse: 0.2489 - mae: 0.2214 - val_loss: 0.2614 - val_mse: 0.2884 - val_mae: 0.2614
# Epoch 81/30000
#  - 8s - loss: 0.2197 - mse: 0.2487 - mae: 0.2197 - val_loss: 0.2557 - val_mse: 0.2873 - val_mae: 0.2557
# Epoch 82/30000
#  - 8s - loss: 0.2188 - mse: 0.2421 - mae: 0.2188 - val_loss: 0.2558 - val_mse: 0.2866 - val_mae: 0.2558
# Epoch 83/30000
#  - 8s - loss: 0.2192 - mse: 0.2414 - mae: 0.2192 - val_loss: 0.2587 - val_mse: 0.2878 - val_mae: 0.2587
# Epoch 84/30000
#  - 8s - loss: 0.2173 - mse: 0.2409 - mae: 0.2173 - val_loss: 0.2556 - val_mse: 0.2860 - val_mae: 0.2556
# Epoch 85/30000
#  - 8s - loss: 0.2174 - mse: 0.2383 - mae: 0.2174 - val_loss: 0.2555 - val_mse: 0.2817 - val_mae: 0.2555
# Epoch 86/30000
#  - 8s - loss: 0.2164 - mse: 0.2386 - mae: 0.2164 - val_loss: 0.2562 - val_mse: 0.2874 - val_mae: 0.2562
# Epoch 87/30000
#  - 8s - loss: 0.2135 - mse: 0.2354 - mae: 0.2135 - val_loss: 0.2537 - val_mse: 0.2784 - val_mae: 0.2537
# Epoch 88/30000
#  - 8s - loss: 0.2162 - mse: 0.2341 - mae: 0.2162 - val_loss: 0.2627 - val_mse: 0.2839 - val_mae: 0.2627
# Epoch 89/30000
#  - 8s - loss: 0.2143 - mse: 0.2352 - mae: 0.2143 - val_loss: 0.2539 - val_mse: 0.2761 - val_mae: 0.2539
# Epoch 90/30000
#  - 8s - loss: 0.2123 - mse: 0.2289 - mae: 0.2123 - val_loss: 0.2607 - val_mse: 0.2798 - val_mae: 0.2607
# Epoch 91/30000
#  - 8s - loss: 0.2111 - mse: 0.2286 - mae: 0.2111 - val_loss: 0.2509 - val_mse: 0.2722 - val_mae: 0.2509
# Epoch 92/30000
#  - 8s - loss: 0.2113 - mse: 0.2292 - mae: 0.2113 - val_loss: 0.2612 - val_mse: 0.2794 - val_mae: 0.2612
# Epoch 93/30000
#  - 8s - loss: 0.2098 - mse: 0.2244 - mae: 0.2098 - val_loss: 0.2517 - val_mse: 0.2730 - val_mae: 0.2517
# Epoch 94/30000
#  - 8s - loss: 0.2090 - mse: 0.2239 - mae: 0.2090 - val_loss: 0.2531 - val_mse: 0.2774 - val_mae: 0.2531
# Epoch 95/30000
#  - 8s - loss: 0.2100 - mse: 0.2235 - mae: 0.2100 - val_loss: 0.2537 - val_mse: 0.2740 - val_mae: 0.2537
# Epoch 96/30000
#  - 8s - loss: 0.2084 - mse: 0.2228 - mae: 0.2084 - val_loss: 0.2517 - val_mse: 0.2737 - val_mae: 0.2517
# Epoch 97/30000
#  - 8s - loss: 0.2061 - mse: 0.2206 - mae: 0.2061 - val_loss: 0.2523 - val_mse: 0.2712 - val_mae: 0.2523
# Epoch 98/30000
#  - 8s - loss: 0.2062 - mse: 0.2175 - mae: 0.2062 - val_loss: 0.2520 - val_mse: 0.2733 - val_mae: 0.2520
# Epoch 99/30000
#  - 8s - loss: 0.2069 - mse: 0.2171 - mae: 0.2069 - val_loss: 0.2553 - val_mse: 0.2728 - val_mae: 0.2553
# Epoch 100/30000
#  - 8s - loss: 0.2063 - mse: 0.2184 - mae: 0.2063 - val_loss: 0.2544 - val_mse: 0.2810 - val_mae: 0.2544
# Epoch 101/30000
#  - 8s - loss: 0.2058 - mse: 0.2185 - mae: 0.2058 - val_loss: 0.2465 - val_mse: 0.2721 - val_mae: 0.2465
# Epoch 102/30000
#  - 8s - loss: 0.2047 - mse: 0.2153 - mae: 0.2047 - val_loss: 0.2482 - val_mse: 0.2721 - val_mae: 0.2482
# Epoch 103/30000
#  - 8s - loss: 0.2039 - mse: 0.2154 - mae: 0.2039 - val_loss: 0.2571 - val_mse: 0.2751 - val_mae: 0.2571
# Epoch 104/30000
#  - 8s - loss: 0.2026 - mse: 0.2124 - mae: 0.2026 - val_loss: 0.2531 - val_mse: 0.2856 - val_mae: 0.2531
# Epoch 105/30000
#  - 8s - loss: 0.2033 - mse: 0.2138 - mae: 0.2033 - val_loss: 0.2488 - val_mse: 0.2710 - val_mae: 0.2488
# Epoch 106/30000
#  - 8s - loss: 0.2017 - mse: 0.2113 - mae: 0.2017 - val_loss: 0.2477 - val_mse: 0.2730 - val_mae: 0.2477
# Epoch 107/30000
#  - 8s - loss: 0.2013 - mse: 0.2126 - mae: 0.2013 - val_loss: 0.2461 - val_mse: 0.2731 - val_mae: 0.2461
# Epoch 108/30000
#  - 8s - loss: 0.2005 - mse: 0.2096 - mae: 0.2005 - val_loss: 0.2503 - val_mse: 0.2711 - val_mae: 0.2503
# Epoch 109/30000
#  - 8s - loss: 0.1991 - mse: 0.2083 - mae: 0.1991 - val_loss: 0.2505 - val_mse: 0.2738 - val_mae: 0.2505
# Epoch 110/30000
#  - 8s - loss: 0.1999 - mse: 0.2066 - mae: 0.1999 - val_loss: 0.2494 - val_mse: 0.2756 - val_mae: 0.2494
# Epoch 111/30000
#  - 8s - loss: 0.1990 - mse: 0.2073 - mae: 0.1990 - val_loss: 0.2462 - val_mse: 0.2724 - val_mae: 0.2462
# Epoch 112/30000
#  - 8s - loss: 0.1981 - mse: 0.2054 - mae: 0.1981 - val_loss: 0.2486 - val_mse: 0.2700 - val_mae: 0.2486
# Epoch 113/30000
#  - 8s - loss: 0.1971 - mse: 0.2044 - mae: 0.1971 - val_loss: 0.2498 - val_mse: 0.2707 - val_mae: 0.2498
# Epoch 114/30000
#  - 8s - loss: 0.1969 - mse: 0.2067 - mae: 0.1969 - val_loss: 0.2455 - val_mse: 0.2694 - val_mae: 0.2455
# Epoch 115/30000
#  - 8s - loss: 0.1966 - mse: 0.2043 - mae: 0.1966 - val_loss: 0.2498 - val_mse: 0.2716 - val_mae: 0.2498
# Epoch 116/30000
#  - 8s - loss: 0.1965 - mse: 0.2019 - mae: 0.1965 - val_loss: 0.2433 - val_mse: 0.2693 - val_mae: 0.2433
# Epoch 117/30000
#  - 8s - loss: 0.1965 - mse: 0.2021 - mae: 0.1965 - val_loss: 0.2467 - val_mse: 0.2724 - val_mae: 0.2467
# Epoch 118/30000
#  - 8s - loss: 0.1954 - mse: 0.2017 - mae: 0.1954 - val_loss: 0.2479 - val_mse: 0.2703 - val_mae: 0.2479
# Epoch 119/30000
#  - 8s - loss: 0.1948 - mse: 0.2003 - mae: 0.1948 - val_loss: 0.2437 - val_mse: 0.2705 - val_mae: 0.2437
# Epoch 120/30000
#  - 8s - loss: 0.1932 - mse: 0.1958 - mae: 0.1932 - val_loss: 0.2455 - val_mse: 0.2669 - val_mae: 0.2455
# Epoch 121/30000
#  - 8s - loss: 0.1940 - mse: 0.1985 - mae: 0.1940 - val_loss: 0.2451 - val_mse: 0.2688 - val_mae: 0.2451
# Epoch 122/30000
#  - 8s - loss: 0.1928 - mse: 0.1973 - mae: 0.1928 - val_loss: 0.2479 - val_mse: 0.2638 - val_mae: 0.2479
# Epoch 123/30000
#  - 8s - loss: 0.1927 - mse: 0.1976 - mae: 0.1927 - val_loss: 0.2436 - val_mse: 0.2623 - val_mae: 0.2436
# Epoch 124/30000
#  - 8s - loss: 0.1927 - mse: 0.1946 - mae: 0.1927 - val_loss: 0.2425 - val_mse: 0.2576 - val_mae: 0.2425
# Epoch 125/30000
#  - 8s - loss: 0.1909 - mse: 0.1963 - mae: 0.1909 - val_loss: 0.2428 - val_mse: 0.2615 - val_mae: 0.2428
# Epoch 126/30000
#  - 8s - loss: 0.1926 - mse: 0.1990 - mae: 0.1926 - val_loss: 0.2422 - val_mse: 0.2628 - val_mae: 0.2422
# Epoch 127/30000
#  - 8s - loss: 0.1900 - mse: 0.1934 - mae: 0.1900 - val_loss: 0.2412 - val_mse: 0.2623 - val_mae: 0.2412
# Epoch 128/30000
#  - 8s - loss: 0.1918 - mse: 0.1930 - mae: 0.1918 - val_loss: 0.2467 - val_mse: 0.2668 - val_mae: 0.2467
# Epoch 129/30000
#  - 8s - loss: 0.1896 - mse: 0.1926 - mae: 0.1896 - val_loss: 0.2413 - val_mse: 0.2539 - val_mae: 0.2413
# Epoch 130/30000
#  - 8s - loss: 0.1880 - mse: 0.1867 - mae: 0.1880 - val_loss: 0.2443 - val_mse: 0.2586 - val_mae: 0.2443
# Epoch 131/30000
#  - 8s - loss: 0.1891 - mse: 0.1900 - mae: 0.1891 - val_loss: 0.2418 - val_mse: 0.2599 - val_mae: 0.2418
# Epoch 132/30000
#  - 8s - loss: 0.1889 - mse: 0.1895 - mae: 0.1889 - val_loss: 0.2423 - val_mse: 0.2543 - val_mae: 0.2423
# Epoch 133/30000
#  - 8s - loss: 0.1877 - mse: 0.1871 - mae: 0.1877 - val_loss: 0.2442 - val_mse: 0.2562 - val_mae: 0.2442
# Epoch 134/30000
#  - 8s - loss: 0.1883 - mse: 0.1852 - mae: 0.1883 - val_loss: 0.2429 - val_mse: 0.2532 - val_mae: 0.2429
# Epoch 135/30000
#  - 8s - loss: 0.1873 - mse: 0.1829 - mae: 0.1873 - val_loss: 0.2442 - val_mse: 0.2557 - val_mae: 0.2442
# Epoch 136/30000
#  - 8s - loss: 0.1867 - mse: 0.1829 - mae: 0.1867 - val_loss: 0.2420 - val_mse: 0.2520 - val_mae: 0.2420
# Epoch 137/30000
#  - 8s - loss: 0.1862 - mse: 0.1809 - mae: 0.1862 - val_loss: 0.2442 - val_mse: 0.2491 - val_mae: 0.2442
# Epoch 138/30000
#  - 8s - loss: 0.1860 - mse: 0.1764 - mae: 0.1860 - val_loss: 0.2416 - val_mse: 0.2479 - val_mae: 0.2416
# Epoch 139/30000
#  - 8s - loss: 0.1859 - mse: 0.1794 - mae: 0.1859 - val_loss: 0.2435 - val_mse: 0.2510 - val_mae: 0.2435
# Epoch 140/30000
#  - 8s - loss: 0.1844 - mse: 0.1720 - mae: 0.1844 - val_loss: 0.2423 - val_mse: 0.2461 - val_mae: 0.2423
# Epoch 141/30000
#  - 8s - loss: 0.1851 - mse: 0.1738 - mae: 0.1851 - val_loss: 0.2433 - val_mse: 0.2527 - val_mae: 0.2433
# Epoch 142/30000
#  - 8s - loss: 0.1846 - mse: 0.1722 - mae: 0.1846 - val_loss: 0.2445 - val_mse: 0.2456 - val_mae: 0.2445
# Epoch 143/30000
#  - 8s - loss: 0.1837 - mse: 0.1722 - mae: 0.1837 - val_loss: 0.2399 - val_mse: 0.2493 - val_mae: 0.2399
# Epoch 144/30000
#  - 8s - loss: 0.1837 - mse: 0.1707 - mae: 0.1837 - val_loss: 0.2388 - val_mse: 0.2444 - val_mae: 0.2388
# Epoch 145/30000
#  - 8s - loss: 0.1838 - mse: 0.1681 - mae: 0.1838 - val_loss: 0.2398 - val_mse: 0.2430 - val_mae: 0.2398
# Epoch 146/30000
#  - 8s - loss: 0.1814 - mse: 0.1657 - mae: 0.1814 - val_loss: 0.2412 - val_mse: 0.2443 - val_mae: 0.2412
# Epoch 147/30000
#  - 8s - loss: 0.1816 - mse: 0.1674 - mae: 0.1816 - val_loss: 0.2388 - val_mse: 0.2381 - val_mae: 0.2388
# Epoch 148/30000
#  - 8s - loss: 0.1813 - mse: 0.1666 - mae: 0.1813 - val_loss: 0.2390 - val_mse: 0.2399 - val_mae: 0.2390
# Epoch 149/30000
#  - 8s - loss: 0.1806 - mse: 0.1625 - mae: 0.1806 - val_loss: 0.2371 - val_mse: 0.2390 - val_mae: 0.2371
# Epoch 150/30000
#  - 8s - loss: 0.1804 - mse: 0.1663 - mae: 0.1804 - val_loss: 0.2403 - val_mse: 0.2422 - val_mae: 0.2403
# Epoch 151/30000
#  - 8s - loss: 0.1825 - mse: 0.1653 - mae: 0.1825 - val_loss: 0.2389 - val_mse: 0.2399 - val_mae: 0.2389
# Epoch 152/30000
#  - 8s - loss: 0.1804 - mse: 0.1639 - mae: 0.1804 - val_loss: 0.2384 - val_mse: 0.2433 - val_mae: 0.2384
# Epoch 153/30000
#  - 8s - loss: 0.1795 - mse: 0.1648 - mae: 0.1795 - val_loss: 0.2397 - val_mse: 0.2418 - val_mae: 0.2397
# Epoch 154/30000
#  - 8s - loss: 0.1798 - mse: 0.1635 - mae: 0.1798 - val_loss: 0.2449 - val_mse: 0.2433 - val_mae: 0.2449
# Epoch 155/30000
#  - 8s - loss: 0.1792 - mse: 0.1605 - mae: 0.1792 - val_loss: 0.2392 - val_mse: 0.2411 - val_mae: 0.2392
# Epoch 156/30000
#  - 8s - loss: 0.1780 - mse: 0.1601 - mae: 0.1780 - val_loss: 0.2351 - val_mse: 0.2389 - val_mae: 0.2351
# Epoch 157/30000
#  - 8s - loss: 0.1778 - mse: 0.1597 - mae: 0.1778 - val_loss: 0.2397 - val_mse: 0.2389 - val_mae: 0.2397
# Epoch 158/30000
#  - 8s - loss: 0.1771 - mse: 0.1611 - mae: 0.1771 - val_loss: 0.2374 - val_mse: 0.2361 - val_mae: 0.2374
# Epoch 159/30000
#  - 8s - loss: 0.1778 - mse: 0.1611 - mae: 0.1778 - val_loss: 0.2377 - val_mse: 0.2371 - val_mae: 0.2377
# Epoch 160/30000
#  - 8s - loss: 0.1767 - mse: 0.1604 - mae: 0.1767 - val_loss: 0.2375 - val_mse: 0.2374 - val_mae: 0.2375
# Epoch 161/30000
#  - 8s - loss: 0.1769 - mse: 0.1569 - mae: 0.1769 - val_loss: 0.2382 - val_mse: 0.2370 - val_mae: 0.2382
# Epoch 162/30000
#  - 8s - loss: 0.1755 - mse: 0.1558 - mae: 0.1755 - val_loss: 0.2369 - val_mse: 0.2353 - val_mae: 0.2369
# Epoch 163/30000
#  - 8s - loss: 0.1771 - mse: 0.1582 - mae: 0.1771 - val_loss: 0.2352 - val_mse: 0.2349 - val_mae: 0.2352
# Epoch 164/30000
#  - 8s - loss: 0.1749 - mse: 0.1556 - mae: 0.1749 - val_loss: 0.2355 - val_mse: 0.2349 - val_mae: 0.2355
# Epoch 165/30000
#  - 8s - loss: 0.1765 - mse: 0.1583 - mae: 0.1765 - val_loss: 0.2380 - val_mse: 0.2322 - val_mae: 0.2380
# Epoch 166/30000
#  - 8s - loss: 0.1749 - mse: 0.1553 - mae: 0.1749 - val_loss: 0.2352 - val_mse: 0.2342 - val_mae: 0.2352
# Epoch 167/30000
#  - 8s - loss: 0.1746 - mse: 0.1560 - mae: 0.1746 - val_loss: 0.2372 - val_mse: 0.2378 - val_mae: 0.2372
# Epoch 168/30000
#  - 8s - loss: 0.1746 - mse: 0.1528 - mae: 0.1746 - val_loss: 0.2369 - val_mse: 0.2338 - val_mae: 0.2369
# Epoch 169/30000
#  - 8s - loss: 0.1735 - mse: 0.1517 - mae: 0.1735 - val_loss: 0.2339 - val_mse: 0.2374 - val_mae: 0.2339
# Epoch 170/30000
#  - 8s - loss: 0.1744 - mse: 0.1552 - mae: 0.1744 - val_loss: 0.2316 - val_mse: 0.2294 - val_mae: 0.2316
# Epoch 171/30000
#  - 8s - loss: 0.1735 - mse: 0.1522 - mae: 0.1735 - val_loss: 0.2375 - val_mse: 0.2348 - val_mae: 0.2375
# Epoch 172/30000
#  - 8s - loss: 0.1729 - mse: 0.1512 - mae: 0.1729 - val_loss: 0.2382 - val_mse: 0.2336 - val_mae: 0.2382
# Epoch 173/30000
#  - 8s - loss: 0.1731 - mse: 0.1501 - mae: 0.1731 - val_loss: 0.2369 - val_mse: 0.2377 - val_mae: 0.2369
# Epoch 174/30000
#  - 8s - loss: 0.1737 - mse: 0.1546 - mae: 0.1737 - val_loss: 0.2361 - val_mse: 0.2427 - val_mae: 0.2361
# Epoch 175/30000
#  - 8s - loss: 0.1726 - mse: 0.1504 - mae: 0.1726 - val_loss: 0.2349 - val_mse: 0.2339 - val_mae: 0.2349
# Epoch 176/30000
#  - 8s - loss: 0.1711 - mse: 0.1499 - mae: 0.1711 - val_loss: 0.2345 - val_mse: 0.2326 - val_mae: 0.2345
# Epoch 177/30000
#  - 8s - loss: 0.1719 - mse: 0.1526 - mae: 0.1719 - val_loss: 0.2374 - val_mse: 0.2395 - val_mae: 0.2374
# Epoch 178/30000
#  - 8s - loss: 0.1720 - mse: 0.1508 - mae: 0.1720 - val_loss: 0.2385 - val_mse: 0.2371 - val_mae: 0.2385
# Epoch 179/30000
#  - 8s - loss: 0.1721 - mse: 0.1490 - mae: 0.1721 - val_loss: 0.2346 - val_mse: 0.2312 - val_mae: 0.2346
# Epoch 180/30000
#  - 8s - loss: 0.1707 - mse: 0.1476 - mae: 0.1707 - val_loss: 0.2375 - val_mse: 0.2357 - val_mae: 0.2375
# Epoch 181/30000
#  - 8s - loss: 0.1697 - mse: 0.1459 - mae: 0.1697 - val_loss: 0.2403 - val_mse: 0.2432 - val_mae: 0.2403
# Epoch 182/30000
#  - 8s - loss: 0.1712 - mse: 0.1488 - mae: 0.1712 - val_loss: 0.2349 - val_mse: 0.2325 - val_mae: 0.2349
# Epoch 183/30000
#  - 8s - loss: 0.1697 - mse: 0.1490 - mae: 0.1697 - val_loss: 0.2334 - val_mse: 0.2375 - val_mae: 0.2334
# Epoch 184/30000
#  - 8s - loss: 0.1696 - mse: 0.1468 - mae: 0.1696 - val_loss: 0.2327 - val_mse: 0.2370 - val_mae: 0.2327
# Epoch 185/30000
#  - 8s - loss: 0.1699 - mse: 0.1470 - mae: 0.1699 - val_loss: 0.2347 - val_mse: 0.2382 - val_mae: 0.2347
# Epoch 186/30000
#  - 8s - loss: 0.1688 - mse: 0.1451 - mae: 0.1688 - val_loss: 0.2339 - val_mse: 0.2382 - val_mae: 0.2339
# Epoch 187/30000
#  - 8s - loss: 0.1691 - mse: 0.1482 - mae: 0.1691 - val_loss: 0.2343 - val_mse: 0.2311 - val_mae: 0.2343
# Epoch 188/30000
#  - 8s - loss: 0.1684 - mse: 0.1453 - mae: 0.1684 - val_loss: 0.2428 - val_mse: 0.2412 - val_mae: 0.2428
# Epoch 189/30000
#  - 8s - loss: 0.1691 - mse: 0.1456 - mae: 0.1691 - val_loss: 0.2358 - val_mse: 0.2343 - val_mae: 0.2358
# Epoch 190/30000
#  - 8s - loss: 0.1686 - mse: 0.1479 - mae: 0.1686 - val_loss: 0.2339 - val_mse: 0.2322 - val_mae: 0.2339
# Epoch 191/30000
#  - 8s - loss: 0.1686 - mse: 0.1457 - mae: 0.1686 - val_loss: 0.2310 - val_mse: 0.2313 - val_mae: 0.2310
# Epoch 192/30000
#  - 8s - loss: 0.1682 - mse: 0.1450 - mae: 0.1682 - val_loss: 0.2347 - val_mse: 0.2377 - val_mae: 0.2347
# Epoch 193/30000
#  - 8s - loss: 0.1687 - mse: 0.1471 - mae: 0.1687 - val_loss: 0.2357 - val_mse: 0.2331 - val_mae: 0.2357
# Epoch 194/30000
#  - 8s - loss: 0.1676 - mse: 0.1442 - mae: 0.1676 - val_loss: 0.2333 - val_mse: 0.2377 - val_mae: 0.2333
# Epoch 195/30000
#  - 8s - loss: 0.1686 - mse: 0.1449 - mae: 0.1686 - val_loss: 0.2327 - val_mse: 0.2300 - val_mae: 0.2327
# Epoch 196/30000
#  - 8s - loss: 0.1677 - mse: 0.1423 - mae: 0.1677 - val_loss: 0.2301 - val_mse: 0.2287 - val_mae: 0.2301
# Epoch 197/30000
#  - 8s - loss: 0.1669 - mse: 0.1425 - mae: 0.1669 - val_loss: 0.2354 - val_mse: 0.2329 - val_mae: 0.2354
# Epoch 198/30000
#  - 8s - loss: 0.1662 - mse: 0.1424 - mae: 0.1662 - val_loss: 0.2360 - val_mse: 0.2367 - val_mae: 0.2360
# Epoch 199/30000
#  - 8s - loss: 0.1655 - mse: 0.1420 - mae: 0.1655 - val_loss: 0.2314 - val_mse: 0.2345 - val_mae: 0.2314
# Epoch 200/30000
#  - 8s - loss: 0.1661 - mse: 0.1441 - mae: 0.1661 - val_loss: 0.2346 - val_mse: 0.2348 - val_mae: 0.2346
# Epoch 201/30000
#  - 8s - loss: 0.1667 - mse: 0.1426 - mae: 0.1667 - val_loss: 0.2310 - val_mse: 0.2267 - val_mae: 0.2310
# Epoch 202/30000
#  - 8s - loss: 0.1657 - mse: 0.1421 - mae: 0.1657 - val_loss: 0.2312 - val_mse: 0.2322 - val_mae: 0.2312
# Epoch 203/30000
#  - 8s - loss: 0.1655 - mse: 0.1404 - mae: 0.1655 - val_loss: 0.2335 - val_mse: 0.2352 - val_mae: 0.2335
# Epoch 204/30000
#  - 8s - loss: 0.1659 - mse: 0.1415 - mae: 0.1659 - val_loss: 0.2331 - val_mse: 0.2301 - val_mae: 0.2331
# Epoch 205/30000
#  - 8s - loss: 0.1642 - mse: 0.1399 - mae: 0.1642 - val_loss: 0.2308 - val_mse: 0.2267 - val_mae: 0.2308
# Epoch 206/30000
#  - 8s - loss: 0.1647 - mse: 0.1401 - mae: 0.1647 - val_loss: 0.2326 - val_mse: 0.2398 - val_mae: 0.2326
# Epoch 207/30000
#  - 8s - loss: 0.1635 - mse: 0.1363 - mae: 0.1635 - val_loss: 0.2331 - val_mse: 0.2324 - val_mae: 0.2331
# Epoch 208/30000
#  - 8s - loss: 0.1644 - mse: 0.1393 - mae: 0.1644 - val_loss: 0.2331 - val_mse: 0.2286 - val_mae: 0.2331
# Epoch 209/30000
#  - 8s - loss: 0.1637 - mse: 0.1404 - mae: 0.1637 - val_loss: 0.2345 - val_mse: 0.2330 - val_mae: 0.2345
# Epoch 210/30000
#  - 8s - loss: 0.1645 - mse: 0.1433 - mae: 0.1645 - val_loss: 0.2360 - val_mse: 0.2368 - val_mae: 0.2360
# Epoch 211/30000
#  - 8s - loss: 0.1630 - mse: 0.1384 - mae: 0.1630 - val_loss: 0.2333 - val_mse: 0.2402 - val_mae: 0.2333
# Epoch 212/30000
#  - 8s - loss: 0.1630 - mse: 0.1390 - mae: 0.1630 - val_loss: 0.2330 - val_mse: 0.2262 - val_mae: 0.2330
# Epoch 213/30000
#  - 8s - loss: 0.1636 - mse: 0.1390 - mae: 0.1636 - val_loss: 0.2338 - val_mse: 0.2281 - val_mae: 0.2338
# Epoch 214/30000
#  - 8s - loss: 0.1635 - mse: 0.1382 - mae: 0.1635 - val_loss: 0.2311 - val_mse: 0.2265 - val_mae: 0.2311
# Epoch 215/30000
#  - 8s - loss: 0.1632 - mse: 0.1379 - mae: 0.1632 - val_loss: 0.2318 - val_mse: 0.2315 - val_mae: 0.2318
# Epoch 216/30000
#  - 8s - loss: 0.1630 - mse: 0.1370 - mae: 0.1630 - val_loss: 0.2345 - val_mse: 0.2352 - val_mae: 0.2345
# Epoch 217/30000
#  - 8s - loss: 0.1618 - mse: 0.1381 - mae: 0.1618 - val_loss: 0.2303 - val_mse: 0.2295 - val_mae: 0.2303
# Epoch 218/30000
#  - 8s - loss: 0.1621 - mse: 0.1366 - mae: 0.1621 - val_loss: 0.2324 - val_mse: 0.2276 - val_mae: 0.2324
# Epoch 219/30000
#  - 8s - loss: 0.1630 - mse: 0.1376 - mae: 0.1630 - val_loss: 0.2341 - val_mse: 0.2366 - val_mae: 0.2341
# Epoch 220/30000
#  - 8s - loss: 0.1619 - mse: 0.1368 - mae: 0.1619 - val_loss: 0.2359 - val_mse: 0.2362 - val_mae: 0.2359
# Epoch 221/30000
#  - 8s - loss: 0.1619 - mse: 0.1378 - mae: 0.1619 - val_loss: 0.2321 - val_mse: 0.2291 - val_mae: 0.2321
# Epoch 222/30000
#  - 8s - loss: 0.1610 - mse: 0.1360 - mae: 0.1610 - val_loss: 0.2275 - val_mse: 0.2250 - val_mae: 0.2275
# Epoch 223/30000
#  - 8s - loss: 0.1624 - mse: 0.1376 - mae: 0.1624 - val_loss: 0.2359 - val_mse: 0.2316 - val_mae: 0.2359
# Epoch 224/30000
#  - 8s - loss: 0.1610 - mse: 0.1359 - mae: 0.1610 - val_loss: 0.2311 - val_mse: 0.2391 - val_mae: 0.2311
# Epoch 225/30000
#  - 8s - loss: 0.1617 - mse: 0.1365 - mae: 0.1617 - val_loss: 0.2330 - val_mse: 0.2307 - val_mae: 0.2330
# Epoch 226/30000
#  - 8s - loss: 0.1607 - mse: 0.1341 - mae: 0.1607 - val_loss: 0.2295 - val_mse: 0.2307 - val_mae: 0.2295
# Epoch 227/30000
#  - 8s - loss: 0.1605 - mse: 0.1348 - mae: 0.1605 - val_loss: 0.2345 - val_mse: 0.2344 - val_mae: 0.2345
# Epoch 228/30000
#  - 8s - loss: 0.1603 - mse: 0.1342 - mae: 0.1603 - val_loss: 0.2297 - val_mse: 0.2306 - val_mae: 0.2297
# Epoch 229/30000
#  - 8s - loss: 0.1599 - mse: 0.1349 - mae: 0.1599 - val_loss: 0.2346 - val_mse: 0.2319 - val_mae: 0.2346
# Epoch 230/30000
#  - 8s - loss: 0.1592 - mse: 0.1341 - mae: 0.1592 - val_loss: 0.2325 - val_mse: 0.2294 - val_mae: 0.2325
# Epoch 231/30000
#  - 8s - loss: 0.1598 - mse: 0.1351 - mae: 0.1598 - val_loss: 0.2325 - val_mse: 0.2360 - val_mae: 0.2325
# Epoch 232/30000
#  - 8s - loss: 0.1609 - mse: 0.1346 - mae: 0.1609 - val_loss: 0.2317 - val_mse: 0.2281 - val_mae: 0.2317
# Epoch 233/30000
#  - 8s - loss: 0.1593 - mse: 0.1338 - mae: 0.1593 - val_loss: 0.2336 - val_mse: 0.2291 - val_mae: 0.2336
# Epoch 234/30000
#  - 8s - loss: 0.1596 - mse: 0.1323 - mae: 0.1596 - val_loss: 0.2288 - val_mse: 0.2265 - val_mae: 0.2288
# Epoch 235/30000
#  - 8s - loss: 0.1595 - mse: 0.1349 - mae: 0.1595 - val_loss: 0.2317 - val_mse: 0.2296 - val_mae: 0.2317
# Epoch 236/30000
#  - 8s - loss: 0.1579 - mse: 0.1329 - mae: 0.1579 - val_loss: 0.2319 - val_mse: 0.2270 - val_mae: 0.2319
# Epoch 237/30000
#  - 8s - loss: 0.1585 - mse: 0.1313 - mae: 0.1585 - val_loss: 0.2307 - val_mse: 0.2317 - val_mae: 0.2307
# Epoch 238/30000
#  - 8s - loss: 0.1589 - mse: 0.1327 - mae: 0.1589 - val_loss: 0.2309 - val_mse: 0.2313 - val_mae: 0.2309
# Epoch 239/30000
#  - 8s - loss: 0.1586 - mse: 0.1321 - mae: 0.1586 - val_loss: 0.2301 - val_mse: 0.2292 - val_mae: 0.2301
# Epoch 240/30000
#  - 8s - loss: 0.1579 - mse: 0.1306 - mae: 0.1579 - val_loss: 0.2346 - val_mse: 0.2346 - val_mae: 0.2346
# Epoch 241/30000
#  - 8s - loss: 0.1574 - mse: 0.1303 - mae: 0.1574 - val_loss: 0.2313 - val_mse: 0.2348 - val_mae: 0.2313
# Epoch 242/30000
#  - 8s - loss: 0.1576 - mse: 0.1308 - mae: 0.1576 - val_loss: 0.2321 - val_mse: 0.2278 - val_mae: 0.2321
# Epoch 243/30000
#  - 8s - loss: 0.1583 - mse: 0.1318 - mae: 0.1583 - val_loss: 0.2296 - val_mse: 0.2285 - val_mae: 0.2296
# Epoch 244/30000
#  - 8s - loss: 0.1571 - mse: 0.1302 - mae: 0.1571 - val_loss: 0.2298 - val_mse: 0.2268 - val_mae: 0.2298
# Epoch 245/30000
#  - 8s - loss: 0.1576 - mse: 0.1314 - mae: 0.1576 - val_loss: 0.2300 - val_mse: 0.2283 - val_mae: 0.2300
# Epoch 246/30000
#  - 8s - loss: 0.1573 - mse: 0.1321 - mae: 0.1573 - val_loss: 0.2299 - val_mse: 0.2258 - val_mae: 0.2299
# Epoch 247/30000
#  - 8s - loss: 0.1562 - mse: 0.1291 - mae: 0.1562 - val_loss: 0.2306 - val_mse: 0.2285 - val_mae: 0.2306
# Epoch 248/30000
#  - 8s - loss: 0.1572 - mse: 0.1306 - mae: 0.1572 - val_loss: 0.2331 - val_mse: 0.2299 - val_mae: 0.2331
# Epoch 249/30000
#  - 8s - loss: 0.1564 - mse: 0.1308 - mae: 0.1564 - val_loss: 0.2329 - val_mse: 0.2288 - val_mae: 0.2329
# Epoch 250/30000
#  - 8s - loss: 0.1575 - mse: 0.1304 - mae: 0.1575 - val_loss: 0.2327 - val_mse: 0.2337 - val_mae: 0.2327
# Epoch 251/30000
#  - 8s - loss: 0.1565 - mse: 0.1302 - mae: 0.1565 - val_loss: 0.2318 - val_mse: 0.2354 - val_mae: 0.2318
# Epoch 252/30000
#  - 8s - loss: 0.1552 - mse: 0.1279 - mae: 0.1552 - val_loss: 0.2367 - val_mse: 0.2345 - val_mae: 0.2367
# Epoch 253/30000
#  - 8s - loss: 0.1544 - mse: 0.1283 - mae: 0.1544 - val_loss: 0.2308 - val_mse: 0.2311 - val_mae: 0.2308
# Epoch 254/30000
#  - 8s - loss: 0.1551 - mse: 0.1278 - mae: 0.1551 - val_loss: 0.2294 - val_mse: 0.2326 - val_mae: 0.2294
# Epoch 255/30000
#  - 8s - loss: 0.1563 - mse: 0.1286 - mae: 0.1563 - val_loss: 0.2337 - val_mse: 0.2342 - val_mae: 0.2337
# Epoch 256/30000
#  - 8s - loss: 0.1562 - mse: 0.1284 - mae: 0.1562 - val_loss: 0.2324 - val_mse: 0.2324 - val_mae: 0.2324
# Epoch 257/30000
#  - 8s - loss: 0.1543 - mse: 0.1266 - mae: 0.1543 - val_loss: 0.2324 - val_mse: 0.2301 - val_mae: 0.2324
# Epoch 258/30000
#  - 8s - loss: 0.1544 - mse: 0.1264 - mae: 0.1544 - val_loss: 0.2283 - val_mse: 0.2293 - val_mae: 0.2283
# Epoch 259/30000
#  - 8s - loss: 0.1547 - mse: 0.1267 - mae: 0.1547 - val_loss: 0.2318 - val_mse: 0.2296 - val_mae: 0.2318
# Epoch 260/30000
#  - 8s - loss: 0.1552 - mse: 0.1268 - mae: 0.1552 - val_loss: 0.2313 - val_mse: 0.2325 - val_mae: 0.2313
# Epoch 261/30000
#  - 8s - loss: 0.1561 - mse: 0.1289 - mae: 0.1561 - val_loss: 0.2300 - val_mse: 0.2307 - val_mae: 0.2300
# Epoch 262/30000
#  - 8s - loss: 0.1543 - mse: 0.1266 - mae: 0.1543 - val_loss: 0.2311 - val_mse: 0.2298 - val_mae: 0.2311
# Epoch 263/30000
#  - 8s - loss: 0.1540 - mse: 0.1263 - mae: 0.1540 - val_loss: 0.2326 - val_mse: 0.2315 - val_mae: 0.2326
# Epoch 264/30000
#  - 8s - loss: 0.1542 - mse: 0.1256 - mae: 0.1542 - val_loss: 0.2291 - val_mse: 0.2316 - val_mae: 0.2291
# Epoch 265/30000
#  - 8s - loss: 0.1539 - mse: 0.1238 - mae: 0.1539 - val_loss: 0.2286 - val_mse: 0.2391 - val_mae: 0.2286
# Epoch 266/30000
#  - 8s - loss: 0.1544 - mse: 0.1267 - mae: 0.1544 - val_loss: 0.2283 - val_mse: 0.2320 - val_mae: 0.2283
# Epoch 267/30000
#  - 8s - loss: 0.1544 - mse: 0.1264 - mae: 0.1544 - val_loss: 0.2316 - val_mse: 0.2331 - val_mae: 0.2316
# Epoch 268/30000
#  - 8s - loss: 0.1539 - mse: 0.1261 - mae: 0.1539 - val_loss: 0.2307 - val_mse: 0.2325 - val_mae: 0.2307
# Epoch 269/30000
#  - 8s - loss: 0.1529 - mse: 0.1242 - mae: 0.1529 - val_loss: 0.2319 - val_mse: 0.2295 - val_mae: 0.2319
# Epoch 270/30000
#  - 8s - loss: 0.1529 - mse: 0.1237 - mae: 0.1529 - val_loss: 0.2295 - val_mse: 0.2340 - val_mae: 0.2295
# Epoch 271/30000
#  - 8s - loss: 0.1538 - mse: 0.1248 - mae: 0.1538 - val_loss: 0.2310 - val_mse: 0.2325 - val_mae: 0.2310
# Epoch 272/30000
#  - 8s - loss: 0.1528 - mse: 0.1250 - mae: 0.1528 - val_loss: 0.2280 - val_mse: 0.2313 - val_mae: 0.2280

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.06 degrees
# Root Mean Squared Error is 1.58 degrees
# Mean Absolute Error is 1.58 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is 0.04 degrees
# Root Mean Squared Error is 3.29 degrees
# Mean Absolute Error is 3.29 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthmodelparam_cnn3v13.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthmodel_cnn3v13.h5')
