# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,25)
nw_resize = 2
nh_resize = 3
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (14668, 40, 80, 3)

# %%
tlen = len(xtemp[0])-2 +len(xtemp[1])-2 #remove 2 samples from 24
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

# %%
plt.imshow(x_train[-2])

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,25)
date = ('11_15_2020','11_19_2020')
y_gt = {}
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])-2 +len(y_gt[1])-3 #remove 2 samples from 24 and 3 from 25
y_train = np.zeros((tlen,1))
y_train[:len(y_gt[0])-2] = y_gt[0][:len(y_gt[0])-2]
y_train[(len(y_gt[0])-2):] = y_gt[1][:len(y_gt[1])-3]

# %%
y_gt[0].shape
# Out:
# (12751, 1)

# %%
# Obtain X and Y data
# x_train.shape
# xtrainnew = pd.DataFrame(data=np.reshape(x_train, (x_train.shape[0],x_train.shape[1]*x_train.shape[2])))
# yframe = pd.DataFrame(data=y_train)

# TheData = pd.concat([xtrainnew,yframe],axis=1) #only contains video data
print(x_train.shape)
print(y_train.shape)
# Out:
# (27415, 40, 80, 3)
# (27415, 1)

# %%
print(xtemp[0].shape)
print(y_gt[0].shape)
print(xtemp[1].shape)
print(y_gt[1].shape)
# Out:
# (12751, 40, 80, 3)
# (12751, 1)
# (14668, 40, 80, 3)
# (14669, 1)

# %%
# xtmp = xtrainnew[300,:]
# plt.imshow(np.reshape(xtmp, (x_train.shape[1],x_train.shape[2])))

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
x_train.shape[1]
# Out:
# 40

# %% [markdown]
# # Regress using Neural Network

# %%
np.min(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 0.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.2
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 40, 80, 3)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 40, 80, 8)         224
# _________________________________________________________________
# activation_17 (Activation)   (None, 40, 80, 8)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 20, 40, 8)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 40, 16)        1168
# _________________________________________________________________
# activation_18 (Activation)   (None, 20, 40, 16)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 10, 20, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 20, 32)        4640
# _________________________________________________________________
# activation_19 (Activation)   (None, 10, 20, 32)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 10, 32)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 10, 64)         18496
# _________________________________________________________________
# activation_20 (Activation)   (None, 5, 10, 64)         0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 2, 5, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 640)               0
# _________________________________________________________________
# activation_21 (Activation)   (None, 640)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               82048
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 106,705
# Trainable params: 106,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True)
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 11734 samples, validate on 2934 samples
# Epoch 1/30000
#  - 1s - loss: 0.6468 - mse: 1.0033 - mae: 0.6468 - val_loss: 0.6459 - val_mse: 0.9559 - val_mae: 0.6459
# Epoch 2/30000
#  - 1s - loss: 0.6450 - mse: 1.0018 - mae: 0.6450 - val_loss: 0.6464 - val_mse: 0.9612 - val_mae: 0.6464
# Epoch 3/30000
#  - 1s - loss: 0.6449 - mse: 1.0017 - mae: 0.6449 - val_loss: 0.6430 - val_mse: 0.9561 - val_mae: 0.6430
# Epoch 4/30000
#  - 1s - loss: 0.6429 - mse: 0.9996 - mae: 0.6429 - val_loss: 0.6413 - val_mse: 0.9516 - val_mae: 0.6413
# Epoch 5/30000
#  - 1s - loss: 0.6391 - mse: 0.9931 - mae: 0.6391 - val_loss: 0.6371 - val_mse: 0.9449 - val_mae: 0.6371
# Epoch 6/30000
#  - 1s - loss: 0.6367 - mse: 0.9889 - mae: 0.6367 - val_loss: 0.6384 - val_mse: 0.9427 - val_mae: 0.6384
# Epoch 7/30000
#  - 1s - loss: 0.6305 - mse: 0.9776 - mae: 0.6305 - val_loss: 0.6315 - val_mse: 0.9299 - val_mae: 0.6315
# Epoch 8/30000
#  - 1s - loss: 0.6246 - mse: 0.9669 - mae: 0.6246 - val_loss: 0.6297 - val_mse: 0.9232 - val_mae: 0.6297
# Epoch 9/30000
#  - 1s - loss: 0.6207 - mse: 0.9542 - mae: 0.6207 - val_loss: 0.6242 - val_mse: 0.9167 - val_mae: 0.6242
# Epoch 10/30000
#  - 1s - loss: 0.6148 - mse: 0.9447 - mae: 0.6148 - val_loss: 0.6192 - val_mse: 0.9027 - val_mae: 0.6192
# Epoch 11/30000
#  - 1s - loss: 0.6072 - mse: 0.9267 - mae: 0.6072 - val_loss: 0.6112 - val_mse: 0.8948 - val_mae: 0.6112
# Epoch 12/30000
#  - 1s - loss: 0.5999 - mse: 0.9097 - mae: 0.5999 - val_loss: 0.6128 - val_mse: 0.8929 - val_mae: 0.6128
# Epoch 13/30000
#  - 1s - loss: 0.5951 - mse: 0.8970 - mae: 0.5951 - val_loss: 0.5994 - val_mse: 0.8691 - val_mae: 0.5994
# Epoch 14/30000
#  - 1s - loss: 0.5879 - mse: 0.8771 - mae: 0.5879 - val_loss: 0.5957 - val_mse: 0.8575 - val_mae: 0.5957
# Epoch 15/30000
#  - 1s - loss: 0.5814 - mse: 0.8595 - mae: 0.5814 - val_loss: 0.5894 - val_mse: 0.8428 - val_mae: 0.5894
# Epoch 16/30000
#  - 1s - loss: 0.5777 - mse: 0.8474 - mae: 0.5777 - val_loss: 0.5873 - val_mse: 0.8298 - val_mae: 0.5873
# Epoch 17/30000
#  - 1s - loss: 0.5677 - mse: 0.8228 - mae: 0.5677 - val_loss: 0.5846 - val_mse: 0.8199 - val_mae: 0.5846
# Epoch 18/30000
#  - 1s - loss: 0.5596 - mse: 0.8026 - mae: 0.5596 - val_loss: 0.5793 - val_mse: 0.7973 - val_mae: 0.5793
# Epoch 19/30000
#  - 1s - loss: 0.5529 - mse: 0.7830 - mae: 0.5529 - val_loss: 0.5822 - val_mse: 0.8010 - val_mae: 0.5822
# Epoch 20/30000
#  - 1s - loss: 0.5483 - mse: 0.7713 - mae: 0.5483 - val_loss: 0.5699 - val_mse: 0.7743 - val_mae: 0.5699
# Epoch 21/30000
#  - 1s - loss: 0.5440 - mse: 0.7516 - mae: 0.5440 - val_loss: 0.5708 - val_mse: 0.7634 - val_mae: 0.5708
# Epoch 22/30000
#  - 1s - loss: 0.5309 - mse: 0.7233 - mae: 0.5309 - val_loss: 0.5564 - val_mse: 0.7461 - val_mae: 0.5564
# Epoch 23/30000
#  - 1s - loss: 0.5283 - mse: 0.7110 - mae: 0.5283 - val_loss: 0.5514 - val_mse: 0.7321 - val_mae: 0.5514
# Epoch 24/30000
#  - 1s - loss: 0.5184 - mse: 0.6876 - mae: 0.5184 - val_loss: 0.5466 - val_mse: 0.7130 - val_mae: 0.5466
# Epoch 25/30000
#  - 1s - loss: 0.5155 - mse: 0.6773 - mae: 0.5155 - val_loss: 0.5455 - val_mse: 0.7084 - val_mae: 0.5455
# Epoch 26/30000
#  - 1s - loss: 0.5033 - mse: 0.6497 - mae: 0.5033 - val_loss: 0.5411 - val_mse: 0.6981 - val_mae: 0.5411
# Epoch 27/30000
#  - 1s - loss: 0.4989 - mse: 0.6369 - mae: 0.4989 - val_loss: 0.5481 - val_mse: 0.6953 - val_mae: 0.5481
# Epoch 28/30000
#  - 1s - loss: 0.4970 - mse: 0.6348 - mae: 0.4970 - val_loss: 0.5407 - val_mse: 0.6828 - val_mae: 0.5407
# Epoch 29/30000
#  - 1s - loss: 0.4863 - mse: 0.6112 - mae: 0.4863 - val_loss: 0.5237 - val_mse: 0.6499 - val_mae: 0.5237
# Epoch 30/30000
#  - 1s - loss: 0.4819 - mse: 0.6012 - mae: 0.4819 - val_loss: 0.5277 - val_mse: 0.6634 - val_mae: 0.5277
# Epoch 31/30000
#  - 1s - loss: 0.4708 - mse: 0.5810 - mae: 0.4708 - val_loss: 0.5193 - val_mse: 0.6485 - val_mae: 0.5193
# Epoch 32/30000
#  - 1s - loss: 0.4673 - mse: 0.5708 - mae: 0.4673 - val_loss: 0.5122 - val_mse: 0.6322 - val_mae: 0.5122
# Epoch 33/30000
#  - 1s - loss: 0.4585 - mse: 0.5552 - mae: 0.4585 - val_loss: 0.5099 - val_mse: 0.6230 - val_mae: 0.5099
# Epoch 34/30000
#  - 1s - loss: 0.4596 - mse: 0.5506 - mae: 0.4596 - val_loss: 0.5182 - val_mse: 0.6418 - val_mae: 0.5182
# Epoch 35/30000
#  - 1s - loss: 0.4483 - mse: 0.5311 - mae: 0.4483 - val_loss: 0.4982 - val_mse: 0.5995 - val_mae: 0.4982
# Epoch 36/30000
#  - 1s - loss: 0.4418 - mse: 0.5190 - mae: 0.4418 - val_loss: 0.4895 - val_mse: 0.5876 - val_mae: 0.4895
# Epoch 37/30000
#  - 1s - loss: 0.4397 - mse: 0.5123 - mae: 0.4397 - val_loss: 0.4915 - val_mse: 0.5903 - val_mae: 0.4915
# Epoch 38/30000
#  - 1s - loss: 0.4335 - mse: 0.5038 - mae: 0.4335 - val_loss: 0.4877 - val_mse: 0.5759 - val_mae: 0.4877
# Epoch 39/30000
#  - 1s - loss: 0.4271 - mse: 0.4896 - mae: 0.4271 - val_loss: 0.4804 - val_mse: 0.5661 - val_mae: 0.4804
# Epoch 40/30000
#  - 1s - loss: 0.4231 - mse: 0.4812 - mae: 0.4231 - val_loss: 0.4893 - val_mse: 0.5687 - val_mae: 0.4893
# Epoch 41/30000
#  - 1s - loss: 0.4138 - mse: 0.4673 - mae: 0.4138 - val_loss: 0.4714 - val_mse: 0.5496 - val_mae: 0.4714
# Epoch 42/30000
#  - 1s - loss: 0.4147 - mse: 0.4638 - mae: 0.4147 - val_loss: 0.4818 - val_mse: 0.5573 - val_mae: 0.4818
# Epoch 43/30000
#  - 1s - loss: 0.4091 - mse: 0.4491 - mae: 0.4091 - val_loss: 0.4730 - val_mse: 0.5439 - val_mae: 0.4730
# Epoch 44/30000
#  - 1s - loss: 0.4035 - mse: 0.4394 - mae: 0.4035 - val_loss: 0.4629 - val_mse: 0.5254 - val_mae: 0.4629
# Epoch 45/30000
#  - 1s - loss: 0.3990 - mse: 0.4367 - mae: 0.3990 - val_loss: 0.4815 - val_mse: 0.5585 - val_mae: 0.4815
# Epoch 46/30000
#  - 1s - loss: 0.3944 - mse: 0.4240 - mae: 0.3944 - val_loss: 0.4569 - val_mse: 0.5168 - val_mae: 0.4569
# Epoch 47/30000
#  - 1s - loss: 0.3883 - mse: 0.4125 - mae: 0.3883 - val_loss: 0.4579 - val_mse: 0.5167 - val_mae: 0.4579
# Epoch 48/30000
#  - 1s - loss: 0.3812 - mse: 0.4006 - mae: 0.3812 - val_loss: 0.4553 - val_mse: 0.5116 - val_mae: 0.4553
# Epoch 49/30000
#  - 1s - loss: 0.3845 - mse: 0.4043 - mae: 0.3845 - val_loss: 0.4464 - val_mse: 0.4944 - val_mae: 0.4464
# Epoch 50/30000
#  - 1s - loss: 0.3741 - mse: 0.3857 - mae: 0.3741 - val_loss: 0.4408 - val_mse: 0.4936 - val_mae: 0.4408
# Epoch 51/30000
#  - 1s - loss: 0.3763 - mse: 0.3894 - mae: 0.3763 - val_loss: 0.4616 - val_mse: 0.5183 - val_mae: 0.4616
# Epoch 52/30000
#  - 1s - loss: 0.3790 - mse: 0.3862 - mae: 0.3790 - val_loss: 0.4440 - val_mse: 0.4912 - val_mae: 0.4440
# Epoch 53/30000
#  - 1s - loss: 0.3657 - mse: 0.3723 - mae: 0.3657 - val_loss: 0.4360 - val_mse: 0.4796 - val_mae: 0.4360
# Epoch 54/30000
#  - 1s - loss: 0.3626 - mse: 0.3639 - mae: 0.3626 - val_loss: 0.4356 - val_mse: 0.4860 - val_mae: 0.4356
# Epoch 55/30000
#  - 1s - loss: 0.3608 - mse: 0.3592 - mae: 0.3608 - val_loss: 0.4325 - val_mse: 0.4681 - val_mae: 0.4325
# Epoch 56/30000
#  - 1s - loss: 0.3493 - mse: 0.3452 - mae: 0.3493 - val_loss: 0.4272 - val_mse: 0.4671 - val_mae: 0.4272
# Epoch 57/30000
#  - 1s - loss: 0.3468 - mse: 0.3393 - mae: 0.3468 - val_loss: 0.4338 - val_mse: 0.4719 - val_mae: 0.4338
# Epoch 58/30000
#  - 1s - loss: 0.3472 - mse: 0.3365 - mae: 0.3472 - val_loss: 0.4233 - val_mse: 0.4530 - val_mae: 0.4233
# Epoch 59/30000
#  - 1s - loss: 0.3488 - mse: 0.3350 - mae: 0.3488 - val_loss: 0.4221 - val_mse: 0.4448 - val_mae: 0.4221
# Epoch 60/30000
#  - 1s - loss: 0.3398 - mse: 0.3243 - mae: 0.3398 - val_loss: 0.4225 - val_mse: 0.4577 - val_mae: 0.4225
# Epoch 61/30000
#  - 1s - loss: 0.3334 - mse: 0.3187 - mae: 0.3334 - val_loss: 0.4203 - val_mse: 0.4571 - val_mae: 0.4203
# Epoch 62/30000
#  - 1s - loss: 0.3374 - mse: 0.3161 - mae: 0.3374 - val_loss: 0.4231 - val_mse: 0.4581 - val_mae: 0.4231
# Epoch 63/30000
#  - 1s - loss: 0.3302 - mse: 0.3083 - mae: 0.3302 - val_loss: 0.4158 - val_mse: 0.4450 - val_mae: 0.4158
# Epoch 64/30000
#  - 1s - loss: 0.3302 - mse: 0.3068 - mae: 0.3302 - val_loss: 0.4137 - val_mse: 0.4406 - val_mae: 0.4137
# Epoch 65/30000
#  - 1s - loss: 0.3276 - mse: 0.3042 - mae: 0.3276 - val_loss: 0.4197 - val_mse: 0.4496 - val_mae: 0.4197
# Epoch 66/30000
#  - 1s - loss: 0.3260 - mse: 0.2999 - mae: 0.3260 - val_loss: 0.4162 - val_mse: 0.4355 - val_mae: 0.4162
# Epoch 67/30000
#  - 1s - loss: 0.3274 - mse: 0.3021 - mae: 0.3274 - val_loss: 0.4139 - val_mse: 0.4373 - val_mae: 0.4139
# Epoch 68/30000
#  - 1s - loss: 0.3151 - mse: 0.2843 - mae: 0.3151 - val_loss: 0.4076 - val_mse: 0.4336 - val_mae: 0.4076
# Epoch 69/30000
#  - 1s - loss: 0.3126 - mse: 0.2830 - mae: 0.3126 - val_loss: 0.4046 - val_mse: 0.4218 - val_mae: 0.4046
# Epoch 70/30000
#  - 1s - loss: 0.3176 - mse: 0.2814 - mae: 0.3176 - val_loss: 0.4123 - val_mse: 0.4226 - val_mae: 0.4123
# Epoch 71/30000
#  - 1s - loss: 0.3163 - mse: 0.2791 - mae: 0.3163 - val_loss: 0.4074 - val_mse: 0.4200 - val_mae: 0.4074
# Epoch 72/30000
#  - 1s - loss: 0.3097 - mse: 0.2724 - mae: 0.3097 - val_loss: 0.4037 - val_mse: 0.4183 - val_mae: 0.4037
# Epoch 73/30000
#  - 1s - loss: 0.3129 - mse: 0.2774 - mae: 0.3129 - val_loss: 0.4004 - val_mse: 0.4183 - val_mae: 0.4004
# Epoch 74/30000
#  - 1s - loss: 0.3101 - mse: 0.2687 - mae: 0.3101 - val_loss: 0.4039 - val_mse: 0.4172 - val_mae: 0.4039
# Epoch 75/30000
#  - 1s - loss: 0.3043 - mse: 0.2634 - mae: 0.3043 - val_loss: 0.4069 - val_mse: 0.4276 - val_mae: 0.4069
# Epoch 76/30000
#  - 1s - loss: 0.3042 - mse: 0.2637 - mae: 0.3042 - val_loss: 0.3971 - val_mse: 0.4141 - val_mae: 0.3971
# Epoch 77/30000
#  - 1s - loss: 0.3001 - mse: 0.2584 - mae: 0.3001 - val_loss: 0.3948 - val_mse: 0.4046 - val_mae: 0.3948
# Epoch 78/30000
#  - 1s - loss: 0.2945 - mse: 0.2526 - mae: 0.2945 - val_loss: 0.3961 - val_mse: 0.4049 - val_mae: 0.3961
# Epoch 79/30000
#  - 1s - loss: 0.2915 - mse: 0.2477 - mae: 0.2915 - val_loss: 0.3917 - val_mse: 0.4041 - val_mae: 0.3917
# Epoch 80/30000
#  - 1s - loss: 0.2948 - mse: 0.2495 - mae: 0.2948 - val_loss: 0.3957 - val_mse: 0.4066 - val_mae: 0.3957
# Epoch 81/30000
#  - 1s - loss: 0.2894 - mse: 0.2431 - mae: 0.2894 - val_loss: 0.3928 - val_mse: 0.3998 - val_mae: 0.3928
# Epoch 82/30000
#  - 1s - loss: 0.2880 - mse: 0.2395 - mae: 0.2880 - val_loss: 0.3937 - val_mse: 0.4078 - val_mae: 0.3937
# Epoch 83/30000
#  - 1s - loss: 0.2859 - mse: 0.2366 - mae: 0.2859 - val_loss: 0.3833 - val_mse: 0.3890 - val_mae: 0.3833
# Epoch 84/30000
#  - 1s - loss: 0.2866 - mse: 0.2373 - mae: 0.2866 - val_loss: 0.3857 - val_mse: 0.3895 - val_mae: 0.3857
# Epoch 85/30000
#  - 1s - loss: 0.2821 - mse: 0.2304 - mae: 0.2821 - val_loss: 0.3896 - val_mse: 0.3934 - val_mae: 0.3896
# Epoch 86/30000
#  - 1s - loss: 0.2847 - mse: 0.2313 - mae: 0.2847 - val_loss: 0.3957 - val_mse: 0.4049 - val_mae: 0.3957
# Epoch 87/30000
#  - 1s - loss: 0.2804 - mse: 0.2302 - mae: 0.2804 - val_loss: 0.3936 - val_mse: 0.4008 - val_mae: 0.3936
# Epoch 88/30000
#  - 1s - loss: 0.2810 - mse: 0.2291 - mae: 0.2810 - val_loss: 0.3850 - val_mse: 0.3841 - val_mae: 0.3850
# Epoch 89/30000
#  - 1s - loss: 0.2805 - mse: 0.2260 - mae: 0.2805 - val_loss: 0.3784 - val_mse: 0.3806 - val_mae: 0.3784
# Epoch 90/30000
#  - 1s - loss: 0.2755 - mse: 0.2230 - mae: 0.2755 - val_loss: 0.3860 - val_mse: 0.3833 - val_mae: 0.3860
# Epoch 91/30000
#  - 1s - loss: 0.2761 - mse: 0.2205 - mae: 0.2761 - val_loss: 0.3823 - val_mse: 0.3801 - val_mae: 0.3823
# Epoch 92/30000
#  - 1s - loss: 0.2747 - mse: 0.2204 - mae: 0.2747 - val_loss: 0.3804 - val_mse: 0.3895 - val_mae: 0.3804
# Epoch 93/30000
#  - 1s - loss: 0.2677 - mse: 0.2107 - mae: 0.2677 - val_loss: 0.3865 - val_mse: 0.3943 - val_mae: 0.3865
# Epoch 94/30000
#  - 1s - loss: 0.2725 - mse: 0.2154 - mae: 0.2725 - val_loss: 0.3835 - val_mse: 0.3822 - val_mae: 0.3835
# Epoch 95/30000
#  - 1s - loss: 0.2707 - mse: 0.2124 - mae: 0.2707 - val_loss: 0.3839 - val_mse: 0.3884 - val_mae: 0.3839
# Epoch 96/30000
#  - 1s - loss: 0.2710 - mse: 0.2120 - mae: 0.2710 - val_loss: 0.3843 - val_mse: 0.3880 - val_mae: 0.3843
# Epoch 97/30000
#  - 1s - loss: 0.2658 - mse: 0.2065 - mae: 0.2658 - val_loss: 0.3684 - val_mse: 0.3665 - val_mae: 0.3684
# Epoch 98/30000
#  - 1s - loss: 0.2602 - mse: 0.2016 - mae: 0.2602 - val_loss: 0.3734 - val_mse: 0.3729 - val_mae: 0.3734
# Epoch 99/30000
#  - 1s - loss: 0.2623 - mse: 0.2026 - mae: 0.2623 - val_loss: 0.3770 - val_mse: 0.3790 - val_mae: 0.3770
# Epoch 100/30000
#  - 1s - loss: 0.2643 - mse: 0.2027 - mae: 0.2643 - val_loss: 0.3756 - val_mse: 0.3734 - val_mae: 0.3756
# Epoch 101/30000
#  - 1s - loss: 0.2585 - mse: 0.1952 - mae: 0.2585 - val_loss: 0.3708 - val_mse: 0.3611 - val_mae: 0.3708
# Epoch 102/30000
#  - 1s - loss: 0.2557 - mse: 0.1939 - mae: 0.2557 - val_loss: 0.3729 - val_mse: 0.3683 - val_mae: 0.3729
# Epoch 103/30000
#  - 1s - loss: 0.2593 - mse: 0.1956 - mae: 0.2593 - val_loss: 0.3774 - val_mse: 0.3743 - val_mae: 0.3774
# Epoch 104/30000
#  - 1s - loss: 0.2591 - mse: 0.1938 - mae: 0.2591 - val_loss: 0.3742 - val_mse: 0.3646 - val_mae: 0.3742
# Epoch 105/30000
#  - 1s - loss: 0.2613 - mse: 0.1966 - mae: 0.2613 - val_loss: 0.3731 - val_mse: 0.3659 - val_mae: 0.3731
# Epoch 106/30000
#  - 1s - loss: 0.2556 - mse: 0.1907 - mae: 0.2556 - val_loss: 0.3715 - val_mse: 0.3647 - val_mae: 0.3715
# Epoch 107/30000
#  - 1s - loss: 0.2502 - mse: 0.1850 - mae: 0.2502 - val_loss: 0.3675 - val_mse: 0.3622 - val_mae: 0.3675
# Epoch 108/30000
#  - 1s - loss: 0.2538 - mse: 0.1855 - mae: 0.2538 - val_loss: 0.3718 - val_mse: 0.3689 - val_mae: 0.3718
# Epoch 109/30000
#  - 1s - loss: 0.2504 - mse: 0.1833 - mae: 0.2504 - val_loss: 0.3669 - val_mse: 0.3572 - val_mae: 0.3669
# Epoch 110/30000
#  - 1s - loss: 0.2493 - mse: 0.1822 - mae: 0.2493 - val_loss: 0.3672 - val_mse: 0.3587 - val_mae: 0.3672
# Epoch 111/30000
#  - 1s - loss: 0.2489 - mse: 0.1822 - mae: 0.2489 - val_loss: 0.3706 - val_mse: 0.3629 - val_mae: 0.3706
# Epoch 112/30000
#  - 1s - loss: 0.2523 - mse: 0.1878 - mae: 0.2523 - val_loss: 0.3659 - val_mse: 0.3576 - val_mae: 0.3659
# Epoch 113/30000
#  - 1s - loss: 0.2450 - mse: 0.1786 - mae: 0.2450 - val_loss: 0.3678 - val_mse: 0.3612 - val_mae: 0.3678
# Epoch 114/30000
#  - 1s - loss: 0.2447 - mse: 0.1779 - mae: 0.2447 - val_loss: 0.3666 - val_mse: 0.3618 - val_mae: 0.3666
# Epoch 115/30000
#  - 1s - loss: 0.2461 - mse: 0.1768 - mae: 0.2461 - val_loss: 0.3692 - val_mse: 0.3666 - val_mae: 0.3692
# Epoch 116/30000
#  - 1s - loss: 0.2405 - mse: 0.1713 - mae: 0.2405 - val_loss: 0.3632 - val_mse: 0.3609 - val_mae: 0.3632
# Epoch 117/30000
#  - 1s - loss: 0.2488 - mse: 0.1795 - mae: 0.2488 - val_loss: 0.3653 - val_mse: 0.3564 - val_mae: 0.3653
# Epoch 118/30000
#  - 1s - loss: 0.2432 - mse: 0.1752 - mae: 0.2432 - val_loss: 0.3560 - val_mse: 0.3447 - val_mae: 0.3560
# Epoch 119/30000
#  - 1s - loss: 0.2399 - mse: 0.1712 - mae: 0.2399 - val_loss: 0.3593 - val_mse: 0.3495 - val_mae: 0.3593
# Epoch 120/30000
#  - 1s - loss: 0.2423 - mse: 0.1736 - mae: 0.2423 - val_loss: 0.3689 - val_mse: 0.3576 - val_mae: 0.3689
# Epoch 121/30000
#  - 1s - loss: 0.2425 - mse: 0.1724 - mae: 0.2425 - val_loss: 0.3580 - val_mse: 0.3522 - val_mae: 0.3580
# Epoch 122/30000
#  - 1s - loss: 0.2365 - mse: 0.1670 - mae: 0.2365 - val_loss: 0.3573 - val_mse: 0.3453 - val_mae: 0.3573
# Epoch 123/30000
#  - 1s - loss: 0.2336 - mse: 0.1620 - mae: 0.2336 - val_loss: 0.3612 - val_mse: 0.3541 - val_mae: 0.3612
# Epoch 124/30000
#  - 1s - loss: 0.2362 - mse: 0.1655 - mae: 0.2362 - val_loss: 0.3695 - val_mse: 0.3574 - val_mae: 0.3695
# Epoch 125/30000
#  - 1s - loss: 0.2402 - mse: 0.1698 - mae: 0.2402 - val_loss: 0.3631 - val_mse: 0.3530 - val_mae: 0.3631
# Epoch 126/30000
#  - 1s - loss: 0.2370 - mse: 0.1651 - mae: 0.2370 - val_loss: 0.3574 - val_mse: 0.3454 - val_mae: 0.3574
# Epoch 127/30000
#  - 1s - loss: 0.2323 - mse: 0.1610 - mae: 0.2323 - val_loss: 0.3595 - val_mse: 0.3378 - val_mae: 0.3595
# Epoch 128/30000
#  - 1s - loss: 0.2347 - mse: 0.1631 - mae: 0.2347 - val_loss: 0.3629 - val_mse: 0.3500 - val_mae: 0.3629
# Epoch 129/30000
#  - 1s - loss: 0.2350 - mse: 0.1611 - mae: 0.2350 - val_loss: 0.3543 - val_mse: 0.3425 - val_mae: 0.3543
# Epoch 130/30000
#  - 1s - loss: 0.2287 - mse: 0.1558 - mae: 0.2287 - val_loss: 0.3612 - val_mse: 0.3448 - val_mae: 0.3612
# Epoch 131/30000
#  - 1s - loss: 0.2318 - mse: 0.1585 - mae: 0.2318 - val_loss: 0.3588 - val_mse: 0.3446 - val_mae: 0.3588
# Epoch 132/30000
#  - 1s - loss: 0.2337 - mse: 0.1608 - mae: 0.2337 - val_loss: 0.3543 - val_mse: 0.3366 - val_mae: 0.3543
# Epoch 133/30000
#  - 1s - loss: 0.2322 - mse: 0.1584 - mae: 0.2322 - val_loss: 0.3574 - val_mse: 0.3480 - val_mae: 0.3574
# Epoch 134/30000
#  - 1s - loss: 0.2339 - mse: 0.1598 - mae: 0.2339 - val_loss: 0.3535 - val_mse: 0.3381 - val_mae: 0.3535
# Epoch 135/30000
#  - 1s - loss: 0.2269 - mse: 0.1564 - mae: 0.2269 - val_loss: 0.3595 - val_mse: 0.3500 - val_mae: 0.3595
# Epoch 136/30000
#  - 1s - loss: 0.2293 - mse: 0.1571 - mae: 0.2293 - val_loss: 0.3586 - val_mse: 0.3423 - val_mae: 0.3586
# Epoch 137/30000
#  - 1s - loss: 0.2283 - mse: 0.1537 - mae: 0.2283 - val_loss: 0.3546 - val_mse: 0.3434 - val_mae: 0.3546
# Epoch 138/30000
#  - 1s - loss: 0.2262 - mse: 0.1524 - mae: 0.2262 - val_loss: 0.3563 - val_mse: 0.3410 - val_mae: 0.3563
# Epoch 139/30000
#  - 1s - loss: 0.2258 - mse: 0.1521 - mae: 0.2258 - val_loss: 0.3563 - val_mse: 0.3428 - val_mae: 0.3563
# Epoch 140/30000
#  - 1s - loss: 0.2275 - mse: 0.1528 - mae: 0.2275 - val_loss: 0.3548 - val_mse: 0.3435 - val_mae: 0.3548
# Epoch 141/30000
#  - 1s - loss: 0.2297 - mse: 0.1575 - mae: 0.2297 - val_loss: 0.3506 - val_mse: 0.3349 - val_mae: 0.3506
# Epoch 142/30000
#  - 1s - loss: 0.2230 - mse: 0.1487 - mae: 0.2230 - val_loss: 0.3527 - val_mse: 0.3374 - val_mae: 0.3527
# Epoch 143/30000
#  - 1s - loss: 0.2210 - mse: 0.1467 - mae: 0.2210 - val_loss: 0.3509 - val_mse: 0.3360 - val_mae: 0.3509
# Epoch 144/30000
#  - 1s - loss: 0.2218 - mse: 0.1467 - mae: 0.2218 - val_loss: 0.3547 - val_mse: 0.3431 - val_mae: 0.3547
# Epoch 145/30000
#  - 1s - loss: 0.2236 - mse: 0.1516 - mae: 0.2236 - val_loss: 0.3514 - val_mse: 0.3342 - val_mae: 0.3514
# Epoch 146/30000
#  - 1s - loss: 0.2208 - mse: 0.1457 - mae: 0.2208 - val_loss: 0.3538 - val_mse: 0.3388 - val_mae: 0.3538
# Epoch 147/30000
#  - 1s - loss: 0.2224 - mse: 0.1479 - mae: 0.2224 - val_loss: 0.3592 - val_mse: 0.3416 - val_mae: 0.3592
# Epoch 148/30000
#  - 1s - loss: 0.2253 - mse: 0.1491 - mae: 0.2253 - val_loss: 0.3454 - val_mse: 0.3260 - val_mae: 0.3454
# Epoch 149/30000
#  - 1s - loss: 0.2193 - mse: 0.1451 - mae: 0.2193 - val_loss: 0.3511 - val_mse: 0.3360 - val_mae: 0.3511
# Epoch 150/30000
#  - 1s - loss: 0.2173 - mse: 0.1438 - mae: 0.2173 - val_loss: 0.3462 - val_mse: 0.3355 - val_mae: 0.3462
# Epoch 151/30000
#  - 1s - loss: 0.2224 - mse: 0.1464 - mae: 0.2224 - val_loss: 0.3569 - val_mse: 0.3431 - val_mae: 0.3569
# Epoch 152/30000
#  - 1s - loss: 0.2234 - mse: 0.1473 - mae: 0.2234 - val_loss: 0.3552 - val_mse: 0.3425 - val_mae: 0.3552
# Epoch 153/30000
#  - 1s - loss: 0.2189 - mse: 0.1444 - mae: 0.2189 - val_loss: 0.3487 - val_mse: 0.3319 - val_mae: 0.3487
# Epoch 154/30000
#  - 1s - loss: 0.2177 - mse: 0.1422 - mae: 0.2177 - val_loss: 0.3476 - val_mse: 0.3332 - val_mae: 0.3476
# Epoch 155/30000
#  - 1s - loss: 0.2154 - mse: 0.1392 - mae: 0.2154 - val_loss: 0.3439 - val_mse: 0.3296 - val_mae: 0.3439
# Epoch 156/30000
#  - 1s - loss: 0.2191 - mse: 0.1429 - mae: 0.2191 - val_loss: 0.3471 - val_mse: 0.3272 - val_mae: 0.3471
# Epoch 157/30000
#  - 1s - loss: 0.2179 - mse: 0.1435 - mae: 0.2179 - val_loss: 0.3492 - val_mse: 0.3380 - val_mae: 0.3492
# Epoch 158/30000
#  - 1s - loss: 0.2147 - mse: 0.1381 - mae: 0.2147 - val_loss: 0.3479 - val_mse: 0.3289 - val_mae: 0.3479
# Epoch 159/30000
#  - 1s - loss: 0.2153 - mse: 0.1413 - mae: 0.2153 - val_loss: 0.3476 - val_mse: 0.3264 - val_mae: 0.3476
# Epoch 160/30000
#  - 1s - loss: 0.2165 - mse: 0.1390 - mae: 0.2165 - val_loss: 0.3451 - val_mse: 0.3264 - val_mae: 0.3451
# Epoch 161/30000
#  - 1s - loss: 0.2180 - mse: 0.1412 - mae: 0.2180 - val_loss: 0.3464 - val_mse: 0.3292 - val_mae: 0.3464
# Epoch 162/30000
#  - 1s - loss: 0.2145 - mse: 0.1360 - mae: 0.2145 - val_loss: 0.3483 - val_mse: 0.3307 - val_mae: 0.3483
# Epoch 163/30000
#  - 1s - loss: 0.2142 - mse: 0.1383 - mae: 0.2142 - val_loss: 0.3458 - val_mse: 0.3301 - val_mae: 0.3458
# Epoch 164/30000
#  - 1s - loss: 0.2132 - mse: 0.1368 - mae: 0.2132 - val_loss: 0.3462 - val_mse: 0.3273 - val_mae: 0.3462
# Epoch 165/30000
#  - 1s - loss: 0.2122 - mse: 0.1365 - mae: 0.2122 - val_loss: 0.3453 - val_mse: 0.3295 - val_mae: 0.3453
# Epoch 166/30000
#  - 1s - loss: 0.2102 - mse: 0.1339 - mae: 0.2102 - val_loss: 0.3455 - val_mse: 0.3254 - val_mae: 0.3455
# Epoch 167/30000
#  - 1s - loss: 0.2149 - mse: 0.1381 - mae: 0.2149 - val_loss: 0.3574 - val_mse: 0.3439 - val_mae: 0.3574
# Epoch 168/30000
#  - 1s - loss: 0.2120 - mse: 0.1356 - mae: 0.2120 - val_loss: 0.3439 - val_mse: 0.3280 - val_mae: 0.3439
# Epoch 169/30000
#  - 1s - loss: 0.2141 - mse: 0.1372 - mae: 0.2141 - val_loss: 0.3459 - val_mse: 0.3221 - val_mae: 0.3459
# Epoch 170/30000
#  - 1s - loss: 0.2100 - mse: 0.1345 - mae: 0.2100 - val_loss: 0.3482 - val_mse: 0.3348 - val_mae: 0.3482
# Epoch 171/30000
#  - 1s - loss: 0.2108 - mse: 0.1331 - mae: 0.2108 - val_loss: 0.3408 - val_mse: 0.3171 - val_mae: 0.3408
# Epoch 172/30000
#  - 1s - loss: 0.2107 - mse: 0.1333 - mae: 0.2107 - val_loss: 0.3452 - val_mse: 0.3281 - val_mae: 0.3452
# Epoch 173/30000
#  - 1s - loss: 0.2129 - mse: 0.1354 - mae: 0.2129 - val_loss: 0.3474 - val_mse: 0.3307 - val_mae: 0.3474
# Epoch 174/30000
#  - 1s - loss: 0.2113 - mse: 0.1340 - mae: 0.2113 - val_loss: 0.3446 - val_mse: 0.3264 - val_mae: 0.3446
# Epoch 175/30000
#  - 1s - loss: 0.2076 - mse: 0.1326 - mae: 0.2076 - val_loss: 0.3442 - val_mse: 0.3269 - val_mae: 0.3442
# Epoch 176/30000
#  - 1s - loss: 0.2123 - mse: 0.1349 - mae: 0.2123 - val_loss: 0.3380 - val_mse: 0.3172 - val_mae: 0.3380
# Epoch 177/30000
#  - 1s - loss: 0.2088 - mse: 0.1313 - mae: 0.2088 - val_loss: 0.3421 - val_mse: 0.3198 - val_mae: 0.3421
# Epoch 178/30000
#  - 1s - loss: 0.2083 - mse: 0.1294 - mae: 0.2083 - val_loss: 0.3474 - val_mse: 0.3315 - val_mae: 0.3474
# Epoch 179/30000
#  - 1s - loss: 0.2111 - mse: 0.1338 - mae: 0.2111 - val_loss: 0.3487 - val_mse: 0.3340 - val_mae: 0.3487
# Epoch 180/30000
#  - 1s - loss: 0.2077 - mse: 0.1292 - mae: 0.2077 - val_loss: 0.3415 - val_mse: 0.3207 - val_mae: 0.3415
# Epoch 181/30000
#  - 1s - loss: 0.2061 - mse: 0.1290 - mae: 0.2061 - val_loss: 0.3487 - val_mse: 0.3296 - val_mae: 0.3487
# Epoch 182/30000
#  - 1s - loss: 0.2035 - mse: 0.1248 - mae: 0.2035 - val_loss: 0.3454 - val_mse: 0.3240 - val_mae: 0.3454
# Epoch 183/30000
#  - 1s - loss: 0.2079 - mse: 0.1305 - mae: 0.2079 - val_loss: 0.3406 - val_mse: 0.3228 - val_mae: 0.3406
# Epoch 184/30000
#  - 1s - loss: 0.2060 - mse: 0.1289 - mae: 0.2060 - val_loss: 0.3363 - val_mse: 0.3203 - val_mae: 0.3363
# Epoch 185/30000
#  - 1s - loss: 0.2036 - mse: 0.1271 - mae: 0.2036 - val_loss: 0.3424 - val_mse: 0.3233 - val_mae: 0.3424
# Epoch 186/30000
#  - 1s - loss: 0.2085 - mse: 0.1320 - mae: 0.2085 - val_loss: 0.3422 - val_mse: 0.3246 - val_mae: 0.3422
# Epoch 187/30000
#  - 1s - loss: 0.2054 - mse: 0.1264 - mae: 0.2054 - val_loss: 0.3409 - val_mse: 0.3218 - val_mae: 0.3409
# Epoch 188/30000
#  - 1s - loss: 0.2016 - mse: 0.1244 - mae: 0.2016 - val_loss: 0.3457 - val_mse: 0.3284 - val_mae: 0.3457
# Epoch 189/30000
#  - 1s - loss: 0.2065 - mse: 0.1285 - mae: 0.2065 - val_loss: 0.3474 - val_mse: 0.3327 - val_mae: 0.3474
# Epoch 190/30000
#  - 1s - loss: 0.2065 - mse: 0.1282 - mae: 0.2065 - val_loss: 0.3454 - val_mse: 0.3286 - val_mae: 0.3454
# Epoch 191/30000
#  - 1s - loss: 0.2029 - mse: 0.1250 - mae: 0.2029 - val_loss: 0.3401 - val_mse: 0.3205 - val_mae: 0.3401
# Epoch 192/30000
#  - 1s - loss: 0.2046 - mse: 0.1260 - mae: 0.2046 - val_loss: 0.3415 - val_mse: 0.3252 - val_mae: 0.3415
# Epoch 193/30000
#  - 1s - loss: 0.2039 - mse: 0.1273 - mae: 0.2039 - val_loss: 0.3358 - val_mse: 0.3156 - val_mae: 0.3358
# Epoch 194/30000
#  - 1s - loss: 0.2043 - mse: 0.1277 - mae: 0.2043 - val_loss: 0.3419 - val_mse: 0.3263 - val_mae: 0.3419
# Epoch 195/30000
#  - 1s - loss: 0.2013 - mse: 0.1254 - mae: 0.2013 - val_loss: 0.3423 - val_mse: 0.3192 - val_mae: 0.3423
# Epoch 196/30000
#  - 1s - loss: 0.2003 - mse: 0.1215 - mae: 0.2003 - val_loss: 0.3474 - val_mse: 0.3350 - val_mae: 0.3474
# Epoch 197/30000
#  - 1s - loss: 0.2005 - mse: 0.1230 - mae: 0.2005 - val_loss: 0.3457 - val_mse: 0.3277 - val_mae: 0.3457
# Epoch 198/30000
#  - 1s - loss: 0.2011 - mse: 0.1228 - mae: 0.2011 - val_loss: 0.3364 - val_mse: 0.3187 - val_mae: 0.3364
# Epoch 199/30000
#  - 1s - loss: 0.2036 - mse: 0.1254 - mae: 0.2036 - val_loss: 0.3390 - val_mse: 0.3164 - val_mae: 0.3390
# Epoch 200/30000
#  - 1s - loss: 0.1991 - mse: 0.1220 - mae: 0.1991 - val_loss: 0.3434 - val_mse: 0.3255 - val_mae: 0.3434
# Epoch 201/30000
#  - 1s - loss: 0.2036 - mse: 0.1253 - mae: 0.2036 - val_loss: 0.3451 - val_mse: 0.3335 - val_mae: 0.3451
# Epoch 202/30000
#  - 1s - loss: 0.2029 - mse: 0.1239 - mae: 0.2029 - val_loss: 0.3470 - val_mse: 0.3286 - val_mae: 0.3470
# Epoch 203/30000
#  - 1s - loss: 0.1990 - mse: 0.1197 - mae: 0.1990 - val_loss: 0.3458 - val_mse: 0.3264 - val_mae: 0.3458
# Epoch 204/30000
#  - 1s - loss: 0.2031 - mse: 0.1253 - mae: 0.2031 - val_loss: 0.3422 - val_mse: 0.3220 - val_mae: 0.3422
# Epoch 205/30000
#  - 1s - loss: 0.1993 - mse: 0.1205 - mae: 0.1993 - val_loss: 0.3416 - val_mse: 0.3245 - val_mae: 0.3416
# Epoch 206/30000
#  - 1s - loss: 0.2010 - mse: 0.1213 - mae: 0.2010 - val_loss: 0.3436 - val_mse: 0.3200 - val_mae: 0.3436
# Epoch 207/30000
#  - 1s - loss: 0.2003 - mse: 0.1228 - mae: 0.2003 - val_loss: 0.3407 - val_mse: 0.3190 - val_mae: 0.3407
# Epoch 208/30000
#  - 1s - loss: 0.1985 - mse: 0.1202 - mae: 0.1985 - val_loss: 0.3407 - val_mse: 0.3172 - val_mae: 0.3407
# Epoch 209/30000
#  - 1s - loss: 0.1908 - mse: 0.1134 - mae: 0.1908 - val_loss: 0.3373 - val_mse: 0.3203 - val_mae: 0.3373
# Epoch 210/30000
#  - 1s - loss: 0.1958 - mse: 0.1179 - mae: 0.1958 - val_loss: 0.3540 - val_mse: 0.3448 - val_mae: 0.3540
# Epoch 211/30000
#  - 1s - loss: 0.1958 - mse: 0.1172 - mae: 0.1958 - val_loss: 0.3361 - val_mse: 0.3083 - val_mae: 0.3361
# Epoch 212/30000
#  - 1s - loss: 0.1957 - mse: 0.1176 - mae: 0.1957 - val_loss: 0.3372 - val_mse: 0.3149 - val_mae: 0.3372
# Epoch 213/30000
#  - 1s - loss: 0.1961 - mse: 0.1196 - mae: 0.1961 - val_loss: 0.3385 - val_mse: 0.3161 - val_mae: 0.3385
# Epoch 214/30000
#  - 1s - loss: 0.1942 - mse: 0.1169 - mae: 0.1942 - val_loss: 0.3439 - val_mse: 0.3294 - val_mae: 0.3439
# Epoch 215/30000
#  - 1s - loss: 0.1940 - mse: 0.1165 - mae: 0.1940 - val_loss: 0.3382 - val_mse: 0.3202 - val_mae: 0.3382
# Epoch 216/30000
#  - 1s - loss: 0.1941 - mse: 0.1169 - mae: 0.1941 - val_loss: 0.3452 - val_mse: 0.3271 - val_mae: 0.3452
# Epoch 217/30000
#  - 1s - loss: 0.1925 - mse: 0.1153 - mae: 0.1925 - val_loss: 0.3396 - val_mse: 0.3204 - val_mae: 0.3396
# Epoch 218/30000
#  - 1s - loss: 0.1920 - mse: 0.1156 - mae: 0.1920 - val_loss: 0.3406 - val_mse: 0.3264 - val_mae: 0.3406
# Epoch 219/30000
#  - 1s - loss: 0.1971 - mse: 0.1184 - mae: 0.1971 - val_loss: 0.3457 - val_mse: 0.3226 - val_mae: 0.3457
# Epoch 220/30000
#  - 1s - loss: 0.1947 - mse: 0.1163 - mae: 0.1947 - val_loss: 0.3369 - val_mse: 0.3243 - val_mae: 0.3369
# Epoch 221/30000
#  - 1s - loss: 0.1927 - mse: 0.1164 - mae: 0.1927 - val_loss: 0.3394 - val_mse: 0.3239 - val_mae: 0.3394
# Epoch 222/30000
#  - 1s - loss: 0.1927 - mse: 0.1157 - mae: 0.1927 - val_loss: 0.3431 - val_mse: 0.3274 - val_mae: 0.3431
# Epoch 223/30000
#  - 1s - loss: 0.1906 - mse: 0.1127 - mae: 0.1906 - val_loss: 0.3365 - val_mse: 0.3179 - val_mae: 0.3365
# Epoch 224/30000
#  - 1s - loss: 0.1901 - mse: 0.1117 - mae: 0.1901 - val_loss: 0.3337 - val_mse: 0.3207 - val_mae: 0.3337
# Epoch 225/30000
#  - 1s - loss: 0.1940 - mse: 0.1153 - mae: 0.1940 - val_loss: 0.3351 - val_mse: 0.3185 - val_mae: 0.3351
# Epoch 226/30000
#  - 1s - loss: 0.1906 - mse: 0.1133 - mae: 0.1906 - val_loss: 0.3369 - val_mse: 0.3200 - val_mae: 0.3369
# Epoch 227/30000
#  - 1s - loss: 0.1927 - mse: 0.1140 - mae: 0.1927 - val_loss: 0.3381 - val_mse: 0.3226 - val_mae: 0.3381
# Epoch 228/30000
#  - 1s - loss: 0.1919 - mse: 0.1138 - mae: 0.1919 - val_loss: 0.3414 - val_mse: 0.3276 - val_mae: 0.3414
# Epoch 229/30000
#  - 1s - loss: 0.1912 - mse: 0.1136 - mae: 0.1912 - val_loss: 0.3381 - val_mse: 0.3245 - val_mae: 0.3381
# Epoch 230/30000
#  - 1s - loss: 0.1915 - mse: 0.1146 - mae: 0.1915 - val_loss: 0.3367 - val_mse: 0.3193 - val_mae: 0.3367
# Epoch 231/30000
#  - 1s - loss: 0.1943 - mse: 0.1146 - mae: 0.1943 - val_loss: 0.3454 - val_mse: 0.3272 - val_mae: 0.3454
# Epoch 232/30000
#  - 1s - loss: 0.1921 - mse: 0.1139 - mae: 0.1921 - val_loss: 0.3401 - val_mse: 0.3246 - val_mae: 0.3401
# Epoch 233/30000
#  - 1s - loss: 0.1907 - mse: 0.1124 - mae: 0.1907 - val_loss: 0.3336 - val_mse: 0.3075 - val_mae: 0.3336
# Epoch 234/30000
#  - 1s - loss: 0.1884 - mse: 0.1097 - mae: 0.1884 - val_loss: 0.3353 - val_mse: 0.3177 - val_mae: 0.3353
# Epoch 235/30000
#  - 1s - loss: 0.1872 - mse: 0.1094 - mae: 0.1872 - val_loss: 0.3316 - val_mse: 0.3127 - val_mae: 0.3316
# Epoch 236/30000
#  - 1s - loss: 0.1892 - mse: 0.1112 - mae: 0.1892 - val_loss: 0.3418 - val_mse: 0.3227 - val_mae: 0.3418
# Epoch 237/30000
#  - 1s - loss: 0.1936 - mse: 0.1145 - mae: 0.1936 - val_loss: 0.3367 - val_mse: 0.3131 - val_mae: 0.3367
# Epoch 238/30000
#  - 1s - loss: 0.1916 - mse: 0.1135 - mae: 0.1916 - val_loss: 0.3368 - val_mse: 0.3165 - val_mae: 0.3368
# Epoch 239/30000
#  - 1s - loss: 0.1954 - mse: 0.1170 - mae: 0.1954 - val_loss: 0.3406 - val_mse: 0.3243 - val_mae: 0.3406
# Epoch 240/30000
#  - 1s - loss: 0.1912 - mse: 0.1126 - mae: 0.1912 - val_loss: 0.3477 - val_mse: 0.3337 - val_mae: 0.3477
# Epoch 241/30000
#  - 1s - loss: 0.1890 - mse: 0.1104 - mae: 0.1890 - val_loss: 0.3350 - val_mse: 0.3164 - val_mae: 0.3350
# Epoch 242/30000
#  - 1s - loss: 0.1902 - mse: 0.1117 - mae: 0.1902 - val_loss: 0.3399 - val_mse: 0.3192 - val_mae: 0.3399
# Epoch 243/30000
#  - 1s - loss: 0.1913 - mse: 0.1131 - mae: 0.1913 - val_loss: 0.3313 - val_mse: 0.3086 - val_mae: 0.3313
# Epoch 244/30000
#  - 1s - loss: 0.1843 - mse: 0.1061 - mae: 0.1843 - val_loss: 0.3351 - val_mse: 0.3149 - val_mae: 0.3351
# Epoch 245/30000
#  - 1s - loss: 0.1866 - mse: 0.1081 - mae: 0.1866 - val_loss: 0.3343 - val_mse: 0.3138 - val_mae: 0.3343
# Epoch 246/30000
#  - 1s - loss: 0.1924 - mse: 0.1130 - mae: 0.1924 - val_loss: 0.3356 - val_mse: 0.3155 - val_mae: 0.3356
# Epoch 247/30000
#  - 1s - loss: 0.1889 - mse: 0.1102 - mae: 0.1889 - val_loss: 0.3344 - val_mse: 0.3164 - val_mae: 0.3344
# Epoch 248/30000
#  - 1s - loss: 0.1888 - mse: 0.1098 - mae: 0.1888 - val_loss: 0.3395 - val_mse: 0.3167 - val_mae: 0.3395
# Epoch 249/30000
#  - 1s - loss: 0.1874 - mse: 0.1112 - mae: 0.1874 - val_loss: 0.3326 - val_mse: 0.3133 - val_mae: 0.3326
# Epoch 250/30000
#  - 1s - loss: 0.1854 - mse: 0.1083 - mae: 0.1854 - val_loss: 0.3377 - val_mse: 0.3207 - val_mae: 0.3377
# Epoch 251/30000
#  - 1s - loss: 0.1933 - mse: 0.1141 - mae: 0.1933 - val_loss: 0.3288 - val_mse: 0.3103 - val_mae: 0.3288
# Epoch 252/30000
#  - 1s - loss: 0.1868 - mse: 0.1097 - mae: 0.1868 - val_loss: 0.3350 - val_mse: 0.3144 - val_mae: 0.3350
# Epoch 253/30000
#  - 1s - loss: 0.1825 - mse: 0.1060 - mae: 0.1825 - val_loss: 0.3305 - val_mse: 0.3147 - val_mae: 0.3305
# Epoch 254/30000
#  - 1s - loss: 0.1894 - mse: 0.1110 - mae: 0.1894 - val_loss: 0.3368 - val_mse: 0.3202 - val_mae: 0.3368
# Epoch 255/30000
#  - 1s - loss: 0.1881 - mse: 0.1092 - mae: 0.1881 - val_loss: 0.3357 - val_mse: 0.3184 - val_mae: 0.3357
# Epoch 256/30000
#  - 1s - loss: 0.1889 - mse: 0.1109 - mae: 0.1889 - val_loss: 0.3393 - val_mse: 0.3191 - val_mae: 0.3393
# Epoch 257/30000
#  - 1s - loss: 0.1861 - mse: 0.1080 - mae: 0.1861 - val_loss: 0.3324 - val_mse: 0.3139 - val_mae: 0.3324
# Epoch 258/30000
#  - 1s - loss: 0.1828 - mse: 0.1063 - mae: 0.1828 - val_loss: 0.3315 - val_mse: 0.3161 - val_mae: 0.3315
# Epoch 259/30000
#  - 1s - loss: 0.1846 - mse: 0.1077 - mae: 0.1846 - val_loss: 0.3388 - val_mse: 0.3217 - val_mae: 0.3388
# Epoch 260/30000
#  - 1s - loss: 0.1876 - mse: 0.1099 - mae: 0.1876 - val_loss: 0.3413 - val_mse: 0.3276 - val_mae: 0.3413
# Epoch 261/30000
#  - 1s - loss: 0.1891 - mse: 0.1093 - mae: 0.1891 - val_loss: 0.3403 - val_mse: 0.3206 - val_mae: 0.3403
# Epoch 262/30000
#  - 1s - loss: 0.1865 - mse: 0.1073 - mae: 0.1865 - val_loss: 0.3369 - val_mse: 0.3197 - val_mae: 0.3369
# Epoch 263/30000
#  - 1s - loss: 0.1870 - mse: 0.1086 - mae: 0.1870 - val_loss: 0.3352 - val_mse: 0.3212 - val_mae: 0.3352
# Epoch 264/30000
#  - 1s - loss: 0.1852 - mse: 0.1061 - mae: 0.1852 - val_loss: 0.3381 - val_mse: 0.3233 - val_mae: 0.3381
# Epoch 265/30000
#  - 1s - loss: 0.1840 - mse: 0.1071 - mae: 0.1840 - val_loss: 0.3351 - val_mse: 0.3154 - val_mae: 0.3351
# Epoch 266/30000
#  - 1s - loss: 0.1841 - mse: 0.1055 - mae: 0.1841 - val_loss: 0.3352 - val_mse: 0.3151 - val_mae: 0.3352
# Epoch 267/30000
#  - 1s - loss: 0.1858 - mse: 0.1063 - mae: 0.1858 - val_loss: 0.3308 - val_mse: 0.3086 - val_mae: 0.3308
# Epoch 268/30000
#  - 1s - loss: 0.1840 - mse: 0.1071 - mae: 0.1840 - val_loss: 0.3317 - val_mse: 0.3097 - val_mae: 0.3317
# Epoch 269/30000
#  - 1s - loss: 0.1834 - mse: 0.1047 - mae: 0.1834 - val_loss: 0.3395 - val_mse: 0.3197 - val_mae: 0.3395
# Epoch 270/30000
#  - 1s - loss: 0.1832 - mse: 0.1053 - mae: 0.1832 - val_loss: 0.3350 - val_mse: 0.3200 - val_mae: 0.3350
# Epoch 271/30000
#  - 1s - loss: 0.1849 - mse: 0.1064 - mae: 0.1849 - val_loss: 0.3317 - val_mse: 0.3128 - val_mae: 0.3317
# Epoch 272/30000
#  - 1s - loss: 0.1826 - mse: 0.1039 - mae: 0.1826 - val_loss: 0.3330 - val_mse: 0.3176 - val_mae: 0.3330
# Epoch 273/30000
#  - 1s - loss: 0.1896 - mse: 0.1102 - mae: 0.1896 - val_loss: 0.3387 - val_mse: 0.3217 - val_mae: 0.3387
# Epoch 274/30000
#  - 1s - loss: 0.1870 - mse: 0.1069 - mae: 0.1870 - val_loss: 0.3322 - val_mse: 0.3178 - val_mae: 0.3322
# Epoch 275/30000
#  - 1s - loss: 0.1826 - mse: 0.1045 - mae: 0.1826 - val_loss: 0.3363 - val_mse: 0.3227 - val_mae: 0.3363
# Epoch 276/30000
#  - 1s - loss: 0.1839 - mse: 0.1053 - mae: 0.1839 - val_loss: 0.3370 - val_mse: 0.3262 - val_mae: 0.3370
# Epoch 277/30000
#  - 1s - loss: 0.1850 - mse: 0.1077 - mae: 0.1850 - val_loss: 0.3287 - val_mse: 0.3140 - val_mae: 0.3287
# Epoch 278/30000
#  - 1s - loss: 0.1854 - mse: 0.1071 - mae: 0.1854 - val_loss: 0.3313 - val_mse: 0.3123 - val_mae: 0.3313
# Epoch 279/30000
#  - 1s - loss: 0.1821 - mse: 0.1021 - mae: 0.1821 - val_loss: 0.3310 - val_mse: 0.3220 - val_mae: 0.3310
# Epoch 280/30000
#  - 1s - loss: 0.1814 - mse: 0.1039 - mae: 0.1814 - val_loss: 0.3371 - val_mse: 0.3232 - val_mae: 0.3371
# Epoch 281/30000
#  - 1s - loss: 0.1838 - mse: 0.1052 - mae: 0.1838 - val_loss: 0.3294 - val_mse: 0.3075 - val_mae: 0.3294
# Epoch 282/30000
#  - 1s - loss: 0.1808 - mse: 0.1027 - mae: 0.1808 - val_loss: 0.3306 - val_mse: 0.3093 - val_mae: 0.3306
# Epoch 283/30000
#  - 1s - loss: 0.1819 - mse: 0.1035 - mae: 0.1819 - val_loss: 0.3334 - val_mse: 0.3167 - val_mae: 0.3334
# Epoch 284/30000
#  - 1s - loss: 0.1848 - mse: 0.1056 - mae: 0.1848 - val_loss: 0.3288 - val_mse: 0.3124 - val_mae: 0.3288
# Epoch 285/30000
#  - 1s - loss: 0.1789 - mse: 0.1017 - mae: 0.1789 - val_loss: 0.3261 - val_mse: 0.3079 - val_mae: 0.3261
# Epoch 286/30000
#  - 1s - loss: 0.1788 - mse: 0.1003 - mae: 0.1788 - val_loss: 0.3345 - val_mse: 0.3160 - val_mae: 0.3345
# Epoch 287/30000
#  - 1s - loss: 0.1802 - mse: 0.1018 - mae: 0.1802 - val_loss: 0.3360 - val_mse: 0.3153 - val_mae: 0.3360
# Epoch 288/30000
#  - 1s - loss: 0.1817 - mse: 0.1028 - mae: 0.1817 - val_loss: 0.3299 - val_mse: 0.3130 - val_mae: 0.3299
# Epoch 289/30000
#  - 1s - loss: 0.1817 - mse: 0.1027 - mae: 0.1817 - val_loss: 0.3347 - val_mse: 0.3161 - val_mae: 0.3347
# Epoch 290/30000
#  - 1s - loss: 0.1811 - mse: 0.1034 - mae: 0.1811 - val_loss: 0.3281 - val_mse: 0.3123 - val_mae: 0.3281
# Epoch 291/30000
#  - 1s - loss: 0.1801 - mse: 0.1017 - mae: 0.1801 - val_loss: 0.3338 - val_mse: 0.3196 - val_mae: 0.3338
# Epoch 292/30000
#  - 1s - loss: 0.1777 - mse: 0.1014 - mae: 0.1777 - val_loss: 0.3316 - val_mse: 0.3143 - val_mae: 0.3316
# Epoch 293/30000
#  - 1s - loss: 0.1831 - mse: 0.1045 - mae: 0.1831 - val_loss: 0.3292 - val_mse: 0.3109 - val_mae: 0.3292
# Epoch 294/30000
#  - 1s - loss: 0.1798 - mse: 0.1014 - mae: 0.1798 - val_loss: 0.3290 - val_mse: 0.3119 - val_mae: 0.3290
# Epoch 295/30000
#  - 1s - loss: 0.1830 - mse: 0.1040 - mae: 0.1830 - val_loss: 0.3315 - val_mse: 0.3174 - val_mae: 0.3315
# Epoch 296/30000
#  - 1s - loss: 0.1793 - mse: 0.1020 - mae: 0.1793 - val_loss: 0.3354 - val_mse: 0.3147 - val_mae: 0.3354
# Epoch 297/30000
#  - 1s - loss: 0.1822 - mse: 0.1032 - mae: 0.1822 - val_loss: 0.3308 - val_mse: 0.3148 - val_mae: 0.3308
# Epoch 298/30000
#  - 1s - loss: 0.1807 - mse: 0.1037 - mae: 0.1807 - val_loss: 0.3286 - val_mse: 0.3081 - val_mae: 0.3286
# Epoch 299/30000
#  - 1s - loss: 0.1818 - mse: 0.1028 - mae: 0.1818 - val_loss: 0.3264 - val_mse: 0.3080 - val_mae: 0.3264
# Epoch 300/30000
#  - 1s - loss: 0.1776 - mse: 0.1003 - mae: 0.1776 - val_loss: 0.3266 - val_mse: 0.3066 - val_mae: 0.3266
# Epoch 301/30000
#  - 1s - loss: 0.1771 - mse: 0.0999 - mae: 0.1771 - val_loss: 0.3321 - val_mse: 0.3110 - val_mae: 0.3321
# Epoch 302/30000
#  - 1s - loss: 0.1762 - mse: 0.0996 - mae: 0.1762 - val_loss: 0.3315 - val_mse: 0.3189 - val_mae: 0.3315
# Epoch 303/30000
#  - 1s - loss: 0.1818 - mse: 0.1035 - mae: 0.1818 - val_loss: 0.3255 - val_mse: 0.3106 - val_mae: 0.3255
# Epoch 304/30000
#  - 1s - loss: 0.1785 - mse: 0.1006 - mae: 0.1785 - val_loss: 0.3340 - val_mse: 0.3166 - val_mae: 0.3340
# Epoch 305/30000
#  - 1s - loss: 0.1783 - mse: 0.1000 - mae: 0.1783 - val_loss: 0.3278 - val_mse: 0.3084 - val_mae: 0.3278
# Epoch 306/30000
#  - 1s - loss: 0.1756 - mse: 0.0972 - mae: 0.1756 - val_loss: 0.3290 - val_mse: 0.3116 - val_mae: 0.3290
# Epoch 307/30000
#  - 1s - loss: 0.1769 - mse: 0.0986 - mae: 0.1769 - val_loss: 0.3322 - val_mse: 0.3138 - val_mae: 0.3322
# Epoch 308/30000
#  - 1s - loss: 0.1766 - mse: 0.0986 - mae: 0.1766 - val_loss: 0.3305 - val_mse: 0.3107 - val_mae: 0.3305
# Epoch 309/30000
#  - 1s - loss: 0.1801 - mse: 0.1007 - mae: 0.1801 - val_loss: 0.3346 - val_mse: 0.3144 - val_mae: 0.3346
# Epoch 310/30000
#  - 1s - loss: 0.1762 - mse: 0.0993 - mae: 0.1762 - val_loss: 0.3344 - val_mse: 0.3165 - val_mae: 0.3344
# Epoch 311/30000
#  - 1s - loss: 0.1761 - mse: 0.0979 - mae: 0.1761 - val_loss: 0.3282 - val_mse: 0.3072 - val_mae: 0.3282
# Epoch 312/30000
#  - 1s - loss: 0.1799 - mse: 0.0996 - mae: 0.1799 - val_loss: 0.3413 - val_mse: 0.3215 - val_mae: 0.3413
# Epoch 313/30000
#  - 1s - loss: 0.1768 - mse: 0.0982 - mae: 0.1768 - val_loss: 0.3305 - val_mse: 0.3056 - val_mae: 0.3305
# Epoch 314/30000
#  - 1s - loss: 0.1768 - mse: 0.1001 - mae: 0.1768 - val_loss: 0.3328 - val_mse: 0.3146 - val_mae: 0.3328
# Epoch 315/30000
#  - 1s - loss: 0.1763 - mse: 0.0989 - mae: 0.1763 - val_loss: 0.3303 - val_mse: 0.3110 - val_mae: 0.3303
# Epoch 316/30000
#  - 1s - loss: 0.1799 - mse: 0.1018 - mae: 0.1799 - val_loss: 0.3282 - val_mse: 0.3141 - val_mae: 0.3282
# Epoch 317/30000
#  - 1s - loss: 0.1753 - mse: 0.0982 - mae: 0.1753 - val_loss: 0.3257 - val_mse: 0.3062 - val_mae: 0.3257
# Epoch 318/30000
#  - 1s - loss: 0.1770 - mse: 0.0996 - mae: 0.1770 - val_loss: 0.3319 - val_mse: 0.3113 - val_mae: 0.3319
# Epoch 319/30000
#  - 1s - loss: 0.1769 - mse: 0.0986 - mae: 0.1769 - val_loss: 0.3277 - val_mse: 0.3112 - val_mae: 0.3277
# Epoch 320/30000
#  - 1s - loss: 0.1748 - mse: 0.0987 - mae: 0.1748 - val_loss: 0.3294 - val_mse: 0.3126 - val_mae: 0.3294
# Epoch 321/30000
#  - 1s - loss: 0.1754 - mse: 0.0969 - mae: 0.1754 - val_loss: 0.3340 - val_mse: 0.3149 - val_mae: 0.3340
# Epoch 322/30000
#  - 1s - loss: 0.1779 - mse: 0.0988 - mae: 0.1779 - val_loss: 0.3298 - val_mse: 0.3078 - val_mae: 0.3298
# Epoch 323/30000
#  - 1s - loss: 0.1783 - mse: 0.0996 - mae: 0.1783 - val_loss: 0.3339 - val_mse: 0.3128 - val_mae: 0.3339
# Epoch 324/30000
#  - 1s - loss: 0.1752 - mse: 0.0963 - mae: 0.1752 - val_loss: 0.3335 - val_mse: 0.3162 - val_mae: 0.3335
# Epoch 325/30000
#  - 1s - loss: 0.1751 - mse: 0.0968 - mae: 0.1751 - val_loss: 0.3255 - val_mse: 0.3016 - val_mae: 0.3255
# Epoch 326/30000
#  - 1s - loss: 0.1761 - mse: 0.0976 - mae: 0.1761 - val_loss: 0.3293 - val_mse: 0.3044 - val_mae: 0.3293
# Epoch 327/30000
#  - 1s - loss: 0.1759 - mse: 0.0972 - mae: 0.1759 - val_loss: 0.3296 - val_mse: 0.3094 - val_mae: 0.3296
# Epoch 328/30000
#  - 1s - loss: 0.1737 - mse: 0.0959 - mae: 0.1737 - val_loss: 0.3325 - val_mse: 0.3132 - val_mae: 0.3325
# Epoch 329/30000
#  - 1s - loss: 0.1760 - mse: 0.0966 - mae: 0.1760 - val_loss: 0.3318 - val_mse: 0.3129 - val_mae: 0.3318
# Epoch 330/30000
#  - 1s - loss: 0.1772 - mse: 0.0984 - mae: 0.1772 - val_loss: 0.3286 - val_mse: 0.3071 - val_mae: 0.3286
# Epoch 331/30000
#  - 1s - loss: 0.1754 - mse: 0.0974 - mae: 0.1754 - val_loss: 0.3316 - val_mse: 0.3154 - val_mae: 0.3316
# Epoch 332/30000
#  - 1s - loss: 0.1756 - mse: 0.0973 - mae: 0.1756 - val_loss: 0.3340 - val_mse: 0.3118 - val_mae: 0.3340
# Epoch 333/30000
#  - 1s - loss: 0.1736 - mse: 0.0956 - mae: 0.1736 - val_loss: 0.3298 - val_mse: 0.3062 - val_mae: 0.3298
# Epoch 334/30000
#  - 1s - loss: 0.1739 - mse: 0.0969 - mae: 0.1739 - val_loss: 0.3324 - val_mse: 0.3152 - val_mae: 0.3324
# Epoch 335/30000
#  - 1s - loss: 0.1759 - mse: 0.0997 - mae: 0.1759 - val_loss: 0.3268 - val_mse: 0.3048 - val_mae: 0.3268
# Epoch 336/30000
#  - 1s - loss: 0.1699 - mse: 0.0927 - mae: 0.1699 - val_loss: 0.3290 - val_mse: 0.3105 - val_mae: 0.3290
# Epoch 337/30000
#  - 1s - loss: 0.1766 - mse: 0.0997 - mae: 0.1766 - val_loss: 0.3268 - val_mse: 0.3116 - val_mae: 0.3268
# Epoch 338/30000
#  - 1s - loss: 0.1784 - mse: 0.0990 - mae: 0.1784 - val_loss: 0.3332 - val_mse: 0.3173 - val_mae: 0.3332
# Epoch 339/30000
#  - 1s - loss: 0.1775 - mse: 0.0973 - mae: 0.1775 - val_loss: 0.3318 - val_mse: 0.3063 - val_mae: 0.3318
# Epoch 340/30000
#  - 1s - loss: 0.1728 - mse: 0.0957 - mae: 0.1728 - val_loss: 0.3268 - val_mse: 0.3140 - val_mae: 0.3268
# Epoch 341/30000
#  - 1s - loss: 0.1720 - mse: 0.0943 - mae: 0.1720 - val_loss: 0.3342 - val_mse: 0.3146 - val_mae: 0.3342
# Epoch 342/30000
#  - 1s - loss: 0.1759 - mse: 0.0974 - mae: 0.1759 - val_loss: 0.3281 - val_mse: 0.3115 - val_mae: 0.3281
# Epoch 343/30000
#  - 1s - loss: 0.1719 - mse: 0.0960 - mae: 0.1719 - val_loss: 0.3271 - val_mse: 0.3030 - val_mae: 0.3271
# Epoch 344/30000
#  - 1s - loss: 0.1719 - mse: 0.0943 - mae: 0.1719 - val_loss: 0.3302 - val_mse: 0.3113 - val_mae: 0.3302
# Epoch 345/30000
#  - 1s - loss: 0.1731 - mse: 0.0951 - mae: 0.1731 - val_loss: 0.3334 - val_mse: 0.3126 - val_mae: 0.3334
# Epoch 346/30000
#  - 1s - loss: 0.1737 - mse: 0.0958 - mae: 0.1737 - val_loss: 0.3264 - val_mse: 0.3084 - val_mae: 0.3264
# Epoch 347/30000
#  - 1s - loss: 0.1725 - mse: 0.0948 - mae: 0.1725 - val_loss: 0.3316 - val_mse: 0.3120 - val_mae: 0.3316
# Epoch 348/30000
#  - 1s - loss: 0.1733 - mse: 0.0953 - mae: 0.1733 - val_loss: 0.3318 - val_mse: 0.3166 - val_mae: 0.3318
# Epoch 349/30000
#  - 1s - loss: 0.1729 - mse: 0.0955 - mae: 0.1729 - val_loss: 0.3285 - val_mse: 0.3138 - val_mae: 0.3285
# Epoch 350/30000
#  - 1s - loss: 0.1708 - mse: 0.0939 - mae: 0.1708 - val_loss: 0.3302 - val_mse: 0.3097 - val_mae: 0.3302
# Epoch 351/30000
#  - 1s - loss: 0.1754 - mse: 0.0969 - mae: 0.1754 - val_loss: 0.3318 - val_mse: 0.3095 - val_mae: 0.3318
# Epoch 352/30000
#  - 1s - loss: 0.1691 - mse: 0.0924 - mae: 0.1691 - val_loss: 0.3275 - val_mse: 0.3083 - val_mae: 0.3275
# Epoch 353/30000
#  - 1s - loss: 0.1709 - mse: 0.0931 - mae: 0.1709 - val_loss: 0.3277 - val_mse: 0.3082 - val_mae: 0.3277

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.09 degrees
# Root Mean Squared Error is 1.59 degrees
# Mean Absolute Error is 1.59 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is -0.16 degrees
# Root Mean Squared Error is 3.71 degrees
# Mean Absolute Error is 3.71 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3v6.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthforcemodel_cnn3v6.h5')
