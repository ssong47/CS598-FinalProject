# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,25)
nw_resize = 2
nh_resize = 3
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (14668, 40, 80, 3)

# %%
tlen = len(xtemp[0])-2 +len(xtemp[1])-2 #remove 2 samples from 24
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

# %%
plt.imshow(x_train[-2])

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,25)
date = ('11_15_2020','11_19_2020')
y_gt = {}
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])-2 +len(y_gt[1])-3 #remove 2 samples from 24 and 3 from 25
y_train = np.zeros((tlen,1))
y_train[:len(y_gt[0])-2] = y_gt[0][:len(y_gt[0])-2]
y_train[(len(y_gt[0])-2):] = y_gt[1][:len(y_gt[1])-3]

# %%
y_gt[0].shape
# Out:
# (12751, 1)

# %%
# Obtain X and Y data
# x_train.shape
# xtrainnew = pd.DataFrame(data=np.reshape(x_train, (x_train.shape[0],x_train.shape[1]*x_train.shape[2])))
# yframe = pd.DataFrame(data=y_train)

# TheData = pd.concat([xtrainnew,yframe],axis=1) #only contains video data
print(x_train.shape)
print(y_train.shape)
# Out:
# (27415, 40, 80, 3)
# (27415, 1)

# %%
print(xtemp[0].shape)
print(y_gt[0].shape)
print(xtemp[1].shape)
print(y_gt[1].shape)
# Out:
# (12751, 40, 80, 3)
# (12751, 1)
# (14668, 40, 80, 3)
# (14669, 1)

# %%
# xtmp = xtrainnew[300,:]
# plt.imshow(np.reshape(xtmp, (x_train.shape[1],x_train.shape[2])))

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
x_train.shape[1]
# Out:
# 40

# %% [markdown]
# # Regress using Neural Network

# %%
np.min(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 0.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model
batch_sz = 32
model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.5
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3))(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = MaxPooling2D(pool_size=(1, 1))(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3))(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = MaxPooling2D(pool_size=(2, 2))(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3))(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = MaxPooling2D(pool_size=(3, 3))(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)


model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 40, 80, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 38, 78, 64)        1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 38, 78, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 38, 78, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 38, 78, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 36, 76, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 36, 76, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 38, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 38, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 36, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 36, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 12, 64)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 12, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# activation_4 (Activation)    (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               491648
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 567,425
# Trainable params: 567,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True)
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 21932 samples, validate on 5483 samples
# Epoch 1/30000
#  - 11s - loss: 0.7318 - mse: 1.1495 - mae: 0.7318 - val_loss: 0.6688 - val_mse: 0.9704 - val_mae: 0.6688
# Epoch 2/30000
#  - 9s - loss: 0.6720 - mse: 0.9592 - mae: 0.6720 - val_loss: 0.6581 - val_mse: 0.9492 - val_mae: 0.6581
# Epoch 3/30000
#  - 9s - loss: 0.6621 - mse: 0.9380 - mae: 0.6621 - val_loss: 0.6488 - val_mse: 0.9339 - val_mae: 0.6488
# Epoch 4/30000
#  - 9s - loss: 0.6577 - mse: 0.9236 - mae: 0.6577 - val_loss: 0.6543 - val_mse: 0.9410 - val_mae: 0.6543
# Epoch 5/30000
#  - 9s - loss: 0.6521 - mse: 0.9075 - mae: 0.6521 - val_loss: 0.6401 - val_mse: 0.9162 - val_mae: 0.6401
# Epoch 6/30000
#  - 9s - loss: 0.6477 - mse: 0.8972 - mae: 0.6477 - val_loss: 0.6359 - val_mse: 0.9016 - val_mae: 0.6359
# Epoch 7/30000
#  - 9s - loss: 0.6427 - mse: 0.8824 - mae: 0.6427 - val_loss: 0.6351 - val_mse: 0.8909 - val_mae: 0.6351
# Epoch 8/30000
#  - 9s - loss: 0.6375 - mse: 0.8682 - mae: 0.6375 - val_loss: 0.6178 - val_mse: 0.8616 - val_mae: 0.6178
# Epoch 9/30000
#  - 9s - loss: 0.6299 - mse: 0.8539 - mae: 0.6299 - val_loss: 0.6197 - val_mse: 0.8609 - val_mae: 0.6197
# Epoch 10/30000
#  - 9s - loss: 0.6260 - mse: 0.8442 - mae: 0.6260 - val_loss: 0.6094 - val_mse: 0.8377 - val_mae: 0.6094
# Epoch 11/30000
#  - 9s - loss: 0.6189 - mse: 0.8325 - mae: 0.6189 - val_loss: 0.6122 - val_mse: 0.8412 - val_mae: 0.6122
# Epoch 12/30000
#  - 9s - loss: 0.6159 - mse: 0.8192 - mae: 0.6159 - val_loss: 0.6017 - val_mse: 0.8140 - val_mae: 0.6017
# Epoch 13/30000
#  - 9s - loss: 0.6075 - mse: 0.8000 - mae: 0.6075 - val_loss: 0.5922 - val_mse: 0.7921 - val_mae: 0.5922
# Epoch 14/30000
#  - 9s - loss: 0.6021 - mse: 0.7860 - mae: 0.6021 - val_loss: 0.5897 - val_mse: 0.7868 - val_mae: 0.5897
# Epoch 15/30000
#  - 9s - loss: 0.5900 - mse: 0.7629 - mae: 0.5900 - val_loss: 0.5767 - val_mse: 0.7595 - val_mae: 0.5767
# Epoch 16/30000
#  - 9s - loss: 0.5842 - mse: 0.7542 - mae: 0.5842 - val_loss: 0.5755 - val_mse: 0.7547 - val_mae: 0.5755
# Epoch 17/30000
#  - 9s - loss: 0.5780 - mse: 0.7383 - mae: 0.5780 - val_loss: 0.5588 - val_mse: 0.7303 - val_mae: 0.5588
# Epoch 18/30000
#  - 9s - loss: 0.5716 - mse: 0.7278 - mae: 0.5716 - val_loss: 0.5590 - val_mse: 0.7197 - val_mae: 0.5590
# Epoch 19/30000
#  - 9s - loss: 0.5656 - mse: 0.7128 - mae: 0.5656 - val_loss: 0.5527 - val_mse: 0.7116 - val_mae: 0.5527
# Epoch 20/30000
#  - 9s - loss: 0.5606 - mse: 0.7036 - mae: 0.5606 - val_loss: 0.5447 - val_mse: 0.6972 - val_mae: 0.5447
# Epoch 21/30000
#  - 9s - loss: 0.5559 - mse: 0.6914 - mae: 0.5559 - val_loss: 0.5385 - val_mse: 0.6861 - val_mae: 0.5385
# Epoch 22/30000
#  - 9s - loss: 0.5544 - mse: 0.6899 - mae: 0.5544 - val_loss: 0.5379 - val_mse: 0.6810 - val_mae: 0.5379
# Epoch 23/30000
#  - 9s - loss: 0.5503 - mse: 0.6837 - mae: 0.5503 - val_loss: 0.5362 - val_mse: 0.6759 - val_mae: 0.5362
# Epoch 24/30000
#  - 9s - loss: 0.5484 - mse: 0.6768 - mae: 0.5484 - val_loss: 0.5305 - val_mse: 0.6650 - val_mae: 0.5305
# Epoch 25/30000
#  - 9s - loss: 0.5436 - mse: 0.6654 - mae: 0.5436 - val_loss: 0.5251 - val_mse: 0.6623 - val_mae: 0.5251
# Epoch 26/30000
#  - 9s - loss: 0.5409 - mse: 0.6623 - mae: 0.5409 - val_loss: 0.5216 - val_mse: 0.6495 - val_mae: 0.5216
# Epoch 27/30000
#  - 9s - loss: 0.5347 - mse: 0.6446 - mae: 0.5347 - val_loss: 0.5225 - val_mse: 0.6537 - val_mae: 0.5225
# Epoch 28/30000
#  - 9s - loss: 0.5324 - mse: 0.6404 - mae: 0.5324 - val_loss: 0.5191 - val_mse: 0.6477 - val_mae: 0.5191
# Epoch 29/30000
#  - 9s - loss: 0.5296 - mse: 0.6358 - mae: 0.5296 - val_loss: 0.5235 - val_mse: 0.6556 - val_mae: 0.5235
# Epoch 30/30000
#  - 9s - loss: 0.5261 - mse: 0.6325 - mae: 0.5261 - val_loss: 0.5146 - val_mse: 0.6369 - val_mae: 0.5146
# Epoch 31/30000
#  - 9s - loss: 0.5231 - mse: 0.6283 - mae: 0.5231 - val_loss: 0.5119 - val_mse: 0.6278 - val_mae: 0.5119
# Epoch 32/30000
#  - 9s - loss: 0.5227 - mse: 0.6235 - mae: 0.5227 - val_loss: 0.5194 - val_mse: 0.6362 - val_mae: 0.5194
# Epoch 33/30000
#  - 9s - loss: 0.5183 - mse: 0.6156 - mae: 0.5183 - val_loss: 0.5067 - val_mse: 0.6226 - val_mae: 0.5067
# Epoch 34/30000
#  - 9s - loss: 0.5159 - mse: 0.6080 - mae: 0.5159 - val_loss: 0.5051 - val_mse: 0.6220 - val_mae: 0.5051
# Epoch 35/30000
#  - 9s - loss: 0.5156 - mse: 0.6121 - mae: 0.5156 - val_loss: 0.5046 - val_mse: 0.6142 - val_mae: 0.5046
# Epoch 36/30000
#  - 9s - loss: 0.5096 - mse: 0.5972 - mae: 0.5096 - val_loss: 0.5019 - val_mse: 0.6113 - val_mae: 0.5019
# Epoch 37/30000
#  - 9s - loss: 0.5071 - mse: 0.5912 - mae: 0.5071 - val_loss: 0.4984 - val_mse: 0.6035 - val_mae: 0.4984
# Epoch 38/30000
#  - 9s - loss: 0.5044 - mse: 0.5873 - mae: 0.5044 - val_loss: 0.4977 - val_mse: 0.6023 - val_mae: 0.4977
# Epoch 39/30000
#  - 9s - loss: 0.5021 - mse: 0.5836 - mae: 0.5021 - val_loss: 0.4960 - val_mse: 0.5970 - val_mae: 0.4960
# Epoch 40/30000
#  - 9s - loss: 0.5009 - mse: 0.5779 - mae: 0.5009 - val_loss: 0.4895 - val_mse: 0.5902 - val_mae: 0.4895
# Epoch 41/30000
#  - 9s - loss: 0.4976 - mse: 0.5736 - mae: 0.4976 - val_loss: 0.4924 - val_mse: 0.5907 - val_mae: 0.4924
# Epoch 42/30000
#  - 9s - loss: 0.4952 - mse: 0.5683 - mae: 0.4952 - val_loss: 0.4828 - val_mse: 0.5749 - val_mae: 0.4828
# Epoch 43/30000
#  - 9s - loss: 0.4929 - mse: 0.5649 - mae: 0.4929 - val_loss: 0.4802 - val_mse: 0.5767 - val_mae: 0.4802
# Epoch 44/30000
#  - 9s - loss: 0.4867 - mse: 0.5514 - mae: 0.4867 - val_loss: 0.4804 - val_mse: 0.5709 - val_mae: 0.4804
# Epoch 45/30000
#  - 9s - loss: 0.4890 - mse: 0.5590 - mae: 0.4890 - val_loss: 0.4785 - val_mse: 0.5704 - val_mae: 0.4785
# Epoch 46/30000
#  - 9s - loss: 0.4839 - mse: 0.5444 - mae: 0.4839 - val_loss: 0.4809 - val_mse: 0.5757 - val_mae: 0.4809
# Epoch 47/30000
#  - 9s - loss: 0.4811 - mse: 0.5423 - mae: 0.4811 - val_loss: 0.4783 - val_mse: 0.5644 - val_mae: 0.4783
# Epoch 48/30000
#  - 9s - loss: 0.4818 - mse: 0.5415 - mae: 0.4818 - val_loss: 0.4811 - val_mse: 0.5688 - val_mae: 0.4811
# Epoch 49/30000
# Epoch 198/30000
#  - 9s - loss: 0.3470 - mse: 0.2985 - mae: 0.3470 - val_loss: 0.3972 - val_mse: 0.4258 - val_mae: 0.3972
# Epoch 199/30000
#  - 9s - loss: 0.3427 - mse: 0.2927 - mae: 0.3427 - val_loss: 0.3988 - val_mse: 0.4287 - val_mae: 0.3988
# Epoch 200/30000
#  - 9s - loss: 0.3479 - mse: 0.3017 - mae: 0.3479 - val_loss: 0.3935 - val_mse: 0.4226 - val_mae: 0.3935
# Epoch 201/30000
#  - 9s - loss: 0.3447 - mse: 0.2946 - mae: 0.3447 - val_loss: 0.3964 - val_mse: 0.4258 - val_mae: 0.3964
# Epoch 202/30000
#  - 9s - loss: 0.3479 - mse: 0.2988 - mae: 0.3479 - val_loss: 0.3988 - val_mse: 0.4284 - val_mae: 0.3988
# Epoch 203/30000
#  - 9s - loss: 0.3461 - mse: 0.2960 - mae: 0.3461 - val_loss: 0.3978 - val_mse: 0.4298 - val_mae: 0.3978
# Epoch 204/30000
#  - 9s - loss: 0.3465 - mse: 0.2980 - mae: 0.3465 - val_loss: 0.3977 - val_mse: 0.4323 - val_mae: 0.3977
# Epoch 205/30000
#  - 9s - loss: 0.3437 - mse: 0.2942 - mae: 0.3437 - val_loss: 0.3968 - val_mse: 0.4310 - val_mae: 0.3968
# Epoch 206/30000
#  - 9s - loss: 0.3471 - mse: 0.2995 - mae: 0.3471 - val_loss: 0.4081 - val_mse: 0.4402 - val_mae: 0.4081
# Epoch 207/30000
#  - 9s - loss: 0.3465 - mse: 0.2960 - mae: 0.3465 - val_loss: 0.4014 - val_mse: 0.4338 - val_mae: 0.4014
# Epoch 208/30000
#  - 9s - loss: 0.3447 - mse: 0.2945 - mae: 0.3447 - val_loss: 0.3939 - val_mse: 0.4268 - val_mae: 0.3939
# Epoch 209/30000
#  - 9s - loss: 0.3454 - mse: 0.2954 - mae: 0.3454 - val_loss: 0.3986 - val_mse: 0.4337 - val_mae: 0.3986
# Epoch 210/30000
#  - 9s - loss: 0.3444 - mse: 0.2928 - mae: 0.3444 - val_loss: 0.3931 - val_mse: 0.4246 - val_mae: 0.3931
# Epoch 211/30000
#  - 9s - loss: 0.3412 - mse: 0.2910 - mae: 0.3412 - val_loss: 0.3993 - val_mse: 0.4308 - val_mae: 0.3993
# Epoch 212/30000
#  - 9s - loss: 0.3432 - mse: 0.2916 - mae: 0.3432 - val_loss: 0.3955 - val_mse: 0.4265 - val_mae: 0.3955
# Epoch 213/30000
#  - 9s - loss: 0.3444 - mse: 0.2957 - mae: 0.3444 - val_loss: 0.3938 - val_mse: 0.4247 - val_mae: 0.3938
# Epoch 214/30000
#  - 9s - loss: 0.3399 - mse: 0.2873 - mae: 0.3399 - val_loss: 0.3936 - val_mse: 0.4216 - val_mae: 0.3936
# Epoch 215/30000
#  - 9s - loss: 0.3425 - mse: 0.2913 - mae: 0.3425 - val_loss: 0.3899 - val_mse: 0.4243 - val_mae: 0.3899
# Epoch 216/30000
#  - 9s - loss: 0.3414 - mse: 0.2910 - mae: 0.3414 - val_loss: 0.3923 - val_mse: 0.4220 - val_mae: 0.3923
# Epoch 217/30000
#  - 9s - loss: 0.3393 - mse: 0.2855 - mae: 0.3393 - val_loss: 0.3957 - val_mse: 0.4297 - val_mae: 0.3957
# Epoch 218/30000
#  - 9s - loss: 0.3406 - mse: 0.2891 - mae: 0.3406 - val_loss: 0.3953 - val_mse: 0.4232 - val_mae: 0.3953
# Epoch 219/30000
#  - 9s - loss: 0.3412 - mse: 0.2898 - mae: 0.3412 - val_loss: 0.3926 - val_mse: 0.4278 - val_mae: 0.3926
# Epoch 220/30000
#  - 9s - loss: 0.3393 - mse: 0.2860 - mae: 0.3393 - val_loss: 0.3936 - val_mse: 0.4233 - val_mae: 0.3936
# Epoch 221/30000
#  - 9s - loss: 0.3386 - mse: 0.2888 - mae: 0.3386 - val_loss: 0.3916 - val_mse: 0.4213 - val_mae: 0.3916
# Epoch 222/30000
#  - 9s - loss: 0.3406 - mse: 0.2876 - mae: 0.3406 - val_loss: 0.4018 - val_mse: 0.4333 - val_mae: 0.4018
# Epoch 223/30000
#  - 9s - loss: 0.3381 - mse: 0.2854 - mae: 0.3381 - val_loss: 0.3929 - val_mse: 0.4252 - val_mae: 0.3929
# Epoch 224/30000
#  - 9s - loss: 0.3392 - mse: 0.2873 - mae: 0.3392 - val_loss: 0.3960 - val_mse: 0.4274 - val_mae: 0.3960
# Epoch 225/30000
#  - 9s - loss: 0.3384 - mse: 0.2842 - mae: 0.3384 - val_loss: 0.3891 - val_mse: 0.4194 - val_mae: 0.3891
# Epoch 226/30000
#  - 9s - loss: 0.3406 - mse: 0.2865 - mae: 0.3406 - val_loss: 0.3931 - val_mse: 0.4233 - val_mae: 0.3931
# Epoch 227/30000
#  - 9s - loss: 0.3378 - mse: 0.2830 - mae: 0.3378 - val_loss: 0.3979 - val_mse: 0.4278 - val_mae: 0.3979
# Epoch 228/30000
#  - 9s - loss: 0.3382 - mse: 0.2832 - mae: 0.3382 - val_loss: 0.3895 - val_mse: 0.4190 - val_mae: 0.3895
# Epoch 229/30000
#  - 9s - loss: 0.3386 - mse: 0.2852 - mae: 0.3386 - val_loss: 0.3923 - val_mse: 0.4200 - val_mae: 0.3923
# Epoch 230/30000
#  - 9s - loss: 0.3386 - mse: 0.2856 - mae: 0.3386 - val_loss: 0.3906 - val_mse: 0.4184 - val_mae: 0.3906
# Epoch 231/30000
#  - 9s - loss: 0.3359 - mse: 0.2799 - mae: 0.3359 - val_loss: 0.3942 - val_mse: 0.4246 - val_mae: 0.3942
# Epoch 232/30000
#  - 9s - loss: 0.3381 - mse: 0.2831 - mae: 0.3381 - val_loss: 0.3892 - val_mse: 0.4162 - val_mae: 0.3892
# Epoch 233/30000
#  - 9s - loss: 0.3354 - mse: 0.2795 - mae: 0.3354 - val_loss: 0.3926 - val_mse: 0.4229 - val_mae: 0.3926
# Epoch 234/30000
#  - 9s - loss: 0.3358 - mse: 0.2806 - mae: 0.3358 - val_loss: 0.4003 - val_mse: 0.4285 - val_mae: 0.4003
# Epoch 235/30000
#  - 9s - loss: 0.3358 - mse: 0.2776 - mae: 0.3358 - val_loss: 0.3907 - val_mse: 0.4218 - val_mae: 0.3907
# Epoch 236/30000
#  - 9s - loss: 0.3328 - mse: 0.2784 - mae: 0.3328 - val_loss: 0.3954 - val_mse: 0.4220 - val_mae: 0.3954
# Epoch 237/30000
#  - 9s - loss: 0.3377 - mse: 0.2853 - mae: 0.3377 - val_loss: 0.3969 - val_mse: 0.4229 - val_mae: 0.3969
# Epoch 238/30000
#  - 9s - loss: 0.3376 - mse: 0.2832 - mae: 0.3376 - val_loss: 0.3983 - val_mse: 0.4262 - val_mae: 0.3983
# Epoch 239/30000
#  - 9s - loss: 0.3359 - mse: 0.2831 - mae: 0.3359 - val_loss: 0.3972 - val_mse: 0.4252 - val_mae: 0.3972
# Epoch 240/30000
#  - 9s - loss: 0.3347 - mse: 0.2782 - mae: 0.3347 - val_loss: 0.3923 - val_mse: 0.4236 - val_mae: 0.3923
# Epoch 241/30000
#  - 9s - loss: 0.3341 - mse: 0.2771 - mae: 0.3341 - val_loss: 0.3963 - val_mse: 0.4238 - val_mae: 0.3963
# Epoch 242/30000
#  - 9s - loss: 0.3337 - mse: 0.2793 - mae: 0.3337 - val_loss: 0.3993 - val_mse: 0.4272 - val_mae: 0.3993
# Epoch 243/30000
#  - 9s - loss: 0.3323 - mse: 0.2777 - mae: 0.3323 - val_loss: 0.3915 - val_mse: 0.4194 - val_mae: 0.3915
# Epoch 244/30000
#  - 9s - loss: 0.3344 - mse: 0.2787 - mae: 0.3344 - val_loss: 0.3891 - val_mse: 0.4185 - val_mae: 0.3891
# Epoch 245/30000
#  - 9s - loss: 0.3338 - mse: 0.2761 - mae: 0.3338 - val_loss: 0.3914 - val_mse: 0.4206 - val_mae: 0.3914
# Epoch 246/30000
#  - 9s - loss: 0.3338 - mse: 0.2785 - mae: 0.3338 - val_loss: 0.3935 - val_mse: 0.4234 - val_mae: 0.3935
# Epoch 247/30000
#  - 9s - loss: 0.3358 - mse: 0.2820 - mae: 0.3358 - val_loss: 0.3926 - val_mse: 0.4237 - val_mae: 0.3926
# Epoch 248/30000
#  - 9s - loss: 0.3320 - mse: 0.2746 - mae: 0.3320 - val_loss: 0.3959 - val_mse: 0.4212 - val_mae: 0.3959
# Epoch 249/30000
#  - 9s - loss: 0.3332 - mse: 0.2758 - mae: 0.3332 - val_loss: 0.3944 - val_mse: 0.4194 - val_mae: 0.3944
# Epoch 250/30000
#  - 9s - loss: 0.3337 - mse: 0.2764 - mae: 0.3337 - val_loss: 0.3947 - val_mse: 0.4210 - val_mae: 0.3947
# Epoch 251/30000
#  - 9s - loss: 0.3349 - mse: 0.2794 - mae: 0.3349 - val_loss: 0.3926 - val_mse: 0.4230 - val_mae: 0.3926
# Epoch 252/30000
#  - 9s - loss: 0.3313 - mse: 0.2757 - mae: 0.3313 - val_loss: 0.3909 - val_mse: 0.4223 - val_mae: 0.3909
# Epoch 253/30000
#  - 9s - loss: 0.3324 - mse: 0.2777 - mae: 0.3324 - val_loss: 0.3966 - val_mse: 0.4259 - val_mae: 0.3966
# Epoch 254/30000
#  - 9s - loss: 0.3320 - mse: 0.2743 - mae: 0.3320 - val_loss: 0.3883 - val_mse: 0.4190 - val_mae: 0.3883
# Epoch 255/30000
#  - 9s - loss: 0.3318 - mse: 0.2754 - mae: 0.3318 - val_loss: 0.3945 - val_mse: 0.4280 - val_mae: 0.3945
# Epoch 256/30000
#  - 9s - loss: 0.3314 - mse: 0.2755 - mae: 0.3314 - val_loss: 0.3936 - val_mse: 0.4234 - val_mae: 0.3936
# Epoch 257/30000
#  - 9s - loss: 0.3319 - mse: 0.2746 - mae: 0.3319 - val_loss: 0.3972 - val_mse: 0.4223 - val_mae: 0.3972
# Epoch 258/30000
#  - 9s - loss: 0.3299 - mse: 0.2728 - mae: 0.3299 - val_loss: 0.3937 - val_mse: 0.4263 - val_mae: 0.3937
# Epoch 259/30000
#  - 9s - loss: 0.3301 - mse: 0.2736 - mae: 0.3301 - val_loss: 0.3920 - val_mse: 0.4197 - val_mae: 0.3920
# Epoch 260/30000
#  - 9s - loss: 0.3304 - mse: 0.2766 - mae: 0.3304 - val_loss: 0.3936 - val_mse: 0.4215 - val_mae: 0.3936
# Epoch 261/30000
#  - 9s - loss: 0.3298 - mse: 0.2737 - mae: 0.3298 - val_loss: 0.3953 - val_mse: 0.4240 - val_mae: 0.3953
# Epoch 262/30000
#  - 9s - loss: 0.3287 - mse: 0.2698 - mae: 0.3287 - val_loss: 0.3883 - val_mse: 0.4186 - val_mae: 0.3883
# Epoch 263/30000
#  - 9s - loss: 0.3291 - mse: 0.2720 - mae: 0.3291 - val_loss: 0.3906 - val_mse: 0.4219 - val_mae: 0.3906
# Epoch 264/30000
#  - 9s - loss: 0.3286 - mse: 0.2722 - mae: 0.3286 - val_loss: 0.3924 - val_mse: 0.4255 - val_mae: 0.3924
# Epoch 265/30000
#  - 9s - loss: 0.3304 - mse: 0.2734 - mae: 0.3304 - val_loss: 0.3900 - val_mse: 0.4216 - val_mae: 0.3900
# Epoch 266/30000
#  - 9s - loss: 0.3291 - mse: 0.2706 - mae: 0.3291 - val_loss: 0.3953 - val_mse: 0.4227 - val_mae: 0.3953
# Epoch 267/30000
#  - 9s - loss: 0.3257 - mse: 0.2679 - mae: 0.3257 - val_loss: 0.3832 - val_mse: 0.4104 - val_mae: 0.3832
# Epoch 268/30000
#  - 9s - loss: 0.3298 - mse: 0.2726 - mae: 0.3298 - val_loss: 0.3915 - val_mse: 0.4178 - val_mae: 0.3915
# Epoch 269/30000
#  - 9s - loss: 0.3318 - mse: 0.2756 - mae: 0.3318 - val_loss: 0.3898 - val_mse: 0.4174 - val_mae: 0.3898
# Epoch 270/30000
#  - 9s - loss: 0.3269 - mse: 0.2676 - mae: 0.3269 - val_loss: 0.3936 - val_mse: 0.4207 - val_mae: 0.3936
# Epoch 271/30000
#  - 9s - loss: 0.3296 - mse: 0.2723 - mae: 0.3296 - val_loss: 0.3934 - val_mse: 0.4211 - val_mae: 0.3934
# Epoch 328/30000
#  - 9s - loss: 0.3156 - mse: 0.2495 - mae: 0.3156 - val_loss: 0.3944 - val_mse: 0.4181 - val_mae: 0.3944
# Epoch 329/30000
#  - 9s - loss: 0.3175 - mse: 0.2505 - mae: 0.3175 - val_loss: 0.3905 - val_mse: 0.4180 - val_mae: 0.3905
# Epoch 330/30000
#  - 9s - loss: 0.3149 - mse: 0.2496 - mae: 0.3149 - val_loss: 0.3923 - val_mse: 0.4239 - val_mae: 0.3923
# Epoch 331/30000
#  - 9s - loss: 0.3169 - mse: 0.2534 - mae: 0.3169 - val_loss: 0.3896 - val_mse: 0.4169 - val_mae: 0.3896
# Epoch 332/30000
#  - 9s - loss: 0.3176 - mse: 0.2517 - mae: 0.3176 - val_loss: 0.3853 - val_mse: 0.4173 - val_mae: 0.3853
# Epoch 333/30000
#  - 9s - loss: 0.3139 - mse: 0.2466 - mae: 0.3139 - val_loss: 0.3916 - val_mse: 0.4198 - val_mae: 0.3916
# Epoch 334/30000
#  - 9s - loss: 0.3170 - mse: 0.2522 - mae: 0.3170 - val_loss: 0.3891 - val_mse: 0.4178 - val_mae: 0.3891
# Epoch 335/30000
#  - 9s - loss: 0.3159 - mse: 0.2508 - mae: 0.3159 - val_loss: 0.3904 - val_mse: 0.4179 - val_mae: 0.3904
# Epoch 336/30000
#  - 9s - loss: 0.3127 - mse: 0.2468 - mae: 0.3127 - val_loss: 0.3917 - val_mse: 0.4189 - val_mae: 0.3917
# Epoch 337/30000
#  - 9s - loss: 0.3145 - mse: 0.2473 - mae: 0.3145 - val_loss: 0.3853 - val_mse: 0.4098 - val_mae: 0.3853
# Epoch 338/30000
#  - 9s - loss: 0.3144 - mse: 0.2469 - mae: 0.3144 - val_loss: 0.3845 - val_mse: 0.4094 - val_mae: 0.3845
# Epoch 339/30000
#  - 9s - loss: 0.3161 - mse: 0.2496 - mae: 0.3161 - val_loss: 0.3859 - val_mse: 0.4167 - val_mae: 0.3859
# Epoch 340/30000
#  - 9s - loss: 0.3164 - mse: 0.2505 - mae: 0.3164 - val_loss: 0.3874 - val_mse: 0.4152 - val_mae: 0.3874
# Epoch 341/30000
#  - 9s - loss: 0.3132 - mse: 0.2476 - mae: 0.3132 - val_loss: 0.3904 - val_mse: 0.4155 - val_mae: 0.3904
# Epoch 342/30000
#  - 9s - loss: 0.3152 - mse: 0.2499 - mae: 0.3152 - val_loss: 0.3882 - val_mse: 0.4176 - val_mae: 0.3882
# Epoch 343/30000
#  - 9s - loss: 0.3108 - mse: 0.2419 - mae: 0.3108 - val_loss: 0.3871 - val_mse: 0.4146 - val_mae: 0.3871
# Epoch 344/30000
#  - 9s - loss: 0.3146 - mse: 0.2478 - mae: 0.3146 - val_loss: 0.3860 - val_mse: 0.4143 - val_mae: 0.3860
# Epoch 345/30000
#  - 9s - loss: 0.3113 - mse: 0.2418 - mae: 0.3113 - val_loss: 0.3884 - val_mse: 0.4156 - val_mae: 0.3884
# Epoch 346/30000
#  - 9s - loss: 0.3115 - mse: 0.2421 - mae: 0.3115 - val_loss: 0.3834 - val_mse: 0.4120 - val_mae: 0.3834
# Epoch 347/30000
#  - 9s - loss: 0.3137 - mse: 0.2477 - mae: 0.3137 - val_loss: 0.3854 - val_mse: 0.4133 - val_mae: 0.3854
# Epoch 348/30000
#  - 9s - loss: 0.3151 - mse: 0.2472 - mae: 0.3151 - val_loss: 0.3843 - val_mse: 0.4142 - val_mae: 0.3843
# Epoch 349/30000
#  - 9s - loss: 0.3152 - mse: 0.2488 - mae: 0.3152 - val_loss: 0.3947 - val_mse: 0.4232 - val_mae: 0.3947
# Epoch 350/30000
#  - 9s - loss: 0.3118 - mse: 0.2436 - mae: 0.3118 - val_loss: 0.3879 - val_mse: 0.4157 - val_mae: 0.3879
# Epoch 351/30000
#  - 9s - loss: 0.3139 - mse: 0.2476 - mae: 0.3139 - val_loss: 0.3837 - val_mse: 0.4126 - val_mae: 0.3837
# Epoch 352/30000
#  - 9s - loss: 0.3118 - mse: 0.2446 - mae: 0.3118 - val_loss: 0.3884 - val_mse: 0.4152 - val_mae: 0.3884
# Epoch 353/30000
#  - 9s - loss: 0.3119 - mse: 0.2440 - mae: 0.3119 - val_loss: 0.3841 - val_mse: 0.4119 - val_mae: 0.3841
# Epoch 354/30000
#  - 9s - loss: 0.3101 - mse: 0.2418 - mae: 0.3101 - val_loss: 0.3955 - val_mse: 0.4185 - val_mae: 0.3955
# Epoch 355/30000
#  - 9s - loss: 0.3115 - mse: 0.2406 - mae: 0.3115 - val_loss: 0.3879 - val_mse: 0.4125 - val_mae: 0.3879
# Epoch 356/30000
#  - 9s - loss: 0.3100 - mse: 0.2391 - mae: 0.3100 - val_loss: 0.3838 - val_mse: 0.4130 - val_mae: 0.3838
# Epoch 357/30000
#  - 9s - loss: 0.3116 - mse: 0.2423 - mae: 0.3116 - val_loss: 0.3820 - val_mse: 0.4098 - val_mae: 0.3820
# Epoch 358/30000
#  - 9s - loss: 0.3101 - mse: 0.2427 - mae: 0.3101 - val_loss: 0.3880 - val_mse: 0.4168 - val_mae: 0.3880
# Epoch 359/30000
#  - 9s - loss: 0.3140 - mse: 0.2465 - mae: 0.3140 - val_loss: 0.3846 - val_mse: 0.4143 - val_mae: 0.3846
# Epoch 360/30000
#  - 9s - loss: 0.3116 - mse: 0.2445 - mae: 0.3116 - val_loss: 0.3839 - val_mse: 0.4130 - val_mae: 0.3839
# Epoch 361/30000
#  - 9s - loss: 0.3092 - mse: 0.2402 - mae: 0.3092 - val_loss: 0.3923 - val_mse: 0.4209 - val_mae: 0.3923
# Epoch 362/30000
#  - 9s - loss: 0.3113 - mse: 0.2425 - mae: 0.3113 - val_loss: 0.3885 - val_mse: 0.4176 - val_mae: 0.3885
# Epoch 363/30000
#  - 9s - loss: 0.3087 - mse: 0.2392 - mae: 0.3087 - val_loss: 0.3889 - val_mse: 0.4223 - val_mae: 0.3889
# Epoch 364/30000
#  - 9s - loss: 0.3112 - mse: 0.2436 - mae: 0.3112 - val_loss: 0.3893 - val_mse: 0.4193 - val_mae: 0.3893
# Epoch 365/30000
#  - 9s - loss: 0.3087 - mse: 0.2404 - mae: 0.3087 - val_loss: 0.3848 - val_mse: 0.4151 - val_mae: 0.3848
# Epoch 366/30000
#  - 9s - loss: 0.3117 - mse: 0.2412 - mae: 0.3117 - val_loss: 0.3875 - val_mse: 0.4131 - val_mae: 0.3875
# Epoch 367/30000
#  - 9s - loss: 0.3096 - mse: 0.2391 - mae: 0.3096 - val_loss: 0.3846 - val_mse: 0.4136 - val_mae: 0.3846
# Epoch 368/30000
#  - 9s - loss: 0.3086 - mse: 0.2396 - mae: 0.3086 - val_loss: 0.3832 - val_mse: 0.4159 - val_mae: 0.3832
# Epoch 369/30000
#  - 9s - loss: 0.3062 - mse: 0.2370 - mae: 0.3062 - val_loss: 0.3875 - val_mse: 0.4193 - val_mae: 0.3875
# Epoch 370/30000
#  - 9s - loss: 0.3103 - mse: 0.2415 - mae: 0.3103 - val_loss: 0.3871 - val_mse: 0.4182 - val_mae: 0.3871
# Epoch 371/30000
#  - 9s - loss: 0.3098 - mse: 0.2403 - mae: 0.3098 - val_loss: 0.3885 - val_mse: 0.4195 - val_mae: 0.3885
# Epoch 372/30000
#  - 9s - loss: 0.3125 - mse: 0.2440 - mae: 0.3125 - val_loss: 0.3912 - val_mse: 0.4222 - val_mae: 0.3912

# %%
# Out:
# <function matplotlib.use(backend, *, force=True)>

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is 0.19 degrees
# Root Mean Squared Error is 2.93 degrees
# Mean Absolute Error is 2.93 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is 0.45 degrees
# Root Mean Squared Error is 5.21 degrees
# Mean Absolute Error is 5.21 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthforcemodelparam_cnn3.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthforcemodel_cnn3.h5')
