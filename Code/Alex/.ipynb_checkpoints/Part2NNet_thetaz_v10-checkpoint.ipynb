# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from scipy import signal
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import random
import tensorflow as tf
import cv2
from scipy import stats

# %% [markdown]
# # Read Depth Camera

# %%
# For reading depth camera
def read_depth_camera(dcamera_path, show_video, nw_resize=1, nh_resize=1):
    video  = cv2.VideoCapture(dcamera_path)
    ret, frame = video.read()
    
    # Get total # of frame count 
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
        
    frame_height = int(frame.shape[0])
    frame_width = int(frame.shape[1])

    
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize)))
    depth_frames = np.empty((frame_count, int(frame_height/nh_resize), int(frame_width/nw_resize),3))
    count = 0
    while (video.isOpened()):
        ret, frame = video.read()
        
        if ret == True:
#             gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame = frame/np.maximum(np.max(frame),255)
            gray_frame = cv2.resize(gray_frame, \
                                    (int(frame_width/nw_resize), int(frame_height/nh_resize)),\
                                    interpolation = cv2.INTER_NEAREST)

            depth_frames[count] = gray_frame
            if show_video == True:
                cv2.imshow("Depth", gray_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            count = count + 1
        else: 
            break
            

    video.release()
    #cv2.destroyAllWindows()
    return depth_frames

# %%
def play_video(read_frames):

    for i in range(len(read_frames)):
        # Capture frame-by-frame
        frame = read_frames[i]

        # Display the resulting frame
        plt.imshow(frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    #cv2.destroyAllWindows()

    return

# %%
def show_frame(read_frames, frame_range):
      # Capture frame-by-frame

    # Display the resulting frame
    for i in frame_range:
        fig = plt.figure(figsize=(6,6))        
        a = plt.imshow(read_frames[i])
        
    return

# %%
#fix this to concatenate everything
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test)+'.avi'
# show_video = 0
# n_resize = 1
# x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=2, nh_resize=3)


n_test = (24,25)
nw_resize = 1
nh_resize = 1
xtemp = {}
show_video = 0
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    train_dcamera_path = data_dir + '/depth_processed_leo_test'+str(n_test[i])+'.avi'
    x_train = read_depth_camera(train_dcamera_path, show_video, nw_resize=nw_resize, nh_resize=nh_resize)
    xtemp[i]=x_train

# %%
x_train.shape
# Out:
# (14668, 120, 160, 3)

# %%
tlen = len(xtemp[0])-2 +len(xtemp[1])-2 #remove 2 samples from 24
x_train = np.zeros((tlen,xtemp[0].shape[1],xtemp[0].shape[2],xtemp[0].shape[3]))
x_train[:len(xtemp[0])-2,:,:,:] = xtemp[0][:len(xtemp[0])-2,:,:,:]
x_train[(len(xtemp[0])-2):,:,:,:] = xtemp[1][:len(xtemp[1])-2,:,:,:]

# %%
plt.imshow(x_train[-2])

# %% [markdown]
# ## model.summary()

# %% [markdown]
# # read fdss data

# %%
#### Removed due to possible syncing/noise issue
# n_test = 24
# date = '11_15_2020'
# test_str = 'test' + str(n_test)
# #data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + "/" + test_str + "/fcss_processed_leo_" + test_str + "_" + date + ".txt"
# tmpdata = pd.read_csv(data_dir)

# %%
# tmpdata.head()

# %% [markdown]
# # Read Output Data

# %%
def read_output_data(qtm_file_data, theta):
    if theta=='x':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Left/Right Angle (deg)"])
    if theta=='y':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Lean Forward/Backwards Angle (deg)"])
    if theta=='z':
        qtm_data = pd.read_csv(qtm_file_data, usecols = ["Torso Twist Angle (deg)"])
        
    
    return qtm_data

# %%
# n_test = 24
# date = '11_15_2020'
# test_str = '/test' + str(n_test)
# # data_dir = r"C:\Users\77bis\Box\CS598 - Final Project\Preliminary Data V4\Test_Subject_Leo" + test_str
# data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V4/Test_Subject_Leo" + test_str
# qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test) + '_' + date + '.txt'
# #show_qtm_plot = True

# y_gt = read_output_data(qtm_file_data_dir,theta_interest).values
# theta_x = read_output_data(qtm_file_data_dir,'x').values
# theta_y = read_output_data(qtm_file_data_dir,'y').values
# theta_z = read_output_data(qtm_file_data_dir,'z').values

n_test = (24,25)
date = ('11_15_2020','11_19_2020')
y_gt = {}
theta_interest = 'z'
for i in range(len(n_test)):
    test_str = '/test' + str(n_test[i])
    data_dir = "/home/asilador/CS598/CS598-FinalProject/Preliminary Data V5/Test_Subject_Leo" + test_str
    qtm_file_data_dir = data_dir + '/qtm_processed_leo_test' + str(n_test[i]) + '_' + date[i] + '.txt'
    y_gttemp = read_output_data(qtm_file_data_dir,theta_interest).values
    y_gt[i]=y_gttemp
    
tlen = len(y_gt[0])-2 +len(y_gt[1])-3 #remove 2 samples from 24 and 3 from 25
y_train = np.zeros((tlen,1))
y_train[:len(y_gt[0])-2] = y_gt[0][:len(y_gt[0])-2]
y_train[(len(y_gt[0])-2):] = y_gt[1][:len(y_gt[1])-3]

# %%
y_gt[0].shape
# Out:
# (12751, 1)

# %%
# Obtain X and Y data
# x_train.shape
# xtrainnew = pd.DataFrame(data=np.reshape(x_train, (x_train.shape[0],x_train.shape[1]*x_train.shape[2])))
# yframe = pd.DataFrame(data=y_train)

# TheData = pd.concat([xtrainnew,yframe],axis=1) #only contains video data
print(x_train.shape)
print(y_train.shape)
# Out:
# (27415, 120, 160, 3)
# (27415, 1)

# %%
print(xtemp[0].shape)
print(y_gt[0].shape)
print(xtemp[1].shape)
print(y_gt[1].shape)
# Out:
# (12751, 120, 160, 3)
# (12751, 1)
# (14668, 120, 160, 3)
# (14669, 1)

# %%
# xtmp = xtrainnew[300,:]
# plt.imshow(np.reshape(xtmp, (x_train.shape[1],x_train.shape[2])))

# %%
nsamps = x_train.shape[0]
n80p = int(np.floor(nsamps*0.8))
rannums = np.array(random.sample(range(1,nsamps,1), n80p))
s_nfiles = np.arange(nsamps)
test_set = np.setdiff1d(s_nfiles,rannums)

#

# %%
Trainset = x_train[rannums,:]
Testset = x_train[test_set,:]
# Trainy= y_gt[rannums,:]
# Testy = y_gt[test_set,:]
Trainy= y_train[rannums,:]
Testy = y_train[test_set,:]

# %%
sc_y = StandardScaler()

# %%
Xtrainz = Trainset
ytrainz = Trainy
X = Xtrainz
y = sc_y.fit_transform(ytrainz)

# %%
#make validation data available to model.fit
Xvalid = Testset

y_valid = Testy
y_valid = sc_y.transform(y_valid)

# %%
x_train.shape[1]
# Out:
# 120

# %% [markdown]
# # Regress using Neural Network

# %%
np.min(Xvalid) #7min*30fps*60s/min*0.8 ~ 10800
# Out:
# 0.0

# %%
# Create Neural Netowrk
# model = tf.keras.Sequential()
# model.add(tf.keras.Input(shape=(X.shape[1],)))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# #model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(200, activation="relu"))
# model.add(tf.keras.layers.Dropout(0.5))          
# model.add(tf.keras.layers.Dense(100, activation='linear')) #added extra layer. probably overkill but want good results
# model.add(tf.keras.layers.Dense(1, activation='linear'))
# model.compile(optimizer='adam',
#               loss='mae',
#               metrics=['mse','mae'])
    
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # loss_fn(y_train[:1], predictions).numpy()

from keras.layers import Bidirectional, Conv2D, MaxPooling2D, Input, Concatenate, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Activation, Dropout, Reshape, Permute, Flatten
from keras.models import Model

model_start = Input(shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
model_cnn = model_start
# f_pool_size = (5,2,2)
dropout_rate = 0.4
# for i, convCnt in enumerate(f_pool_size):
#     model_cnn = Conv2D(filters=x_train.shape[2], kernel_size=(3, 3))(model_cnn)
#     model_cnn = BatchNormalization()(model_cnn)
#     model_cnn = Activation('relu')(model_cnn)
#     model_cnn = MaxPooling2D(pool_size=(f_pool_size[i], f_pool_size[i]))(model_cnn)
#     model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=8, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=16, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=32, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Conv2D(filters=64, kernel_size=(3, 3),padding='same')(model_cnn)
# model_cnn = BatchNormalization()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = AveragePooling2D(pool_size=(2, 2))(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Flatten()(model_cnn)
model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

model_cnn = Dense(128)(model_cnn)
model_cnn = Activation('relu')(model_cnn)
model_cnn = Dropout(dropout_rate)(model_cnn)

# model_cnn = Dense(200)(model_cnn)
# model_cnn = Activation('relu')(model_cnn)
# model_cnn = Dropout(dropout_rate)(model_cnn)

output = Dense(1)(model_cnn)
output = Activation('linear', name='thetaz_out')(output)
model = Model(inputs=model_start,outputs=output)
model.compile(optimizer='adam',
              loss='mae',
              metrics=['mse','mae'])


callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True) #Moving to 1000 patience. 
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 120, 160, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 120, 160, 8)       224
# _________________________________________________________________
# activation_7 (Activation)    (None, 120, 160, 8)       0
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 60, 80, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 16)        1168
# _________________________________________________________________
# activation_8 (Activation)    (None, 60, 80, 16)        0
# _________________________________________________________________
# average_pooling2d_6 (Average (None, 30, 40, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 32)        4640
# _________________________________________________________________
# activation_9 (Activation)    (None, 30, 40, 32)        0
# _________________________________________________________________
# average_pooling2d_7 (Average (None, 15, 20, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 20, 64)        18496
# _________________________________________________________________
# activation_10 (Activation)   (None, 15, 20, 64)        0
# _________________________________________________________________
# average_pooling2d_8 (Average (None, 7, 10, 64)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4480)              0
# _________________________________________________________________
# activation_11 (Activation)   (None, 4480)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               573568
# _________________________________________________________________
# activation_12 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# _________________________________________________________________
# thetaz_out (Activation)      (None, 1)                 0
# =================================================================
# Total params: 598,225
# Trainable params: 598,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(30000)
batch_size = 256
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50,restore_best_weights=True)
history = model.fit(X, y,batch_size=batch_size, epochs = epochs,callbacks = [callback],validation_data = (Xvalid, y_valid),verbose=2)

# model.save('depthforcemodel.h5')
#history.save('depthforcehist.h5')
# Out:
# Train on 21932 samples, validate on 5483 samples
# Epoch 1/30000
#  - 10s - loss: 0.6658 - mse: 0.9507 - mae: 0.6658 - val_loss: 0.6620 - val_mse: 0.9473 - val_mae: 0.6620
# Epoch 2/30000
#  - 9s - loss: 0.6481 - mse: 0.9076 - mae: 0.6481 - val_loss: 0.6437 - val_mse: 0.9002 - val_mae: 0.6437
# Epoch 3/30000
#  - 9s - loss: 0.6204 - mse: 0.8377 - mae: 0.6204 - val_loss: 0.6152 - val_mse: 0.8399 - val_mae: 0.6152
# Epoch 4/30000
#  - 9s - loss: 0.6018 - mse: 0.7951 - mae: 0.6018 - val_loss: 0.5819 - val_mse: 0.7618 - val_mae: 0.5819
# Epoch 5/30000
#  - 9s - loss: 0.5753 - mse: 0.7361 - mae: 0.5753 - val_loss: 0.5708 - val_mse: 0.7372 - val_mae: 0.5708
# Epoch 6/30000
#  - 9s - loss: 0.5592 - mse: 0.7081 - mae: 0.5592 - val_loss: 0.5490 - val_mse: 0.6960 - val_mae: 0.5490
# Epoch 7/30000
#  - 10s - loss: 0.5458 - mse: 0.6763 - mae: 0.5458 - val_loss: 0.5379 - val_mse: 0.6779 - val_mae: 0.5379
# Epoch 8/30000
#  - 10s - loss: 0.5330 - mse: 0.6544 - mae: 0.5330 - val_loss: 0.5206 - val_mse: 0.6408 - val_mae: 0.5206
# Epoch 9/30000
#  - 10s - loss: 0.5196 - mse: 0.6297 - mae: 0.5196 - val_loss: 0.5260 - val_mse: 0.6486 - val_mae: 0.5260
# Epoch 10/30000
#  - 10s - loss: 0.5123 - mse: 0.6158 - mae: 0.5123 - val_loss: 0.5044 - val_mse: 0.6083 - val_mae: 0.5044
# Epoch 11/30000
#  - 10s - loss: 0.5038 - mse: 0.5998 - mae: 0.5038 - val_loss: 0.4931 - val_mse: 0.5920 - val_mae: 0.4931
# Epoch 12/30000
#  - 10s - loss: 0.4947 - mse: 0.5833 - mae: 0.4947 - val_loss: 0.4944 - val_mse: 0.5928 - val_mae: 0.4944
# Epoch 13/30000
#  - 10s - loss: 0.4884 - mse: 0.5714 - mae: 0.4884 - val_loss: 0.4899 - val_mse: 0.5803 - val_mae: 0.4899
# Epoch 14/30000
#  - 10s - loss: 0.4820 - mse: 0.5601 - mae: 0.4820 - val_loss: 0.4897 - val_mse: 0.5761 - val_mae: 0.4897
# Epoch 15/30000
#  - 9s - loss: 0.4761 - mse: 0.5454 - mae: 0.4761 - val_loss: 0.4712 - val_mse: 0.5553 - val_mae: 0.4712
# Epoch 16/30000
#  - 10s - loss: 0.4653 - mse: 0.5263 - mae: 0.4653 - val_loss: 0.4619 - val_mse: 0.5377 - val_mae: 0.4619
# Epoch 17/30000
#  - 9s - loss: 0.4584 - mse: 0.5145 - mae: 0.4584 - val_loss: 0.4571 - val_mse: 0.5265 - val_mae: 0.4571
# Epoch 18/30000
#  - 9s - loss: 0.4536 - mse: 0.5068 - mae: 0.4536 - val_loss: 0.4572 - val_mse: 0.5234 - val_mae: 0.4572
# Epoch 19/30000
#  - 10s - loss: 0.4492 - mse: 0.4970 - mae: 0.4492 - val_loss: 0.4561 - val_mse: 0.5213 - val_mae: 0.4561
# Epoch 20/30000
#  - 10s - loss: 0.4422 - mse: 0.4861 - mae: 0.4422 - val_loss: 0.4404 - val_mse: 0.4949 - val_mae: 0.4404
# Epoch 21/30000
#  - 10s - loss: 0.4344 - mse: 0.4720 - mae: 0.4344 - val_loss: 0.4429 - val_mse: 0.4987 - val_mae: 0.4429
# Epoch 22/30000
#  - 10s - loss: 0.4317 - mse: 0.4661 - mae: 0.4317 - val_loss: 0.4360 - val_mse: 0.4836 - val_mae: 0.4360
# Epoch 23/30000
#  - 10s - loss: 0.4265 - mse: 0.4553 - mae: 0.4265 - val_loss: 0.4357 - val_mse: 0.4866 - val_mae: 0.4357
# Epoch 24/30000
#  - 10s - loss: 0.4207 - mse: 0.4495 - mae: 0.4207 - val_loss: 0.4279 - val_mse: 0.4736 - val_mae: 0.4279
# Epoch 25/30000
#  - 10s - loss: 0.4187 - mse: 0.4450 - mae: 0.4187 - val_loss: 0.4206 - val_mse: 0.4589 - val_mae: 0.4206
# Epoch 26/30000
#  - 10s - loss: 0.4120 - mse: 0.4331 - mae: 0.4120 - val_loss: 0.4241 - val_mse: 0.4675 - val_mae: 0.4241
# Epoch 27/30000
#  - 10s - loss: 0.4064 - mse: 0.4220 - mae: 0.4064 - val_loss: 0.4082 - val_mse: 0.4407 - val_mae: 0.4082
# Epoch 28/30000
#  - 10s - loss: 0.4051 - mse: 0.4184 - mae: 0.4051 - val_loss: 0.4070 - val_mse: 0.4411 - val_mae: 0.4070
# Epoch 29/30000
#  - 10s - loss: 0.3980 - mse: 0.4123 - mae: 0.3980 - val_loss: 0.4187 - val_mse: 0.4463 - val_mae: 0.4187
# Epoch 30/30000
#  - 10s - loss: 0.3930 - mse: 0.3985 - mae: 0.3930 - val_loss: 0.4060 - val_mse: 0.4337 - val_mae: 0.4060
# Epoch 31/30000
#  - 10s - loss: 0.3893 - mse: 0.3947 - mae: 0.3893 - val_loss: 0.4020 - val_mse: 0.4260 - val_mae: 0.4020
# Epoch 32/30000
#  - 10s - loss: 0.3882 - mse: 0.3891 - mae: 0.3882 - val_loss: 0.4045 - val_mse: 0.4285 - val_mae: 0.4045
# Epoch 33/30000
#  - 9s - loss: 0.3817 - mse: 0.3795 - mae: 0.3817 - val_loss: 0.3943 - val_mse: 0.4169 - val_mae: 0.3943
# Epoch 34/30000
#  - 9s - loss: 0.3789 - mse: 0.3736 - mae: 0.3789 - val_loss: 0.4007 - val_mse: 0.4205 - val_mae: 0.4007
# Epoch 35/30000
#  - 10s - loss: 0.3759 - mse: 0.3705 - mae: 0.3759 - val_loss: 0.3902 - val_mse: 0.4080 - val_mae: 0.3902
# Epoch 36/30000
#  - 10s - loss: 0.3736 - mse: 0.3663 - mae: 0.3736 - val_loss: 0.3889 - val_mse: 0.4043 - val_mae: 0.3889
# Epoch 37/30000
#  - 10s - loss: 0.3714 - mse: 0.3600 - mae: 0.3714 - val_loss: 0.3843 - val_mse: 0.3992 - val_mae: 0.3843
# Epoch 38/30000
#  - 10s - loss: 0.3652 - mse: 0.3505 - mae: 0.3652 - val_loss: 0.3812 - val_mse: 0.3956 - val_mae: 0.3812
# Epoch 39/30000
#  - 10s - loss: 0.3618 - mse: 0.3451 - mae: 0.3618 - val_loss: 0.3897 - val_mse: 0.4002 - val_mae: 0.3897
# Epoch 40/30000
#  - 10s - loss: 0.3618 - mse: 0.3453 - mae: 0.3618 - val_loss: 0.3803 - val_mse: 0.3887 - val_mae: 0.3803
# Epoch 41/30000
#  - 10s - loss: 0.3605 - mse: 0.3447 - mae: 0.3605 - val_loss: 0.3769 - val_mse: 0.3816 - val_mae: 0.3769
# Epoch 42/30000
#  - 10s - loss: 0.3597 - mse: 0.3433 - mae: 0.3597 - val_loss: 0.3750 - val_mse: 0.3800 - val_mae: 0.3750
# Epoch 43/30000
#  - 10s - loss: 0.3549 - mse: 0.3351 - mae: 0.3549 - val_loss: 0.3767 - val_mse: 0.3810 - val_mae: 0.3767
# Epoch 44/30000
#  - 10s - loss: 0.3500 - mse: 0.3262 - mae: 0.3500 - val_loss: 0.3686 - val_mse: 0.3699 - val_mae: 0.3686
# Epoch 45/30000
#  - 10s - loss: 0.3500 - mse: 0.3259 - mae: 0.3500 - val_loss: 0.3811 - val_mse: 0.3874 - val_mae: 0.3811
# Epoch 46/30000
#  - 10s - loss: 0.3460 - mse: 0.3208 - mae: 0.3460 - val_loss: 0.3712 - val_mse: 0.3736 - val_mae: 0.3712
# Epoch 47/30000
#  - 10s - loss: 0.3435 - mse: 0.3186 - mae: 0.3435 - val_loss: 0.3621 - val_mse: 0.3653 - val_mae: 0.3621
# Epoch 48/30000
#  - 10s - loss: 0.3410 - mse: 0.3136 - mae: 0.3410 - val_loss: 0.3575 - val_mse: 0.3567 - val_mae: 0.3575
# Epoch 49/30000
#  - 10s - loss: 0.3395 - mse: 0.3127 - mae: 0.3395 - val_loss: 0.3578 - val_mse: 0.3577 - val_mae: 0.3578
# Epoch 50/30000
#  - 10s - loss: 0.3379 - mse: 0.3082 - mae: 0.3379 - val_loss: 0.3664 - val_mse: 0.3586 - val_mae: 0.3664
# Epoch 51/30000
#  - 10s - loss: 0.3372 - mse: 0.3079 - mae: 0.3372 - val_loss: 0.3549 - val_mse: 0.3499 - val_mae: 0.3549
# Epoch 52/30000
#  - 10s - loss: 0.3353 - mse: 0.3024 - mae: 0.3353 - val_loss: 0.3601 - val_mse: 0.3525 - val_mae: 0.3601
# Epoch 53/30000
#  - 10s - loss: 0.3334 - mse: 0.3011 - mae: 0.3334 - val_loss: 0.3515 - val_mse: 0.3463 - val_mae: 0.3515
# Epoch 54/30000
#  - 10s - loss: 0.3296 - mse: 0.2939 - mae: 0.3296 - val_loss: 0.3519 - val_mse: 0.3470 - val_mae: 0.3519
# Epoch 55/30000
#  - 10s - loss: 0.3261 - mse: 0.2918 - mae: 0.3261 - val_loss: 0.3534 - val_mse: 0.3476 - val_mae: 0.3534
# Epoch 56/30000
#  - 10s - loss: 0.3266 - mse: 0.2924 - mae: 0.3266 - val_loss: 0.3540 - val_mse: 0.3460 - val_mae: 0.3540
# Epoch 57/30000
#  - 10s - loss: 0.3224 - mse: 0.2840 - mae: 0.3224 - val_loss: 0.3450 - val_mse: 0.3338 - val_mae: 0.3450
# Epoch 58/30000
#  - 10s - loss: 0.3205 - mse: 0.2832 - mae: 0.3205 - val_loss: 0.3517 - val_mse: 0.3417 - val_mae: 0.3517
# Epoch 59/30000
#  - 10s - loss: 0.3226 - mse: 0.2841 - mae: 0.3226 - val_loss: 0.3477 - val_mse: 0.3362 - val_mae: 0.3477
# Epoch 60/30000
#  - 10s - loss: 0.3226 - mse: 0.2847 - mae: 0.3226 - val_loss: 0.3435 - val_mse: 0.3306 - val_mae: 0.3435
# Epoch 61/30000
#  - 10s - loss: 0.3189 - mse: 0.2782 - mae: 0.3189 - val_loss: 0.3478 - val_mse: 0.3362 - val_mae: 0.3478
# Epoch 62/30000
#  - 10s - loss: 0.3184 - mse: 0.2800 - mae: 0.3184 - val_loss: 0.3502 - val_mse: 0.3370 - val_mae: 0.3502
# Epoch 63/30000
#  - 9s - loss: 0.3173 - mse: 0.2793 - mae: 0.3173 - val_loss: 0.3561 - val_mse: 0.3410 - val_mae: 0.3561
# Epoch 64/30000
#  - 10s - loss: 0.3131 - mse: 0.2699 - mae: 0.3131 - val_loss: 0.3539 - val_mse: 0.3377 - val_mae: 0.3539
# Epoch 65/30000
#  - 10s - loss: 0.3144 - mse: 0.2734 - mae: 0.3144 - val_loss: 0.3408 - val_mse: 0.3300 - val_mae: 0.3408
# Epoch 66/30000
#  - 10s - loss: 0.3118 - mse: 0.2680 - mae: 0.3118 - val_loss: 0.3424 - val_mse: 0.3292 - val_mae: 0.3424
# Epoch 67/30000
#  - 10s - loss: 0.3117 - mse: 0.2681 - mae: 0.3117 - val_loss: 0.3447 - val_mse: 0.3271 - val_mae: 0.3447
# Epoch 68/30000
#  - 10s - loss: 0.3075 - mse: 0.2619 - mae: 0.3075 - val_loss: 0.3481 - val_mse: 0.3331 - val_mae: 0.3481
# Epoch 69/30000
#  - 10s - loss: 0.3043 - mse: 0.2580 - mae: 0.3043 - val_loss: 0.3407 - val_mse: 0.3232 - val_mae: 0.3407
# Epoch 70/30000
#  - 10s - loss: 0.3043 - mse: 0.2576 - mae: 0.3043 - val_loss: 0.3496 - val_mse: 0.3318 - val_mae: 0.3496
# Epoch 71/30000
#  - 10s - loss: 0.3061 - mse: 0.2599 - mae: 0.3061 - val_loss: 0.3413 - val_mse: 0.3204 - val_mae: 0.3413
# Epoch 72/30000
#  - 10s - loss: 0.3014 - mse: 0.2536 - mae: 0.3014 - val_loss: 0.3392 - val_mse: 0.3208 - val_mae: 0.3392
# Epoch 73/30000
#  - 10s - loss: 0.3016 - mse: 0.2551 - mae: 0.3016 - val_loss: 0.3376 - val_mse: 0.3204 - val_mae: 0.3376
# Epoch 74/30000
#  - 10s - loss: 0.3005 - mse: 0.2519 - mae: 0.3005 - val_loss: 0.3353 - val_mse: 0.3147 - val_mae: 0.3353
# Epoch 75/30000
#  - 10s - loss: 0.2993 - mse: 0.2521 - mae: 0.2993 - val_loss: 0.3375 - val_mse: 0.3212 - val_mae: 0.3375
# Epoch 76/30000
#  - 10s - loss: 0.2976 - mse: 0.2488 - mae: 0.2976 - val_loss: 0.3364 - val_mse: 0.3158 - val_mae: 0.3364
# Epoch 77/30000
#  - 10s - loss: 0.2961 - mse: 0.2457 - mae: 0.2961 - val_loss: 0.3483 - val_mse: 0.3291 - val_mae: 0.3483
# Epoch 78/30000
#  - 10s - loss: 0.2945 - mse: 0.2458 - mae: 0.2945 - val_loss: 0.3366 - val_mse: 0.3222 - val_mae: 0.3366
# Epoch 79/30000
#  - 10s - loss: 0.2975 - mse: 0.2457 - mae: 0.2975 - val_loss: 0.3370 - val_mse: 0.3131 - val_mae: 0.3370
# Epoch 80/30000
#  - 10s - loss: 0.2965 - mse: 0.2461 - mae: 0.2965 - val_loss: 0.3273 - val_mse: 0.3054 - val_mae: 0.3273
# Epoch 81/30000
#  - 10s - loss: 0.2942 - mse: 0.2444 - mae: 0.2942 - val_loss: 0.3253 - val_mse: 0.3065 - val_mae: 0.3253
# Epoch 82/30000
#  - 10s - loss: 0.2902 - mse: 0.2354 - mae: 0.2902 - val_loss: 0.3345 - val_mse: 0.3115 - val_mae: 0.3345
# Epoch 83/30000
#  - 10s - loss: 0.2885 - mse: 0.2355 - mae: 0.2885 - val_loss: 0.3229 - val_mse: 0.2985 - val_mae: 0.3229
# Epoch 84/30000
#  - 10s - loss: 0.2909 - mse: 0.2383 - mae: 0.2909 - val_loss: 0.3326 - val_mse: 0.3089 - val_mae: 0.3326
# Epoch 85/30000
#  - 10s - loss: 0.2898 - mse: 0.2358 - mae: 0.2898 - val_loss: 0.3258 - val_mse: 0.3023 - val_mae: 0.3258
# Epoch 86/30000
#  - 10s - loss: 0.2879 - mse: 0.2322 - mae: 0.2879 - val_loss: 0.3287 - val_mse: 0.3043 - val_mae: 0.3287
# Epoch 87/30000
#  - 10s - loss: 0.2871 - mse: 0.2314 - mae: 0.2871 - val_loss: 0.3296 - val_mse: 0.3031 - val_mae: 0.3296
# Epoch 88/30000
#  - 10s - loss: 0.2852 - mse: 0.2316 - mae: 0.2852 - val_loss: 0.3276 - val_mse: 0.3033 - val_mae: 0.3276
# Epoch 89/30000
#  - 10s - loss: 0.2854 - mse: 0.2293 - mae: 0.2854 - val_loss: 0.3207 - val_mse: 0.2928 - val_mae: 0.3207
# Epoch 90/30000
#  - 10s - loss: 0.2819 - mse: 0.2263 - mae: 0.2819 - val_loss: 0.3229 - val_mse: 0.2933 - val_mae: 0.3229
# Epoch 91/30000
#  - 10s - loss: 0.2829 - mse: 0.2271 - mae: 0.2829 - val_loss: 0.3211 - val_mse: 0.2940 - val_mae: 0.3211
# Epoch 92/30000
#  - 10s - loss: 0.2853 - mse: 0.2304 - mae: 0.2853 - val_loss: 0.3236 - val_mse: 0.2979 - val_mae: 0.3236
# Epoch 93/30000
#  - 10s - loss: 0.2816 - mse: 0.2232 - mae: 0.2816 - val_loss: 0.3221 - val_mse: 0.2973 - val_mae: 0.3221
# Epoch 94/30000
#  - 10s - loss: 0.2800 - mse: 0.2246 - mae: 0.2800 - val_loss: 0.3240 - val_mse: 0.2995 - val_mae: 0.3240
# Epoch 95/30000
#  - 10s - loss: 0.2786 - mse: 0.2212 - mae: 0.2786 - val_loss: 0.3248 - val_mse: 0.2991 - val_mae: 0.3248
# Epoch 96/30000
#  - 10s - loss: 0.2819 - mse: 0.2244 - mae: 0.2819 - val_loss: 0.3226 - val_mse: 0.2955 - val_mae: 0.3226
# Epoch 97/30000
#  - 10s - loss: 0.2794 - mse: 0.2202 - mae: 0.2794 - val_loss: 0.3201 - val_mse: 0.2924 - val_mae: 0.3201
# Epoch 98/30000
#  - 10s - loss: 0.2772 - mse: 0.2196 - mae: 0.2772 - val_loss: 0.3191 - val_mse: 0.2924 - val_mae: 0.3191
# Epoch 99/30000
#  - 10s - loss: 0.2780 - mse: 0.2190 - mae: 0.2780 - val_loss: 0.3195 - val_mse: 0.2928 - val_mae: 0.3195
# Epoch 100/30000
#  - 10s - loss: 0.2786 - mse: 0.2216 - mae: 0.2786 - val_loss: 0.3127 - val_mse: 0.2846 - val_mae: 0.3127
# Epoch 101/30000
#  - 10s - loss: 0.2752 - mse: 0.2168 - mae: 0.2752 - val_loss: 0.3173 - val_mse: 0.2918 - val_mae: 0.3173
# Epoch 102/30000
#  - 10s - loss: 0.2765 - mse: 0.2177 - mae: 0.2765 - val_loss: 0.3268 - val_mse: 0.2979 - val_mae: 0.3268
# Epoch 103/30000
#  - 10s - loss: 0.2753 - mse: 0.2155 - mae: 0.2753 - val_loss: 0.3162 - val_mse: 0.2885 - val_mae: 0.3162
# Epoch 104/30000
#  - 10s - loss: 0.2728 - mse: 0.2134 - mae: 0.2728 - val_loss: 0.3357 - val_mse: 0.3076 - val_mae: 0.3357
# Epoch 105/30000
#  - 10s - loss: 0.2739 - mse: 0.2129 - mae: 0.2739 - val_loss: 0.3258 - val_mse: 0.2947 - val_mae: 0.3258
# Epoch 106/30000
#  - 10s - loss: 0.2722 - mse: 0.2097 - mae: 0.2722 - val_loss: 0.3151 - val_mse: 0.2845 - val_mae: 0.3151
# Epoch 107/30000
#  - 10s - loss: 0.2715 - mse: 0.2132 - mae: 0.2715 - val_loss: 0.3212 - val_mse: 0.2913 - val_mae: 0.3212
# Epoch 108/30000
#  - 10s - loss: 0.2683 - mse: 0.2085 - mae: 0.2683 - val_loss: 0.3225 - val_mse: 0.2905 - val_mae: 0.3225
# Epoch 109/30000
#  - 10s - loss: 0.2692 - mse: 0.2068 - mae: 0.2692 - val_loss: 0.3218 - val_mse: 0.2953 - val_mae: 0.3218
# Epoch 110/30000
#  - 10s - loss: 0.2686 - mse: 0.2060 - mae: 0.2686 - val_loss: 0.3133 - val_mse: 0.2803 - val_mae: 0.3133
# Epoch 111/30000
#  - 10s - loss: 0.2690 - mse: 0.2073 - mae: 0.2690 - val_loss: 0.3186 - val_mse: 0.2887 - val_mae: 0.3186
# Epoch 112/30000
#  - 10s - loss: 0.2668 - mse: 0.2065 - mae: 0.2668 - val_loss: 0.3227 - val_mse: 0.2904 - val_mae: 0.3227
# Epoch 113/30000
#  - 10s - loss: 0.2674 - mse: 0.2066 - mae: 0.2674 - val_loss: 0.3143 - val_mse: 0.2866 - val_mae: 0.3143
# Epoch 114/30000
#  - 10s - loss: 0.2698 - mse: 0.2095 - mae: 0.2698 - val_loss: 0.3106 - val_mse: 0.2798 - val_mae: 0.3106
# Epoch 115/30000
#  - 10s - loss: 0.2677 - mse: 0.2057 - mae: 0.2677 - val_loss: 0.3114 - val_mse: 0.2809 - val_mae: 0.3114
# Epoch 116/30000
#  - 10s - loss: 0.2652 - mse: 0.2033 - mae: 0.2652 - val_loss: 0.3121 - val_mse: 0.2815 - val_mae: 0.3121
# Epoch 117/30000
#  - 10s - loss: 0.2614 - mse: 0.1987 - mae: 0.2614 - val_loss: 0.3104 - val_mse: 0.2773 - val_mae: 0.3104
# Epoch 118/30000
#  - 10s - loss: 0.2635 - mse: 0.2005 - mae: 0.2635 - val_loss: 0.3135 - val_mse: 0.2822 - val_mae: 0.3135
# Epoch 119/30000
#  - 10s - loss: 0.2633 - mse: 0.2003 - mae: 0.2633 - val_loss: 0.3083 - val_mse: 0.2744 - val_mae: 0.3083
# Epoch 120/30000
#  - 10s - loss: 0.2627 - mse: 0.1992 - mae: 0.2627 - val_loss: 0.3094 - val_mse: 0.2776 - val_mae: 0.3094
# Epoch 121/30000
#  - 10s - loss: 0.2619 - mse: 0.1980 - mae: 0.2619 - val_loss: 0.3210 - val_mse: 0.2895 - val_mae: 0.3210
# Epoch 122/30000
#  - 10s - loss: 0.2609 - mse: 0.1980 - mae: 0.2609 - val_loss: 0.3149 - val_mse: 0.2806 - val_mae: 0.3149
# Epoch 123/30000
#  - 10s - loss: 0.2595 - mse: 0.1960 - mae: 0.2595 - val_loss: 0.3157 - val_mse: 0.2846 - val_mae: 0.3157
# Epoch 124/30000
#  - 10s - loss: 0.2592 - mse: 0.1954 - mae: 0.2592 - val_loss: 0.3113 - val_mse: 0.2802 - val_mae: 0.3113
# Epoch 125/30000
#  - 10s - loss: 0.2568 - mse: 0.1929 - mae: 0.2568 - val_loss: 0.3175 - val_mse: 0.2849 - val_mae: 0.3175
# Epoch 126/30000
#  - 10s - loss: 0.2585 - mse: 0.1946 - mae: 0.2585 - val_loss: 0.3149 - val_mse: 0.2807 - val_mae: 0.3149
# Epoch 127/30000
#  - 10s - loss: 0.2598 - mse: 0.1958 - mae: 0.2598 - val_loss: 0.3191 - val_mse: 0.2877 - val_mae: 0.3191
# Epoch 128/30000
#  - 10s - loss: 0.2579 - mse: 0.1945 - mae: 0.2579 - val_loss: 0.3148 - val_mse: 0.2825 - val_mae: 0.3148
# Epoch 129/30000
#  - 10s - loss: 0.2569 - mse: 0.1924 - mae: 0.2569 - val_loss: 0.3088 - val_mse: 0.2794 - val_mae: 0.3088
# Epoch 130/30000
#  - 10s - loss: 0.2544 - mse: 0.1890 - mae: 0.2544 - val_loss: 0.3072 - val_mse: 0.2722 - val_mae: 0.3072
# Epoch 131/30000
#  - 10s - loss: 0.2537 - mse: 0.1874 - mae: 0.2537 - val_loss: 0.3152 - val_mse: 0.2820 - val_mae: 0.3152
# Epoch 132/30000
#  - 10s - loss: 0.2568 - mse: 0.1920 - mae: 0.2568 - val_loss: 0.3060 - val_mse: 0.2716 - val_mae: 0.3060
# Epoch 133/30000
#  - 10s - loss: 0.2509 - mse: 0.1860 - mae: 0.2509 - val_loss: 0.3117 - val_mse: 0.2764 - val_mae: 0.3117
# Epoch 134/30000
#  - 10s - loss: 0.2544 - mse: 0.1905 - mae: 0.2544 - val_loss: 0.3085 - val_mse: 0.2731 - val_mae: 0.3085
# Epoch 135/30000
#  - 10s - loss: 0.2559 - mse: 0.1918 - mae: 0.2559 - val_loss: 0.3033 - val_mse: 0.2665 - val_mae: 0.3033
# Epoch 136/30000
#  - 10s - loss: 0.2520 - mse: 0.1870 - mae: 0.2520 - val_loss: 0.3046 - val_mse: 0.2708 - val_mae: 0.3046
# Epoch 137/30000
#  - 10s - loss: 0.2533 - mse: 0.1846 - mae: 0.2533 - val_loss: 0.3091 - val_mse: 0.2758 - val_mae: 0.3091
# Epoch 138/30000
#  - 10s - loss: 0.2526 - mse: 0.1875 - mae: 0.2526 - val_loss: 0.3056 - val_mse: 0.2745 - val_mae: 0.3056
# Epoch 139/30000
#  - 10s - loss: 0.2532 - mse: 0.1880 - mae: 0.2532 - val_loss: 0.3190 - val_mse: 0.2852 - val_mae: 0.3190
# Epoch 140/30000
#  - 10s - loss: 0.2521 - mse: 0.1862 - mae: 0.2521 - val_loss: 0.3049 - val_mse: 0.2706 - val_mae: 0.3049
# Epoch 141/30000
#  - 10s - loss: 0.2528 - mse: 0.1881 - mae: 0.2528 - val_loss: 0.3067 - val_mse: 0.2742 - val_mae: 0.3067
# Epoch 142/30000
#  - 10s - loss: 0.2524 - mse: 0.1855 - mae: 0.2524 - val_loss: 0.3165 - val_mse: 0.2833 - val_mae: 0.3165
# Epoch 143/30000
#  - 10s - loss: 0.2521 - mse: 0.1849 - mae: 0.2521 - val_loss: 0.3115 - val_mse: 0.2789 - val_mae: 0.3115
# Epoch 144/30000
#  - 10s - loss: 0.2484 - mse: 0.1801 - mae: 0.2484 - val_loss: 0.3118 - val_mse: 0.2757 - val_mae: 0.3118
# Epoch 145/30000
#  - 10s - loss: 0.2477 - mse: 0.1802 - mae: 0.2477 - val_loss: 0.3116 - val_mse: 0.2786 - val_mae: 0.3116
# Epoch 146/30000
#  - 10s - loss: 0.2474 - mse: 0.1827 - mae: 0.2474 - val_loss: 0.3047 - val_mse: 0.2704 - val_mae: 0.3047
# Epoch 147/30000
#  - 10s - loss: 0.2472 - mse: 0.1805 - mae: 0.2472 - val_loss: 0.3064 - val_mse: 0.2741 - val_mae: 0.3064
# Epoch 148/30000
#  - 10s - loss: 0.2492 - mse: 0.1827 - mae: 0.2492 - val_loss: 0.3068 - val_mse: 0.2694 - val_mae: 0.3068
# Epoch 149/30000
#  - 10s - loss: 0.2483 - mse: 0.1820 - mae: 0.2483 - val_loss: 0.3113 - val_mse: 0.2746 - val_mae: 0.3113
# Epoch 150/30000
#  - 10s - loss: 0.2483 - mse: 0.1815 - mae: 0.2483 - val_loss: 0.3054 - val_mse: 0.2704 - val_mae: 0.3054
# Epoch 151/30000
#  - 10s - loss: 0.2465 - mse: 0.1799 - mae: 0.2465 - val_loss: 0.3120 - val_mse: 0.2799 - val_mae: 0.3120
# Epoch 152/30000
#  - 10s - loss: 0.2475 - mse: 0.1803 - mae: 0.2475 - val_loss: 0.3046 - val_mse: 0.2689 - val_mae: 0.3046
# Epoch 153/30000
#  - 10s - loss: 0.2471 - mse: 0.1795 - mae: 0.2471 - val_loss: 0.3013 - val_mse: 0.2660 - val_mae: 0.3013
# Epoch 154/30000
#  - 10s - loss: 0.2455 - mse: 0.1791 - mae: 0.2455 - val_loss: 0.3015 - val_mse: 0.2659 - val_mae: 0.3015
# Epoch 155/30000
#  - 10s - loss: 0.2463 - mse: 0.1790 - mae: 0.2463 - val_loss: 0.3043 - val_mse: 0.2684 - val_mae: 0.3043
# Epoch 156/30000
#  - 10s - loss: 0.2427 - mse: 0.1745 - mae: 0.2427 - val_loss: 0.3007 - val_mse: 0.2671 - val_mae: 0.3007
# Epoch 157/30000
#  - 9s - loss: 0.2446 - mse: 0.1754 - mae: 0.2446 - val_loss: 0.3056 - val_mse: 0.2686 - val_mae: 0.3056
# Epoch 158/30000
#  - 10s - loss: 0.2462 - mse: 0.1788 - mae: 0.2462 - val_loss: 0.3046 - val_mse: 0.2661 - val_mae: 0.3046
# Epoch 159/30000
#  - 10s - loss: 0.2437 - mse: 0.1765 - mae: 0.2437 - val_loss: 0.3012 - val_mse: 0.2650 - val_mae: 0.3012
# Epoch 160/30000
#  - 10s - loss: 0.2453 - mse: 0.1778 - mae: 0.2453 - val_loss: 0.3123 - val_mse: 0.2747 - val_mae: 0.3123
# Epoch 161/30000
#  - 10s - loss: 0.2445 - mse: 0.1745 - mae: 0.2445 - val_loss: 0.3041 - val_mse: 0.2668 - val_mae: 0.3041
# Epoch 162/30000
#  - 10s - loss: 0.2419 - mse: 0.1734 - mae: 0.2419 - val_loss: 0.3101 - val_mse: 0.2717 - val_mae: 0.3101
# Epoch 163/30000
#  - 10s - loss: 0.2436 - mse: 0.1748 - mae: 0.2436 - val_loss: 0.3009 - val_mse: 0.2637 - val_mae: 0.3009
# Epoch 164/30000
#  - 10s - loss: 0.2415 - mse: 0.1735 - mae: 0.2415 - val_loss: 0.3062 - val_mse: 0.2683 - val_mae: 0.3062
# Epoch 165/30000
#  - 9s - loss: 0.2401 - mse: 0.1705 - mae: 0.2401 - val_loss: 0.3108 - val_mse: 0.2734 - val_mae: 0.3108
# Epoch 166/30000
#  - 10s - loss: 0.2422 - mse: 0.1739 - mae: 0.2422 - val_loss: 0.3075 - val_mse: 0.2714 - val_mae: 0.3075
# Epoch 167/30000
#  - 9s - loss: 0.2412 - mse: 0.1729 - mae: 0.2412 - val_loss: 0.3096 - val_mse: 0.2712 - val_mae: 0.3096
# Epoch 168/30000
#  - 10s - loss: 0.2390 - mse: 0.1706 - mae: 0.2390 - val_loss: 0.3066 - val_mse: 0.2672 - val_mae: 0.3066
# Epoch 169/30000
#  - 10s - loss: 0.2414 - mse: 0.1714 - mae: 0.2414 - val_loss: 0.3106 - val_mse: 0.2752 - val_mae: 0.3106
# Epoch 170/30000
#  - 9s - loss: 0.2421 - mse: 0.1723 - mae: 0.2421 - val_loss: 0.2975 - val_mse: 0.2589 - val_mae: 0.2975
# Epoch 171/30000
#  - 10s - loss: 0.2407 - mse: 0.1723 - mae: 0.2407 - val_loss: 0.3047 - val_mse: 0.2665 - val_mae: 0.3047
# Epoch 172/30000
#  - 10s - loss: 0.2407 - mse: 0.1692 - mae: 0.2407 - val_loss: 0.3006 - val_mse: 0.2632 - val_mae: 0.3006
# Epoch 173/30000
#  - 10s - loss: 0.2360 - mse: 0.1654 - mae: 0.2360 - val_loss: 0.2958 - val_mse: 0.2565 - val_mae: 0.2958
# Epoch 174/30000
#  - 10s - loss: 0.2362 - mse: 0.1665 - mae: 0.2362 - val_loss: 0.3038 - val_mse: 0.2633 - val_mae: 0.3038
# Epoch 175/30000
#  - 10s - loss: 0.2397 - mse: 0.1696 - mae: 0.2397 - val_loss: 0.3093 - val_mse: 0.2717 - val_mae: 0.3093
# Epoch 176/30000
#  - 10s - loss: 0.2397 - mse: 0.1688 - mae: 0.2397 - val_loss: 0.3002 - val_mse: 0.2641 - val_mae: 0.3002
# Epoch 177/30000
#  - 10s - loss: 0.2380 - mse: 0.1677 - mae: 0.2380 - val_loss: 0.3066 - val_mse: 0.2690 - val_mae: 0.3066
# Epoch 178/30000
#  - 10s - loss: 0.2369 - mse: 0.1684 - mae: 0.2369 - val_loss: 0.3090 - val_mse: 0.2708 - val_mae: 0.3090
# Epoch 179/30000
#  - 10s - loss: 0.2377 - mse: 0.1683 - mae: 0.2377 - val_loss: 0.2995 - val_mse: 0.2605 - val_mae: 0.2995
# Epoch 180/30000
#  - 10s - loss: 0.2325 - mse: 0.1614 - mae: 0.2325 - val_loss: 0.3074 - val_mse: 0.2668 - val_mae: 0.3074
# Epoch 181/30000
#  - 10s - loss: 0.2365 - mse: 0.1660 - mae: 0.2365 - val_loss: 0.2996 - val_mse: 0.2585 - val_mae: 0.2996
# Epoch 182/30000
#  - 10s - loss: 0.2353 - mse: 0.1660 - mae: 0.2353 - val_loss: 0.3086 - val_mse: 0.2703 - val_mae: 0.3086
# Epoch 183/30000
#  - 10s - loss: 0.2393 - mse: 0.1689 - mae: 0.2393 - val_loss: 0.3042 - val_mse: 0.2654 - val_mae: 0.3042
# Epoch 184/30000
#  - 10s - loss: 0.2366 - mse: 0.1656 - mae: 0.2366 - val_loss: 0.3054 - val_mse: 0.2684 - val_mae: 0.3054
# Epoch 185/30000
#  - 10s - loss: 0.2375 - mse: 0.1671 - mae: 0.2375 - val_loss: 0.3011 - val_mse: 0.2630 - val_mae: 0.3011
# Epoch 186/30000
#  - 10s - loss: 0.2368 - mse: 0.1643 - mae: 0.2368 - val_loss: 0.2973 - val_mse: 0.2563 - val_mae: 0.2973
# Epoch 187/30000
#  - 10s - loss: 0.2348 - mse: 0.1627 - mae: 0.2348 - val_loss: 0.3031 - val_mse: 0.2609 - val_mae: 0.3031
# Epoch 188/30000
#  - 10s - loss: 0.2331 - mse: 0.1622 - mae: 0.2331 - val_loss: 0.3024 - val_mse: 0.2634 - val_mae: 0.3024
# Epoch 189/30000
#  - 10s - loss: 0.2358 - mse: 0.1640 - mae: 0.2358 - val_loss: 0.3065 - val_mse: 0.2656 - val_mae: 0.3065
# Epoch 190/30000
#  - 10s - loss: 0.2335 - mse: 0.1618 - mae: 0.2335 - val_loss: 0.2948 - val_mse: 0.2553 - val_mae: 0.2948
# Epoch 191/30000
#  - 10s - loss: 0.2318 - mse: 0.1596 - mae: 0.2318 - val_loss: 0.3008 - val_mse: 0.2617 - val_mae: 0.3008
# Epoch 192/30000
#  - 10s - loss: 0.2308 - mse: 0.1596 - mae: 0.2308 - val_loss: 0.2997 - val_mse: 0.2584 - val_mae: 0.2997
# Epoch 193/30000
#  - 10s - loss: 0.2350 - mse: 0.1621 - mae: 0.2350 - val_loss: 0.3090 - val_mse: 0.2695 - val_mae: 0.3090
# Epoch 194/30000
#  - 10s - loss: 0.2322 - mse: 0.1611 - mae: 0.2322 - val_loss: 0.3064 - val_mse: 0.2705 - val_mae: 0.3064
# Epoch 195/30000
#  - 10s - loss: 0.2339 - mse: 0.1621 - mae: 0.2339 - val_loss: 0.2989 - val_mse: 0.2587 - val_mae: 0.2989
# Epoch 196/30000
#  - 10s - loss: 0.2307 - mse: 0.1581 - mae: 0.2307 - val_loss: 0.2935 - val_mse: 0.2575 - val_mae: 0.2935
# Epoch 197/30000
#  - 10s - loss: 0.2325 - mse: 0.1611 - mae: 0.2325 - val_loss: 0.2981 - val_mse: 0.2590 - val_mae: 0.2981
# Epoch 198/30000
#  - 10s - loss: 0.2304 - mse: 0.1585 - mae: 0.2304 - val_loss: 0.2986 - val_mse: 0.2629 - val_mae: 0.2986
# Epoch 199/30000
#  - 10s - loss: 0.2305 - mse: 0.1593 - mae: 0.2305 - val_loss: 0.3018 - val_mse: 0.2622 - val_mae: 0.3018
# Epoch 200/30000
#  - 10s - loss: 0.2295 - mse: 0.1567 - mae: 0.2295 - val_loss: 0.3055 - val_mse: 0.2665 - val_mae: 0.3055
# Epoch 201/30000
#  - 10s - loss: 0.2313 - mse: 0.1595 - mae: 0.2313 - val_loss: 0.2954 - val_mse: 0.2536 - val_mae: 0.2954
# Epoch 202/30000
#  - 10s - loss: 0.2299 - mse: 0.1577 - mae: 0.2299 - val_loss: 0.3014 - val_mse: 0.2626 - val_mae: 0.3014
# Epoch 203/30000
#  - 9s - loss: 0.2316 - mse: 0.1593 - mae: 0.2316 - val_loss: 0.2992 - val_mse: 0.2583 - val_mae: 0.2992
# Epoch 204/30000
#  - 10s - loss: 0.2329 - mse: 0.1607 - mae: 0.2329 - val_loss: 0.3025 - val_mse: 0.2619 - val_mae: 0.3025
# Epoch 205/30000
#  - 9s - loss: 0.2280 - mse: 0.1553 - mae: 0.2280 - val_loss: 0.2947 - val_mse: 0.2530 - val_mae: 0.2947
# Epoch 206/30000
#  - 10s - loss: 0.2297 - mse: 0.1562 - mae: 0.2297 - val_loss: 0.2996 - val_mse: 0.2575 - val_mae: 0.2996
# Epoch 207/30000
#  - 9s - loss: 0.2289 - mse: 0.1569 - mae: 0.2289 - val_loss: 0.2965 - val_mse: 0.2513 - val_mae: 0.2965
# Epoch 208/30000
#  - 10s - loss: 0.2296 - mse: 0.1535 - mae: 0.2296 - val_loss: 0.2961 - val_mse: 0.2542 - val_mae: 0.2961
# Epoch 209/30000
#  - 10s - loss: 0.2257 - mse: 0.1510 - mae: 0.2257 - val_loss: 0.3021 - val_mse: 0.2595 - val_mae: 0.3021
# Epoch 210/30000
#  - 10s - loss: 0.2270 - mse: 0.1530 - mae: 0.2270 - val_loss: 0.2950 - val_mse: 0.2493 - val_mae: 0.2950
# Epoch 211/30000
#  - 10s - loss: 0.2300 - mse: 0.1585 - mae: 0.2300 - val_loss: 0.3033 - val_mse: 0.2635 - val_mae: 0.3033
# Epoch 212/30000
#  - 10s - loss: 0.2275 - mse: 0.1543 - mae: 0.2275 - val_loss: 0.3038 - val_mse: 0.2608 - val_mae: 0.3038
# Epoch 213/30000
#  - 10s - loss: 0.2292 - mse: 0.1538 - mae: 0.2292 - val_loss: 0.2945 - val_mse: 0.2532 - val_mae: 0.2945
# Epoch 214/30000
#  - 10s - loss: 0.2282 - mse: 0.1528 - mae: 0.2282 - val_loss: 0.3001 - val_mse: 0.2573 - val_mae: 0.3001
# Epoch 215/30000
#  - 10s - loss: 0.2260 - mse: 0.1521 - mae: 0.2260 - val_loss: 0.2982 - val_mse: 0.2556 - val_mae: 0.2982
# Epoch 216/30000
#  - 10s - loss: 0.2278 - mse: 0.1518 - mae: 0.2278 - val_loss: 0.2935 - val_mse: 0.2497 - val_mae: 0.2935
# Epoch 217/30000
#  - 10s - loss: 0.2277 - mse: 0.1558 - mae: 0.2277 - val_loss: 0.3042 - val_mse: 0.2641 - val_mae: 0.3042
# Epoch 218/30000
#  - 9s - loss: 0.2272 - mse: 0.1539 - mae: 0.2272 - val_loss: 0.2976 - val_mse: 0.2542 - val_mae: 0.2976
# Epoch 219/30000
#  - 9s - loss: 0.2256 - mse: 0.1514 - mae: 0.2256 - val_loss: 0.2956 - val_mse: 0.2557 - val_mae: 0.2956
# Epoch 220/30000
#  - 10s - loss: 0.2242 - mse: 0.1499 - mae: 0.2242 - val_loss: 0.2941 - val_mse: 0.2539 - val_mae: 0.2941
# Epoch 221/30000
#  - 9s - loss: 0.2240 - mse: 0.1499 - mae: 0.2240 - val_loss: 0.3068 - val_mse: 0.2679 - val_mae: 0.3068
# Epoch 222/30000
#  - 9s - loss: 0.2246 - mse: 0.1523 - mae: 0.2246 - val_loss: 0.2975 - val_mse: 0.2576 - val_mae: 0.2975
# Epoch 223/30000
#  - 10s - loss: 0.2238 - mse: 0.1488 - mae: 0.2238 - val_loss: 0.2991 - val_mse: 0.2576 - val_mae: 0.2991
# Epoch 224/30000
#  - 10s - loss: 0.2257 - mse: 0.1522 - mae: 0.2257 - val_loss: 0.3018 - val_mse: 0.2582 - val_mae: 0.3018
# Epoch 225/30000
#  - 10s - loss: 0.2247 - mse: 0.1528 - mae: 0.2247 - val_loss: 0.2976 - val_mse: 0.2561 - val_mae: 0.2976
# Epoch 226/30000
#  - 10s - loss: 0.2234 - mse: 0.1498 - mae: 0.2234 - val_loss: 0.2942 - val_mse: 0.2490 - val_mae: 0.2942
# Epoch 227/30000
#  - 10s - loss: 0.2262 - mse: 0.1521 - mae: 0.2262 - val_loss: 0.2968 - val_mse: 0.2541 - val_mae: 0.2968
# Epoch 228/30000
#  - 10s - loss: 0.2253 - mse: 0.1504 - mae: 0.2253 - val_loss: 0.3058 - val_mse: 0.2640 - val_mae: 0.3058
# Epoch 229/30000
#  - 10s - loss: 0.2248 - mse: 0.1503 - mae: 0.2248 - val_loss: 0.2994 - val_mse: 0.2560 - val_mae: 0.2994
# Epoch 230/30000
#  - 10s - loss: 0.2235 - mse: 0.1494 - mae: 0.2235 - val_loss: 0.2998 - val_mse: 0.2572 - val_mae: 0.2998
# Epoch 231/30000
#  - 10s - loss: 0.2222 - mse: 0.1478 - mae: 0.2222 - val_loss: 0.2979 - val_mse: 0.2536 - val_mae: 0.2979
# Epoch 232/30000
#  - 10s - loss: 0.2223 - mse: 0.1449 - mae: 0.2223 - val_loss: 0.2926 - val_mse: 0.2493 - val_mae: 0.2926
# Epoch 233/30000
#  - 10s - loss: 0.2204 - mse: 0.1436 - mae: 0.2204 - val_loss: 0.3038 - val_mse: 0.2590 - val_mae: 0.3038
# Epoch 234/30000
#  - 10s - loss: 0.2252 - mse: 0.1483 - mae: 0.2252 - val_loss: 0.3027 - val_mse: 0.2578 - val_mae: 0.3027
# Epoch 235/30000
#  - 9s - loss: 0.2221 - mse: 0.1443 - mae: 0.2221 - val_loss: 0.2964 - val_mse: 0.2518 - val_mae: 0.2964
# Epoch 236/30000
#  - 10s - loss: 0.2223 - mse: 0.1476 - mae: 0.2223 - val_loss: 0.2956 - val_mse: 0.2494 - val_mae: 0.2956
# Epoch 237/30000
#  - 10s - loss: 0.2221 - mse: 0.1476 - mae: 0.2221 - val_loss: 0.2996 - val_mse: 0.2564 - val_mae: 0.2996
# Epoch 238/30000
#  - 9s - loss: 0.2193 - mse: 0.1449 - mae: 0.2193 - val_loss: 0.3009 - val_mse: 0.2570 - val_mae: 0.3009
# Epoch 239/30000
#  - 10s - loss: 0.2215 - mse: 0.1456 - mae: 0.2215 - val_loss: 0.2985 - val_mse: 0.2541 - val_mae: 0.2985
# Epoch 240/30000
#  - 9s - loss: 0.2216 - mse: 0.1477 - mae: 0.2216 - val_loss: 0.2939 - val_mse: 0.2500 - val_mae: 0.2939
# Epoch 241/30000
#  - 10s - loss: 0.2225 - mse: 0.1475 - mae: 0.2225 - val_loss: 0.2963 - val_mse: 0.2537 - val_mae: 0.2963
# Epoch 242/30000
#  - 9s - loss: 0.2210 - mse: 0.1453 - mae: 0.2210 - val_loss: 0.2960 - val_mse: 0.2540 - val_mae: 0.2960
# Epoch 243/30000
#  - 10s - loss: 0.2214 - mse: 0.1442 - mae: 0.2214 - val_loss: 0.2959 - val_mse: 0.2532 - val_mae: 0.2959
# Epoch 244/30000
#  - 10s - loss: 0.2217 - mse: 0.1441 - mae: 0.2217 - val_loss: 0.2968 - val_mse: 0.2525 - val_mae: 0.2968
# Epoch 245/30000
#  - 10s - loss: 0.2205 - mse: 0.1433 - mae: 0.2205 - val_loss: 0.3039 - val_mse: 0.2586 - val_mae: 0.3039
# Epoch 246/30000
#  - 10s - loss: 0.2204 - mse: 0.1442 - mae: 0.2204 - val_loss: 0.3018 - val_mse: 0.2581 - val_mae: 0.3018
# Epoch 247/30000
#  - 10s - loss: 0.2186 - mse: 0.1419 - mae: 0.2186 - val_loss: 0.2899 - val_mse: 0.2467 - val_mae: 0.2899
# Epoch 248/30000
#  - 10s - loss: 0.2200 - mse: 0.1443 - mae: 0.2200 - val_loss: 0.2949 - val_mse: 0.2500 - val_mae: 0.2949
# Epoch 249/30000
#  - 10s - loss: 0.2188 - mse: 0.1409 - mae: 0.2188 - val_loss: 0.2958 - val_mse: 0.2514 - val_mae: 0.2958
# Epoch 250/30000
#  - 10s - loss: 0.2212 - mse: 0.1457 - mae: 0.2212 - val_loss: 0.2948 - val_mse: 0.2499 - val_mae: 0.2948
# Epoch 251/30000
#  - 10s - loss: 0.2187 - mse: 0.1410 - mae: 0.2187 - val_loss: 0.2975 - val_mse: 0.2509 - val_mae: 0.2975
# Epoch 252/30000
#  - 9s - loss: 0.2191 - mse: 0.1424 - mae: 0.2191 - val_loss: 0.2936 - val_mse: 0.2487 - val_mae: 0.2936
# Epoch 253/30000
#  - 10s - loss: 0.2221 - mse: 0.1463 - mae: 0.2221 - val_loss: 0.3068 - val_mse: 0.2598 - val_mae: 0.3068
# Epoch 254/30000
#  - 10s - loss: 0.2185 - mse: 0.1408 - mae: 0.2185 - val_loss: 0.2897 - val_mse: 0.2448 - val_mae: 0.2897
# Epoch 255/30000
#  - 9s - loss: 0.2208 - mse: 0.1457 - mae: 0.2208 - val_loss: 0.2936 - val_mse: 0.2474 - val_mae: 0.2936
# Epoch 256/30000
#  - 10s - loss: 0.2184 - mse: 0.1412 - mae: 0.2184 - val_loss: 0.2946 - val_mse: 0.2495 - val_mae: 0.2946
# Epoch 257/30000
#  - 10s - loss: 0.2171 - mse: 0.1393 - mae: 0.2171 - val_loss: 0.2952 - val_mse: 0.2518 - val_mae: 0.2952
# Epoch 258/30000
#  - 10s - loss: 0.2190 - mse: 0.1436 - mae: 0.2190 - val_loss: 0.2971 - val_mse: 0.2529 - val_mae: 0.2971
# Epoch 259/30000
#  - 10s - loss: 0.2155 - mse: 0.1388 - mae: 0.2155 - val_loss: 0.2945 - val_mse: 0.2492 - val_mae: 0.2945
# Epoch 260/30000
#  - 10s - loss: 0.2204 - mse: 0.1434 - mae: 0.2204 - val_loss: 0.2907 - val_mse: 0.2444 - val_mae: 0.2907
# Epoch 261/30000
#  - 10s - loss: 0.2156 - mse: 0.1388 - mae: 0.2156 - val_loss: 0.2978 - val_mse: 0.2543 - val_mae: 0.2978
# Epoch 262/30000
#  - 9s - loss: 0.2169 - mse: 0.1378 - mae: 0.2169 - val_loss: 0.2943 - val_mse: 0.2509 - val_mae: 0.2943
# Epoch 263/30000
#  - 10s - loss: 0.2190 - mse: 0.1427 - mae: 0.2190 - val_loss: 0.2963 - val_mse: 0.2514 - val_mae: 0.2963
# Epoch 264/30000
#  - 10s - loss: 0.2139 - mse: 0.1343 - mae: 0.2139 - val_loss: 0.2975 - val_mse: 0.2542 - val_mae: 0.2975
# Epoch 265/30000
#  - 10s - loss: 0.2131 - mse: 0.1360 - mae: 0.2131 - val_loss: 0.2951 - val_mse: 0.2517 - val_mae: 0.2951
# Epoch 266/30000
#  - 10s - loss: 0.2181 - mse: 0.1421 - mae: 0.2181 - val_loss: 0.2913 - val_mse: 0.2467 - val_mae: 0.2913
# Epoch 267/30000
#  - 10s - loss: 0.2167 - mse: 0.1396 - mae: 0.2167 - val_loss: 0.2903 - val_mse: 0.2472 - val_mae: 0.2903
# Epoch 268/30000
#  - 10s - loss: 0.2156 - mse: 0.1383 - mae: 0.2156 - val_loss: 0.2954 - val_mse: 0.2495 - val_mae: 0.2954
# Epoch 269/30000
#  - 10s - loss: 0.2152 - mse: 0.1351 - mae: 0.2152 - val_loss: 0.2908 - val_mse: 0.2453 - val_mae: 0.2908
# Epoch 270/30000
#  - 9s - loss: 0.2149 - mse: 0.1387 - mae: 0.2149 - val_loss: 0.2911 - val_mse: 0.2466 - val_mae: 0.2911
# Epoch 271/30000
#  - 10s - loss: 0.2161 - mse: 0.1397 - mae: 0.2161 - val_loss: 0.2917 - val_mse: 0.2497 - val_mae: 0.2917
# Epoch 272/30000
#  - 10s - loss: 0.2156 - mse: 0.1397 - mae: 0.2156 - val_loss: 0.2908 - val_mse: 0.2433 - val_mae: 0.2908
# Epoch 273/30000
#  - 10s - loss: 0.2141 - mse: 0.1357 - mae: 0.2141 - val_loss: 0.2935 - val_mse: 0.2471 - val_mae: 0.2935
# Epoch 274/30000
#  - 9s - loss: 0.2155 - mse: 0.1382 - mae: 0.2155 - val_loss: 0.2983 - val_mse: 0.2519 - val_mae: 0.2983
# Epoch 275/30000
#  - 10s - loss: 0.2129 - mse: 0.1332 - mae: 0.2129 - val_loss: 0.3079 - val_mse: 0.2649 - val_mae: 0.3079
# Epoch 276/30000
#  - 10s - loss: 0.2138 - mse: 0.1346 - mae: 0.2138 - val_loss: 0.2935 - val_mse: 0.2501 - val_mae: 0.2935
# Epoch 277/30000
#  - 10s - loss: 0.2144 - mse: 0.1365 - mae: 0.2144 - val_loss: 0.2975 - val_mse: 0.2519 - val_mae: 0.2975
# Epoch 278/30000
#  - 10s - loss: 0.2124 - mse: 0.1345 - mae: 0.2124 - val_loss: 0.2994 - val_mse: 0.2544 - val_mae: 0.2994
# Epoch 279/30000
#  - 10s - loss: 0.2117 - mse: 0.1345 - mae: 0.2117 - val_loss: 0.2953 - val_mse: 0.2498 - val_mae: 0.2953
# Epoch 280/30000
#  - 10s - loss: 0.2148 - mse: 0.1365 - mae: 0.2148 - val_loss: 0.2887 - val_mse: 0.2412 - val_mae: 0.2887
# Epoch 281/30000
#  - 9s - loss: 0.2137 - mse: 0.1363 - mae: 0.2137 - val_loss: 0.2922 - val_mse: 0.2454 - val_mae: 0.2922
# Epoch 282/30000
#  - 10s - loss: 0.2130 - mse: 0.1351 - mae: 0.2130 - val_loss: 0.2933 - val_mse: 0.2470 - val_mae: 0.2933
# Epoch 283/30000
#  - 9s - loss: 0.2122 - mse: 0.1357 - mae: 0.2122 - val_loss: 0.2994 - val_mse: 0.2531 - val_mae: 0.2994
# Epoch 284/30000
#  - 10s - loss: 0.2113 - mse: 0.1315 - mae: 0.2113 - val_loss: 0.2965 - val_mse: 0.2500 - val_mae: 0.2965
# Epoch 285/30000
#  - 10s - loss: 0.2154 - mse: 0.1385 - mae: 0.2154 - val_loss: 0.2965 - val_mse: 0.2492 - val_mae: 0.2965
# Epoch 286/30000
#  - 10s - loss: 0.2159 - mse: 0.1375 - mae: 0.2159 - val_loss: 0.2881 - val_mse: 0.2406 - val_mae: 0.2881
# Epoch 287/30000
#  - 10s - loss: 0.2129 - mse: 0.1348 - mae: 0.2129 - val_loss: 0.2907 - val_mse: 0.2437 - val_mae: 0.2907
# Epoch 288/30000
#  - 10s - loss: 0.2125 - mse: 0.1342 - mae: 0.2125 - val_loss: 0.2957 - val_mse: 0.2451 - val_mae: 0.2957
# Epoch 289/30000
#  - 10s - loss: 0.2133 - mse: 0.1333 - mae: 0.2133 - val_loss: 0.2896 - val_mse: 0.2407 - val_mae: 0.2896
# Epoch 290/30000
#  - 10s - loss: 0.2126 - mse: 0.1322 - mae: 0.2126 - val_loss: 0.2889 - val_mse: 0.2431 - val_mae: 0.2889
# Epoch 291/30000
#  - 10s - loss: 0.2128 - mse: 0.1335 - mae: 0.2128 - val_loss: 0.3007 - val_mse: 0.2526 - val_mae: 0.3007
# Epoch 292/30000
#  - 10s - loss: 0.2118 - mse: 0.1354 - mae: 0.2118 - val_loss: 0.2922 - val_mse: 0.2461 - val_mae: 0.2922
# Epoch 293/30000
#  - 10s - loss: 0.2107 - mse: 0.1287 - mae: 0.2107 - val_loss: 0.2974 - val_mse: 0.2489 - val_mae: 0.2974
# Epoch 294/30000
#  - 10s - loss: 0.2109 - mse: 0.1303 - mae: 0.2109 - val_loss: 0.2966 - val_mse: 0.2491 - val_mae: 0.2966
# Epoch 295/30000
#  - 10s - loss: 0.2110 - mse: 0.1297 - mae: 0.2110 - val_loss: 0.2935 - val_mse: 0.2477 - val_mae: 0.2935
# Epoch 296/30000
#  - 10s - loss: 0.2121 - mse: 0.1326 - mae: 0.2121 - val_loss: 0.2954 - val_mse: 0.2499 - val_mae: 0.2954
# Epoch 297/30000
#  - 10s - loss: 0.2145 - mse: 0.1337 - mae: 0.2145 - val_loss: 0.2892 - val_mse: 0.2373 - val_mae: 0.2892
# Epoch 298/30000
#  - 10s - loss: 0.2100 - mse: 0.1306 - mae: 0.2100 - val_loss: 0.2935 - val_mse: 0.2450 - val_mae: 0.2935
# Epoch 299/30000
#  - 10s - loss: 0.2107 - mse: 0.1309 - mae: 0.2107 - val_loss: 0.2920 - val_mse: 0.2441 - val_mae: 0.2920
# Epoch 300/30000
#  - 10s - loss: 0.2092 - mse: 0.1302 - mae: 0.2092 - val_loss: 0.2969 - val_mse: 0.2488 - val_mae: 0.2969
# Epoch 301/30000
#  - 10s - loss: 0.2104 - mse: 0.1309 - mae: 0.2104 - val_loss: 0.2947 - val_mse: 0.2452 - val_mae: 0.2947
# Epoch 302/30000
#  - 10s - loss: 0.2112 - mse: 0.1328 - mae: 0.2112 - val_loss: 0.2935 - val_mse: 0.2479 - val_mae: 0.2935
# Epoch 303/30000
#  - 10s - loss: 0.2078 - mse: 0.1265 - mae: 0.2078 - val_loss: 0.2904 - val_mse: 0.2439 - val_mae: 0.2904
# Epoch 304/30000
#  - 10s - loss: 0.2090 - mse: 0.1267 - mae: 0.2090 - val_loss: 0.2902 - val_mse: 0.2426 - val_mae: 0.2902
# Epoch 305/30000
#  - 10s - loss: 0.2094 - mse: 0.1273 - mae: 0.2094 - val_loss: 0.2920 - val_mse: 0.2452 - val_mae: 0.2920
# Epoch 306/30000
#  - 9s - loss: 0.2115 - mse: 0.1313 - mae: 0.2115 - val_loss: 0.2958 - val_mse: 0.2494 - val_mae: 0.2958
# Epoch 307/30000
#  - 9s - loss: 0.2078 - mse: 0.1272 - mae: 0.2078 - val_loss: 0.2951 - val_mse: 0.2452 - val_mae: 0.2951
# Epoch 308/30000
#  - 10s - loss: 0.2084 - mse: 0.1254 - mae: 0.2084 - val_loss: 0.2921 - val_mse: 0.2438 - val_mae: 0.2921
# Epoch 309/30000
#  - 10s - loss: 0.2093 - mse: 0.1304 - mae: 0.2093 - val_loss: 0.2957 - val_mse: 0.2487 - val_mae: 0.2957
# Epoch 310/30000
#  - 10s - loss: 0.2088 - mse: 0.1286 - mae: 0.2088 - val_loss: 0.2921 - val_mse: 0.2421 - val_mae: 0.2921
# Epoch 311/30000
#  - 10s - loss: 0.2064 - mse: 0.1256 - mae: 0.2064 - val_loss: 0.2940 - val_mse: 0.2473 - val_mae: 0.2940
# Epoch 312/30000
#  - 9s - loss: 0.2079 - mse: 0.1251 - mae: 0.2079 - val_loss: 0.2953 - val_mse: 0.2472 - val_mae: 0.2953
# Epoch 313/30000
#  - 10s - loss: 0.2117 - mse: 0.1305 - mae: 0.2117 - val_loss: 0.2897 - val_mse: 0.2414 - val_mae: 0.2897
# Epoch 314/30000
#  - 10s - loss: 0.2082 - mse: 0.1273 - mae: 0.2082 - val_loss: 0.3012 - val_mse: 0.2505 - val_mae: 0.3012
# Epoch 315/30000
#  - 10s - loss: 0.2074 - mse: 0.1246 - mae: 0.2074 - val_loss: 0.2959 - val_mse: 0.2491 - val_mae: 0.2959
# Epoch 316/30000
#  - 10s - loss: 0.2067 - mse: 0.1267 - mae: 0.2067 - val_loss: 0.2925 - val_mse: 0.2457 - val_mae: 0.2925
# Epoch 317/30000
#  - 10s - loss: 0.2074 - mse: 0.1287 - mae: 0.2074 - val_loss: 0.2907 - val_mse: 0.2397 - val_mae: 0.2907
# Epoch 318/30000
#  - 10s - loss: 0.2074 - mse: 0.1241 - mae: 0.2074 - val_loss: 0.2920 - val_mse: 0.2419 - val_mae: 0.2920
# Epoch 319/30000
#  - 10s - loss: 0.2081 - mse: 0.1269 - mae: 0.2081 - val_loss: 0.2914 - val_mse: 0.2435 - val_mae: 0.2914
# Epoch 320/30000
#  - 10s - loss: 0.2088 - mse: 0.1285 - mae: 0.2088 - val_loss: 0.2992 - val_mse: 0.2495 - val_mae: 0.2992
# Epoch 321/30000
#  - 10s - loss: 0.2081 - mse: 0.1258 - mae: 0.2081 - val_loss: 0.2915 - val_mse: 0.2410 - val_mae: 0.2915
# Epoch 322/30000
#  - 10s - loss: 0.2057 - mse: 0.1253 - mae: 0.2057 - val_loss: 0.2968 - val_mse: 0.2496 - val_mae: 0.2968
# Epoch 323/30000
#  - 9s - loss: 0.2061 - mse: 0.1241 - mae: 0.2061 - val_loss: 0.2905 - val_mse: 0.2419 - val_mae: 0.2905
# Epoch 324/30000
#  - 10s - loss: 0.2068 - mse: 0.1244 - mae: 0.2068 - val_loss: 0.2961 - val_mse: 0.2467 - val_mae: 0.2961
# Epoch 325/30000
#  - 10s - loss: 0.2048 - mse: 0.1239 - mae: 0.2048 - val_loss: 0.2963 - val_mse: 0.2468 - val_mae: 0.2963
# Epoch 326/30000
#  - 10s - loss: 0.2065 - mse: 0.1254 - mae: 0.2065 - val_loss: 0.2982 - val_mse: 0.2487 - val_mae: 0.2982
# Epoch 327/30000
#  - 10s - loss: 0.2071 - mse: 0.1262 - mae: 0.2071 - val_loss: 0.2882 - val_mse: 0.2394 - val_mae: 0.2882
# Epoch 328/30000
#  - 10s - loss: 0.2057 - mse: 0.1245 - mae: 0.2057 - val_loss: 0.3022 - val_mse: 0.2501 - val_mae: 0.3022
# Epoch 329/30000
#  - 10s - loss: 0.2044 - mse: 0.1235 - mae: 0.2044 - val_loss: 0.3049 - val_mse: 0.2532 - val_mae: 0.3049
# Epoch 330/30000
#  - 10s - loss: 0.2071 - mse: 0.1262 - mae: 0.2071 - val_loss: 0.2907 - val_mse: 0.2411 - val_mae: 0.2907
# Epoch 331/30000
#  - 10s - loss: 0.2061 - mse: 0.1239 - mae: 0.2061 - val_loss: 0.2890 - val_mse: 0.2397 - val_mae: 0.2890
# Epoch 332/30000
#  - 9s - loss: 0.2054 - mse: 0.1231 - mae: 0.2054 - val_loss: 0.2970 - val_mse: 0.2487 - val_mae: 0.2970
# Epoch 333/30000
#  - 10s - loss: 0.2063 - mse: 0.1236 - mae: 0.2063 - val_loss: 0.2936 - val_mse: 0.2436 - val_mae: 0.2936
# Epoch 334/30000
#  - 10s - loss: 0.2059 - mse: 0.1238 - mae: 0.2059 - val_loss: 0.2889 - val_mse: 0.2402 - val_mae: 0.2889
# Epoch 335/30000
#  - 10s - loss: 0.2059 - mse: 0.1221 - mae: 0.2059 - val_loss: 0.2921 - val_mse: 0.2415 - val_mae: 0.2921
# Epoch 336/30000
#  - 10s - loss: 0.2061 - mse: 0.1240 - mae: 0.2061 - val_loss: 0.2856 - val_mse: 0.2338 - val_mae: 0.2856
# Epoch 337/30000
#  - 10s - loss: 0.2052 - mse: 0.1233 - mae: 0.2052 - val_loss: 0.3017 - val_mse: 0.2497 - val_mae: 0.3017
# Epoch 338/30000
#  - 9s - loss: 0.2039 - mse: 0.1213 - mae: 0.2039 - val_loss: 0.2952 - val_mse: 0.2402 - val_mae: 0.2952
# Epoch 339/30000
#  - 10s - loss: 0.2055 - mse: 0.1231 - mae: 0.2055 - val_loss: 0.2873 - val_mse: 0.2374 - val_mae: 0.2873
# Epoch 340/30000
#  - 10s - loss: 0.2026 - mse: 0.1199 - mae: 0.2026 - val_loss: 0.2984 - val_mse: 0.2466 - val_mae: 0.2984
# Epoch 341/30000
#  - 10s - loss: 0.1996 - mse: 0.1156 - mae: 0.1996 - val_loss: 0.2866 - val_mse: 0.2356 - val_mae: 0.2866
# Epoch 342/30000
#  - 10s - loss: 0.2046 - mse: 0.1221 - mae: 0.2046 - val_loss: 0.3010 - val_mse: 0.2496 - val_mae: 0.3010
# Epoch 343/30000
#  - 10s - loss: 0.2075 - mse: 0.1268 - mae: 0.2075 - val_loss: 0.2871 - val_mse: 0.2363 - val_mae: 0.2871
# Epoch 344/30000
#  - 10s - loss: 0.2043 - mse: 0.1203 - mae: 0.2043 - val_loss: 0.2906 - val_mse: 0.2407 - val_mae: 0.2906
# Epoch 345/30000
#  - 10s - loss: 0.2028 - mse: 0.1186 - mae: 0.2028 - val_loss: 0.2894 - val_mse: 0.2405 - val_mae: 0.2894
# Epoch 346/30000
#  - 10s - loss: 0.2030 - mse: 0.1187 - mae: 0.2030 - val_loss: 0.2921 - val_mse: 0.2407 - val_mae: 0.2921
# Epoch 347/30000
#  - 10s - loss: 0.2016 - mse: 0.1195 - mae: 0.2016 - val_loss: 0.2873 - val_mse: 0.2384 - val_mae: 0.2873
# Epoch 348/30000
#  - 10s - loss: 0.2024 - mse: 0.1175 - mae: 0.2024 - val_loss: 0.2867 - val_mse: 0.2381 - val_mae: 0.2867
# Epoch 349/30000
#  - 9s - loss: 0.2026 - mse: 0.1169 - mae: 0.2026 - val_loss: 0.2925 - val_mse: 0.2403 - val_mae: 0.2925
# Epoch 350/30000
#  - 10s - loss: 0.2038 - mse: 0.1207 - mae: 0.2038 - val_loss: 0.2920 - val_mse: 0.2391 - val_mae: 0.2920
# Epoch 351/30000
#  - 10s - loss: 0.2033 - mse: 0.1181 - mae: 0.2033 - val_loss: 0.2894 - val_mse: 0.2387 - val_mae: 0.2894
# Epoch 352/30000
#  - 10s - loss: 0.2017 - mse: 0.1187 - mae: 0.2017 - val_loss: 0.2955 - val_mse: 0.2456 - val_mae: 0.2955
# Epoch 353/30000
#  - 10s - loss: 0.2015 - mse: 0.1190 - mae: 0.2015 - val_loss: 0.2900 - val_mse: 0.2363 - val_mae: 0.2900
# Epoch 354/30000
#  - 10s - loss: 0.2013 - mse: 0.1176 - mae: 0.2013 - val_loss: 0.2948 - val_mse: 0.2430 - val_mae: 0.2948
# Epoch 355/30000
#  - 10s - loss: 0.2035 - mse: 0.1210 - mae: 0.2035 - val_loss: 0.2953 - val_mse: 0.2424 - val_mae: 0.2953
# Epoch 356/30000
#  - 10s - loss: 0.2011 - mse: 0.1186 - mae: 0.2011 - val_loss: 0.2956 - val_mse: 0.2439 - val_mae: 0.2956
# Epoch 357/30000
#  - 10s - loss: 0.2014 - mse: 0.1155 - mae: 0.2014 - val_loss: 0.2886 - val_mse: 0.2339 - val_mae: 0.2886
# Epoch 358/30000
#  - 10s - loss: 0.2016 - mse: 0.1163 - mae: 0.2016 - val_loss: 0.2923 - val_mse: 0.2382 - val_mae: 0.2923
# Epoch 359/30000
#  - 10s - loss: 0.1998 - mse: 0.1148 - mae: 0.1998 - val_loss: 0.2908 - val_mse: 0.2380 - val_mae: 0.2908
# Epoch 360/30000
#  - 10s - loss: 0.2011 - mse: 0.1172 - mae: 0.2011 - val_loss: 0.2905 - val_mse: 0.2384 - val_mae: 0.2905
# Epoch 361/30000
#  - 10s - loss: 0.1994 - mse: 0.1143 - mae: 0.1994 - val_loss: 0.2857 - val_mse: 0.2344 - val_mae: 0.2857
# Epoch 362/30000
#  - 10s - loss: 0.2024 - mse: 0.1184 - mae: 0.2024 - val_loss: 0.2838 - val_mse: 0.2333 - val_mae: 0.2838
# Epoch 363/30000
#  - 10s - loss: 0.2029 - mse: 0.1197 - mae: 0.2029 - val_loss: 0.2901 - val_mse: 0.2383 - val_mae: 0.2901
# Epoch 364/30000
#  - 10s - loss: 0.2000 - mse: 0.1167 - mae: 0.2000 - val_loss: 0.2875 - val_mse: 0.2355 - val_mae: 0.2875
# Epoch 365/30000
#  - 10s - loss: 0.1992 - mse: 0.1141 - mae: 0.1992 - val_loss: 0.2909 - val_mse: 0.2378 - val_mae: 0.2909
# Epoch 366/30000
#  - 10s - loss: 0.1986 - mse: 0.1129 - mae: 0.1986 - val_loss: 0.3008 - val_mse: 0.2473 - val_mae: 0.3008
# Epoch 367/30000
#  - 10s - loss: 0.2007 - mse: 0.1167 - mae: 0.2007 - val_loss: 0.2828 - val_mse: 0.2301 - val_mae: 0.2828
# Epoch 368/30000
#  - 10s - loss: 0.1975 - mse: 0.1132 - mae: 0.1975 - val_loss: 0.2913 - val_mse: 0.2387 - val_mae: 0.2913
# Epoch 369/30000
#  - 10s - loss: 0.2019 - mse: 0.1180 - mae: 0.2019 - val_loss: 0.2908 - val_mse: 0.2392 - val_mae: 0.2908
# Epoch 370/30000
#  - 10s - loss: 0.2003 - mse: 0.1163 - mae: 0.2003 - val_loss: 0.2936 - val_mse: 0.2411 - val_mae: 0.2936
# Epoch 371/30000
#  - 10s - loss: 0.2006 - mse: 0.1158 - mae: 0.2006 - val_loss: 0.2895 - val_mse: 0.2387 - val_mae: 0.2895
# Epoch 372/30000
#  - 10s - loss: 0.1977 - mse: 0.1139 - mae: 0.1977 - val_loss: 0.2914 - val_mse: 0.2394 - val_mae: 0.2914
# Epoch 373/30000
#  - 10s - loss: 0.1986 - mse: 0.1135 - mae: 0.1986 - val_loss: 0.2949 - val_mse: 0.2448 - val_mae: 0.2949
# Epoch 374/30000
#  - 10s - loss: 0.2005 - mse: 0.1189 - mae: 0.2005 - val_loss: 0.2920 - val_mse: 0.2401 - val_mae: 0.2920
# Epoch 375/30000
#  - 10s - loss: 0.1965 - mse: 0.1119 - mae: 0.1965 - val_loss: 0.2853 - val_mse: 0.2338 - val_mae: 0.2853
# Epoch 376/30000
#  - 10s - loss: 0.2005 - mse: 0.1170 - mae: 0.2005 - val_loss: 0.2935 - val_mse: 0.2423 - val_mae: 0.2935
# Epoch 377/30000
#  - 10s - loss: 0.2004 - mse: 0.1141 - mae: 0.2004 - val_loss: 0.2934 - val_mse: 0.2416 - val_mae: 0.2934
# Epoch 378/30000
#  - 10s - loss: 0.1979 - mse: 0.1115 - mae: 0.1979 - val_loss: 0.2831 - val_mse: 0.2308 - val_mae: 0.2831
# Epoch 379/30000
#  - 9s - loss: 0.1989 - mse: 0.1154 - mae: 0.1989 - val_loss: 0.2913 - val_mse: 0.2386 - val_mae: 0.2913
# Epoch 380/30000
#  - 10s - loss: 0.1990 - mse: 0.1123 - mae: 0.1990 - val_loss: 0.2946 - val_mse: 0.2430 - val_mae: 0.2946
# Epoch 381/30000
#  - 10s - loss: 0.2019 - mse: 0.1170 - mae: 0.2019 - val_loss: 0.2864 - val_mse: 0.2358 - val_mae: 0.2864
# Epoch 382/30000
#  - 10s - loss: 0.1977 - mse: 0.1122 - mae: 0.1977 - val_loss: 0.2847 - val_mse: 0.2323 - val_mae: 0.2847
# Epoch 383/30000
#  - 10s - loss: 0.1977 - mse: 0.1109 - mae: 0.1977 - val_loss: 0.2839 - val_mse: 0.2320 - val_mae: 0.2839
# Epoch 384/30000
#  - 9s - loss: 0.1996 - mse: 0.1128 - mae: 0.1996 - val_loss: 0.2934 - val_mse: 0.2404 - val_mae: 0.2934
# Epoch 385/30000
#  - 10s - loss: 0.1978 - mse: 0.1132 - mae: 0.1978 - val_loss: 0.2904 - val_mse: 0.2371 - val_mae: 0.2904
# Epoch 386/30000
#  - 10s - loss: 0.1989 - mse: 0.1132 - mae: 0.1989 - val_loss: 0.2840 - val_mse: 0.2311 - val_mae: 0.2840
# Epoch 387/30000
#  - 10s - loss: 0.1990 - mse: 0.1137 - mae: 0.1990 - val_loss: 0.2838 - val_mse: 0.2316 - val_mae: 0.2838
# Epoch 388/30000
#  - 10s - loss: 0.1975 - mse: 0.1119 - mae: 0.1975 - val_loss: 0.2918 - val_mse: 0.2378 - val_mae: 0.2918
# Epoch 389/30000
#  - 10s - loss: 0.1985 - mse: 0.1129 - mae: 0.1985 - val_loss: 0.2889 - val_mse: 0.2353 - val_mae: 0.2889
# Epoch 390/30000
#  - 10s - loss: 0.1977 - mse: 0.1134 - mae: 0.1977 - val_loss: 0.2898 - val_mse: 0.2374 - val_mae: 0.2898
# Epoch 391/30000
#  - 10s - loss: 0.1976 - mse: 0.1120 - mae: 0.1976 - val_loss: 0.2930 - val_mse: 0.2409 - val_mae: 0.2930
# Epoch 392/30000
#  - 10s - loss: 0.1958 - mse: 0.1112 - mae: 0.1958 - val_loss: 0.2955 - val_mse: 0.2421 - val_mae: 0.2955
# Epoch 393/30000
#  - 10s - loss: 0.1985 - mse: 0.1129 - mae: 0.1985 - val_loss: 0.2809 - val_mse: 0.2287 - val_mae: 0.2809
# Epoch 394/30000
#  - 10s - loss: 0.1978 - mse: 0.1124 - mae: 0.1978 - val_loss: 0.2909 - val_mse: 0.2394 - val_mae: 0.2909
# Epoch 395/30000
#  - 10s - loss: 0.1970 - mse: 0.1116 - mae: 0.1970 - val_loss: 0.2944 - val_mse: 0.2417 - val_mae: 0.2944
# Epoch 396/30000
#  - 9s - loss: 0.1953 - mse: 0.1121 - mae: 0.1953 - val_loss: 0.2866 - val_mse: 0.2340 - val_mae: 0.2866
# Epoch 397/30000
#  - 10s - loss: 0.1959 - mse: 0.1086 - mae: 0.1959 - val_loss: 0.2894 - val_mse: 0.2369 - val_mae: 0.2894
# Epoch 398/30000
#  - 10s - loss: 0.1927 - mse: 0.1049 - mae: 0.1927 - val_loss: 0.2941 - val_mse: 0.2407 - val_mae: 0.2941
# Epoch 399/30000
#  - 10s - loss: 0.1974 - mse: 0.1085 - mae: 0.1974 - val_loss: 0.2867 - val_mse: 0.2364 - val_mae: 0.2867
# Epoch 400/30000
#  - 10s - loss: 0.1952 - mse: 0.1081 - mae: 0.1952 - val_loss: 0.2942 - val_mse: 0.2395 - val_mae: 0.2942
# Epoch 401/30000
#  - 9s - loss: 0.1965 - mse: 0.1118 - mae: 0.1965 - val_loss: 0.2923 - val_mse: 0.2385 - val_mae: 0.2923
# Epoch 402/30000
#  - 10s - loss: 0.1937 - mse: 0.1086 - mae: 0.1937 - val_loss: 0.2864 - val_mse: 0.2352 - val_mae: 0.2864
# Epoch 403/30000
#  - 10s - loss: 0.1969 - mse: 0.1114 - mae: 0.1969 - val_loss: 0.2925 - val_mse: 0.2410 - val_mae: 0.2925
# Epoch 404/30000
#  - 10s - loss: 0.1952 - mse: 0.1081 - mae: 0.1952 - val_loss: 0.2861 - val_mse: 0.2341 - val_mae: 0.2861
# Epoch 405/30000
#  - 10s - loss: 0.1960 - mse: 0.1096 - mae: 0.1960 - val_loss: 0.2849 - val_mse: 0.2316 - val_mae: 0.2849
# Epoch 406/30000
#  - 10s - loss: 0.1978 - mse: 0.1113 - mae: 0.1978 - val_loss: 0.2834 - val_mse: 0.2288 - val_mae: 0.2834
# Epoch 407/30000
#  - 9s - loss: 0.1954 - mse: 0.1084 - mae: 0.1954 - val_loss: 0.2942 - val_mse: 0.2414 - val_mae: 0.2942
# Epoch 408/30000
#  - 9s - loss: 0.1963 - mse: 0.1105 - mae: 0.1963 - val_loss: 0.2887 - val_mse: 0.2349 - val_mae: 0.2887
# Epoch 409/30000
#  - 10s - loss: 0.1960 - mse: 0.1102 - mae: 0.1960 - val_loss: 0.2909 - val_mse: 0.2363 - val_mae: 0.2909
# Epoch 410/30000
#  - 10s - loss: 0.1962 - mse: 0.1106 - mae: 0.1962 - val_loss: 0.2889 - val_mse: 0.2362 - val_mae: 0.2889
# Epoch 411/30000
#  - 9s - loss: 0.1958 - mse: 0.1075 - mae: 0.1958 - val_loss: 0.2864 - val_mse: 0.2330 - val_mae: 0.2864
# Epoch 412/30000
#  - 9s - loss: 0.1956 - mse: 0.1110 - mae: 0.1956 - val_loss: 0.2829 - val_mse: 0.2288 - val_mae: 0.2829
# Epoch 413/30000
#  - 10s - loss: 0.1987 - mse: 0.1135 - mae: 0.1987 - val_loss: 0.2878 - val_mse: 0.2356 - val_mae: 0.2878
# Epoch 414/30000
#  - 10s - loss: 0.1966 - mse: 0.1112 - mae: 0.1966 - val_loss: 0.2864 - val_mse: 0.2338 - val_mae: 0.2864
# Epoch 415/30000
#  - 10s - loss: 0.1958 - mse: 0.1087 - mae: 0.1958 - val_loss: 0.2845 - val_mse: 0.2307 - val_mae: 0.2845
# Epoch 416/30000
#  - 9s - loss: 0.1960 - mse: 0.1109 - mae: 0.1960 - val_loss: 0.2852 - val_mse: 0.2331 - val_mae: 0.2852
# Epoch 417/30000
#  - 10s - loss: 0.1927 - mse: 0.1063 - mae: 0.1927 - val_loss: 0.2802 - val_mse: 0.2297 - val_mae: 0.2802
# Epoch 418/30000
#  - 10s - loss: 0.1956 - mse: 0.1096 - mae: 0.1956 - val_loss: 0.2871 - val_mse: 0.2349 - val_mae: 0.2871
# Epoch 419/30000
#  - 10s - loss: 0.1961 - mse: 0.1103 - mae: 0.1961 - val_loss: 0.2909 - val_mse: 0.2403 - val_mae: 0.2909
# Epoch 420/30000
#  - 10s - loss: 0.1956 - mse: 0.1099 - mae: 0.1956 - val_loss: 0.2819 - val_mse: 0.2301 - val_mae: 0.2819
# Epoch 421/30000
#  - 10s - loss: 0.1953 - mse: 0.1080 - mae: 0.1953 - val_loss: 0.2911 - val_mse: 0.2376 - val_mae: 0.2911
# Epoch 422/30000
#  - 10s - loss: 0.1939 - mse: 0.1053 - mae: 0.1939 - val_loss: 0.2861 - val_mse: 0.2340 - val_mae: 0.2861
# Epoch 423/30000
#  - 10s - loss: 0.1931 - mse: 0.1051 - mae: 0.1931 - val_loss: 0.2942 - val_mse: 0.2412 - val_mae: 0.2942
# Epoch 424/30000
#  - 10s - loss: 0.1956 - mse: 0.1093 - mae: 0.1956 - val_loss: 0.2907 - val_mse: 0.2400 - val_mae: 0.2907
# Epoch 425/30000
#  - 10s - loss: 0.1944 - mse: 0.1091 - mae: 0.1944 - val_loss: 0.2877 - val_mse: 0.2342 - val_mae: 0.2877
# Epoch 426/30000
#  - 10s - loss: 0.1943 - mse: 0.1080 - mae: 0.1943 - val_loss: 0.2921 - val_mse: 0.2371 - val_mae: 0.2921
# Epoch 427/30000
#  - 10s - loss: 0.1933 - mse: 0.1064 - mae: 0.1933 - val_loss: 0.2949 - val_mse: 0.2427 - val_mae: 0.2949
# Epoch 428/30000
#  - 10s - loss: 0.1931 - mse: 0.1055 - mae: 0.1931 - val_loss: 0.2858 - val_mse: 0.2316 - val_mae: 0.2858
# Epoch 429/30000
#  - 10s - loss: 0.1939 - mse: 0.1074 - mae: 0.1939 - val_loss: 0.2889 - val_mse: 0.2345 - val_mae: 0.2889
# Epoch 430/30000
#  - 10s - loss: 0.1929 - mse: 0.1080 - mae: 0.1929 - val_loss: 0.2897 - val_mse: 0.2360 - val_mae: 0.2897
# Epoch 431/30000
#  - 10s - loss: 0.1938 - mse: 0.1059 - mae: 0.1938 - val_loss: 0.2839 - val_mse: 0.2312 - val_mae: 0.2839
# Epoch 432/30000
#  - 10s - loss: 0.1918 - mse: 0.1053 - mae: 0.1918 - val_loss: 0.2885 - val_mse: 0.2329 - val_mae: 0.2885
# Epoch 433/30000
#  - 10s - loss: 0.1956 - mse: 0.1088 - mae: 0.1956 - val_loss: 0.2871 - val_mse: 0.2318 - val_mae: 0.2871
# Epoch 434/30000
#  - 10s - loss: 0.1931 - mse: 0.1041 - mae: 0.1931 - val_loss: 0.2834 - val_mse: 0.2315 - val_mae: 0.2834
# Epoch 435/30000
#  - 10s - loss: 0.1952 - mse: 0.1075 - mae: 0.1952 - val_loss: 0.2950 - val_mse: 0.2400 - val_mae: 0.2950
# Epoch 436/30000
#  - 10s - loss: 0.1909 - mse: 0.1056 - mae: 0.1909 - val_loss: 0.2844 - val_mse: 0.2307 - val_mae: 0.2844
# Epoch 437/30000
#  - 10s - loss: 0.1922 - mse: 0.1033 - mae: 0.1922 - val_loss: 0.2884 - val_mse: 0.2360 - val_mae: 0.2884
# Epoch 438/30000
#  - 10s - loss: 0.1920 - mse: 0.1047 - mae: 0.1920 - val_loss: 0.2869 - val_mse: 0.2353 - val_mae: 0.2869
# Epoch 439/30000
#  - 10s - loss: 0.1905 - mse: 0.1027 - mae: 0.1905 - val_loss: 0.2861 - val_mse: 0.2334 - val_mae: 0.2861
# Epoch 440/30000
#  - 10s - loss: 0.1912 - mse: 0.1058 - mae: 0.1912 - val_loss: 0.2854 - val_mse: 0.2308 - val_mae: 0.2854
# Epoch 441/30000
#  - 10s - loss: 0.1917 - mse: 0.1042 - mae: 0.1917 - val_loss: 0.2952 - val_mse: 0.2399 - val_mae: 0.2952
# Epoch 442/30000
#  - 9s - loss: 0.1913 - mse: 0.1036 - mae: 0.1913 - val_loss: 0.2957 - val_mse: 0.2397 - val_mae: 0.2957
# Epoch 443/30000
#  - 10s - loss: 0.1928 - mse: 0.1041 - mae: 0.1928 - val_loss: 0.2827 - val_mse: 0.2281 - val_mae: 0.2827
# Epoch 444/30000
#  - 9s - loss: 0.1915 - mse: 0.1036 - mae: 0.1915 - val_loss: 0.2835 - val_mse: 0.2315 - val_mae: 0.2835
# Epoch 445/30000
#  - 9s - loss: 0.1921 - mse: 0.1043 - mae: 0.1921 - val_loss: 0.2881 - val_mse: 0.2344 - val_mae: 0.2881
# Epoch 446/30000
#  - 10s - loss: 0.1890 - mse: 0.1015 - mae: 0.1890 - val_loss: 0.2904 - val_mse: 0.2365 - val_mae: 0.2904
# Epoch 447/30000
#  - 10s - loss: 0.1928 - mse: 0.1048 - mae: 0.1928 - val_loss: 0.2913 - val_mse: 0.2375 - val_mae: 0.2913
# Epoch 448/30000
#  - 10s - loss: 0.1900 - mse: 0.1016 - mae: 0.1900 - val_loss: 0.2873 - val_mse: 0.2340 - val_mae: 0.2873
# Epoch 449/30000
#  - 10s - loss: 0.1913 - mse: 0.1034 - mae: 0.1913 - val_loss: 0.2826 - val_mse: 0.2302 - val_mae: 0.2826
# Epoch 450/30000
#  - 10s - loss: 0.1928 - mse: 0.1050 - mae: 0.1928 - val_loss: 0.2927 - val_mse: 0.2383 - val_mae: 0.2927
# Epoch 451/30000
#  - 10s - loss: 0.1912 - mse: 0.1031 - mae: 0.1912 - val_loss: 0.2886 - val_mse: 0.2340 - val_mae: 0.2886
# Epoch 452/30000
#  - 9s - loss: 0.1920 - mse: 0.1049 - mae: 0.1920 - val_loss: 0.2851 - val_mse: 0.2337 - val_mae: 0.2851
# Epoch 453/30000
#  - 10s - loss: 0.1897 - mse: 0.1010 - mae: 0.1897 - val_loss: 0.2842 - val_mse: 0.2318 - val_mae: 0.2842
# Epoch 454/30000
#  - 10s - loss: 0.1912 - mse: 0.1038 - mae: 0.1912 - val_loss: 0.2899 - val_mse: 0.2353 - val_mae: 0.2899
# Epoch 455/30000
#  - 10s - loss: 0.1924 - mse: 0.1051 - mae: 0.1924 - val_loss: 0.2880 - val_mse: 0.2335 - val_mae: 0.2880
# Epoch 456/30000
#  - 10s - loss: 0.1896 - mse: 0.1016 - mae: 0.1896 - val_loss: 0.2842 - val_mse: 0.2306 - val_mae: 0.2842
# Epoch 457/30000
#  - 9s - loss: 0.1902 - mse: 0.1011 - mae: 0.1902 - val_loss: 0.2935 - val_mse: 0.2410 - val_mae: 0.2935
# Epoch 458/30000
#  - 10s - loss: 0.1917 - mse: 0.1021 - mae: 0.1917 - val_loss: 0.2955 - val_mse: 0.2419 - val_mae: 0.2955
# Epoch 459/30000
#  - 10s - loss: 0.1942 - mse: 0.1077 - mae: 0.1942 - val_loss: 0.2954 - val_mse: 0.2428 - val_mae: 0.2954
# Epoch 460/30000
#  - 10s - loss: 0.1903 - mse: 0.1015 - mae: 0.1903 - val_loss: 0.2889 - val_mse: 0.2341 - val_mae: 0.2889
# Epoch 461/30000
#  - 10s - loss: 0.1926 - mse: 0.1036 - mae: 0.1926 - val_loss: 0.2907 - val_mse: 0.2381 - val_mae: 0.2907
# Epoch 462/30000
#  - 10s - loss: 0.1933 - mse: 0.1043 - mae: 0.1933 - val_loss: 0.2928 - val_mse: 0.2389 - val_mae: 0.2928
# Epoch 463/30000
#  - 10s - loss: 0.1905 - mse: 0.0999 - mae: 0.1905 - val_loss: 0.2861 - val_mse: 0.2338 - val_mae: 0.2861
# Epoch 464/30000
#  - 10s - loss: 0.1894 - mse: 0.1000 - mae: 0.1894 - val_loss: 0.2882 - val_mse: 0.2338 - val_mae: 0.2882
# Epoch 465/30000
#  - 10s - loss: 0.1885 - mse: 0.0997 - mae: 0.1885 - val_loss: 0.2929 - val_mse: 0.2385 - val_mae: 0.2929
# Epoch 466/30000
#  - 9s - loss: 0.1890 - mse: 0.0999 - mae: 0.1890 - val_loss: 0.2857 - val_mse: 0.2330 - val_mae: 0.2857
# Epoch 467/30000
#  - 10s - loss: 0.1895 - mse: 0.0993 - mae: 0.1895 - val_loss: 0.2866 - val_mse: 0.2349 - val_mae: 0.2866

# %%
def plot_loss(history):
    
    v1 = history.history['mae']*np.sqrt(sc_y.var_)
    v2 = history.history['val_mae']*np.sqrt(sc_y.var_)
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    ax1.plot(v1, label='mae')
    ax1.plot(v2, label='val_mae')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Error [deg]')
    ax1.legend()
    ax1.grid(True)
    plt.show()
    
    v3 = history.history['mse']*sc_y.var_
    v4 = history.history['val_mse']*sc_y.var_
    fig2 = plt.figure()
    ax2 = fig2.add_subplot(111)
    ax2.plot(v3, label='mse')
    ax2.plot(v4, label='val_mse')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Error [deg^2]')
    ax2.legend()
    ax2.grid(True)
    plt.show()
    
    
plot_loss(history)

# %% [markdown]
# ### 4-layer Network: Predict Against Training Data as a Sanity Check

# %%
# sanity check with 80% data
Xtrain = Trainset
y_pred = model.predict(Xtrain)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Trainy
plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Training Set (Sanity Check)')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()
# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Training Set (Sanity Check)')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Training Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle of Training Set')
plt.show()
# Out:
# Average error is -0.09 degrees
# Root Mean Squared Error is 1.44 degrees
# Mean Absolute Error is 1.44 degrees

# %% [markdown]
# ### 4-layer Neural Network: Predict Test Set

# %%
# Redo test set
Xtest = Testset
y_pred = model.predict(Xtest)
#y_pred = sc_y.inverse_transform(y_pred)
y_pred = sc_y.inverse_transform(y_pred)
y_new = Testy

plt.figure(figsize=(20,6))
plt.plot(y_new,'k')
plt.plot(y_pred,'r--')
plt.title('Prediction of Test')
#plt.axis([xmin, xmax, ymin, ymax])
plt.legend(labels=['Ground Truth','Prediction'])
plt.show()

# Squared-root of Squared Error

test_error = (y_pred - y_new)
print('Average error is {:4.2f} degrees'.format(np.sum(test_error)/test_error.shape[0]))
rmse = np.sqrt(test_error**2)
print('Root Mean Squared Error is {:4.2f} degrees'.format(np.sum(rmse)/test_error.shape[0]))
# Mean absolute error
print('Mean Absolute Error is {:4.2f} degrees'.format(np.sum(np.abs(test_error))/test_error.shape[0]))
plt.figure(figsize=(20,6))
plt.plot(rmse,'.')
plt.title('Sqrt(Squared Error) of Test Set')
plt.xlabel('Sample')
plt.ylabel('Error (degrees)')
plt.show()

plt.figure()
plt.hist(test_error,bins=100)
plt.title('Histogram of Residuals in Test Set')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.show()

#plot scatterplot of data
plt.figure(figsize=(10,5))
plt.scatter(y_pred,y_new,marker='.',color='black')
plt.xlabel('Predicted angle (degrees)')
plt.ylabel('Ground truth angle (degrees)')
plt.title('Ground truth vs predicted angle')
plt.show()
# Out:
# Average error is -0.02 degrees
# Root Mean Squared Error is 3.82 degrees
# Mean Absolute Error is 3.82 degrees

# %%
save_notebookparams = 1
if save_notebookparams:
    pkl_filename = "depthmodelparam_cnn3v10.pkl"
    randata = {}
    randata['nsamps']=nsamps
    randata['n80p']=n80p
    randata['rannums']=rannums
    randata['test_set']=test_set
    modelhistory = history.history
    
    
    with open(pkl_filename, 'wb') as file:
        pickle.dump([randata,sc_y,modelhistory], file)
        
    model.save('depthmodel_cnn3v10.h5')
